# %% [markdown]
# # Legibility

# %% [markdown]
# ## Libraries

# %%
from bs4 import BeautifulSoup
from nltk.stem import PorterStemmer
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import numpy as np
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
#Generate random integer values
from random import seed
from random import randint
import math
#Regular Expressions
import re

# %%
A = np.array([[1, 2]])
B = np.array([[5, 6]])
A
B
np.concatenate((A, B), axis = 1)
# Out:
# array([[1, 2, 5, 6]])

# %% [markdown]
# ## Functions

# %%
#Functions:
#The following function receives a string indicating the path to follow and
#and returns the data in the file.
def openFile(s):
    file = open(s)
    data_file = file.read()
    file.close()
    return data_file
#The following function receives the data from the stop word's file, splits them
#and extends them.
def cleanStop(sw):
    csw = [ts for ts in sw.split()]
    esw = ['.', ',',';',':', '/','"', '?', '!', '¡', '<', '>', 'El', '>El']
    csw.extend(esw)
    return csw
#   The following function utilizes beautiful soup to obtain the methodologies
#   and put them into
def bsMeth(s):
    # Use beautiful Soup to separate the methodologies
    with open(s) as fp:
        soup = BeautifulSoup(fp, 'xml')
    all = soup.find_all('Problema')

    counter = 1
    problem = ""
    for met in soup.find_all('Problema'):
        [s.extract() for s in met.findAll('Problema')]
        ######print("*Metodologia", counter)
        #####print(met)
        problem = problem + str(met) + "\n"
        #####print("\n")
        counter += 1
    return problem
#   The following function receives the methodologies and separates them. It
#   creates a dictionary-matrix with the following structure:
#   Methodologies-Number-Word
def sepMeth(justificacion):
    met_matrix = {}
    counter_met = 1
    for met in justificacion:
        met_vector = {}
        counter_word = 1
        met = [d for d in met.split()]
        for word in met:
            met_vector[counter_word] = word
            counter_word += 1
        if(met_vector):
            met_vector.popitem()
        met_matrix["Problema" + str(counter_met)] = met_vector
        counter_met += 1
    return met_matrix

#   The following function receives the Stop Words and the Methodologies and
#   removes the stop words from the methodologies (It basically returns the
#   methodologies clean.).
def cleanMeth(sw, meth):
    cleanMeth_matrix = {}
    for m, m_vector in meth.items():
        cleanMeth_vector = {}
        for num, word in m_vector.items():
            word = word.lower()
            word = re.sub('[^a-zñáéíóú]', '', word)
            if (word not in sw) and word:
                cleanMeth_vector[num] = word
        cleanMeth_matrix[m] = cleanMeth_vector
    return cleanMeth_matrix
#   The following function receives the clean methodologies and returns a
#   dictionary with the structure Methodologies-WordVector
def listMeth(meth):
    listMethMatrix = {}
    for m, m_vector in meth.items():
        listMethVector = []
        for num, word in m_vector.items():
            listMethVector.append(word)
        listMethMatrix[m] = listMethVector
    return listMethMatrix
#   The following function gets the frequency of each word and divides them by
#   the amount of words in the document.
def relFreq(meth):
    freqMethMatrix = {}
    for m, m_vector in meth.items():
        freqMethVector = {}
        sizeM = len(m_vector)
        freq = nltk.FreqDist(m_vector)
        for word, frequency in freq.most_common():
            if word not in freqMethVector:
#                 print('Frequency: {}, SizeM: {}'.format(frequency, sizeM))
                freqMethVector[word] = frequency/sizeM
        freqMethMatrix[m] = freqMethVector
    return freqMethMatrix
#   The following function opens the frequency for the most common words in
#   spanish and returns a dictionary with the following structure: Word-Freq
def mostCommon():
    f = open("frecuencia.txt", "r")
    mostCommonVector = {}
    for line in f:
        line = [d for d in line.split()]
        line[2] = line[2].replace(',', '')
        mostCommonVector[line[1]] = line[2]
    return mostCommonVector
#   The following function receives the dictionary with the sections and
#   returns a Dictionary-Matrix with the following form:
#   Section#-Word:LogFrequency
def logFreq(meth, common):
    logFreqMatrix = {}
    for m, methVector in meth.items():
        logFreqVector = {}
        for word in methVector:
            ####print("Word:", word)
            if (word in common):
                ####print("Word:", word)
                ####print("Value:", common[word])
                logFreqVector[word] = np.log(float(common[word]))
            else:
                logFreqVector[word] = 0.0
        logFreqMatrix[m] = logFreqVector
    return logFreqMatrix
#   The following function receives a single dictionary dictionary of specific
#   sections. It returns a vocabulary based on all the words that appear in the
#   the complete set of documents.
def obtainVocSingle(D):
    voc = []
    for s, svec in D.items():
        for word in svec:
            if word not in voc:
                voc.append(word)
    return voc
#   The following function receives two dictionaries of specific sections. It returns
#   It returns a vocabulary based on all the words that appear in the complete set of
#   documents.
def obtainVocDouble(d1, d2):
    voc = []
    for s, svec in d1.items():
        for word in svec:
            if word not in voc:
                voc.append(word)
    for s, svec in d2.items():
        for word in svec:
            if word not in voc:
                voc.append(word)
    return voc

#   The following function creates a vocabulary for all the words that appear in
#   justifications.
def obtainVoc(TSU, Lic, Maestria, Doctorado):
    vocabulary = []
    for m, mvec in TSU.items():
        for word in mvec:
            if word not in vocabulary:
                vocabulary.append(word)
    for m, mvec in Lic.items():
        for word in mvec:
            if word not in vocabulary:
                vocabulary.append(word)
    for m, mvec in Maestria.items():
        for word in mvec:
            if word not in vocabulary:
                vocabulary.append(word)
    for m, mvec in Doctorado.items():
        for word in mvec:
            if word not in vocabulary:
                vocabulary.append(word)
    return vocabulary
#   The following function creates a vocabulary for all the words that appear in
#   justifications.
def obtainVoc3(TSU, Lic, Maestria):
    vocabulary = []
    for m, mvec in TSU.items():
        for word in mvec:
            if word not in vocabulary:
                vocabulary.append(word)
    for m, mvec in Lic.items():
        for word in mvec:
            if word not in vocabulary:
                vocabulary.append(word)
    for m, mvec in Maestria.items():
        for word in mvec:
            if word not in vocabulary:
                vocabulary.append(word)
    return vocabulary
#   The following function utilizes the vocabulary to dimensionate the relative
#   frequency.
def dimRelFreq(matrix, voc):
    dimRelFreqMatrix = {}
    for j, jvec in matrix.items():
        dimRelFreqVec = {}
        for word in voc:
            if word in jvec:
                dimRelFreqVec[word] = jvec[word]
            else:
                dimRelFreqVec[word] = 0.0
        dimRelFreqMatrix[j] = dimRelFreqVec
    return dimRelFreqMatrix

#   The following function subcatenates two matrices, it subtracts one from the
#   vector from the other and return the result in the following form
#   Justification-ResultantVector
def substract(A, B):
    resultantMatrix = {}
    for (a, avec), (b, bvec) in zip(A.items(), B.items()):
        resultantVec = []
        for (wa, va), (wb, vb) in zip(avec.items(), bvec.items()):
            resultantVec.append(va-vb)
        resultantMatrix[a] = resultantVec
    return resultantMatrix
#   The following function substracts entrance by entrance two dictionary
#   vectors. It returns the result of the subtraction but in a vector, no longer
#   a dictionary.
def substractVec(A, B):
    resultantVec = []
    for (wa, va), (wb, vb) in zip(A.items(), B.items()):
        resultantVec.append(va-vb)
    return resultantVec
#   The following function receives two dictionary matrixes, and concatenates
#   their respective vectors row by row
def concatenate(A, B):
    resultantMatrix = []
    for(a, avec), (b, bvec) in zip(A.items(), B.items()):
        resultantVec = []
        resultantVec = avec + bvec
        ###print(len(resultantVec))
        resultantMatrix.append(resultantVec)
    return resultantMatrix
#   The following function receives two list-vectors and concatenates them in
#   the order A+B. It returns the concatenated vector.
def concatenateVec(A, B):
    resultantVec = A + B
    return resultantVec
#   The followign function receives two dictionary list-vector and concatenates
#   them vector-entry by vector-entry. It returns that concatenation.
def concatenateDictionaries(A, B):
    resultantMatrix = []
    for(a, avec), (b, bvec) in zip(A.items(), B.items()):
        resultantVec = []
        for (wa, va) in avec.items():
            resultantVec.append(va)
        for(wb, vb) in bvec.items():
            resultantVec.append(vb)
        resultantMatrix.append(resultantVec)
    return resultantMatrix
#   The following function receives a dictionary-dictionary and returns a
#   a dictionary-list.
def enlist(A):
    resultantMatrix = {}
    for (a, avec) in (A.items()):
        resultantVec = []
        for(w, v) in avec.items():
            resultantVec.append(v)
        resultantMatrix[a] = resultantVec
    return resultantMatrix
#   The following function receives a dictionary-vector and returns a
#   list.
def enlistVec(A):
    resultantVec = []
    for(w, v) in A.items():
        resultantVec.append(v)
    return resultantVec

#   The following function takes two matrixes A, B and returns a training matrix
#   and a classification matrix. The training matrix contains all the related
#   vectors in a single matrix.
def training(A, B):
    trainingMatrix = []
    classMatrix = []
    for av in A:
        trainingMatrix.append(av)
        classMatrix.append(-1.0)
    for bv in B:
        trainingMatrix.append(bv)
        classMatrix.append(1.0)
    return (trainingMatrix, classMatrix)
#   The following function takes fifty vectors from A, B matrixes and stores
#   them in a single matrix (This will be our training matrix). The Function
#   also creates a vector as the classification vector.
def trainingR(A, B, C, D, E, F):
    trainingMatrix = []
    classMatrix = []
    for av in A:
        trainingMatrix.append(av)
        classMatrix.append(-1.0)
    for cv in C:
        trainingMatrix.append(cv)
        classMatrix.append(-1.0)
    for ev in E:
        trainingMatrix.append(ev)
        classMatrix.append(-1.0)
    for bv in B:
        trainingMatrix.append(bv)
        classMatrix.append(1.0)
    for dv in D:
        trainingMatrix.append(dv)
        classMatrix.append(1.0)
    for fv in F:
        trainingMatrix.append(fv)
        classMatrix.append(1.0)
    return(trainingMatrix, classMatrix)
#   The following function receives two dictionaries and returns the vectors
#   in the dictionary concatenated with the other matrix and a classification
#   matrix.
def trainingL(A, B):
    tMatrix = []
    cMatrix = []
    for a, avec in A.items():
        tMatrix.append(avec)
        cMatrix.append(-1.0)
    for b, bvec in B.items():
        tMatrix.append(bvec)
        cMatrix.append(1.0)
    return (tMatrix, cMatrix)
def trainingLR(A, B, C, D, E, F):
    trainingMatrix = []
    classMatrix = []
    for a, avec in A.items():
        trainingMatrix.append(avec)
        classMatrix.append(-1.0)
    for c, cvec in C.items():
        trainingMatrix.append(cvec)
        classMatrix.append(-1.0)
    for e, evec in E.items():
        trainingMatrix.append(evec)
        classMatrix.append(-1.0)
    for b, bvec in B.items():
        trainingMatrix.append(bvec)
        classMatrix.append(1.0)
    for d, dvec in D.items():
        trainingMatrix.append(dvec)
        classMatrix.append(1.0)
    for f, fvec in F.items():
        trainingMatrix.append(fvec)
        classMatrix.append(1.0)
    return(trainingMatrix, classMatrix)
###############################################
#           Science Contribution              #
###############################################

#   The following function receives a dimensionalized vector from one of the
#   possible classes of justifications and returns a test vector.
def obtainTest(A, B):
    # seed random number generator
    seed(1)
    # generate the random number
    r = randint(0, len(A))
    counter = 0
    testRF = {}
    testLF = {}
    for (wordA, vwordA), (wordB, vwordB) in zip(A.items(), B.items()):
        if counter == r:
            testRF = vwordA
            testLF = vwordB
            impWord = wordA
        counter += 1
    A.pop(impWord)
    B.pop(impWord)
    return (testRF, testLF)

#   The following function receives a Matrix and returns a random vector in it.
#   This vector will be use as a representative vector of the class in order
#   to classify a text file as easier or more difficult than it.
def random(A, B):
    seed(1)
    r = randint(0, len(A))
    counter = 0
    randRF = []
    randLF = []
    for (wordA, vwordA), (wordB, vwordB) in zip(A.items(), B.items()):
        if counter == r:
            randRF = vwordA
            randLF = vwordB
            impWord = wordA
        counter += 1
    A.pop(impWord)
    B.pop(impWord)
    return(randRF, randLF)
#   The following function receives a set of vectors and returns a random vector
#   from the collection.
def randomR(A):
    seed()
    print("Length of vector for random choice:", len(A))
    random = randint(0, len(A)-1)
    randVector = A[random]
    return randVector, random
#   The following function receives a set of matrixes and returns a list of random
#   vectors, one for each matrix.
def obtainRandomVectorsR(A, B, C, D):
    vecList = []
    vecPosition = []
    randomVecA, randomPositionA = randomR(A)
    vecList.append(randomVecA)
    vecPosition.append(randomPositionA)
    randomVecB, randomPositionB = randomR(B)
    vecList.append(randomVecB)
    vecPosition.append(randomPositionB)
    randomVecC, randomPositionC = randomR(C)
    vecList.append(randomVecC)
    vecPosition.append(randomPositionC)
    return vecList
#   The following function receives a set of matrixes and returns a list of random
#   vectors, one for each matrix.
def obtainRandomVectors3(A, B, C):
    vecList = []
    vecPosition = []
    randomVecA, randomPositionA = randomR(A)
    vecList.append(randomVecA)
    vecPosition.append(randomPositionA)
    randomVecB, randomPositionB = randomR(B)
    vecList.append(randomVecB)
    vecPosition.append(randomPositionB)
    randomVecC, randomPositionC = randomR(C)
    vecList.append(randomVecC)
    vecPosition.append(randomPositionC)
    return vecList, vecPosition
#   The following function receives eight matrixes and returns two lists: the
#   first list contains all the random RF vectors and the second list contains
#   LF vectors.
def obtainRandomVectors(A, B, C, D, E, F, G, H):
    vecListRF = [None]*4
    vecListLF = [None]*4
    (vecListRF[0], vecListLF[0]) = random(A, B)
    (vecListRF[1], vecListLF[1]) = random(C, D)
    (vecListRF[2], vecListLF[2]) = random(E, F)
    (vecListRF[3], vecListLF[3]) = random(G, H)

    return (vecListRF, vecListLF)
#   The following function receives eight matrixes two test vector related to
#   RF and LF, the general training matrix and its classyfying vector. The
#   function returns the maximum level of difficulty of the text.
def obtainGrade(lRF, lLF, testRF, testLF, tMatrix, CV):
    #Train the SVM
    clf = svm.SVC()
    clf.fit(tMatrix, CV)

    grade = 0
    goodGrade = 0
    ##print(testRF)
    for (vecRF, vecLF) in zip(lRF, lLF):
        testSubRF = substractVec(testRF, vecRF)
        testSubLF = substractVec(testLF, vecLF)
        conTest = concatenateVec(testSubRF, testSubLF)
        result = clf.predict([conTest])
        #print("Resultado: ")
        #print(result[0])
        if (result[0] == -1.0 or goodGrade>=3):
            #print("Entering results:")
            #print("Grade: ", grade)
            if(grade == 0):
                print("Your text is as good as TSU.")
            elif(grade == 1):
                print("Your text is as good as Lic.")
            elif(grade == 2):
                print("Your text is as good as Maestria.")
            elif(grade >= 3):
                print("Your text is as good as Doctorado.")
            break
        else:
            goodGrade += 1

        grade = grade + 1
#   The following function receives a list with the respective centroids, a
#   vector test in order to try and the training matrix with its respective
#   classes.
def obtainGradeR(centroidList, testRF, testLF, tMatrix, CV):
    clf = svm.SVC()
    clf.fit(tMatrix, CV)

    grade = 0
    goodGrade = 0
    #print(testRF)
    #print(len(testRF))
    testRF = enlistVec(testRF)
    testLF = enlistVec(testLF)
    conTest = concatenateVec(testRF, testLF)
    conTest = np.array(conTest)
    #print(conTest)
    #print(len(conTest))
    result = clf.predict([conTest])
    for vec in centroidList:
        vec = np.array(vec)
        #print(vec)
        #print(len(vec))
        subVec = conTest - vec
        #print(subVec)
        #print(len(subVec))
        result = clf.predict([subVec])
        #print(result)
        if (result[0] == -1.0 or goodGrade>=3):
            if(grade == 0):
                print("Your text is as good as TSU.")
            elif(grade == 1):
                print("Your text is as good as Lic.")
            elif(grade == 2):
                print("Your text is as good as Maestria.")
            elif(grade >= 3):
                print("Your text is as good as Doctorado.")
            break
        else:
            goodGrade += 1

        grade = grade + 1
#   The following function receives a test vector and a list of random vectors.
#   It returns the grade of the vector.
def obtainGradeRandom(vector, vector_list, clf):
    grade = 0
    goodGrade = 0
    for vec in vector_list:
        vector = vector - vec
        result = clf.predict([vector])
        #print("Result: ", result)
        if (result[0] == -1.0 or goodGrade>=3):
            if(grade == 0):
                #print("Your text is as good as TSU.")
                return 0
            elif(grade == 1):
                #print("Your text is as good as Lic.")
                return 1
            elif(grade >= 2):
                #print("Your text is as good as Maestria.")
                return 2
            break
        else:
            goodGrade += 1

        grade = grade + 1
#   The following function receives a testMatrix, its vector classification and a
#   list of random vector. It returns the accuracy of the evaluator.
def randomEvaluator(test_matrix, classification, vector_list, clf):
    acc = 0
    print("Test Matrix: ")
    print(test_matrix)
    print("Length of Random: ", len(test_matrix))
    for i in range(len(test_matrix)):
        grade = obtainGradeRandom(test_matrix[i], vector_list, clf)
        #print("Grade: ", grade)
        #print("Classification: ", int(classification[i]))
        if grade == int(classification[i]):
            acc += 1
    return acc/len(test_matrix)
# #   The following function receives a testMatrix, its vector classification and a
# #   list of random vector and the plain justifications. It returns the justification
# #   and its respective classification wether it was wrong or not.
def getJustificationEvaluation(test_matrix, classification, vector_list, clf, justificacionTSU, justificacionLic, justificacionMaestria):
    acc = 0
    print("Test Matrix: ")
    print(test_matrix)
    print("Length of Random: ", len(test_matrix))
    counter = 1
    for i in range(len(test_matrix)):
        grade = obtainGradeRandom(test_matrix[i], vector_list, clf)
        #print("Grade: ", grade)
        #print("Classification: ", int(classification[i]))
        if counter <= 11:
            print("Justificacion de TSU:")
            if grade == int(classification[i]):
                print("Justificacion Correcta: ")
                print(justificacionTSU[counter])
                acc += 1
            else:
                print("Justificacion Incorrecta: ")
                print(justificacionTSU[counter])
            counter += 1
        elif 12<= counter <=23:
            print("Justificaciones de Licenciatura")
            if grade == int(classification[i]):
                print("Justificacion Correcta: ")
                print(justificacionLic[counter])
                acc += 1
            else:
                print("Justificacion Incorrecta: ")
                print(justificacionLic[counter])
            counter += 1
        else:
            print("Justificaciones de Maestria: ")
            if grade == int(classification[i]):
                print("Justificacion Correcta: ")
                print(justificacionMaestria[counter])
                acc += 1
            else:
                print("Justificacion Incorrecta: ")
                print(justificacionMaestria[counter])
            counter += 1

    return acc/len(test_matrix)
#   The following function receives all the justifications for all the different
#   scholar levels and a list for the positions of the random vectors.
#   It returns the random selected vectors and prints them in screen.
def getRandomJustifications(list, A, B, C):
    print("TSU random justification:")
    print(A[list[0]+6])
    print("Lic. random justification: ")
    print(A[list[1]+6])
    print("Maestria random justification: ")
    print(A[list[2]+6])


#   The following function receives two matrixes, one related to the Relative
#   Frequency vectors and one related to the Logarithmic Frequency. It concatenates
#   them, tranforms them into a vector instead of a dictionary and returns the
#   centroid of them all.
def centroid(A, B):
    A = enlist(A)
    B = enlist(B)
    M = concatenate(A, B)
    #Transform into a numpy array
    Marray = np.array(M)
    length = len(Marray)
    centroid = np.zeros(33642)
    for vec in Marray:
        centroid = np.add(centroid, vec)
    centroid = centroid*(1/len(M[0]))
    return centroid

def centroidR(A, B):
    A = enlist(A)
    B = enlist(B)
    M = concatenate(A, B)
    length = len(M)
    centroid = np.zeros(33642)
    for i in range(length):
        for j in range(len(M[0])):
            centroid[j] = centroid[j] + M[i][j]
    for j in range(len(M[0])):
        centroid[j] = centroid[j]/(len(M[0]))
    return centroid
#   The following function receives a matrix and returns its centroid.
def centroidRR(A):
    centroid = np.zeros(len(A[0]))
    for vec in A:
        centroid = centroid + vec
    return centroid/(len(A))
#   The following function receives the test matrix, the classification vector,
#   the centroid list and the svm classifier. It returns the accuracy of the centroid
#   evaluator.
def centroidEvaluator(test_matrix, classification, centroids, clf):
    acc = 0
    for i in range(len(test_matrix)):
        grade = obtainGradeRandom(test_matrix[i], centroids, clf)
        #print("Grade: ", grade)
        #print("Classification: ", int(classification[i]))
        if grade == int(classification[i]):
            acc += 1
    return acc/len(test_matrix)
#   The following function receives four matrixes and returns a list of centroids.
#   One for each matrix.
def obtainCentroids(A, B, C, D):
    list = []
    list.append(centroidRR(A))
    list.append(centroidRR(B))
    list.append(centroidRR(C))
    list.append(centroidRR(D))
    return list
#   The following function receives four matrixes and returns a list of centroids.
#   One for each matrix.
def obtainCentroids3(A, B, C):
    list = []
    list.append(centroidRR(A))
    list.append(centroidRR(B))
    list.append(centroidRR(C))
    return list
#   The following function removes the len zero vectors from the dictionary and
#   returns a dictionary.
def removeZero(GM):
    l = []
    for n, w_vec in GM.items():
        if len(w_vec) == 0:
            l.append(n)
    for e in l:
        del GM[e]
    return GM

#   The follwing function receives a matrix and eliminates the zero lenght vectors
#   from it.
def cleanVector(A):
    return removeZero(A)

#   The following function receives the four grade matrixes and eliminates the
#   zero length vectors from it.
def cleanVectors(A, B, C, D):
    
    return removeZero(A), removeZero(B), removeZero(C), removeZero(D)
#   The following function gets the size of the smallest vector in the dictionary
#   vector-word matrix.
def smallest(GM):
    smallestValue = 1000000
    for n, w_vec in GM.items():
        if smallestValue > len(w_vec):
            smallestValue = len(w_vec)
    return smallestValue
#   The following function gets the size of the biggest vector in the dictionry
#   vector-word matrix.
def biggest(GM):
    biggestValue = 0
    for n, w_vec in GM.items():
        if biggestValue < len(w_vec):
            biggestValue = len(w_vec)
    return biggestValue
#   The following function receives a grade matrix and returns the average size
#   of the vectors in it.
def average(GM):
    averageValue = 0
    allElements = len(GM)
    for n, w_vec in GM.items():
        averageValue = averageValue + len(w_vec)
    return (averageValue/allElements)
#   The following function receives a grade matrix and returns a dictionary with
#   the size of the smallest vector, the biggest vector and the average sizes
#   of the vectors.
def returnSizes(GM):
    sizes = {}
    sizes['Smallest'] = smallest(GM)
    sizes['Biggest'] = biggest(GM)
    sizes['Average'] = average(GM)
    return sizes
#   The following function receives two grade matrixes dimensionalized and concatenated
#   and returns the substraction of both of them.
def subInc(A, B):
    matrix = []
    A = np.array(A)
    B = np.array(B)
    for vecA in A:
        for vecB in B:
            matrix.append(vecA - vecB)
    return matrix
#   The following function receives two matrices dimensionalized and concatenated
#   and returns their conmutative combination in two differente matrices. The plusOne
#   and the minusOne.
def comData(A, B):
    plusOne = subInc(B, A)
    minusOne = subInc(A, B)
    return plusOne, minusOne

#   The following function receives two matrixes dimensionalized and concatenated with
#   vectors with the form: local-global. It returns a matrix which concatenates each vector
#   of the first matrix with eache vector of the second one, thus returning a matrix with 
#   vectors with form: localA-globalA-localB-globalB.
def conMatrixes(A, B):
    concatenated_matrix = []
    A = np.array(A)
    B = np.array(B)
    for vecA in A:
        for vecB in B:
            concatenated_matrix.append(np.hstack((vecA, vecB)))
    return concatenated_matrix
    
#   The following function receives two matrices dimensionalized and concatenated
#   with the following form of vectors: (Local and Global). It concatenates the matrixes
#   in both orders PlusOne and MinusOne and returns matrixes with vectors with the 
#   following form: localA-globalA-localB-globalB and localB-globalB-localA-globalA.
def comConData(A, B):
    plusOneMatrix = conMatrixes(B, A)
    minusOneMatrix = conMatrixes(A, B)
    return plusOneMatrix, minusOneMatrix

#   The following function receives a matrix and returns the 80 percent of the values
#   in one matrix and the other twenty in another matrix.
def eightyTwenty(A):
    m = np.array([])
    twenty = math.ceil(len(A)*(1/5))
    for i in range(twenty):
        np.append(m, A[i], 0)
        np.delete(A, i, 0)
    return A, m
#   The following function receives the plusOne and minusOne version for all the grades
#   and returns the training matrix along with its classification vector.
def allTogetherNow(POT, MOT, POL, MOL, POM, MOM):
    M = np.array([])
    y = np.array([])
    M = np.append(POT, POL, 0)
    M = np.append(M, POM, 0)
    M = np.append(M, MOT, 0)
    M = np.append(M, MOL, 0)
    M = np.append(M, MOM, 0)
    y1 = np.ones(len(POT) + len(POL) + len(POM))
    y2 = np.zeros(len(MOT) + len(MOL) + len(MOM))
    y2 = y2-1
    y = np.append(y1, y2, 0)
    return M, y
#   The following function receives plusOne and minusOne version for all the grades
#   and returns the training matrix along with its classification vector.
def allTogetherNow(POT, MOT, POL, MOL):
    M = np.array([])
    y = np.array([])
    M = np.append(POT, POL, 0)
    M = np.append(M, MOT, 0)
    M = np.append(M, MOL, 0)
    y1 = np.ones(len(POT) + len(POL))
    y2 = np.zeros(len(MOT) + len(MOL))
    y2 = y2-1
    y = np.append(y1, y2, 0)
    return M, y
#   The following function receives a plusOne and a minusOne matrix. It returns a 
#   an appended matrix of the both along with its classification vector.
def allTogetherNowDouble(PO, MO):
    M = np.array([])
    y = np.array([])
    M = np.append(PO, MO, axis = 0)
    y1 = np.ones(len(PO))
    y2 = np.zeros(len(MO))
    y = np.append(y1, y2, axis = 0)
    return M, y

#   The following function receives a dictionary-list matrix and returns eighty
#   percent of the vectors in one matrix and the other twenty percent in another
#   matrix.
def divideEightyTwenty(M):
    twenty = {}
    eighty = {}
    counter = 0
    stop = int(len(M)/5)
    for v, vvec in M.items():
        if counter <= stop:
            twenty[v] = vvec
        else:
            eighty[v] = vvec
        counter += 1
    return twenty, eighty
#   The following function receives two matrixes the plusOne and the minusOne and
#   returns it's respective trainingMatrix with their related classification vector.
def togetherNow(A, B):
    M = np.array([])
    y = np.array([])
    M = np.append(A,B,0)
    y1 = np.ones(len(A))
    y2 = np.zeros(len(B))
    y2 = y2-1
    y = np.append(y1, y2, 0)
    return M, y
#   The following function divides our whole training set into 80 percent for
#   training and 20 percent for testing. It returns both matrixes.
def getEightyTwenty(M, y):
    print("Enter Eighty Twenty")
    np.c_[M, y]
    length = len(M)
    testMatrix = np.array([])
    print(int(length*(1/5)))
    seed(1)
    for i in range(int(length*(1/5))):
        print(i)
        random = randint(0, length)
        np.append(testMatrix, M[random])
        np.delete(M, random, 0)
    with open('traingMatrix.txt', 'wb') as f:
        for line in trainingMatrix:
            np.savetxt(f, line, fmt = '%.2f')
    return trainingMatrix, testMatrix
#   The following function receives the M matrix which corresponds to the training
#   objects and the test matrix. It first trains the SVM for later test the accuracy
#   of it five times. Finally it returns the five accuracies along with its standard
#   deviation.
def testAccuracy(M, tM):
    #Get the training Matrix just values
    M = np.array(M)
    y = M[:, len(M[0])-1]
    M = np.delete(M, len(M[0])-1, 1)
    yt = tM[:, len(tM[0])-1]
    tM = np.delete(tM, len(tM[0])-1, 1)
    # Train the svm
    clf = svm.SVC()
    clf.fit(M)
    for i in range(5):
        counter = 0
        for j in range(len(tM)):
            if clf.predict(tM[i]) == y[i]:
                counter += 1
        accuracy.append(counter/len(tM))
    return accuracy
#   The following function receives four matrixes and constructs a single matrix
#   with the vectors of all the other matrixes and a vector with their grade
#   classification.
def testEvaluatorMatrix(A, B, C, D):
    M = np.array([])
    M = np.concatenate((A, B), axis = 0)
    M = np.concatenate((M, C), axis = 0)
    M = np.concatenate((M, D), axis = 0)
    y = np.array([])
    y1 = np.zeros(len(A))
    y2 = np.zeros(len(B)) + 1
    y3 = np.zeros(len(C))  + 2
    y4 = np.zeros(len(D)) + 3
    y = np.concatenate((y1, y2), axis = 0)
    y = np.concatenate((y, y3), axis = 0)
    y = np.concatenate((y, y4), axis = 0)
    return M, y
#   The following function receives four matrixes and constructs a single matrix
#   with the vectors of all the other matrixes and a vector with their grade
#   classification.
def testEvaluatorMatrix3(A, B, C):
    M = np.array([])
    M = np.concatenate((A, B), axis = 0)
    M = np.concatenate((M, C), axis = 0)
    y = np.array([])
    y1 = np.zeros(len(A))
    y2 = np.zeros(len(B)) + 1
    y3 = np.zeros(len(C))  + 2
    y = np.concatenate((y1, y2), axis = 0)
    y = np.concatenate((y, y3), axis = 0)
    return M, y
#   The following function receives a number (amount of specific sections to retrieve) and
#   a dictionary of specific sections.
def getNVector(n, A):
    rA = {}
    counter = 0
    stop = n
    for (a, avec) in A.items():
        if counter < stop: 
            rA[a] = avec
        else:
            break
        counter += 1
    return rA
#   The following function receives four matrixes and a number. It returns the
#   amount of vectors in the number for each of the matrixes.
def getNVectors(n, A, B, C, D):
    rA = {}
    rB = {}
    rC = {}
    rD = {}
    for (a, avec), (b, bvec), (c, cvec), (d, dvec) in zip (A.items(), B.items(), C.items(), D.items()):
        rA[a] = avec
        rB[b] = bvec
        rC[c] = cvec
        rD[d] = dvec
    return rA, rB, rC, rD
#   The following function receives three matrixes and a number. It returns the
#   amount of vectors in the number for each of the matrixes.
def get3NVectors(n, A, B, C):
    rA = {}
    rB = {}
    rC = {}
    counter = 0
    stop = n
    for (a, avec), (b, bvec), (c, cvec) in zip (A.items(), B.items(), C.items()):
        if counter < stop:
            rA[a] = avec
            rB[b] = bvec
            rC[c] = cvec
        else:
            break
        counter+=1
    return rA, rB, rC
#   The following function receives two vectors, actual results for the test vector and the
#   predicted vector produced by our classifier, it then returns the accuracy report for
#   our classifier. Accuracy considered as number of correct predictions divided by total
#   number of predictions made.
def obtain_accuracy(a, b):
    correct = np.where(a == b)
    return np.size(correct)/np.size(a)
    

#   Open the stop words file.
sw = openFile("stopWords.txt")
#   Curate the stop words.
sw = cleanStop(sw)
sw
# Out:
# ['a',
#  'al',
#  'algo',
#  'algunas',
#  'algunos',
#  'ante',
#  'antes',
#  'como',
#  'con',
#  'contra',
#  'cual',
#  'cuando',
#  'de',
#  'del',
#  'desde',
#  'donde',
#  'durante',
#  'e',
#  'el',
#  'ella',
#  'ellas',
#  'ellos',
#  'en',
#  'entre',
#  'era',
#  'erais',
#  'eran',
#  'eras',
#  'eres',
#  'es',
#  'esa',
#  'esas',
#  'ese',
#  'eso',
#  'esos',
#  'esta',
#  'estaba',
#  'estabais',
#  'estaban',
#  'estabas',
#  'estad',
#  'estada',
#  'estadas',
#  'estado',
#  'estados',
#  'estamos',
#  'estando',
#  'estar',
#  'estaremos',
#  'estará',
#  'estarán',
#  'estarás',
#  'estaré',
#  'estaréis',
#  'estaría',
#  'estaríais',
#  'estaríamos',
#  'estarían',
#  'estarías',
#  'estas',
#  'este',
#  'estemos',
#  'esto',
#  'estos',
#  'estoy',
#  'estuve',
#  'estuviera',
#  'estuvierais',
#  'estuvieran',
#  'estuvieras',
#  'estuvieron',
#  'estuviese',
#  'estuvieseis',
#  'estuviesen',
#  'estuvieses',
#  'estuvimos',
#  'estuviste',
#  'estuvisteis',
#  'estuviéramos',
#  'estuviésemos',
#  'estuvo',
#  'está',
#  'estábamos',
#  'estáis',
#  'están',
#  'estás',
#  'esté',
#  'estéis',
#  'estén',
#  'estés',
#  'fue',
#  'fuera',
#  'fuerais',
#  'fueran',
#  'fueras',
#  'fueron',
#  'fuese',
#  'fueseis',
#  'fuesen',
#  'fueses',
#  'fui',
#  'fuimos',
#  'fuiste',
#  'fuisteis',
#  'fuéramos',
#  'fuésemos',
#  'ha',
#  'habida',
#  'habidas',
#  'habido',
#  'habidos',
#  'habiendo',
#  'habremos',
#  'habrá',
#  'habrán',
#  'habrás',
#  'habré',
#  'habréis',
#  'habría',
#  'habríais',
#  'habríamos',
#  'habrían',
#  'habrías',
#  'habéis',
#  'había',
#  'habíais',
#  'habíamos',
#  'habían',
#  'habías',
#  'han',
#  'has',
#  'hasta',
#  'hay',
#  'haya',
#  'hayamos',
#  'hayan',
#  'hayas',
#  'hayáis',
#  'he',
#  'hemos',
#  'hube',
#  'hubiera',
#  'hubierais',
#  'hubieran',
#  'hubieras',
#  'hubieron',
#  'hubiese',
#  'hubieseis',
#  'hubiesen',
#  'hubieses',
#  'hubimos',
#  'hubiste',
#  'hubisteis',
#  'hubiéramos',
#  'hubiésemos',
#  'hubo',
#  'la',
#  'las',
#  'le',
#  'les',
#  'lo',
#  'los',
#  'me',
#  'mi',
#  'mis',
#  'mucho',
#  'muchos',
#  'muy',
#  'más',
#  'mí',
#  'mía',
#  'mías',
#  'mío',
#  'míos',
#  'nada',
#  'ni',
#  'no',
#  'nos',
#  'nosotras',
#  'nosotros',
#  'nuestra',
#  'nuestras',
#  'nuestro',
#  'nuestros',
#  'o',
#  'os',
#  'otra',
#  'otras',
#  'otro',
#  'otros',
#  'para',
#  'pero',
#  'poco',
#  'por',
#  'porque',
#  'que',
#  'quien',
#  'quienes',
#  'qué',
#  'se',
#  'sea',
#  'seamos',
#  'sean',
#  'seas',
#  'seremos',
#  'será',
#  'serán',
#  'serás',
#  'seré',
#  'seréis',
#  'sería',
#  'seríais',
#  'seríamos',
#  'serían',
#  'serías',
#  'seáis',
#  'sido',
#  'siendo',
#  'sin',
#  'sobre',
#  'sois',
#  'somos',
#  'son',
#  'soy',
#  'su',
#  'sus',
#  'suya',
#  'suyas',
#  'suyo',
#  'suyos',
#  'sí',
#  'también',
#  'tanto',
#  'te',
#  'tendremos',
#  'tendrá',
#  'tendrán',
#  'tendrás',
#  'tendré',
#  'tendréis',
#  'tendría',
#  'tendríais',
#  'tendríamos',
#  'tendrían',
#  'tendrías',
#  'tened',
#  'tenemos',
#  'tenga',
#  'tengamos',
#  'tengan',
#  'tengas',
#  'tengo',
#  'tengáis',
#  'tenida',
#  'tenidas',
#  'tenido',
#  'tenidos',
#  'teniendo',
#  'tenéis',
#  'tenía',
#  'teníais',
#  'teníamos',
#  'tenían',
#  'tenías',
#  'ti',
#  'tiene',
#  'tienen',
#  'tienes',
#  'todo',
#  'todos',
#  'tu',
#  'tus',
#  'tuve',
#  'tuviera',
#  'tuvierais',
#  'tuvieran',
#  'tuvieras',
#  'tuvieron',
#  'tuviese',
#  'tuvieseis',
#  'tuviesen',
#  'tuvieses',
#  'tuvimos',
#  'tuviste',
#  'tuvisteis',
#  'tuviéramos',
#  'tuviésemos',
#  'tuvo',
#  'tuya',
#  'tuyas',
#  'tuyo',
#  'tuyos',
#  'tú',
#  'un',
#  'una',
#  'uno',
#  'unos',
#  'vosotras',
#  'vosotros',
#  'vuestra',
#  'vuestras',
#  'vuestro',
#  'vuestros',
#  'y',
#  'ya',
#  'yo',
#  'él',
#  'éramos',
#  '.',
#  ',',
#  ';',
#  ':',
#  '/',
#  '"',
#  '?',
#  '!',
#  '¡',
#  '<',
#  '>',
#  'El',
#  '>El']

# %%
# !ls
# Out:
# AvancesRecuperacionDeInformacion-3.pdf
# Doctorado.xml
# DoctoradoCompleto.xml
# LegibilityRevisedJustification.py
# Licenciatura.xml
# LicenciaturaCompleto.xml
# Maestria.xml
# MaestriaCompleto.xml
# ResultsTablesForClassificationI.ipynb
# SoftwareRevisionJustification.ipynb
# SoftwareRevisionProblem.ipynb
# SoftwareRevisionProblemConcatenation.ipynb
# SoftwareRevisionResults.ipynb
# TSU.xml
# TSUCompleta.xml
# Untitled.ipynb
# Untitled1.ipynb
# completeTrainingData.txt
# frecuencia.txt
# justificacionDoctorado.xml
# justificacionLic.xml
# justificacionMaestria.xml
# justificacionTSU.xml
# obatinMet9.0.py
# obtainMet.py
# obtainMet1.0.py
# obtainMet10.0.py
# obtainMet2.0.py
# obtainMet3.0.py
# obtainMet4.0.py
# obtainMet5.0.py
# obtainMet6.0.py
# obtainMet6.0py.py
# obtainMet7.0.py
# obtainMet8.0.py
# obtainMet9.0.py
# rp_svm.py
# stopWords.txt
# tesis.xml

# %% [markdown]
# # Main

# %%
s = 'TSUCompleta.xml'
with open(s) as fp:
    soup = BeautifulSoup(fp, 'xml')
    all = soup.find_all('Problema')
soup.find_all('Problema')

counter = 1
problema = ""
for met in soup.find_all('Problema'):
    [s.extract() for s in met.findAll('Problema')]
    ######print("*Metodologia", counter)
    #####print(met)
    problema = problema + str(met) + "\n"
    #####print("\n")
    counter += 1
problema
# Out:
# '<Problema>AUTOMATIZACIÓN DEL MÓDULO\nDE CAJA.El proceso que se realiza en la actualidad no permite conocer la información\noportunamente, ya que el tiempo que se llevan en recopilar la información depende\nde las personas involucradas en el proceso, además de que se presta a errores y\nmalos manejos.\nEl usuario tiene que trasladarse hasta las oficinas administrativas de la empresa para\nllenar la solicitud, y para llevar el control de la comprobación de los gastos lo hacen a\ntravés de una hoja de Excel, de la cual si no actualizan sus formulas, generan datos\nincorrectos.\nEn cuestión de almacenamiento lo único que se guarda directo al servidor es el\nmonto de dinero solicitado durante el día, pero no la información generada de cada\nuno de los solicitantes que es importante para el seguimiento del proceso.\nPara el departamento de contabilidad es bastante laborioso, ubicar cada uno de los\ndiferentes gastos en las cuentas contables al final del mes cuando generan la póliza,\ndebido a que tienen que recurrir a cada una de las solicitudes y en cuando la solicitud\nno muestra la información necesaria, entonces deben dirigirse personalmente con el\nsolicitante y preguntarle sobre los gastos que realizó.\nEn los casos en que el solicitante no presente sus comprobantes de gastos, muchas\nveces por errores técnicos el dinero que les fue otorgado no se les descuenta de nomina y por política de la empresa, todo solicitante que no realice la comprobación,\ntendrá que devolver al 100% el dinero otorgado.\nPor último, no existe ningún tipo de reporte que muestre información sobre el\ndepartamento de caja, por lo que es cuestionable su buen funcionamiento.</Problema>\n<Problema>El software usado anteriormente para la administración requería tener ciertos privilegios en las cuentas de los usuarios que lo usaban, lo cual provocaba que la seguridad de su servidor se volviera vulnerable, debido a esto en muchas ocasiones el software no podía ser utilizado.\nA pesar de ser un software diseñado para trabajar en un ambiente cliente / servidor era muy lento y se sobrecargaba debido a la utilización de varias operaciones sobre la misma tabla.</Problema>\n<Problema>El tratamiento y manejo de la literatura científica por medios cuantitativos\nsirve no sólo para analizar el volumen de publicaciones, la productividad de\nautores, revistas o materias, sino también en un sentido más amplio, para el\nconocimiento de los procesos y la naturaleza de las ciencias.\nEs de gran importancia conocer el material bibliográfico con el que cuenta la\nDGB a través de sus catálogos disponibles, sin embargo, como dependencia\nencargada de coordinar el sistema bibliotecario de la UNAM, surge la necesidad de\nobtener indicadores bibliométricos, es decir, medidas basadas habitualmente en\nrecuentos de publicaciones que persiguen cuantificar resultados.\nUno de los problemas que se tienen en la actualidad en la Dirección General\nde Bibliotecas es que no cuenta con un sistema automatizado para la obtención de\nmedidas cuantitativas de la información contenida en sus bases de datos.\nConsiderando el volumen actual de la base de datos TESIUNAM y su\nperspectiva de crecimiento, la Biblioteca Central, la cual se encarga de la recepción\nde tesis, se ve en la necesidad de obtener información cuantitativa de la producción\nde tesis llevando un “control en bitácoras en papel, lo cual es un procedimiento\nobsoleto, poco fiable ya que no se asegura de que todas y cada una de las tesis sean\nregistradas, además que es un procedimiento manual, tedioso y redundante\ndebido a que la catalogación bibliográfica se realiza en el sistema ALEPH.\nLa obtención de indicadores bibliométricos no es tarea fácil, ya que los\nregistros bibliográficos almacenados en la base de tesis no cuentan con el formato\npara acceder de manera directa a la información y la forma de catalogar los\nregistros bibliográficos no está unificada.\nEl formato en el que los registros bibliográficos se encuentran al ...

# %% [markdown]
# ## Obtain Problem

# %%
problemTSU = bsMeth('TSUCompleta.xml')
problemLic = bsMeth('LicenciaturaCompleto.xml')
problemMasters = bsMeth('MaestriaCompleto.xml')
problemPhd = bsMeth('DoctoradoCompleto.xml')
problemTSU
problemLic
problemMasters
problemPhd
# Out:
# '<Problema>La gran cantidad de información disponible en Internet, la complejidad y heterogeneidad de la\nmisma, junto con las distintas características de los usuarios que acceden a dicha información, así\ncomo la gran competencia existente en la red, hacen crítico que el desarrollo de aplicaciones\nbasadas en Web, y de manera particular los sitios Web educativos deban contemplar no solo\naspectos de funcionalidad sino también de usabilidad, tomando en cuenta que estas aplicaciones no\nsolo deben tener como objetivo poner a disposición de los usuarios información exacta, sino orientar\nadecuadamente al usuario en su búsqueda, adecuando los caminos más apropiados para cada\nusuario de acuerdo con sus objetivos, sus conocimientos previos o sus necesidades y perfiles.\nLa usabilidad en este contexto, se enmarca en una pregunta sobre si una aplicación Web educativa\nes lo suficientemente buena para satisfacer las necesidades y requerimientos del usuario. Es decir,\nla usabilidad corresponde a una variable en el marco de la aceptación práctica de un sitio Web\neducativo. Así, para que un sitio Web pueda ser utilizado para alcanzar alguna tarea, tiene que\ncumplir con criterios de utilización (es decir referido a la funcionalidad: puede hacer lo que se\nnecesita) y usabilidad (cuán bien los usuarios pueden usar esa funcionalidad del sitio Web). La\nusabilidad considera todos los aspectos de un sitio Web educativo con el que el usuario puede\ninteractuar y sus principales criterios de evaluación (aprendizaje, operabilidad, comunicación\ncontenido, etc.). Por ejemplo, el sitio debe cumplir una funcionalidad de presentar determinado tipo\nde contenido, pero este contenido debe ser presentado de una manera atractiva y sencilla al usuario\ny que además el aprendizaje de su uso y navegación sea intuitiva y fácil, para llevar a cabo un\nproceso de aprendizaje rápido y eficaz.\nMuchos son los autores que han investigado y propuesto recomendaciones (guías, listas de\ncomprobación, principios, etc.) para el desarrollo de aplicaciones usables ([NIE90a], [NIE94a],\n[SHN98], [BEV93] entre otros), y muy pocos sobre la evaluación de la usabilidad de sitios Web\neducativos [GON03], [CAR02]. Sin embargo, basta hacer una exploración en la Web para\ncomprobar que esto aún sigue siendo un problema. Si tenemos en cuenta que existe una diversidad\nde dominios de aplicación basadas en Web, comerciales, ocio, entretenimiento, educación, etc.; una\nmala usabilidad en sitios comerciales, de ocio o incluso de noticias puede significar simplemente que\nel usuario busque otro lugar. Sin embargo, en el caso de sitios de carácter educativo el problema se\nagudiza ya que una mala usabilidad puede repercutir fuertemente en los objetivos de aprendizaje.\nEs decir, los requisitos de usabilidad de un sitio Web comercial de venta de herramientas de\ncarpintería orientado a aquellos profesionales del área o personas aficionadas a la carpintería, cuyo\ninterés esta centrado en encontrar un producto de carpintería determinado al mejor precio, será\ndiferente de los requisitos de usabilidad del sitio Web de algún curso de una universidad o institución\neducativa, en principio por que las motivaciones de los usuarios son distintas, el perfil de ellos\ntambién lo es, así como las metas a alcanzar por cada uno. Así preparar el proceso de evaluación\nde usabilidad de un sitio comercial no será el mismo que el de un sitio educativo aunque ambos\nbuscan cubrir un servicio, lograr la satisfacción del usuario y en algunos casos ambos pretendan\nlograr dividendos económicos. Los sitios Web educativos tienen un añadido fundamental, y es la\ntransmisión y adquisición del conocimiento. Por ende un factor importante de evaluación es el\naspecto educativo y su presentación de contenidos.\nLa consideración de la usabilidad como un factor importante en el desarrollo de aplicaciones Web ha\nido en aumento en los últimos años. Basándose en el fundamento teórico de la usabilidad de\nsoftwar ...

# %% [markdown]
# ## Separate Problem Sections

# %%
problemTSU = [j for j in problemTSU.split("<Problema>")]
problemLic = [j for j in problemLic.split("<Problema>")]
problemMasters = [j for j in problemMasters.split('<Problema>')]
problemPhd = [j for j in problemPhd.split('<Problema>')]
problemTSU
problemLic
problemMasters
problemPhd
# Out:
# ['',
#  'La gran cantidad de información disponible en Internet, la complejidad y heterogeneidad de la\nmisma, junto con las distintas características de los usuarios que acceden a dicha información, así\ncomo la gran competencia existente en la red, hacen crítico que el desarrollo de aplicaciones\nbasadas en Web, y de manera particular los sitios Web educativos deban contemplar no solo\naspectos de funcionalidad sino también de usabilidad, tomando en cuenta que estas aplicaciones no\nsolo deben tener como objetivo poner a disposición de los usuarios información exacta, sino orientar\nadecuadamente al usuario en su búsqueda, adecuando los caminos más apropiados para cada\nusuario de acuerdo con sus objetivos, sus conocimientos previos o sus necesidades y perfiles.\nLa usabilidad en este contexto, se enmarca en una pregunta sobre si una aplicación Web educativa\nes lo suficientemente buena para satisfacer las necesidades y requerimientos del usuario. Es decir,\nla usabilidad corresponde a una variable en el marco de la aceptación práctica de un sitio Web\neducativo. Así, para que un sitio Web pueda ser utilizado para alcanzar alguna tarea, tiene que\ncumplir con criterios de utilización (es decir referido a la funcionalidad: puede hacer lo que se\nnecesita) y usabilidad (cuán bien los usuarios pueden usar esa funcionalidad del sitio Web). La\nusabilidad considera todos los aspectos de un sitio Web educativo con el que el usuario puede\ninteractuar y sus principales criterios de evaluación (aprendizaje, operabilidad, comunicación\ncontenido, etc.). Por ejemplo, el sitio debe cumplir una funcionalidad de presentar determinado tipo\nde contenido, pero este contenido debe ser presentado de una manera atractiva y sencilla al usuario\ny que además el aprendizaje de su uso y navegación sea intuitiva y fácil, para llevar a cabo un\nproceso de aprendizaje rápido y eficaz.\nMuchos son los autores que han investigado y propuesto recomendaciones (guías, listas de\ncomprobación, principios, etc.) para el desarrollo de aplicaciones usables ([NIE90a], [NIE94a],\n[SHN98], [BEV93] entre otros), y muy pocos sobre la evaluación de la usabilidad de sitios Web\neducativos [GON03], [CAR02]. Sin embargo, basta hacer una exploración en la Web para\ncomprobar que esto aún sigue siendo un problema. Si tenemos en cuenta que existe una diversidad\nde dominios de aplicación basadas en Web, comerciales, ocio, entretenimiento, educación, etc.; una\nmala usabilidad en sitios comerciales, de ocio o incluso de noticias puede significar simplemente que\nel usuario busque otro lugar. Sin embargo, en el caso de sitios de carácter educativo el problema se\nagudiza ya que una mala usabilidad puede repercutir fuertemente en los objetivos de aprendizaje.\nEs decir, los requisitos de usabilidad de un sitio Web comercial de venta de herramientas de\ncarpintería orientado a aquellos profesionales del área o personas aficionadas a la carpintería, cuyo\ninterés esta centrado en encontrar un producto de carpintería determinado al mejor precio, será\ndiferente de los requisitos de usabilidad del sitio Web de algún curso de una universidad o institución\neducativa, en principio por que las motivaciones de los usuarios son distintas, el perfil de ellos\ntambién lo es, así como las metas a alcanzar por cada uno. Así preparar el proceso de evaluación\nde usabilidad de un sitio comercial no será el mismo que el de un sitio educativo aunque ambos\nbuscan cubrir un servicio, lograr la satisfacción del usuario y en algunos casos ambos pretendan\nlograr dividendos económicos. Los sitios Web educativos tienen un añadido fundamental, y es la\ntransmisión y adquisición del conocimiento. Por ende un factor importante de evaluación es el\naspecto educativo y su presentación de contenidos.\nLa consideración de la usabilidad como un factor importante en el desarrollo de aplicaciones Web ha\nido en aumento en los últimos años. Basándose en el fundamento teórico de la usabilidad de\nsoftware tradici ...
#  'Debido a que las redes de sensores inalambricas son un campo en pleno desarrollo, que la operacion de servicios de autenticidad en sus comunicaciones es un problema que no ha sido resuelto de forma definitiva y que la naturaleza de operacion de dichas redes presenta requerimientos específicos de escalabilidad y flexibilidad para el diseño de cualquier control de seguridad, se llego a determinar lo siguiente.\nEl problema a resolver es la busqueda de un mecanismo que permita el\nuso de operaciones de criptografía asimetrica en un ambiente de redes de\nsensores, para operar de forma eficiente un protocolo de autenticacion que\npermita explotar las características de flexibilidad y escalabilidad en dicho\nambiente.</Problema>\n',
#  "En una red celular, diseñar un protocolo para la generación y distribución de llaves, \npara una comunicacion multimedia multipartita segura, requiere consideraciones adicionales que para una red fi\x81ja. Tales consideraciones estan en función de las características de la multimedia, de las caracter'ísticas para una comunicacion en grupo segura, de \nla arquitectura de la red celular y del modo de comunicacion a considerar. Por ello, \nabordamos el problema desde cuatro puntos de vista. Primero, consideramos las caracteíísticas necesarias a garantizar para una comunicacion en grupo segura. Segundo, \nse toman en cuenta los problemas que surgen debido a las características de la arquitectura de una red celular. Tercero, se consideran aspectos relacionados al uso de una\ncomunicacion asíncrona. Cuarto, consideramos las características de la multimedia.</Problema>\n",
#  'El aprendizaje por refuerzo se ha aplicado para resolver problemas en\nvarias disciplinas, incluyendo aplicaciones recientes, como la robótica. Los\nretos actuales principales para aprendizaje por refuerzo son:\nLa exploración en el ambiente real consume mucho tiempo.\nEl conocimiento obtenido se limita a resolver solamente la tarea apren-\ndida.\nLos dominios probados en el estado del arte son de dinámicas simples.\nEl dilema exploración-explotación es algo que ha ocupado a los investi-\ngadores en el área de aprendizaje por refuerzo. Las técnicas se han inclinado\npor algoritmos que encuentren un correcto balance entre la exploración y\nla explotación durante el aprendizaje, y con ello hallar una buena política\nen un tiempo reducido. U na solución alternativa, que permite reutilizar el\nconocimiento entre tareas similares y así reducir el tiempo de aprendizaje en\nla tarea objetivo, es la transferencia de conocimiento.\nEn a~nos recientes se han hecho avances en algoritmos para transferir di-\nferentes tipos de conocimiento entre tareas de aprendizaje por refuerzo, sin\nembargo, la mayoría de los trabajos se ha centrado en tareas con una natu-\nraleza discreta.\nEl trabajo que aquí se propone se enfoca en la transferencia de conoci-\nmiento entre problemas con dinámicas complejas y con espacios de estado y acciones continuos, usando una representación cualitativa compacta y gene-\nralizada, adquirida durante el aprendizaje de una primera tarea relacionada\ny aplicada como guía para el aprendizaje de la tarea objetivo.\nSon muy pocos los trabajos que han hecho transferencia en tareas de\nestados continuos [Taylor et al., 2008], [Lazaric et al., 2008] y nulos en tareas\ncon acciones continuas. De tal situación se hace visible la importancia de este\ntrabajo, cuyo objetivo es transferir información cualitativa entre tareas con\nespacios de estado y acción continuos.\nLa ventaja de una abstracción cualitativa sobre otros enfoques es la gene-\nralidad en la representación de acciones y estados así como la representación\ncompacta del conocimiento sobre la tarea. El razonamiento cualitativo y abs-\ntracciones cualitativas han sido empleados para representar funciones cuali-\ntativas en procesos de control ([Mugan, 2010], [Suc, 2003]).También se han\nusado para representar reglas durante el aprendizaje por refuerzo ([Mugan\nand Kuipers, 2008], [Mugan, 2010]), pero hasta el momento no se han desarro-\nllado trabajos sobre transferencia de información cualitativa en aprendizaje\npor refuerzo, lo cual es el objetivo que persigue este trabajo.\nEn una tarea donde el agente se arriesga al hacer exploración, es deseable\ntener un desempe~no inicial al ejecutarse los primeros episodios del aprendi-\nzaje y correr menos riesgo de realizar acciones peligrosas. En aprendizaje por\nrefuerzo la métrica que mejor re\neja tal comportamiento es jumpstart1\n. En\nla literatura revisada no se encontraron trabajos en los cuáles se centraran\nlos esfuerzos en generar un alto valor de jumpstart, excepto por el trabajo de\nLazaric ([Lazaric et al., 2008]). El trabajo que aquí se propone se enfoca en\ngenerar un valor de jumpstart suficientemente alto para guíar la exploración\ny reducir el riesgo de explorar acciones peligrosas, evitando la transferencia\nnegativa2\n.\nTodos los trabajos de transferencia para aprendizaje por refuerzo que\nse han encontrado en la literatura, han sido probados por sus autores en\nsimulaciones. Uno de los objetivos del trabajo propuesto es hacer validaciones\nde transferencia de conocimiento en un problema de robótica complejo, con\nalta dimensionalidad, dinámica no-lineal y estocasticidad, ese será en volar\nde manera autónoma un helicóptero.</Problema>\n',
#  'El algoritmo de clasificación supervisada, basado en la búsqueda del vecino más cercano (NN) \n[COVER67], ha sido ampliamente utilizado debido a su simplicidad y capacidad para resolver \nproblemas complejos de Reconocimiento de Patrones. Este algoritmo está basado en un \nconjunto de objetos de entrenamiento T, previamente clasificado. \nT = {Zi | 1 &lt;= i &lt;=N}\t\t\t(1) \n\nDonde N es el número de objetos. El objeto Zi\nestá descrito por d atributos en un espacio R^d. \n\nZi = [x1(Zi), x2(Zi),..., xd(Zi)] \t\t(2) \n\nDado un nuevo objeto Q a clasificar, el objetivo del clasificador es encontrar el objeto ONN en el \nconjunto T que minimice la función de distancia Dist con el objeto Q. \n\nO[MN] = minDist [Z=T](Zi ,Q) \t\t (3) \n\nPara encontrar ONN se requiere una comparación exhaustiva entre Q y cada objeto del conjunto \nT. Una vez encontrado el vecino más cercano, se asigna la clase de este objeto a Q. \n Una generalización de este método es el algoritmo de k vecinos más cercanos (k-NN). En \neste caso, la búsqueda se realiza de la misma forma que en NN, salvo que en lugar de encontrar \nun sólo objeto, se buscan los k más cercanos. Finalmente, la clase del objeto Q se elige por \nvotación de los k objetos más cercanos. Un diagrama del algoritmo NN se muestra en la figura \n1.1.\nEl algoritmo de clasificación basado en la búsqueda del vecino más cercano se ha aplicado \nen otros problemas aparte de la clasificación, tal es el caso de: estimación de densidad \n[CHEN89], compresión de datos [GERSHO91], recuperación de información \n[DEERWESTER90], reconocimiento de caracteres [STELIOS93], cuantización de vectores \n[CHEN97]. \nEn las aplicaciones antes mencionadas, dicho algoritmo de clasificación ha presentado un \nbuen desempeño. Sin embargo, comparar un nuevo objeto Q contra todos los elementos del \nconjunto T implica un alto costo en tiempo, cuando T es muy grande. Por esta razón en los \núltimos años se han propuesto métodos para hacer más rápida la búsqueda, la mayoría de los \ncuales omiten comparaciones con base en propiedades métricas de la función de distancia.</Problema>\n',
#  'La efectividad de una representación de documentos, está directamente relacionada a la \nexactitud con la cual el conjunto de términos seleccionados representa el contenido de un \ndocumento y a cuán bien se puede contrastar el contenido de dicho documento con otro. Es decir, \ndados dos documentos D1 y D2 y sus representaciones R1 y R2, respectivamente, si R1 es igual a R2\nesto significa que el contenido de R1 es igual al contenido de R2 a cierto nivel de abstracción. \nEn cuanto a la representación de contenido, la bolsa de palabras es insuficiente, ya que \npalabras aisladas son poco específicas para efectuar una discriminación adecuada entre documentos \n[23, 26]. Un método más apropiado, como se ha mencionado, sería identificar grupos de palabras \ncon significado que denoten conceptos o relaciones, este será el trabajo de la presente investigación, \nla utilidad de la representación resultante será comprobada en RI, por tal motivo, a continuación se \npresenta una descripción de dicha tarea.\nLa recuperación de información (RI) se interesa en seleccionar, de grandes volúmenes de \ntexto, aquellos documentos que contienen información relevante de acuerdo a las necesidades de \ninformación expresadas por un usuario. \nLa RI incluye dos actividades principales: indexar y buscar. La primera se refiere a \nrepresentar el contenido de los documentos y la solicitud de información que emite el usuario. La \nsegunda, a la forma de examinar la representación de los documentos con respecto a la petición de \ninformación, para proporcionar como respuesta los que resulten de mayor relevancia. \nLa riqueza inherente al lenguaje, y la diversidad en la manera de expresar las necesidades \nde información por parte de los usuarios, ocasionan que las operaciones de indexar y de buscar \nnunca recuperen información de manera perfecta, como puede ser el caso de los manejadores de \nbases de datos. Por lo tanto, ha sido necesario establecer métodos cuantitativos (funciones de \nrelevancia) para evaluar de forma aproximada la similitud entre la consulta y los documentos, y \nentonces determinar cuáles recuperar. \nUn modelo de RI se define con la representación que se da a los documentos y las consultas \n(objetivo de esta investigación), y la función de relevancia que se emplea para compararlos. \nAhora bien, dada una solicitud de información, por ejemplo: \n"Estoy interesado en mecanismos de comunicación entre procesos disjuntos, posiblemente, \npero no exclusivamente en ambientes distribuidos. Preferiría ver descripciones de mecanismos\ncompletos con o sin implementación en lugar de trabajos teóricos del problema. Llamada a \nprocedimientos remotos y paso de mensajes, son ejemplos de mi interés" [10]. \nPodemos observar que existen palabras como descripciones, mecanismos, implementación\ny problema, que deberían estar presentes en los documentos recuperados pero manteniendo la \nrelación expresada, ya que se buscan "descripciones de mecanismos de comunicación entre \nprocesos". Si empleamos de manera aislada las palabras mencionadas, algunas serán ignoradas por \nsu generalidad al crear el índice y si se incluyen en el índice conducirán a recuperar gran cantidad \nde documentos irrelevantes. \nCuando se recupera un grupo de documentos se encontrará que algunos de ellos no son \nrelevantes y que algunos relevantes no se han recuperado. El éxito de la recuperación se establece \nmediante dos métricas: la precisión, que es la razón de los documentos relevantes recuperados entre \nel total de documentos recuperados y el recuerdo, la razón del número de documentos relevantes \nrecuperados entre el total de documentos relevantes existentes en la colección. \nEn el área de recuperación de información se continúa experimentando con nuevos modelos \ny por ende nuevas representaciones de documentos, para intentar cubrir con mayor precisión las \nnecesidades de información de los usuarios. \nComo se ha especificado, nos centraremos en RI, donde si  ...
#  'Debido al vertiginoso ritmo de aparición y posicionamiento de las tecnologías, tanto en \nel nivel de las comunicaciones como en el de tráfico, se han cometido diversos errores \nen cuanto a la generación de los contenidos publicados en la Web, y la forma en la que \nson transmitidos a los usuarios. Estos errores han constituido duplicidad de esfuerzos al \ndesarrollar diversas aplicaciones entre diferentes administradores, sin una \nestandarización como base y generalmente asociada con el desarrollo de contenidos \nbasados en lenguajes de marcado como HTML. Esto ha dificultado procesos deseables \ncomo el compartir la información al tratar con vocabularios no comunes entre los \ndiferentes elementos involucrados, y que al final dan como resultado la percepción por \nparte del usuario de información diversa y difusa. \nA continuación se describen cada uno de los problemas que bajo mi perspectiva, \ncaracterizan la problemática de la difusión de información de tráfico vía Web: \nProblema 1: Ausencia de vocabularios comunes \n En el desarrollo de las distintas aplicaciones de tráfico es característico la \nausencia de vocabularios comunes que puedan ser elegidos como núcleo y punto de \npartida para desarrolladores de contenidos. Por ejemplo, en el caso de las aplicaciones \nsobre gestión de incidencias de tráfico, no existen tales vocabularios comunes que sean \nasociados a los descriptores o metadatos3\n de la información que deben de desarrollar las \naplicaciones, con lo que los desarrolladores pueden llegar a describir la información \n(por ejemplo de los vehículos implicados en un accidente) de diferente forma, inclusive \nentre desarrolladores de una misma empresa de desarrollo y más aún entre diferentes \nadministraciones y países. \nProblema 2: Múltiples fuentes y formatos \n Existe una distribución inherente de los datos e información repartidos entre \nfuentes muy diversas como bases de datos y portales web entre otras. Incluso los \ndocumentos públicos aportados por las diferentes entidades, aparecen en formatos tan diversos como puedan ser HTML, XML, WML, VoiceXML etc. y a su vez dicha \ninformación debe ser tratada por diferentes usuarios como puedan ser las propias \nadministraciones de tráfico o por los conductores o viajeros. En el dominio de los ITS el \ntratamiento de la información y las consecuencias de este tratamiento, como la toma de \ndecisiones o la simple consulta de este tipo de información han sido hasta la fecha \naltamente dependientes del conocimiento humano. \nProblema 3: Gran volumen de información distribuido \n La difusión de información de tráfico abarca un gran abanico de posibilidades \nque hacen que el tratamiento de la información se deba abordar de manera eficaz. El \nusuario se ve obligado a tratar con un gran volumen de información que aparece a su \nvez distribuida por los diferentes portales web de administraciones o entidades privadas \nque la ofrecen. A su vez la aparición de múltiples dispositivos de usuario final ha dado \nlugar a que desde el punto de vista del usuario haya una gran dificultad para encontrar \nestos lugares y tratar con las diferentes representaciones y accesos a la información. \nProblema 4: Imposibilidad de almacenaje de toda la información \n Por otra parte, un usuario puede necesitar información de diferente naturaleza, y \npor lo tanto el almacenaje de toda esta información en un solo sitio web no es viable a \nnivel de costes de almacenamiento ni incluso a nivel de mantenimiento. \nProblema 5: Carencia de descripciones semánticas y de servicios web \n Tal y como se describe en el problema 1, los vocabularios o lenguajes que \ndescriben conceptos y estructuras de datos relacionados con tráfico suelen ser Ad Hoc \npara cada aplicación siendo además descripciones de tipo sintáctico, carentes de \nsemántica. Hasta donde llegó la búsqueda y revisión bibliográfica de esta tesis, no se \nencontraron ontologías o vocabularios con valor semántico que aporten sign ...
#  'La minería de texto es el área de investigación más reciente del procesamiento de\ntextos. Ella se define como el proceso de descubrimiento de patrones interesantes\nen una colección de textos. Estos patrones no deben de existir explícitamente en\nningún texto de la colección, y deben de surgir de relacionar el contenido de varios\nde ellos (Hearst, 1999; Kodratoff, 1999).\nEl proceso de minería de texto consiste de dos etapas principales: una etapa de\npreprocesamiento y una etapa de descubrimiento (Tan, 1999). En la primera etapa, \nlos textos se transforman a algún tipo de representación estructurada o semiestructurada que facilite su posterior análisis, mientras que en la segunda etapa las representaciones intermedias se analizan con el objetivo de descubrir en ellas algunos patrones interesantes o nuevos conocimiento.\nEntonces, dependiendo del tipo de métodos aplicados en la etapa de preprocesamiento son el tipo de representaciones intermedias construidas, y en función de\ndicha representación son el tipo de métodos usados en la etapa de descubrimiento, y \nen consecuencia, el tipo de patrones descubiertos.\nLa figura 1.1 muestra las principales estrategias usadas en los actuales sistemas\nde minería de texto. De acuerdo con esta figura, la mayoría de los actuales de minería de texto limitan sus resultados a un nivel temático o de entidad, y por lo tanto\nimposibilitan el descubrimiento de cosas más detalladas como:\n\t\t*\tConsensos, que por ejemplo respondan a preguntas como: * ¿Cuál es la opinión\nmayoritaria de los mexicanos sobre el gobierno de Fox?\n\t\t*\tTendencias, que indiquen por ejemplo si han existido variaciones en la postura de \nFox con respecto a la educación.\n\t\t*\tDesviaciones, que identifiquen por ejemplo opiniones "raras\x9d con respecto al desempeño de la selección mexicana de fútbol.\nUna idea para mejorar la expresividad y la diversidad de los descubrimientos de\nlos sistemas de minería de textos consiste en usar una representación del contenido\nde los textos más completa que las representaciones usadas actualmente. Siguiendo \neste enfoque, en esta investigación se propone usar los grafos conceptuales (Sowa,\n1984; 1999) como representación del contenido de los textos. \nLos grafos conceptuales se seleccionaron de entre otras representaciones (por\nejemplo, árboles sintácticos, predicados lógicos y KL-ONE) por las siguientes razones:\n1. Los grafos conceptuales permiten representar adecuadamente en términos de\nexpresividad y eficiencia notacional la información en lenguaje natural.1\n2. Los grafos conceptuales disponen de mecanismos formales que facilitan su manipulación, transformación y análisis (ver sección 3.2).\n3. Los grafos conceptuales se usan en otras tareas afines a la minería de texto, por\nejemplo en la recuperación de información y en el agrupamiento de textos.\nAhora bien, realizar la minería de texto usando los grafos conceptuales como representación del contenido de los textos involucra dos problemas diferentes. En primer lugar, la transformación de los textos en grafos conceptuales, y en segundo lugar, el análisis automático de un conjunto de grafos conceptuales.\nLa transformación de los textos en grafos conceptuales es un problema complejo \nvinculado con su análisis sintáctico y semántico (Sowa and Way, 1986; Sowa 1991). \nDebido a ello, todos los métodos que existen para realizar dicha transformación se\nenfocan en un dominio único y restringido. Algunos ejemplos son los siguientes:\n\t\t*\tPartes de artículos científicos a grafos conceptuales (Myaeng and Khoo, 1994;\nLópez-López, 1995; Montes-y-Gómez, 1998; Montes-y-Gómez et al., 1999e).\n\t\t*\tPartes de expedientes médicos a grafos conceptuales (Baud et al., 1992; Rassinoux et al., 1994).\n\t\t*\tPartes de casos legales a grafos conceptuales (Boucier and Rajman, 1994).\n\t\t*\tPartes de manuales de referencia a grafos conceptuales (Petermann, 1996).\nPor su parte, el análisis automático de un conjunto de grafos conce ...
#  'El objetivo de la desambiguación de los sentidos de las palabras es determinar el\nsignificado correcto, o el sentido de una palabra dada en el contexto. Este se consi-\ndera como uno de los problemas más difíciles en el nivel léxico del procesamiento del\nlenguaje natural [2], [3] y es fundamental en aplicaciones de traducción automática,\nrecuperación de información, etc.\nLas dificultades provienen de algunos orígenes, incluyendo la falta de medios para\nformalizar las propiedades o parámetros del contexto que caracterizan el uso de una pa-\nlabra ambigua en un sentido en particular y la falta de un inventario de sentidos usuales.\nEntre los enfoques que existen para WSD, el de aprendizaje supervisado es el más\nexitoso hasta la fecha [4]. En este se emplea un corpus en el que cada ocurrencia de una\npalabra ambigua w ha sido manualmente anotada con el sentido correcto, de acuer-\ndo con la existencia de sentidos en un diccionario. De esta forma, este corpus sirve\ncomo material de entrenamiento para el algoritmo de aprendizaje, cuyo resultado es\nun modelo automáticamente aprendido y que puede ser usado para atribuir el sentido.\nLos corpus empleados en la tarea de clasificación supervisada, requieren una gran\ncantidad ejemplos para cada sentido de la palabra. Este requisito hace al enfoque su-\npervisado impracticable al tratar de desambiguar todas las palabras en los textos. Este\nproblema ha sido llamado: obstáculo de adquisición de conocimientos [5].\nHa sido reconocido que la mejor manera adquirir etiquetas de sentidos para las pa-\nlabras en un corpus es a mano [6]. Sin embargo, la formulación manual de inventarios\nde sentidos ha estado basada en la intuición de los lexicógrafos y se ha visto afectada de\nproblemas que incluyen el alto costo, la asignación arbitraria del significado a palabras\ny el emparejamiento equivocado a dominios de aplicación [7].\nDebido a los anteriores inconvenientes, los acercamientos no supervisados han re-\ncibido mucha atención en los últimos años, pues tienen el potencial para superar el\ncuello de botella de adquisición de sentidos. Esto lo han conseguido con la introducción\ndel sentido de la palabra directamente del corpus. Sin embargo, lo que parece a simple\nvista una ventaja, constituye también su principal desventaja: la desambiguación se\nlleva a cabo partiendo de un conjunto no muy bien definido de sentidos, lo que conlle-\nva en muchas ocasiones a la obtención de resultados pobres durante el proceso de WSD.</Problema>\n',
#  'El área de reconocimiento automático de emociones ha sido un área de investigación muy activa en \nlos últimos años, no obstante aun no hay una solución clara para este problema. Diversos \ninconvenientes han influido en la construcción de una solución apropiada. Por un lado, un factor \nque afecta el desempeño de los reconocedores de emociones en contextos reales es la dificultad de \ngenerar bases de datos con emociones espontáneas. Generalmente se ha trabajado con bases de \ndatos actuadas las cuales proporcionan "Retratos de emociones" representando expresiones \nprototípicas e intensas que facilitan la búsqueda de correlación acústica y la subsecuente \nclasificación automática, sin embargo, no se han tenido buenos resultados al trasladar el \nconocimiento extraído de estas bases de datos a contextos reales (Steidl, 2009). \nLas características de las bases de datos actuadas son: \n1. Los "Retratos de emociones" representando expresiones prototípicas e intensas facilitan la \nbúsqueda de correlación acústica y la subsecuente clasificación automática. \n2. Las grabaciones en estudio con alta calidad eliminan problemas en el procesamiento de la \nseñal. Por ejemplo ruido o reverberación. \n3. Se puede garantizar una cantidad balanceada de ejemplos por clase. \nEn contraparte, las bases de datos con emociones espontáneas muestran elocuciones con contenido \nemocional no perteneciente a una sola clase, sino que son una mezcla de emociones. En otros casos, \nexisten elocuciones con una carga emocional muy ligera, cercana a un estado emocional neutro. \nAdemás, las bases de datos con emociones espontáneas suelen grabarse en ambientes ruidosos \ncomo conversaciones telefónicas o programas de televisión lo que conlleva la inclusión de ruido. \nFinalmente, por la naturaleza misma del problema no es posible asegurar una cantidad balanceada \nde ejemplos por clase. \nOtro reto a resolver es la identificación de un conjunto de características acústicas que permitan \nreconocer emociones en el habla espontánea. El trabajo hecho a la fecha se ha centrado \nprincipalmente en características relacionadas con aspectos prosódicos. Sin embargo, se ha \ndescubierto que entre más nos acercamos a un escenario realista, menos fiable es la prosodia como \nun indicador del estado emocional del hablante (Batliner, et al., 2003), por lo tanto es necesario \nencontrar características que complementen la información que proporciona el aspecto prosódico de \nla voz. \nFinalmente, hasta la fecha la mayoría de los trabajos han utilizado modelos emocionales discretos, \ndonde las emociones a reconocer están claramente identificadas en el corpus de entrenamiento. Bajo \neste enfoque no existe una valoración de la emoción sino la búsqueda de una o varias reglas que \npermitan la discriminación de las emociones en cuestión. De esta forma, es prácticamente necesario \nrepetir todo el trabajo si se desea agregar una nueva emoción o se desea trabajar con otro corpus. \nAdemás los modelos discretos no parecen ser los más adecuados para trabajar con emociones \nespontáneas ya que no representan apropiadamente el traslape de emociones en el habla. \nA pesar de que los avances en el área han sido importantes, se ha comprobado que en contextos \nrealistas aún falta mucho por hacer. Por lo tanto, es necesario proponer y explorar otros enfoques \nque permitan llegar a un buen desempeño del reconocimiento de emociones en aplicaciones del \nmundo real. Para ello, en esta tesis se propone trabajar con características diversificadas que \nexpandan el uso de características acústicas y lingïsticas, además de emplear un modelo continuo que nos permita apegarnos más a la realidad. Nuestro trabajo estará basado en un modelo continuo \ntridimensional cuyas primitivas son Valencia, Activación y Dominación. Se emplearán \nprincipalmente características acústicas, que incluyen características prosódicas, de calidad de voz, \ny espectrales. Se explorará el uso de característica ...
#  'Esta tesis parte de considerar que las tecnologías en general y las TIC en \nparticular no son neutrales ni autónomas. \nEn tal sentido, una de las premisas clave de las que se parte tiene que ver con \nla idea de que una pieza de tecnología adquiere su significado dentro de grupos \nsociales más amplios. Es decir, no se desarrolla bajo su propia lógica técnica \ninmanente. Las tecnologías adquieren significados en el mundo social y estos \nsignificados dan forma y constriñen su desarrollo. A menudo en las etapas iniciales de \nsu producción, se conciben diferentes significados de una tecnología, algunos \nenfrentados entre sí.\nLa concepción "instrumentalista\x9d de la tecnología, es decir, aquella que \nconsidera que las tecnologías son simples herramientas o artefactos construidos para \nuna diversidad de tareas, colabora a consolidar la percepción de la misma como algo \n"neutral\x9d. El problema mayor de ese planteo es que considera que la tecnología es \nindependiente de cualquier sistema político o social y así cualquier tecnología puede \nser transferida de un espacio social a otro sin mayores consecuencias. \nEn esta tesis se considera que tales cosmovisiones son reduccionistas y \nesconden el potencial peligro que acarrea ignorar las redes de intereses sociales, \neconómicos y políticos de aquellos que diseñan, desarrollan, financian y controlan la \ntecnología (González García, López Cerezo y Luján López, 2000).\nEl desarrollo de la informática agudizó la percepción de la centralidad de lo \ntecnológico en los procesos de cambio social. Al mismo tiempo, pareciera que tales \nprocesos demandan, promueven o motivan cambios tecnológicos. La importancia de lo \ntecnológico ha alcanzado una relativa centralidad entre investigadores provenientes de \ntradiciones disciplinares diversas, no obstante, la pregunta por el "cómo\x9d se articulan tales cambios junto a otros político institucionales, organizacionales, económicos, \ncognitivos, simbólicos y territoriales, es crucial y aún permanece abierta. \nSi bien pareciera haber cada vez más esfuerzos por sistematizar teorías en \ntorno a distintas problemáticas de las TIC, los términos, las formulaciones y hasta las \ndescripciones se revelan como insuficientes frente a las dimensiones de un fenómeno \nque no termina de "estabilizarse\x9d. En efecto, apenas una configuración de sentido \ncomienza a consolidarse se produce algún cambio en la tecnología que obliga a \nrevisar lo que hasta hace poco se pensaba. Para Castells (2002) el "paradigma de la \ntecnología de la información\x9d no evoluciona hacia su cierre como sistema, sino hacia \nsu apertura como una red multifacética. Es poderoso e imponente en su materialidad, \npero adaptable y abierto en su desarrollo histórico. Sus cualidades decisivas son su \ncarácter integrador, la complejidad, la interconexión y la generación de redes.\nLa incertidumbre surge en este escenario caracterizado por la complejidad de \nun entorno cada vez más abierto. Así, resulta central contar con un adecuado corpus \nteórico para el estudio específico de las TIC. Por supuesto, en esta finalidad hay \ndesafíos complejos ya que por un lado, se debe tener en consideración la "flexibilidad\x9d \nque imponen los cambios tecnológicos y, por otro lado, debe ser posible enmarcar a \nlos distintos campos del desarrollo de las TIC. En un escenario marcado por la \ninestabilidad y velocidad del cambio junto a la obsolescencia de teorías, es importante \ncontribuir en la consolidación de conocimientos así como en la descripción de \nexperiencias, a fin de ir constituyendo un corpus que permita aproximar a la \ncomprensión de los fenómenos en su singularidad. En tal sentido, a medida que las \nTIC se "difunden\x9d en la vida cotidiana y se internalizan y "naturalizan\x9d determinados \nusos tecnológicos, se desconoce cuán complejo es el funcionamiento interno de la \ntecnología lo que contribuye a crear una "percepción mágica\x9d sobre las TIC. Esta idea ...
#  'Actualmente nos encontramos en la denominada Sociedad Red, que de acuerdo a \nCastells (2000), es una sociedad que se generó de la revolución tecnológica de la \ninformación y el florecimiento de las redes sociales, creando una nueva estructura social \ndominante con una nueva economía informacional/global y una nueva cultura de la \nvirtualidad/real. Este nuevo tipo de sociedad se inició aproximadamente en los años 60 \ndel siglo pasado, con la incorporación de una serie de nuevas tecnologías y medios que \ntuvieron como finalidad como señala MacLuhan (1964) de extender el cuerpo y la \nmente. La Sociedad Red ha traído consigo una serie de transformaciones tanto en los \naspectos económicos, políticos, sociales, culturales, comunicacionales, tecnológicos, \npsicológicos y también educativos. Castells (2006), establece que estamos en los inicios \nde la Sociedad Red y que a futuro se avizora una serie de transformaciones en diversos \ncampos incluidos en el educativo. \nUn aspecto importante de la Sociedad Red es que no todos los países se vienen \nincorporando de una manera homogénea, sino que existen grandes diferencias en \ndiversos aspectos tal como refiere (Barbero, 2005, p.14) "la brecha digital en realidad es \nuna brecha social\x9d. Mientras que en los países desarrollados cerca del 80% de hogares \ntienen acceso a Internet en los hogares de Lima de acuerdo al reporte del Instituto \nNacional de Estadística e Informática del Perú (2008) el 26,4% disponen de una \ncomputadora y el 14,7% tienen instalado acceso a Internet en el hogar. \nUn fenómeno muy importante que se debe tomar en cuenta en el campo educativo, es \nque actualmente de acuerdo a APOYO (2008) el acceso a las nuevas TIC en este caso al \nInternet, especialmente por la generación joven entre los 12 y 17 años de edad es en el \n95% en forma permanente, la cual se da principalmente en las cabinas públicas de \nInternet. Aparte del acceso en las cabinas públicas, también se inició con el Proyecto \nHuascarán, el acceso a Internet en las instituciones educativas. Con esto se evidencia el \nmayor acceso de los jóvenes a la computadora y el Internet, incluso en las instituciones \neducativas. \nEn este marco, en el Perú desde el año 2002 se viene implementando paulatinamente la \nintegración de las TIC en el sistema educativo de la educación básica, habiéndose \niniciado con el Proyecto Huascarán y desde el año 2007 a través de la Dirección de \nTecnologías Educativas del Ministerio de Educación. La visión de la integración de las TIC en el sistema educativo peruano es crear entornos de aprendizaje con mejor calidad \ny mayores oportunidades educativas, en el marco de una política intercultural y \nbilingüe, mediante la generación de un proceso sostenido de la aplicación de tecnologías \nde información y comunicación en todos los niveles y procesos del sistema educativo. \nLos estudiantes que están inmersos en la integración de las TIC, estudian semanalmente \nen las Aulas de Innovación Pedagógica en promedio 4 horas pedagógicas, siendo al mes \naproximadamente 16 horas y durante el año escolar 144 horas pedagógicas. \nAsí, los estudiantes de educación básica vienen teniendo un acceso e interacción muy \nimportante de forma regular y planificada a las nuevas TIC, es decir a la computadora e \nInternet. Esto implica que los estudiantes al estar en contacto con las nuevas TIC, \nvienen teniendo efectos tanto CON la tecnología y efectos DE la tecnología. El efecto \nCON la tecnología está referido a un mejor desempeño académico en el desarrollo de \nlas asignaturas que cursan regularmente como son matemática, comunicación, ciencias \nsociales, entre otras y el efecto DE la tecnología comprende los residuos cognitivos que \nse van generando y que se concretizan en "nuevas capacidades tecnológicas\x9d, a las \ncuales las denominamos las capacidades TIC.</Problema>\n',
#  'Los avances en la tecnología y las técnicas criptográfi\x81cas han hecho posible considerar a\nlas votaciones electrónicas como una alternativa factible para las elecciones tradicionales.\nLos medios de comunicación como el Internet y los dispositivos electrónicos como las\ncomputadoras personales, los teléfonos celulares, tarjetas inteligentes, etc., facilitan la\ncaptura, transmisión y recepción del voto, permitiendo así un sistema de elecciones más\ncómodo para los votantes y más efi\x81ciente para las autoridades electorales.\nSin embargo, la efi\x81ciencia y la comodidad que ofrecen los esquemas de votación\nelectrónica abren la puerta a distintos problemas de los ya existentes en las votaciones\ntradicionales. Por ejemplo, la identifi\x81cación del votante no es tan simple en las votaciones\nelectrónicas como lo es en las convencionales, si se considera que el votante debe ser\nidentifi\x81cado antes de votar y a su vez su identidad debe ser anónima al momento de\nemitir el voto.\nOtro problema es la auditoria de la elección. En las votaciones tradicionales, el resguardo de las boletas electorales impresas ofrece una garantía de escrutinio. Si existieran\ndudas o desconfi\x81anza en los resultados fi\x81nales, bastaría con realizar un recuento de votos\npara verifi\x81car la validez del resultado fi\x81nal. De manera electrónica, el voto es capturado y\ntransmitido hasta la urna electoral electrónica para ser contabilizado al fi\x81nal del periodo\nde votación, sin alguna comprobación contundente que asegure al votante que su voto\nfue correctamente recibido y contabilizado.\nLo que indican los problemas mencionados es que, considerando que Internet es un\ncanal inseguro de comunicación, son necesarios los esquemas de seguridad para votaciones electrónicas que permitan ofrecer la seguridad y la privacidad requeridas en todo\nproceso electoral. Sin embargo, no siempre es obvia la forma de alcanzar tales características a un precio razonable, debido al hecho de que cuando un proceso electoral se\nlleva a cabo, los mecanismos que aseguran tanto la seguridad como la privacidad pueden\nser demasiado costosos para los administradores (entidades electorales) por un lado, e inconvenientes para los usuarios (votantes) por el otro. En este sentido, un sistema de\nvotación electrónica no puede ser completamente automatizado. No obstante, mediante\nel uso de herramientas criptográfi\x81cas, es posible satisfacer los requisitos de seguridad\nmás importantes asociados a los esquemas de votación electrónica.\nEn esta tesis estamos interesados en los sistemas de votación electrónica los cuales\nutilizan Internet para transmitir los votos. Informalmente, este tipo de sistemas se puede\ndefi\x81nir como sigue.\nDefi\x81nición 1.1.1. Un sistema electrónico de votación por Internet es un sistema de\nelección que genera boletas electorales electrónicas, que permite a los votantes emitir\nsu voto desde un dispositivo electrónico y transmitirlo por Internet hacia la urna electoral también electrónica donde será depositado y contabilizado al término de la jornada\nelectoral.\nDe manera general, un sistema de votación electrónica por Internet debe cubrir todos los\nrequisitos funcionales del proceso electoral, así como los servicios de seguridad necesarios\npara protegerse de potenciales ataques provenientes de la red. Algunos de los requisitos\nesenciales son los siguientes.\n. Autenticación: sólo los votantes incluidos en el padrón electoral serán autorizados\npara emitir su voto.\n. Anonimato y no coerción: nadie debe ser capaz de determinar el valor del voto ni\nde vincularlo con el votante.\n. Unicidad: ningún votante debe votar más de una sola vez.\n. Integridad: los votos no pueden ser modifi\x81cados, olvidados o borrados sin ser detectado.\n. Verifi\x81cación y auditoría: debe ser posible verifi\x81car que al fi\x81nal del proceso electoral,\ntodos los votos fueron contados correctamente, demostrando así la honorabilidad\ndel sistema. ...
#  'Las imágenes adquiridas remotamente son empleadas para la construcción de mapas \ntemáticos. Estos mapas pueden ser generados a través de un proceso de análisis de \nimágenes. Normalmente, este proceso incluye etapas como segmentación, extracción de \nlas características de las regiones de interés y la etapa de clasificación. La clasificación de \nimágenes sensadas remotamente se refiere al reconocimiento de las coberturas de cada \ntipo de suelo presentes en la superficie terrestre.\nEn el contexto de las imágenes sensadas remotamente, las coberturas presentes en la \nsuperficie terrestre incluyen zonas urbanas, zonas de vegetación (bosque, pastizales, \nmanglares, etc.), cuerpos de agua (mares, ríos, lagos, etc.), y zonas dedicadas al cultivo de \nplantas, entre otras coberturas.\nLa extracción de mapas temáticos a partir de la clasificación de imágenes sensadas \nremotamente es un área de investigación importante por la aplicación que éstos tienen \npara la obtención de conocimiento del medio ambiente global, usos de suelo, recursos \nrenovables y no renovables, desastres naturales, geología y muchos otros. Por lo anterior, \nse trabaja en la obtención mapas de alta calidad, lo cual no se ha logrado del todo con los \nesquemas de clasificación utilizados hasta el momento.\nHistóricamente, los ecologistas han estudiado regiones homogéneas para caracterizar y \nentender los procesos de los ecosistemas y han evitado las áreas heterogéneas entre \necosistemas. Como resultado, las zonas de transición han sido frecuentemente ignoradas \no reducidas a líneas sobre un mapa temático. Sin embargo, estas zonas de transición, \nllamadas "ecotonos\x9d, controlan el flujo de materiales entre ecosistemas y la influencia de \nla biodiversidad [Fortin, 2000].\nEn la generación de estos mapas temáticos, la mejor calidad en la clasificación se presenta \ncuando se clasifican las coberturas que son básicamente homogéneas. Una cobertura \nhomogénea se considera aquella que está constituida por una sola cobertura. El paso de \nuna cobertura a otra, por ejemplo, al pasar de bosque a suelo descubierto, no se realiza \nde manera abrupta sino de una forma gradual, generándose una zona de transición \nformada por las coberturas homogéneas (en este caso, por el bosque y el suelo \ndescubierto), ver figura 3.1. Esta zona de transición genera límites indeterminados y se \nencuentra compuesta de manera proporcional por las coberturas que la delimitan. Debido \na esto determinar esta composición no resulta trivial para los esquemas usados.</Problema>\n',
# ...
#  'Planteamiento \n\nLa Teoría de Conjuntos Difusos y la Lógica Difusa [KY95, Zad65, Zim96,\nDP97] son una gran herramienta para manejar situaciones de incertidumbre\ninherentes a sistemas complejos. Cualquier sistema dinámico o estático que hace uso\nde estas herramientas, se considera un Sistema Difuso [DP97]. \n\nLos Sistemas Difusos han demostrado su habilidad para resolver diferentes \ntipos de problemas tales como control [Zha95, DHR93, SYZL05, SGB05, PRG+04],\nmodelado [Ped96, SY93, TS85, Jin00, HD97a] o clasificación [MB05, Kun00,\nCYP96, Leo99, Jin03]. Asimismo, han sido empleados en un amplio rango de\naplicaciones, por ejemplo, procesamiento de señales e imágenes [CYP96, DP97,\nST99, SISM01], evaluación de riesgos [LH04, Leo99, Jin03],  recuperación de\ninformación [CHL01, Miy89], procesos industriales [Jin03, Leo99, HS95, BBC+95,\nDO01], etc. En muchos de los casos, la clave del éxito era la incorporación del\nconocimiento experto humano. Sin embargo, muchas de las investigaciones\nrealizadas en el campo durante los años 90 no contienen capacidad de aprendizaje y\nadaptación. En la última década, ha existido un gran interés en incluir capacidad de\naprendizaje a los sistemas difusos. Esto se ha logrado por medio del desarrollo de\ntécnicas híbridas que incluyen los sistemas difusos junto con técnicas\ncomplementarias como lo son las redes neuronales, los algoritmos evolutivos  o  los\nmétodos probabilísticos. \n\nExiste consenso entre los investigadores en que se pueden obtener sistemas más \ninteligentes por medio de la hibridación de metodologías de Soft Computing\nOva04], haciendo de este modo que las debilidades de unos sistemas se compensen\ncon las bondades de otros.  Los  Sistemas Neurodifusos (SNDs) y los Sistemas\nDifusos Evolutivos (SDEs) constituyen la más notoria representatividad de sistemas\nhíbridos dentro de Soft Computing. Estos sistemas mezclan los métodos de\nrazonamiento aproximado de los sistemas difusos con las capacidades de aprendizaje\nde las Redes Neuronales (RNs) y los Algoritmos Evolutivos (AEs), respectivamente.\nHay numerosas investigaciones en ambos temas pero los más usados han sido los\nSNDs [JSM97, NKK97, Ful99]. Sin embargo, se han obtenido resultados muy \nprometedores en los últimos años para los SDEs [CHL96, CHL97a, CHL97b, HV96, \nPed97, SSZ97, Tet95, CHHM01, CPC04, CCdJH05, ACP06].  \n\nUn Sistema Difuso Evolutivo [CH95, CHHM01, HM97] es básicamente un \nsistema difuso robustecido por un proceso de aprendizaje basado en un AE [Bäc96],\nen particular los Algoritmos Genéticos (AGs) [Gol89, Hol75, Mic96], los cuales están\nconsiderados actualmente como la técnica de búsqueda global más conocida y\nempleada. Este tipo de algoritmos presentan la capacidad de explorar y explotar\nespacios de búsqueda complejos, lo que les permite obtener soluciones muy próximas\na la óptima en dichos espacios. Además, la codificación genética que emplean les\npermite incorporar conocimiento a priori de una forma muy sencilla y aprovecharlo\npara guiar la búsqueda. \n\nEn esta memoria, se proponen SDEs que mejoran la técnica de modelado y \nsimulación denominada Razonamiento Inductivo Difuso (FIR^2). Se persigue\naprovechar las potencialidades de los AGs para aprender los parámetros de\ndiscretización de la metodología FIR, es decir, el número de clases por variable\n(granularidad) y las funciones de pertenencia (landmarks) que definen su semántica.\nDebido al hecho que es una metodología basada en lógica difusa, la eficiencia en el\nmodelado y predicción de FIR está influenciada de forma directa por estos\nparámetros de discretización.  \n\nFIR surge o emerge del enfoque del Resolvedor de Problemas de Sistemas\nGenerales (GSPS^3) propuesto por Klir [Kli85] y es una herramienta para el análisis\nde sistemas generales que permite estudiar los modos de comportamiento de los\nsistemas dinámicos. Realiza dos tareas principales, la primera es identificar las\nrelaciones causales entre las variables del si ...
#  'Diferentes modelos de redes neuronales artificiales son ampliamente estudiadas en [1, 2],\nlas cuales se pueden clasificar dependiendo del flujo de datos a través de la red, como redes\nneuronales estáticas y redes neuronales recurrentes. En las redes neuronales estáticas, el flujo\nde datos siempre es en dirección de entrada a la salida de la red neuronal, mientras que en la\nred neuronal recurrente el flujo de datos se mueve de entrada a la salida de la red neuronal más\nuna realimentación de los datos de salida a la entrada y capas interiores de la red neuronal.\nOtra forma de clasificar las redes es por el tipo de aprendizaje, si la red neuronal se entrena\ncon un conjunto de datos, previo a su trabajo con el sistema o proceso se le conoce como\n“aprendizaje fuera de proceso”, en cambio si la red neuronal aprende en tiempo real cuando se\ntrabaja mutuamente con el sistema se llama “aprendizaje durante el proceso” [3, 4].\nLa clase de sistemas o procesos que se tratan en esta tesis son modelados por ecuaciones\ndiferenciales [5, 6, 7, 8], sin embargo, los mecanismos que se tratan en esta tesis solo se conocen\nla estructura del modelo. Por ejemplo, si\nx˙ =f(x) + g(x)u,\ny =h(x),\nes un modelo de algún sistema en particular, donde f : IRn → IRn\n, g : IRn → IRn×r\n, el vector de\ncontrol u ∈ IRr\npara r ≤ n, con variables de estado x ∈ IRn\ny el vector de salida y : IRn → IRm,\nentonces dada la forma de la representación del modelo dinámico se conoce su estructura, pero\nlas funciones f(x), g(x) y h(x) son desconocidas.\nLos sistemas dinámicos se clasifican de acuerdo a su grado de actuación (número de actuadores\nrespecto a los grados de libertad del sistema), en sistemas completamente actuados [6] y\nsistemas subastados [9]. Los sistemas completamente actuados tienen igual número de actúa dores que grados de libertad del sistema, mientras que los subastados tienen menos actuadores\nque grados de libertad y son más difíciles de controlar. Los modelos dinámicos con alto grado de\nincertidumbre, no integran todas las dinámicas del sistema físico, como la fricción, zona muerta,\nsaturación, vacilas (“perdida de movimiento en un mecanismo causado por la holgura entre\nsus partes”) y dinámicas desconocidas, entonces es conveniente el uso de redes neuronales, dado\nque tienen la capacidad de aprender y adaptarse al sistema.\nRecientemente los avances en el ´área de redes neuronales han dado un gran impulso al\ncontrol de sistemas no lineales a través de procesos de aprendizaje. En los sistemas de control,\nse aprovecha la capacidad de la red neuronal de modelar funciones diferenciales no lineales,\nla habilidad de aprender y adaptarse en tiempo de ejecución del proceso [3, 4, 10, 11]. Por\nejemplo, Narendra y Parthasarathy [4] demuestran que las redes neurales pueden ser usadas\nefectivamente para la identificación y control de procesos dinámicos no lineales.\nUn problema en el control de mecanismos es la determinación del modelo dinámico, ya sea\npor lo difícil de obtener un modelo dinámico del sistema [5, 6], por el desconocimiento de los\nparámetros del modelo o de algunas de sus dinámicas. Las redes neuronales, como una clase\nde sistemas adaptativos [12, 13], son ´útiles en tales situaciones, ya que pueden adaptarse a la\ndinámica del sistema que se desconoce.\nLos controladores neuronales con aprendizaje durante el proceso, permiten controlar los\nsistemas dinámicos sin la necesidad de un entrenamiento previo de la red neuronal, además, el\ndesempeño de la red neuronal no está sujeto a un entrenamiento realizado por un conjunto de\ndatos delimitados.\nUn controlador basado en retroalimentación, es confiable si ´este es respaldado por un estudio\nde estabilidad. Es importante notar que algunos trabajos de investigación de controladores\nneuronales que están en la literatura, no tienen un estudio de estabilidad del sistema dinámico\nen lazo cerrado, por lo que la confiabilidad de los controladores propuestos es degradada.\ ...
#  'El incremento en potencia es crucial para alcanzar la relación señal a ruido deseada en el\nreceptor, ya que la señal no pudiera ser detectable [42]. Para hacer posible la comunicación\ninalámbrica con un amplio ancho de banda es necesario basarse en esquemas de multiplexación\ncomplejos como Acceso Múltiple por División de Código de Banda Ancha (WCDMA) y\nMultiplexación por División de Frecuencias Ortogonales (OFDM), y otras técnicas de modulación\ncomo 16-, 32-, 64-, 128- Modulación de Amplitud en Cuadratura (QAM) o incluso 256-\nModulación por Desplazamiento de Fase (QPSK). Al momento de transmitir altas tasas de datos\nse produce un recrecimiento espectral cuando se agregan efectos de memoria y no linealidades\ndebido a las características intrínsecas del PA.\nEl PA es el dispositivo en la etapa del transmisor que agrega la mayoría de las no linealidades y\nefectos de memoria. Existen esfuerzos en la investigación basados en polinomios y modelos que\ntoman en cuenta la memoria y otros basados en redes neuronales. Sin embargo, no existe una\nplataforma completa capaz de emular en hardware comportamientos adecuados de PAs donde\nparta de las mediciones de las curvas de distorsión AM/AM y AM/PM y otorgue una integración\nde modelos que permitan niveles de no linealidad y orden de memoria variables con modelos\npolinomiales con memoria y de aprendizaje, además de algoritmos adaptativos que permitan\nmodelar PAs con comportamientos más complejos.\nEl PA es el componente principal en el consumo de energía en la etapa del transmisor y es\nnecesario establecer un compromiso entre linealidad y su eficiencia. Para lograr este propósito\nes crucial contar con modelos de comportamiento donde se tenga un nivel variable de memoria\ny de no linealidad.\nLa linealización de PAs se ha convertido en un área de gran interés en los sistemas de\ncomunicación inalámbrica modernos. Para ellos se requieren modelos de comportamiento que\ndescriban fielmente el funcionamiento del PA. Cabe indicar que existen diversas técnicas para\nlograr este proceso de linealización, lo cual contribuye a lograr una eficiencia en potencia del PA\nal trabajarlo linealmente. Por mencionar algunos métodos comúnmente utilizados se encuentra\nla prealimentación, la retroalimentación o la predistorsión analógica [43]. Los modelos\nmencionados son eficientes para aplicaciones de baja frecuencia, pero a frecuencias altas, estas\ntécnicas pueden sufrir pérdidas de estabilidad [2].\nLos efectos producidos por las no linealidades en los PAs repercuten de dos maneras, por un\nlado causan recrecimiento espectral, dando lugar a interferencias en los canales de transmisión\nadyacentes (distorsión fuera de banda de operación asignada), mientras que por otro lado,\ncausan distorsión dentro de la propia banda de transmisión, degradando por tanto la Tasa de\nError de Bits (BER) [9]. Los organismos reguladores fijan a través de los diferentes estándares de\ncomunicaciones, los niveles máximos permitidos de emisión fuera de banda, así como de los límites de distorsión en la banda, por ejemplo especificando porcentajes máximos de error en\nlas constelaciones. Las sanciones por violar cualquiera de las especificaciones como son\npotencia de transmisión, emisión fuera de banda entre otras son multas elevadas.\nLas series de Volterra pueden ser usadas para describir un sistema estable no lineal con pérdida\nde memoria con un error arbitrario pequeño. Sin embargo, las desventajas principales son el\nincremento dramático del número de parámetros con respecto al orden de no linealidad y\nprofundidad de memoria lo cual causa un incremento drástico de la complejidad de cálculo e\nidentificación de parámetros. Esta es la razón por la que resulta altamente impráctico el uso de\nlas series completas de Volterra para representar matemáticamente el comportamiento de\nsistemas con alta no linealidad y profundidad de memoria por lo que se requiere el uso de\ntruncaciones como MPM, Wiener y Hammerst ...
#  'Uno de los principales problemas que los sistemas normales de sensado en estructuras\npresentan es que son puntuales y necesitan cableado y protección que resulta pesado,\nincrementado el peso total a la estructura. Además se emplea cableado para alimentación de\nenergía o en un mejor caso se emplean baterías cuando se utiliza comunicación\ninalámbrica. Aunado a esto, en ocasiones se necesita colocar sensores en lugares de difícil\nacceso, así como formar una red de sensores para buscar una mayor exactitud. Lo anterior\ninvolucra un sistema de adquisición limitado por el número de canales, que en caso de\nrequerir de una mayor cantidad de sensores, se necesitará de varios sistemas de adquisición.\nEs necesario entonces, estudiar las técnicas actuales de sensado que emplean diferentes\ntipos de fibras ópticas, tanto estándar como dopadas de tierras raras y el empleo de métodos\nmenos complejos que permitan un sensado confiable.</Problema>\n',
#  'En visiÃ³n artificial, la segmentaciÃ³n de imÃ¡genes es el proceso de particiÃ³n de una imagen digital en mÃºltiples segmentos (conjuntos de pÃ\xadxeles, tambiÃ©n conocidos como\nsuperpÃ\xadxeles). El objetivo de la segmentaciÃ³n es simplificar y / o cambiar la representaciÃ³n de una imagen en algo que es mÃ¡s significativo y fÃ¡cil de analizar. La segmentaciÃ³n de imÃ¡genes se utiliza normalmente para localizar objetos y bordes (regiones, lÃ\xadneas, curvas, etc.) en imÃ¡genes. MÃ¡s precisamente, la segmentaciÃ³n de imÃ¡genes es el proceso de asignar una etiqueta a cada pÃ\xadxel de una imagen de modo que los pÃ\xadxeles con la misma etiqueta comparten ciertas caracterÃ\xadsticas comunes [47].\nEl resultado de la segmentaciÃ³n es un conjunto de segmentos que cubren colectivamente toda la imagen o un conjunto de contornos extraÃ\xaddos de la imagen (ver detecciÃ³n de bordes). Cada uno de los pÃ\xadxeles de una regiÃ³n es similar con respecto a alguna caracterÃ\xadstica o propiedad calculada, como el color, la intensidad o la textura. Las regiones adyacentes son significativamente diferentes con respecto a la misma caracterÃ\xadstica (s) [47].\nâ€œLa segmentaciÃ³n de una imagen consiste en la particiÃ³n de dicha imagen en diferentes\nregiones similares en alguna caracterÃ\xadstica predefinida (â€¦) Los seres humanos usamos\nnuestro sentido visual para separar nuestro entorno inmediato en objetos distintos sin\nesfuerzo alguno para reconocerlos, guiar nuestros movimientos y para casi todas las\nactividades de nuestra vida.â€\x9d (K.N., Plataniotis, y A.N.Venetsanopoulos, 2000, p. 237, traducido).\nLa segmentaciÃ³n es una caracterÃ\xadstica importante de la percepciÃ³n visual humana que se manifiesta de forma espontÃ¡nea y natural; aunque estÃ¡n involucrados procesos complejos\ncomo el anÃ¡lisis de color, la forma, el movimiento, la textura, etc. [1][2][3].\nEl color es una caracterÃ\xadstica visual poderosa y robusta para diferenciar los diferentes objetos en una imagen. Es una importante fuente de informaciÃ³n en el proceso de segmentaciÃ³n y puede en muchos casos ser utilizado como Ãºnica caracterÃ\xadstica y Ãºnico descriptor para la segmentaciÃ³n de los objetos de interÃ©s [1][2][3].\nEn este trabajo de tesis se busca investigar sobre un mÃ©todo propio de segmentaciÃ³n del\ncolor en imÃ¡genes de color. El mÃ©todo sÃ³lo utiliza la informaciÃ³n de color para realizar la segmentaciÃ³n, por lo que se considera como un indispensable paso previo al de\nreconocimiento. En este trabajo no se pretende llegar al reconocimiento de objetos o clases de objetos, sino Ãºnicamente a la segmentaciÃ³n de la imagen en regiones homogÃ©neas de color que podrÃ\xadan ser utilizadas para alimentar a tareas subsecuentes.</Problema>\n']

# %% [markdown]
# ## Structure the Data

# %%
TSU_structured = sepMeth(problemTSU)
Lic_structured = sepMeth(problemLic)
Masters_structured = sepMeth(problemMasters)
Phd_structured = sepMeth(problemPhd)
TSU_structured
Lic_structured
Masters_structured
Phd_structured
# Out:
# {'Problema1': {},
#  'Problema2': {1: 'La',
#   2: 'gran',
#   3: 'cantidad',
#   4: 'de',
#   5: 'información',
#   6: 'disponible',
#   7: 'en',
#   8: 'Internet,',
#   9: 'la',
#   10: 'complejidad',
#   11: 'y',
#   12: 'heterogeneidad',
#   13: 'de',
#   14: 'la',
#   15: 'misma,',
#   16: 'junto',
#   17: 'con',
#   18: 'las',
#   19: 'distintas',
#   20: 'características',
#   21: 'de',
#   22: 'los',
#   23: 'usuarios',
#   24: 'que',
#   25: 'acceden',
#   26: 'a',
#   27: 'dicha',
#   28: 'información,',
#   29: 'así',
#   30: 'como',
#   31: 'la',
#   32: 'gran',
#   33: 'competencia',
#   34: 'existente',
#   35: 'en',
#   36: 'la',
#   37: 'red,',
#   38: 'hacen',
#   39: 'crítico',
#   40: 'que',
#   41: 'el',
#   42: 'desarrollo',
#   43: 'de',
#   44: 'aplicaciones',
#   45: 'basadas',
#   46: 'en',
#   47: 'Web,',
#   48: 'y',
#   49: 'de',
#   50: 'manera',
#   51: 'particular',
#   52: 'los',
#   53: 'sitios',
#   54: 'Web',
#   55: 'educativos',
#   56: 'deban',
#   57: 'contemplar',
#   58: 'no',
#   59: 'solo',
#   60: 'aspectos',
#   61: 'de',
#   62: 'funcionalidad',
#   63: 'sino',
#   64: 'también',
#   65: 'de',
#   66: 'usabilidad,',
#   67: 'tomando',
#   68: 'en',
#   69: 'cuenta',
#   70: 'que',
#   71: 'estas',
#   72: 'aplicaciones',
#   73: 'no',
#   74: 'solo',
#   75: 'deben',
#   76: 'tener',
#   77: 'como',
#   78: 'objetivo',
#   79: 'poner',
#   80: 'a',
#   81: 'disposición',
#   82: 'de',
#   83: 'los',
#   84: 'usuarios',
#   85: 'información',
#   86: 'exacta,',
#   87: 'sino',
#   88: 'orientar',
#   89: 'adecuadamente',
#   90: 'al',
#   91: 'usuario',
#   92: 'en',
#   93: 'su',
#   94: 'búsqueda,',
#   95: 'adecuando',
#   96: 'los',
#   97: 'caminos',
#   98: 'más',
#   99: 'apropiados',
#   100: 'para',
#   101: 'cada',
#   102: 'usuario',
#   103: 'de',
#   104: 'acuerdo',
#   105: 'con',
#   106: 'sus',
#   107: 'objetivos,',
#   108: 'sus',
#   109: 'conocimientos',
#   110: 'previos',
#   111: 'o',
#   112: 'sus',
#   113: 'necesidades',
#   114: 'y',
#   115: 'perfiles.',
#   116: 'La',
#   117: 'usabilidad',
#   118: 'en',
#   119: 'este',
#   120: 'contexto,',
#   121: 'se',
#   122: 'enmarca',
#   123: 'en',
#   124: 'una',
#   125: 'pregunta',
#   126: 'sobre',
#   127: 'si',
#   128: 'una',
#   129: 'aplicación',
#   130: 'Web',
#   131: 'educativa',
#   132: 'es',
#   133: 'lo',
#   134: 'suficientemente',
#   135: 'buena',
#   136: 'para',
#   137: 'satisfacer',
#   138: 'las',
#   139: 'necesidades',
#   140: 'y',
#   141: 'requerimientos',
#   142: 'del',
#   143: 'usuario.',
#   144: 'Es',
#   145: 'decir,',
#   146: 'la',
#   147: 'usabilidad',
#   148: 'corresponde',
#   149: 'a',
#   150: 'una',
#   151: 'variable',
#   152: 'en',
#   153: 'el',
#   154: 'marco',
#   155: 'de',
#   156: 'la',
#   157: 'aceptación',
#   158: 'práctica',
#   159: 'de',
#   160: 'un',
#   161: 'sitio',
#   162: 'Web',
#   163: 'educativo.',
#   164: 'Así,',
#   165: 'para',
#   166: 'que',
#   167: 'un',
#   168: 'sitio',
#   169: 'Web',
#   170: 'pueda',
#   171: 'ser',
#   172: 'utilizado',
#   173: 'para',
#   174: 'alcanzar',
#   175: 'alguna',
#   176: 'tarea,',
#   177: 'tiene',
#   178: 'que',
#   179: 'cumplir',
#   180: 'con',
#   181: 'criterios',
#   182: 'de',
#   183: 'utilización',
#   184: '(es',
#   185: 'decir',
#   186: 'referido',
#   187: 'a',
#   188: 'la',
#   189: 'funcionalidad:',
#   190: 'puede',
#   191: 'hacer',
#   192: 'lo',
#   193: 'que',
#   194: 'se',
#   195: 'necesita)',
#   196: 'y',
#   197: 'usabilidad',
#   198: '(cuán',
#   199: 'bien',
#   200: 'los',
#   201: 'usuarios',
#   202: 'pueden',
#   203: 'usar',
#   204: 'esa',
#   205: 'funcionalidad',
#   206: 'del',
#   207: 'sitio',
#   208: 'Web).',
#   209: 'La',
#   210: 'usabilidad',
#   211: 'considera',
#   212: 'todos',
#   213: 'los',
#   214: 'aspectos',
#   215: 'de',
#   216: 'un',
#   217: 'sitio',
#   218: 'Web',
#   219: 'educativo',
#   220: 'con',
#   221: 'el',
#   222: 'que',
#   223: 'el',
#   224: 'usuario',
#   225: 'puede',
#   226: 'interactuar',
#   227: 'y',
#   228: 'sus',
#   229: 'principales',
#   230: 'criterios',
#   231: 'de',
#   232: 'evaluación',
#   233: '(aprendizaje,',
#   234: 'operabilidad,',
#   235: 'comunicación',
#   236: 'contenido,',
#   237: 'etc.).',
#   238: 'Por',
#   239: 'ejemplo,',
#   240: 'el',
#   241: 'sitio',
#   242: 'debe',
#   243: 'cumplir',
#   244: 'una',
#   245: 'funcionalidad',
#   246: 'de',
#   247: 'presentar',
#   248: 'determinado',
#   249: 'tipo',
#   250: 'de',
#   251: 'contenido,',
#   252: 'pero',
#   253: 'este',
#   254: 'contenido',
#   255: 'debe',
#   256: 'ser',
#   257: 'presentado',
#   258: 'de',
#   259: 'una',
#   260: 'manera',
#   261: 'atractiva',
#   262: 'y',
#   263: 'sencilla',
#   264: 'al',
#   265: 'usuario',
#   266: 'y',
#   267: 'que',
#   268: 'además',
#   269: 'el',
#   270: 'aprendizaje',
#   271: 'de',
#   272: 'su',
#   273: 'uso',
#   274: 'y',
#   275: 'navegación',
#   276: 'sea',
#   277: 'intuitiva',
#   278: 'y',
#   279: 'fácil,',
#   280: 'para',
#   281: 'llevar',
#   282: 'a',
#   283: 'cabo',
#   284: 'un',
#   285: 'proceso',
#   286: 'de',
#   287: 'aprendizaje',
#   288: 'rápido',
#   289: 'y',
#   290: 'eficaz.',
#   291: 'Muchos',
#   292: 'son',
#   293: 'los',
#   294: 'autores',
#   295: 'que',
#   296: 'han',
#   297: 'investigado',
#   298: 'y',
#   299: 'propuesto',
#   300: 'recomendaciones',
#   301: '(guías,',
#   302: 'listas',
#   303: 'de',
#   304: 'comprobación,',
#   305: 'principios,',
#   306: 'etc.)',
#   307: 'para',
#   308: 'el',
#   309: 'desarrollo',
#   310: 'de',
#   311: 'aplicaciones',
#   312: 'usables',
#   313: '([NIE90a],',
#   314: '[NIE94a],',
#   315: '[SHN98],',
#   316: '[BEV93]',
#   317: 'entre',
#   318: 'otros),',
#   319: 'y',
#   320: 'muy',
#   321: 'pocos',
#   322: 'sobre',
#   323: 'la',
#   324: 'evaluación',
#   325: 'de',
#   326: 'la',
#   327: 'usabilidad',
#   328: 'de',
#   329: 'sitios',
#   330: 'Web',
#   331: 'educativos',
#   332: '[GON03],',
#   333: '[CAR02].',
#   334: 'Sin',
#   335: 'embargo,',
#   336: 'basta',
#   337: 'hacer',
#   338: 'una',
#   339: 'exploración',
#   340: 'en',
#   341: 'la',
#   342: 'Web',
#   343: 'para',
#   344: 'comprobar',
#   345: 'que',
#   346: 'esto',
#   347: 'aún',
#   348: 'sigue',
#   349: 'siendo',
#   350: 'un',
#   351: 'problema.',
#   352: 'Si',
#   353: 'tenemos',
#   354: 'en',
#   355: 'cuenta',
#   356: 'que',
#   357: 'existe',
#   358: 'una',
#   359: 'diversidad',
#   360: 'de',
#   361: 'dominios',
#   362: 'de',
#   363: 'aplicación',
#   364: 'basadas',
#   365: 'en',
#   366: 'Web,',
#   367: 'comerciales,',
#   368: 'ocio,',
#   369: 'entretenimiento,',
#   370: 'educación,',
#   371: 'etc.;',
#   372: 'una',
#   373: 'mala',
#   374: 'usabilidad',
#   375: 'en',
#   376: 'sitios',
#   377: 'comerciales,',
#   378: 'de',
#   379: 'ocio',
#   380: 'o',
#   381: 'incluso',
#   382: 'de',
#   383: 'noticias',
#   384: 'puede',
#   385: 'significar',
#   386: 'simplemente',
#   387: 'que',
#   388: 'el',
#   389: 'usuario',
#   390: 'busque',
#   391: 'otro',
#   392: 'lugar.',
#   393: 'Sin',
#   394: 'embargo,',
#   395: 'en',
#   396: 'el',
#   397: 'caso',
#   398: 'de',
#   399: 'sitios',
#   400: 'de',
#   401: 'carácter',
#   402: 'educativo',
#   403: 'el',
#   404: 'problema',
#   405: 'se',
#   406: 'agudiza',
#   407: 'ya',
#   408: 'que',
#   409: 'una',
#   410: 'mala',
#   411: 'usabilidad',
#   412: 'puede',
#   413: 'repercutir',
#   414: 'fuertemente',
#   415: 'en',
#   416: 'los',
#   417: 'objetivos',
#   418: 'de',
#   419: 'aprendizaje.',
#   420: 'Es',
#   421: 'decir,',
#   422: 'los',
#   423: 'requisitos',
#   424: 'de',
#   425: 'usabilidad',
#   426: 'de',
#   427: 'un',
#   428: 'sitio',
#   429: 'Web',
#   430: 'comercial',
#   431: 'de',
#   432: 'venta',
#   433: 'de',
#   434: 'herramientas',
#   435: 'de',
#   436: 'carpintería',
#   437: 'orientado',
#   438: 'a',
#   439: 'aquellos',
#   440: 'profesionales',
#   441: 'del',
#   442: 'área',
#   443: 'o',
#   444: 'personas',
#   445: 'aficionadas',
#   446: 'a',
#   447: 'la',
#   448: 'carpintería,',
#   449: 'cuyo',
#   450: 'interés',
#   451: 'esta',
#   452: 'centrado',
#   453: 'en',
#   454: 'encontrar',
#   455: 'un',
#   456: 'producto',
#   457: 'de',
#   458: 'carpintería',
#   459: 'determinado',
#   460: 'al',
#   461: 'mejor',
#   462: 'precio,',
#   463: 'será',
#   464: 'diferente',
#   465: 'de',
#   466: 'los',
#   467: 'requisitos',
#   468: 'de',
#   469: 'usabilidad',
#   470: 'del',
#   471: 'sitio',
#   472: 'Web',
#   473: 'de',
#   474: 'algún',
#   475: 'curso',
#   476: 'de',
#   477: 'una',
#   478: 'universidad',
#   479: 'o',
#   480: 'institución',
#   481: 'educativa,',
#   482: 'en',
#   483: 'principio',
#   484: 'por',
#   485: 'que',
#   486: 'las',
#   487: 'motivaciones',
#   488: 'de',
#   489: 'los',
#   490: 'usuarios',
#   491: 'son',
#   492: 'distintas,',
#   493: 'el',
#   494: 'perfil',
#   495: 'de',
#   496: 'ellos',
#   497: 'también',
#   498: 'lo',
#   499: 'es,',
#   500: 'así',
#   501: 'como',
#   502: 'las',
#   503: 'metas',
#   504: 'a',
#   505: 'alcanzar',
#   506: 'por',
#   507: 'cada',
#   508: 'uno.',
#   509: 'Así',
#   510: 'preparar',
#   511: 'el',
#   512: 'proceso',
#   513: 'de',
#   514: 'evaluación',
#   515: 'de',
#   516: 'usabilidad',
#   517: 'de',
#   518: 'un',
#   519: 'sitio',
#   520: 'comercial',
#   521: 'no',
#   522: 'será',
#   523: 'el',
#   524: 'mismo',
#   525: 'que',
#   526: 'el',
#   527: 'de',
#   528: 'un',
#   529: 'sitio',
#   530: 'educativo',
#   531: 'aunque',
#   532: 'ambos',
#   533: 'buscan',
#   534: 'cubrir',
#   535: 'un',
#   536: 'servicio,',
#   537: 'lograr',
#   538: 'la',
#   539: 'satisfacción',
#   540: 'del',
#   541: 'usuario',
#   542: 'y',
#   543: 'en',
#   544: 'algunos',
#   545: 'casos',
#   546: 'ambos',
#   547: 'pretendan',
#   548: 'lograr',
#   549: 'dividendos',
#   550: 'económicos.',
#   551: 'Los',
#   552: 'sitios',
#   553: 'Web',
#   554: 'educativos',
#   555: 'tienen',
#   556: 'un',
#   557: 'añadido',
#   558: 'fundamental,',
#   559: 'y',
#   560: 'es',
#   561: 'la',
#   562: 'transmisión',
#   563: 'y',
#   564: 'adquisición',
#   565: 'del',
#   566: 'conocimiento.',
#   567: 'Por',
#   568: 'ende',
#   569: 'un',
#   570: 'factor',
#   571: 'importante',
#   572: 'de',
#   573: 'evaluación',
#   574: 'es',
#   575: 'el',
#   576: 'aspecto',
#   577: 'educativo',
#   578: 'y',
#   579: 'su',
#   580: 'presentación',
#   581: 'de',
#   582: 'contenidos.',
#   583: 'La',
#   584: 'consideración',
#   585: 'de',
#   586: 'la',
#   587: 'usabilidad',
#   588: 'como',
#   589: 'un',
#   590: 'factor',
#   591: 'importante',
#   592: 'en',
#   593: 'el',
#   594: 'desarrollo',
#   595: 'de',
#   596: 'aplicaciones',
#   597: 'Web',
#   598: 'ha',
#   599: 'ido',
#   600: 'en',
#   601: 'aumento',
#   602: 'en',
#   603: 'los',
#   604: 'últimos',
#   605: 'años.',
#   606: 'Basándose',
#   607: 'en',
#   608: 'el',
#   609: 'fundamento',
#   610: 'teórico',
#   611: 'de',
#   612: 'la',
#   613: 'usabilidad',
#   614: 'de',
#   615: 'software',
#   616: 'tradicional,',
#   617: 'y',
#   618: 'en',
#   619: 'los',
#   620: 'principios',
#   621: 'establecidos',
#   622: 'por',
#   623: 'los',
#   624: 'estándares',
#   625: 'internacionales',
#   626: 'y',
#   627: 'en',
#   628: 'la',
#   629: 'experiencia',
#   630: 'adquirida',
#   631: 'por',
#   632: 'el',
#   633: 'diseño',
#   634: 'y',
#   635: 'desarrollo',
#   636: 'de',
#   637: 'aplicaciones',
#   638: 'Web,',
#   639: 'se',
#   640: 'han',
#   641: 'desarrollado',
#   642: 'metodologías',
#   643: 'y',
#   644: 'guías',
#   645: 'para',
#   646: 'el',
#   647: 'desarrollo',
#   648: 'de',
#   649: 'aplicaciones',
#   650: 'Web',
#   651: 'con',
#   652: 'criterios',
#   653: 'de',
#   654: 'usabilidad.',
#   655: 'Estas',
#   656: 'permiten',
#   657: 'realizar',
#   658: 'un',
#   659: 'proceso',
#   660: 'de',
#   661: 'evaluación',
#   662: 'de',
#   663: 'usabilidad,',
#   664: 'pero',
#   665: 'limitados',
#   666: 'a',
#   667: 'aspectos',
#   668: 'específicos',
#   669: 'de',
#   670: 'la',
#   671: 'misma,',
#   672: 'y',
#   673: 'enfocados',
#   674: 'a',
#   675: 'la',
#   676: 'evaluación',
#   677: 'de',
#   678: 'sitios',
#   679: 'comerciales,',
#   680: 'que',
#   681: 'aunque',
#   682: 'señalan',
#   683: 'su',
#   684: 'extensión',
#   685: 'a',
#   686: 'sitios',
#   687: 'educativos,',
#   688: 'los',
#   689: 'criterios',
#   690: 'considerados',
#   691: 'no',
#   692: 'se',
#   693: 'ajustan',
#   694: 'a',
#   695: 'los',
#   696: 'requisitos',
#   697: 'de',
#   698: 'usabilidad',
#   699: 'de',
#   700: 'estas',
#   701: 'aplicaciones.',
#   702: 'En',
#   703: 'la',
#   704: 'actualidad',
#   705: 'existen',
#   706: 'diferentes',
#   707: 'métodos',
#   708: 'que',
#   709: 'pueden',
#   710: 'ser',
#   711: 'usados',
#   712: 'durante',
#   713: 'una',
#   714: 'evaluación',
#   715: 'de',
#   716: 'usabilidad.',
#   717: 'Dependiendo',
#   718: 'del',
#   719: 'propósito',
#   720: 'de',
#   721: 'medición,',
#   722: 'del',
#   723: 'tipo',
#   724: 'de',
#   725: 'medida',
#   726: 'a',
#   727: 'obtener,',
#   728: 'de',
#   729: 'la',
#   730: 'etapa',
#   731: 'del',
#   732: 'ciclo',
#   733: 'de',
#   734: 'vida,',
#   735: 'etc.,',
#   736: 'unos',
#   737: 'u',
#   738: 'otros',
#   739: 'son',
#   740: 'usados',
#   741: 'para',
#   742: 'asegurar',
#   743: 'referencias',
#   744: 'que',
#   745: 'mejoren',
#   746: 'la',
#   747: 'usabilidad',
#   748: 'o',
#   749: 'establezcan',
#   750: 'si',
#   751: 'esta',
#   752: 'es',
#   753: 'lo',
#   754: '“suficientemente',
#   755: 'buena\x9d.',
#   756: 'Desafortunadamente,',
#   757: 'no',
#   758: 'hay',
#   759: 'un',
#   760: 'acuerdo',
#   761: 'respecto',
#   762: 'a',
#   763: 'la',
#   764: 'denominación,',
#   765: 'uso',
#   766: 'y',
#   767: 'aplicación',
#   768: 'de',
#   769: 'los',
#   770: 'métodos',
#   771: 'existentes',
#   772: 'en',
#   773: 'el',
#   774: 'desarrollo',
#   775: 'de',
#   776: 'aplicaciones',
#   777: 'Web.',
#   778: 'Así',
#   779: 'los',
#   780: 'diferentes',
#   781: 'autores',
#   782: 'los',
#   783: 'denominan',
#   784: 'de',
#   785: 'acuerdo',
#   786: 'a',
#   787: 'sus',
#   788: 'preferencias',
#   789: 'y',
#   790: 'juicio',
#   791: 'o',
#   792: 'experiencia',
#   793: '(Kirakowski:',
#   794: 'Indagación,',
#   795: '[KIR95]),',
#   796: '(Nielsen:',
#   797: 'las',
#   798: 'Heurísticas,',
#   799: 'Nielsen',
#   800: '[NIE94],',
#   801: '[NIE90c]),',
#   802: '(Preece:',
#   803: 'Evaluación',
#   804: 'de',
#   805: 'expertos',
#   806: '[PRE93]),',
#   807: '(Scriven:',
#   808: 'Formativa/Sumativa',
#   809: '[SCR67]).',
#   810: 'Los',
#   811: 'métodos',
#   812: 'de',
#   813: 'evaluación',
#   814: 'de',
#   815: 'usabilidad',
#   816: 'por',
#   817: 'un',
#   818: 'lado',
#   819: 'tienen',
#   820: 'fortalezas',
#   821: 'y',
#   822: 'debilidades,',
#   823: 'y',
#   824: 'por',
#   825: 'otro',
#   826: 'están',
#   827: 'enfocados',
#   828: 'a',
#   829: 'evaluar',
#   830: 'determinados',
#   831: 'aspectos',
#   832: 'o',
#   833: 'requisitos',
#   834: 'de',
#   835: 'usabilidad,',
#   836: 'por',
#   837: 'lo',
#   838: 'que',
#   839: 'es',
#   840: 'recomendable',
#   841: 'combinarlos',
#   842: 'en',
#   843: 'una',
#   844: 'evaluación',
#   845: 'para',
#   846: 'complementar',
#   847: 'unos',
#   848: 'con',
#   849: 'otros',
#   850: 'en',
#   851: 'cuanto',
#   852: 'a',
#   853: 'sus',
#   854: 'fortalezas',
#   855: 'y',
#   856: 'lograr',
#   857: 'cubrir',
#   858: 'un',
#   859: 'mayor',
#   860: 'número',
#   861: 'de',
#   862: 'aspectos',
#   863: 'de',
#   864: 'evaluación.',
#   865: 'La',
#   866: 'selección',
#   867: 'y',
#   868: 'combinación',
#   869: 'de',
#   870: 'los',
#   871: 'métodos',
#   872: 'de',
#   873: 'evaluación',
#   874: 'dependerá',
#   875: 'de',
#   876: 'restricciones',
#   877: 'financieras',
#   878: 'y',
#   879: 'de',
#   880: 'tiempo,',
#   881: 'de',
#   882: 'las',
#   883: 'fases',
#   884: 'en',
#   885: 'el',
#   886: 'ciclo',
#   887: 'de',
#   888: 'desarrollo',
#   889: 'y',
#   890: 'de',
#   891: 'la',
#   892: 'naturaleza',
#   893: 'del',
#   894: 'sistema',
#   895: 'bajo',
#   896: 'desarrollo',
#   897: '(Bevan,',
#   898: '[BEV94]),',
#   899: '(Nielsen,',
#   900: '[NIE94b]).',
#   901: 'En',
#   902: 'la',
#   903: 'aplicación',
#   904: 'de',
#   905: 'los',
#   906: 'métodos',
#   907: 'de',
#   908: 'evaluación',
#   909: 'de',
#   910: 'usabilidad,',
#   911: 'los',
#   912: 'evaluadores',
#   913: 'hacen',
#   914: 'uso',
#   915: 'de',
#   916: 'un',
#   917: 'conjunto',
#   918: 'de',
#   919: 'técnicas',
#   920: 'diseñadas',
#   921: 'para',
#   922: 'la',
#   923: 'recolección',
#   924: 'de',
#   925: 'datos',
#   926: 'de',
#   927: 'usabilidad,',
#   928: 'y',
#   929: 'definidas',
#   930: 'en',
#   931: 'términos',
#   932: 'del',
#   933: 'método',
#   934: 'que',
#   935: 'soportan,',
#   936: 'su',
#   937: 'aplicabilidad',
#   938: 'en',
#   939: 'las',
#   940: 'diferentes',
#   941: 'etapas',
#   942: 'de',
#   943: 'desarrollo,',
#   944: 'costos',
#   945: 'y',
#   946: 'número',
#   947: 'de',
#   948: 'participantes',
#   949: 'necesarios',
#   950: 'para',
#   951: 'la',
#   952: 'obtención',
#   953: 'de',
#   954: 'la',
#   955: 'información.',
#   956: '(Focus',
#   957: 'Group',
#   958: '[NIE97c],',
#   959: 'Think',
#   960: 'Aloud',
#   961: '[BOR00],',
#   962: 'cuestionarios,',
#   963: 'entre',
#   964: 'otros).',
#   965: 'Es',
#   966: 'importante',
#   967: 'establecer',
#   968: 'que',
#   969: 'al',
#   970: 'igual',
#   971: 'que',
#   972: 'con',
#   973: 'los',
#   974: 'métodos',
#   975: 'es',
#   976: 'necesario',
#   977: 'seleccionar',
#   978: 'las',
#   979: 'técnicas',
#   980: 'más',
#   981: 'adecuadas',
#   982: 'en',
#   983: 'función',
#   984: 'a',
#   985: 'sus',
#   986: 'características',
#   987: 'y',
#   988: 'fortalezas,',
#   989: 'así',
#   990: 'como',
#   991: 'combinarlos',
#   992: 'adecuadamente',
#   993: 'para',
#   994: 'la',
#   995: 'obtención',
#   996: 'de',
#   997: 'una',
#   998: 'mayor',
#   999: 'cantidad',
#   1000: 'de',
#   ...},
#  'Problema3': {1: 'Debido',
#   2: 'a',
#   3: 'que',
#   4: 'las',
#   5: 'redes',
#   6: 'de',
#   7: 'sensores',
#   8: 'inalambricas',
#   9: 'son',
#   10: 'un',
#   11: 'campo',
#   12: 'en',
#   13: 'pleno',
#   14: 'desarrollo,',
#   15: 'que',
#   16: 'la',
#   17: 'operacion',
#   18: 'de',
#   19: 'servicios',
#   20: 'de',
#   21: 'autenticidad',
#   22: 'en',
#   23: 'sus',
#   24: 'comunicaciones',
#   25: 'es',
#   26: 'un',
#   27: 'problema',
#   28: 'que',
#   29: 'no',
#   30: 'ha',
#   31: 'sido',
#   32: 'resuelto',
#   33: 'de',
#   34: 'forma',
#   35: 'definitiva',
#   36: 'y',
#   37: 'que',
#   38: 'la',
#   39: 'naturaleza',
#   40: 'de',
#   41: 'operacion',
#   42: 'de',
#   43: 'dichas',
#   44: 'redes',
#   45: 'presenta',
#   46: 'requerimientos',
#   47: 'específicos',
#   48: 'de',
#   49: 'escalabilidad',
#   50: 'y',
#   51: 'flexibilidad',
#   52: 'para',
#   53: 'el',
#   54: 'diseño',
#   55: 'de',
#   56: 'cualquier',
#   57: 'control',
#   58: 'de',
#   59: 'seguridad,',
#   60: 'se',
#   61: 'llego',
#   62: 'a',
#   63: 'determinar',
#   64: 'lo',
#   65: 'siguiente.',
#   66: 'El',
#   67: 'problema',
#   68: 'a',
#   69: 'resolver',
#   70: 'es',
#   71: 'la',
#   72: 'busqueda',
#   73: 'de',
#   74: 'un',
#   75: 'mecanismo',
#   76: 'que',
#   77: 'permita',
#   78: 'el',
#   79: 'uso',
#   80: 'de',
#   81: 'operaciones',
#   82: 'de',
#   83: 'criptografía',
#   84: 'asimetrica',
#   85: 'en',
#   86: 'un',
#   87: 'ambiente',
#   88: 'de',
#   89: 'redes',
#   90: 'de',
#   91: 'sensores,',
#   92: 'para',
#   93: 'operar',
#   94: 'de',
#   95: 'forma',
#   96: 'eficiente',
#   97: 'un',
#   98: 'protocolo',
#   99: 'de',
#   100: 'autenticacion',
#   101: 'que',
#   102: 'permita',
#   103: 'explotar',
#   104: 'las',
#   105: 'características',
#   106: 'de',
#   107: 'flexibilidad',
#   108: 'y',
#   109: 'escalabilidad',
#   110: 'en',
#   111: 'dicho'},
#  'Problema4': {1: 'En',
#   2: 'una',
#   3: 'red',
#   4: 'celular,',
#   5: 'diseñar',
#   6: 'un',
#   7: 'protocolo',
#   8: 'para',
#   9: 'la',
#   10: 'generación',
#   11: 'y',
#   12: 'distribución',
#   13: 'de',
#   14: 'llaves,',
#   15: 'para',
#   16: 'una',
#   17: 'comunicacion',
#   18: 'multimedia',
#   19: 'multipartita',
#   20: 'segura,',
#   21: 'requiere',
#   22: 'consideraciones',
#   23: 'adicionales',
#   24: 'que',
#   25: 'para',
#   26: 'una',
#   27: 'red',
#   28: 'fi\x81ja.',
#   29: 'Tales',
#   30: 'consideraciones',
#   31: 'estan',
#   32: 'en',
#   33: 'función',
#   34: 'de',
#   35: 'las',
#   36: 'características',
#   37: 'de',
#   38: 'la',
#   39: 'multimedia,',
#   40: 'de',
#   41: 'las',
#   42: "caracter'ísticas",
#   43: 'para',
#   44: 'una',
#   45: 'comunicacion',
#   46: 'en',
#   47: 'grupo',
#   48: 'segura,',
#   49: 'de',
#   50: 'la',
#   51: 'arquitectura',
#   52: 'de',
#   53: 'la',
#   54: 'red',
#   55: 'celular',
#   56: 'y',
#   57: 'del',
#   58: 'modo',
#   59: 'de',
#   60: 'comunicacion',
#   61: 'a',
#   62: 'considerar.',
#   63: 'Por',
#   64: 'ello,',
#   65: 'abordamos',
#   66: 'el',
#   67: 'problema',
#   68: 'desde',
#   69: 'cuatro',
#   70: 'puntos',
#   71: 'de',
#   72: 'vista.',
#   73: 'Primero,',
#   74: 'consideramos',
#   75: 'las',
#   76: 'caracteíísticas',
#   77: 'necesarias',
#   78: 'a',
#   79: 'garantizar',
#   80: 'para',
#   81: 'una',
#   82: 'comunicacion',
#   83: 'en',
#   84: 'grupo',
#   85: 'segura.',
#   86: 'Segundo,',
#   87: 'se',
#   88: 'toman',
#   89: 'en',
#   90: 'cuenta',
#   91: 'los',
#   92: 'problemas',
#   93: 'que',
#   94: 'surgen',
#   95: 'debido',
#   96: 'a',
#   97: 'las',
#   98: 'características',
#   99: 'de',
#   100: 'la',
#   101: 'arquitectura',
#   102: 'de',
#   103: 'una',
#   104: 'red',
#   105: 'celular.',
#   106: 'Tercero,',
#   107: 'se',
#   108: 'consideran',
#   109: 'aspectos',
#   110: 'relacionados',
#   111: 'al',
#   112: 'uso',
#   113: 'de',
#   114: 'una',
#   115: 'comunicacion',
#   116: 'asíncrona.',
#   117: 'Cuarto,',
#   118: 'consideramos',
#   119: 'las',
#   120: 'características',
#   121: 'de',
#   122: 'la'},
#  'Problema5': {1: 'El',
#   2: 'aprendizaje',
#   3: 'por',
#   4: 'refuerzo',
#   5: 'se',
#   6: 'ha',
#   7: 'aplicado',
#   8: 'para',
#   9: 'resolver',
#   10: 'problemas',
#   11: 'en',
#   12: 'varias',
#   13: 'disciplinas,',
#   14: 'incluyendo',
#   15: 'aplicaciones',
#   16: 'recientes,',
#   17: 'como',
#   18: 'la',
#   19: 'robótica.',
#   20: 'Los',
#   21: 'retos',
#   22: 'actuales',
#   23: 'principales',
#   24: 'para',
#   25: 'aprendizaje',
#   26: 'por',
#   27: 'refuerzo',
#   28: 'son:',
#   29: 'La',
#   30: 'exploración',
#   31: 'en',
#   32: 'el',
#   33: 'ambiente',
#   34: 'real',
#   35: 'consume',
#   36: 'mucho',
#   37: 'tiempo.',
#   38: 'El',
#   39: 'conocimiento',
#   40: 'obtenido',
#   41: 'se',
#   42: 'limita',
#   43: 'a',
#   44: 'resolver',
#   45: 'solamente',
#   46: 'la',
#   47: 'tarea',
#   48: 'apren-',
#   49: 'dida.',
#   50: 'Los',
#   51: 'dominios',
#   52: 'probados',
#   53: 'en',
#   54: 'el',
#   55: 'estado',
#   56: 'del',
#   57: 'arte',
#   58: 'son',
#   59: 'de',
#   60: 'dinámicas',
#   61: 'simples.',
#   62: 'El',
#   63: 'dilema',
#   64: 'exploración-explotación',
#   65: 'es',
#   66: 'algo',
#   67: 'que',
#   68: 'ha',
#   69: 'ocupado',
#   70: 'a',
#   71: 'los',
#   72: 'investi-',
#   73: 'gadores',
#   74: 'en',
#   75: 'el',
#   76: 'área',
#   77: 'de',
#   78: 'aprendizaje',
#   79: 'por',
#   80: 'refuerzo.',
#   81: 'Las',
#   82: 'técnicas',
#   83: 'se',
#   84: 'han',
#   85: 'inclinado',
#   86: 'por',
#   87: 'algoritmos',
#   88: 'que',
#   89: 'encuentren',
#   90: 'un',
#   91: 'correcto',
#   92: 'balance',
#   93: 'entre',
#   94: 'la',
#   95: 'exploración',
#   96: 'y',
#   97: 'la',
#   98: 'explotación',
#   99: 'durante',
#   100: 'el',
#   101: 'aprendizaje,',
#   102: 'y',
#   103: 'con',
#   104: 'ello',
#   105: 'hallar',
#   106: 'una',
#   107: 'buena',
#   108: 'política',
#   109: 'en',
#   110: 'un',
#   111: 'tiempo',
#   112: 'reducido.',
#   113: 'U',
#   114: 'na',
#   115: 'solución',
#   116: 'alternativa,',
#   117: 'que',
#   118: 'permite',
#   119: 'reutilizar',
#   120: 'el',
#   121: 'conocimiento',
#   122: 'entre',
#   123: 'tareas',
#   124: 'similares',
#   125: 'y',
#   126: 'así',
#   127: 'reducir',
#   128: 'el',
#   129: 'tiempo',
#   130: 'de',
#   131: 'aprendizaje',
#   132: 'en',
#   133: 'la',
#   134: 'tarea',
#   135: 'objetivo,',
#   136: 'es',
#   137: 'la',
#   138: 'transferencia',
#   139: 'de',
#   140: 'conocimiento.',
#   141: 'En',
#   142: 'a~nos',
#   143: 'recientes',
#   144: 'se',
#   145: 'han',
#   146: 'hecho',
#   147: 'avances',
#   148: 'en',
#   149: 'algoritmos',
#   150: 'para',
#   151: 'transferir',
#   152: 'di-',
#   153: 'ferentes',
#   154: 'tipos',
#   155: 'de',
#   156: 'conocimiento',
#   157: 'entre',
#   158: 'tareas',
#   159: 'de',
#   160: 'aprendizaje',
#   161: 'por',
#   162: 'refuerzo,',
#   163: 'sin',
#   164: 'embargo,',
#   165: 'la',
#   166: 'mayoría',
#   167: 'de',
#   168: 'los',
#   169: 'trabajos',
#   170: 'se',
#   171: 'ha',
#   172: 'centrado',
#   173: 'en',
#   174: 'tareas',
#   175: 'con',
#   176: 'una',
#   177: 'natu-',
#   178: 'raleza',
#   179: 'discreta.',
#   180: 'El',
#   181: 'trabajo',
#   182: 'que',
#   183: 'aquí',
#   184: 'se',
#   185: 'propone',
#   186: 'se',
#   187: 'enfoca',
#   188: 'en',
#   189: 'la',
#   190: 'transferencia',
#   191: 'de',
#   192: 'conoci-',
#   193: 'miento',
#   194: 'entre',
#   195: 'problemas',
#   196: 'con',
#   197: 'dinámicas',
#   198: 'complejas',
#   199: 'y',
#   200: 'con',
#   201: 'espacios',
#   202: 'de',
#   203: 'estado',
#   204: 'y',
#   205: 'acciones',
#   206: 'continuos,',
#   207: 'usando',
#   208: 'una',
#   209: 'representación',
#   210: 'cualitativa',
#   211: 'compacta',
#   212: 'y',
#   213: 'gene-',
#   214: 'ralizada,',
#   215: 'adquirida',
#   216: 'durante',
#   217: 'el',
#   218: 'aprendizaje',
#   219: 'de',
#   220: 'una',
#   221: 'primera',
#   222: 'tarea',
#   223: 'relacionada',
#   224: 'y',
#   225: 'aplicada',
#   226: 'como',
#   227: 'guía',
#   228: 'para',
#   229: 'el',
#   230: 'aprendizaje',
#   231: 'de',
#   232: 'la',
#   233: 'tarea',
#   234: 'objetivo.',
#   235: 'Son',
#   236: 'muy',
#   237: 'pocos',
#   238: 'los',
#   239: 'trabajos',
#   240: 'que',
#   241: 'han',
#   242: 'hecho',
#   243: 'transferencia',
#   244: 'en',
#   245: 'tareas',
#   246: 'de',
#   247: 'estados',
#   248: 'continuos',
#   249: '[Taylor',
#   250: 'et',
#   251: 'al.,',
#   252: '2008],',
#   253: '[Lazaric',
#   254: 'et',
#   255: 'al.,',
#   256: '2008]',
#   257: 'y',
#   258: 'nulos',
#   259: 'en',
#   260: 'tareas',
#   261: 'con',
#   262: 'acciones',
#   263: 'continuas.',
#   264: 'De',
#   265: 'tal',
#   266: 'situación',
#   267: 'se',
#   268: 'hace',
#   269: 'visible',
#   270: 'la',
#   271: 'importancia',
#   272: 'de',
#   273: 'este',
#   274: 'trabajo,',
#   275: 'cuyo',
#   276: 'objetivo',
#   277: 'es',
#   278: 'transferir',
#   279: 'información',
#   280: 'cualitativa',
#   281: 'entre',
#   282: 'tareas',
#   283: 'con',
#   284: 'espacios',
#   285: 'de',
#   286: 'estado',
#   287: 'y',
#   288: 'acción',
#   289: 'continuos.',
#   290: 'La',
#   291: 'ventaja',
#   292: 'de',
#   293: 'una',
#   294: 'abstracción',
#   295: 'cualitativa',
#   296: 'sobre',
#   297: 'otros',
#   298: 'enfoques',
#   299: 'es',
#   300: 'la',
#   301: 'gene-',
#   302: 'ralidad',
#   303: 'en',
#   304: 'la',
#   305: 'representación',
#   306: 'de',
#   307: 'acciones',
#   308: 'y',
#   309: 'estados',
#   310: 'así',
#   311: 'como',
#   312: 'la',
#   313: 'representación',
#   314: 'compacta',
#   315: 'del',
#   316: 'conocimiento',
#   317: 'sobre',
#   318: 'la',
#   319: 'tarea.',
#   320: 'El',
#   321: 'razonamiento',
#   322: 'cualitativo',
#   323: 'y',
#   324: 'abs-',
#   325: 'tracciones',
#   326: 'cualitativas',
#   327: 'han',
#   328: 'sido',
#   329: 'empleados',
#   330: 'para',
#   331: 'representar',
#   332: 'funciones',
#   333: 'cuali-',
#   334: 'tativas',
#   335: 'en',
#   336: 'procesos',
#   337: 'de',
#   338: 'control',
#   339: '([Mugan,',
#   340: '2010],',
#   341: '[Suc,',
#   342: '2003]).También',
#   343: 'se',
#   344: 'han',
#   345: 'usado',
#   346: 'para',
#   347: 'representar',
#   348: 'reglas',
#   349: 'durante',
#   350: 'el',
#   351: 'aprendizaje',
#   352: 'por',
#   353: 'refuerzo',
#   354: '([Mugan',
#   355: 'and',
#   356: 'Kuipers,',
#   357: '2008],',
#   358: '[Mugan,',
#   359: '2010]),',
#   360: 'pero',
#   361: 'hasta',
#   362: 'el',
#   363: 'momento',
#   364: 'no',
#   365: 'se',
#   366: 'han',
#   367: 'desarro-',
#   368: 'llado',
#   369: 'trabajos',
#   370: 'sobre',
#   371: 'transferencia',
#   372: 'de',
#   373: 'información',
#   374: 'cualitativa',
#   375: 'en',
#   376: 'aprendizaje',
#   377: 'por',
#   378: 'refuerzo,',
#   379: 'lo',
#   380: 'cual',
#   381: 'es',
#   382: 'el',
#   383: 'objetivo',
#   384: 'que',
#   385: 'persigue',
#   386: 'este',
#   387: 'trabajo.',
#   388: 'En',
#   389: 'una',
#   390: 'tarea',
#   391: 'donde',
#   392: 'el',
#   393: 'agente',
#   394: 'se',
#   395: 'arriesga',
#   396: 'al',
#   397: 'hacer',
#   398: 'exploración,',
#   399: 'es',
#   400: 'deseable',
#   401: 'tener',
#   402: 'un',
#   403: 'desempe~no',
#   404: 'inicial',
#   405: 'al',
#   406: 'ejecutarse',
#   407: 'los',
#   408: 'primeros',
#   409: 'episodios',
#   410: 'del',
#   411: 'aprendi-',
#   412: 'zaje',
#   413: 'y',
#   414: 'correr',
#   415: 'menos',
#   416: 'riesgo',
#   417: 'de',
#   418: 'realizar',
#   419: 'acciones',
#   420: 'peligrosas.',
#   421: 'En',
#   422: 'aprendizaje',
#   423: 'por',
#   424: 'refuerzo',
#   425: 'la',
#   426: 'métrica',
#   427: 'que',
#   428: 'mejor',
#   429: 're',
#   430: 'eja',
#   431: 'tal',
#   432: 'comportamiento',
#   433: 'es',
#   434: 'jumpstart1',
#   435: '.',
#   436: 'En',
#   437: 'la',
#   438: 'literatura',
#   439: 'revisada',
#   440: 'no',
#   441: 'se',
#   442: 'encontraron',
#   443: 'trabajos',
#   444: 'en',
#   445: 'los',
#   446: 'cuáles',
#   447: 'se',
#   448: 'centraran',
#   449: 'los',
#   450: 'esfuerzos',
#   451: 'en',
#   452: 'generar',
#   453: 'un',
#   454: 'alto',
#   455: 'valor',
#   456: 'de',
#   457: 'jumpstart,',
#   458: 'excepto',
#   459: 'por',
#   460: 'el',
#   461: 'trabajo',
#   462: 'de',
#   463: 'Lazaric',
#   464: '([Lazaric',
#   465: 'et',
#   466: 'al.,',
#   467: '2008]).',
#   468: 'El',
#   469: 'trabajo',
#   470: 'que',
#   471: 'aquí',
#   472: 'se',
#   473: 'propone',
#   474: 'se',
#   475: 'enfoca',
#   476: 'en',
#   477: 'generar',
#   478: 'un',
#   479: 'valor',
#   480: 'de',
#   481: 'jumpstart',
#   482: 'suficientemente',
#   483: 'alto',
#   484: 'para',
#   485: 'guíar',
#   486: 'la',
#   487: 'exploración',
#   488: 'y',
#   489: 'reducir',
#   490: 'el',
#   491: 'riesgo',
#   492: 'de',
#   493: 'explorar',
#   494: 'acciones',
#   495: 'peligrosas,',
#   496: 'evitando',
#   497: 'la',
#   498: 'transferencia',
#   499: 'negativa2',
#   500: '.',
#   501: 'Todos',
#   502: 'los',
#   503: 'trabajos',
#   504: 'de',
#   505: 'transferencia',
#   506: 'para',
#   507: 'aprendizaje',
#   508: 'por',
#   509: 'refuerzo',
#   510: 'que',
#   511: 'se',
#   512: 'han',
#   513: 'encontrado',
#   514: 'en',
#   515: 'la',
#   516: 'literatura,',
#   517: 'han',
#   518: 'sido',
#   519: 'probados',
#   520: 'por',
#   521: 'sus',
#   522: 'autores',
#   523: 'en',
#   524: 'simulaciones.',
#   525: 'Uno',
#   526: 'de',
#   527: 'los',
#   528: 'objetivos',
#   529: 'del',
#   530: 'trabajo',
#   531: 'propuesto',
#   532: 'es',
#   533: 'hacer',
#   534: 'validaciones',
#   535: 'de',
#   536: 'transferencia',
#   537: 'de',
#   538: 'conocimiento',
#   539: 'en',
#   540: 'un',
#   541: 'problema',
#   542: 'de',
#   543: 'robótica',
#   544: 'complejo,',
#   545: 'con',
#   546: 'alta',
#   547: 'dimensionalidad,',
#   548: 'dinámica',
#   549: 'no-lineal',
#   550: 'y',
#   551: 'estocasticidad,',
#   552: 'ese',
#   553: 'será',
#   554: 'en',
#   555: 'volar',
#   556: 'de',
#   557: 'manera',
#   558: 'autónoma',
#   559: 'un'},
#  'Problema6': {1: 'El',
#   2: 'algoritmo',
#   3: 'de',
#   4: 'clasificación',
#   5: 'supervisada,',
#   6: 'basado',
#   7: 'en',
#   8: 'la',
#   9: 'búsqueda',
#   10: 'del',
#   11: 'vecino',
#   12: 'más',
#   13: 'cercano',
#   14: '(NN)',
#   15: '[COVER67],',
#   16: 'ha',
#   17: 'sido',
#   18: 'ampliamente',
#   19: 'utilizado',
#   20: 'debido',
#   21: 'a',
#   22: 'su',
#   23: 'simplicidad',
#   24: 'y',
#   25: 'capacidad',
#   26: 'para',
#   27: 'resolver',
#   28: 'problemas',
#   29: 'complejos',
#   30: 'de',
#   31: 'Reconocimiento',
#   32: 'de',
#   33: 'Patrones.',
#   34: 'Este',
#   35: 'algoritmo',
#   36: 'está',
#   37: 'basado',
#   38: 'en',
#   39: 'un',
#   40: 'conjunto',
#   41: 'de',
#   42: 'objetos',
#   43: 'de',
#   44: 'entrenamiento',
#   45: 'T,',
#   46: 'previamente',
#   47: 'clasificado.',
#   48: 'T',
#   49: '=',
#   50: '{Zi',
#   51: '|',
#   52: '1',
#   53: '&lt;=',
#   54: 'i',
#   55: '&lt;=N}',
#   56: '(1)',
#   57: 'Donde',
#   58: 'N',
#   59: 'es',
#   60: 'el',
#   61: 'número',
#   62: 'de',
#   63: 'objetos.',
#   64: 'El',
#   65: 'objeto',
#   66: 'Zi',
#   67: 'está',
#   68: 'descrito',
#   69: 'por',
#   70: 'd',
#   71: 'atributos',
#   72: 'en',
#   73: 'un',
#   74: 'espacio',
#   75: 'R^d.',
#   76: 'Zi',
#   77: '=',
#   78: '[x1(Zi),',
#   79: 'x2(Zi),...,',
#   80: 'xd(Zi)]',
#   81: '(2)',
#   82: 'Dado',
#   83: 'un',
#   84: 'nuevo',
#   85: 'objeto',
#   86: 'Q',
#   87: 'a',
#   88: 'clasificar,',
#   89: 'el',
#   90: 'objetivo',
#   91: 'del',
#   92: 'clasificador',
#   93: 'es',
#   94: 'encontrar',
#   95: 'el',
#   96: 'objeto',
#   97: 'ONN',
#   98: 'en',
#   99: 'el',
#   100: 'conjunto',
#   101: 'T',
#   102: 'que',
#   103: 'minimice',
#   104: 'la',
#   105: 'función',
#   106: 'de',
#   107: 'distancia',
#   108: 'Dist',
#   109: 'con',
#   110: 'el',
#   111: 'objeto',
#   112: 'Q.',
#   113: 'O[MN]',
#   114: '=',
#   115: 'minDist',
#   116: '[Z=T](Zi',
#   117: ',Q)',
#   118: '(3)',
#   119: 'Para',
#   120: 'encontrar',
#   121: 'ONN',
#   122: 'se',
#   123: 'requiere',
#   124: 'una',
#   125: 'comparación',
#   126: 'exhaustiva',
#   127: 'entre',
#   128: 'Q',
#   129: 'y',
#   130: 'cada',
#   131: 'objeto',
#   132: 'del',
#   133: 'conjunto',
#   134: 'T.',
#   135: 'Una',
#   136: 'vez',
#   137: 'encontrado',
#   138: 'el',
#   139: 'vecino',
#   140: 'más',
#   141: 'cercano,',
#   142: 'se',
#   143: 'asigna',
#   144: 'la',
#   145: 'clase',
#   146: 'de',
#   147: 'este',
#   148: 'objeto',
#   149: 'a',
#   150: 'Q.',
#   151: 'Una',
#   152: 'generalización',
#   153: 'de',
#   154: 'este',
#   155: 'método',
#   156: 'es',
#   157: 'el',
#   158: 'algoritmo',
#   159: 'de',
#   160: 'k',
#   161: 'vecinos',
#   162: 'más',
#   163: 'cercanos',
#   164: '(k-NN).',
#   165: 'En',
#   166: 'este',
#   167: 'caso,',
#   168: 'la',
#   169: 'búsqueda',
#   170: 'se',
#   171: 'realiza',
#   172: 'de',
#   173: 'la',
#   174: 'misma',
#   175: 'forma',
#   176: 'que',
#   177: 'en',
#   178: 'NN,',
#   179: 'salvo',
#   180: 'que',
#   181: 'en',
#   182: 'lugar',
#   183: 'de',
#   184: 'encontrar',
#   185: 'un',
#   186: 'sólo',
#   187: 'objeto,',
#   188: 'se',
#   189: 'buscan',
#   190: 'los',
#   191: 'k',
#   192: 'más',
#   193: 'cercanos.',
#   194: 'Finalmente,',
#   195: 'la',
#   196: 'clase',
#   197: 'del',
#   198: 'objeto',
#   199: 'Q',
#   200: 'se',
#   201: 'elige',
#   202: 'por',
#   203: 'votación',
#   204: 'de',
#   205: 'los',
#   206: 'k',
#   207: 'objetos',
#   208: 'más',
#   209: 'cercanos.',
#   210: 'Un',
#   211: 'diagrama',
#   212: 'del',
#   213: 'algoritmo',
#   214: 'NN',
#   215: 'se',
#   216: 'muestra',
#   217: 'en',
#   218: 'la',
#   219: 'figura',
#   220: '1.1.',
#   221: 'El',
#   222: 'algoritmo',
#   223: 'de',
#   224: 'clasificación',
#   225: 'basado',
#   226: 'en',
#   227: 'la',
#   228: 'búsqueda',
#   229: 'del',
#   230: 'vecino',
#   231: 'más',
#   232: 'cercano',
#   233: 'se',
#   234: 'ha',
#   235: 'aplicado',
#   236: 'en',
#   237: 'otros',
#   238: 'problemas',
#   239: 'aparte',
#   240: 'de',
#   241: 'la',
#   242: 'clasificación,',
#   243: 'tal',
#   244: 'es',
#   245: 'el',
#   246: 'caso',
#   247: 'de:',
#   248: 'estimación',
#   249: 'de',
#   250: 'densidad',
#   251: '[CHEN89],',
#   252: 'compresión',
#   253: 'de',
#   254: 'datos',
#   255: '[GERSHO91],',
#   256: 'recuperación',
#   257: 'de',
#   258: 'información',
#   259: '[DEERWESTER90],',
#   260: 'reconocimiento',
#   261: 'de',
#   262: 'caracteres',
#   263: '[STELIOS93],',
#   264: 'cuantización',
#   265: 'de',
#   266: 'vectores',
#   267: '[CHEN97].',
#   268: 'En',
#   269: 'las',
#   270: 'aplicaciones',
#   271: 'antes',
#   272: 'mencionadas,',
#   273: 'dicho',
#   274: 'algoritmo',
#   275: 'de',
#   276: 'clasificación',
#   277: 'ha',
#   278: 'presentado',
#   279: 'un',
#   280: 'buen',
#   281: 'desempeño.',
#   282: 'Sin',
#   283: 'embargo,',
#   284: 'comparar',
#   285: 'un',
#   286: 'nuevo',
#   287: 'objeto',
#   288: 'Q',
#   289: 'contra',
#   290: 'todos',
#   291: 'los',
#   292: 'elementos',
#   293: 'del',
#   294: 'conjunto',
#   295: 'T',
#   296: 'implica',
#   297: 'un',
#   298: 'alto',
#   299: 'costo',
#   300: 'en',
#   301: 'tiempo,',
#   302: 'cuando',
#   303: 'T',
#   304: 'es',
#   305: 'muy',
#   306: 'grande.',
#   307: 'Por',
#   308: 'esta',
#   309: 'razón',
#   310: 'en',
#   311: 'los',
#   312: 'últimos',
#   313: 'años',
#   314: 'se',
#   315: 'han',
#   316: 'propuesto',
#   317: 'métodos',
#   318: 'para',
#   319: 'hacer',
#   320: 'más',
#   321: 'rápida',
#   322: 'la',
#   323: 'búsqueda,',
#   324: 'la',
#   325: 'mayoría',
#   326: 'de',
#   327: 'los',
#   328: 'cuales',
#   329: 'omiten',
#   330: 'comparaciones',
#   331: 'con',
#   332: 'base',
#   333: 'en',
#   334: 'propiedades',
#   335: 'métricas',
#   336: 'de',
#   337: 'la',
#   338: 'función',
#   339: 'de'},
#  'Problema7': {1: 'La',
#   2: 'efectividad',
#   3: 'de',
#   4: 'una',
#   5: 'representación',
#   6: 'de',
#   7: 'documentos,',
#   8: 'está',
#   9: 'directamente',
#   10: 'relacionada',
#   11: 'a',
#   12: 'la',
#   13: 'exactitud',
#   14: 'con',
#   15: 'la',
#   16: 'cual',
#   17: 'el',
#   18: 'conjunto',
#   19: 'de',
#   20: 'términos',
#   21: 'seleccionados',
#   22: 'representa',
#   23: 'el',
#   24: 'contenido',
#   25: 'de',
#   26: 'un',
#   27: 'documento',
#   28: 'y',
#   29: 'a',
#   30: 'cuán',
#   31: 'bien',
#   32: 'se',
#   33: 'puede',
#   34: 'contrastar',
#   35: 'el',
#   36: 'contenido',
#   37: 'de',
#   38: 'dicho',
#   39: 'documento',
#   40: 'con',
#   41: 'otro.',
#   42: 'Es',
#   43: 'decir,',
#   44: 'dados',
#   45: 'dos',
#   46: 'documentos',
#   47: 'D1',
#   48: 'y',
#   49: 'D2',
#   50: 'y',
#   51: 'sus',
#   52: 'representaciones',
#   53: 'R1',
#   54: 'y',
#   55: 'R2,',
#   56: 'respectivamente,',
#   57: 'si',
#   58: 'R1',
#   59: 'es',
#   60: 'igual',
#   61: 'a',
#   62: 'R2',
#   63: 'esto',
#   64: 'significa',
#   65: 'que',
#   66: 'el',
#   67: 'contenido',
#   68: 'de',
#   69: 'R1',
#   70: 'es',
#   71: 'igual',
#   72: 'al',
#   73: 'contenido',
#   74: 'de',
#   75: 'R2',
#   76: 'a',
#   77: 'cierto',
#   78: 'nivel',
#   79: 'de',
#   80: 'abstracción.',
#   81: 'En',
#   82: 'cuanto',
#   83: 'a',
#   84: 'la',
#   85: 'representación',
#   86: 'de',
#   87: 'contenido,',
#   88: 'la',
#   89: 'bolsa',
#   90: 'de',
#   91: 'palabras',
#   92: 'es',
#   93: 'insuficiente,',
#   94: 'ya',
#   95: 'que',
#   96: 'palabras',
#   97: 'aisladas',
#   98: 'son',
#   99: 'poco',
#   100: 'específicas',
#   101: 'para',
#   102: 'efectuar',
#   103: 'una',
#   104: 'discriminación',
#   105: 'adecuada',
#   106: 'entre',
#   107: 'documentos',
#   108: '[23,',
#   109: '26].',
#   110: 'Un',
#   111: 'método',
#   112: 'más',
#   113: 'apropiado,',
#   114: 'como',
#   115: 'se',
#   116: 'ha',
#   117: 'mencionado,',
#   118: 'sería',
#   119: 'identificar',
#   120: 'grupos',
#   121: 'de',
#   122: 'palabras',
#   123: 'con',
#   124: 'significado',
#   125: 'que',
#   126: 'denoten',
#   127: 'conceptos',
#   128: 'o',
#   129: 'relaciones,',
#   130: 'este',
#   131: 'será',
#   132: 'el',
#   133: 'trabajo',
#   134: 'de',
#   135: 'la',
#   136: 'presente',
#   137: 'investigación,',
#   138: 'la',
#   139: 'utilidad',
#   140: 'de',
#   141: 'la',
#   142: 'representación',
#   143: 'resultante',
#   144: 'será',
#   145: 'comprobada',
#   146: 'en',
#   147: 'RI,',
#   148: 'por',
#   149: 'tal',
#   150: 'motivo,',
#   151: 'a',
#   152: 'continuación',
#   153: 'se',
#   154: 'presenta',
#   155: 'una',
#   156: 'descripción',
#   157: 'de',
#   158: 'dicha',
#   159: 'tarea.',
#   160: 'La',
#   161: 'recuperación',
#   162: 'de',
#   163: 'información',
#   164: '(RI)',
#   165: 'se',
#   166: 'interesa',
#   167: 'en',
#   168: 'seleccionar,',
#   169: 'de',
#   170: 'grandes',
#   171: 'volúmenes',
#   172: 'de',
#   173: 'texto,',
#   174: 'aquellos',
#   175: 'documentos',
#   176: 'que',
#   177: 'contienen',
#   178: 'información',
#   179: 'relevante',
#   180: 'de',
#   181: 'acuerdo',
#   182: 'a',
#   183: 'las',
#   184: 'necesidades',
#   185: 'de',
#   186: 'información',
#   187: 'expresadas',
#   188: 'por',
#   189: 'un',
#   190: 'usuario.',
#   191: 'La',
#   192: 'RI',
#   193: 'incluye',
#   194: 'dos',
#   195: 'actividades',
#   196: 'principales:',
#   197: 'indexar',
#   198: 'y',
#   199: 'buscar.',
#   200: 'La',
#   201: 'primera',
#   202: 'se',
#   203: 'refiere',
#   204: 'a',
#   205: 'representar',
#   206: 'el',
#   207: 'contenido',
#   208: 'de',
#   209: 'los',
#   210: 'documentos',
#   211: 'y',
#   212: 'la',
#   213: 'solicitud',
#   214: 'de',
#   215: 'información',
#   216: 'que',
#   217: 'emite',
#   218: 'el',
#   219: 'usuario.',
#   220: 'La',
#   221: 'segunda,',
#   222: 'a',
#   223: 'la',
#   224: 'forma',
#   225: 'de',
#   226: 'examinar',
#   227: 'la',
#   228: 'representación',
#   229: 'de',
#   230: 'los',
#   231: 'documentos',
#   232: 'con',
#   233: 'respecto',
#   234: 'a',
#   235: 'la',
#   236: 'petición',
#   237: 'de',
#   238: 'información,',
#   239: 'para',
#   240: 'proporcionar',
#   241: 'como',
#   242: 'respuesta',
#   243: 'los',
#   244: 'que',
#   245: 'resulten',
#   246: 'de',
#   247: 'mayor',
#   248: 'relevancia.',
#   249: 'La',
#   250: 'riqueza',
#   251: 'inherente',
#   252: 'al',
#   253: 'lenguaje,',
#   254: 'y',
#   255: 'la',
#   256: 'diversidad',
#   257: 'en',
#   258: 'la',
#   259: 'manera',
#   260: 'de',
#   261: 'expresar',
#   262: 'las',
#   263: 'necesidades',
#   264: 'de',
#   265: 'información',
#   266: 'por',
#   267: 'parte',
#   268: 'de',
#   269: 'los',
#   270: 'usuarios,',
#   271: 'ocasionan',
#   272: 'que',
#   273: 'las',
#   274: 'operaciones',
#   275: 'de',
#   276: 'indexar',
#   277: 'y',
#   278: 'de',
#   279: 'buscar',
#   280: 'nunca',
#   281: 'recuperen',
#   282: 'información',
#   283: 'de',
#   284: 'manera',
#   285: 'perfecta,',
#   286: 'como',
#   287: 'puede',
#   288: 'ser',
#   289: 'el',
#   290: 'caso',
#   291: 'de',
#   292: 'los',
#   293: 'manejadores',
#   294: 'de',
#   295: 'bases',
#   296: 'de',
#   297: 'datos.',
#   298: 'Por',
#   299: 'lo',
#   300: 'tanto,',
#   301: 'ha',
#   302: 'sido',
#   303: 'necesario',
#   304: 'establecer',
#   305: 'métodos',
#   306: 'cuantitativos',
#   307: '(funciones',
#   308: 'de',
#   309: 'relevancia)',
#   310: 'para',
#   311: 'evaluar',
#   312: 'de',
#   313: 'forma',
#   314: 'aproximada',
#   315: 'la',
#   316: 'similitud',
#   317: 'entre',
#   318: 'la',
#   319: 'consulta',
#   320: 'y',
#   321: 'los',
#   322: 'documentos,',
#   323: 'y',
#   324: 'entonces',
#   325: 'determinar',
#   326: 'cuáles',
#   327: 'recuperar.',
#   328: 'Un',
#   329: 'modelo',
#   330: 'de',
#   331: 'RI',
#   332: 'se',
#   333: 'define',
#   334: 'con',
#   335: 'la',
#   336: 'representación',
#   337: 'que',
#   338: 'se',
#   339: 'da',
#   340: 'a',
#   341: 'los',
#   342: 'documentos',
#   343: 'y',
#   344: 'las',
#   345: 'consultas',
#   346: '(objetivo',
#   347: 'de',
#   348: 'esta',
#   349: 'investigación),',
#   350: 'y',
#   351: 'la',
#   352: 'función',
#   353: 'de',
#   354: 'relevancia',
#   355: 'que',
#   356: 'se',
#   357: 'emplea',
#   358: 'para',
#   359: 'compararlos.',
#   360: 'Ahora',
#   361: 'bien,',
#   362: 'dada',
#   363: 'una',
#   364: 'solicitud',
#   365: 'de',
#   366: 'información,',
#   367: 'por',
#   368: 'ejemplo:',
#   369: '"Estoy',
#   370: 'interesado',
#   371: 'en',
#   372: 'mecanismos',
#   373: 'de',
#   374: 'comunicación',
#   375: 'entre',
#   376: 'procesos',
#   377: 'disjuntos,',
#   378: 'posiblemente,',
#   379: 'pero',
#   380: 'no',
#   381: 'exclusivamente',
#   382: 'en',
#   383: 'ambientes',
#   384: 'distribuidos.',
#   385: 'Preferiría',
#   386: 'ver',
#   387: 'descripciones',
#   388: 'de',
#   389: 'mecanismos',
#   390: 'completos',
#   391: 'con',
#   392: 'o',
#   393: 'sin',
#   394: 'implementación',
#   395: 'en',
#   396: 'lugar',
#   397: 'de',
#   398: 'trabajos',
#   399: 'teóricos',
#   400: 'del',
#   401: 'problema.',
#   402: 'Llamada',
#   403: 'a',
#   404: 'procedimientos',
#   405: 'remotos',
#   406: 'y',
#   407: 'paso',
#   408: 'de',
#   409: 'mensajes,',
#   410: 'son',
#   411: 'ejemplos',
#   412: 'de',
#   413: 'mi',
#   414: 'interés"',
#   415: '[10].',
#   416: 'Podemos',
#   417: 'observar',
#   418: 'que',
#   419: 'existen',
#   420: 'palabras',
#   421: 'como',
#   422: 'descripciones,',
#   423: 'mecanismos,',
#   424: 'implementación',
#   425: 'y',
#   426: 'problema,',
#   427: 'que',
#   428: 'deberían',
#   429: 'estar',
#   430: 'presentes',
#   431: 'en',
#   432: 'los',
#   433: 'documentos',
#   434: 'recuperados',
#   435: 'pero',
#   436: 'manteniendo',
#   437: 'la',
#   438: 'relación',
#   439: 'expresada,',
#   440: 'ya',
#   441: 'que',
#   442: 'se',
#   443: 'buscan',
#   444: '"descripciones',
#   445: 'de',
#   446: 'mecanismos',
#   447: 'de',
#   448: 'comunicación',
#   449: 'entre',
#   450: 'procesos".',
#   451: 'Si',
#   452: 'empleamos',
#   453: 'de',
#   454: 'manera',
#   455: 'aislada',
#   456: 'las',
#   457: 'palabras',
#   458: 'mencionadas,',
#   459: 'algunas',
#   460: 'serán',
#   461: 'ignoradas',
#   462: 'por',
#   463: 'su',
#   464: 'generalidad',
#   465: 'al',
#   466: 'crear',
#   467: 'el',
#   468: 'índice',
#   469: 'y',
#   470: 'si',
#   471: 'se',
#   472: 'incluyen',
#   473: 'en',
#   474: 'el',
#   475: 'índice',
#   476: 'conducirán',
#   477: 'a',
#   478: 'recuperar',
#   479: 'gran',
#   480: 'cantidad',
#   481: 'de',
#   482: 'documentos',
#   483: 'irrelevantes.',
#   484: 'Cuando',
#   485: 'se',
#   486: 'recupera',
#   487: 'un',
#   488: 'grupo',
#   489: 'de',
#   490: 'documentos',
#   491: 'se',
#   492: 'encontrará',
#   493: 'que',
#   494: 'algunos',
#   495: 'de',
#   496: 'ellos',
#   497: 'no',
#   498: 'son',
#   499: 'relevantes',
#   500: 'y',
#   501: 'que',
#   502: 'algunos',
#   503: 'relevantes',
#   504: 'no',
#   505: 'se',
#   506: 'han',
#   507: 'recuperado.',
#   508: 'El',
#   509: 'éxito',
#   510: 'de',
#   511: 'la',
#   512: 'recuperación',
#   513: 'se',
#   514: 'establece',
#   515: 'mediante',
#   516: 'dos',
#   517: 'métricas:',
#   518: 'la',
#   519: 'precisión,',
#   520: 'que',
#   521: 'es',
#   522: 'la',
#   523: 'razón',
#   524: 'de',
#   525: 'los',
#   526: 'documentos',
#   527: 'relevantes',
#   528: 'recuperados',
#   529: 'entre',
#   530: 'el',
#   531: 'total',
#   532: 'de',
#   533: 'documentos',
#   534: 'recuperados',
#   535: 'y',
#   536: 'el',
#   537: 'recuerdo,',
#   538: 'la',
#   539: 'razón',
#   540: 'del',
#   541: 'número',
#   542: 'de',
#   543: 'documentos',
#   544: 'relevantes',
#   545: 'recuperados',
#   546: 'entre',
#   547: 'el',
#   548: 'total',
#   549: 'de',
#   550: 'documentos',
#   551: 'relevantes',
#   552: 'existentes',
#   553: 'en',
#   554: 'la',
#   555: 'colección.',
#   556: 'En',
#   557: 'el',
#   558: 'área',
#   559: 'de',
#   560: 'recuperación',
#   561: 'de',
#   562: 'información',
#   563: 'se',
#   564: 'continúa',
#   565: 'experimentando',
#   566: 'con',
#   567: 'nuevos',
#   568: 'modelos',
#   569: 'y',
#   570: 'por',
#   571: 'ende',
#   572: 'nuevas',
#   573: 'representaciones',
#   574: 'de',
#   575: 'documentos,',
#   576: 'para',
#   577: 'intentar',
#   578: 'cubrir',
#   579: 'con',
#   580: 'mayor',
#   581: 'precisión',
#   582: 'las',
#   583: 'necesidades',
#   584: 'de',
#   585: 'información',
#   586: 'de',
#   587: 'los',
#   588: 'usuarios.',
#   589: 'Como',
#   590: 'se',
#   591: 'ha',
#   592: 'especificado,',
#   593: 'nos',
#   594: 'centraremos',
#   595: 'en',
#   596: 'RI,',
#   597: 'donde',
#   598: 'si',
#   599: 'se',
#   600: 'desea',
#   601: 'obtener',
#   602: 'mejoras',
#   603: 'substanciales',
#   604: 'debe',
#   605: 'empezarse',
#   606: 'a',
#   607: 'pensar',
#   608: 'más',
#   609: 'allá',
#   610: 'de',
#   611: 'la',
#   612: 'aproximación',
#   613: 'de',
#   614: 'bolsa',
#   615: 'de',
#   616: 'palabras,',
#   617: 'con',
#   618: 'precisiones',
#   619: 'típicamente',
#   620: 'por',
#   621: 'debajo',
#   622: 'del',
#   623: '50%',
#   624: 'hay',
#   625: 'mucho',
#   626: 'margen',
#   627: 'para',
#   628: 'mejorar',
#   629: '[27].',
#   630: 'En',
#   631: 'la',
#   632: 'siguiente',
#   633: 'sección',
#   634: 'se',
#   635: 'presentan',
#   636: 'trabajos',
#   637: 'que',
#   638: 'describen',
#   639: 'modelos',
#   640: 'clásicos',
#   641: 'y',
#   642: 'nuevos',
#   643: 'de',
#   644: 'recuperación',
#   645: 'de',
#   646: 'información',
#   647: 'para',
#   648: 'concluir',
#   649: 'con',
#   650: 'métodos',
#   651: 'que',
#   652: 'explotan',
#   653: 'la',
#   654: 'obtención',
#   655: 'de',
#   656: 'relaciones,',
#   657: 'empleando',
#   658: 'técnicas',
#   659: 'de',
#   660: 'procesamiento',
#   661: 'de',
#   662: 'lenguaje',
#   663: 'natural,',
#   664: 'para',
#   665: 'realizar',
#   666: 'recuperación',
#   667: 'de'},
#  'Problema8': {1: 'Debido',
#   2: 'al',
#   3: 'vertiginoso',
#   4: 'ritmo',
#   5: 'de',
#   6: 'aparición',
#   7: 'y',
#   8: 'posicionamiento',
#   9: 'de',
#   10: 'las',
#   11: 'tecnologías,',
#   12: 'tanto',
#   13: 'en',
#   14: 'el',
#   15: 'nivel',
#   16: 'de',
#   17: 'las',
#   18: 'comunicaciones',
#   19: 'como',
#   20: 'en',
#   21: 'el',
#   22: 'de',
#   23: 'tráfico,',
#   24: 'se',
#   25: 'han',
#   26: 'cometido',
#   27: 'diversos',
#   28: 'errores',
#   29: 'en',
#   30: 'cuanto',
#   31: 'a',
#   32: 'la',
#   33: 'generación',
#   34: 'de',
#   35: 'los',
#   36: 'contenidos',
#   37: 'publicados',
#   38: 'en',
#   39: 'la',
#   40: 'Web,',
#   41: 'y',
#   42: 'la',
#   43: 'forma',
#   44: 'en',
#   45: 'la',
#   46: 'que',
#   47: 'son',
#   48: 'transmitidos',
#   49: 'a',
#   50: 'los',
#   51: 'usuarios.',
#   52: 'Estos',
#   53: 'errores',
#   54: 'han',
#   55: 'constituido',
#   56: 'duplicidad',
#   57: 'de',
#   58: 'esfuerzos',
#   59: 'al',
#   60: 'desarrollar',
#   61: 'diversas',
#   62: 'aplicaciones',
#   63: 'entre',
#   64: 'diferentes',
#   65: 'administradores,',
#   66: 'sin',
#   67: 'una',
#   68: 'estandarización',
#   69: 'como',
#   70: 'base',
#   71: 'y',
#   72: 'generalmente',
#   73: 'asociada',
#   74: 'con',
#   75: 'el',
#   76: 'desarrollo',
#   77: 'de',
#   78: 'contenidos',
#   79: 'basados',
#   80: 'en',
#   81: 'lenguajes',
#   82: 'de',
#   83: 'marcado',
#   84: 'como',
#   85: 'HTML.',
#   86: 'Esto',
#   87: 'ha',
#   88: 'dificultado',
#   89: 'procesos',
#   90: 'deseables',
#   91: 'como',
#   92: 'el',
#   93: 'compartir',
#   94: 'la',
#   95: 'información',
#   96: 'al',
#   97: 'tratar',
#   98: 'con',
#   99: 'vocabularios',
#   100: 'no',
#   101: 'comunes',
#   102: 'entre',
#   103: 'los',
#   104: 'diferentes',
#   105: 'elementos',
#   106: 'involucrados,',
#   107: 'y',
#   108: 'que',
#   109: 'al',
#   110: 'final',
#   111: 'dan',
#   112: 'como',
#   113: 'resultado',
#   114: 'la',
#   115: 'percepción',
#   116: 'por',
#   117: 'parte',
#   118: 'del',
#   119: 'usuario',
#   120: 'de',
#   121: 'información',
#   122: 'diversa',
#   123: 'y',
#   124: 'difusa.',
#   125: 'A',
#   126: 'continuación',
#   127: 'se',
#   128: 'describen',
#   129: 'cada',
#   130: 'uno',
#   131: 'de',
#   132: 'los',
#   133: 'problemas',
#   134: 'que',
#   135: 'bajo',
#   136: 'mi',
#   137: 'perspectiva,',
#   138: 'caracterizan',
#   139: 'la',
#   140: 'problemática',
#   141: 'de',
#   142: 'la',
#   143: 'difusión',
#   144: 'de',
#   145: 'información',
#   146: 'de',
#   147: 'tráfico',
#   148: 'vía',
#   149: 'Web:',
#   150: 'Problema',
#   151: '1:',
#   152: 'Ausencia',
# ...
#   379: 'Los',
#   380: 'efectos',
#   381: 'producidos',
#   382: 'por',
#   383: 'las',
#   384: 'no',
#   385: 'linealidades',
#   386: 'en',
#   387: 'los',
#   388: 'PAs',
#   389: 'repercuten',
#   390: 'de',
#   391: 'dos',
#   392: 'maneras,',
#   393: 'por',
#   394: 'un',
#   395: 'lado',
#   396: 'causan',
#   397: 'recrecimiento',
#   398: 'espectral,',
#   399: 'dando',
#   400: 'lugar',
#   401: 'a',
#   402: 'interferencias',
#   403: 'en',
#   404: 'los',
#   405: 'canales',
#   406: 'de',
#   407: 'transmisión',
#   408: 'adyacentes',
#   409: '(distorsión',
#   410: 'fuera',
#   411: 'de',
#   412: 'banda',
#   413: 'de',
#   414: 'operación',
#   415: 'asignada),',
#   416: 'mientras',
#   417: 'que',
#   418: 'por',
#   419: 'otro',
#   420: 'lado,',
#   421: 'causan',
#   422: 'distorsión',
#   423: 'dentro',
#   424: 'de',
#   425: 'la',
#   426: 'propia',
#   427: 'banda',
#   428: 'de',
#   429: 'transmisión,',
#   430: 'degradando',
#   431: 'por',
#   432: 'tanto',
#   433: 'la',
#   434: 'Tasa',
#   435: 'de',
#   436: 'Error',
#   437: 'de',
#   438: 'Bits',
#   439: '(BER)',
#   440: '[9].',
#   441: 'Los',
#   442: 'organismos',
#   443: 'reguladores',
#   444: 'fijan',
#   445: 'a',
#   446: 'través',
#   447: 'de',
#   448: 'los',
#   449: 'diferentes',
#   450: 'estándares',
#   451: 'de',
#   452: 'comunicaciones,',
#   453: 'los',
#   454: 'niveles',
#   455: 'máximos',
#   456: 'permitidos',
#   457: 'de',
#   458: 'emisión',
#   459: 'fuera',
#   460: 'de',
#   461: 'banda,',
#   462: 'así',
#   463: 'como',
#   464: 'de',
#   465: 'los',
#   466: 'límites',
#   467: 'de',
#   468: 'distorsión',
#   469: 'en',
#   470: 'la',
#   471: 'banda,',
#   472: 'por',
#   473: 'ejemplo',
#   474: 'especificando',
#   475: 'porcentajes',
#   476: 'máximos',
#   477: 'de',
#   478: 'error',
#   479: 'en',
#   480: 'las',
#   481: 'constelaciones.',
#   482: 'Las',
#   483: 'sanciones',
#   484: 'por',
#   485: 'violar',
#   486: 'cualquiera',
#   487: 'de',
#   488: 'las',
#   489: 'especificaciones',
#   490: 'como',
#   491: 'son',
#   492: 'potencia',
#   493: 'de',
#   494: 'transmisión,',
#   495: 'emisión',
#   496: 'fuera',
#   497: 'de',
#   498: 'banda',
#   499: 'entre',
#   500: 'otras',
#   501: 'son',
#   502: 'multas',
#   503: 'elevadas.',
#   504: 'Las',
#   505: 'series',
#   506: 'de',
#   507: 'Volterra',
#   508: 'pueden',
#   509: 'ser',
#   510: 'usadas',
#   511: 'para',
#   512: 'describir',
#   513: 'un',
#   514: 'sistema',
#   515: 'estable',
#   516: 'no',
#   517: 'lineal',
#   518: 'con',
#   519: 'pérdida',
#   520: 'de',
#   521: 'memoria',
#   522: 'con',
#   523: 'un',
#   524: 'error',
#   525: 'arbitrario',
#   526: 'pequeño.',
#   527: 'Sin',
#   528: 'embargo,',
#   529: 'las',
#   530: 'desventajas',
#   531: 'principales',
#   532: 'son',
#   533: 'el',
#   534: 'incremento',
#   535: 'dramático',
#   536: 'del',
#   537: 'número',
#   538: 'de',
#   539: 'parámetros',
#   540: 'con',
#   541: 'respecto',
#   542: 'al',
#   543: 'orden',
#   544: 'de',
#   545: 'no',
#   546: 'linealidad',
#   547: 'y',
#   548: 'profundidad',
#   549: 'de',
#   550: 'memoria',
#   551: 'lo',
#   552: 'cual',
#   553: 'causa',
#   554: 'un',
#   555: 'incremento',
#   556: 'drástico',
#   557: 'de',
#   558: 'la',
#   559: 'complejidad',
#   560: 'de',
#   561: 'cálculo',
#   562: 'e',
#   563: 'identificación',
#   564: 'de',
#   565: 'parámetros.',
#   566: 'Esta',
#   567: 'es',
#   568: 'la',
#   569: 'razón',
#   570: 'por',
#   571: 'la',
#   572: 'que',
#   573: 'resulta',
#   574: 'altamente',
#   575: 'impráctico',
#   576: 'el',
#   577: 'uso',
#   578: 'de',
#   579: 'las',
#   580: 'series',
#   581: 'completas',
#   582: 'de',
#   583: 'Volterra',
#   584: 'para',
#   585: 'representar',
#   586: 'matemáticamente',
#   587: 'el',
#   588: 'comportamiento',
#   589: 'de',
#   590: 'sistemas',
#   591: 'con',
#   592: 'alta',
#   593: 'no',
#   594: 'linealidad',
#   595: 'y',
#   596: 'profundidad',
#   597: 'de',
#   598: 'memoria',
#   599: 'por',
#   600: 'lo',
#   601: 'que',
#   602: 'se',
#   603: 'requiere',
#   604: 'el',
#   605: 'uso',
#   606: 'de',
#   607: 'truncaciones',
#   608: 'como',
#   609: 'MPM,',
#   610: 'Wiener',
#   611: 'y',
#   612: 'Hammerstein',
#   613: 'donde',
#   614: 'el',
#   615: 'costo',
#   616: 'computacional',
#   617: 'y',
#   618: 'de',
#   619: 'cálculo',
#   620: 'de',
#   621: 'los',
#   622: 'kernels',
#   623: 'de',
#   624: 'cada',
#   625: 'modelo',
#   626: 'sea',
#   627: 'reducido',
#   628: 'en',
#   629: 'comparación',
#   630: 'con',
#   631: 'las',
#   632: 'series',
#   633: 'completas.',
#   634: 'Aunado',
#   635: 'al',
#   636: 'proceso',
#   637: 'de',
#   638: 'modelado',
#   639: 'de',
#   640: 'comportamiento',
#   641: 'del',
#   642: 'PA',
#   643: 'y',
#   644: 'de',
#   645: 'un',
#   646: 'sistema',
#   647: 'completo',
#   648: 'que',
#   649: 'incluya',
#   650: 'diversos',
#   651: 'modelos',
#   652: 'de',
#   653: 'comportamiento,',
#   654: 'es',
#   655: 'necesario',
#   656: 'desarrollar',
#   657: 'técnicas',
#   658: 'de',
#   659: 'medición',
#   660: 'de',
#   661: 'bajo',
#   662: 'costo,',
#   663: 'donde',
#   664: 'métodos',
#   665: 'tradicionales',
#   666: 'de',
#   667: 'medición',
#   668: 'a',
#   669: 'través',
#   670: 'de',
#   671: 'un',
#   672: 'VNA',
#   673: 'no',
#   674: 'sean',
#   675: 'indispensables',
#   676: 'al',
#   677: 'realizar',
#   678: 'un',
#   679: 'proceso',
#   680: 'de',
#   681: 'linealización.',
#   682: 'La',
#   683: 'medición',
#   684: 'en',
#   685: 'fase',
#   686: 'del',
#   687: 'parámetro',
#   688: 'de',
#   689: 'dispersión',
#   690: 'S21',
#   691: 'provee',
#   692: 'la',
#   693: 'información',
#   694: 'de',
#   695: 'la',
#   696: 'distorsión',
#   697: 'en',
#   698: 'fase',
#   699: 'del',
#   700: 'PA.',
#   701: 'Sin',
#   702: 'embargo',
#   703: 'como',
#   704: 'se',
#   705: 'menciona',
#   706: 'involucra',
#   707: 'un',
#   708: 'costoso',
#   709: 'uso',
#   710: 'de',
#   711: 'equipo',
#   712: 'de',
#   713: 'laboratorio,',
#   714: 'además',
#   715: 'de',
#   716: 'instalación',
#   717: 'y',
#   718: 'calibración',
#   719: 'previa,',
#   720: 'donde',
#   721: 'involucra',
#   722: 'diversas',
#   723: 'consideraciones',
#   724: 'para',
#   725: 'un',
#   726: 'método',
#   727: 'tradicional',
#   728: 'de',
#   729: 'medición',
#   730: '[36].',
#   731: 'Todo',
#   732: 'lo',
#   733: 'anterior',
#   734: 'nos',
#   735: 'lleva',
#   736: 'a',
#   737: 'la',
#   738: 'necesidad',
#   739: 'de',
#   740: 'contar',
#   741: 'con',
#   742: 'un',
#   743: 'sistema',
#   744: 'digital',
#   745: 'completo',
#   746: 'que',
#   747: 'pueda',
#   748: 'modelar',
#   749: 'las',
#   750: 'curvas',
#   751: 'de',
#   752: 'distorsión',
#   753: 'de',
#   754: 'un',
#   755: 'PA,',
#   756: 'estimar',
#   757: 'su',
#   758: 'comportamiento',
#   759: 'si',
#   760: 'el',
#   761: 'PA',
#   762: 'es',
#   763: 'utilizado',
#   764: 'como',
#   765: 'DUT,',
#   766: 'realizar',
#   767: 'el',
#   768: 'proceso',
#   769: 'de',
#   770: 'modelado',
#   771: 'y',
#   772: 'utilizar',
#   773: 'algoritmos',
#   774: 'de',
#   775: 'aprendizaje',
#   776: 'como',
#   777: 'ANN',
#   778: 'y',
#   779: 'ANFIS',
#   780: 'dado',
#   781: 'que',
#   782: 'se',
#   783: 'obtuvo',
#   784: 'comportamiento',
#   785: 'complejos',
#   786: 'de',
#   787: 'PAs',
#   788: 'con',
#   789: 'una',
#   790: 'infinidad',
#   791: 'de',
#   792: 'datos',
#   793: 'a',
#   794: 'estimar.',
#   795: 'Y',
#   796: 'además',
#   797: 'estimar',
#   798: 'la',
#   799: 'distorsión',
#   800: 'en',
#   801: 'fase',
#   802: 'del',
#   803: 'PA',
#   804: 'usando',
#   805: 'la',
#   806: 'teoría',
#   807: 'de',
#   808: 'transformación',
#   809: 'de',
#   810: 'amplitud',
#   811: 'a',
#   812: 'fase.'},
#  'Problema33': {1: 'Uno',
#   2: 'de',
#   3: 'los',
#   4: 'principales',
#   5: 'problemas',
#   6: 'que',
#   7: 'los',
#   8: 'sistemas',
#   9: 'normales',
#   10: 'de',
#   11: 'sensado',
#   12: 'en',
#   13: 'estructuras',
#   14: 'presentan',
#   15: 'es',
#   16: 'que',
#   17: 'son',
#   18: 'puntuales',
#   19: 'y',
#   20: 'necesitan',
#   21: 'cableado',
#   22: 'y',
#   23: 'protección',
#   24: 'que',
#   25: 'resulta',
#   26: 'pesado,',
#   27: 'incrementado',
#   28: 'el',
#   29: 'peso',
#   30: 'total',
#   31: 'a',
#   32: 'la',
#   33: 'estructura.',
#   34: 'Además',
#   35: 'se',
#   36: 'emplea',
#   37: 'cableado',
#   38: 'para',
#   39: 'alimentación',
#   40: 'de',
#   41: 'energía',
#   42: 'o',
#   43: 'en',
#   44: 'un',
#   45: 'mejor',
#   46: 'caso',
#   47: 'se',
#   48: 'emplean',
#   49: 'baterías',
#   50: 'cuando',
#   51: 'se',
#   52: 'utiliza',
#   53: 'comunicación',
#   54: 'inalámbrica.',
#   55: 'Aunado',
#   56: 'a',
#   57: 'esto,',
#   58: 'en',
#   59: 'ocasiones',
#   60: 'se',
#   61: 'necesita',
#   62: 'colocar',
#   63: 'sensores',
#   64: 'en',
#   65: 'lugares',
#   66: 'de',
#   67: 'difícil',
#   68: 'acceso,',
#   69: 'así',
#   70: 'como',
#   71: 'formar',
#   72: 'una',
#   73: 'red',
#   74: 'de',
#   75: 'sensores',
#   76: 'para',
#   77: 'buscar',
#   78: 'una',
#   79: 'mayor',
#   80: 'exactitud.',
#   81: 'Lo',
#   82: 'anterior',
#   83: 'involucra',
#   84: 'un',
#   85: 'sistema',
#   86: 'de',
#   87: 'adquisición',
#   88: 'limitado',
#   89: 'por',
#   90: 'el',
#   91: 'número',
#   92: 'de',
#   93: 'canales,',
#   94: 'que',
#   95: 'en',
#   96: 'caso',
#   97: 'de',
#   98: 'requerir',
#   99: 'de',
#   100: 'una',
#   101: 'mayor',
#   102: 'cantidad',
#   103: 'de',
#   104: 'sensores,',
#   105: 'se',
#   106: 'necesitará',
#   107: 'de',
#   108: 'varios',
#   109: 'sistemas',
#   110: 'de',
#   111: 'adquisición.',
#   112: 'Es',
#   113: 'necesario',
#   114: 'entonces,',
#   115: 'estudiar',
#   116: 'las',
#   117: 'técnicas',
#   118: 'actuales',
#   119: 'de',
#   120: 'sensado',
#   121: 'que',
#   122: 'emplean',
#   123: 'diferentes',
#   124: 'tipos',
#   125: 'de',
#   126: 'fibras',
#   127: 'ópticas,',
#   128: 'tanto',
#   129: 'estándar',
#   130: 'como',
#   131: 'dopadas',
#   132: 'de',
#   133: 'tierras',
#   134: 'raras',
#   135: 'y',
#   136: 'el',
#   137: 'empleo',
#   138: 'de',
#   139: 'métodos',
#   140: 'menos',
#   141: 'complejos',
#   142: 'que',
#   143: 'permitan',
#   144: 'un',
#   145: 'sensado'},
#  'Problema34': {1: 'En',
#   2: 'visiÃ³n',
#   3: 'artificial,',
#   4: 'la',
#   5: 'segmentaciÃ³n',
#   6: 'de',
#   7: 'imÃ¡genes',
#   8: 'es',
#   9: 'el',
#   10: 'proceso',
#   11: 'de',
#   12: 'particiÃ³n',
#   13: 'de',
#   14: 'una',
#   15: 'imagen',
#   16: 'digital',
#   17: 'en',
#   18: 'mÃºltiples',
#   19: 'segmentos',
#   20: '(conjuntos',
#   21: 'de',
#   22: 'pÃ\xadxeles,',
#   23: 'tambiÃ©n',
#   24: 'conocidos',
#   25: 'como',
#   26: 'superpÃ\xadxeles).',
#   27: 'El',
#   28: 'objetivo',
#   29: 'de',
#   30: 'la',
#   31: 'segmentaciÃ³n',
#   32: 'es',
#   33: 'simplificar',
#   34: 'y',
#   35: '/',
#   36: 'o',
#   37: 'cambiar',
#   38: 'la',
#   39: 'representaciÃ³n',
#   40: 'de',
#   41: 'una',
#   42: 'imagen',
#   43: 'en',
#   44: 'algo',
#   45: 'que',
#   46: 'es',
#   47: 'mÃ¡s',
#   48: 'significativo',
#   49: 'y',
#   50: 'fÃ¡cil',
#   51: 'de',
#   52: 'analizar.',
#   53: 'La',
#   54: 'segmentaciÃ³n',
#   55: 'de',
#   56: 'imÃ¡genes',
#   57: 'se',
#   58: 'utiliza',
#   59: 'normalmente',
#   60: 'para',
#   61: 'localizar',
#   62: 'objetos',
#   63: 'y',
#   64: 'bordes',
#   65: '(regiones,',
#   66: 'lÃ\xadneas,',
#   67: 'curvas,',
#   68: 'etc.)',
#   69: 'en',
#   70: 'imÃ¡genes.',
#   71: 'MÃ¡s',
#   72: 'precisamente,',
#   73: 'la',
#   74: 'segmentaciÃ³n',
#   75: 'de',
#   76: 'imÃ¡genes',
#   77: 'es',
#   78: 'el',
#   79: 'proceso',
#   80: 'de',
#   81: 'asignar',
#   82: 'una',
#   83: 'etiqueta',
#   84: 'a',
#   85: 'cada',
#   86: 'pÃ\xadxel',
#   87: 'de',
#   88: 'una',
#   89: 'imagen',
#   90: 'de',
#   91: 'modo',
#   92: 'que',
#   93: 'los',
#   94: 'pÃ\xadxeles',
#   95: 'con',
#   96: 'la',
#   97: 'misma',
#   98: 'etiqueta',
#   99: 'comparten',
#   100: 'ciertas',
#   101: 'caracterÃ\xadsticas',
#   102: 'comunes',
#   103: '[47].',
#   104: 'El',
#   105: 'resultado',
#   106: 'de',
#   107: 'la',
#   108: 'segmentaciÃ³n',
#   109: 'es',
#   110: 'un',
#   111: 'conjunto',
#   112: 'de',
#   113: 'segmentos',
#   114: 'que',
#   115: 'cubren',
#   116: 'colectivamente',
#   117: 'toda',
#   118: 'la',
#   119: 'imagen',
#   120: 'o',
#   121: 'un',
#   122: 'conjunto',
#   123: 'de',
#   124: 'contornos',
#   125: 'extraÃ\xaddos',
#   126: 'de',
#   127: 'la',
#   128: 'imagen',
#   129: '(ver',
#   130: 'detecciÃ³n',
#   131: 'de',
#   132: 'bordes).',
#   133: 'Cada',
#   134: 'uno',
#   135: 'de',
#   136: 'los',
#   137: 'pÃ\xadxeles',
#   138: 'de',
#   139: 'una',
#   140: 'regiÃ³n',
#   141: 'es',
#   142: 'similar',
#   143: 'con',
#   144: 'respecto',
#   145: 'a',
#   146: 'alguna',
#   147: 'caracterÃ\xadstica',
#   148: 'o',
#   149: 'propiedad',
#   150: 'calculada,',
#   151: 'como',
#   152: 'el',
#   153: 'color,',
#   154: 'la',
#   155: 'intensidad',
#   156: 'o',
#   157: 'la',
#   158: 'textura.',
#   159: 'Las',
#   160: 'regiones',
#   161: 'adyacentes',
#   162: 'son',
#   163: 'significativamente',
#   164: 'diferentes',
#   165: 'con',
#   166: 'respecto',
#   167: 'a',
#   168: 'la',
#   169: 'misma',
#   170: 'caracterÃ\xadstica',
#   171: '(s)',
#   172: '[47].',
#   173: 'â€œLa',
#   174: 'segmentaciÃ³n',
#   175: 'de',
#   176: 'una',
#   177: 'imagen',
#   178: 'consiste',
#   179: 'en',
#   180: 'la',
#   181: 'particiÃ³n',
#   182: 'de',
#   183: 'dicha',
#   184: 'imagen',
#   185: 'en',
#   186: 'diferentes',
#   187: 'regiones',
#   188: 'similares',
#   189: 'en',
#   190: 'alguna',
#   191: 'caracterÃ\xadstica',
#   192: 'predefinida',
#   193: '(â€¦)',
#   194: 'Los',
#   195: 'seres',
#   196: 'humanos',
#   197: 'usamos',
#   198: 'nuestro',
#   199: 'sentido',
#   200: 'visual',
#   201: 'para',
#   202: 'separar',
#   203: 'nuestro',
#   204: 'entorno',
#   205: 'inmediato',
#   206: 'en',
#   207: 'objetos',
#   208: 'distintos',
#   209: 'sin',
#   210: 'esfuerzo',
#   211: 'alguno',
#   212: 'para',
#   213: 'reconocerlos,',
#   214: 'guiar',
#   215: 'nuestros',
#   216: 'movimientos',
#   217: 'y',
#   218: 'para',
#   219: 'casi',
#   220: 'todas',
#   221: 'las',
#   222: 'actividades',
#   223: 'de',
#   224: 'nuestra',
#   225: 'vida.â€\x9d',
#   226: '(K.N.,',
#   227: 'Plataniotis,',
#   228: 'y',
#   229: 'A.N.Venetsanopoulos,',
#   230: '2000,',
#   231: 'p.',
#   232: '237,',
#   233: 'traducido).',
#   234: 'La',
#   235: 'segmentaciÃ³n',
#   236: 'es',
#   237: 'una',
#   238: 'caracterÃ\xadstica',
#   239: 'importante',
#   240: 'de',
#   241: 'la',
#   242: 'percepciÃ³n',
#   243: 'visual',
#   244: 'humana',
#   245: 'que',
#   246: 'se',
#   247: 'manifiesta',
#   248: 'de',
#   249: 'forma',
#   250: 'espontÃ¡nea',
#   251: 'y',
#   252: 'natural;',
#   253: 'aunque',
#   254: 'estÃ¡n',
#   255: 'involucrados',
#   256: 'procesos',
#   257: 'complejos',
#   258: 'como',
#   259: 'el',
#   260: 'anÃ¡lisis',
#   261: 'de',
#   262: 'color,',
#   263: 'la',
#   264: 'forma,',
#   265: 'el',
#   266: 'movimiento,',
#   267: 'la',
#   268: 'textura,',
#   269: 'etc.',
#   270: '[1][2][3].',
#   271: 'El',
#   272: 'color',
#   273: 'es',
#   274: 'una',
#   275: 'caracterÃ\xadstica',
#   276: 'visual',
#   277: 'poderosa',
#   278: 'y',
#   279: 'robusta',
#   280: 'para',
#   281: 'diferenciar',
#   282: 'los',
#   283: 'diferentes',
#   284: 'objetos',
#   285: 'en',
#   286: 'una',
#   287: 'imagen.',
#   288: 'Es',
#   289: 'una',
#   290: 'importante',
#   291: 'fuente',
#   292: 'de',
#   293: 'informaciÃ³n',
#   294: 'en',
#   295: 'el',
#   296: 'proceso',
#   297: 'de',
#   298: 'segmentaciÃ³n',
#   299: 'y',
#   300: 'puede',
#   301: 'en',
#   302: 'muchos',
#   303: 'casos',
#   304: 'ser',
#   305: 'utilizado',
#   306: 'como',
#   307: 'Ãºnica',
#   308: 'caracterÃ\xadstica',
#   309: 'y',
#   310: 'Ãºnico',
#   311: 'descriptor',
#   312: 'para',
#   313: 'la',
#   314: 'segmentaciÃ³n',
#   315: 'de',
#   316: 'los',
#   317: 'objetos',
#   318: 'de',
#   319: 'interÃ©s',
#   320: '[1][2][3].',
#   321: 'En',
#   322: 'este',
#   323: 'trabajo',
#   324: 'de',
#   325: 'tesis',
#   326: 'se',
#   327: 'busca',
#   328: 'investigar',
#   329: 'sobre',
#   330: 'un',
#   331: 'mÃ©todo',
#   332: 'propio',
#   333: 'de',
#   334: 'segmentaciÃ³n',
#   335: 'del',
#   336: 'color',
#   337: 'en',
#   338: 'imÃ¡genes',
#   339: 'de',
#   340: 'color.',
#   341: 'El',
#   342: 'mÃ©todo',
#   343: 'sÃ³lo',
#   344: 'utiliza',
#   345: 'la',
#   346: 'informaciÃ³n',
#   347: 'de',
#   348: 'color',
#   349: 'para',
#   350: 'realizar',
#   351: 'la',
#   352: 'segmentaciÃ³n,',
#   353: 'por',
#   354: 'lo',
#   355: 'que',
#   356: 'se',
#   357: 'considera',
#   358: 'como',
#   359: 'un',
#   360: 'indispensable',
#   361: 'paso',
#   362: 'previo',
#   363: 'al',
#   364: 'de',
#   365: 'reconocimiento.',
#   366: 'En',
#   367: 'este',
#   368: 'trabajo',
#   369: 'no',
#   370: 'se',
#   371: 'pretende',
#   372: 'llegar',
#   373: 'al',
#   374: 'reconocimiento',
#   375: 'de',
#   376: 'objetos',
#   377: 'o',
#   378: 'clases',
#   379: 'de',
#   380: 'objetos,',
#   381: 'sino',
#   382: 'Ãºnicamente',
#   383: 'a',
#   384: 'la',
#   385: 'segmentaciÃ³n',
#   386: 'de',
#   387: 'la',
#   388: 'imagen',
#   389: 'en',
#   390: 'regiones',
#   391: 'homogÃ©neas',
#   392: 'de',
#   393: 'color',
#   394: 'que',
#   395: 'podrÃ\xadan',
#   396: 'ser',
#   397: 'utilizadas',
#   398: 'para',
#   399: 'alimentar',
#   400: 'a',
#   401: 'tareas'}}

# %% [markdown]
# ## Remove Empty Dictionaries

# %%
TSU_structured = cleanVector(TSU_structured)
Lic_structured = cleanVector(Lic_structured)
Masters_structured = cleanVector(Masters_structured)
Phd_structured = cleanVector(Phd_structured)
TSU_structured
Lic_structured
Masters_structured
Phd_structured
# Out:
# {'Problema2': {1: 'La',
#   2: 'gran',
#   3: 'cantidad',
#   4: 'de',
#   5: 'información',
#   6: 'disponible',
#   7: 'en',
#   8: 'Internet,',
#   9: 'la',
#   10: 'complejidad',
#   11: 'y',
#   12: 'heterogeneidad',
#   13: 'de',
#   14: 'la',
#   15: 'misma,',
#   16: 'junto',
#   17: 'con',
#   18: 'las',
#   19: 'distintas',
#   20: 'características',
#   21: 'de',
#   22: 'los',
#   23: 'usuarios',
#   24: 'que',
#   25: 'acceden',
#   26: 'a',
#   27: 'dicha',
#   28: 'información,',
#   29: 'así',
#   30: 'como',
#   31: 'la',
#   32: 'gran',
#   33: 'competencia',
#   34: 'existente',
#   35: 'en',
#   36: 'la',
#   37: 'red,',
#   38: 'hacen',
#   39: 'crítico',
#   40: 'que',
#   41: 'el',
#   42: 'desarrollo',
#   43: 'de',
#   44: 'aplicaciones',
#   45: 'basadas',
#   46: 'en',
#   47: 'Web,',
#   48: 'y',
#   49: 'de',
#   50: 'manera',
#   51: 'particular',
#   52: 'los',
#   53: 'sitios',
#   54: 'Web',
#   55: 'educativos',
#   56: 'deban',
#   57: 'contemplar',
#   58: 'no',
#   59: 'solo',
#   60: 'aspectos',
#   61: 'de',
#   62: 'funcionalidad',
#   63: 'sino',
#   64: 'también',
#   65: 'de',
#   66: 'usabilidad,',
#   67: 'tomando',
#   68: 'en',
#   69: 'cuenta',
#   70: 'que',
#   71: 'estas',
#   72: 'aplicaciones',
#   73: 'no',
#   74: 'solo',
#   75: 'deben',
#   76: 'tener',
#   77: 'como',
#   78: 'objetivo',
#   79: 'poner',
#   80: 'a',
#   81: 'disposición',
#   82: 'de',
#   83: 'los',
#   84: 'usuarios',
#   85: 'información',
#   86: 'exacta,',
#   87: 'sino',
#   88: 'orientar',
#   89: 'adecuadamente',
#   90: 'al',
#   91: 'usuario',
#   92: 'en',
#   93: 'su',
#   94: 'búsqueda,',
#   95: 'adecuando',
#   96: 'los',
#   97: 'caminos',
#   98: 'más',
#   99: 'apropiados',
#   100: 'para',
#   101: 'cada',
#   102: 'usuario',
#   103: 'de',
#   104: 'acuerdo',
#   105: 'con',
#   106: 'sus',
#   107: 'objetivos,',
#   108: 'sus',
#   109: 'conocimientos',
#   110: 'previos',
#   111: 'o',
#   112: 'sus',
#   113: 'necesidades',
#   114: 'y',
#   115: 'perfiles.',
#   116: 'La',
#   117: 'usabilidad',
#   118: 'en',
#   119: 'este',
#   120: 'contexto,',
#   121: 'se',
#   122: 'enmarca',
#   123: 'en',
#   124: 'una',
#   125: 'pregunta',
#   126: 'sobre',
#   127: 'si',
#   128: 'una',
#   129: 'aplicación',
#   130: 'Web',
#   131: 'educativa',
#   132: 'es',
#   133: 'lo',
#   134: 'suficientemente',
#   135: 'buena',
#   136: 'para',
#   137: 'satisfacer',
#   138: 'las',
#   139: 'necesidades',
#   140: 'y',
#   141: 'requerimientos',
#   142: 'del',
#   143: 'usuario.',
#   144: 'Es',
#   145: 'decir,',
#   146: 'la',
#   147: 'usabilidad',
#   148: 'corresponde',
#   149: 'a',
#   150: 'una',
#   151: 'variable',
#   152: 'en',
#   153: 'el',
#   154: 'marco',
#   155: 'de',
#   156: 'la',
#   157: 'aceptación',
#   158: 'práctica',
#   159: 'de',
#   160: 'un',
#   161: 'sitio',
#   162: 'Web',
#   163: 'educativo.',
#   164: 'Así,',
#   165: 'para',
#   166: 'que',
#   167: 'un',
#   168: 'sitio',
#   169: 'Web',
#   170: 'pueda',
#   171: 'ser',
#   172: 'utilizado',
#   173: 'para',
#   174: 'alcanzar',
#   175: 'alguna',
#   176: 'tarea,',
#   177: 'tiene',
#   178: 'que',
#   179: 'cumplir',
#   180: 'con',
#   181: 'criterios',
#   182: 'de',
#   183: 'utilización',
#   184: '(es',
#   185: 'decir',
#   186: 'referido',
#   187: 'a',
#   188: 'la',
#   189: 'funcionalidad:',
#   190: 'puede',
#   191: 'hacer',
#   192: 'lo',
#   193: 'que',
#   194: 'se',
#   195: 'necesita)',
#   196: 'y',
#   197: 'usabilidad',
#   198: '(cuán',
#   199: 'bien',
#   200: 'los',
#   201: 'usuarios',
#   202: 'pueden',
#   203: 'usar',
#   204: 'esa',
#   205: 'funcionalidad',
#   206: 'del',
#   207: 'sitio',
#   208: 'Web).',
#   209: 'La',
#   210: 'usabilidad',
#   211: 'considera',
#   212: 'todos',
#   213: 'los',
#   214: 'aspectos',
#   215: 'de',
#   216: 'un',
#   217: 'sitio',
#   218: 'Web',
#   219: 'educativo',
#   220: 'con',
#   221: 'el',
#   222: 'que',
#   223: 'el',
#   224: 'usuario',
#   225: 'puede',
#   226: 'interactuar',
#   227: 'y',
#   228: 'sus',
#   229: 'principales',
#   230: 'criterios',
#   231: 'de',
#   232: 'evaluación',
#   233: '(aprendizaje,',
#   234: 'operabilidad,',
#   235: 'comunicación',
#   236: 'contenido,',
#   237: 'etc.).',
#   238: 'Por',
#   239: 'ejemplo,',
#   240: 'el',
#   241: 'sitio',
#   242: 'debe',
#   243: 'cumplir',
#   244: 'una',
#   245: 'funcionalidad',
#   246: 'de',
#   247: 'presentar',
#   248: 'determinado',
#   249: 'tipo',
#   250: 'de',
#   251: 'contenido,',
#   252: 'pero',
#   253: 'este',
#   254: 'contenido',
#   255: 'debe',
#   256: 'ser',
#   257: 'presentado',
#   258: 'de',
#   259: 'una',
#   260: 'manera',
#   261: 'atractiva',
#   262: 'y',
#   263: 'sencilla',
#   264: 'al',
#   265: 'usuario',
#   266: 'y',
#   267: 'que',
#   268: 'además',
#   269: 'el',
#   270: 'aprendizaje',
#   271: 'de',
#   272: 'su',
#   273: 'uso',
#   274: 'y',
#   275: 'navegación',
#   276: 'sea',
#   277: 'intuitiva',
#   278: 'y',
#   279: 'fácil,',
#   280: 'para',
#   281: 'llevar',
#   282: 'a',
#   283: 'cabo',
#   284: 'un',
#   285: 'proceso',
#   286: 'de',
#   287: 'aprendizaje',
#   288: 'rápido',
#   289: 'y',
#   290: 'eficaz.',
#   291: 'Muchos',
#   292: 'son',
#   293: 'los',
#   294: 'autores',
#   295: 'que',
#   296: 'han',
#   297: 'investigado',
#   298: 'y',
#   299: 'propuesto',
#   300: 'recomendaciones',
#   301: '(guías,',
#   302: 'listas',
#   303: 'de',
#   304: 'comprobación,',
#   305: 'principios,',
#   306: 'etc.)',
#   307: 'para',
#   308: 'el',
#   309: 'desarrollo',
#   310: 'de',
#   311: 'aplicaciones',
#   312: 'usables',
#   313: '([NIE90a],',
#   314: '[NIE94a],',
#   315: '[SHN98],',
#   316: '[BEV93]',
#   317: 'entre',
#   318: 'otros),',
#   319: 'y',
#   320: 'muy',
#   321: 'pocos',
#   322: 'sobre',
#   323: 'la',
#   324: 'evaluación',
#   325: 'de',
#   326: 'la',
#   327: 'usabilidad',
#   328: 'de',
#   329: 'sitios',
#   330: 'Web',
#   331: 'educativos',
#   332: '[GON03],',
#   333: '[CAR02].',
#   334: 'Sin',
#   335: 'embargo,',
#   336: 'basta',
#   337: 'hacer',
#   338: 'una',
#   339: 'exploración',
#   340: 'en',
#   341: 'la',
#   342: 'Web',
#   343: 'para',
#   344: 'comprobar',
#   345: 'que',
#   346: 'esto',
#   347: 'aún',
#   348: 'sigue',
#   349: 'siendo',
#   350: 'un',
#   351: 'problema.',
#   352: 'Si',
#   353: 'tenemos',
#   354: 'en',
#   355: 'cuenta',
#   356: 'que',
#   357: 'existe',
#   358: 'una',
#   359: 'diversidad',
#   360: 'de',
#   361: 'dominios',
#   362: 'de',
#   363: 'aplicación',
#   364: 'basadas',
#   365: 'en',
#   366: 'Web,',
#   367: 'comerciales,',
#   368: 'ocio,',
#   369: 'entretenimiento,',
#   370: 'educación,',
#   371: 'etc.;',
#   372: 'una',
#   373: 'mala',
#   374: 'usabilidad',
#   375: 'en',
#   376: 'sitios',
#   377: 'comerciales,',
#   378: 'de',
#   379: 'ocio',
#   380: 'o',
#   381: 'incluso',
#   382: 'de',
#   383: 'noticias',
#   384: 'puede',
#   385: 'significar',
#   386: 'simplemente',
#   387: 'que',
#   388: 'el',
#   389: 'usuario',
#   390: 'busque',
#   391: 'otro',
#   392: 'lugar.',
#   393: 'Sin',
#   394: 'embargo,',
#   395: 'en',
#   396: 'el',
#   397: 'caso',
#   398: 'de',
#   399: 'sitios',
#   400: 'de',
#   401: 'carácter',
#   402: 'educativo',
#   403: 'el',
#   404: 'problema',
#   405: 'se',
#   406: 'agudiza',
#   407: 'ya',
#   408: 'que',
#   409: 'una',
#   410: 'mala',
#   411: 'usabilidad',
#   412: 'puede',
#   413: 'repercutir',
#   414: 'fuertemente',
#   415: 'en',
#   416: 'los',
#   417: 'objetivos',
#   418: 'de',
#   419: 'aprendizaje.',
#   420: 'Es',
#   421: 'decir,',
#   422: 'los',
#   423: 'requisitos',
#   424: 'de',
#   425: 'usabilidad',
#   426: 'de',
#   427: 'un',
#   428: 'sitio',
#   429: 'Web',
#   430: 'comercial',
#   431: 'de',
#   432: 'venta',
#   433: 'de',
#   434: 'herramientas',
#   435: 'de',
#   436: 'carpintería',
#   437: 'orientado',
#   438: 'a',
#   439: 'aquellos',
#   440: 'profesionales',
#   441: 'del',
#   442: 'área',
#   443: 'o',
#   444: 'personas',
#   445: 'aficionadas',
#   446: 'a',
#   447: 'la',
#   448: 'carpintería,',
#   449: 'cuyo',
#   450: 'interés',
#   451: 'esta',
#   452: 'centrado',
#   453: 'en',
#   454: 'encontrar',
#   455: 'un',
#   456: 'producto',
#   457: 'de',
#   458: 'carpintería',
#   459: 'determinado',
#   460: 'al',
#   461: 'mejor',
#   462: 'precio,',
#   463: 'será',
#   464: 'diferente',
#   465: 'de',
#   466: 'los',
#   467: 'requisitos',
#   468: 'de',
#   469: 'usabilidad',
#   470: 'del',
#   471: 'sitio',
#   472: 'Web',
#   473: 'de',
#   474: 'algún',
#   475: 'curso',
#   476: 'de',
#   477: 'una',
#   478: 'universidad',
#   479: 'o',
#   480: 'institución',
#   481: 'educativa,',
#   482: 'en',
#   483: 'principio',
#   484: 'por',
#   485: 'que',
#   486: 'las',
#   487: 'motivaciones',
#   488: 'de',
#   489: 'los',
#   490: 'usuarios',
#   491: 'son',
#   492: 'distintas,',
#   493: 'el',
#   494: 'perfil',
#   495: 'de',
#   496: 'ellos',
#   497: 'también',
#   498: 'lo',
#   499: 'es,',
#   500: 'así',
#   501: 'como',
#   502: 'las',
#   503: 'metas',
#   504: 'a',
#   505: 'alcanzar',
#   506: 'por',
#   507: 'cada',
#   508: 'uno.',
#   509: 'Así',
#   510: 'preparar',
#   511: 'el',
#   512: 'proceso',
#   513: 'de',
#   514: 'evaluación',
#   515: 'de',
#   516: 'usabilidad',
#   517: 'de',
#   518: 'un',
#   519: 'sitio',
#   520: 'comercial',
#   521: 'no',
#   522: 'será',
#   523: 'el',
#   524: 'mismo',
#   525: 'que',
#   526: 'el',
#   527: 'de',
#   528: 'un',
#   529: 'sitio',
#   530: 'educativo',
#   531: 'aunque',
#   532: 'ambos',
#   533: 'buscan',
#   534: 'cubrir',
#   535: 'un',
#   536: 'servicio,',
#   537: 'lograr',
#   538: 'la',
#   539: 'satisfacción',
#   540: 'del',
#   541: 'usuario',
#   542: 'y',
#   543: 'en',
#   544: 'algunos',
#   545: 'casos',
#   546: 'ambos',
#   547: 'pretendan',
#   548: 'lograr',
#   549: 'dividendos',
#   550: 'económicos.',
#   551: 'Los',
#   552: 'sitios',
#   553: 'Web',
#   554: 'educativos',
#   555: 'tienen',
#   556: 'un',
#   557: 'añadido',
#   558: 'fundamental,',
#   559: 'y',
#   560: 'es',
#   561: 'la',
#   562: 'transmisión',
#   563: 'y',
#   564: 'adquisición',
#   565: 'del',
#   566: 'conocimiento.',
#   567: 'Por',
#   568: 'ende',
#   569: 'un',
#   570: 'factor',
#   571: 'importante',
#   572: 'de',
#   573: 'evaluación',
#   574: 'es',
#   575: 'el',
#   576: 'aspecto',
#   577: 'educativo',
#   578: 'y',
#   579: 'su',
#   580: 'presentación',
#   581: 'de',
#   582: 'contenidos.',
#   583: 'La',
#   584: 'consideración',
#   585: 'de',
#   586: 'la',
#   587: 'usabilidad',
#   588: 'como',
#   589: 'un',
#   590: 'factor',
#   591: 'importante',
#   592: 'en',
#   593: 'el',
#   594: 'desarrollo',
#   595: 'de',
#   596: 'aplicaciones',
#   597: 'Web',
#   598: 'ha',
#   599: 'ido',
#   600: 'en',
#   601: 'aumento',
#   602: 'en',
#   603: 'los',
#   604: 'últimos',
#   605: 'años.',
#   606: 'Basándose',
#   607: 'en',
#   608: 'el',
#   609: 'fundamento',
#   610: 'teórico',
#   611: 'de',
#   612: 'la',
#   613: 'usabilidad',
#   614: 'de',
#   615: 'software',
#   616: 'tradicional,',
#   617: 'y',
#   618: 'en',
#   619: 'los',
#   620: 'principios',
#   621: 'establecidos',
#   622: 'por',
#   623: 'los',
#   624: 'estándares',
#   625: 'internacionales',
#   626: 'y',
#   627: 'en',
#   628: 'la',
#   629: 'experiencia',
#   630: 'adquirida',
#   631: 'por',
#   632: 'el',
#   633: 'diseño',
#   634: 'y',
#   635: 'desarrollo',
#   636: 'de',
#   637: 'aplicaciones',
#   638: 'Web,',
#   639: 'se',
#   640: 'han',
#   641: 'desarrollado',
#   642: 'metodologías',
#   643: 'y',
#   644: 'guías',
#   645: 'para',
#   646: 'el',
#   647: 'desarrollo',
#   648: 'de',
#   649: 'aplicaciones',
#   650: 'Web',
#   651: 'con',
#   652: 'criterios',
#   653: 'de',
#   654: 'usabilidad.',
#   655: 'Estas',
#   656: 'permiten',
#   657: 'realizar',
#   658: 'un',
#   659: 'proceso',
#   660: 'de',
#   661: 'evaluación',
#   662: 'de',
#   663: 'usabilidad,',
#   664: 'pero',
#   665: 'limitados',
#   666: 'a',
#   667: 'aspectos',
#   668: 'específicos',
#   669: 'de',
#   670: 'la',
#   671: 'misma,',
#   672: 'y',
#   673: 'enfocados',
#   674: 'a',
#   675: 'la',
#   676: 'evaluación',
#   677: 'de',
#   678: 'sitios',
#   679: 'comerciales,',
#   680: 'que',
#   681: 'aunque',
#   682: 'señalan',
#   683: 'su',
#   684: 'extensión',
#   685: 'a',
#   686: 'sitios',
#   687: 'educativos,',
#   688: 'los',
#   689: 'criterios',
#   690: 'considerados',
#   691: 'no',
#   692: 'se',
#   693: 'ajustan',
#   694: 'a',
#   695: 'los',
#   696: 'requisitos',
#   697: 'de',
#   698: 'usabilidad',
#   699: 'de',
#   700: 'estas',
#   701: 'aplicaciones.',
#   702: 'En',
#   703: 'la',
#   704: 'actualidad',
#   705: 'existen',
#   706: 'diferentes',
#   707: 'métodos',
#   708: 'que',
#   709: 'pueden',
#   710: 'ser',
#   711: 'usados',
#   712: 'durante',
#   713: 'una',
#   714: 'evaluación',
#   715: 'de',
#   716: 'usabilidad.',
#   717: 'Dependiendo',
#   718: 'del',
#   719: 'propósito',
#   720: 'de',
#   721: 'medición,',
#   722: 'del',
#   723: 'tipo',
#   724: 'de',
#   725: 'medida',
#   726: 'a',
#   727: 'obtener,',
#   728: 'de',
#   729: 'la',
#   730: 'etapa',
#   731: 'del',
#   732: 'ciclo',
#   733: 'de',
#   734: 'vida,',
#   735: 'etc.,',
#   736: 'unos',
#   737: 'u',
#   738: 'otros',
#   739: 'son',
#   740: 'usados',
#   741: 'para',
#   742: 'asegurar',
#   743: 'referencias',
#   744: 'que',
#   745: 'mejoren',
#   746: 'la',
#   747: 'usabilidad',
#   748: 'o',
#   749: 'establezcan',
#   750: 'si',
#   751: 'esta',
#   752: 'es',
#   753: 'lo',
#   754: '“suficientemente',
#   755: 'buena\x9d.',
#   756: 'Desafortunadamente,',
#   757: 'no',
#   758: 'hay',
#   759: 'un',
#   760: 'acuerdo',
#   761: 'respecto',
#   762: 'a',
#   763: 'la',
#   764: 'denominación,',
#   765: 'uso',
#   766: 'y',
#   767: 'aplicación',
#   768: 'de',
#   769: 'los',
#   770: 'métodos',
#   771: 'existentes',
#   772: 'en',
#   773: 'el',
#   774: 'desarrollo',
#   775: 'de',
#   776: 'aplicaciones',
#   777: 'Web.',
#   778: 'Así',
#   779: 'los',
#   780: 'diferentes',
#   781: 'autores',
#   782: 'los',
#   783: 'denominan',
#   784: 'de',
#   785: 'acuerdo',
#   786: 'a',
#   787: 'sus',
#   788: 'preferencias',
#   789: 'y',
#   790: 'juicio',
#   791: 'o',
#   792: 'experiencia',
#   793: '(Kirakowski:',
#   794: 'Indagación,',
#   795: '[KIR95]),',
#   796: '(Nielsen:',
#   797: 'las',
#   798: 'Heurísticas,',
#   799: 'Nielsen',
#   800: '[NIE94],',
#   801: '[NIE90c]),',
#   802: '(Preece:',
#   803: 'Evaluación',
#   804: 'de',
#   805: 'expertos',
#   806: '[PRE93]),',
#   807: '(Scriven:',
#   808: 'Formativa/Sumativa',
#   809: '[SCR67]).',
#   810: 'Los',
#   811: 'métodos',
#   812: 'de',
#   813: 'evaluación',
#   814: 'de',
#   815: 'usabilidad',
#   816: 'por',
#   817: 'un',
#   818: 'lado',
#   819: 'tienen',
#   820: 'fortalezas',
#   821: 'y',
#   822: 'debilidades,',
#   823: 'y',
#   824: 'por',
#   825: 'otro',
#   826: 'están',
#   827: 'enfocados',
#   828: 'a',
#   829: 'evaluar',
#   830: 'determinados',
#   831: 'aspectos',
#   832: 'o',
#   833: 'requisitos',
#   834: 'de',
#   835: 'usabilidad,',
#   836: 'por',
#   837: 'lo',
#   838: 'que',
#   839: 'es',
#   840: 'recomendable',
#   841: 'combinarlos',
#   842: 'en',
#   843: 'una',
#   844: 'evaluación',
#   845: 'para',
#   846: 'complementar',
#   847: 'unos',
#   848: 'con',
#   849: 'otros',
#   850: 'en',
#   851: 'cuanto',
#   852: 'a',
#   853: 'sus',
#   854: 'fortalezas',
#   855: 'y',
#   856: 'lograr',
#   857: 'cubrir',
#   858: 'un',
#   859: 'mayor',
#   860: 'número',
#   861: 'de',
#   862: 'aspectos',
#   863: 'de',
#   864: 'evaluación.',
#   865: 'La',
#   866: 'selección',
#   867: 'y',
#   868: 'combinación',
#   869: 'de',
#   870: 'los',
#   871: 'métodos',
#   872: 'de',
#   873: 'evaluación',
#   874: 'dependerá',
#   875: 'de',
#   876: 'restricciones',
#   877: 'financieras',
#   878: 'y',
#   879: 'de',
#   880: 'tiempo,',
#   881: 'de',
#   882: 'las',
#   883: 'fases',
#   884: 'en',
#   885: 'el',
#   886: 'ciclo',
#   887: 'de',
#   888: 'desarrollo',
#   889: 'y',
#   890: 'de',
#   891: 'la',
#   892: 'naturaleza',
#   893: 'del',
#   894: 'sistema',
#   895: 'bajo',
#   896: 'desarrollo',
#   897: '(Bevan,',
#   898: '[BEV94]),',
#   899: '(Nielsen,',
#   900: '[NIE94b]).',
#   901: 'En',
#   902: 'la',
#   903: 'aplicación',
#   904: 'de',
#   905: 'los',
#   906: 'métodos',
#   907: 'de',
#   908: 'evaluación',
#   909: 'de',
#   910: 'usabilidad,',
#   911: 'los',
#   912: 'evaluadores',
#   913: 'hacen',
#   914: 'uso',
#   915: 'de',
#   916: 'un',
#   917: 'conjunto',
#   918: 'de',
#   919: 'técnicas',
#   920: 'diseñadas',
#   921: 'para',
#   922: 'la',
#   923: 'recolección',
#   924: 'de',
#   925: 'datos',
#   926: 'de',
#   927: 'usabilidad,',
#   928: 'y',
#   929: 'definidas',
#   930: 'en',
#   931: 'términos',
#   932: 'del',
#   933: 'método',
#   934: 'que',
#   935: 'soportan,',
#   936: 'su',
#   937: 'aplicabilidad',
#   938: 'en',
#   939: 'las',
#   940: 'diferentes',
#   941: 'etapas',
#   942: 'de',
#   943: 'desarrollo,',
#   944: 'costos',
#   945: 'y',
#   946: 'número',
#   947: 'de',
#   948: 'participantes',
#   949: 'necesarios',
#   950: 'para',
#   951: 'la',
#   952: 'obtención',
#   953: 'de',
#   954: 'la',
#   955: 'información.',
#   956: '(Focus',
#   957: 'Group',
#   958: '[NIE97c],',
#   959: 'Think',
#   960: 'Aloud',
#   961: '[BOR00],',
#   962: 'cuestionarios,',
#   963: 'entre',
#   964: 'otros).',
#   965: 'Es',
#   966: 'importante',
#   967: 'establecer',
#   968: 'que',
#   969: 'al',
#   970: 'igual',
#   971: 'que',
#   972: 'con',
#   973: 'los',
#   974: 'métodos',
#   975: 'es',
#   976: 'necesario',
#   977: 'seleccionar',
#   978: 'las',
#   979: 'técnicas',
#   980: 'más',
#   981: 'adecuadas',
#   982: 'en',
#   983: 'función',
#   984: 'a',
#   985: 'sus',
#   986: 'características',
#   987: 'y',
#   988: 'fortalezas,',
#   989: 'así',
#   990: 'como',
#   991: 'combinarlos',
#   992: 'adecuadamente',
#   993: 'para',
#   994: 'la',
#   995: 'obtención',
#   996: 'de',
#   997: 'una',
#   998: 'mayor',
#   999: 'cantidad',
#   1000: 'de',
#   ...},
#  'Problema3': {1: 'Debido',
#   2: 'a',
#   3: 'que',
#   4: 'las',
#   5: 'redes',
#   6: 'de',
#   7: 'sensores',
#   8: 'inalambricas',
#   9: 'son',
#   10: 'un',
#   11: 'campo',
#   12: 'en',
#   13: 'pleno',
#   14: 'desarrollo,',
#   15: 'que',
#   16: 'la',
#   17: 'operacion',
#   18: 'de',
#   19: 'servicios',
#   20: 'de',
#   21: 'autenticidad',
#   22: 'en',
#   23: 'sus',
#   24: 'comunicaciones',
#   25: 'es',
#   26: 'un',
#   27: 'problema',
#   28: 'que',
#   29: 'no',
#   30: 'ha',
#   31: 'sido',
#   32: 'resuelto',
#   33: 'de',
#   34: 'forma',
#   35: 'definitiva',
#   36: 'y',
#   37: 'que',
#   38: 'la',
#   39: 'naturaleza',
#   40: 'de',
#   41: 'operacion',
#   42: 'de',
#   43: 'dichas',
#   44: 'redes',
#   45: 'presenta',
#   46: 'requerimientos',
#   47: 'específicos',
#   48: 'de',
#   49: 'escalabilidad',
#   50: 'y',
#   51: 'flexibilidad',
#   52: 'para',
#   53: 'el',
#   54: 'diseño',
#   55: 'de',
#   56: 'cualquier',
#   57: 'control',
#   58: 'de',
#   59: 'seguridad,',
#   60: 'se',
#   61: 'llego',
#   62: 'a',
#   63: 'determinar',
#   64: 'lo',
#   65: 'siguiente.',
#   66: 'El',
#   67: 'problema',
#   68: 'a',
#   69: 'resolver',
#   70: 'es',
#   71: 'la',
#   72: 'busqueda',
#   73: 'de',
#   74: 'un',
#   75: 'mecanismo',
#   76: 'que',
#   77: 'permita',
#   78: 'el',
#   79: 'uso',
#   80: 'de',
#   81: 'operaciones',
#   82: 'de',
#   83: 'criptografía',
#   84: 'asimetrica',
#   85: 'en',
#   86: 'un',
#   87: 'ambiente',
#   88: 'de',
#   89: 'redes',
#   90: 'de',
#   91: 'sensores,',
#   92: 'para',
#   93: 'operar',
#   94: 'de',
#   95: 'forma',
#   96: 'eficiente',
#   97: 'un',
#   98: 'protocolo',
#   99: 'de',
#   100: 'autenticacion',
#   101: 'que',
#   102: 'permita',
#   103: 'explotar',
#   104: 'las',
#   105: 'características',
#   106: 'de',
#   107: 'flexibilidad',
#   108: 'y',
#   109: 'escalabilidad',
#   110: 'en',
#   111: 'dicho'},
#  'Problema4': {1: 'En',
#   2: 'una',
#   3: 'red',
#   4: 'celular,',
#   5: 'diseñar',
#   6: 'un',
#   7: 'protocolo',
#   8: 'para',
#   9: 'la',
#   10: 'generación',
#   11: 'y',
#   12: 'distribución',
#   13: 'de',
#   14: 'llaves,',
#   15: 'para',
#   16: 'una',
#   17: 'comunicacion',
#   18: 'multimedia',
#   19: 'multipartita',
#   20: 'segura,',
#   21: 'requiere',
#   22: 'consideraciones',
#   23: 'adicionales',
#   24: 'que',
#   25: 'para',
#   26: 'una',
#   27: 'red',
#   28: 'fi\x81ja.',
#   29: 'Tales',
#   30: 'consideraciones',
#   31: 'estan',
#   32: 'en',
#   33: 'función',
#   34: 'de',
#   35: 'las',
#   36: 'características',
#   37: 'de',
#   38: 'la',
#   39: 'multimedia,',
#   40: 'de',
#   41: 'las',
#   42: "caracter'ísticas",
#   43: 'para',
#   44: 'una',
#   45: 'comunicacion',
#   46: 'en',
#   47: 'grupo',
#   48: 'segura,',
#   49: 'de',
#   50: 'la',
#   51: 'arquitectura',
#   52: 'de',
#   53: 'la',
#   54: 'red',
#   55: 'celular',
#   56: 'y',
#   57: 'del',
#   58: 'modo',
#   59: 'de',
#   60: 'comunicacion',
#   61: 'a',
#   62: 'considerar.',
#   63: 'Por',
#   64: 'ello,',
#   65: 'abordamos',
#   66: 'el',
#   67: 'problema',
#   68: 'desde',
#   69: 'cuatro',
#   70: 'puntos',
#   71: 'de',
#   72: 'vista.',
#   73: 'Primero,',
#   74: 'consideramos',
#   75: 'las',
#   76: 'caracteíísticas',
#   77: 'necesarias',
#   78: 'a',
#   79: 'garantizar',
#   80: 'para',
#   81: 'una',
#   82: 'comunicacion',
#   83: 'en',
#   84: 'grupo',
#   85: 'segura.',
#   86: 'Segundo,',
#   87: 'se',
#   88: 'toman',
#   89: 'en',
#   90: 'cuenta',
#   91: 'los',
#   92: 'problemas',
#   93: 'que',
#   94: 'surgen',
#   95: 'debido',
#   96: 'a',
#   97: 'las',
#   98: 'características',
#   99: 'de',
#   100: 'la',
#   101: 'arquitectura',
#   102: 'de',
#   103: 'una',
#   104: 'red',
#   105: 'celular.',
#   106: 'Tercero,',
#   107: 'se',
#   108: 'consideran',
#   109: 'aspectos',
#   110: 'relacionados',
#   111: 'al',
#   112: 'uso',
#   113: 'de',
#   114: 'una',
#   115: 'comunicacion',
#   116: 'asíncrona.',
#   117: 'Cuarto,',
#   118: 'consideramos',
#   119: 'las',
#   120: 'características',
#   121: 'de',
#   122: 'la'},
#  'Problema5': {1: 'El',
#   2: 'aprendizaje',
#   3: 'por',
#   4: 'refuerzo',
#   5: 'se',
#   6: 'ha',
#   7: 'aplicado',
#   8: 'para',
#   9: 'resolver',
#   10: 'problemas',
#   11: 'en',
#   12: 'varias',
#   13: 'disciplinas,',
#   14: 'incluyendo',
#   15: 'aplicaciones',
#   16: 'recientes,',
#   17: 'como',
#   18: 'la',
#   19: 'robótica.',
#   20: 'Los',
#   21: 'retos',
#   22: 'actuales',
#   23: 'principales',
#   24: 'para',
#   25: 'aprendizaje',
#   26: 'por',
#   27: 'refuerzo',
#   28: 'son:',
#   29: 'La',
#   30: 'exploración',
#   31: 'en',
#   32: 'el',
#   33: 'ambiente',
#   34: 'real',
#   35: 'consume',
#   36: 'mucho',
#   37: 'tiempo.',
#   38: 'El',
#   39: 'conocimiento',
#   40: 'obtenido',
#   41: 'se',
#   42: 'limita',
#   43: 'a',
#   44: 'resolver',
#   45: 'solamente',
#   46: 'la',
#   47: 'tarea',
#   48: 'apren-',
#   49: 'dida.',
#   50: 'Los',
#   51: 'dominios',
#   52: 'probados',
#   53: 'en',
#   54: 'el',
#   55: 'estado',
#   56: 'del',
#   57: 'arte',
#   58: 'son',
#   59: 'de',
#   60: 'dinámicas',
#   61: 'simples.',
#   62: 'El',
#   63: 'dilema',
#   64: 'exploración-explotación',
#   65: 'es',
#   66: 'algo',
#   67: 'que',
#   68: 'ha',
#   69: 'ocupado',
#   70: 'a',
#   71: 'los',
#   72: 'investi-',
#   73: 'gadores',
#   74: 'en',
#   75: 'el',
#   76: 'área',
#   77: 'de',
#   78: 'aprendizaje',
#   79: 'por',
#   80: 'refuerzo.',
#   81: 'Las',
#   82: 'técnicas',
#   83: 'se',
#   84: 'han',
#   85: 'inclinado',
#   86: 'por',
#   87: 'algoritmos',
#   88: 'que',
#   89: 'encuentren',
#   90: 'un',
#   91: 'correcto',
#   92: 'balance',
#   93: 'entre',
#   94: 'la',
#   95: 'exploración',
#   96: 'y',
#   97: 'la',
#   98: 'explotación',
#   99: 'durante',
#   100: 'el',
#   101: 'aprendizaje,',
#   102: 'y',
#   103: 'con',
#   104: 'ello',
#   105: 'hallar',
#   106: 'una',
#   107: 'buena',
#   108: 'política',
#   109: 'en',
#   110: 'un',
#   111: 'tiempo',
#   112: 'reducido.',
#   113: 'U',
#   114: 'na',
#   115: 'solución',
#   116: 'alternativa,',
#   117: 'que',
#   118: 'permite',
#   119: 'reutilizar',
#   120: 'el',
#   121: 'conocimiento',
#   122: 'entre',
#   123: 'tareas',
#   124: 'similares',
#   125: 'y',
#   126: 'así',
#   127: 'reducir',
#   128: 'el',
#   129: 'tiempo',
#   130: 'de',
#   131: 'aprendizaje',
#   132: 'en',
#   133: 'la',
#   134: 'tarea',
#   135: 'objetivo,',
#   136: 'es',
#   137: 'la',
#   138: 'transferencia',
#   139: 'de',
#   140: 'conocimiento.',
#   141: 'En',
#   142: 'a~nos',
#   143: 'recientes',
#   144: 'se',
#   145: 'han',
#   146: 'hecho',
#   147: 'avances',
#   148: 'en',
#   149: 'algoritmos',
#   150: 'para',
#   151: 'transferir',
#   152: 'di-',
#   153: 'ferentes',
#   154: 'tipos',
#   155: 'de',
#   156: 'conocimiento',
#   157: 'entre',
#   158: 'tareas',
#   159: 'de',
#   160: 'aprendizaje',
#   161: 'por',
#   162: 'refuerzo,',
#   163: 'sin',
#   164: 'embargo,',
#   165: 'la',
#   166: 'mayoría',
#   167: 'de',
#   168: 'los',
#   169: 'trabajos',
#   170: 'se',
#   171: 'ha',
#   172: 'centrado',
#   173: 'en',
#   174: 'tareas',
#   175: 'con',
#   176: 'una',
#   177: 'natu-',
#   178: 'raleza',
#   179: 'discreta.',
#   180: 'El',
#   181: 'trabajo',
#   182: 'que',
#   183: 'aquí',
#   184: 'se',
#   185: 'propone',
#   186: 'se',
#   187: 'enfoca',
#   188: 'en',
#   189: 'la',
#   190: 'transferencia',
#   191: 'de',
#   192: 'conoci-',
#   193: 'miento',
#   194: 'entre',
#   195: 'problemas',
#   196: 'con',
#   197: 'dinámicas',
#   198: 'complejas',
#   199: 'y',
#   200: 'con',
#   201: 'espacios',
#   202: 'de',
#   203: 'estado',
#   204: 'y',
#   205: 'acciones',
#   206: 'continuos,',
#   207: 'usando',
#   208: 'una',
#   209: 'representación',
#   210: 'cualitativa',
#   211: 'compacta',
#   212: 'y',
#   213: 'gene-',
#   214: 'ralizada,',
#   215: 'adquirida',
#   216: 'durante',
#   217: 'el',
#   218: 'aprendizaje',
#   219: 'de',
#   220: 'una',
#   221: 'primera',
#   222: 'tarea',
#   223: 'relacionada',
#   224: 'y',
#   225: 'aplicada',
#   226: 'como',
#   227: 'guía',
#   228: 'para',
#   229: 'el',
#   230: 'aprendizaje',
#   231: 'de',
#   232: 'la',
#   233: 'tarea',
#   234: 'objetivo.',
#   235: 'Son',
#   236: 'muy',
#   237: 'pocos',
#   238: 'los',
#   239: 'trabajos',
#   240: 'que',
#   241: 'han',
#   242: 'hecho',
#   243: 'transferencia',
#   244: 'en',
#   245: 'tareas',
#   246: 'de',
#   247: 'estados',
#   248: 'continuos',
#   249: '[Taylor',
#   250: 'et',
#   251: 'al.,',
#   252: '2008],',
#   253: '[Lazaric',
#   254: 'et',
#   255: 'al.,',
#   256: '2008]',
#   257: 'y',
#   258: 'nulos',
#   259: 'en',
#   260: 'tareas',
#   261: 'con',
#   262: 'acciones',
#   263: 'continuas.',
#   264: 'De',
#   265: 'tal',
#   266: 'situación',
#   267: 'se',
#   268: 'hace',
#   269: 'visible',
#   270: 'la',
#   271: 'importancia',
#   272: 'de',
#   273: 'este',
#   274: 'trabajo,',
#   275: 'cuyo',
#   276: 'objetivo',
#   277: 'es',
#   278: 'transferir',
#   279: 'información',
#   280: 'cualitativa',
#   281: 'entre',
#   282: 'tareas',
#   283: 'con',
#   284: 'espacios',
#   285: 'de',
#   286: 'estado',
#   287: 'y',
#   288: 'acción',
#   289: 'continuos.',
#   290: 'La',
#   291: 'ventaja',
#   292: 'de',
#   293: 'una',
#   294: 'abstracción',
#   295: 'cualitativa',
#   296: 'sobre',
#   297: 'otros',
#   298: 'enfoques',
#   299: 'es',
#   300: 'la',
#   301: 'gene-',
#   302: 'ralidad',
#   303: 'en',
#   304: 'la',
#   305: 'representación',
#   306: 'de',
#   307: 'acciones',
#   308: 'y',
#   309: 'estados',
#   310: 'así',
#   311: 'como',
#   312: 'la',
#   313: 'representación',
#   314: 'compacta',
#   315: 'del',
#   316: 'conocimiento',
#   317: 'sobre',
#   318: 'la',
#   319: 'tarea.',
#   320: 'El',
#   321: 'razonamiento',
#   322: 'cualitativo',
#   323: 'y',
#   324: 'abs-',
#   325: 'tracciones',
#   326: 'cualitativas',
#   327: 'han',
#   328: 'sido',
#   329: 'empleados',
#   330: 'para',
#   331: 'representar',
#   332: 'funciones',
#   333: 'cuali-',
#   334: 'tativas',
#   335: 'en',
#   336: 'procesos',
#   337: 'de',
#   338: 'control',
#   339: '([Mugan,',
#   340: '2010],',
#   341: '[Suc,',
#   342: '2003]).También',
#   343: 'se',
#   344: 'han',
#   345: 'usado',
#   346: 'para',
#   347: 'representar',
#   348: 'reglas',
#   349: 'durante',
#   350: 'el',
#   351: 'aprendizaje',
#   352: 'por',
#   353: 'refuerzo',
#   354: '([Mugan',
#   355: 'and',
#   356: 'Kuipers,',
#   357: '2008],',
#   358: '[Mugan,',
#   359: '2010]),',
#   360: 'pero',
#   361: 'hasta',
#   362: 'el',
#   363: 'momento',
#   364: 'no',
#   365: 'se',
#   366: 'han',
#   367: 'desarro-',
#   368: 'llado',
#   369: 'trabajos',
#   370: 'sobre',
#   371: 'transferencia',
#   372: 'de',
#   373: 'información',
#   374: 'cualitativa',
#   375: 'en',
#   376: 'aprendizaje',
#   377: 'por',
#   378: 'refuerzo,',
#   379: 'lo',
#   380: 'cual',
#   381: 'es',
#   382: 'el',
#   383: 'objetivo',
#   384: 'que',
#   385: 'persigue',
#   386: 'este',
#   387: 'trabajo.',
#   388: 'En',
#   389: 'una',
#   390: 'tarea',
#   391: 'donde',
#   392: 'el',
#   393: 'agente',
#   394: 'se',
#   395: 'arriesga',
#   396: 'al',
#   397: 'hacer',
#   398: 'exploración,',
#   399: 'es',
#   400: 'deseable',
#   401: 'tener',
#   402: 'un',
#   403: 'desempe~no',
#   404: 'inicial',
#   405: 'al',
#   406: 'ejecutarse',
#   407: 'los',
#   408: 'primeros',
#   409: 'episodios',
#   410: 'del',
#   411: 'aprendi-',
#   412: 'zaje',
#   413: 'y',
#   414: 'correr',
#   415: 'menos',
#   416: 'riesgo',
#   417: 'de',
#   418: 'realizar',
#   419: 'acciones',
#   420: 'peligrosas.',
#   421: 'En',
#   422: 'aprendizaje',
#   423: 'por',
#   424: 'refuerzo',
#   425: 'la',
#   426: 'métrica',
#   427: 'que',
#   428: 'mejor',
#   429: 're',
#   430: 'eja',
#   431: 'tal',
#   432: 'comportamiento',
#   433: 'es',
#   434: 'jumpstart1',
#   435: '.',
#   436: 'En',
#   437: 'la',
#   438: 'literatura',
#   439: 'revisada',
#   440: 'no',
#   441: 'se',
#   442: 'encontraron',
#   443: 'trabajos',
#   444: 'en',
#   445: 'los',
#   446: 'cuáles',
#   447: 'se',
#   448: 'centraran',
#   449: 'los',
#   450: 'esfuerzos',
#   451: 'en',
#   452: 'generar',
#   453: 'un',
#   454: 'alto',
#   455: 'valor',
#   456: 'de',
#   457: 'jumpstart,',
#   458: 'excepto',
#   459: 'por',
#   460: 'el',
#   461: 'trabajo',
#   462: 'de',
#   463: 'Lazaric',
#   464: '([Lazaric',
#   465: 'et',
#   466: 'al.,',
#   467: '2008]).',
#   468: 'El',
#   469: 'trabajo',
#   470: 'que',
#   471: 'aquí',
#   472: 'se',
#   473: 'propone',
#   474: 'se',
#   475: 'enfoca',
#   476: 'en',
#   477: 'generar',
#   478: 'un',
#   479: 'valor',
#   480: 'de',
#   481: 'jumpstart',
#   482: 'suficientemente',
#   483: 'alto',
#   484: 'para',
#   485: 'guíar',
#   486: 'la',
#   487: 'exploración',
#   488: 'y',
#   489: 'reducir',
#   490: 'el',
#   491: 'riesgo',
#   492: 'de',
#   493: 'explorar',
#   494: 'acciones',
#   495: 'peligrosas,',
#   496: 'evitando',
#   497: 'la',
#   498: 'transferencia',
#   499: 'negativa2',
#   500: '.',
#   501: 'Todos',
#   502: 'los',
#   503: 'trabajos',
#   504: 'de',
#   505: 'transferencia',
#   506: 'para',
#   507: 'aprendizaje',
#   508: 'por',
#   509: 'refuerzo',
#   510: 'que',
#   511: 'se',
#   512: 'han',
#   513: 'encontrado',
#   514: 'en',
#   515: 'la',
#   516: 'literatura,',
#   517: 'han',
#   518: 'sido',
#   519: 'probados',
#   520: 'por',
#   521: 'sus',
#   522: 'autores',
#   523: 'en',
#   524: 'simulaciones.',
#   525: 'Uno',
#   526: 'de',
#   527: 'los',
#   528: 'objetivos',
#   529: 'del',
#   530: 'trabajo',
#   531: 'propuesto',
#   532: 'es',
#   533: 'hacer',
#   534: 'validaciones',
#   535: 'de',
#   536: 'transferencia',
#   537: 'de',
#   538: 'conocimiento',
#   539: 'en',
#   540: 'un',
#   541: 'problema',
#   542: 'de',
#   543: 'robótica',
#   544: 'complejo,',
#   545: 'con',
#   546: 'alta',
#   547: 'dimensionalidad,',
#   548: 'dinámica',
#   549: 'no-lineal',
#   550: 'y',
#   551: 'estocasticidad,',
#   552: 'ese',
#   553: 'será',
#   554: 'en',
#   555: 'volar',
#   556: 'de',
#   557: 'manera',
#   558: 'autónoma',
#   559: 'un'},
#  'Problema6': {1: 'El',
#   2: 'algoritmo',
#   3: 'de',
#   4: 'clasificación',
#   5: 'supervisada,',
#   6: 'basado',
#   7: 'en',
#   8: 'la',
#   9: 'búsqueda',
#   10: 'del',
#   11: 'vecino',
#   12: 'más',
#   13: 'cercano',
#   14: '(NN)',
#   15: '[COVER67],',
#   16: 'ha',
#   17: 'sido',
#   18: 'ampliamente',
#   19: 'utilizado',
#   20: 'debido',
#   21: 'a',
#   22: 'su',
#   23: 'simplicidad',
#   24: 'y',
#   25: 'capacidad',
#   26: 'para',
#   27: 'resolver',
#   28: 'problemas',
#   29: 'complejos',
#   30: 'de',
#   31: 'Reconocimiento',
#   32: 'de',
#   33: 'Patrones.',
#   34: 'Este',
#   35: 'algoritmo',
#   36: 'está',
#   37: 'basado',
#   38: 'en',
#   39: 'un',
#   40: 'conjunto',
#   41: 'de',
#   42: 'objetos',
#   43: 'de',
#   44: 'entrenamiento',
#   45: 'T,',
#   46: 'previamente',
#   47: 'clasificado.',
#   48: 'T',
#   49: '=',
#   50: '{Zi',
#   51: '|',
#   52: '1',
#   53: '&lt;=',
#   54: 'i',
#   55: '&lt;=N}',
#   56: '(1)',
#   57: 'Donde',
#   58: 'N',
#   59: 'es',
#   60: 'el',
#   61: 'número',
#   62: 'de',
#   63: 'objetos.',
#   64: 'El',
#   65: 'objeto',
#   66: 'Zi',
#   67: 'está',
#   68: 'descrito',
#   69: 'por',
#   70: 'd',
#   71: 'atributos',
#   72: 'en',
#   73: 'un',
#   74: 'espacio',
#   75: 'R^d.',
#   76: 'Zi',
#   77: '=',
#   78: '[x1(Zi),',
#   79: 'x2(Zi),...,',
#   80: 'xd(Zi)]',
#   81: '(2)',
#   82: 'Dado',
#   83: 'un',
#   84: 'nuevo',
#   85: 'objeto',
#   86: 'Q',
#   87: 'a',
#   88: 'clasificar,',
#   89: 'el',
#   90: 'objetivo',
#   91: 'del',
#   92: 'clasificador',
#   93: 'es',
#   94: 'encontrar',
#   95: 'el',
#   96: 'objeto',
#   97: 'ONN',
#   98: 'en',
#   99: 'el',
#   100: 'conjunto',
#   101: 'T',
#   102: 'que',
#   103: 'minimice',
#   104: 'la',
#   105: 'función',
#   106: 'de',
#   107: 'distancia',
#   108: 'Dist',
#   109: 'con',
#   110: 'el',
#   111: 'objeto',
#   112: 'Q.',
#   113: 'O[MN]',
#   114: '=',
#   115: 'minDist',
#   116: '[Z=T](Zi',
#   117: ',Q)',
#   118: '(3)',
#   119: 'Para',
#   120: 'encontrar',
#   121: 'ONN',
#   122: 'se',
#   123: 'requiere',
#   124: 'una',
#   125: 'comparación',
#   126: 'exhaustiva',
#   127: 'entre',
#   128: 'Q',
#   129: 'y',
#   130: 'cada',
#   131: 'objeto',
#   132: 'del',
#   133: 'conjunto',
#   134: 'T.',
#   135: 'Una',
#   136: 'vez',
#   137: 'encontrado',
#   138: 'el',
#   139: 'vecino',
#   140: 'más',
#   141: 'cercano,',
#   142: 'se',
#   143: 'asigna',
#   144: 'la',
#   145: 'clase',
#   146: 'de',
#   147: 'este',
#   148: 'objeto',
#   149: 'a',
#   150: 'Q.',
#   151: 'Una',
#   152: 'generalización',
#   153: 'de',
#   154: 'este',
#   155: 'método',
#   156: 'es',
#   157: 'el',
#   158: 'algoritmo',
#   159: 'de',
#   160: 'k',
#   161: 'vecinos',
#   162: 'más',
#   163: 'cercanos',
#   164: '(k-NN).',
#   165: 'En',
#   166: 'este',
#   167: 'caso,',
#   168: 'la',
#   169: 'búsqueda',
#   170: 'se',
#   171: 'realiza',
#   172: 'de',
#   173: 'la',
#   174: 'misma',
#   175: 'forma',
#   176: 'que',
#   177: 'en',
#   178: 'NN,',
#   179: 'salvo',
#   180: 'que',
#   181: 'en',
#   182: 'lugar',
#   183: 'de',
#   184: 'encontrar',
#   185: 'un',
#   186: 'sólo',
#   187: 'objeto,',
#   188: 'se',
#   189: 'buscan',
#   190: 'los',
#   191: 'k',
#   192: 'más',
#   193: 'cercanos.',
#   194: 'Finalmente,',
#   195: 'la',
#   196: 'clase',
#   197: 'del',
#   198: 'objeto',
#   199: 'Q',
#   200: 'se',
#   201: 'elige',
#   202: 'por',
#   203: 'votación',
#   204: 'de',
#   205: 'los',
#   206: 'k',
#   207: 'objetos',
#   208: 'más',
#   209: 'cercanos.',
#   210: 'Un',
#   211: 'diagrama',
#   212: 'del',
#   213: 'algoritmo',
#   214: 'NN',
#   215: 'se',
#   216: 'muestra',
#   217: 'en',
#   218: 'la',
#   219: 'figura',
#   220: '1.1.',
#   221: 'El',
#   222: 'algoritmo',
#   223: 'de',
#   224: 'clasificación',
#   225: 'basado',
#   226: 'en',
#   227: 'la',
#   228: 'búsqueda',
#   229: 'del',
#   230: 'vecino',
#   231: 'más',
#   232: 'cercano',
#   233: 'se',
#   234: 'ha',
#   235: 'aplicado',
#   236: 'en',
#   237: 'otros',
#   238: 'problemas',
#   239: 'aparte',
#   240: 'de',
#   241: 'la',
#   242: 'clasificación,',
#   243: 'tal',
#   244: 'es',
#   245: 'el',
#   246: 'caso',
#   247: 'de:',
#   248: 'estimación',
#   249: 'de',
#   250: 'densidad',
#   251: '[CHEN89],',
#   252: 'compresión',
#   253: 'de',
#   254: 'datos',
#   255: '[GERSHO91],',
#   256: 'recuperación',
#   257: 'de',
#   258: 'información',
#   259: '[DEERWESTER90],',
#   260: 'reconocimiento',
#   261: 'de',
#   262: 'caracteres',
#   263: '[STELIOS93],',
#   264: 'cuantización',
#   265: 'de',
#   266: 'vectores',
#   267: '[CHEN97].',
#   268: 'En',
#   269: 'las',
#   270: 'aplicaciones',
#   271: 'antes',
#   272: 'mencionadas,',
#   273: 'dicho',
#   274: 'algoritmo',
#   275: 'de',
#   276: 'clasificación',
#   277: 'ha',
#   278: 'presentado',
#   279: 'un',
#   280: 'buen',
#   281: 'desempeño.',
#   282: 'Sin',
#   283: 'embargo,',
#   284: 'comparar',
#   285: 'un',
#   286: 'nuevo',
#   287: 'objeto',
#   288: 'Q',
#   289: 'contra',
#   290: 'todos',
#   291: 'los',
#   292: 'elementos',
#   293: 'del',
#   294: 'conjunto',
#   295: 'T',
#   296: 'implica',
#   297: 'un',
#   298: 'alto',
#   299: 'costo',
#   300: 'en',
#   301: 'tiempo,',
#   302: 'cuando',
#   303: 'T',
#   304: 'es',
#   305: 'muy',
#   306: 'grande.',
#   307: 'Por',
#   308: 'esta',
#   309: 'razón',
#   310: 'en',
#   311: 'los',
#   312: 'últimos',
#   313: 'años',
#   314: 'se',
#   315: 'han',
#   316: 'propuesto',
#   317: 'métodos',
#   318: 'para',
#   319: 'hacer',
#   320: 'más',
#   321: 'rápida',
#   322: 'la',
#   323: 'búsqueda,',
#   324: 'la',
#   325: 'mayoría',
#   326: 'de',
#   327: 'los',
#   328: 'cuales',
#   329: 'omiten',
#   330: 'comparaciones',
#   331: 'con',
#   332: 'base',
#   333: 'en',
#   334: 'propiedades',
#   335: 'métricas',
#   336: 'de',
#   337: 'la',
#   338: 'función',
#   339: 'de'},
#  'Problema7': {1: 'La',
#   2: 'efectividad',
#   3: 'de',
#   4: 'una',
#   5: 'representación',
#   6: 'de',
#   7: 'documentos,',
#   8: 'está',
#   9: 'directamente',
#   10: 'relacionada',
#   11: 'a',
#   12: 'la',
#   13: 'exactitud',
#   14: 'con',
#   15: 'la',
#   16: 'cual',
#   17: 'el',
#   18: 'conjunto',
#   19: 'de',
#   20: 'términos',
#   21: 'seleccionados',
#   22: 'representa',
#   23: 'el',
#   24: 'contenido',
#   25: 'de',
#   26: 'un',
#   27: 'documento',
#   28: 'y',
#   29: 'a',
#   30: 'cuán',
#   31: 'bien',
#   32: 'se',
#   33: 'puede',
#   34: 'contrastar',
#   35: 'el',
#   36: 'contenido',
#   37: 'de',
#   38: 'dicho',
#   39: 'documento',
#   40: 'con',
#   41: 'otro.',
#   42: 'Es',
#   43: 'decir,',
#   44: 'dados',
#   45: 'dos',
#   46: 'documentos',
#   47: 'D1',
#   48: 'y',
#   49: 'D2',
#   50: 'y',
#   51: 'sus',
#   52: 'representaciones',
#   53: 'R1',
#   54: 'y',
#   55: 'R2,',
#   56: 'respectivamente,',
#   57: 'si',
#   58: 'R1',
#   59: 'es',
#   60: 'igual',
#   61: 'a',
#   62: 'R2',
#   63: 'esto',
#   64: 'significa',
#   65: 'que',
#   66: 'el',
#   67: 'contenido',
#   68: 'de',
#   69: 'R1',
#   70: 'es',
#   71: 'igual',
#   72: 'al',
#   73: 'contenido',
#   74: 'de',
#   75: 'R2',
#   76: 'a',
#   77: 'cierto',
#   78: 'nivel',
#   79: 'de',
#   80: 'abstracción.',
#   81: 'En',
#   82: 'cuanto',
#   83: 'a',
#   84: 'la',
#   85: 'representación',
#   86: 'de',
#   87: 'contenido,',
#   88: 'la',
#   89: 'bolsa',
#   90: 'de',
#   91: 'palabras',
#   92: 'es',
#   93: 'insuficiente,',
#   94: 'ya',
#   95: 'que',
#   96: 'palabras',
#   97: 'aisladas',
#   98: 'son',
#   99: 'poco',
#   100: 'específicas',
#   101: 'para',
#   102: 'efectuar',
#   103: 'una',
#   104: 'discriminación',
#   105: 'adecuada',
#   106: 'entre',
#   107: 'documentos',
#   108: '[23,',
#   109: '26].',
#   110: 'Un',
#   111: 'método',
#   112: 'más',
#   113: 'apropiado,',
#   114: 'como',
#   115: 'se',
#   116: 'ha',
#   117: 'mencionado,',
#   118: 'sería',
#   119: 'identificar',
#   120: 'grupos',
#   121: 'de',
#   122: 'palabras',
#   123: 'con',
#   124: 'significado',
#   125: 'que',
#   126: 'denoten',
#   127: 'conceptos',
#   128: 'o',
#   129: 'relaciones,',
#   130: 'este',
#   131: 'será',
#   132: 'el',
#   133: 'trabajo',
#   134: 'de',
#   135: 'la',
#   136: 'presente',
#   137: 'investigación,',
#   138: 'la',
#   139: 'utilidad',
#   140: 'de',
#   141: 'la',
#   142: 'representación',
#   143: 'resultante',
#   144: 'será',
#   145: 'comprobada',
#   146: 'en',
#   147: 'RI,',
#   148: 'por',
#   149: 'tal',
#   150: 'motivo,',
#   151: 'a',
#   152: 'continuación',
#   153: 'se',
#   154: 'presenta',
#   155: 'una',
#   156: 'descripción',
#   157: 'de',
#   158: 'dicha',
#   159: 'tarea.',
#   160: 'La',
#   161: 'recuperación',
#   162: 'de',
#   163: 'información',
#   164: '(RI)',
#   165: 'se',
#   166: 'interesa',
#   167: 'en',
#   168: 'seleccionar,',
#   169: 'de',
#   170: 'grandes',
#   171: 'volúmenes',
#   172: 'de',
#   173: 'texto,',
#   174: 'aquellos',
#   175: 'documentos',
#   176: 'que',
#   177: 'contienen',
#   178: 'información',
#   179: 'relevante',
#   180: 'de',
#   181: 'acuerdo',
#   182: 'a',
#   183: 'las',
#   184: 'necesidades',
#   185: 'de',
#   186: 'información',
#   187: 'expresadas',
#   188: 'por',
#   189: 'un',
#   190: 'usuario.',
#   191: 'La',
#   192: 'RI',
#   193: 'incluye',
#   194: 'dos',
#   195: 'actividades',
#   196: 'principales:',
#   197: 'indexar',
#   198: 'y',
#   199: 'buscar.',
#   200: 'La',
#   201: 'primera',
#   202: 'se',
#   203: 'refiere',
#   204: 'a',
#   205: 'representar',
#   206: 'el',
#   207: 'contenido',
#   208: 'de',
#   209: 'los',
#   210: 'documentos',
#   211: 'y',
#   212: 'la',
#   213: 'solicitud',
#   214: 'de',
#   215: 'información',
#   216: 'que',
#   217: 'emite',
#   218: 'el',
#   219: 'usuario.',
#   220: 'La',
#   221: 'segunda,',
#   222: 'a',
#   223: 'la',
#   224: 'forma',
#   225: 'de',
#   226: 'examinar',
#   227: 'la',
#   228: 'representación',
#   229: 'de',
#   230: 'los',
#   231: 'documentos',
#   232: 'con',
#   233: 'respecto',
#   234: 'a',
#   235: 'la',
#   236: 'petición',
#   237: 'de',
#   238: 'información,',
#   239: 'para',
#   240: 'proporcionar',
#   241: 'como',
#   242: 'respuesta',
#   243: 'los',
#   244: 'que',
#   245: 'resulten',
#   246: 'de',
#   247: 'mayor',
#   248: 'relevancia.',
#   249: 'La',
#   250: 'riqueza',
#   251: 'inherente',
#   252: 'al',
#   253: 'lenguaje,',
#   254: 'y',
#   255: 'la',
#   256: 'diversidad',
#   257: 'en',
#   258: 'la',
#   259: 'manera',
#   260: 'de',
#   261: 'expresar',
#   262: 'las',
#   263: 'necesidades',
#   264: 'de',
#   265: 'información',
#   266: 'por',
#   267: 'parte',
#   268: 'de',
#   269: 'los',
#   270: 'usuarios,',
#   271: 'ocasionan',
#   272: 'que',
#   273: 'las',
#   274: 'operaciones',
#   275: 'de',
#   276: 'indexar',
#   277: 'y',
#   278: 'de',
#   279: 'buscar',
#   280: 'nunca',
#   281: 'recuperen',
#   282: 'información',
#   283: 'de',
#   284: 'manera',
#   285: 'perfecta,',
#   286: 'como',
#   287: 'puede',
#   288: 'ser',
#   289: 'el',
#   290: 'caso',
#   291: 'de',
#   292: 'los',
#   293: 'manejadores',
#   294: 'de',
#   295: 'bases',
#   296: 'de',
#   297: 'datos.',
#   298: 'Por',
#   299: 'lo',
#   300: 'tanto,',
#   301: 'ha',
#   302: 'sido',
#   303: 'necesario',
#   304: 'establecer',
#   305: 'métodos',
#   306: 'cuantitativos',
#   307: '(funciones',
#   308: 'de',
#   309: 'relevancia)',
#   310: 'para',
#   311: 'evaluar',
#   312: 'de',
#   313: 'forma',
#   314: 'aproximada',
#   315: 'la',
#   316: 'similitud',
#   317: 'entre',
#   318: 'la',
#   319: 'consulta',
#   320: 'y',
#   321: 'los',
#   322: 'documentos,',
#   323: 'y',
#   324: 'entonces',
#   325: 'determinar',
#   326: 'cuáles',
#   327: 'recuperar.',
#   328: 'Un',
#   329: 'modelo',
#   330: 'de',
#   331: 'RI',
#   332: 'se',
#   333: 'define',
#   334: 'con',
#   335: 'la',
#   336: 'representación',
#   337: 'que',
#   338: 'se',
#   339: 'da',
#   340: 'a',
#   341: 'los',
#   342: 'documentos',
#   343: 'y',
#   344: 'las',
#   345: 'consultas',
#   346: '(objetivo',
#   347: 'de',
#   348: 'esta',
#   349: 'investigación),',
#   350: 'y',
#   351: 'la',
#   352: 'función',
#   353: 'de',
#   354: 'relevancia',
#   355: 'que',
#   356: 'se',
#   357: 'emplea',
#   358: 'para',
#   359: 'compararlos.',
#   360: 'Ahora',
#   361: 'bien,',
#   362: 'dada',
#   363: 'una',
#   364: 'solicitud',
#   365: 'de',
#   366: 'información,',
#   367: 'por',
#   368: 'ejemplo:',
#   369: '"Estoy',
#   370: 'interesado',
#   371: 'en',
#   372: 'mecanismos',
#   373: 'de',
#   374: 'comunicación',
#   375: 'entre',
#   376: 'procesos',
#   377: 'disjuntos,',
#   378: 'posiblemente,',
#   379: 'pero',
#   380: 'no',
#   381: 'exclusivamente',
#   382: 'en',
#   383: 'ambientes',
#   384: 'distribuidos.',
#   385: 'Preferiría',
#   386: 'ver',
#   387: 'descripciones',
#   388: 'de',
#   389: 'mecanismos',
#   390: 'completos',
#   391: 'con',
#   392: 'o',
#   393: 'sin',
#   394: 'implementación',
#   395: 'en',
#   396: 'lugar',
#   397: 'de',
#   398: 'trabajos',
#   399: 'teóricos',
#   400: 'del',
#   401: 'problema.',
#   402: 'Llamada',
#   403: 'a',
#   404: 'procedimientos',
#   405: 'remotos',
#   406: 'y',
#   407: 'paso',
#   408: 'de',
#   409: 'mensajes,',
#   410: 'son',
#   411: 'ejemplos',
#   412: 'de',
#   413: 'mi',
#   414: 'interés"',
#   415: '[10].',
#   416: 'Podemos',
#   417: 'observar',
#   418: 'que',
#   419: 'existen',
#   420: 'palabras',
#   421: 'como',
#   422: 'descripciones,',
#   423: 'mecanismos,',
#   424: 'implementación',
#   425: 'y',
#   426: 'problema,',
#   427: 'que',
#   428: 'deberían',
#   429: 'estar',
#   430: 'presentes',
#   431: 'en',
#   432: 'los',
#   433: 'documentos',
#   434: 'recuperados',
#   435: 'pero',
#   436: 'manteniendo',
#   437: 'la',
#   438: 'relación',
#   439: 'expresada,',
#   440: 'ya',
#   441: 'que',
#   442: 'se',
#   443: 'buscan',
#   444: '"descripciones',
#   445: 'de',
#   446: 'mecanismos',
#   447: 'de',
#   448: 'comunicación',
#   449: 'entre',
#   450: 'procesos".',
#   451: 'Si',
#   452: 'empleamos',
#   453: 'de',
#   454: 'manera',
#   455: 'aislada',
#   456: 'las',
#   457: 'palabras',
#   458: 'mencionadas,',
#   459: 'algunas',
#   460: 'serán',
#   461: 'ignoradas',
#   462: 'por',
#   463: 'su',
#   464: 'generalidad',
#   465: 'al',
#   466: 'crear',
#   467: 'el',
#   468: 'índice',
#   469: 'y',
#   470: 'si',
#   471: 'se',
#   472: 'incluyen',
#   473: 'en',
#   474: 'el',
#   475: 'índice',
#   476: 'conducirán',
#   477: 'a',
#   478: 'recuperar',
#   479: 'gran',
#   480: 'cantidad',
#   481: 'de',
#   482: 'documentos',
#   483: 'irrelevantes.',
#   484: 'Cuando',
#   485: 'se',
#   486: 'recupera',
#   487: 'un',
#   488: 'grupo',
#   489: 'de',
#   490: 'documentos',
#   491: 'se',
#   492: 'encontrará',
#   493: 'que',
#   494: 'algunos',
#   495: 'de',
#   496: 'ellos',
#   497: 'no',
#   498: 'son',
#   499: 'relevantes',
#   500: 'y',
#   501: 'que',
#   502: 'algunos',
#   503: 'relevantes',
#   504: 'no',
#   505: 'se',
#   506: 'han',
#   507: 'recuperado.',
#   508: 'El',
#   509: 'éxito',
#   510: 'de',
#   511: 'la',
#   512: 'recuperación',
#   513: 'se',
#   514: 'establece',
#   515: 'mediante',
#   516: 'dos',
#   517: 'métricas:',
#   518: 'la',
#   519: 'precisión,',
#   520: 'que',
#   521: 'es',
#   522: 'la',
#   523: 'razón',
#   524: 'de',
#   525: 'los',
#   526: 'documentos',
#   527: 'relevantes',
#   528: 'recuperados',
#   529: 'entre',
#   530: 'el',
#   531: 'total',
#   532: 'de',
#   533: 'documentos',
#   534: 'recuperados',
#   535: 'y',
#   536: 'el',
#   537: 'recuerdo,',
#   538: 'la',
#   539: 'razón',
#   540: 'del',
#   541: 'número',
#   542: 'de',
#   543: 'documentos',
#   544: 'relevantes',
#   545: 'recuperados',
#   546: 'entre',
#   547: 'el',
#   548: 'total',
#   549: 'de',
#   550: 'documentos',
#   551: 'relevantes',
#   552: 'existentes',
#   553: 'en',
#   554: 'la',
#   555: 'colección.',
#   556: 'En',
#   557: 'el',
#   558: 'área',
#   559: 'de',
#   560: 'recuperación',
#   561: 'de',
#   562: 'información',
#   563: 'se',
#   564: 'continúa',
#   565: 'experimentando',
#   566: 'con',
#   567: 'nuevos',
#   568: 'modelos',
#   569: 'y',
#   570: 'por',
#   571: 'ende',
#   572: 'nuevas',
#   573: 'representaciones',
#   574: 'de',
#   575: 'documentos,',
#   576: 'para',
#   577: 'intentar',
#   578: 'cubrir',
#   579: 'con',
#   580: 'mayor',
#   581: 'precisión',
#   582: 'las',
#   583: 'necesidades',
#   584: 'de',
#   585: 'información',
#   586: 'de',
#   587: 'los',
#   588: 'usuarios.',
#   589: 'Como',
#   590: 'se',
#   591: 'ha',
#   592: 'especificado,',
#   593: 'nos',
#   594: 'centraremos',
#   595: 'en',
#   596: 'RI,',
#   597: 'donde',
#   598: 'si',
#   599: 'se',
#   600: 'desea',
#   601: 'obtener',
#   602: 'mejoras',
#   603: 'substanciales',
#   604: 'debe',
#   605: 'empezarse',
#   606: 'a',
#   607: 'pensar',
#   608: 'más',
#   609: 'allá',
#   610: 'de',
#   611: 'la',
#   612: 'aproximación',
#   613: 'de',
#   614: 'bolsa',
#   615: 'de',
#   616: 'palabras,',
#   617: 'con',
#   618: 'precisiones',
#   619: 'típicamente',
#   620: 'por',
#   621: 'debajo',
#   622: 'del',
#   623: '50%',
#   624: 'hay',
#   625: 'mucho',
#   626: 'margen',
#   627: 'para',
#   628: 'mejorar',
#   629: '[27].',
#   630: 'En',
#   631: 'la',
#   632: 'siguiente',
#   633: 'sección',
#   634: 'se',
#   635: 'presentan',
#   636: 'trabajos',
#   637: 'que',
#   638: 'describen',
#   639: 'modelos',
#   640: 'clásicos',
#   641: 'y',
#   642: 'nuevos',
#   643: 'de',
#   644: 'recuperación',
#   645: 'de',
#   646: 'información',
#   647: 'para',
#   648: 'concluir',
#   649: 'con',
#   650: 'métodos',
#   651: 'que',
#   652: 'explotan',
#   653: 'la',
#   654: 'obtención',
#   655: 'de',
#   656: 'relaciones,',
#   657: 'empleando',
#   658: 'técnicas',
#   659: 'de',
#   660: 'procesamiento',
#   661: 'de',
#   662: 'lenguaje',
#   663: 'natural,',
#   664: 'para',
#   665: 'realizar',
#   666: 'recuperación',
#   667: 'de'},
#  'Problema8': {1: 'Debido',
#   2: 'al',
#   3: 'vertiginoso',
#   4: 'ritmo',
#   5: 'de',
#   6: 'aparición',
#   7: 'y',
#   8: 'posicionamiento',
#   9: 'de',
#   10: 'las',
#   11: 'tecnologías,',
#   12: 'tanto',
#   13: 'en',
#   14: 'el',
#   15: 'nivel',
#   16: 'de',
#   17: 'las',
#   18: 'comunicaciones',
#   19: 'como',
#   20: 'en',
#   21: 'el',
#   22: 'de',
#   23: 'tráfico,',
#   24: 'se',
#   25: 'han',
#   26: 'cometido',
#   27: 'diversos',
#   28: 'errores',
#   29: 'en',
#   30: 'cuanto',
#   31: 'a',
#   32: 'la',
#   33: 'generación',
#   34: 'de',
#   35: 'los',
#   36: 'contenidos',
#   37: 'publicados',
#   38: 'en',
#   39: 'la',
#   40: 'Web,',
#   41: 'y',
#   42: 'la',
#   43: 'forma',
#   44: 'en',
#   45: 'la',
#   46: 'que',
#   47: 'son',
#   48: 'transmitidos',
#   49: 'a',
#   50: 'los',
#   51: 'usuarios.',
#   52: 'Estos',
#   53: 'errores',
#   54: 'han',
#   55: 'constituido',
#   56: 'duplicidad',
#   57: 'de',
#   58: 'esfuerzos',
#   59: 'al',
#   60: 'desarrollar',
#   61: 'diversas',
#   62: 'aplicaciones',
#   63: 'entre',
#   64: 'diferentes',
#   65: 'administradores,',
#   66: 'sin',
#   67: 'una',
#   68: 'estandarización',
#   69: 'como',
#   70: 'base',
#   71: 'y',
#   72: 'generalmente',
#   73: 'asociada',
#   74: 'con',
#   75: 'el',
#   76: 'desarrollo',
#   77: 'de',
#   78: 'contenidos',
#   79: 'basados',
#   80: 'en',
#   81: 'lenguajes',
#   82: 'de',
#   83: 'marcado',
#   84: 'como',
#   85: 'HTML.',
#   86: 'Esto',
#   87: 'ha',
#   88: 'dificultado',
#   89: 'procesos',
#   90: 'deseables',
#   91: 'como',
#   92: 'el',
#   93: 'compartir',
#   94: 'la',
#   95: 'información',
#   96: 'al',
#   97: 'tratar',
#   98: 'con',
#   99: 'vocabularios',
#   100: 'no',
#   101: 'comunes',
#   102: 'entre',
#   103: 'los',
#   104: 'diferentes',
#   105: 'elementos',
#   106: 'involucrados,',
#   107: 'y',
#   108: 'que',
#   109: 'al',
#   110: 'final',
#   111: 'dan',
#   112: 'como',
#   113: 'resultado',
#   114: 'la',
#   115: 'percepción',
#   116: 'por',
#   117: 'parte',
#   118: 'del',
#   119: 'usuario',
#   120: 'de',
#   121: 'información',
#   122: 'diversa',
#   123: 'y',
#   124: 'difusa.',
#   125: 'A',
#   126: 'continuación',
#   127: 'se',
#   128: 'describen',
#   129: 'cada',
#   130: 'uno',
#   131: 'de',
#   132: 'los',
#   133: 'problemas',
#   134: 'que',
#   135: 'bajo',
#   136: 'mi',
#   137: 'perspectiva,',
#   138: 'caracterizan',
#   139: 'la',
#   140: 'problemática',
#   141: 'de',
#   142: 'la',
#   143: 'difusión',
#   144: 'de',
#   145: 'información',
#   146: 'de',
#   147: 'tráfico',
#   148: 'vía',
#   149: 'Web:',
#   150: 'Problema',
#   151: '1:',
#   152: 'Ausencia',
#   153: 'de',
# ...
#   379: 'Los',
#   380: 'efectos',
#   381: 'producidos',
#   382: 'por',
#   383: 'las',
#   384: 'no',
#   385: 'linealidades',
#   386: 'en',
#   387: 'los',
#   388: 'PAs',
#   389: 'repercuten',
#   390: 'de',
#   391: 'dos',
#   392: 'maneras,',
#   393: 'por',
#   394: 'un',
#   395: 'lado',
#   396: 'causan',
#   397: 'recrecimiento',
#   398: 'espectral,',
#   399: 'dando',
#   400: 'lugar',
#   401: 'a',
#   402: 'interferencias',
#   403: 'en',
#   404: 'los',
#   405: 'canales',
#   406: 'de',
#   407: 'transmisión',
#   408: 'adyacentes',
#   409: '(distorsión',
#   410: 'fuera',
#   411: 'de',
#   412: 'banda',
#   413: 'de',
#   414: 'operación',
#   415: 'asignada),',
#   416: 'mientras',
#   417: 'que',
#   418: 'por',
#   419: 'otro',
#   420: 'lado,',
#   421: 'causan',
#   422: 'distorsión',
#   423: 'dentro',
#   424: 'de',
#   425: 'la',
#   426: 'propia',
#   427: 'banda',
#   428: 'de',
#   429: 'transmisión,',
#   430: 'degradando',
#   431: 'por',
#   432: 'tanto',
#   433: 'la',
#   434: 'Tasa',
#   435: 'de',
#   436: 'Error',
#   437: 'de',
#   438: 'Bits',
#   439: '(BER)',
#   440: '[9].',
#   441: 'Los',
#   442: 'organismos',
#   443: 'reguladores',
#   444: 'fijan',
#   445: 'a',
#   446: 'través',
#   447: 'de',
#   448: 'los',
#   449: 'diferentes',
#   450: 'estándares',
#   451: 'de',
#   452: 'comunicaciones,',
#   453: 'los',
#   454: 'niveles',
#   455: 'máximos',
#   456: 'permitidos',
#   457: 'de',
#   458: 'emisión',
#   459: 'fuera',
#   460: 'de',
#   461: 'banda,',
#   462: 'así',
#   463: 'como',
#   464: 'de',
#   465: 'los',
#   466: 'límites',
#   467: 'de',
#   468: 'distorsión',
#   469: 'en',
#   470: 'la',
#   471: 'banda,',
#   472: 'por',
#   473: 'ejemplo',
#   474: 'especificando',
#   475: 'porcentajes',
#   476: 'máximos',
#   477: 'de',
#   478: 'error',
#   479: 'en',
#   480: 'las',
#   481: 'constelaciones.',
#   482: 'Las',
#   483: 'sanciones',
#   484: 'por',
#   485: 'violar',
#   486: 'cualquiera',
#   487: 'de',
#   488: 'las',
#   489: 'especificaciones',
#   490: 'como',
#   491: 'son',
#   492: 'potencia',
#   493: 'de',
#   494: 'transmisión,',
#   495: 'emisión',
#   496: 'fuera',
#   497: 'de',
#   498: 'banda',
#   499: 'entre',
#   500: 'otras',
#   501: 'son',
#   502: 'multas',
#   503: 'elevadas.',
#   504: 'Las',
#   505: 'series',
#   506: 'de',
#   507: 'Volterra',
#   508: 'pueden',
#   509: 'ser',
#   510: 'usadas',
#   511: 'para',
#   512: 'describir',
#   513: 'un',
#   514: 'sistema',
#   515: 'estable',
#   516: 'no',
#   517: 'lineal',
#   518: 'con',
#   519: 'pérdida',
#   520: 'de',
#   521: 'memoria',
#   522: 'con',
#   523: 'un',
#   524: 'error',
#   525: 'arbitrario',
#   526: 'pequeño.',
#   527: 'Sin',
#   528: 'embargo,',
#   529: 'las',
#   530: 'desventajas',
#   531: 'principales',
#   532: 'son',
#   533: 'el',
#   534: 'incremento',
#   535: 'dramático',
#   536: 'del',
#   537: 'número',
#   538: 'de',
#   539: 'parámetros',
#   540: 'con',
#   541: 'respecto',
#   542: 'al',
#   543: 'orden',
#   544: 'de',
#   545: 'no',
#   546: 'linealidad',
#   547: 'y',
#   548: 'profundidad',
#   549: 'de',
#   550: 'memoria',
#   551: 'lo',
#   552: 'cual',
#   553: 'causa',
#   554: 'un',
#   555: 'incremento',
#   556: 'drástico',
#   557: 'de',
#   558: 'la',
#   559: 'complejidad',
#   560: 'de',
#   561: 'cálculo',
#   562: 'e',
#   563: 'identificación',
#   564: 'de',
#   565: 'parámetros.',
#   566: 'Esta',
#   567: 'es',
#   568: 'la',
#   569: 'razón',
#   570: 'por',
#   571: 'la',
#   572: 'que',
#   573: 'resulta',
#   574: 'altamente',
#   575: 'impráctico',
#   576: 'el',
#   577: 'uso',
#   578: 'de',
#   579: 'las',
#   580: 'series',
#   581: 'completas',
#   582: 'de',
#   583: 'Volterra',
#   584: 'para',
#   585: 'representar',
#   586: 'matemáticamente',
#   587: 'el',
#   588: 'comportamiento',
#   589: 'de',
#   590: 'sistemas',
#   591: 'con',
#   592: 'alta',
#   593: 'no',
#   594: 'linealidad',
#   595: 'y',
#   596: 'profundidad',
#   597: 'de',
#   598: 'memoria',
#   599: 'por',
#   600: 'lo',
#   601: 'que',
#   602: 'se',
#   603: 'requiere',
#   604: 'el',
#   605: 'uso',
#   606: 'de',
#   607: 'truncaciones',
#   608: 'como',
#   609: 'MPM,',
#   610: 'Wiener',
#   611: 'y',
#   612: 'Hammerstein',
#   613: 'donde',
#   614: 'el',
#   615: 'costo',
#   616: 'computacional',
#   617: 'y',
#   618: 'de',
#   619: 'cálculo',
#   620: 'de',
#   621: 'los',
#   622: 'kernels',
#   623: 'de',
#   624: 'cada',
#   625: 'modelo',
#   626: 'sea',
#   627: 'reducido',
#   628: 'en',
#   629: 'comparación',
#   630: 'con',
#   631: 'las',
#   632: 'series',
#   633: 'completas.',
#   634: 'Aunado',
#   635: 'al',
#   636: 'proceso',
#   637: 'de',
#   638: 'modelado',
#   639: 'de',
#   640: 'comportamiento',
#   641: 'del',
#   642: 'PA',
#   643: 'y',
#   644: 'de',
#   645: 'un',
#   646: 'sistema',
#   647: 'completo',
#   648: 'que',
#   649: 'incluya',
#   650: 'diversos',
#   651: 'modelos',
#   652: 'de',
#   653: 'comportamiento,',
#   654: 'es',
#   655: 'necesario',
#   656: 'desarrollar',
#   657: 'técnicas',
#   658: 'de',
#   659: 'medición',
#   660: 'de',
#   661: 'bajo',
#   662: 'costo,',
#   663: 'donde',
#   664: 'métodos',
#   665: 'tradicionales',
#   666: 'de',
#   667: 'medición',
#   668: 'a',
#   669: 'través',
#   670: 'de',
#   671: 'un',
#   672: 'VNA',
#   673: 'no',
#   674: 'sean',
#   675: 'indispensables',
#   676: 'al',
#   677: 'realizar',
#   678: 'un',
#   679: 'proceso',
#   680: 'de',
#   681: 'linealización.',
#   682: 'La',
#   683: 'medición',
#   684: 'en',
#   685: 'fase',
#   686: 'del',
#   687: 'parámetro',
#   688: 'de',
#   689: 'dispersión',
#   690: 'S21',
#   691: 'provee',
#   692: 'la',
#   693: 'información',
#   694: 'de',
#   695: 'la',
#   696: 'distorsión',
#   697: 'en',
#   698: 'fase',
#   699: 'del',
#   700: 'PA.',
#   701: 'Sin',
#   702: 'embargo',
#   703: 'como',
#   704: 'se',
#   705: 'menciona',
#   706: 'involucra',
#   707: 'un',
#   708: 'costoso',
#   709: 'uso',
#   710: 'de',
#   711: 'equipo',
#   712: 'de',
#   713: 'laboratorio,',
#   714: 'además',
#   715: 'de',
#   716: 'instalación',
#   717: 'y',
#   718: 'calibración',
#   719: 'previa,',
#   720: 'donde',
#   721: 'involucra',
#   722: 'diversas',
#   723: 'consideraciones',
#   724: 'para',
#   725: 'un',
#   726: 'método',
#   727: 'tradicional',
#   728: 'de',
#   729: 'medición',
#   730: '[36].',
#   731: 'Todo',
#   732: 'lo',
#   733: 'anterior',
#   734: 'nos',
#   735: 'lleva',
#   736: 'a',
#   737: 'la',
#   738: 'necesidad',
#   739: 'de',
#   740: 'contar',
#   741: 'con',
#   742: 'un',
#   743: 'sistema',
#   744: 'digital',
#   745: 'completo',
#   746: 'que',
#   747: 'pueda',
#   748: 'modelar',
#   749: 'las',
#   750: 'curvas',
#   751: 'de',
#   752: 'distorsión',
#   753: 'de',
#   754: 'un',
#   755: 'PA,',
#   756: 'estimar',
#   757: 'su',
#   758: 'comportamiento',
#   759: 'si',
#   760: 'el',
#   761: 'PA',
#   762: 'es',
#   763: 'utilizado',
#   764: 'como',
#   765: 'DUT,',
#   766: 'realizar',
#   767: 'el',
#   768: 'proceso',
#   769: 'de',
#   770: 'modelado',
#   771: 'y',
#   772: 'utilizar',
#   773: 'algoritmos',
#   774: 'de',
#   775: 'aprendizaje',
#   776: 'como',
#   777: 'ANN',
#   778: 'y',
#   779: 'ANFIS',
#   780: 'dado',
#   781: 'que',
#   782: 'se',
#   783: 'obtuvo',
#   784: 'comportamiento',
#   785: 'complejos',
#   786: 'de',
#   787: 'PAs',
#   788: 'con',
#   789: 'una',
#   790: 'infinidad',
#   791: 'de',
#   792: 'datos',
#   793: 'a',
#   794: 'estimar.',
#   795: 'Y',
#   796: 'además',
#   797: 'estimar',
#   798: 'la',
#   799: 'distorsión',
#   800: 'en',
#   801: 'fase',
#   802: 'del',
#   803: 'PA',
#   804: 'usando',
#   805: 'la',
#   806: 'teoría',
#   807: 'de',
#   808: 'transformación',
#   809: 'de',
#   810: 'amplitud',
#   811: 'a',
#   812: 'fase.'},
#  'Problema33': {1: 'Uno',
#   2: 'de',
#   3: 'los',
#   4: 'principales',
#   5: 'problemas',
#   6: 'que',
#   7: 'los',
#   8: 'sistemas',
#   9: 'normales',
#   10: 'de',
#   11: 'sensado',
#   12: 'en',
#   13: 'estructuras',
#   14: 'presentan',
#   15: 'es',
#   16: 'que',
#   17: 'son',
#   18: 'puntuales',
#   19: 'y',
#   20: 'necesitan',
#   21: 'cableado',
#   22: 'y',
#   23: 'protección',
#   24: 'que',
#   25: 'resulta',
#   26: 'pesado,',
#   27: 'incrementado',
#   28: 'el',
#   29: 'peso',
#   30: 'total',
#   31: 'a',
#   32: 'la',
#   33: 'estructura.',
#   34: 'Además',
#   35: 'se',
#   36: 'emplea',
#   37: 'cableado',
#   38: 'para',
#   39: 'alimentación',
#   40: 'de',
#   41: 'energía',
#   42: 'o',
#   43: 'en',
#   44: 'un',
#   45: 'mejor',
#   46: 'caso',
#   47: 'se',
#   48: 'emplean',
#   49: 'baterías',
#   50: 'cuando',
#   51: 'se',
#   52: 'utiliza',
#   53: 'comunicación',
#   54: 'inalámbrica.',
#   55: 'Aunado',
#   56: 'a',
#   57: 'esto,',
#   58: 'en',
#   59: 'ocasiones',
#   60: 'se',
#   61: 'necesita',
#   62: 'colocar',
#   63: 'sensores',
#   64: 'en',
#   65: 'lugares',
#   66: 'de',
#   67: 'difícil',
#   68: 'acceso,',
#   69: 'así',
#   70: 'como',
#   71: 'formar',
#   72: 'una',
#   73: 'red',
#   74: 'de',
#   75: 'sensores',
#   76: 'para',
#   77: 'buscar',
#   78: 'una',
#   79: 'mayor',
#   80: 'exactitud.',
#   81: 'Lo',
#   82: 'anterior',
#   83: 'involucra',
#   84: 'un',
#   85: 'sistema',
#   86: 'de',
#   87: 'adquisición',
#   88: 'limitado',
#   89: 'por',
#   90: 'el',
#   91: 'número',
#   92: 'de',
#   93: 'canales,',
#   94: 'que',
#   95: 'en',
#   96: 'caso',
#   97: 'de',
#   98: 'requerir',
#   99: 'de',
#   100: 'una',
#   101: 'mayor',
#   102: 'cantidad',
#   103: 'de',
#   104: 'sensores,',
#   105: 'se',
#   106: 'necesitará',
#   107: 'de',
#   108: 'varios',
#   109: 'sistemas',
#   110: 'de',
#   111: 'adquisición.',
#   112: 'Es',
#   113: 'necesario',
#   114: 'entonces,',
#   115: 'estudiar',
#   116: 'las',
#   117: 'técnicas',
#   118: 'actuales',
#   119: 'de',
#   120: 'sensado',
#   121: 'que',
#   122: 'emplean',
#   123: 'diferentes',
#   124: 'tipos',
#   125: 'de',
#   126: 'fibras',
#   127: 'ópticas,',
#   128: 'tanto',
#   129: 'estándar',
#   130: 'como',
#   131: 'dopadas',
#   132: 'de',
#   133: 'tierras',
#   134: 'raras',
#   135: 'y',
#   136: 'el',
#   137: 'empleo',
#   138: 'de',
#   139: 'métodos',
#   140: 'menos',
#   141: 'complejos',
#   142: 'que',
#   143: 'permitan',
#   144: 'un',
#   145: 'sensado'},
#  'Problema34': {1: 'En',
#   2: 'visiÃ³n',
#   3: 'artificial,',
#   4: 'la',
#   5: 'segmentaciÃ³n',
#   6: 'de',
#   7: 'imÃ¡genes',
#   8: 'es',
#   9: 'el',
#   10: 'proceso',
#   11: 'de',
#   12: 'particiÃ³n',
#   13: 'de',
#   14: 'una',
#   15: 'imagen',
#   16: 'digital',
#   17: 'en',
#   18: 'mÃºltiples',
#   19: 'segmentos',
#   20: '(conjuntos',
#   21: 'de',
#   22: 'pÃ\xadxeles,',
#   23: 'tambiÃ©n',
#   24: 'conocidos',
#   25: 'como',
#   26: 'superpÃ\xadxeles).',
#   27: 'El',
#   28: 'objetivo',
#   29: 'de',
#   30: 'la',
#   31: 'segmentaciÃ³n',
#   32: 'es',
#   33: 'simplificar',
#   34: 'y',
#   35: '/',
#   36: 'o',
#   37: 'cambiar',
#   38: 'la',
#   39: 'representaciÃ³n',
#   40: 'de',
#   41: 'una',
#   42: 'imagen',
#   43: 'en',
#   44: 'algo',
#   45: 'que',
#   46: 'es',
#   47: 'mÃ¡s',
#   48: 'significativo',
#   49: 'y',
#   50: 'fÃ¡cil',
#   51: 'de',
#   52: 'analizar.',
#   53: 'La',
#   54: 'segmentaciÃ³n',
#   55: 'de',
#   56: 'imÃ¡genes',
#   57: 'se',
#   58: 'utiliza',
#   59: 'normalmente',
#   60: 'para',
#   61: 'localizar',
#   62: 'objetos',
#   63: 'y',
#   64: 'bordes',
#   65: '(regiones,',
#   66: 'lÃ\xadneas,',
#   67: 'curvas,',
#   68: 'etc.)',
#   69: 'en',
#   70: 'imÃ¡genes.',
#   71: 'MÃ¡s',
#   72: 'precisamente,',
#   73: 'la',
#   74: 'segmentaciÃ³n',
#   75: 'de',
#   76: 'imÃ¡genes',
#   77: 'es',
#   78: 'el',
#   79: 'proceso',
#   80: 'de',
#   81: 'asignar',
#   82: 'una',
#   83: 'etiqueta',
#   84: 'a',
#   85: 'cada',
#   86: 'pÃ\xadxel',
#   87: 'de',
#   88: 'una',
#   89: 'imagen',
#   90: 'de',
#   91: 'modo',
#   92: 'que',
#   93: 'los',
#   94: 'pÃ\xadxeles',
#   95: 'con',
#   96: 'la',
#   97: 'misma',
#   98: 'etiqueta',
#   99: 'comparten',
#   100: 'ciertas',
#   101: 'caracterÃ\xadsticas',
#   102: 'comunes',
#   103: '[47].',
#   104: 'El',
#   105: 'resultado',
#   106: 'de',
#   107: 'la',
#   108: 'segmentaciÃ³n',
#   109: 'es',
#   110: 'un',
#   111: 'conjunto',
#   112: 'de',
#   113: 'segmentos',
#   114: 'que',
#   115: 'cubren',
#   116: 'colectivamente',
#   117: 'toda',
#   118: 'la',
#   119: 'imagen',
#   120: 'o',
#   121: 'un',
#   122: 'conjunto',
#   123: 'de',
#   124: 'contornos',
#   125: 'extraÃ\xaddos',
#   126: 'de',
#   127: 'la',
#   128: 'imagen',
#   129: '(ver',
#   130: 'detecciÃ³n',
#   131: 'de',
#   132: 'bordes).',
#   133: 'Cada',
#   134: 'uno',
#   135: 'de',
#   136: 'los',
#   137: 'pÃ\xadxeles',
#   138: 'de',
#   139: 'una',
#   140: 'regiÃ³n',
#   141: 'es',
#   142: 'similar',
#   143: 'con',
#   144: 'respecto',
#   145: 'a',
#   146: 'alguna',
#   147: 'caracterÃ\xadstica',
#   148: 'o',
#   149: 'propiedad',
#   150: 'calculada,',
#   151: 'como',
#   152: 'el',
#   153: 'color,',
#   154: 'la',
#   155: 'intensidad',
#   156: 'o',
#   157: 'la',
#   158: 'textura.',
#   159: 'Las',
#   160: 'regiones',
#   161: 'adyacentes',
#   162: 'son',
#   163: 'significativamente',
#   164: 'diferentes',
#   165: 'con',
#   166: 'respecto',
#   167: 'a',
#   168: 'la',
#   169: 'misma',
#   170: 'caracterÃ\xadstica',
#   171: '(s)',
#   172: '[47].',
#   173: 'â€œLa',
#   174: 'segmentaciÃ³n',
#   175: 'de',
#   176: 'una',
#   177: 'imagen',
#   178: 'consiste',
#   179: 'en',
#   180: 'la',
#   181: 'particiÃ³n',
#   182: 'de',
#   183: 'dicha',
#   184: 'imagen',
#   185: 'en',
#   186: 'diferentes',
#   187: 'regiones',
#   188: 'similares',
#   189: 'en',
#   190: 'alguna',
#   191: 'caracterÃ\xadstica',
#   192: 'predefinida',
#   193: '(â€¦)',
#   194: 'Los',
#   195: 'seres',
#   196: 'humanos',
#   197: 'usamos',
#   198: 'nuestro',
#   199: 'sentido',
#   200: 'visual',
#   201: 'para',
#   202: 'separar',
#   203: 'nuestro',
#   204: 'entorno',
#   205: 'inmediato',
#   206: 'en',
#   207: 'objetos',
#   208: 'distintos',
#   209: 'sin',
#   210: 'esfuerzo',
#   211: 'alguno',
#   212: 'para',
#   213: 'reconocerlos,',
#   214: 'guiar',
#   215: 'nuestros',
#   216: 'movimientos',
#   217: 'y',
#   218: 'para',
#   219: 'casi',
#   220: 'todas',
#   221: 'las',
#   222: 'actividades',
#   223: 'de',
#   224: 'nuestra',
#   225: 'vida.â€\x9d',
#   226: '(K.N.,',
#   227: 'Plataniotis,',
#   228: 'y',
#   229: 'A.N.Venetsanopoulos,',
#   230: '2000,',
#   231: 'p.',
#   232: '237,',
#   233: 'traducido).',
#   234: 'La',
#   235: 'segmentaciÃ³n',
#   236: 'es',
#   237: 'una',
#   238: 'caracterÃ\xadstica',
#   239: 'importante',
#   240: 'de',
#   241: 'la',
#   242: 'percepciÃ³n',
#   243: 'visual',
#   244: 'humana',
#   245: 'que',
#   246: 'se',
#   247: 'manifiesta',
#   248: 'de',
#   249: 'forma',
#   250: 'espontÃ¡nea',
#   251: 'y',
#   252: 'natural;',
#   253: 'aunque',
#   254: 'estÃ¡n',
#   255: 'involucrados',
#   256: 'procesos',
#   257: 'complejos',
#   258: 'como',
#   259: 'el',
#   260: 'anÃ¡lisis',
#   261: 'de',
#   262: 'color,',
#   263: 'la',
#   264: 'forma,',
#   265: 'el',
#   266: 'movimiento,',
#   267: 'la',
#   268: 'textura,',
#   269: 'etc.',
#   270: '[1][2][3].',
#   271: 'El',
#   272: 'color',
#   273: 'es',
#   274: 'una',
#   275: 'caracterÃ\xadstica',
#   276: 'visual',
#   277: 'poderosa',
#   278: 'y',
#   279: 'robusta',
#   280: 'para',
#   281: 'diferenciar',
#   282: 'los',
#   283: 'diferentes',
#   284: 'objetos',
#   285: 'en',
#   286: 'una',
#   287: 'imagen.',
#   288: 'Es',
#   289: 'una',
#   290: 'importante',
#   291: 'fuente',
#   292: 'de',
#   293: 'informaciÃ³n',
#   294: 'en',
#   295: 'el',
#   296: 'proceso',
#   297: 'de',
#   298: 'segmentaciÃ³n',
#   299: 'y',
#   300: 'puede',
#   301: 'en',
#   302: 'muchos',
#   303: 'casos',
#   304: 'ser',
#   305: 'utilizado',
#   306: 'como',
#   307: 'Ãºnica',
#   308: 'caracterÃ\xadstica',
#   309: 'y',
#   310: 'Ãºnico',
#   311: 'descriptor',
#   312: 'para',
#   313: 'la',
#   314: 'segmentaciÃ³n',
#   315: 'de',
#   316: 'los',
#   317: 'objetos',
#   318: 'de',
#   319: 'interÃ©s',
#   320: '[1][2][3].',
#   321: 'En',
#   322: 'este',
#   323: 'trabajo',
#   324: 'de',
#   325: 'tesis',
#   326: 'se',
#   327: 'busca',
#   328: 'investigar',
#   329: 'sobre',
#   330: 'un',
#   331: 'mÃ©todo',
#   332: 'propio',
#   333: 'de',
#   334: 'segmentaciÃ³n',
#   335: 'del',
#   336: 'color',
#   337: 'en',
#   338: 'imÃ¡genes',
#   339: 'de',
#   340: 'color.',
#   341: 'El',
#   342: 'mÃ©todo',
#   343: 'sÃ³lo',
#   344: 'utiliza',
#   345: 'la',
#   346: 'informaciÃ³n',
#   347: 'de',
#   348: 'color',
#   349: 'para',
#   350: 'realizar',
#   351: 'la',
#   352: 'segmentaciÃ³n,',
#   353: 'por',
#   354: 'lo',
#   355: 'que',
#   356: 'se',
#   357: 'considera',
#   358: 'como',
#   359: 'un',
#   360: 'indispensable',
#   361: 'paso',
#   362: 'previo',
#   363: 'al',
#   364: 'de',
#   365: 'reconocimiento.',
#   366: 'En',
#   367: 'este',
#   368: 'trabajo',
#   369: 'no',
#   370: 'se',
#   371: 'pretende',
#   372: 'llegar',
#   373: 'al',
#   374: 'reconocimiento',
#   375: 'de',
#   376: 'objetos',
#   377: 'o',
#   378: 'clases',
#   379: 'de',
#   380: 'objetos,',
#   381: 'sino',
#   382: 'Ãºnicamente',
#   383: 'a',
#   384: 'la',
#   385: 'segmentaciÃ³n',
#   386: 'de',
#   387: 'la',
#   388: 'imagen',
#   389: 'en',
#   390: 'regiones',
#   391: 'homogÃ©neas',
#   392: 'de',
#   393: 'color',
#   394: 'que',
#   395: 'podrÃ\xadan',
#   396: 'ser',
#   397: 'utilizadas',
#   398: 'para',
#   399: 'alimentar',
#   400: 'a',
#   401: 'tareas'}}

# %% [markdown]
# ## Obtain Size for the Justification Data

# %%
sizesTSU = returnSizes(TSU_structured)
sizesLic = returnSizes(Lic_structured)
sizesMasters = returnSizes(Masters_structured)
sizesPhd = returnSizes(Phd_structured)
sizesTSU
sizesLic 
sizesMasters
sizesPhd
# Out:
# {'Smallest': 43, 'Biggest': 1642, 'Average': 588.3636363636364}

# %% [markdown]
# ## Remove Stop Words and Cleaning

# %%
TSU_structured = cleanMeth(sw, TSU_structured)
Lic_structured = cleanMeth(sw, Lic_structured)
Masters_structured = cleanMeth(sw, Masters_structured)
Phd_structured = cleanMeth(sw, Phd_structured)
TSU_structured
Lic_structured
Masters_structured
Phd_structured
# Out:
# {'Problema2': {2: 'gran',
#   3: 'cantidad',
#   5: 'información',
#   6: 'disponible',
#   8: 'internet',
#   10: 'complejidad',
#   12: 'heterogeneidad',
#   15: 'misma',
#   16: 'junto',
#   19: 'distintas',
#   20: 'características',
#   23: 'usuarios',
#   25: 'acceden',
#   27: 'dicha',
#   28: 'información',
#   29: 'así',
#   32: 'gran',
#   33: 'competencia',
#   34: 'existente',
#   37: 'red',
#   38: 'hacen',
#   39: 'crítico',
#   42: 'desarrollo',
#   44: 'aplicaciones',
#   45: 'basadas',
#   47: 'web',
#   50: 'manera',
#   51: 'particular',
#   53: 'sitios',
#   54: 'web',
#   55: 'educativos',
#   56: 'deban',
#   57: 'contemplar',
#   59: 'solo',
#   60: 'aspectos',
#   62: 'funcionalidad',
#   63: 'sino',
#   66: 'usabilidad',
#   67: 'tomando',
#   69: 'cuenta',
#   72: 'aplicaciones',
#   74: 'solo',
#   75: 'deben',
#   76: 'tener',
#   78: 'objetivo',
#   79: 'poner',
#   81: 'disposición',
#   84: 'usuarios',
#   85: 'información',
#   86: 'exacta',
#   87: 'sino',
#   88: 'orientar',
#   89: 'adecuadamente',
#   91: 'usuario',
#   94: 'búsqueda',
#   95: 'adecuando',
#   97: 'caminos',
#   99: 'apropiados',
#   101: 'cada',
#   102: 'usuario',
#   104: 'acuerdo',
#   107: 'objetivos',
#   109: 'conocimientos',
#   110: 'previos',
#   113: 'necesidades',
#   115: 'perfiles',
#   117: 'usabilidad',
#   120: 'contexto',
#   122: 'enmarca',
#   125: 'pregunta',
#   127: 'si',
#   129: 'aplicación',
#   130: 'web',
#   131: 'educativa',
#   134: 'suficientemente',
#   135: 'buena',
#   137: 'satisfacer',
#   139: 'necesidades',
#   141: 'requerimientos',
#   143: 'usuario',
#   145: 'decir',
#   147: 'usabilidad',
#   148: 'corresponde',
#   151: 'variable',
#   154: 'marco',
#   157: 'aceptación',
#   158: 'práctica',
#   161: 'sitio',
#   162: 'web',
#   163: 'educativo',
#   164: 'así',
#   168: 'sitio',
#   169: 'web',
#   170: 'pueda',
#   171: 'ser',
#   172: 'utilizado',
#   174: 'alcanzar',
#   175: 'alguna',
#   176: 'tarea',
#   179: 'cumplir',
#   181: 'criterios',
#   183: 'utilización',
#   185: 'decir',
#   186: 'referido',
#   189: 'funcionalidad',
#   190: 'puede',
#   191: 'hacer',
#   195: 'necesita',
#   197: 'usabilidad',
#   198: 'cuán',
#   199: 'bien',
#   201: 'usuarios',
#   202: 'pueden',
#   203: 'usar',
#   205: 'funcionalidad',
#   207: 'sitio',
#   208: 'web',
#   210: 'usabilidad',
#   211: 'considera',
#   214: 'aspectos',
#   217: 'sitio',
#   218: 'web',
#   219: 'educativo',
#   224: 'usuario',
#   225: 'puede',
#   226: 'interactuar',
#   229: 'principales',
#   230: 'criterios',
#   232: 'evaluación',
#   233: 'aprendizaje',
#   234: 'operabilidad',
#   235: 'comunicación',
#   236: 'contenido',
#   237: 'etc',
#   239: 'ejemplo',
#   241: 'sitio',
#   242: 'debe',
#   243: 'cumplir',
#   245: 'funcionalidad',
#   247: 'presentar',
#   248: 'determinado',
#   249: 'tipo',
#   251: 'contenido',
#   254: 'contenido',
#   255: 'debe',
#   256: 'ser',
#   257: 'presentado',
#   260: 'manera',
#   261: 'atractiva',
#   263: 'sencilla',
#   265: 'usuario',
#   268: 'además',
#   270: 'aprendizaje',
#   273: 'uso',
#   275: 'navegación',
#   277: 'intuitiva',
#   279: 'fácil',
#   281: 'llevar',
#   283: 'cabo',
#   285: 'proceso',
#   287: 'aprendizaje',
#   288: 'rápido',
#   290: 'eficaz',
#   294: 'autores',
#   297: 'investigado',
#   299: 'propuesto',
#   300: 'recomendaciones',
#   301: 'guías',
#   302: 'listas',
#   304: 'comprobación',
#   305: 'principios',
#   306: 'etc',
#   309: 'desarrollo',
#   311: 'aplicaciones',
#   312: 'usables',
#   313: 'niea',
#   314: 'niea',
#   315: 'shn',
#   316: 'bev',
#   321: 'pocos',
#   324: 'evaluación',
#   327: 'usabilidad',
#   329: 'sitios',
#   330: 'web',
#   331: 'educativos',
#   332: 'gon',
#   333: 'car',
#   335: 'embargo',
#   336: 'basta',
#   337: 'hacer',
#   339: 'exploración',
#   342: 'web',
#   344: 'comprobar',
#   347: 'aún',
#   348: 'sigue',
#   351: 'problema',
#   352: 'si',
#   355: 'cuenta',
#   357: 'existe',
#   359: 'diversidad',
#   361: 'dominios',
#   363: 'aplicación',
#   364: 'basadas',
#   366: 'web',
#   367: 'comerciales',
#   368: 'ocio',
#   369: 'entretenimiento',
#   370: 'educación',
#   371: 'etc',
#   373: 'mala',
#   374: 'usabilidad',
#   376: 'sitios',
#   377: 'comerciales',
#   379: 'ocio',
#   381: 'incluso',
#   383: 'noticias',
#   384: 'puede',
#   385: 'significar',
#   386: 'simplemente',
#   389: 'usuario',
#   390: 'busque',
#   392: 'lugar',
#   394: 'embargo',
#   397: 'caso',
#   399: 'sitios',
#   401: 'carácter',
#   402: 'educativo',
#   404: 'problema',
#   406: 'agudiza',
#   410: 'mala',
#   411: 'usabilidad',
#   412: 'puede',
#   413: 'repercutir',
#   414: 'fuertemente',
#   417: 'objetivos',
#   419: 'aprendizaje',
#   421: 'decir',
#   423: 'requisitos',
#   425: 'usabilidad',
#   428: 'sitio',
#   429: 'web',
#   430: 'comercial',
#   432: 'venta',
#   434: 'herramientas',
#   436: 'carpintería',
#   437: 'orientado',
#   439: 'aquellos',
#   440: 'profesionales',
#   442: 'área',
#   444: 'personas',
#   445: 'aficionadas',
#   448: 'carpintería',
#   449: 'cuyo',
#   450: 'interés',
#   452: 'centrado',
#   454: 'encontrar',
#   456: 'producto',
#   458: 'carpintería',
#   459: 'determinado',
#   461: 'mejor',
#   462: 'precio',
#   464: 'diferente',
#   467: 'requisitos',
#   469: 'usabilidad',
#   471: 'sitio',
#   472: 'web',
#   474: 'algún',
#   475: 'curso',
#   478: 'universidad',
#   480: 'institución',
#   481: 'educativa',
#   483: 'principio',
#   487: 'motivaciones',
#   490: 'usuarios',
#   492: 'distintas',
#   494: 'perfil',
#   500: 'así',
#   503: 'metas',
#   505: 'alcanzar',
#   507: 'cada',
#   509: 'así',
#   510: 'preparar',
#   512: 'proceso',
#   514: 'evaluación',
#   516: 'usabilidad',
#   519: 'sitio',
#   520: 'comercial',
#   524: 'mismo',
#   529: 'sitio',
#   530: 'educativo',
#   531: 'aunque',
#   532: 'ambos',
#   533: 'buscan',
#   534: 'cubrir',
#   536: 'servicio',
#   537: 'lograr',
#   539: 'satisfacción',
#   541: 'usuario',
#   545: 'casos',
#   546: 'ambos',
#   547: 'pretendan',
#   548: 'lograr',
#   549: 'dividendos',
#   550: 'económicos',
#   552: 'sitios',
#   553: 'web',
#   554: 'educativos',
#   557: 'añadido',
#   558: 'fundamental',
#   562: 'transmisión',
#   564: 'adquisición',
#   566: 'conocimiento',
#   568: 'ende',
#   570: 'factor',
#   571: 'importante',
#   573: 'evaluación',
#   576: 'aspecto',
#   577: 'educativo',
#   580: 'presentación',
#   582: 'contenidos',
#   584: 'consideración',
#   587: 'usabilidad',
#   590: 'factor',
#   591: 'importante',
#   594: 'desarrollo',
#   596: 'aplicaciones',
#   597: 'web',
#   599: 'ido',
#   601: 'aumento',
#   604: 'últimos',
#   605: 'años',
#   606: 'basándose',
#   609: 'fundamento',
#   610: 'teórico',
#   613: 'usabilidad',
#   615: 'software',
#   616: 'tradicional',
#   620: 'principios',
#   621: 'establecidos',
#   624: 'estándares',
#   625: 'internacionales',
#   629: 'experiencia',
#   630: 'adquirida',
#   633: 'diseño',
#   635: 'desarrollo',
#   637: 'aplicaciones',
#   638: 'web',
#   641: 'desarrollado',
#   642: 'metodologías',
#   644: 'guías',
#   647: 'desarrollo',
#   649: 'aplicaciones',
#   650: 'web',
#   652: 'criterios',
#   654: 'usabilidad',
#   656: 'permiten',
#   657: 'realizar',
#   659: 'proceso',
#   661: 'evaluación',
#   663: 'usabilidad',
#   665: 'limitados',
#   667: 'aspectos',
#   668: 'específicos',
#   671: 'misma',
#   673: 'enfocados',
#   676: 'evaluación',
#   678: 'sitios',
#   679: 'comerciales',
#   681: 'aunque',
#   682: 'señalan',
#   684: 'extensión',
#   686: 'sitios',
#   687: 'educativos',
#   689: 'criterios',
#   690: 'considerados',
#   693: 'ajustan',
#   696: 'requisitos',
#   698: 'usabilidad',
#   701: 'aplicaciones',
#   704: 'actualidad',
#   705: 'existen',
#   706: 'diferentes',
#   707: 'métodos',
#   709: 'pueden',
#   710: 'ser',
#   711: 'usados',
#   714: 'evaluación',
#   716: 'usabilidad',
#   717: 'dependiendo',
#   719: 'propósito',
#   721: 'medición',
#   723: 'tipo',
#   725: 'medida',
#   727: 'obtener',
#   730: 'etapa',
#   732: 'ciclo',
#   734: 'vida',
#   735: 'etc',
#   737: 'u',
#   740: 'usados',
#   742: 'asegurar',
#   743: 'referencias',
#   745: 'mejoren',
#   747: 'usabilidad',
#   749: 'establezcan',
#   750: 'si',
#   754: 'suficientemente',
#   755: 'buena',
#   756: 'desafortunadamente',
#   760: 'acuerdo',
#   761: 'respecto',
#   764: 'denominación',
#   765: 'uso',
#   767: 'aplicación',
#   770: 'métodos',
#   771: 'existentes',
#   774: 'desarrollo',
#   776: 'aplicaciones',
#   777: 'web',
#   778: 'así',
#   780: 'diferentes',
#   781: 'autores',
#   783: 'denominan',
#   785: 'acuerdo',
#   788: 'preferencias',
#   790: 'juicio',
#   792: 'experiencia',
#   793: 'kirakowski',
#   794: 'indagación',
#   795: 'kir',
#   796: 'nielsen',
#   798: 'heurísticas',
#   799: 'nielsen',
#   800: 'nie',
#   801: 'niec',
#   802: 'preece',
#   803: 'evaluación',
#   805: 'expertos',
#   806: 'pre',
#   807: 'scriven',
#   808: 'formativasumativa',
#   809: 'scr',
#   811: 'métodos',
#   813: 'evaluación',
#   815: 'usabilidad',
#   818: 'lado',
#   820: 'fortalezas',
#   822: 'debilidades',
#   827: 'enfocados',
#   829: 'evaluar',
#   830: 'determinados',
#   831: 'aspectos',
#   833: 'requisitos',
#   835: 'usabilidad',
#   840: 'recomendable',
#   841: 'combinarlos',
#   844: 'evaluación',
#   846: 'complementar',
#   851: 'cuanto',
#   854: 'fortalezas',
#   856: 'lograr',
#   857: 'cubrir',
#   859: 'mayor',
#   860: 'número',
#   862: 'aspectos',
#   864: 'evaluación',
#   866: 'selección',
#   868: 'combinación',
#   871: 'métodos',
#   873: 'evaluación',
#   874: 'dependerá',
#   876: 'restricciones',
#   877: 'financieras',
#   880: 'tiempo',
#   883: 'fases',
#   886: 'ciclo',
#   888: 'desarrollo',
#   892: 'naturaleza',
#   894: 'sistema',
#   895: 'bajo',
#   896: 'desarrollo',
#   897: 'bevan',
#   898: 'bev',
#   899: 'nielsen',
#   900: 'nieb',
#   903: 'aplicación',
#   906: 'métodos',
#   908: 'evaluación',
#   910: 'usabilidad',
#   912: 'evaluadores',
#   913: 'hacen',
#   914: 'uso',
#   917: 'conjunto',
#   919: 'técnicas',
#   920: 'diseñadas',
#   923: 'recolección',
#   925: 'datos',
#   927: 'usabilidad',
#   929: 'definidas',
#   931: 'términos',
#   933: 'método',
#   935: 'soportan',
#   937: 'aplicabilidad',
#   940: 'diferentes',
#   941: 'etapas',
#   943: 'desarrollo',
#   944: 'costos',
#   946: 'número',
#   948: 'participantes',
#   949: 'necesarios',
#   952: 'obtención',
#   955: 'información',
#   956: 'focus',
#   957: 'group',
#   958: 'niec',
#   959: 'think',
#   960: 'aloud',
#   961: 'bor',
#   962: 'cuestionarios',
#   966: 'importante',
#   967: 'establecer',
#   970: 'igual',
#   974: 'métodos',
#   976: 'necesario',
#   977: 'seleccionar',
#   979: 'técnicas',
#   981: 'adecuadas',
#   983: 'función',
#   986: 'características',
#   988: 'fortalezas',
#   989: 'así',
#   991: 'combinarlos',
#   992: 'adecuadamente',
#   995: 'obtención',
#   998: 'mayor',
#   999: 'cantidad',
#   1001: 'información',
#   1004: 'segura',
#   1006: 'confiable',
#   1008: 'ahora',
#   1011: 'desarrollado',
#   1012: 'muchas',
#   1013: 'herramientas',
#   1015: 'soporte',
#   1018: 'aplicación',
#   1020: 'determinados',
#   1021: 'métodos',
#   1023: 'evaluación',
#   1025: 'usabilidad',
#   1027: 'aunque',
#   1030: 'basadas',
#   1033: 'mismo',
#   1034: 'método',
#   1036: 'utilizan',
#   1037: 'técnicas',
#   1038: 'comunes',
#   1041: 'colección',
#   1043: 'datos',
#   1047: 'logrado',
#   1048: 'establecer',
#   1050: 'acuerdo',
#   1051: 'respecto',
#   1054: 'criterios',
#   1056: 'evaluación',
#   1061: 'respecto',
#   1064: 'estándares',
#   1065: 'establecidos',
#   1068: 'mayoría',
#   1071: 'desarrolladas',
#   1073: 'dar',
#   1074: 'soporte',
#   1077: 'evaluación',
#   1080: 'aplicación',
#   1081: 'particular',
#   1084: 'contexto',
#   1086: 'específico',
#   1087: 'principalmente',
#   1088: 'aplicaciones',
#   1089: 'comerciales',
#   1092: 'actualidad',
#   1095: 'desarrollado',
#   1097: 'metodologías',
#   1099: 'evaluar',
#   1101: 'usabilidad',
#   1103: 'aplicaciones',
#   1104: 'basadas',
#   1106: 'web',
#   1109: 'mayoría',
#   1110: 'orientadas',
#   1111: 'principalmente',
#   1113: 'sitios',
#   1114: 'comerciales',
#   1117: 'situación',
#   1118: 'creemos',
#   1119: 'necesario',
#   1121: 'modelo',
#   1123: 'evaluación',
#   1125: 'usabilidad',
#   1126: 'orientada',
#   1127: 'específicamente',
#   1130: 'aplicaciones',
#   1131: 'educativas',
#   1132: 'basadas',
#   1134: 'web',
#   1136: 'contemple',
#   1138: 'objetivos',
#   1139: 'propios',
#   1142: 'dominio',
#   1144: 'aspectos',
#   1147: 'necesidades',
#   1150: 'audiencia',
#   1151: 'destino',
#   1154: 'perfil',
#   1156: 'usuario'},
#  'Problema3': {1: 'debido',
#   5: 'redes',
#   7: 'sensores',
#   8: 'inalambricas',
#   11: 'campo',
#   13: 'pleno',
#   14: 'desarrollo',
#   17: 'operacion',
#   19: 'servicios',
#   21: 'autenticidad',
#   24: 'comunicaciones',
#   27: 'problema',
#   32: 'resuelto',
#   34: 'forma',
#   35: 'definitiva',
#   39: 'naturaleza',
#   41: 'operacion',
#   43: 'dichas',
#   44: 'redes',
#   45: 'presenta',
#   46: 'requerimientos',
#   47: 'específicos',
#   49: 'escalabilidad',
#   51: 'flexibilidad',
#   54: 'diseño',
#   56: 'cualquier',
#   57: 'control',
#   59: 'seguridad',
#   61: 'llego',
#   63: 'determinar',
#   65: 'siguiente',
#   67: 'problema',
#   69: 'resolver',
#   72: 'busqueda',
#   75: 'mecanismo',
#   77: 'permita',
#   79: 'uso',
#   81: 'operaciones',
#   83: 'criptografía',
#   84: 'asimetrica',
#   87: 'ambiente',
#   89: 'redes',
#   91: 'sensores',
#   93: 'operar',
#   95: 'forma',
#   96: 'eficiente',
#   98: 'protocolo',
#   100: 'autenticacion',
#   102: 'permita',
#   103: 'explotar',
#   105: 'características',
#   107: 'flexibilidad',
#   109: 'escalabilidad',
#   111: 'dicho'},
#  'Problema4': {3: 'red',
#   4: 'celular',
#   5: 'diseñar',
#   7: 'protocolo',
#   10: 'generación',
#   12: 'distribución',
#   14: 'llaves',
#   17: 'comunicacion',
#   18: 'multimedia',
#   19: 'multipartita',
#   20: 'segura',
#   21: 'requiere',
#   22: 'consideraciones',
#   23: 'adicionales',
#   27: 'red',
#   28: 'fija',
#   29: 'tales',
#   30: 'consideraciones',
#   31: 'estan',
#   33: 'función',
#   36: 'características',
#   39: 'multimedia',
#   42: 'características',
#   45: 'comunicacion',
#   47: 'grupo',
#   48: 'segura',
#   51: 'arquitectura',
#   54: 'red',
#   55: 'celular',
#   58: 'modo',
#   60: 'comunicacion',
#   62: 'considerar',
#   64: 'ello',
#   65: 'abordamos',
#   67: 'problema',
#   69: 'cuatro',
#   70: 'puntos',
#   72: 'vista',
#   73: 'primero',
#   74: 'consideramos',
#   76: 'caracteíísticas',
#   77: 'necesarias',
#   79: 'garantizar',
#   82: 'comunicacion',
#   84: 'grupo',
#   85: 'segura',
#   86: 'segundo',
#   88: 'toman',
#   90: 'cuenta',
#   92: 'problemas',
#   94: 'surgen',
#   95: 'debido',
#   98: 'características',
#   101: 'arquitectura',
#   104: 'red',
#   105: 'celular',
#   106: 'tercero',
#   108: 'consideran',
#   109: 'aspectos',
#   110: 'relacionados',
#   112: 'uso',
#   115: 'comunicacion',
#   116: 'asíncrona',
#   117: 'cuarto',
#   118: 'consideramos',
#   120: 'características'},
#  'Problema5': {2: 'aprendizaje',
#   4: 'refuerzo',
#   7: 'aplicado',
#   9: 'resolver',
#   10: 'problemas',
#   12: 'varias',
#   13: 'disciplinas',
#   14: 'incluyendo',
#   15: 'aplicaciones',
#   16: 'recientes',
#   19: 'robótica',
#   21: 'retos',
#   22: 'actuales',
#   23: 'principales',
#   25: 'aprendizaje',
#   27: 'refuerzo',
#   30: 'exploración',
#   33: 'ambiente',
#   34: 'real',
#   35: 'consume',
#   37: 'tiempo',
#   39: 'conocimiento',
#   40: 'obtenido',
#   42: 'limita',
#   44: 'resolver',
#   45: 'solamente',
#   47: 'tarea',
#   48: 'apren',
#   49: 'dida',
#   51: 'dominios',
#   52: 'probados',
#   57: 'arte',
#   60: 'dinámicas',
#   61: 'simples',
#   63: 'dilema',
#   64: 'exploraciónexplotación',
#   69: 'ocupado',
#   72: 'investi',
#   73: 'gadores',
#   76: 'área',
#   78: 'aprendizaje',
#   80: 'refuerzo',
#   82: 'técnicas',
#   85: 'inclinado',
#   87: 'algoritmos',
#   89: 'encuentren',
#   91: 'correcto',
#   92: 'balance',
#   95: 'exploración',
#   98: 'explotación',
#   101: 'aprendizaje',
#   104: 'ello',
#   105: 'hallar',
#   107: 'buena',
#   108: 'política',
#   111: 'tiempo',
#   112: 'reducido',
#   113: 'u',
#   114: 'na',
#   115: 'solución',
#   116: 'alternativa',
#   118: 'permite',
#   119: 'reutilizar',
#   121: 'conocimiento',
#   123: 'tareas',
#   124: 'similares',
#   126: 'así',
#   127: 'reducir',
#   129: 'tiempo',
#   131: 'aprendizaje',
#   134: 'tarea',
#   135: 'objetivo',
#   138: 'transferencia',
#   140: 'conocimiento',
#   142: 'anos',
#   143: 'recientes',
#   146: 'hecho',
#   147: 'avances',
#   149: 'algoritmos',
#   151: 'transferir',
#   152: 'di',
#   153: 'ferentes',
#   154: 'tipos',
#   156: 'conocimiento',
#   158: 'tareas',
#   160: 'aprendizaje',
#   162: 'refuerzo',
#   164: 'embargo',
#   166: 'mayoría',
#   169: 'trabajos',
#   172: 'centrado',
#   174: 'tareas',
#   177: 'natu',
#   178: 'raleza',
#   179: 'discreta',
#   181: 'trabajo',
#   183: 'aquí',
#   185: 'propone',
#   187: 'enfoca',
#   190: 'transferencia',
#   192: 'conoci',
#   193: 'miento',
#   195: 'problemas',
#   197: 'dinámicas',
#   198: 'complejas',
#   201: 'espacios',
#   205: 'acciones',
#   206: 'continuos',
#   207: 'usando',
#   209: 'representación',
#   210: 'cualitativa',
#   211: 'compacta',
#   213: 'gene',
#   214: 'ralizada',
#   215: 'adquirida',
#   218: 'aprendizaje',
#   221: 'primera',
#   222: 'tarea',
#   223: 'relacionada',
#   225: 'aplicada',
#   227: 'guía',
#   230: 'aprendizaje',
#   233: 'tarea',
#   234: 'objetivo',
#   237: 'pocos',
#   239: 'trabajos',
#   242: 'hecho',
#   243: 'transferencia',
#   245: 'tareas',
#   248: 'continuos',
#   249: 'taylor',
#   250: 'et',
#   253: 'lazaric',
#   254: 'et',
#   258: 'nulos',
#   260: 'tareas',
#   262: 'acciones',
#   263: 'continuas',
#   265: 'tal',
#   266: 'situación',
#   268: 'hace',
#   269: 'visible',
#   271: 'importancia',
#   274: 'trabajo',
#   275: 'cuyo',
#   276: 'objetivo',
#   278: 'transferir',
#   279: 'información',
#   280: 'cualitativa',
#   282: 'tareas',
#   284: 'espacios',
#   288: 'acción',
#   289: 'continuos',
#   291: 'ventaja',
#   294: 'abstracción',
#   295: 'cualitativa',
#   298: 'enfoques',
#   301: 'gene',
#   302: 'ralidad',
#   305: 'representación',
#   307: 'acciones',
#   310: 'así',
#   313: 'representación',
#   314: 'compacta',
#   316: 'conocimiento',
#   319: 'tarea',
#   321: 'razonamiento',
#   322: 'cualitativo',
#   324: 'abs',
#   325: 'tracciones',
#   326: 'cualitativas',
#   329: 'empleados',
#   331: 'representar',
#   332: 'funciones',
#   333: 'cuali',
#   334: 'tativas',
#   336: 'procesos',
#   338: 'control',
#   339: 'mugan',
#   341: 'suc',
#   345: 'usado',
#   347: 'representar',
#   348: 'reglas',
#   351: 'aprendizaje',
#   353: 'refuerzo',
#   354: 'mugan',
#   355: 'and',
#   356: 'kuipers',
#   358: 'mugan',
#   363: 'momento',
#   367: 'desarro',
#   368: 'llado',
#   369: 'trabajos',
#   371: 'transferencia',
#   373: 'información',
#   374: 'cualitativa',
#   376: 'aprendizaje',
#   378: 'refuerzo',
#   383: 'objetivo',
#   385: 'persigue',
#   387: 'trabajo',
#   390: 'tarea',
#   393: 'agente',
#   395: 'arriesga',
#   397: 'hacer',
#   398: 'exploración',
#   400: 'deseable',
#   401: 'tener',
#   403: 'desempeno',
#   404: 'inicial',
#   406: 'ejecutarse',
#   408: 'primeros',
#   409: 'episodios',
#   411: 'aprendi',
#   412: 'zaje',
#   414: 'correr',
#   415: 'menos',
#   416: 'riesgo',
#   418: 'realizar',
#   419: 'acciones',
#   420: 'peligrosas',
#   422: 'aprendizaje',
#   424: 'refuerzo',
#   426: 'métrica',
#   428: 'mejor',
#   429: 're',
#   430: 'eja',
#   431: 'tal',
#   432: 'comportamiento',
#   434: 'jumpstart',
#   438: 'literatura',
#   439: 'revisada',
#   442: 'encontraron',
#   443: 'trabajos',
#   446: 'cuáles',
#   448: 'centraran',
#   450: 'esfuerzos',
#   452: 'generar',
#   454: 'alto',
#   455: 'valor',
#   457: 'jumpstart',
#   458: 'excepto',
#   461: 'trabajo',
#   463: 'lazaric',
#   464: 'lazaric',
#   465: 'et',
#   469: 'trabajo',
#   471: 'aquí',
#   473: 'propone',
#   475: 'enfoca',
#   477: 'generar',
#   479: 'valor',
#   481: 'jumpstart',
#   482: 'suficientemente',
#   483: 'alto',
#   485: 'guíar',
#   487: 'exploración',
#   489: 'reducir',
#   491: 'riesgo',
#   493: 'explorar',
#   494: 'acciones',
#   495: 'peligrosas',
#   496: 'evitando',
#   498: 'transferencia',
#   499: 'negativa',
#   503: 'trabajos',
#   505: 'transferencia',
#   507: 'aprendizaje',
#   509: 'refuerzo',
#   513: 'encontrado',
#   516: 'literatura',
#   519: 'probados',
#   522: 'autores',
#   524: 'simulaciones',
#   528: 'objetivos',
#   530: 'trabajo',
#   531: 'propuesto',
#   533: 'hacer',
#   534: 'validaciones',
#   536: 'transferencia',
#   538: 'conocimiento',
#   541: 'problema',
#   543: 'robótica',
#   544: 'complejo',
#   546: 'alta',
#   547: 'dimensionalidad',
#   548: 'dinámica',
#   549: 'nolineal',
#   551: 'estocasticidad',
#   555: 'volar',
#   557: 'manera',
#   558: 'autónoma'},
#  'Problema6': {2: 'algoritmo',
#   4: 'clasificación',
#   5: 'supervisada',
#   6: 'basado',
#   9: 'búsqueda',
#   11: 'vecino',
#   13: 'cercano',
#   14: 'nn',
#   15: 'cover',
#   18: 'ampliamente',
#   19: 'utilizado',
#   20: 'debido',
#   23: 'simplicidad',
#   25: 'capacidad',
#   27: 'resolver',
#   28: 'problemas',
#   29: 'complejos',
#   31: 'reconocimiento',
#   33: 'patrones',
#   35: 'algoritmo',
#   37: 'basado',
#   40: 'conjunto',
#   42: 'objetos',
#   44: 'entrenamiento',
#   45: 't',
#   46: 'previamente',
#   47: 'clasificado',
#   48: 't',
#   50: 'zi',
#   53: 'lt',
#   54: 'i',
#   55: 'ltn',
#   58: 'n',
#   61: 'número',
#   63: 'objetos',
#   65: 'objeto',
#   66: 'zi',
#   68: 'descrito',
#   70: 'd',
#   71: 'atributos',
#   74: 'espacio',
#   75: 'rd',
#   76: 'zi',
#   78: 'xzi',
#   79: 'xzi',
#   80: 'xdzi',
#   82: 'dado',
#   84: 'nuevo',
#   85: 'objeto',
#   86: 'q',
#   88: 'clasificar',
#   90: 'objetivo',
#   92: 'clasificador',
#   94: 'encontrar',
#   96: 'objeto',
#   97: 'onn',
#   100: 'conjunto',
#   101: 't',
#   103: 'minimice',
#   105: 'función',
#   107: 'distancia',
#   108: 'dist',
#   111: 'objeto',
#   112: 'q',
#   113: 'omn',
#   115: 'mindist',
#   116: 'ztzi',
#   117: 'q',
#   120: 'encontrar',
#   121: 'onn',
#   123: 'requiere',
#   125: 'comparación',
#   126: 'exhaustiva',
#   128: 'q',
#   130: 'cada',
#   131: 'objeto',
#   133: 'conjunto',
#   134: 't',
#   136: 'vez',
#   137: 'encontrado',
#   139: 'vecino',
#   141: 'cercano',
#   143: 'asigna',
#   145: 'clase',
#   148: 'objeto',
#   150: 'q',
#   152: 'generalización',
#   155: 'método',
#   158: 'algoritmo',
#   160: 'k',
#   161: 'vecinos',
#   163: 'cercanos',
#   164: 'knn',
#   167: 'caso',
#   169: 'búsqueda',
#   171: 'realiza',
#   174: 'misma',
#   175: 'forma',
#   178: 'nn',
#   179: 'salvo',
#   182: 'lugar',
#   184: 'encontrar',
#   186: 'sólo',
#   187: 'objeto',
#   189: 'buscan',
#   191: 'k',
#   193: 'cercanos',
#   194: 'finalmente',
#   196: 'clase',
#   198: 'objeto',
#   199: 'q',
#   201: 'elige',
#   203: 'votación',
#   206: 'k',
#   207: 'objetos',
#   209: 'cercanos',
#   211: 'diagrama',
#   213: 'algoritmo',
#   214: 'nn',
#   216: 'muestra',
#   219: 'figura',
#   222: 'algoritmo',
#   224: 'clasificación',
#   225: 'basado',
#   228: 'búsqueda',
#   230: 'vecino',
#   232: 'cercano',
#   235: 'aplicado',
#   238: 'problemas',
#   239: 'aparte',
#   242: 'clasificación',
#   243: 'tal',
#   246: 'caso',
#   248: 'estimación',
#   250: 'densidad',
#   251: 'chen',
#   252: 'compresión',
#   254: 'datos',
#   255: 'gersho',
#   256: 'recuperación',
#   258: 'información',
#   259: 'deerwester',
#   260: 'reconocimiento',
#   262: 'caracteres',
#   263: 'stelios',
#   264: 'cuantización',
#   266: 'vectores',
#   267: 'chen',
#   270: 'aplicaciones',
#   272: 'mencionadas',
#   273: 'dicho',
#   274: 'algoritmo',
#   276: 'clasificación',
#   278: 'presentado',
#   280: 'buen',
#   281: 'desempeño',
#   283: 'embargo',
#   284: 'comparar',
#   286: 'nuevo',
#   287: 'objeto',
#   288: 'q',
#   292: 'elementos',
#   294: 'conjunto',
#   295: 't',
#   296: 'implica',
#   298: 'alto',
#   299: 'costo',
#   301: 'tiempo',
#   303: 't',
#   306: 'grande',
#   309: 'razón',
#   312: 'últimos',
#   313: 'años',
#   316: 'propuesto',
#   317: 'métodos',
#   319: 'hacer',
#   321: 'rápida',
#   323: 'búsqueda',
#   325: 'mayoría',
#   328: 'cuales',
#   329: 'omiten',
#   330: 'comparaciones',
#   332: 'base',
#   334: 'propiedades',
#   335: 'métricas',
#   338: 'función'},
#  'Problema7': {2: 'efectividad',
#   5: 'representación',
#   7: 'documentos',
#   9: 'directamente',
#   10: 'relacionada',
#   13: 'exactitud',
#   18: 'conjunto',
#   20: 'términos',
#   21: 'seleccionados',
#   22: 'representa',
#   24: 'contenido',
#   27: 'documento',
#   30: 'cuán',
#   31: 'bien',
#   33: 'puede',
#   34: 'contrastar',
#   36: 'contenido',
#   38: 'dicho',
#   39: 'documento',
#   43: 'decir',
#   44: 'dados',
#   45: 'dos',
#   46: 'documentos',
#   47: 'd',
#   49: 'd',
#   52: 'representaciones',
#   53: 'r',
#   55: 'r',
#   56: 'respectivamente',
#   57: 'si',
#   58: 'r',
#   60: 'igual',
#   62: 'r',
#   64: 'significa',
#   67: 'contenido',
#   69: 'r',
#   71: 'igual',
#   73: 'contenido',
#   75: 'r',
#   77: 'cierto',
#   78: 'nivel',
#   80: 'abstracción',
#   82: 'cuanto',
#   85: 'representación',
#   87: 'contenido',
#   89: 'bolsa',
#   91: 'palabras',
#   93: 'insuficiente',
#   96: 'palabras',
#   97: 'aisladas',
#   100: 'específicas',
#   102: 'efectuar',
#   104: 'discriminación',
#   105: 'adecuada',
#   107: 'documentos',
#   111: 'método',
#   113: 'apropiado',
#   117: 'mencionado',
#   119: 'identificar',
#   120: 'grupos',
#   122: 'palabras',
#   124: 'significado',
#   126: 'denoten',
#   127: 'conceptos',
#   129: 'relaciones',
#   133: 'trabajo',
#   136: 'presente',
#   137: 'investigación',
#   139: 'utilidad',
#   142: 'representación',
#   143: 'resultante',
#   145: 'comprobada',
#   147: 'ri',
#   149: 'tal',
#   150: 'motivo',
#   152: 'continuación',
#   154: 'presenta',
#   156: 'descripción',
#   158: 'dicha',
#   159: 'tarea',
#   161: 'recuperación',
#   163: 'información',
#   164: 'ri',
#   166: 'interesa',
#   168: 'seleccionar',
#   170: 'grandes',
#   171: 'volúmenes',
#   173: 'texto',
#   174: 'aquellos',
#   175: 'documentos',
#   177: 'contienen',
#   178: 'información',
#   179: 'relevante',
#   181: 'acuerdo',
#   184: 'necesidades',
#   186: 'información',
#   187: 'expresadas',
#   190: 'usuario',
#   192: 'ri',
#   193: 'incluye',
#   194: 'dos',
#   195: 'actividades',
#   196: 'principales',
#   197: 'indexar',
#   199: 'buscar',
#   201: 'primera',
#   203: 'refiere',
#   205: 'representar',
#   207: 'contenido',
#   210: 'documentos',
#   213: 'solicitud',
#   215: 'información',
#   217: 'emite',
#   219: 'usuario',
#   221: 'segunda',
#   224: 'forma',
#   226: 'examinar',
#   228: 'representación',
#   231: 'documentos',
#   233: 'respecto',
#   236: 'petición',
#   238: 'información',
#   240: 'proporcionar',
#   242: 'respuesta',
#   245: 'resulten',
#   247: 'mayor',
#   248: 'relevancia',
#   250: 'riqueza',
#   251: 'inherente',
#   253: 'lenguaje',
#   256: 'diversidad',
#   259: 'manera',
#   261: 'expresar',
#   263: 'necesidades',
#   265: 'información',
#   267: 'parte',
#   270: 'usuarios',
#   271: 'ocasionan',
#   274: 'operaciones',
#   276: 'indexar',
#   279: 'buscar',
#   280: 'nunca',
#   281: 'recuperen',
#   282: 'información',
#   284: 'manera',
#   285: 'perfecta',
#   287: 'puede',
#   288: 'ser',
#   290: 'caso',
#   293: 'manejadores',
#   295: 'bases',
#   297: 'datos',
#   303: 'necesario',
#   304: 'establecer',
#   305: 'métodos',
#   306: 'cuantitativos',
#   307: 'funciones',
#   309: 'relevancia',
#   311: 'evaluar',
#   313: 'forma',
#   314: 'aproximada',
#   316: 'similitud',
#   319: 'consulta',
#   322: 'documentos',
#   324: 'entonces',
#   325: 'determinar',
#   326: 'cuáles',
#   327: 'recuperar',
#   329: 'modelo',
#   331: 'ri',
#   333: 'define',
#   336: 'representación',
#   339: 'da',
#   342: 'documentos',
#   345: 'consultas',
#   346: 'objetivo',
#   349: 'investigación',
#   352: 'función',
#   354: 'relevancia',
#   357: 'emplea',
#   359: 'compararlos',
#   360: 'ahora',
#   361: 'bien',
#   362: 'dada',
#   364: 'solicitud',
#   366: 'información',
#   368: 'ejemplo',
#   370: 'interesado',
#   372: 'mecanismos',
#   374: 'comunicación',
#   376: 'procesos',
#   377: 'disjuntos',
#   378: 'posiblemente',
#   381: 'exclusivamente',
#   383: 'ambientes',
#   384: 'distribuidos',
#   385: 'preferiría',
#   386: 'ver',
#   387: 'descripciones',
#   389: 'mecanismos',
#   390: 'completos',
#   394: 'implementación',
#   396: 'lugar',
#   398: 'trabajos',
#   399: 'teóricos',
#   401: 'problema',
#   402: 'llamada',
#   404: 'procedimientos',
#   405: 'remotos',
#   407: 'paso',
#   409: 'mensajes',
#   411: 'ejemplos',
#   414: 'interés',
#   416: 'podemos',
#   417: 'observar',
#   419: 'existen',
#   420: 'palabras',
#   422: 'descripciones',
#   423: 'mecanismos',
#   424: 'implementación',
#   426: 'problema',
#   428: 'deberían',
#   430: 'presentes',
#   433: 'documentos',
#   434: 'recuperados',
#   436: 'manteniendo',
#   438: 'relación',
#   439: 'expresada',
#   443: 'buscan',
#   444: 'descripciones',
#   446: 'mecanismos',
#   448: 'comunicación',
#   450: 'procesos',
#   451: 'si',
#   452: 'empleamos',
#   454: 'manera',
#   455: 'aislada',
#   457: 'palabras',
#   458: 'mencionadas',
#   461: 'ignoradas',
#   464: 'generalidad',
#   466: 'crear',
#   468: 'índice',
#   470: 'si',
#   472: 'incluyen',
#   475: 'índice',
#   476: 'conducirán',
#   478: 'recuperar',
#   479: 'gran',
#   480: 'cantidad',
#   482: 'documentos',
#   483: 'irrelevantes',
#   486: 'recupera',
#   488: 'grupo',
#   490: 'documentos',
#   492: 'encontrará',
#   499: 'relevantes',
#   503: 'relevantes',
#   507: 'recuperado',
#   509: 'éxito',
#   512: 'recuperación',
#   514: 'establece',
#   515: 'mediante',
#   516: 'dos',
#   517: 'métricas',
#   519: 'precisión',
#   523: 'razón',
#   526: 'documentos',
#   527: 'relevantes',
#   528: 'recuperados',
#   531: 'total',
#   533: 'documentos',
#   534: 'recuperados',
#   537: 'recuerdo',
#   539: 'razón',
#   541: 'número',
#   543: 'documentos',
#   544: 'relevantes',
#   545: 'recuperados',
#   548: 'total',
#   550: 'documentos',
#   551: 'relevantes',
#   552: 'existentes',
#   555: 'colección',
#   558: 'área',
#   560: 'recuperación',
#   562: 'información',
#   564: 'continúa',
#   565: 'experimentando',
#   567: 'nuevos',
#   568: 'modelos',
#   571: 'ende',
#   572: 'nuevas',
#   573: 'representaciones',
#   575: 'documentos',
#   577: 'intentar',
#   578: 'cubrir',
#   580: 'mayor',
#   581: 'precisión',
#   583: 'necesidades',
#   585: 'información',
#   588: 'usuarios',
#   592: 'especificado',
#   594: 'centraremos',
#   596: 'ri',
#   598: 'si',
#   600: 'desea',
#   601: 'obtener',
#   602: 'mejoras',
#   603: 'substanciales',
#   604: 'debe',
#   605: 'empezarse',
#   607: 'pensar',
#   609: 'allá',
#   612: 'aproximación',
#   614: 'bolsa',
#   616: 'palabras',
#   618: 'precisiones',
#   619: 'típicamente',
#   621: 'debajo',
#   626: 'margen',
#   628: 'mejorar',
#   632: 'siguiente',
#   633: 'sección',
#   635: 'presentan',
#   636: 'trabajos',
#   638: 'describen',
#   639: 'modelos',
#   640: 'clásicos',
#   642: 'nuevos',
#   644: 'recuperación',
#   646: 'información',
#   648: 'concluir',
#   650: 'métodos',
#   652: 'explotan',
#   654: 'obtención',
#   656: 'relaciones',
#   657: 'empleando',
#   658: 'técnicas',
#   660: 'procesamiento',
#   662: 'lenguaje',
#   663: 'natural',
#   665: 'realizar',
#   666: 'recuperación'},
#  'Problema8': {1: 'debido',
#   3: 'vertiginoso',
#   4: 'ritmo',
#   6: 'aparición',
#   8: 'posicionamiento',
#   11: 'tecnologías',
#   15: 'nivel',
#   18: 'comunicaciones',
#   23: 'tráfico',
#   26: 'cometido',
#   27: 'diversos',
#   28: 'errores',
#   30: 'cuanto',
#   33: 'generación',
#   36: 'contenidos',
#   37: 'publicados',
#   40: 'web',
#   43: 'forma',
#   48: 'transmitidos',
#   51: 'usuarios',
#   53: 'errores',
#   55: 'constituido',
#   56: 'duplicidad',
#   58: 'esfuerzos',
#   60: 'desarrollar',
#   61: 'diversas',
#   62: 'aplicaciones',
#   64: 'diferentes',
#   65: 'administradores',
#   68: 'estandarización',
#   70: 'base',
#   72: 'generalmente',
#   73: 'asociada',
#   76: 'desarrollo',
#   78: 'contenidos',
#   79: 'basados',
#   81: 'lenguajes',
#   83: 'marcado',
#   85: 'html',
#   88: 'dificultado',
#   89: 'procesos',
#   90: 'deseables',
#   93: 'compartir',
#   95: 'información',
#   97: 'tratar',
#   99: 'vocabularios',
#   101: 'comunes',
#   104: 'diferentes',
#   105: 'elementos',
#   106: 'involucrados',
#   110: 'final',
#   111: 'dan',
#   113: 'resultado',
#   115: 'percepción',
#   117: 'parte',
#   119: 'usuario',
#   121: 'información',
#   122: 'diversa',
#   124: 'difusa',
#   126: 'continuación',
#   128: 'describen',
#   129: 'cada',
#   133: 'problemas',
#   135: 'bajo',
#   137: 'perspectiva',
#   138: 'caracterizan',
#   140: 'problemática',
#   143: 'difusión',
#   145: 'información',
#   147: 'tráfico',
#   148: 'vía',
#   149: 'web',
#   150: 'problema',
#   152: 'ausencia',
#   154: 'vocabularios',
#   155: 'comunes',
#   158: 'desarrollo',
#   161: 'distintas',
#   162: 'aplicaciones',
#   164: 'tráfico',
#   166: 'característico',
#   168: 'ausencia',
#   170: 'vocabularios',
#   171: 'comunes',
#   173: 'puedan',
#   174: 'ser',
#   175: 'elegidos',
#   177: 'núcleo',
#   179: 'punto',
#   181: 'partida',
#   183: 'desarrolladores',
#   185: 'contenidos',
#   187: 'ejemplo',
#   190: 'caso',
#   193: 'aplicaciones',
#   195: 'gestión',
#   197: 'incidencias',
#   199: 'tráfico',
#   201: 'existen',
#   202: 'tales',
#   203: 'vocabularios',
#   204: 'comunes',
#   207: 'asociados',
#   210: 'descriptores',
#   212: 'metadatos',
#   215: 'información',
#   217: 'deben',
#   219: 'desarrollar',
#   221: 'aplicaciones',
#   226: 'desarrolladores',
#   227: 'pueden',
#   228: 'llegar',
#   230: 'describir',
#   232: 'información',
#   234: 'ejemplo',
#   237: 'vehículos',
#   238: 'implicados',
#   241: 'accidente',
#   243: 'diferente',
#   244: 'forma',
#   245: 'inclusive',
#   247: 'desarrolladores',
#   250: 'misma',
#   251: 'empresa',
#   253: 'desarrollo',
#   256: 'aún',
#   258: 'diferentes',
#   259: 'administraciones',
#   261: 'países',
#   262: 'problema',
#   264: 'múltiples',
#   265: 'fuentes',
#   267: 'formatos',
#   268: 'existe',
#   270: 'distribución',
#   271: 'inherente',
#   274: 'datos',
#   276: 'información',
#   277: 'repartidos',
#   279: 'fuentes',
#   281: 'diversas',
#   283: 'bases',
#   285: 'datos',
#   287: 'portales',
#   288: 'web',
#   291: 'incluso',
#   293: 'documentos',
#   294: 'públicos',
#   295: 'aportados',
#   298: 'diferentes',
#   299: 'entidades',
#   300: 'aparecen',
#   302: 'formatos',
#   303: 'tan',
#   304: 'diversos',
#   306: 'puedan',
#   307: 'ser',
#   308: 'html',
#   309: 'xml',
#   310: 'wml',
#   311: 'voicexml',
#   312: 'etc',
#   316: 'vez',
#   317: 'dicha',
#   318: 'información',
#   319: 'debe',
#   320: 'ser',
#   321: 'tratada',
#   323: 'diferentes',
#   324: 'usuarios',
#   326: 'puedan',
#   327: 'ser',
#   329: 'propias',
#   330: 'administraciones',
#   332: 'tráfico',
#   336: 'conductores',
#   338: 'viajeros',
#   341: 'dominio',
#   344: 'its',
#   346: 'tratamiento',
#   349: 'información',
#   352: 'consecuencias',
#   355: 'tratamiento',
#   358: 'toma',
#   360: 'decisiones',
#   363: 'simple',
#   364: 'consulta',
#   367: 'tipo',
#   369: 'información',
#   374: 'fecha',
#   375: 'altamente',
#   376: 'dependientes',
#   378: 'conocimiento',
#   379: 'humano',
#   380: 'problema',
#   382: 'gran',
#   383: 'volumen',
#   385: 'información',
#   386: 'distribuido',
#   388: 'difusión',
#   390: 'información',
#   392: 'tráfico',
#   393: 'abarca',
#   395: 'gran',
#   396: 'abanico',
#   398: 'posibilidades',
#   400: 'hacen',
#   403: 'tratamiento',
#   406: 'información',
#   408: 'deba',
#   409: 'abordar',
#   411: 'manera',
#   412: 'eficaz',
#   414: 'usuario',
#   416: 've',
#   417: 'obligado',
#   419: 'tratar',
#   422: 'gran',
#   423: 'volumen',
#   425: 'información',
#   427: 'aparece',
#   430: 'vez',
#   431: 'distribuida',
#   434: 'diferentes',
#   435: 'portales',
#   436: 'web',
#   438: 'administraciones',
#   440: 'entidades',
#   441: 'privadas',
#   444: 'ofrecen',
#   447: 'vez',
#   449: 'aparición',
#   451: 'múltiples',
#   452: 'dispositivos',
#   454: 'usuario',
#   455: 'final',
#   457: 'dado',
#   458: 'lugar',
#   463: 'punto',
#   465: 'vista',
#   467: 'usuario',
#   470: 'gran',
#   471: 'dificultad',
#   473: 'encontrar',
#   475: 'lugares',
#   477: 'tratar',
#   480: 'diferentes',
#   481: 'representaciones',
#   483: 'accesos',
#   486: 'información',
#   487: 'problema',
#   489: 'imposibilidad',
#   491: 'almacenaje',
#   493: 'toda',
#   495: 'información',
#   498: 'parte',
#   500: 'usuario',
#   501: 'puede',
#   502: 'necesitar',
#   503: 'información',
#   505: 'diferente',
#   506: 'naturaleza',
#   512: 'almacenaje',
#   514: 'toda',
#   516: 'información',
#   519: 'solo',
#   520: 'sitio',
#   521: 'web',
#   524: 'viable',
#   526: 'nivel',
#   528: 'costes',
#   530: 'almacenamiento',
#   532: 'incluso',
#   534: 'nivel',
#   536: 'mantenimiento',
#   537: 'problema',
#   539: 'carencia',
#   541: 'descripciones',
#   542: 'semánticas',
#   545: 'servicios',
#   546: 'web',
#   547: 'tal',
#   551: 'describe',
#   554: 'problema',
#   557: 'vocabularios',
#   559: 'lenguajes',
#   561: 'describen',
#   562: 'conceptos',
#   564: 'estructuras',
#   566: 'datos',
#   567: 'relacionados',
#   569: 'tráfico',
#   570: 'suelen',
#   571: 'ser',
#   572: 'ad',
#   573: 'hoc',
#   575: 'cada',
#   576: 'aplicación',
#   578: 'además',
#   579: 'descripciones',
#   581: 'tipo',
#   582: 'sintáctico',
#   583: 'carentes',
#   585: 'semántica',
#   588: 'llegó',
#   590: 'búsqueda',
#   592: 'revisión',
#   593: 'bibliográfica',
#   596: 'tesis',
#   599: 'encontraron',
#   600: 'ontologías',
#   602: 'vocabularios',
#   604: 'valor',
#   605: 'semántico',
#   607: 'aporten',
#   608: 'significado',
#   611: 'conceptos',
#   614: 'relaciones',
#   615: 'tampoco',
#   617: 'conoce',
#   620: 'existencia',
#   622: 'servicios',
#   623: 'web',
#   624: 'sw',
#   626: 'información',
#   628: 'tráfico',
#   629: 'problema',
#   631: 'solamente',
#   633: 'posible',
#   634: 'obtener',
#   635: 'conocimiento',
#   636: 'explícito',
#   638: 'problema',
#   640: 'derivado',
#   642: 'anterior',
#   644: 'tratamiento',
#   647: 'información',
#   649: 'permite',
#   650: 'realizar',
#   651: 'inferencias',
#   655: 'manera',
#   657: 'pueda',
#   658: 'ser',
#   659: 'obtenida',
#   661: 'resultado',
#   662: 'información',
#   665: 'priori',
#   668: 'explícitamente'},
#  'Problema9': {2: 'minería',
#   4: 'texto',
#   7: 'área',
#   9: 'investigación',
#   11: 'reciente',
#   13: 'procesamiento',
#   15: 'textos',
#   18: 'define',
#   21: 'proceso',
#   23: 'descubrimiento',
#   25: 'patrones',
#   26: 'interesantes',
#   29: 'colección',
#   31: 'textos',
#   33: 'patrones',
#   35: 'deben',
#   37: 'existir',
#   38: 'explícitamente',
#   40: 'ningún',
#   41: 'texto',
#   44: 'colección',
#   46: 'deben',
#   48: 'surgir',
#   50: 'relacionar',
#   52: 'contenido',
#   54: 'varios',
#   57: 'hearst',
#   59: 'kodratoff',
#   62: 'proceso',
#   64: 'minería',
#   66: 'texto',
#   67: 'consiste',
#   69: 'dos',
#   70: 'etapas',
#   71: 'principales',
#   73: 'etapa',
#   75: 'preprocesamiento',
#   78: 'etapa',
#   80: 'descubrimiento',
#   81: 'tan',
#   85: 'primera',
#   86: 'etapa',
#   88: 'textos',
#   90: 'transforman',
#   92: 'algún',
#   93: 'tipo',
#   95: 'representación',
#   96: 'estructurada',
#   98: 'semiestructurada',
#   100: 'facilite',
#   102: 'posterior',
#   103: 'análisis',
#   104: 'mientras',
#   108: 'segunda',
#   109: 'etapa',
#   111: 'representaciones',
#   112: 'intermedias',
#   114: 'analizan',
#   117: 'objetivo',
#   119: 'descubrir',
#   123: 'patrones',
#   124: 'interesantes',
#   126: 'nuevos',
#   127: 'conocimiento',
#   128: 'entonces',
#   129: 'dependiendo',
#   131: 'tipo',
#   133: 'métodos',
#   134: 'aplicados',
#   137: 'etapa',
#   139: 'preprocesamiento',
#   142: 'tipo',
#   144: 'representaciones',
#   145: 'intermedias',
#   146: 'construidas',
#   149: 'función',
#   151: 'dicha',
#   152: 'representación',
#   155: 'tipo',
#   157: 'métodos',
#   158: 'usados',
#   161: 'etapa',
#   163: 'descubrimiento',
#   166: 'consecuencia',
#   168: 'tipo',
#   170: 'patrones',
#   171: 'descubiertos',
#   173: 'figura',
#   175: 'muestra',
#   177: 'principales',
#   178: 'estrategias',
#   179: 'usadas',
#   182: 'actuales',
#   183: 'sistemas',
#   185: 'minería',
#   187: 'texto',
#   189: 'acuerdo',
#   192: 'figura',
#   194: 'mayoría',
#   197: 'actuales',
#   199: 'minería',
#   201: 'texto',
#   202: 'limitan',
#   204: 'resultados',
#   207: 'nivel',
#   208: 'temático',
#   211: 'entidad',
#   216: 'imposibilitan',
#   218: 'descubrimiento',
#   220: 'cosas',
#   222: 'detalladas',
#   225: 'consensos',
#   228: 'ejemplo',
#   229: 'respondan',
#   231: 'preguntas',
#   234: 'cuál',
#   237: 'opinión',
#   238: 'mayoritaria',
#   241: 'mexicanos',
#   244: 'gobierno',
#   246: 'fox',
#   248: 'tendencias',
#   250: 'indiquen',
#   252: 'ejemplo',
#   253: 'si',
#   255: 'existido',
#   256: 'variaciones',
#   259: 'postura',
#   261: 'fox',
#   263: 'respecto',
#   266: 'educación',
#   268: 'desviaciones',
#   270: 'identifiquen',
#   272: 'ejemplo',
#   273: 'opiniones',
#   274: 'raras',
#   276: 'respecto',
#   278: 'desempeño',
#   281: 'selección',
#   282: 'mexicana',
#   284: 'fútbol',
#   286: 'idea',
#   288: 'mejorar',
#   290: 'expresividad',
#   293: 'diversidad',
#   296: 'descubrimientos',
#   299: 'sistemas',
#   301: 'minería',
#   303: 'textos',
#   304: 'consiste',
#   306: 'usar',
#   308: 'representación',
#   310: 'contenido',
#   313: 'textos',
#   315: 'completa',
#   318: 'representaciones',
#   319: 'usadas',
#   320: 'actualmente',
#   321: 'siguiendo',
#   323: 'enfoque',
#   326: 'investigación',
#   328: 'propone',
#   329: 'usar',
#   331: 'grafos',
#   332: 'conceptuales',
#   333: 'sowa',
#   337: 'representación',
#   339: 'contenido',
#   342: 'textos',
#   344: 'grafos',
#   345: 'conceptuales',
#   347: 'seleccionaron',
#   351: 'representaciones',
#   353: 'ejemplo',
#   354: 'árboles',
#   355: 'sintácticos',
#   356: 'predicados',
#   357: 'lógicos',
#   359: 'klone',
#   362: 'siguientes',
#   363: 'razones',
#   366: 'grafos',
#   367: 'conceptuales',
#   368: 'permiten',
#   369: 'representar',
#   370: 'adecuadamente',
#   372: 'términos',
#   374: 'expresividad',
#   376: 'eficiencia',
#   377: 'notacional',
#   379: 'información',
#   381: 'lenguaje',
#   382: 'natural',
#   385: 'grafos',
#   386: 'conceptuales',
#   387: 'disponen',
#   389: 'mecanismos',
#   390: 'formales',
#   392: 'facilitan',
#   394: 'manipulación',
#   395: 'transformación',
#   397: 'análisis',
#   398: 'ver',
#   399: 'sección',
#   403: 'grafos',
#   404: 'conceptuales',
#   406: 'usan',
#   409: 'tareas',
#   410: 'afines',
#   413: 'minería',
#   415: 'texto',
#   417: 'ejemplo',
#   420: 'recuperación',
#   422: 'información',
#   426: 'agrupamiento',
#   428: 'textos',
#   429: 'ahora',
#   430: 'bien',
#   431: 'realizar',
#   433: 'minería',
#   435: 'texto',
#   436: 'usando',
#   438: 'grafos',
#   439: 'conceptuales',
#   441: 'representación',
#   443: 'contenido',
#   446: 'textos',
#   447: 'involucra',
#   448: 'dos',
#   449: 'problemas',
#   450: 'diferentes',
#   452: 'primer',
#   453: 'lugar',
#   455: 'transformación',
#   458: 'textos',
#   460: 'grafos',
#   461: 'conceptuales',
#   464: 'segundo',
#   465: 'lugar',
#   467: 'análisis',
#   468: 'automático',
#   471: 'conjunto',
#   473: 'grafos',
#   474: 'conceptuales',
#   476: 'transformación',
#   479: 'textos',
#   481: 'grafos',
#   482: 'conceptuales',
#   485: 'problema',
#   486: 'complejo',
#   487: 'vinculado',
#   490: 'análisis',
#   491: 'sintáctico',
#   493: 'semántico',
#   494: 'sowa',
#   495: 'and',
#   496: 'way',
#   498: 'sowa',
#   500: 'debido',
#   502: 'ello',
#   505: 'métodos',
#   507: 'existen',
#   509: 'realizar',
#   510: 'dicha',
#   511: 'transformación',
#   513: 'enfocan',
#   516: 'dominio',
#   517: 'único',
#   519: 'restringido',
#   521: 'ejemplos',
#   524: 'siguientes',
#   526: 'partes',
#   528: 'artículos',
#   529: 'científicos',
#   531: 'grafos',
#   532: 'conceptuales',
#   533: 'myaeng',
#   534: 'and',
#   535: 'khoo',
#   537: 'lópezlópez',
#   539: 'montesygómez',
#   541: 'montesygómez',
#   542: 'et',
#   546: 'partes',
#   548: 'expedientes',
#   549: 'médicos',
#   551: 'grafos',
#   552: 'conceptuales',
#   553: 'baud',
#   554: 'et',
#   557: 'rassinoux',
#   558: 'et',
#   562: 'partes',
#   564: 'casos',
#   565: 'legales',
#   567: 'grafos',
#   568: 'conceptuales',
#   569: 'boucier',
#   570: 'and',
#   571: 'rajman',
#   574: 'partes',
#   576: 'manuales',
#   578: 'referencia',
#   580: 'grafos',
#   581: 'conceptuales',
#   582: 'petermann',
#   586: 'parte',
#   588: 'análisis',
#   589: 'automático',
#   592: 'conjunto',
#   594: 'grafos',
#   595: 'conceptuales',
#   596: 'orientado',
#   598: 'descubrimiento',
#   600: 'patrones',
#   601: 'descriptivos',
#   602: 'nuevos',
#   603: 'conocimientos',
#   606: 'problema',
#   608: 'estudiado',
#   609: 'mineau',
#   610: 'and',
#   611: 'godin',
#   613: 'godin',
#   614: 'et',
#   617: 'bournaud',
#   618: 'and',
#   619: 'ganascia',
#   621: 'bournaud',
#   622: 'and',
#   623: 'ganascia',
#   625: 'míller',
#   627: 'así',
#   628: 'pues',
#   630: 'trabajo',
#   632: 'investigación',
#   634: 'enfoca',
#   637: 'análisis',
#   640: 'conjunto',
#   642: 'grafos',
#   643: 'conceptuales',
#   645: 'representan',
#   647: 'contenido',
#   650: 'conjunto',
#   652: 'textos',
#   656: 'descubrimiento',
#   658: 'varios',
#   659: 'tipos',
#   661: 'patrones',
#   662: 'interesantes',
#   664: 'ejemplo',
#   665: 'agrupamientos',
#   666: 'asociaciones'},
#  'Problema10': {2: 'objetivo',
#   5: 'desambiguación',
#   8: 'sentidos',
#   11: 'palabras',
#   13: 'determinar',
#   15: 'significado',
#   16: 'correcto',
#   19: 'sentido',
#   22: 'palabra',
#   23: 'dada',
#   26: 'contexto',
#   29: 'consi',
#   30: 'dera',
#   35: 'problemas',
#   37: 'difíciles',
#   40: 'nivel',
#   41: 'léxico',
#   43: 'procesamiento',
#   45: 'lenguaje',
#   46: 'natural',
#   51: 'fundamental',
#   53: 'aplicaciones',
#   55: 'traducción',
#   56: 'automática',
#   57: 'recuperación',
#   59: 'información',
#   60: 'etc',
#   62: 'dificultades',
#   63: 'provienen',
#   66: 'orígenes',
#   67: 'incluyendo',
#   69: 'falta',
#   71: 'medios',
#   73: 'formalizar',
#   75: 'propiedades',
#   77: 'parámetros',
#   79: 'contexto',
#   81: 'caracterizan',
#   83: 'uso',
#   86: 'pa',
#   87: 'labra',
#   88: 'ambigua',
#   91: 'sentido',
#   93: 'particular',
#   96: 'falta',
#   99: 'inventario',
#   101: 'sentidos',
#   102: 'usuales',
#   105: 'enfoques',
#   107: 'existen',
#   109: 'wsd',
#   112: 'aprendizaje',
#   113: 'supervisado',
#   117: 'exitoso',
#   120: 'fecha',
#   125: 'emplea',
#   127: 'corpus',
#   131: 'cada',
#   132: 'ocurrencia',
#   135: 'palabra',
#   136: 'ambigua',
#   137: 'w',
#   140: 'manualmente',
#   141: 'anotada',
#   144: 'sentido',
#   145: 'correcto',
#   147: 'acuer',
#   148: 'do',
#   151: 'existencia',
#   153: 'sentidos',
#   156: 'diccionario',
#   159: 'forma',
#   161: 'corpus',
#   162: 'sirve',
#   164: 'material',
#   166: 'entrenamiento',
#   169: 'algoritmo',
#   171: 'aprendizaje',
#   172: 'cuyo',
#   173: 'resultado',
#   176: 'modelo',
#   177: 'automáticamente',
#   178: 'aprendido',
#   181: 'puede',
#   182: 'ser',
#   183: 'usado',
#   185: 'atribuir',
#   187: 'sentido',
#   189: 'corpus',
#   190: 'empleados',
#   193: 'tarea',
#   195: 'clasificación',
#   196: 'supervisada',
#   197: 'requieren',
#   199: 'gran',
#   200: 'cantidad',
#   201: 'ejemplos',
#   203: 'cada',
#   204: 'sentido',
#   207: 'palabra',
#   209: 'requisito',
#   210: 'hace',
#   212: 'enfoque',
#   214: 'pervisado',
#   215: 'impracticable',
#   217: 'tratar',
#   219: 'desambiguar',
#   220: 'todas',
#   222: 'palabras',
#   225: 'textos',
#   227: 'problema',
#   230: 'llamado',
#   231: 'obstáculo',
#   233: 'adquisición',
#   235: 'conocimientos',
#   239: 'reconocido',
#   242: 'mejor',
#   243: 'manera',
#   244: 'adquirir',
#   245: 'etiquetas',
#   247: 'sentidos',
#   250: 'pa',
#   251: 'labras',
#   254: 'corpus',
#   257: 'mano',
#   260: 'embargo',
#   262: 'formulación',
#   263: 'manual',
#   265: 'inventarios',
#   267: 'sentidos',
#   270: 'basada',
#   273: 'intuición',
#   276: 'lexicógrafos',
#   280: 'visto',
#   281: 'afectada',
#   283: 'problemas',
#   285: 'incluyen',
#   287: 'alto',
#   288: 'costo',
#   290: 'asignación',
#   291: 'arbitraria',
#   293: 'significado',
#   295: 'palabras',
#   298: 'emparejamiento',
#   299: 'equivocado',
#   301: 'dominios',
#   303: 'aplicación',
#   305: 'debido',
#   308: 'anteriores',
#   309: 'inconvenientes',
#   311: 'acercamientos',
#   313: 'supervisados',
#   315: 're',
#   316: 'cibido',
#   317: 'mucha',
#   318: 'atención',
#   321: 'últimos',
#   322: 'años',
#   323: 'pues',
#   326: 'potencial',
#   328: 'superar',
#   330: 'cuello',
#   332: 'botella',
#   334: 'adquisición',
#   336: 'sentidos',
#   340: 'conseguido',
#   343: 'introducción',
#   345: 'sentido',
#   348: 'palabra',
#   349: 'directamente',
#   351: 'corpus',
#   353: 'embargo',
#   356: 'parece',
#   358: 'simple',
#   359: 'vista',
#   361: 'ventaja',
#   362: 'constituye',
#   365: 'principal',
#   366: 'desventaja',
#   368: 'desambiguación',
#   370: 'lleva',
#   372: 'cabo',
#   373: 'partiendo',
#   376: 'conjunto',
#   379: 'bien',
#   380: 'definido',
#   382: 'sentidos',
#   385: 'conlle',
#   386: 'va',
#   388: 'muchas',
#   389: 'ocasiones',
#   392: 'obtención',
#   394: 'resultados',
#   395: 'pobres',
#   398: 'proceso'},
#  'Problema11': {2: 'área',
#   4: 'reconocimiento',
#   5: 'automático',
#   7: 'emociones',
#   11: 'área',
#   13: 'investigación',
#   15: 'activa',
#   18: 'últimos',
#   19: 'años',
#   21: 'obstante',
#   22: 'aun',
#   26: 'solución',
#   27: 'clara',
#   30: 'problema',
#   31: 'diversos',
#   32: 'inconvenientes',
#   34: 'influido',
#   37: 'construcción',
#   40: 'solución',
#   41: 'apropiada',
#   44: 'lado',
#   46: 'factor',
#   48: 'afecta',
#   50: 'desempeño',
#   53: 'reconocedores',
#   55: 'emociones',
#   57: 'contextos',
#   58: 'reales',
#   61: 'dificultad',
#   63: 'generar',
#   64: 'bases',
#   66: 'datos',
#   68: 'emociones',
#   69: 'espontáneas',
#   70: 'generalmente',
#   73: 'trabajado',
#   75: 'bases',
#   77: 'datos',
#   78: 'actuadas',
#   80: 'cuales',
#   81: 'proporcionan',
#   82: 'retratos',
#   84: 'emociones',
#   85: 'representando',
#   86: 'expresiones',
#   87: 'prototípicas',
#   89: 'intensas',
#   91: 'facilitan',
#   93: 'búsqueda',
#   95: 'correlación',
#   96: 'acústica',
#   99: 'subsecuente',
#   100: 'clasificación',
#   101: 'automática',
#   103: 'embargo',
#   108: 'buenos',
#   109: 'resultados',
#   111: 'trasladar',
#   113: 'conocimiento',
#   114: 'extraído',
#   117: 'bases',
#   119: 'datos',
#   121: 'contextos',
#   122: 'reales',
#   123: 'steidl',
#   126: 'características',
#   129: 'bases',
#   131: 'datos',
#   132: 'actuadas',
#   136: 'retratos',
#   138: 'emociones',
#   139: 'representando',
#   140: 'expresiones',
#   141: 'prototípicas',
#   143: 'intensas',
#   144: 'facilitan',
#   146: 'búsqueda',
#   148: 'correlación',
#   149: 'acústica',
#   152: 'subsecuente',
#   153: 'clasificación',
#   154: 'automática',
#   157: 'grabaciones',
#   159: 'estudio',
#   161: 'alta',
#   162: 'calidad',
#   163: 'eliminan',
#   164: 'problemas',
#   167: 'procesamiento',
#   170: 'señal',
#   172: 'ejemplo',
#   173: 'ruido',
#   175: 'reverberación',
#   178: 'puede',
#   179: 'garantizar',
#   181: 'cantidad',
#   182: 'balanceada',
#   184: 'ejemplos',
# ...
#   451: 'habilidad',
#   453: 'aprender',
#   455: 'adaptarse',
#   457: 'tiempo',
#   459: 'ejecución',
#   461: 'proceso',
#   467: 'ejemplo',
#   468: 'narendra',
#   470: 'parthasarathy',
#   472: 'demuestran',
#   475: 'redes',
#   476: 'neurales',
#   477: 'pueden',
#   478: 'ser',
#   479: 'usadas',
#   480: 'efectivamente',
#   483: 'identificación',
#   485: 'control',
#   487: 'procesos',
#   488: 'dinámicos',
#   490: 'lineales',
#   492: 'problema',
#   495: 'control',
#   497: 'mecanismos',
#   500: 'determinación',
#   502: 'modelo',
#   503: 'dinámico',
#   508: 'difícil',
#   510: 'obtener',
#   512: 'modelo',
#   513: 'dinámico',
#   515: 'sistema',
#   520: 'desconocimiento',
#   523: 'parámetros',
#   525: 'modelo',
#   531: 'dinámicas',
#   533: 'redes',
#   534: 'neuronales',
#   537: 'clase',
#   539: 'sistemas',
#   540: 'adaptativos',
#   544: 'útiles',
#   546: 'tales',
#   547: 'situaciones',
#   550: 'pueden',
#   551: 'adaptarse',
#   554: 'dinámica',
#   556: 'sistema',
#   559: 'desconoce',
#   561: 'controladores',
#   562: 'neuronales',
#   564: 'aprendizaje',
#   567: 'proceso',
#   568: 'permiten',
#   569: 'controlar',
#   571: 'sistemas',
#   572: 'dinámicos',
#   575: 'necesidad',
#   578: 'entrenamiento',
#   579: 'previo',
#   582: 'red',
#   583: 'neuronal',
#   584: 'además',
#   586: 'desempeño',
#   589: 'red',
#   590: 'neuronal',
#   593: 'sujeto',
#   596: 'entrenamiento',
#   597: 'realizado',
#   600: 'conjunto',
#   602: 'datos',
#   603: 'delimitados',
#   605: 'controlador',
#   606: 'basado',
#   608: 'retroalimentación',
#   610: 'confiable',
#   611: 'si',
#   614: 'respaldado',
#   617: 'estudio',
#   619: 'estabilidad',
#   621: 'importante',
#   622: 'notar',
#   625: 'trabajos',
#   627: 'investigación',
#   629: 'controladores',
#   630: 'neuronales',
#   635: 'literatura',
#   639: 'estudio',
#   641: 'estabilidad',
#   643: 'sistema',
#   644: 'dinámico',
#   646: 'lazo',
#   647: 'cerrado',
#   652: 'confiabilidad',
#   655: 'controladores',
#   656: 'propuestos',
#   658: 'degradada',
#   660: 'redes',
#   661: 'neuronales',
#   664: 'control',
#   666: 'sistemas',
#   667: 'subastados',
#   670: 'campo',
#   672: 'conocimiento',
#   674: 'necesita',
#   675: 'trabajo',
#   677: 'investigación',
#   679: 'encuentran',
#   680: 'trabajos',
#   682: 'investigación',
#   685: 'control',
#   687: 'mecanismos',
#   689: 'pendubot',
#   690: 'acrobot',
#   691: 'péndulo',
#   693: 'furuta',
#   695: 'péndulo',
#   697: 'rueda',
#   698: 'inercial',
#   701: 'trabajos',
#   705: 'estudio',
#   707: 'estabilidad',
#   710: 'si',
#   713: 'problema',
#   715: 'seguimiento',
#   717: 'trayectorias',
#   718: 'además',
#   720: 'importante',
#   721: 'conocer',
#   723: 'desempeño',
#   726: 'controladores',
#   727: 'neuronales',
#   730: 'clase',
#   732: 'sistemas'},
#  'Problema32': {2: 'incremento',
#   4: 'potencia',
#   6: 'crucial',
#   8: 'alcanzar',
#   10: 'relación',
#   11: 'señal',
#   13: 'ruido',
#   14: 'deseada',
#   17: 'receptor',
#   21: 'señal',
#   23: 'pudiera',
#   24: 'ser',
#   25: 'detectable',
#   28: 'hacer',
#   29: 'posible',
#   31: 'comunicación',
#   32: 'inalámbrica',
#   35: 'amplio',
#   36: 'ancho',
#   38: 'banda',
#   40: 'necesario',
#   41: 'basarse',
#   43: 'esquemas',
#   45: 'multiplexación',
#   46: 'complejos',
#   48: 'acceso',
#   49: 'múltiple',
#   51: 'división',
#   53: 'código',
#   55: 'banda',
#   56: 'ancha',
#   57: 'wcdma',
#   59: 'multiplexación',
#   61: 'división',
#   63: 'frecuencias',
#   64: 'ortogonales',
#   65: 'ofdm',
#   68: 'técnicas',
#   70: 'modulación',
#   76: 'modulación',
#   78: 'amplitud',
#   80: 'cuadratura',
#   81: 'qam',
#   83: 'incluso',
#   85: 'modulación',
#   87: 'desplazamiento',
#   89: 'fase',
#   90: 'qpsk',
#   92: 'momento',
#   94: 'transmitir',
#   95: 'altas',
#   96: 'tasas',
#   98: 'datos',
#   100: 'produce',
#   102: 'recrecimiento',
#   103: 'espectral',
#   106: 'agregan',
#   107: 'efectos',
#   109: 'memoria',
#   112: 'linealidades',
#   113: 'debido',
#   116: 'características',
#   117: 'intrínsecas',
#   119: 'pa',
#   121: 'pa',
#   124: 'dispositivo',
#   127: 'etapa',
#   129: 'transmisor',
#   131: 'agrega',
#   133: 'mayoría',
#   137: 'linealidades',
#   139: 'efectos',
#   141: 'memoria',
#   142: 'existen',
#   143: 'esfuerzos',
#   146: 'investigación',
#   147: 'basados',
#   149: 'polinomios',
#   151: 'modelos',
#   153: 'toman',
#   155: 'cuenta',
#   157: 'memoria',
#   160: 'basados',
#   162: 'redes',
#   163: 'neuronales',
#   165: 'embargo',
#   167: 'existe',
#   169: 'plataforma',
#   170: 'completa',
#   171: 'capaz',
#   173: 'emular',
#   175: 'hardware',
#   176: 'comportamientos',
#   177: 'adecuados',
#   179: 'pas',
#   181: 'parta',
#   184: 'mediciones',
#   187: 'curvas',
#   189: 'distorsión',
#   190: 'amam',
#   192: 'ampm',
#   194: 'otorgue',
#   196: 'integración',
#   198: 'modelos',
#   200: 'permitan',
#   201: 'niveles',
#   204: 'linealidad',
#   206: 'orden',
#   208: 'memoria',
#   209: 'variables',
#   211: 'modelos',
#   212: 'polinomiales',
#   214: 'memoria',
#   217: 'aprendizaje',
#   218: 'además',
#   220: 'algoritmos',
#   221: 'adaptativos',
#   223: 'permitan',
#   224: 'modelar',
#   225: 'pas',
#   227: 'comportamientos',
#   229: 'complejos',
#   231: 'pa',
#   234: 'componente',
#   235: 'principal',
#   238: 'consumo',
#   240: 'energía',
#   243: 'etapa',
#   245: 'transmisor',
#   248: 'necesario',
#   249: 'establecer',
#   251: 'compromiso',
#   253: 'linealidad',
#   256: 'eficiencia',
#   258: 'lograr',
#   260: 'propósito',
#   262: 'crucial',
#   263: 'contar',
#   265: 'modelos',
#   267: 'comportamiento',
#   272: 'nivel',
#   273: 'variable',
#   275: 'memoria',
#   279: 'linealidad',
#   281: 'linealización',
#   283: 'pas',
#   286: 'convertido',
#   289: 'área',
#   291: 'gran',
#   292: 'interés',
#   295: 'sistemas',
#   297: 'comunicación',
#   298: 'inalámbrica',
#   299: 'modernos',
#   303: 'requieren',
#   304: 'modelos',
#   306: 'comportamiento',
#   308: 'describan',
#   309: 'fielmente',
#   311: 'funcionamiento',
#   313: 'pa',
#   314: 'cabe',
#   315: 'indicar',
#   317: 'existen',
#   318: 'diversas',
#   319: 'técnicas',
#   321: 'lograr',
#   323: 'proceso',
#   325: 'linealización',
#   328: 'contribuye',
#   330: 'lograr',
#   332: 'eficiencia',
#   334: 'potencia',
#   336: 'pa',
#   338: 'trabajarlo',
#   339: 'linealmente',
#   341: 'mencionar',
#   343: 'métodos',
#   344: 'comúnmente',
#   345: 'utilizados',
#   347: 'encuentra',
#   349: 'prealimentación',
#   351: 'retroalimentación',
#   354: 'predistorsión',
#   355: 'analógica',
#   358: 'modelos',
#   359: 'mencionados',
#   361: 'eficientes',
#   363: 'aplicaciones',
#   365: 'baja',
#   366: 'frecuencia',
#   369: 'frecuencias',
#   370: 'altas',
#   372: 'técnicas',
#   373: 'pueden',
#   374: 'sufrir',
#   375: 'pérdidas',
#   377: 'estabilidad',
#   380: 'efectos',
#   381: 'producidos',
#   385: 'linealidades',
#   388: 'pas',
#   389: 'repercuten',
#   391: 'dos',
#   392: 'maneras',
#   395: 'lado',
#   396: 'causan',
#   397: 'recrecimiento',
#   398: 'espectral',
#   399: 'dando',
#   400: 'lugar',
#   402: 'interferencias',
#   405: 'canales',
#   407: 'transmisión',
#   408: 'adyacentes',
#   409: 'distorsión',
#   412: 'banda',
#   414: 'operación',
#   415: 'asignada',
#   416: 'mientras',
#   420: 'lado',
#   421: 'causan',
#   422: 'distorsión',
#   423: 'dentro',
#   426: 'propia',
#   427: 'banda',
#   429: 'transmisión',
#   430: 'degradando',
#   434: 'tasa',
#   436: 'error',
#   438: 'bits',
#   439: 'ber',
#   442: 'organismos',
#   443: 'reguladores',
#   444: 'fijan',
#   446: 'través',
#   449: 'diferentes',
#   450: 'estándares',
#   452: 'comunicaciones',
#   454: 'niveles',
#   455: 'máximos',
#   456: 'permitidos',
#   458: 'emisión',
#   461: 'banda',
#   462: 'así',
#   466: 'límites',
#   468: 'distorsión',
#   471: 'banda',
#   473: 'ejemplo',
#   474: 'especificando',
#   475: 'porcentajes',
#   476: 'máximos',
#   478: 'error',
#   481: 'constelaciones',
#   483: 'sanciones',
#   485: 'violar',
#   486: 'cualquiera',
#   489: 'especificaciones',
#   492: 'potencia',
#   494: 'transmisión',
#   495: 'emisión',
#   498: 'banda',
#   502: 'multas',
#   503: 'elevadas',
#   505: 'series',
#   507: 'volterra',
#   508: 'pueden',
#   509: 'ser',
#   510: 'usadas',
#   512: 'describir',
#   514: 'sistema',
#   515: 'estable',
#   517: 'lineal',
#   519: 'pérdida',
#   521: 'memoria',
#   524: 'error',
#   525: 'arbitrario',
#   526: 'pequeño',
#   528: 'embargo',
#   530: 'desventajas',
#   531: 'principales',
#   534: 'incremento',
#   535: 'dramático',
#   537: 'número',
#   539: 'parámetros',
#   541: 'respecto',
#   543: 'orden',
#   546: 'linealidad',
#   548: 'profundidad',
#   550: 'memoria',
#   553: 'causa',
#   555: 'incremento',
#   556: 'drástico',
#   559: 'complejidad',
#   561: 'cálculo',
#   563: 'identificación',
#   565: 'parámetros',
#   569: 'razón',
#   573: 'resulta',
#   574: 'altamente',
#   575: 'impráctico',
#   577: 'uso',
#   580: 'series',
#   581: 'completas',
#   583: 'volterra',
#   585: 'representar',
#   586: 'matemáticamente',
#   588: 'comportamiento',
#   590: 'sistemas',
#   592: 'alta',
#   594: 'linealidad',
#   596: 'profundidad',
#   598: 'memoria',
#   603: 'requiere',
#   605: 'uso',
#   607: 'truncaciones',
#   609: 'mpm',
#   610: 'wiener',
#   612: 'hammerstein',
#   615: 'costo',
#   616: 'computacional',
#   619: 'cálculo',
#   622: 'kernels',
#   624: 'cada',
#   625: 'modelo',
#   627: 'reducido',
#   629: 'comparación',
#   632: 'series',
#   633: 'completas',
#   634: 'aunado',
#   636: 'proceso',
#   638: 'modelado',
#   640: 'comportamiento',
#   642: 'pa',
#   646: 'sistema',
#   647: 'completo',
#   649: 'incluya',
#   650: 'diversos',
#   651: 'modelos',
#   653: 'comportamiento',
#   655: 'necesario',
#   656: 'desarrollar',
#   657: 'técnicas',
#   659: 'medición',
#   661: 'bajo',
#   662: 'costo',
#   664: 'métodos',
#   665: 'tradicionales',
#   667: 'medición',
#   669: 'través',
#   672: 'vna',
#   675: 'indispensables',
#   677: 'realizar',
#   679: 'proceso',
#   681: 'linealización',
#   683: 'medición',
#   685: 'fase',
#   687: 'parámetro',
#   689: 'dispersión',
#   690: 's',
#   691: 'provee',
#   693: 'información',
#   696: 'distorsión',
#   698: 'fase',
#   700: 'pa',
#   702: 'embargo',
#   705: 'menciona',
#   706: 'involucra',
#   708: 'costoso',
#   709: 'uso',
#   711: 'equipo',
#   713: 'laboratorio',
#   714: 'además',
#   716: 'instalación',
#   718: 'calibración',
#   719: 'previa',
#   721: 'involucra',
#   722: 'diversas',
#   723: 'consideraciones',
#   726: 'método',
#   727: 'tradicional',
#   729: 'medición',
#   733: 'anterior',
#   735: 'lleva',
#   738: 'necesidad',
#   740: 'contar',
#   743: 'sistema',
#   744: 'digital',
#   745: 'completo',
#   747: 'pueda',
#   748: 'modelar',
#   750: 'curvas',
#   752: 'distorsión',
#   755: 'pa',
#   756: 'estimar',
#   758: 'comportamiento',
#   759: 'si',
#   761: 'pa',
#   763: 'utilizado',
#   765: 'dut',
#   766: 'realizar',
#   768: 'proceso',
#   770: 'modelado',
#   772: 'utilizar',
#   773: 'algoritmos',
#   775: 'aprendizaje',
#   777: 'ann',
#   779: 'anfis',
#   780: 'dado',
#   783: 'obtuvo',
#   784: 'comportamiento',
#   785: 'complejos',
#   787: 'pas',
#   790: 'infinidad',
#   792: 'datos',
#   794: 'estimar',
#   796: 'además',
#   797: 'estimar',
#   799: 'distorsión',
#   801: 'fase',
#   803: 'pa',
#   804: 'usando',
#   806: 'teoría',
#   808: 'transformación',
#   810: 'amplitud',
#   812: 'fase'},
#  'Problema33': {4: 'principales',
#   5: 'problemas',
#   8: 'sistemas',
#   9: 'normales',
#   11: 'sensado',
#   13: 'estructuras',
#   14: 'presentan',
#   18: 'puntuales',
#   20: 'necesitan',
#   21: 'cableado',
#   23: 'protección',
#   25: 'resulta',
#   26: 'pesado',
#   27: 'incrementado',
#   29: 'peso',
#   30: 'total',
#   33: 'estructura',
#   34: 'además',
#   36: 'emplea',
#   37: 'cableado',
#   39: 'alimentación',
#   41: 'energía',
#   45: 'mejor',
#   46: 'caso',
#   48: 'emplean',
#   49: 'baterías',
#   52: 'utiliza',
#   53: 'comunicación',
#   54: 'inalámbrica',
#   55: 'aunado',
#   59: 'ocasiones',
#   61: 'necesita',
#   62: 'colocar',
#   63: 'sensores',
#   65: 'lugares',
#   67: 'difícil',
#   68: 'acceso',
#   69: 'así',
#   71: 'formar',
#   73: 'red',
#   75: 'sensores',
#   77: 'buscar',
#   79: 'mayor',
#   80: 'exactitud',
#   82: 'anterior',
#   83: 'involucra',
#   85: 'sistema',
#   87: 'adquisición',
#   88: 'limitado',
#   91: 'número',
#   93: 'canales',
#   96: 'caso',
#   98: 'requerir',
#   101: 'mayor',
#   102: 'cantidad',
#   104: 'sensores',
#   106: 'necesitará',
#   108: 'varios',
#   109: 'sistemas',
#   111: 'adquisición',
#   113: 'necesario',
#   114: 'entonces',
#   115: 'estudiar',
#   117: 'técnicas',
#   118: 'actuales',
#   120: 'sensado',
#   122: 'emplean',
#   123: 'diferentes',
#   124: 'tipos',
#   126: 'fibras',
#   127: 'ópticas',
#   129: 'estándar',
#   131: 'dopadas',
#   133: 'tierras',
#   134: 'raras',
#   137: 'empleo',
#   139: 'métodos',
#   140: 'menos',
#   141: 'complejos',
#   143: 'permitan',
#   145: 'sensado'},
#  'Problema34': {2: 'visin',
#   3: 'artificial',
#   5: 'segmentacin',
#   7: 'imgenes',
#   10: 'proceso',
#   12: 'particin',
#   15: 'imagen',
#   16: 'digital',
#   18: 'mltiples',
#   19: 'segmentos',
#   20: 'conjuntos',
#   22: 'pxeles',
#   23: 'tambin',
#   24: 'conocidos',
#   26: 'superpxeles',
#   28: 'objetivo',
#   31: 'segmentacin',
#   33: 'simplificar',
#   37: 'cambiar',
#   39: 'representacin',
#   42: 'imagen',
#   47: 'ms',
#   48: 'significativo',
#   50: 'fcil',
#   52: 'analizar',
#   54: 'segmentacin',
#   56: 'imgenes',
#   58: 'utiliza',
#   59: 'normalmente',
#   61: 'localizar',
#   62: 'objetos',
#   64: 'bordes',
#   65: 'regiones',
#   66: 'lneas',
#   67: 'curvas',
#   68: 'etc',
#   70: 'imgenes',
#   71: 'ms',
#   72: 'precisamente',
#   74: 'segmentacin',
#   76: 'imgenes',
#   79: 'proceso',
#   81: 'asignar',
#   83: 'etiqueta',
#   85: 'cada',
#   86: 'pxel',
#   89: 'imagen',
#   91: 'modo',
#   94: 'pxeles',
#   97: 'misma',
#   98: 'etiqueta',
#   99: 'comparten',
#   100: 'ciertas',
#   101: 'caractersticas',
#   102: 'comunes',
#   105: 'resultado',
#   108: 'segmentacin',
#   111: 'conjunto',
#   113: 'segmentos',
#   115: 'cubren',
#   116: 'colectivamente',
#   117: 'toda',
#   119: 'imagen',
#   122: 'conjunto',
#   124: 'contornos',
#   125: 'extrados',
#   128: 'imagen',
#   129: 'ver',
#   130: 'deteccin',
#   132: 'bordes',
#   133: 'cada',
#   137: 'pxeles',
#   140: 'regin',
#   142: 'similar',
#   144: 'respecto',
#   146: 'alguna',
#   147: 'caracterstica',
#   149: 'propiedad',
#   150: 'calculada',
#   153: 'color',
#   155: 'intensidad',
#   158: 'textura',
#   160: 'regiones',
#   161: 'adyacentes',
#   163: 'significativamente',
#   164: 'diferentes',
#   166: 'respecto',
#   169: 'misma',
#   170: 'caracterstica',
#   171: 's',
#   174: 'segmentacin',
#   177: 'imagen',
#   178: 'consiste',
#   181: 'particin',
#   183: 'dicha',
#   184: 'imagen',
#   186: 'diferentes',
#   187: 'regiones',
#   188: 'similares',
#   190: 'alguna',
#   191: 'caracterstica',
#   192: 'predefinida',
#   195: 'seres',
#   196: 'humanos',
#   197: 'usamos',
#   199: 'sentido',
#   200: 'visual',
#   202: 'separar',
#   204: 'entorno',
#   205: 'inmediato',
#   207: 'objetos',
#   208: 'distintos',
#   210: 'esfuerzo',
#   211: 'alguno',
#   213: 'reconocerlos',
#   214: 'guiar',
#   216: 'movimientos',
#   219: 'casi',
#   220: 'todas',
#   222: 'actividades',
#   225: 'vida',
#   226: 'kn',
#   227: 'plataniotis',
#   229: 'anvenetsanopoulos',
#   231: 'p',
#   233: 'traducido',
#   235: 'segmentacin',
#   238: 'caracterstica',
#   239: 'importante',
#   242: 'percepcin',
#   243: 'visual',
#   244: 'humana',
#   247: 'manifiesta',
#   249: 'forma',
#   250: 'espontnea',
#   252: 'natural',
#   253: 'aunque',
#   254: 'estn',
#   255: 'involucrados',
#   256: 'procesos',
#   257: 'complejos',
#   260: 'anlisis',
#   262: 'color',
#   264: 'forma',
#   266: 'movimiento',
#   268: 'textura',
#   269: 'etc',
#   272: 'color',
#   275: 'caracterstica',
#   276: 'visual',
#   277: 'poderosa',
#   279: 'robusta',
#   281: 'diferenciar',
#   283: 'diferentes',
#   284: 'objetos',
#   287: 'imagen',
#   290: 'importante',
#   291: 'fuente',
#   293: 'informacin',
#   296: 'proceso',
#   298: 'segmentacin',
#   300: 'puede',
#   303: 'casos',
#   304: 'ser',
#   305: 'utilizado',
#   307: 'nica',
#   308: 'caracterstica',
#   310: 'nico',
#   311: 'descriptor',
#   314: 'segmentacin',
#   317: 'objetos',
#   319: 'inters',
#   323: 'trabajo',
#   325: 'tesis',
#   327: 'busca',
#   328: 'investigar',
#   331: 'mtodo',
#   332: 'propio',
#   334: 'segmentacin',
#   336: 'color',
#   338: 'imgenes',
#   340: 'color',
#   342: 'mtodo',
#   343: 'slo',
#   344: 'utiliza',
#   346: 'informacin',
#   348: 'color',
#   350: 'realizar',
#   352: 'segmentacin',
#   357: 'considera',
#   360: 'indispensable',
#   361: 'paso',
#   362: 'previo',
#   365: 'reconocimiento',
#   368: 'trabajo',
#   371: 'pretende',
#   372: 'llegar',
#   374: 'reconocimiento',
#   376: 'objetos',
#   378: 'clases',
#   380: 'objetos',
#   381: 'sino',
#   382: 'nicamente',
#   385: 'segmentacin',
#   388: 'imagen',
#   390: 'regiones',
#   391: 'homogneas',
#   393: 'color',
#   395: 'podran',
#   396: 'ser',
#   397: 'utilizadas',
#   399: 'alimentar',
#   401: 'tareas'}}

# %% [markdown]
# ## Create a Dictionary: Justification#-List of Words (Easier to handle)

# %%
TSU_structured = listMeth(TSU_structured)
Lic_structured = listMeth(Lic_structured)
Masters_structured = listMeth(Masters_structured)
Phd_structured = listMeth(Phd_structured)

TSU_structured
Lic_structured
Masters_structured
Phd_structured
# Out:
# {'Problema2': ['gran',
#   'cantidad',
#   'información',
#   'disponible',
#   'internet',
#   'complejidad',
#   'heterogeneidad',
#   'misma',
#   'junto',
#   'distintas',
#   'características',
#   'usuarios',
#   'acceden',
#   'dicha',
#   'información',
#   'así',
#   'gran',
#   'competencia',
#   'existente',
#   'red',
#   'hacen',
#   'crítico',
#   'desarrollo',
#   'aplicaciones',
#   'basadas',
#   'web',
#   'manera',
#   'particular',
#   'sitios',
#   'web',
#   'educativos',
#   'deban',
#   'contemplar',
#   'solo',
#   'aspectos',
#   'funcionalidad',
#   'sino',
#   'usabilidad',
#   'tomando',
#   'cuenta',
#   'aplicaciones',
#   'solo',
#   'deben',
#   'tener',
#   'objetivo',
#   'poner',
#   'disposición',
#   'usuarios',
#   'información',
#   'exacta',
#   'sino',
#   'orientar',
#   'adecuadamente',
#   'usuario',
#   'búsqueda',
#   'adecuando',
#   'caminos',
#   'apropiados',
#   'cada',
#   'usuario',
#   'acuerdo',
#   'objetivos',
#   'conocimientos',
#   'previos',
#   'necesidades',
#   'perfiles',
#   'usabilidad',
#   'contexto',
#   'enmarca',
#   'pregunta',
#   'si',
#   'aplicación',
#   'web',
#   'educativa',
#   'suficientemente',
#   'buena',
#   'satisfacer',
#   'necesidades',
#   'requerimientos',
#   'usuario',
#   'decir',
#   'usabilidad',
#   'corresponde',
#   'variable',
#   'marco',
#   'aceptación',
#   'práctica',
#   'sitio',
#   'web',
#   'educativo',
#   'así',
#   'sitio',
#   'web',
#   'pueda',
#   'ser',
#   'utilizado',
#   'alcanzar',
#   'alguna',
#   'tarea',
#   'cumplir',
#   'criterios',
#   'utilización',
#   'decir',
#   'referido',
#   'funcionalidad',
#   'puede',
#   'hacer',
#   'necesita',
#   'usabilidad',
#   'cuán',
#   'bien',
#   'usuarios',
#   'pueden',
#   'usar',
#   'funcionalidad',
#   'sitio',
#   'web',
#   'usabilidad',
#   'considera',
#   'aspectos',
#   'sitio',
#   'web',
#   'educativo',
#   'usuario',
#   'puede',
#   'interactuar',
#   'principales',
#   'criterios',
#   'evaluación',
#   'aprendizaje',
#   'operabilidad',
#   'comunicación',
#   'contenido',
#   'etc',
#   'ejemplo',
#   'sitio',
#   'debe',
#   'cumplir',
#   'funcionalidad',
#   'presentar',
#   'determinado',
#   'tipo',
#   'contenido',
#   'contenido',
#   'debe',
#   'ser',
#   'presentado',
#   'manera',
#   'atractiva',
#   'sencilla',
#   'usuario',
#   'además',
#   'aprendizaje',
#   'uso',
#   'navegación',
#   'intuitiva',
#   'fácil',
#   'llevar',
#   'cabo',
#   'proceso',
#   'aprendizaje',
#   'rápido',
#   'eficaz',
#   'autores',
#   'investigado',
#   'propuesto',
#   'recomendaciones',
#   'guías',
#   'listas',
#   'comprobación',
#   'principios',
#   'etc',
#   'desarrollo',
#   'aplicaciones',
#   'usables',
#   'niea',
#   'niea',
#   'shn',
#   'bev',
#   'pocos',
#   'evaluación',
#   'usabilidad',
#   'sitios',
#   'web',
#   'educativos',
#   'gon',
#   'car',
#   'embargo',
#   'basta',
#   'hacer',
#   'exploración',
#   'web',
#   'comprobar',
#   'aún',
#   'sigue',
#   'problema',
#   'si',
#   'cuenta',
#   'existe',
#   'diversidad',
#   'dominios',
#   'aplicación',
#   'basadas',
#   'web',
#   'comerciales',
#   'ocio',
#   'entretenimiento',
#   'educación',
#   'etc',
#   'mala',
#   'usabilidad',
#   'sitios',
#   'comerciales',
#   'ocio',
#   'incluso',
#   'noticias',
#   'puede',
#   'significar',
#   'simplemente',
#   'usuario',
#   'busque',
#   'lugar',
#   'embargo',
#   'caso',
#   'sitios',
#   'carácter',
#   'educativo',
#   'problema',
#   'agudiza',
#   'mala',
#   'usabilidad',
#   'puede',
#   'repercutir',
#   'fuertemente',
#   'objetivos',
#   'aprendizaje',
#   'decir',
#   'requisitos',
#   'usabilidad',
#   'sitio',
#   'web',
#   'comercial',
#   'venta',
#   'herramientas',
#   'carpintería',
#   'orientado',
#   'aquellos',
#   'profesionales',
#   'área',
#   'personas',
#   'aficionadas',
#   'carpintería',
#   'cuyo',
#   'interés',
#   'centrado',
#   'encontrar',
#   'producto',
#   'carpintería',
#   'determinado',
#   'mejor',
#   'precio',
#   'diferente',
#   'requisitos',
#   'usabilidad',
#   'sitio',
#   'web',
#   'algún',
#   'curso',
#   'universidad',
#   'institución',
#   'educativa',
#   'principio',
#   'motivaciones',
#   'usuarios',
#   'distintas',
#   'perfil',
#   'así',
#   'metas',
#   'alcanzar',
#   'cada',
#   'así',
#   'preparar',
#   'proceso',
#   'evaluación',
#   'usabilidad',
#   'sitio',
#   'comercial',
#   'mismo',
#   'sitio',
#   'educativo',
#   'aunque',
#   'ambos',
#   'buscan',
#   'cubrir',
#   'servicio',
#   'lograr',
#   'satisfacción',
#   'usuario',
#   'casos',
#   'ambos',
#   'pretendan',
#   'lograr',
#   'dividendos',
#   'económicos',
#   'sitios',
#   'web',
#   'educativos',
#   'añadido',
#   'fundamental',
#   'transmisión',
#   'adquisición',
#   'conocimiento',
#   'ende',
#   'factor',
#   'importante',
#   'evaluación',
#   'aspecto',
#   'educativo',
#   'presentación',
#   'contenidos',
#   'consideración',
#   'usabilidad',
#   'factor',
#   'importante',
#   'desarrollo',
#   'aplicaciones',
#   'web',
#   'ido',
#   'aumento',
#   'últimos',
#   'años',
#   'basándose',
#   'fundamento',
#   'teórico',
#   'usabilidad',
#   'software',
#   'tradicional',
#   'principios',
#   'establecidos',
#   'estándares',
#   'internacionales',
#   'experiencia',
#   'adquirida',
#   'diseño',
#   'desarrollo',
#   'aplicaciones',
#   'web',
#   'desarrollado',
#   'metodologías',
#   'guías',
#   'desarrollo',
#   'aplicaciones',
#   'web',
#   'criterios',
#   'usabilidad',
#   'permiten',
#   'realizar',
#   'proceso',
#   'evaluación',
#   'usabilidad',
#   'limitados',
#   'aspectos',
#   'específicos',
#   'misma',
#   'enfocados',
#   'evaluación',
#   'sitios',
#   'comerciales',
#   'aunque',
#   'señalan',
#   'extensión',
#   'sitios',
#   'educativos',
#   'criterios',
#   'considerados',
#   'ajustan',
#   'requisitos',
#   'usabilidad',
#   'aplicaciones',
#   'actualidad',
#   'existen',
#   'diferentes',
#   'métodos',
#   'pueden',
#   'ser',
#   'usados',
#   'evaluación',
#   'usabilidad',
#   'dependiendo',
#   'propósito',
#   'medición',
#   'tipo',
#   'medida',
#   'obtener',
#   'etapa',
#   'ciclo',
#   'vida',
#   'etc',
#   'u',
#   'usados',
#   'asegurar',
#   'referencias',
#   'mejoren',
#   'usabilidad',
#   'establezcan',
#   'si',
#   'suficientemente',
#   'buena',
#   'desafortunadamente',
#   'acuerdo',
#   'respecto',
#   'denominación',
#   'uso',
#   'aplicación',
#   'métodos',
#   'existentes',
#   'desarrollo',
#   'aplicaciones',
#   'web',
#   'así',
#   'diferentes',
#   'autores',
#   'denominan',
#   'acuerdo',
#   'preferencias',
#   'juicio',
#   'experiencia',
#   'kirakowski',
#   'indagación',
#   'kir',
#   'nielsen',
#   'heurísticas',
#   'nielsen',
#   'nie',
#   'niec',
#   'preece',
#   'evaluación',
#   'expertos',
#   'pre',
#   'scriven',
#   'formativasumativa',
#   'scr',
#   'métodos',
#   'evaluación',
#   'usabilidad',
#   'lado',
#   'fortalezas',
#   'debilidades',
#   'enfocados',
#   'evaluar',
#   'determinados',
#   'aspectos',
#   'requisitos',
#   'usabilidad',
#   'recomendable',
#   'combinarlos',
#   'evaluación',
#   'complementar',
#   'cuanto',
#   'fortalezas',
#   'lograr',
#   'cubrir',
#   'mayor',
#   'número',
#   'aspectos',
#   'evaluación',
#   'selección',
#   'combinación',
#   'métodos',
#   'evaluación',
#   'dependerá',
#   'restricciones',
#   'financieras',
#   'tiempo',
#   'fases',
#   'ciclo',
#   'desarrollo',
#   'naturaleza',
#   'sistema',
#   'bajo',
#   'desarrollo',
#   'bevan',
#   'bev',
#   'nielsen',
#   'nieb',
#   'aplicación',
#   'métodos',
#   'evaluación',
#   'usabilidad',
#   'evaluadores',
#   'hacen',
#   'uso',
#   'conjunto',
#   'técnicas',
#   'diseñadas',
#   'recolección',
#   'datos',
#   'usabilidad',
#   'definidas',
#   'términos',
#   'método',
#   'soportan',
#   'aplicabilidad',
#   'diferentes',
#   'etapas',
#   'desarrollo',
#   'costos',
#   'número',
#   'participantes',
#   'necesarios',
#   'obtención',
#   'información',
#   'focus',
#   'group',
#   'niec',
#   'think',
#   'aloud',
#   'bor',
#   'cuestionarios',
#   'importante',
#   'establecer',
#   'igual',
#   'métodos',
#   'necesario',
#   'seleccionar',
#   'técnicas',
#   'adecuadas',
#   'función',
#   'características',
#   'fortalezas',
#   'así',
#   'combinarlos',
#   'adecuadamente',
#   'obtención',
#   'mayor',
#   'cantidad',
#   'información',
#   'segura',
#   'confiable',
#   'ahora',
#   'desarrollado',
#   'muchas',
#   'herramientas',
#   'soporte',
#   'aplicación',
#   'determinados',
#   'métodos',
#   'evaluación',
#   'usabilidad',
#   'aunque',
#   'basadas',
#   'mismo',
#   'método',
#   'utilizan',
#   'técnicas',
#   'comunes',
#   'colección',
#   'datos',
#   'logrado',
#   'establecer',
#   'acuerdo',
#   'respecto',
#   'criterios',
#   'evaluación',
#   'respecto',
#   'estándares',
#   'establecidos',
#   'mayoría',
#   'desarrolladas',
#   'dar',
#   'soporte',
#   'evaluación',
#   'aplicación',
#   'particular',
#   'contexto',
#   'específico',
#   'principalmente',
#   'aplicaciones',
#   'comerciales',
#   'actualidad',
#   'desarrollado',
#   'metodologías',
#   'evaluar',
#   'usabilidad',
#   'aplicaciones',
#   'basadas',
#   'web',
#   'mayoría',
#   'orientadas',
#   'principalmente',
#   'sitios',
#   'comerciales',
#   'situación',
#   'creemos',
#   'necesario',
#   'modelo',
#   'evaluación',
#   'usabilidad',
#   'orientada',
#   'específicamente',
#   'aplicaciones',
#   'educativas',
#   'basadas',
#   'web',
#   'contemple',
#   'objetivos',
#   'propios',
#   'dominio',
#   'aspectos',
#   'necesidades',
#   'audiencia',
#   'destino',
#   'perfil',
#   'usuario'],
#  'Problema3': ['debido',
#   'redes',
#   'sensores',
#   'inalambricas',
#   'campo',
#   'pleno',
#   'desarrollo',
#   'operacion',
#   'servicios',
#   'autenticidad',
#   'comunicaciones',
#   'problema',
#   'resuelto',
#   'forma',
#   'definitiva',
#   'naturaleza',
#   'operacion',
#   'dichas',
#   'redes',
#   'presenta',
#   'requerimientos',
#   'específicos',
#   'escalabilidad',
#   'flexibilidad',
#   'diseño',
#   'cualquier',
#   'control',
#   'seguridad',
#   'llego',
#   'determinar',
#   'siguiente',
#   'problema',
#   'resolver',
#   'busqueda',
#   'mecanismo',
#   'permita',
#   'uso',
#   'operaciones',
#   'criptografía',
#   'asimetrica',
#   'ambiente',
#   'redes',
#   'sensores',
#   'operar',
#   'forma',
#   'eficiente',
#   'protocolo',
#   'autenticacion',
#   'permita',
#   'explotar',
#   'características',
#   'flexibilidad',
#   'escalabilidad',
#   'dicho'],
#  'Problema4': ['red',
#   'celular',
#   'diseñar',
#   'protocolo',
#   'generación',
#   'distribución',
#   'llaves',
#   'comunicacion',
#   'multimedia',
#   'multipartita',
#   'segura',
#   'requiere',
#   'consideraciones',
#   'adicionales',
#   'red',
#   'fija',
#   'tales',
#   'consideraciones',
#   'estan',
#   'función',
#   'características',
#   'multimedia',
#   'características',
#   'comunicacion',
#   'grupo',
#   'segura',
#   'arquitectura',
#   'red',
#   'celular',
#   'modo',
#   'comunicacion',
#   'considerar',
#   'ello',
#   'abordamos',
#   'problema',
#   'cuatro',
#   'puntos',
#   'vista',
#   'primero',
#   'consideramos',
#   'caracteíísticas',
#   'necesarias',
#   'garantizar',
#   'comunicacion',
#   'grupo',
#   'segura',
#   'segundo',
#   'toman',
#   'cuenta',
#   'problemas',
#   'surgen',
#   'debido',
#   'características',
#   'arquitectura',
#   'red',
#   'celular',
#   'tercero',
#   'consideran',
#   'aspectos',
#   'relacionados',
#   'uso',
#   'comunicacion',
#   'asíncrona',
#   'cuarto',
#   'consideramos',
#   'características'],
#  'Problema5': ['aprendizaje',
#   'refuerzo',
#   'aplicado',
#   'resolver',
#   'problemas',
#   'varias',
#   'disciplinas',
#   'incluyendo',
#   'aplicaciones',
#   'recientes',
#   'robótica',
#   'retos',
#   'actuales',
#   'principales',
#   'aprendizaje',
#   'refuerzo',
#   'exploración',
#   'ambiente',
#   'real',
#   'consume',
#   'tiempo',
#   'conocimiento',
#   'obtenido',
#   'limita',
#   'resolver',
#   'solamente',
#   'tarea',
#   'apren',
#   'dida',
#   'dominios',
#   'probados',
#   'arte',
#   'dinámicas',
#   'simples',
#   'dilema',
#   'exploraciónexplotación',
#   'ocupado',
#   'investi',
#   'gadores',
#   'área',
#   'aprendizaje',
#   'refuerzo',
#   'técnicas',
#   'inclinado',
#   'algoritmos',
#   'encuentren',
#   'correcto',
#   'balance',
#   'exploración',
#   'explotación',
#   'aprendizaje',
#   'ello',
#   'hallar',
#   'buena',
#   'política',
#   'tiempo',
#   'reducido',
#   'u',
#   'na',
#   'solución',
#   'alternativa',
#   'permite',
#   'reutilizar',
#   'conocimiento',
#   'tareas',
#   'similares',
#   'así',
#   'reducir',
#   'tiempo',
#   'aprendizaje',
#   'tarea',
#   'objetivo',
#   'transferencia',
#   'conocimiento',
#   'anos',
#   'recientes',
#   'hecho',
#   'avances',
#   'algoritmos',
#   'transferir',
#   'di',
#   'ferentes',
#   'tipos',
#   'conocimiento',
#   'tareas',
#   'aprendizaje',
#   'refuerzo',
#   'embargo',
#   'mayoría',
#   'trabajos',
#   'centrado',
#   'tareas',
#   'natu',
#   'raleza',
#   'discreta',
#   'trabajo',
#   'aquí',
#   'propone',
#   'enfoca',
#   'transferencia',
#   'conoci',
#   'miento',
#   'problemas',
#   'dinámicas',
#   'complejas',
#   'espacios',
#   'acciones',
#   'continuos',
#   'usando',
#   'representación',
#   'cualitativa',
#   'compacta',
#   'gene',
#   'ralizada',
#   'adquirida',
#   'aprendizaje',
#   'primera',
#   'tarea',
#   'relacionada',
#   'aplicada',
#   'guía',
#   'aprendizaje',
#   'tarea',
#   'objetivo',
#   'pocos',
#   'trabajos',
#   'hecho',
#   'transferencia',
#   'tareas',
#   'continuos',
#   'taylor',
#   'et',
#   'lazaric',
#   'et',
#   'nulos',
#   'tareas',
#   'acciones',
#   'continuas',
#   'tal',
#   'situación',
#   'hace',
#   'visible',
#   'importancia',
#   'trabajo',
#   'cuyo',
#   'objetivo',
#   'transferir',
#   'información',
#   'cualitativa',
#   'tareas',
#   'espacios',
#   'acción',
#   'continuos',
#   'ventaja',
#   'abstracción',
#   'cualitativa',
#   'enfoques',
#   'gene',
#   'ralidad',
#   'representación',
#   'acciones',
#   'así',
#   'representación',
#   'compacta',
#   'conocimiento',
#   'tarea',
#   'razonamiento',
#   'cualitativo',
#   'abs',
#   'tracciones',
#   'cualitativas',
#   'empleados',
#   'representar',
#   'funciones',
#   'cuali',
#   'tativas',
#   'procesos',
#   'control',
#   'mugan',
#   'suc',
#   'usado',
#   'representar',
#   'reglas',
#   'aprendizaje',
#   'refuerzo',
#   'mugan',
#   'and',
#   'kuipers',
#   'mugan',
#   'momento',
#   'desarro',
#   'llado',
#   'trabajos',
#   'transferencia',
#   'información',
#   'cualitativa',
#   'aprendizaje',
#   'refuerzo',
#   'objetivo',
#   'persigue',
#   'trabajo',
#   'tarea',
#   'agente',
#   'arriesga',
#   'hacer',
#   'exploración',
#   'deseable',
#   'tener',
#   'desempeno',
#   'inicial',
#   'ejecutarse',
#   'primeros',
#   'episodios',
#   'aprendi',
#   'zaje',
#   'correr',
#   'menos',
#   'riesgo',
#   'realizar',
#   'acciones',
#   'peligrosas',
#   'aprendizaje',
#   'refuerzo',
#   'métrica',
#   'mejor',
#   're',
#   'eja',
#   'tal',
#   'comportamiento',
#   'jumpstart',
#   'literatura',
#   'revisada',
#   'encontraron',
#   'trabajos',
#   'cuáles',
#   'centraran',
#   'esfuerzos',
#   'generar',
#   'alto',
#   'valor',
#   'jumpstart',
#   'excepto',
#   'trabajo',
#   'lazaric',
#   'lazaric',
#   'et',
#   'trabajo',
#   'aquí',
#   'propone',
#   'enfoca',
#   'generar',
#   'valor',
#   'jumpstart',
#   'suficientemente',
#   'alto',
#   'guíar',
#   'exploración',
#   'reducir',
#   'riesgo',
#   'explorar',
#   'acciones',
#   'peligrosas',
#   'evitando',
#   'transferencia',
#   'negativa',
#   'trabajos',
#   'transferencia',
#   'aprendizaje',
#   'refuerzo',
#   'encontrado',
#   'literatura',
#   'probados',
#   'autores',
#   'simulaciones',
#   'objetivos',
#   'trabajo',
#   'propuesto',
#   'hacer',
#   'validaciones',
#   'transferencia',
#   'conocimiento',
#   'problema',
#   'robótica',
#   'complejo',
#   'alta',
#   'dimensionalidad',
#   'dinámica',
#   'nolineal',
#   'estocasticidad',
#   'volar',
#   'manera',
#   'autónoma'],
#  'Problema6': ['algoritmo',
#   'clasificación',
#   'supervisada',
#   'basado',
#   'búsqueda',
#   'vecino',
#   'cercano',
#   'nn',
#   'cover',
#   'ampliamente',
#   'utilizado',
#   'debido',
#   'simplicidad',
#   'capacidad',
#   'resolver',
#   'problemas',
#   'complejos',
#   'reconocimiento',
#   'patrones',
#   'algoritmo',
#   'basado',
#   'conjunto',
#   'objetos',
#   'entrenamiento',
#   't',
#   'previamente',
#   'clasificado',
#   't',
#   'zi',
#   'lt',
#   'i',
#   'ltn',
#   'n',
#   'número',
#   'objetos',
#   'objeto',
#   'zi',
#   'descrito',
#   'd',
#   'atributos',
#   'espacio',
#   'rd',
#   'zi',
#   'xzi',
#   'xzi',
#   'xdzi',
#   'dado',
#   'nuevo',
#   'objeto',
#   'q',
#   'clasificar',
#   'objetivo',
#   'clasificador',
#   'encontrar',
#   'objeto',
#   'onn',
#   'conjunto',
#   't',
#   'minimice',
#   'función',
#   'distancia',
#   'dist',
#   'objeto',
#   'q',
#   'omn',
#   'mindist',
#   'ztzi',
#   'q',
#   'encontrar',
#   'onn',
#   'requiere',
#   'comparación',
#   'exhaustiva',
#   'q',
#   'cada',
#   'objeto',
#   'conjunto',
#   't',
#   'vez',
#   'encontrado',
#   'vecino',
#   'cercano',
#   'asigna',
#   'clase',
#   'objeto',
#   'q',
#   'generalización',
#   'método',
#   'algoritmo',
#   'k',
#   'vecinos',
#   'cercanos',
#   'knn',
#   'caso',
#   'búsqueda',
#   'realiza',
#   'misma',
#   'forma',
#   'nn',
#   'salvo',
#   'lugar',
#   'encontrar',
#   'sólo',
#   'objeto',
#   'buscan',
#   'k',
#   'cercanos',
#   'finalmente',
#   'clase',
#   'objeto',
#   'q',
#   'elige',
#   'votación',
#   'k',
#   'objetos',
#   'cercanos',
#   'diagrama',
#   'algoritmo',
#   'nn',
#   'muestra',
#   'figura',
#   'algoritmo',
#   'clasificación',
#   'basado',
#   'búsqueda',
#   'vecino',
#   'cercano',
#   'aplicado',
#   'problemas',
#   'aparte',
#   'clasificación',
#   'tal',
#   'caso',
#   'estimación',
#   'densidad',
#   'chen',
#   'compresión',
#   'datos',
#   'gersho',
#   'recuperación',
#   'información',
#   'deerwester',
#   'reconocimiento',
#   'caracteres',
#   'stelios',
#   'cuantización',
#   'vectores',
#   'chen',
#   'aplicaciones',
#   'mencionadas',
#   'dicho',
#   'algoritmo',
#   'clasificación',
#   'presentado',
#   'buen',
#   'desempeño',
#   'embargo',
#   'comparar',
#   'nuevo',
#   'objeto',
#   'q',
#   'elementos',
#   'conjunto',
#   't',
#   'implica',
#   'alto',
#   'costo',
#   'tiempo',
#   't',
#   'grande',
#   'razón',
#   'últimos',
#   'años',
#   'propuesto',
#   'métodos',
#   'hacer',
#   'rápida',
#   'búsqueda',
#   'mayoría',
#   'cuales',
#   'omiten',
#   'comparaciones',
#   'base',
#   'propiedades',
#   'métricas',
#   'función'],
#  'Problema7': ['efectividad',
#   'representación',
#   'documentos',
#   'directamente',
#   'relacionada',
#   'exactitud',
#   'conjunto',
#   'términos',
#   'seleccionados',
#   'representa',
#   'contenido',
#   'documento',
#   'cuán',
#   'bien',
#   'puede',
#   'contrastar',
#   'contenido',
#   'dicho',
#   'documento',
#   'decir',
#   'dados',
#   'dos',
#   'documentos',
#   'd',
#   'd',
#   'representaciones',
#   'r',
#   'r',
#   'respectivamente',
#   'si',
#   'r',
#   'igual',
#   'r',
#   'significa',
#   'contenido',
#   'r',
#   'igual',
#   'contenido',
#   'r',
#   'cierto',
#   'nivel',
#   'abstracción',
#   'cuanto',
#   'representación',
#   'contenido',
#   'bolsa',
#   'palabras',
#   'insuficiente',
#   'palabras',
#   'aisladas',
#   'específicas',
#   'efectuar',
#   'discriminación',
#   'adecuada',
#   'documentos',
#   'método',
#   'apropiado',
#   'mencionado',
#   'identificar',
#   'grupos',
#   'palabras',
#   'significado',
#   'denoten',
#   'conceptos',
#   'relaciones',
#   'trabajo',
#   'presente',
#   'investigación',
#   'utilidad',
#   'representación',
#   'resultante',
#   'comprobada',
#   'ri',
#   'tal',
#   'motivo',
#   'continuación',
#   'presenta',
#   'descripción',
#   'dicha',
#   'tarea',
#   'recuperación',
#   'información',
#   'ri',
#   'interesa',
#   'seleccionar',
#   'grandes',
#   'volúmenes',
#   'texto',
#   'aquellos',
#   'documentos',
#   'contienen',
#   'información',
#   'relevante',
#   'acuerdo',
#   'necesidades',
#   'información',
#   'expresadas',
#   'usuario',
#   'ri',
#   'incluye',
#   'dos',
#   'actividades',
#   'principales',
#   'indexar',
#   'buscar',
#   'primera',
#   'refiere',
#   'representar',
#   'contenido',
#   'documentos',
#   'solicitud',
#   'información',
#   'emite',
#   'usuario',
#   'segunda',
#   'forma',
#   'examinar',
#   'representación',
#   'documentos',
#   'respecto',
#   'petición',
#   'información',
#   'proporcionar',
#   'respuesta',
#   'resulten',
#   'mayor',
#   'relevancia',
#   'riqueza',
#   'inherente',
#   'lenguaje',
#   'diversidad',
#   'manera',
#   'expresar',
#   'necesidades',
#   'información',
#   'parte',
#   'usuarios',
#   'ocasionan',
#   'operaciones',
#   'indexar',
#   'buscar',
#   'nunca',
#   'recuperen',
#   'información',
#   'manera',
#   'perfecta',
#   'puede',
#   'ser',
#   'caso',
#   'manejadores',
#   'bases',
#   'datos',
#   'necesario',
#   'establecer',
#   'métodos',
#   'cuantitativos',
#   'funciones',
#   'relevancia',
#   'evaluar',
#   'forma',
#   'aproximada',
#   'similitud',
#   'consulta',
#   'documentos',
#   'entonces',
#   'determinar',
#   'cuáles',
#   'recuperar',
#   'modelo',
#   'ri',
#   'define',
#   'representación',
#   'da',
#   'documentos',
#   'consultas',
#   'objetivo',
#   'investigación',
#   'función',
#   'relevancia',
#   'emplea',
#   'compararlos',
#   'ahora',
#   'bien',
#   'dada',
#   'solicitud',
#   'información',
#   'ejemplo',
#   'interesado',
#   'mecanismos',
#   'comunicación',
#   'procesos',
#   'disjuntos',
#   'posiblemente',
#   'exclusivamente',
#   'ambientes',
#   'distribuidos',
#   'preferiría',
#   'ver',
#   'descripciones',
#   'mecanismos',
#   'completos',
#   'implementación',
#   'lugar',
#   'trabajos',
#   'teóricos',
#   'problema',
#   'llamada',
#   'procedimientos',
#   'remotos',
#   'paso',
#   'mensajes',
#   'ejemplos',
#   'interés',
#   'podemos',
#   'observar',
#   'existen',
#   'palabras',
#   'descripciones',
#   'mecanismos',
#   'implementación',
#   'problema',
#   'deberían',
#   'presentes',
#   'documentos',
#   'recuperados',
#   'manteniendo',
#   'relación',
#   'expresada',
#   'buscan',
#   'descripciones',
#   'mecanismos',
#   'comunicación',
#   'procesos',
#   'si',
#   'empleamos',
#   'manera',
#   'aislada',
#   'palabras',
#   'mencionadas',
#   'ignoradas',
#   'generalidad',
#   'crear',
#   'índice',
#   'si',
#   'incluyen',
#   'índice',
#   'conducirán',
#   'recuperar',
#   'gran',
#   'cantidad',
#   'documentos',
#   'irrelevantes',
#   'recupera',
#   'grupo',
#   'documentos',
#   'encontrará',
#   'relevantes',
#   'relevantes',
#   'recuperado',
#   'éxito',
#   'recuperación',
#   'establece',
#   'mediante',
#   'dos',
#   'métricas',
#   'precisión',
#   'razón',
#   'documentos',
#   'relevantes',
#   'recuperados',
#   'total',
#   'documentos',
#   'recuperados',
#   'recuerdo',
#   'razón',
#   'número',
#   'documentos',
#   'relevantes',
#   'recuperados',
#   'total',
#   'documentos',
#   'relevantes',
#   'existentes',
#   'colección',
#   'área',
#   'recuperación',
#   'información',
#   'continúa',
#   'experimentando',
#   'nuevos',
#   'modelos',
#   'ende',
#   'nuevas',
#   'representaciones',
#   'documentos',
#   'intentar',
#   'cubrir',
#   'mayor',
#   'precisión',
#   'necesidades',
#   'información',
#   'usuarios',
#   'especificado',
#   'centraremos',
#   'ri',
#   'si',
#   'desea',
#   'obtener',
#   'mejoras',
#   'substanciales',
#   'debe',
#   'empezarse',
#   'pensar',
#   'allá',
#   'aproximación',
#   'bolsa',
#   'palabras',
#   'precisiones',
#   'típicamente',
#   'debajo',
#   'margen',
#   'mejorar',
#   'siguiente',
#   'sección',
#   'presentan',
#   'trabajos',
#   'describen',
#   'modelos',
#   'clásicos',
#   'nuevos',
#   'recuperación',
#   'información',
#   'concluir',
#   'métodos',
#   'explotan',
#   'obtención',
#   'relaciones',
#   'empleando',
#   'técnicas',
#   'procesamiento',
#   'lenguaje',
#   'natural',
#   'realizar',
#   'recuperación'],
#  'Problema8': ['debido',
#   'vertiginoso',
#   'ritmo',
#   'aparición',
#   'posicionamiento',
#   'tecnologías',
#   'nivel',
#   'comunicaciones',
#   'tráfico',
#   'cometido',
#   'diversos',
#   'errores',
#   'cuanto',
#   'generación',
#   'contenidos',
#   'publicados',
#   'web',
#   'forma',
#   'transmitidos',
#   'usuarios',
#   'errores',
#   'constituido',
#   'duplicidad',
#   'esfuerzos',
#   'desarrollar',
#   'diversas',
#   'aplicaciones',
#   'diferentes',
#   'administradores',
#   'estandarización',
#   'base',
#   'generalmente',
#   'asociada',
#   'desarrollo',
#   'contenidos',
#   'basados',
#   'lenguajes',
#   'marcado',
#   'html',
#   'dificultado',
#   'procesos',
#   'deseables',
#   'compartir',
#   'información',
#   'tratar',
#   'vocabularios',
#   'comunes',
#   'diferentes',
#   'elementos',
#   'involucrados',
#   'final',
#   'dan',
#   'resultado',
#   'percepción',
#   'parte',
#   'usuario',
#   'información',
#   'diversa',
#   'difusa',
#   'continuación',
#   'describen',
#   'cada',
#   'problemas',
#   'bajo',
#   'perspectiva',
#   'caracterizan',
#   'problemática',
#   'difusión',
#   'información',
#   'tráfico',
#   'vía',
#   'web',
#   'problema',
#   'ausencia',
#   'vocabularios',
#   'comunes',
#   'desarrollo',
#   'distintas',
#   'aplicaciones',
#   'tráfico',
#   'característico',
#   'ausencia',
#   'vocabularios',
#   'comunes',
#   'puedan',
#   'ser',
#   'elegidos',
#   'núcleo',
#   'punto',
#   'partida',
#   'desarrolladores',
#   'contenidos',
#   'ejemplo',
#   'caso',
#   'aplicaciones',
#   'gestión',
#   'incidencias',
#   'tráfico',
#   'existen',
#   'tales',
#   'vocabularios',
#   'comunes',
#   'asociados',
#   'descriptores',
#   'metadatos',
#   'información',
#   'deben',
#   'desarrollar',
#   'aplicaciones',
#   'desarrolladores',
#   'pueden',
#   'llegar',
#   'describir',
#   'información',
#   'ejemplo',
#   'vehículos',
#   'implicados',
#   'accidente',
#   'diferente',
#   'forma',
#   'inclusive',
#   'desarrolladores',
#   'misma',
#   'empresa',
#   'desarrollo',
#   'aún',
#   'diferentes',
#   'administraciones',
#   'países',
#   'problema',
#   'múltiples',
#   'fuentes',
#   'formatos',
#   'existe',
#   'distribución',
#   'inherente',
#   'datos',
#   'información',
#   'repartidos',
#   'fuentes',
#   'diversas',
#   'bases',
#   'datos',
#   'portales',
#   'web',
#   'incluso',
#   'documentos',
#   'públicos',
#   'aportados',
#   'diferentes',
#   'entidades',
#   'aparecen',
#   'formatos',
#   'tan',
#   'diversos',
#   'puedan',
#   'ser',
#   'html',
#   'xml',
#   'wml',
#   'voicexml',
#   'etc',
#   'vez',
#   'dicha',
#   'información',
#   'debe',
#   'ser',
#   'tratada',
#   'diferentes',
#   'usuarios',
#   'puedan',
#   'ser',
#   'propias',
#   'administraciones',
#   'tráfico',
#   'conductores',
#   'viajeros',
#   'dominio',
#   'its',
#   'tratamiento',
#   'información',
#   'consecuencias',
#   'tratamiento',
#   'toma',
#   'decisiones',
#   'simple',
#   'consulta',
#   'tipo',
#   'información',
#   'fecha',
#   'altamente',
#   'dependientes',
#   'conocimiento',
#   'humano',
#   'problema',
#   'gran',
#   'volumen',
#   'información',
#   'distribuido',
#   'difusión',
#   'información',
#   'tráfico',
#   'abarca',
#   'gran',
#   'abanico',
#   'posibilidades',
#   'hacen',
#   'tratamiento',
#   'información',
#   'deba',
#   'abordar',
#   'manera',
#   'eficaz',
#   'usuario',
#   've',
#   'obligado',
#   'tratar',
#   'gran',
#   'volumen',
#   'información',
#   'aparece',
#   'vez',
#   'distribuida',
#   'diferentes',
#   'portales',
#   'web',
#   'administraciones',
#   'entidades',
#   'privadas',
#   'ofrecen',
#   'vez',
#   'aparición',
#   'múltiples',
#   'dispositivos',
#   'usuario',
#   'final',
#   'dado',
#   'lugar',
#   'punto',
#   'vista',
#   'usuario',
#   'gran',
#   'dificultad',
#   'encontrar',
#   'lugares',
#   'tratar',
#   'diferentes',
#   'representaciones',
#   'accesos',
#   'información',
#   'problema',
#   'imposibilidad',
#   'almacenaje',
#   'toda',
#   'información',
#   'parte',
#   'usuario',
#   'puede',
#   'necesitar',
#   'información',
#   'diferente',
#   'naturaleza',
#   'almacenaje',
#   'toda',
#   'información',
#   'solo',
#   'sitio',
#   'web',
#   'viable',
#   'nivel',
#   'costes',
#   'almacenamiento',
#   'incluso',
#   'nivel',
#   'mantenimiento',
#   'problema',
#   'carencia',
#   'descripciones',
#   'semánticas',
#   'servicios',
#   'web',
#   'tal',
#   'describe',
#   'problema',
#   'vocabularios',
#   'lenguajes',
#   'describen',
#   'conceptos',
#   'estructuras',
#   'datos',
#   'relacionados',
#   'tráfico',
#   'suelen',
#   'ser',
#   'ad',
#   'hoc',
#   'cada',
#   'aplicación',
#   'además',
#   'descripciones',
#   'tipo',
#   'sintáctico',
#   'carentes',
#   'semántica',
#   'llegó',
#   'búsqueda',
#   'revisión',
#   'bibliográfica',
#   'tesis',
#   'encontraron',
#   'ontologías',
#   'vocabularios',
#   'valor',
#   'semántico',
#   'aporten',
#   'significado',
#   'conceptos',
#   'relaciones',
#   'tampoco',
#   'conoce',
#   'existencia',
#   'servicios',
#   'web',
#   'sw',
#   'información',
#   'tráfico',
#   'problema',
#   'solamente',
#   'posible',
#   'obtener',
#   'conocimiento',
#   'explícito',
#   'problema',
#   'derivado',
#   'anterior',
#   'tratamiento',
#   'información',
#   'permite',
#   'realizar',
#   'inferencias',
#   'manera',
#   'pueda',
#   'ser',
#   'obtenida',
#   'resultado',
#   'información',
#   'priori',
#   'explícitamente'],
#  'Problema9': ['minería',
#   'texto',
#   'área',
#   'investigación',
#   'reciente',
#   'procesamiento',
#   'textos',
#   'define',
#   'proceso',
#   'descubrimiento',
#   'patrones',
#   'interesantes',
#   'colección',
#   'textos',
#   'patrones',
#   'deben',
#   'existir',
#   'explícitamente',
#   'ningún',
#   'texto',
#   'colección',
#   'deben',
#   'surgir',
#   'relacionar',
#   'contenido',
#   'varios',
#   'hearst',
#   'kodratoff',
#   'proceso',
#   'minería',
#   'texto',
#   'consiste',
#   'dos',
#   'etapas',
#   'principales',
#   'etapa',
#   'preprocesamiento',
#   'etapa',
#   'descubrimiento',
#   'tan',
#   'primera',
#   'etapa',
#   'textos',
#   'transforman',
#   'algún',
#   'tipo',
#   'representación',
#   'estructurada',
#   'semiestructurada',
#   'facilite',
#   'posterior',
#   'análisis',
#   'mientras',
#   'segunda',
#   'etapa',
#   'representaciones',
#   'intermedias',
#   'analizan',
#   'objetivo',
#   'descubrir',
#   'patrones',
#   'interesantes',
#   'nuevos',
#   'conocimiento',
#   'entonces',
#   'dependiendo',
#   'tipo',
#   'métodos',
#   'aplicados',
#   'etapa',
#   'preprocesamiento',
#   'tipo',
#   'representaciones',
#   'intermedias',
#   'construidas',
#   'función',
#   'dicha',
#   'representación',
#   'tipo',
#   'métodos',
#   'usados',
#   'etapa',
#   'descubrimiento',
#   'consecuencia',
#   'tipo',
#   'patrones',
#   'descubiertos',
#   'figura',
#   'muestra',
#   'principales',
#   'estrategias',
#   'usadas',
#   'actuales',
#   'sistemas',
#   'minería',
#   'texto',
#   'acuerdo',
#   'figura',
#   'mayoría',
#   'actuales',
#   'minería',
#   'texto',
#   'limitan',
#   'resultados',
#   'nivel',
#   'temático',
#   'entidad',
#   'imposibilitan',
#   'descubrimiento',
#   'cosas',
#   'detalladas',
#   'consensos',
#   'ejemplo',
#   'respondan',
#   'preguntas',
#   'cuál',
#   'opinión',
#   'mayoritaria',
#   'mexicanos',
#   'gobierno',
#   'fox',
#   'tendencias',
#   'indiquen',
#   'ejemplo',
#   'si',
#   'existido',
#   'variaciones',
#   'postura',
#   'fox',
#   'respecto',
#   'educación',
#   'desviaciones',
#   'identifiquen',
#   'ejemplo',
#   'opiniones',
#   'raras',
#   'respecto',
#   'desempeño',
#   'selección',
#   'mexicana',
#   'fútbol',
#   'idea',
#   'mejorar',
#   'expresividad',
#   'diversidad',
#   'descubrimientos',
#   'sistemas',
#   'minería',
#   'textos',
#   'consiste',
#   'usar',
#   'representación',
#   'contenido',
#   'textos',
#   'completa',
#   'representaciones',
#   'usadas',
#   'actualmente',
#   'siguiendo',
#   'enfoque',
#   'investigación',
#   'propone',
#   'usar',
#   'grafos',
#   'conceptuales',
#   'sowa',
#   'representación',
#   'contenido',
#   'textos',
#   'grafos',
#   'conceptuales',
#   'seleccionaron',
#   'representaciones',
#   'ejemplo',
#   'árboles',
#   'sintácticos',
#   'predicados',
#   'lógicos',
#   'klone',
#   'siguientes',
#   'razones',
#   'grafos',
#   'conceptuales',
#   'permiten',
#   'representar',
#   'adecuadamente',
#   'términos',
#   'expresividad',
#   'eficiencia',
#   'notacional',
#   'información',
#   'lenguaje',
#   'natural',
#   'grafos',
#   'conceptuales',
#   'disponen',
#   'mecanismos',
#   'formales',
#   'facilitan',
#   'manipulación',
#   'transformación',
#   'análisis',
#   'ver',
#   'sección',
#   'grafos',
#   'conceptuales',
#   'usan',
#   'tareas',
#   'afines',
#   'minería',
#   'texto',
#   'ejemplo',
#   'recuperación',
#   'información',
#   'agrupamiento',
#   'textos',
#   'ahora',
#   'bien',
#   'realizar',
#   'minería',
#   'texto',
#   'usando',
#   'grafos',
#   'conceptuales',
#   'representación',
#   'contenido',
#   'textos',
#   'involucra',
#   'dos',
#   'problemas',
#   'diferentes',
#   'primer',
#   'lugar',
#   'transformación',
#   'textos',
#   'grafos',
#   'conceptuales',
#   'segundo',
#   'lugar',
#   'análisis',
#   'automático',
#   'conjunto',
#   'grafos',
#   'conceptuales',
#   'transformación',
#   'textos',
#   'grafos',
#   'conceptuales',
#   'problema',
#   'complejo',
#   'vinculado',
#   'análisis',
#   'sintáctico',
#   'semántico',
#   'sowa',
#   'and',
#   'way',
#   'sowa',
#   'debido',
#   'ello',
#   'métodos',
#   'existen',
#   'realizar',
#   'dicha',
#   'transformación',
#   'enfocan',
#   'dominio',
#   'único',
#   'restringido',
#   'ejemplos',
#   'siguientes',
#   'partes',
#   'artículos',
#   'científicos',
#   'grafos',
#   'conceptuales',
#   'myaeng',
#   'and',
#   'khoo',
#   'lópezlópez',
#   'montesygómez',
#   'montesygómez',
#   'et',
#   'partes',
#   'expedientes',
#   'médicos',
#   'grafos',
#   'conceptuales',
#   'baud',
#   'et',
#   'rassinoux',
#   'et',
#   'partes',
#   'casos',
#   'legales',
#   'grafos',
#   'conceptuales',
#   'boucier',
#   'and',
#   'rajman',
#   'partes',
#   'manuales',
#   'referencia',
#   'grafos',
#   'conceptuales',
#   'petermann',
#   'parte',
#   'análisis',
#   'automático',
#   'conjunto',
#   'grafos',
#   'conceptuales',
#   'orientado',
#   'descubrimiento',
#   'patrones',
#   'descriptivos',
#   'nuevos',
#   'conocimientos',
#   'problema',
#   'estudiado',
#   'mineau',
#   'and',
#   'godin',
#   'godin',
#   'et',
#   'bournaud',
#   'and',
#   'ganascia',
#   'bournaud',
#   'and',
#   'ganascia',
#   'míller',
#   'así',
#   'pues',
#   'trabajo',
#   'investigación',
#   'enfoca',
#   'análisis',
#   'conjunto',
#   'grafos',
#   'conceptuales',
#   'representan',
#   'contenido',
#   'conjunto',
#   'textos',
#   'descubrimiento',
#   'varios',
#   'tipos',
#   'patrones',
#   'interesantes',
#   'ejemplo',
#   'agrupamientos',
#   'asociaciones'],
#  'Problema10': ['objetivo',
#   'desambiguación',
#   'sentidos',
#   'palabras',
#   'determinar',
#   'significado',
#   'correcto',
#   'sentido',
#   'palabra',
#   'dada',
#   'contexto',
#   'consi',
#   'dera',
#   'problemas',
#   'difíciles',
#   'nivel',
#   'léxico',
#   'procesamiento',
#   'lenguaje',
#   'natural',
#   'fundamental',
#   'aplicaciones',
#   'traducción',
#   'automática',
#   'recuperación',
#   'información',
#   'etc',
#   'dificultades',
#   'provienen',
#   'orígenes',
#   'incluyendo',
#   'falta',
#   'medios',
#   'formalizar',
#   'propiedades',
#   'parámetros',
#   'contexto',
#   'caracterizan',
#   'uso',
#   'pa',
#   'labra',
#   'ambigua',
#   'sentido',
#   'particular',
#   'falta',
#   'inventario',
#   'sentidos',
#   'usuales',
#   'enfoques',
#   'existen',
#   'wsd',
#   'aprendizaje',
#   'supervisado',
#   'exitoso',
#   'fecha',
#   'emplea',
#   'corpus',
#   'cada',
#   'ocurrencia',
#   'palabra',
#   'ambigua',
#   'w',
#   'manualmente',
#   'anotada',
#   'sentido',
#   'correcto',
#   'acuer',
#   'do',
#   'existencia',
#   'sentidos',
#   'diccionario',
#   'forma',
#   'corpus',
#   'sirve',
#   'material',
#   'entrenamiento',
#   'algoritmo',
#   'aprendizaje',
#   'cuyo',
#   'resultado',
#   'modelo',
#   'automáticamente',
#   'aprendido',
#   'puede',
#   'ser',
#   'usado',
#   'atribuir',
#   'sentido',
#   'corpus',
#   'empleados',
#   'tarea',
#   'clasificación',
#   'supervisada',
#   'requieren',
#   'gran',
#   'cantidad',
#   'ejemplos',
#   'cada',
#   'sentido',
#   'palabra',
#   'requisito',
#   'hace',
#   'enfoque',
#   'pervisado',
#   'impracticable',
#   'tratar',
#   'desambiguar',
#   'todas',
#   'palabras',
#   'textos',
#   'problema',
#   'llamado',
#   'obstáculo',
#   'adquisición',
#   'conocimientos',
#   'reconocido',
#   'mejor',
#   'manera',
#   'adquirir',
#   'etiquetas',
#   'sentidos',
#   'pa',
#   'labras',
#   'corpus',
#   'mano',
#   'embargo',
#   'formulación',
#   'manual',
#   'inventarios',
#   'sentidos',
#   'basada',
#   'intuición',
#   'lexicógrafos',
#   'visto',
#   'afectada',
#   'problemas',
#   'incluyen',
#   'alto',
#   'costo',
#   'asignación',
#   'arbitraria',
#   'significado',
#   'palabras',
#   'emparejamiento',
#   'equivocado',
#   'dominios',
#   'aplicación',
#   'debido',
#   'anteriores',
#   'inconvenientes',
#   'acercamientos',
#   'supervisados',
#   're',
#   'cibido',
#   'mucha',
#   'atención',
#   'últimos',
#   'años',
#   'pues',
#   'potencial',
#   'superar',
#   'cuello',
#   'botella',
#   'adquisición',
#   'sentidos',
#   'conseguido',
#   'introducción',
#   'sentido',
#   'palabra',
#   'directamente',
#   'corpus',
#   'embargo',
#   'parece',
#   'simple',
#   'vista',
#   'ventaja',
#   'constituye',
#   'principal',
#   'desventaja',
#   'desambiguación',
#   'lleva',
#   'cabo',
#   'partiendo',
#   'conjunto',
#   'bien',
#   'definido',
#   'sentidos',
#   'conlle',
#   'va',
#   'muchas',
#   'ocasiones',
#   'obtención',
#   'resultados',
#   'pobres',
#   'proceso'],
#  'Problema11': ['área',
#   'reconocimiento',
#   'automático',
#   'emociones',
#   'área',
#   'investigación',
#   'activa',
#   'últimos',
#   'años',
#   'obstante',
#   'aun',
#   'solución',
#   'clara',
#   'problema',
#   'diversos',
#   'inconvenientes',
#   'influido',
#   'construcción',
#   'solución',
#   'apropiada',
#   'lado',
#   'factor',
#   'afecta',
#   'desempeño',
#   'reconocedores',
#   'emociones',
#   'contextos',
#   'reales',
#   'dificultad',
#   'generar',
#   'bases',
#   'datos',
#   'emociones',
#   'espontáneas',
#   'generalmente',
#   'trabajado',
#   'bases',
#   'datos',
#   'actuadas',
#   'cuales',
#   'proporcionan',
#   'retratos',
#   'emociones',
#   'representando',
#   'expresiones',
#   'prototípicas',
#   'intensas',
#   'facilitan',
#   'búsqueda',
#   'correlación',
#   'acústica',
#   'subsecuente',
#   'clasificación',
#   'automática',
#   'embargo',
#   'buenos',
#   'resultados',
#   'trasladar',
#   'conocimiento',
#   'extraído',
#   'bases',
#   'datos',
#   'contextos',
#   'reales',
#   'steidl',
#   'características',
#   'bases',
#   'datos',
#   'actuadas',
#   'retratos',
#   'emociones',
#   'representando',
#   'expresiones',
#   'prototípicas',
#   'intensas',
#   'facilitan',
#   'búsqueda',
#   'correlación',
#   'acústica',
#   'subsecuente',
#   'clasificación',
#   'automática',
#   'grabaciones',
#   'estudio',
#   'alta',
#   'calidad',
#   'eliminan',
#   'problemas',
#   'procesamiento',
#   'señal',
#   'ejemplo',
#   'ruido',
#   'reverberación',
#   'puede',
#   'garantizar',
#   'cantidad',
#   'balanceada',
#   'ejemplos',
#   'clase',
#   'contraparte',
#   'bases',
#   'datos',
#   'emociones',
#   'espontáneas',
#   'muestran',
#   'elocuciones',
#   'contenido',
#   'emocional',
#   'perteneciente',
#   'sola',
#   'clase',
#   'sino',
#   'mezcla',
#   'emociones',
#   'casos',
#   'existen',
#   'elocuciones',
#   'carga',
#   'emocional',
#   'ligera',
#   'cercana',
#   'emocional',
#   'neutro',
#   'además',
#   'bases',
#   'datos',
#   'emociones',
#   'espontáneas',
#   'suelen',
#   'grabarse',
#   'ambientes',
#   'ruidosos',
#   'conversaciones',
#   'telefónicas',
#   'programas',
#   'televisión',
#   'conlleva',
#   'inclusión',
#   'ruido',
#   'finalmente',
#   'naturaleza',
#   'misma',
#   'problema',
#   'posible',
#   'asegurar',
#   'cantidad',
#   'balanceada',
#   'ejemplos',
#   'clase',
#   'reto',
#   'resolver',
#   'identificación',
#   'conjunto',
#   'características',
#   'acústicas',
#   'permitan',
#   'reconocer',
#   'emociones',
#   'habla',
#   'espontánea',
#   'trabajo',
#   'hecho',
#   'fecha',
#   'centrado',
#   'principalmente',
#   'características',
#   'relacionadas',
#   'aspectos',
#   'prosódicos',
#   'embargo',
#   'descubierto',
#   'acercamos',
#   'escenario',
#   'realista',
#   'menos',
#   'fiable',
#   'prosodia',
#   'indicador',
#   'emocional',
#   'hablante',
#   'batliner',
#   'et',
#   'necesario',
#   'encontrar',
#   'características',
#   'complementen',
#   'información',
#   'proporciona',
#   'aspecto',
#   'prosódico',
#   'voz',
#   'finalmente',
#   'fecha',
#   'mayoría',
#   'trabajos',
#   'utilizado',
#   'modelos',
#   'emocionales',
#   'discretos',
#   'emociones',
#   'reconocer',
#   'claramente',
#   'identificadas',
#   'corpus',
#   'entrenamiento',
#   'bajo',
#   'enfoque',
#   'existe',
#   'valoración',
#   'emoción',
#   'sino',
#   'búsqueda',
#   'varias',
#   'reglas',
#   'permitan',
#   'discriminación',
#   'emociones',
#   'cuestión',
#   'forma',
#   'prácticamente',
#   'necesario',
#   'repetir',
#   'trabajo',
#   'si',
#   'desea',
#   'agregar',
#   'nueva',
#   'emoción',
#   'desea',
#   'trabajar',
#   'corpus',
#   'además',
#   'modelos',
#   'discretos',
#   'parecen',
#   'ser',
#   'adecuados',
#   'trabajar',
#   'emociones',
#   'espontáneas',
#   'representan',
#   'apropiadamente',
#   'traslape',
#   'emociones',
#   'habla',
#   'pesar',
#   'avances',
#   'área',
#   'importantes',
#   'comprobado',
#   'contextos',
#   'realistas',
#   'aún',
#   'falta',
#   'hacer',
#   'necesario',
#   'proponer',
#   'explorar',
#   'enfoques',
#   'permitan',
#   'llegar',
#   'buen',
#   'desempeño',
#   'reconocimiento',
#   'emociones',
#   'aplicaciones',
#   'mundo',
#   'real',
#   'ello',
#   'tesis',
#   'propone',
#   'trabajar',
#   'características',
#   'diversificadas',
#   'expandan',
#   'uso',
#   'características',
#   'acústicas',
#   'lingsticas',
#   'además',
#   'emplear',
#   'modelo',
#   'continuo',
#   'permita',
#   'apegarnos',
#   'realidad',
#   'trabajo',
#   'basado',
#   'modelo',
#   'continuo',
#   'tridimensional',
#   'cuyas',
#   'primitivas',
#   'valencia',
#   'activación',
#   'dominación',
#   'emplearán',
#   'principalmente',
#   'características',
#   'acústicas',
#   'incluyen',
#   'características',
#   'prosódicas',
#   'calidad',
#   'voz',
#   'espectrales',
#   'explorará',
#   'uso',
#   'características',
#   'lingsticas',
#   'complemento',
#   'soporte',
#   'características',
#   'acústicas',
#   'además',
#   'explorará',
#   'uso',
#   'procesamiento',
#   'estático',
#   'dinámico'],
#  'Problema12': ['tesis',
#   'parte',
#   'considerar',
#   'tecnologías',
#   'general',
#   'tic',
#   'particular',
#   'neutrales',
#   'autónomas',
#   'tal',
#   'sentido',
#   'premisas',
#   'clave',
#   'parte',
#   'ver',
#   'idea',
#   'pieza',
#   'tecnología',
#   'adquiere',
#   'significado',
#   'dentro',
#   'grupos',
#   'sociales',
#   'amplios',
#   'decir',
#   'desarrolla',
#   'bajo',
#   'propia',
#   'lógica',
#   'técnica',
#   'inmanente',
#   'tecnologías',
#   'adquieren',
#   'significados',
#   'mundo',
#   'social',
#   'significados',
#   'dan',
#   'forma',
#   'constriñen',
#   'desarrollo',
#   'menudo',
#   'etapas',
#   'iniciales',
#   'producción',
#   'conciben',
#   'diferentes',
#   'significados',
#   'tecnología',
#   'enfrentados',
#   'concepción',
#   'instrumentalista',
#   'tecnología',
#   'decir',
#   'aquella',
#   'considera',
#   'tecnologías',
#   'simples',
#   'herramientas',
#   'artefactos',
#   'construidos',
#   'diversidad',
#   'tareas',
#   'colabora',
#   'consolidar',
#   'percepción',
#   'misma',
#   'neutral',
#   'problema',
#   'mayor',
#   'planteo',
#   'considera',
#   'tecnología',
#   'independiente',
#   'cualquier',
#   'sistema',
#   'político',
#   'social',
#   'así',
#   'cualquier',
#   'tecnología',
#   'puede',
#   'ser',
#   'transferida',
#   'espacio',
#   'social',
#   'mayores',
#   'consecuencias',
#   'tesis',
#   'considera',
#   'tales',
#   'cosmovisiones',
#   'reduccionistas',
#   'esconden',
#   'potencial',
#   'peligro',
#   'acarrea',
#   'ignorar',
#   'redes',
#   'intereses',
#   'sociales',
#   'económicos',
#   'políticos',
#   'aquellos',
#   'diseñan',
#   'desarrollan',
#   'financian',
#   'controlan',
#   'tecnología',
#   'gonzález',
#   'garcía',
#   'lópez',
#   'cerezo',
#   'luján',
#   'lópez',
#   'desarrollo',
#   'informática',
#   'agudizó',
#   'percepción',
#   'centralidad',
#   'tecnológico',
#   'procesos',
#   'cambio',
#   'social',
#   'mismo',
#   'tiempo',
#   'pareciera',
#   'tales',
#   'procesos',
#   'demandan',
#   'promueven',
#   'motivan',
#   'cambios',
#   'tecnológicos',
#   'importancia',
#   'tecnológico',
#   'alcanzado',
#   'relativa',
#   'centralidad',
#   'investigadores',
#   'provenientes',
#   'tradiciones',
#   'disciplinares',
#   'diversas',
#   'obstante',
#   'pregunta',
#   'cómo',
#   'articulan',
#   'tales',
#   'cambios',
#   'junto',
#   'político',
#   'institucionales',
#   'organizacionales',
#   'económicos',
#   'cognitivos',
#   'simbólicos',
#   'territoriales',
#   'crucial',
#   'aún',
#   'permanece',
#   'abierta',
#   'si',
#   'bien',
#   'pareciera',
#   'haber',
#   'cada',
#   'vez',
#   'esfuerzos',
#   'sistematizar',
#   'teorías',
#   'torno',
#   'distintas',
#   'problemáticas',
#   'tic',
#   'términos',
#   'formulaciones',
#   'descripciones',
#   'revelan',
#   'insuficientes',
#   'frente',
#   'dimensiones',
#   'fenómeno',
#   'termina',
#   'estabilizarse',
#   'efecto',
#   'apenas',
#   'configuración',
#   'sentido',
#   'comienza',
#   'consolidarse',
#   'produce',
#   'algún',
#   'cambio',
#   'tecnología',
#   'obliga',
#   'revisar',
#   'hace',
#   'pensaba',
#   'castells',
#   'paradigma',
#   'tecnología',
#   'información',
#   'evoluciona',
#   'hacia',
#   'cierre',
#   'sistema',
#   'sino',
#   'hacia',
#   'apertura',
#   'red',
#   'multifacética',
#   'poderoso',
#   'imponente',
#   'materialidad',
#   'adaptable',
#   'abierto',
#   'desarrollo',
#   'histórico',
#   'cualidades',
#   'decisivas',
#   'carácter',
#   'integrador',
#   'complejidad',
#   'interconexión',
#   'generación',
#   'redes',
#   'incertidumbre',
#   'surge',
#   'escenario',
#   'caracterizado',
#   'complejidad',
#   'entorno',
#   'cada',
#   'vez',
#   'abierto',
#   'así',
#   'resulta',
#   'central',
#   'contar',
#   'adecuado',
#   'corpus',
#   'teórico',
#   'estudio',
#   'específico',
#   'tic',
#   'supuesto',
#   'finalidad',
#   'desafíos',
#   'complejos',
#   'lado',
#   'debe',
#   'tener',
#   'consideración',
#   'flexibilidad',
#   'imponen',
#   'cambios',
#   'tecnológicos',
#   'lado',
#   'debe',
#   'ser',
#   'posible',
#   'enmarcar',
#   'distintos',
#   'campos',
#   'desarrollo',
#   'tic',
#   'escenario',
#   'marcado',
#   'inestabilidad',
#   'velocidad',
#   'cambio',
#   'junto',
#   'obsolescencia',
#   'teorías',
#   'importante',
#   'contribuir',
#   'consolidación',
#   'conocimientos',
#   'así',
#   'descripción',
#   'experiencias',
#   'fin',
#   'ir',
#   'constituyendo',
#   'corpus',
#   'permita',
#   'aproximar',
#   'comprensión',
#   'fenómenos',
#   'singularidad',
#   'tal',
#   'sentido',
#   'medida',
#   'tic',
#   'difunden',
#   'vida',
#   'cotidiana',
#   'internalizan',
#   'naturalizan',
#   'determinados',
#   'usos',
#   'tecnológicos',
#   'desconoce',
#   'cuán',
#   'complejo',
#   'funcionamiento',
#   'interno',
#   'tecnología',
#   'contribuye',
#   'crear',
#   'percepción',
#   'mágica',
#   'tic',
#   'idea',
#   'fantástica',
#   'refuerza',
#   'encuentra',
#   'arraigada',
#   'estudios',
#   'orientados',
#   'analizar',
#   'impactos',
#   'efectos',
#   'nuevas',
#   'tecnologías',
#   'sociedad',
#   'tesis',
#   'deterministas',
#   'tienden',
#   'naturalizar',
#   'aparente',
#   'neutralidad',
#   'autonomía',
#   'tecnología',
#   'relación',
#   'informática',
#   'suele',
#   'describir',
#   'desarrollo',
#   'proceso',
#   'autónomo',
#   'sigue',
#   'lógica',
#   'propia',
#   'margen',
#   'cualquier',
#   'dinámica',
#   'social',
#   'piensa',
#   'así',
#   'tecnología',
#   'sigue',
#   'propio',
#   'curso',
#   'margen',
#   'intervención',
#   'humana',
#   'tesis',
#   'tecnología',
#   'autónoma',
#   'patrocina',
#   'relación',
#   'unidireccional',
#   'tecnología',
#   'sociedad',
#   'considera',
#   'desarrollos',
#   'tecnológicos',
#   'influyen',
#   'significativamente',
#   'orden',
#   'social',
#   'mientras',
#   'tecnología',
#   'muestra',
#   'contrario',
#   'impermeable',
#   'influencia',
#   'factores',
#   'sociales',
#   'influencia',
#   'tecnología',
#   'ámbito',
#   'social',
#   'produce',
#   'pues',
#   'exterior',
#   'emparentadas',
#   'ideas',
#   'encuentran',
#   'sostienen',
#   'cambio',
#   'social',
#   'determinado',
#   'cambio',
#   'tecnológico',
#   'supuestos',
#   'consideran',
#   'base',
#   'técnica',
#   'sociedad',
#   'condición',
#   'fundamental',
#   'afecta',
#   'modos',
#   'existencia',
#   'social',
#   'cambios',
#   'tecnológicos',
#   'fuente',
#   'importante',
#   'cambios',
#   'sociales',
#   'tesis',
#   'contrario',
#   'sostiene',
#   'tecnología',
#   'moldeada',
#   'socialmente',
#   'problema',
#   'radica',
#   'enfoques',
#   'tecnocráticos',
#   'ignoran',
#   'complejidad',
#   'procesos',
#   'sociales',
#   'consiguiente',
#   'abrir',
#   'caja',
#   'negra',
#   'tic',
#   'vuelve',
#   'crucial',
#   'fin',
#   'evitar',
#   'recaer',
#   'viejo',
#   'dualismo',
#   'tecnología',
#   'sociedad',
#   'ello',
#   'analizar',
#   'cómo',
#   'opciones',
#   'sociales',
#   'cristalizan',
#   'encastran',
#   'decir',
#   'instituyen',
#   'dentro',
#   'tecnología',
#   'fundamental',
#   'desafío',
#   'deviene',
#   'comprender',
#   'cómo',
#   'tecnologías',
#   'mismas',
#   'socialmente',
#   'construidas',
#   'describir',
#   'procesos',
#   'adopción',
#   'cambio',
#   'tecnologías',
#   'través',
#   'conceptualizaciones',
#   'dinámicas',
#   'den',
#   'lugar',
#   'análisis',
#   'términos',
#   'relaciones',
#   'procesos',
#   'requirió',
#   'abordaje',
#   'analítico',
#   'conceptual',
#   'generó',
#   'mediante',
#   'procedimiento',
#   'triangulación',
#   'teórica',
#   'dicha',
#   'triangulación',
#   'combinaron',
#   'conceptos',
#   'acuñados',
#   'distintos',
#   'campos',
#   'disciplinares',
#   'estudios',
#   'sociales',
#   'tecnología',
#   'estudios',
#   'educación',
#   'superior',
#   'universidades',
#   'estudios',
#   'territoriales',
#   'relación',
#   'educación',
#   'superior',
#   'universidad',
#   'particular',
#   'denominada',
#   'sociedad',
#   'información',
#   'conocimiento',
#   'modifica',
#   'misión',
#   'institucional',
#   'universidades',
#   'amplían',
#   'alcances',
#   'territoriales',
#   'medio',
#   'generación',
#   'propuestas',
#   'virtuales',
#   'enseñanza',
#   'casos',
#   'trascienden',
#   'límites',
#   'institucionales',
#   'tal',
#   'sentido',
#   'campus',
#   'virtuales',
#   'dependiendo',
#   'distintas',
#   'tramas',
#   'significados',
#   'co',
#   'construyen',
#   'acrecientan',
#   'posibilidades',
#   'expansivas',
#   'universidad',
#   'ramificando',
#   'casos',
#   'área',
#   'influencia',
#   'geográfica',
#   'instituciones',
#   'universitarias',
#   'así',
#   'tesis',
#   'considera',
#   'campus',
#   'virtual',
#   'entidad',
#   'desterritorializada',
#   'sino',
#   'física',
#   'virtualmente',
#   'situado',
#   'soporte',
#   'dado',
#   'elementos',
#   'componentes',
#   'circulan',
#   'mediante',
#   'redes',
#   'contexto',
#   'local',
#   'regional',
#   'elementos',
#   'influyó',
#   'localización',
#   'universidades',
#   'nacionales',
#   'argentinas',
#   'así',
#   'casos',
#   'privilegió',
#   'relación',
#   'medio',
#   'socio',
#   'productivo',
#   'región',
#   'pertenencia',
#   'dichas',
#   'instituciones',
#   'relaciones',
#   'establecidas',
#   'distintos',
#   'organismos',
#   'vinculados',
#   'contexto',
#   'local',
#   'encuentran',
#   'ubicadas',
#   'manera',
#   'dimensión',
#   'territorial',
#   'elemento',
#   'importante',
#   'análisis',
#   'objeto',
#   'estudio',
#   'obra',
#   'siempre',
#   'veremos',
#   'capítulo',
#   'incorporado',
#   'análisis',
#   'procesos',
#   'construcción',
#   'social',
#   'tecnología',
#   'argentina',
#   'particular',
#   'américa',
#   'latina',
#   'general',
#   'enfoque',
#   'combine',
#   'distintas',
#   'disciplinas',
#   'vuelve',
#   'necesario',
#   'comprender',
#   'características',
#   'tecnología',
#   'local',
#   'posibilidades',
#   'desarrollo',
#   'éstas',
#   'pueden',
#   'brindar',
#   'región',
#   'condiciones',
#   'producen',
#   'utilizan',
#   'tecnologías',
#   'países',
#   'presentan',
#   'dinámica',
# ...
#   'discretización',
#   'relevante',
#   'identificación',
#   'buen',
#   'modelo',
#   'capture',
#   'comportamiento',
#   'sistema',
#   'manera',
#   'precisa',
#   'sentido',
#   'muchas',
#   'aplicaciones',
#   'estudiadas',
#   'necesario',
#   'seleccionar',
#   'modelos',
#   'fir',
#   'subóptimos',
#   'poder',
#   'predicción',
#   'mayor',
#   'obtenido',
#   'modelo',
#   'óptimo',
#   'incluso',
#   'comprobó',
#   'pequeños',
#   'cambios',
#   'valores',
#   'landmarks',
#   'producían',
#   'consecuencias',
#   'importantes',
#   'capacidad',
#   'predicción',
#   'modelos',
#   'identificados',
#   'óptimos',
#   'subóptimos',
#   'ello',
#   'determinación',
#   'automática',
#   'parámetros',
#   'adecuados',
#   'discretización',
#   'metodología',
#   'fir',
#   'surge',
#   'alternativa',
#   'gran',
#   'interés',
#   'utilidad',
#   'uso',
#   'valores',
#   'heurísticos',
#   'defecto',
#   'aún',
#   'automatizar',
#   'selección',
#   'valores',
#   'adecuados',
#   'parámetros',
#   'permite',
#   'uso',
#   'metodología',
#   'fir',
#   'usuarios',
#   'expertos',
#   'modelado',
#   'sistemas',
#   'lógica',
#   'difusa',
#   'garantizándoles',
#   'mejor',
#   'rendimiento',
#   'metodología'],
#  'Problema31': ['diferentes',
#   'modelos',
#   'redes',
#   'neuronales',
#   'artificiales',
#   'ampliamente',
#   'estudiadas',
#   'cuales',
#   'pueden',
#   'clasificar',
#   'dependiendo',
#   'flujo',
#   'datos',
#   'través',
#   'red',
#   'redes',
#   'neuronales',
#   'estáticas',
#   'redes',
#   'neuronales',
#   'recurrentes',
#   'redes',
#   'neuronales',
#   'estáticas',
#   'flujo',
#   'datos',
#   'siempre',
#   'dirección',
#   'entrada',
#   'salida',
#   'red',
#   'neuronal',
#   'mientras',
#   'red',
#   'neuronal',
#   'recurrente',
#   'flujo',
#   'datos',
#   'mueve',
#   'entrada',
#   'salida',
#   'red',
#   'neuronal',
#   'realimentación',
#   'datos',
#   'salida',
#   'entrada',
#   'capas',
#   'interiores',
#   'red',
#   'neuronal',
#   'forma',
#   'clasificar',
#   'redes',
#   'tipo',
#   'aprendizaje',
#   'si',
#   'red',
#   'neuronal',
#   'entrena',
#   'conjunto',
#   'datos',
#   'previo',
#   'trabajo',
#   'sistema',
#   'proceso',
#   'conoce',
#   'aprendizaje',
#   'proceso',
#   'cambio',
#   'si',
#   'red',
#   'neuronal',
#   'aprende',
#   'tiempo',
#   'real',
#   'trabaja',
#   'mutuamente',
#   'sistema',
#   'llama',
#   'aprendizaje',
#   'proceso',
#   'clase',
#   'sistemas',
#   'procesos',
#   'tratan',
#   'tesis',
#   'modelados',
#   'ecuaciones',
#   'diferenciales',
#   'embargo',
#   'mecanismos',
#   'tratan',
#   'tesis',
#   'solo',
#   'conocen',
#   'estructura',
#   'modelo',
#   'ejemplo',
#   'si',
#   'x',
#   'fx',
#   'gxu',
#   'hx',
#   'modelo',
#   'algún',
#   'sistema',
#   'particular',
#   'f',
#   'irn',
#   'irn',
#   'g',
#   'irn',
#   'irnr',
#   'vector',
#   'control',
#   'u',
#   'irr',
#   'r',
#   'n',
#   'variables',
#   'x',
#   'irn',
#   'vector',
#   'salida',
#   'irn',
#   'irm',
#   'entonces',
#   'dada',
#   'forma',
#   'representación',
#   'modelo',
#   'dinámico',
#   'conoce',
#   'estructura',
#   'funciones',
#   'fx',
#   'gx',
#   'hx',
#   'desconocidas',
#   'sistemas',
#   'dinámicos',
#   'clasifican',
#   'acuerdo',
#   'grado',
#   'actuación',
#   'número',
#   'actuadores',
#   'respecto',
#   'grados',
#   'libertad',
#   'sistema',
#   'sistemas',
#   'completamente',
#   'actuados',
#   'sistemas',
#   'subastados',
#   'sistemas',
#   'completamente',
#   'actuados',
#   'igual',
#   'número',
#   'actúa',
#   'dores',
#   'grados',
#   'libertad',
#   'sistema',
#   'mientras',
#   'subastados',
#   'menos',
#   'actuadores',
#   'grados',
#   'libertad',
#   'difíciles',
#   'controlar',
#   'modelos',
#   'dinámicos',
#   'alto',
#   'grado',
#   'incertidumbre',
#   'integran',
#   'todas',
#   'dinámicas',
#   'sistema',
#   'físico',
#   'fricción',
#   'zona',
#   'muerta',
#   'saturación',
#   'vacilas',
#   'perdida',
#   'movimiento',
#   'mecanismo',
#   'causado',
#   'holgura',
#   'partes',
#   'dinámicas',
#   'desconocidas',
#   'entonces',
#   'conveniente',
#   'uso',
#   'redes',
#   'neuronales',
#   'dado',
#   'capacidad',
#   'aprender',
#   'adaptarse',
#   'sistema',
#   'recientemente',
#   'avances',
#   'área',
#   'redes',
#   'neuronales',
#   'dado',
#   'gran',
#   'impulso',
#   'control',
#   'sistemas',
#   'lineales',
#   'través',
#   'procesos',
#   'aprendizaje',
#   'sistemas',
#   'control',
#   'aprovecha',
#   'capacidad',
#   'red',
#   'neuronal',
#   'modelar',
#   'funciones',
#   'diferenciales',
#   'lineales',
#   'habilidad',
#   'aprender',
#   'adaptarse',
#   'tiempo',
#   'ejecución',
#   'proceso',
#   'ejemplo',
#   'narendra',
#   'parthasarathy',
#   'demuestran',
#   'redes',
#   'neurales',
#   'pueden',
#   'ser',
#   'usadas',
#   'efectivamente',
#   'identificación',
#   'control',
#   'procesos',
#   'dinámicos',
#   'lineales',
#   'problema',
#   'control',
#   'mecanismos',
#   'determinación',
#   'modelo',
#   'dinámico',
#   'difícil',
#   'obtener',
#   'modelo',
#   'dinámico',
#   'sistema',
#   'desconocimiento',
#   'parámetros',
#   'modelo',
#   'dinámicas',
#   'redes',
#   'neuronales',
#   'clase',
#   'sistemas',
#   'adaptativos',
#   'útiles',
#   'tales',
#   'situaciones',
#   'pueden',
#   'adaptarse',
#   'dinámica',
#   'sistema',
#   'desconoce',
#   'controladores',
#   'neuronales',
#   'aprendizaje',
#   'proceso',
#   'permiten',
#   'controlar',
#   'sistemas',
#   'dinámicos',
#   'necesidad',
#   'entrenamiento',
#   'previo',
#   'red',
#   'neuronal',
#   'además',
#   'desempeño',
#   'red',
#   'neuronal',
#   'sujeto',
#   'entrenamiento',
#   'realizado',
#   'conjunto',
#   'datos',
#   'delimitados',
#   'controlador',
#   'basado',
#   'retroalimentación',
#   'confiable',
#   'si',
#   'respaldado',
#   'estudio',
#   'estabilidad',
#   'importante',
#   'notar',
#   'trabajos',
#   'investigación',
#   'controladores',
#   'neuronales',
#   'literatura',
#   'estudio',
#   'estabilidad',
#   'sistema',
#   'dinámico',
#   'lazo',
#   'cerrado',
#   'confiabilidad',
#   'controladores',
#   'propuestos',
#   'degradada',
#   'redes',
#   'neuronales',
#   'control',
#   'sistemas',
#   'subastados',
#   'campo',
#   'conocimiento',
#   'necesita',
#   'trabajo',
#   'investigación',
#   'encuentran',
#   'trabajos',
#   'investigación',
#   'control',
#   'mecanismos',
#   'pendubot',
#   'acrobot',
#   'péndulo',
#   'furuta',
#   'péndulo',
#   'rueda',
#   'inercial',
#   'trabajos',
#   'estudio',
#   'estabilidad',
#   'si',
#   'problema',
#   'seguimiento',
#   'trayectorias',
#   'además',
#   'importante',
#   'conocer',
#   'desempeño',
#   'controladores',
#   'neuronales',
#   'clase',
#   'sistemas'],
#  'Problema32': ['incremento',
#   'potencia',
#   'crucial',
#   'alcanzar',
#   'relación',
#   'señal',
#   'ruido',
#   'deseada',
#   'receptor',
#   'señal',
#   'pudiera',
#   'ser',
#   'detectable',
#   'hacer',
#   'posible',
#   'comunicación',
#   'inalámbrica',
#   'amplio',
#   'ancho',
#   'banda',
#   'necesario',
#   'basarse',
#   'esquemas',
#   'multiplexación',
#   'complejos',
#   'acceso',
#   'múltiple',
#   'división',
#   'código',
#   'banda',
#   'ancha',
#   'wcdma',
#   'multiplexación',
#   'división',
#   'frecuencias',
#   'ortogonales',
#   'ofdm',
#   'técnicas',
#   'modulación',
#   'modulación',
#   'amplitud',
#   'cuadratura',
#   'qam',
#   'incluso',
#   'modulación',
#   'desplazamiento',
#   'fase',
#   'qpsk',
#   'momento',
#   'transmitir',
#   'altas',
#   'tasas',
#   'datos',
#   'produce',
#   'recrecimiento',
#   'espectral',
#   'agregan',
#   'efectos',
#   'memoria',
#   'linealidades',
#   'debido',
#   'características',
#   'intrínsecas',
#   'pa',
#   'pa',
#   'dispositivo',
#   'etapa',
#   'transmisor',
#   'agrega',
#   'mayoría',
#   'linealidades',
#   'efectos',
#   'memoria',
#   'existen',
#   'esfuerzos',
#   'investigación',
#   'basados',
#   'polinomios',
#   'modelos',
#   'toman',
#   'cuenta',
#   'memoria',
#   'basados',
#   'redes',
#   'neuronales',
#   'embargo',
#   'existe',
#   'plataforma',
#   'completa',
#   'capaz',
#   'emular',
#   'hardware',
#   'comportamientos',
#   'adecuados',
#   'pas',
#   'parta',
#   'mediciones',
#   'curvas',
#   'distorsión',
#   'amam',
#   'ampm',
#   'otorgue',
#   'integración',
#   'modelos',
#   'permitan',
#   'niveles',
#   'linealidad',
#   'orden',
#   'memoria',
#   'variables',
#   'modelos',
#   'polinomiales',
#   'memoria',
#   'aprendizaje',
#   'además',
#   'algoritmos',
#   'adaptativos',
#   'permitan',
#   'modelar',
#   'pas',
#   'comportamientos',
#   'complejos',
#   'pa',
#   'componente',
#   'principal',
#   'consumo',
#   'energía',
#   'etapa',
#   'transmisor',
#   'necesario',
#   'establecer',
#   'compromiso',
#   'linealidad',
#   'eficiencia',
#   'lograr',
#   'propósito',
#   'crucial',
#   'contar',
#   'modelos',
#   'comportamiento',
#   'nivel',
#   'variable',
#   'memoria',
#   'linealidad',
#   'linealización',
#   'pas',
#   'convertido',
#   'área',
#   'gran',
#   'interés',
#   'sistemas',
#   'comunicación',
#   'inalámbrica',
#   'modernos',
#   'requieren',
#   'modelos',
#   'comportamiento',
#   'describan',
#   'fielmente',
#   'funcionamiento',
#   'pa',
#   'cabe',
#   'indicar',
#   'existen',
#   'diversas',
#   'técnicas',
#   'lograr',
#   'proceso',
#   'linealización',
#   'contribuye',
#   'lograr',
#   'eficiencia',
#   'potencia',
#   'pa',
#   'trabajarlo',
#   'linealmente',
#   'mencionar',
#   'métodos',
#   'comúnmente',
#   'utilizados',
#   'encuentra',
#   'prealimentación',
#   'retroalimentación',
#   'predistorsión',
#   'analógica',
#   'modelos',
#   'mencionados',
#   'eficientes',
#   'aplicaciones',
#   'baja',
#   'frecuencia',
#   'frecuencias',
#   'altas',
#   'técnicas',
#   'pueden',
#   'sufrir',
#   'pérdidas',
#   'estabilidad',
#   'efectos',
#   'producidos',
#   'linealidades',
#   'pas',
#   'repercuten',
#   'dos',
#   'maneras',
#   'lado',
#   'causan',
#   'recrecimiento',
#   'espectral',
#   'dando',
#   'lugar',
#   'interferencias',
#   'canales',
#   'transmisión',
#   'adyacentes',
#   'distorsión',
#   'banda',
#   'operación',
#   'asignada',
#   'mientras',
#   'lado',
#   'causan',
#   'distorsión',
#   'dentro',
#   'propia',
#   'banda',
#   'transmisión',
#   'degradando',
#   'tasa',
#   'error',
#   'bits',
#   'ber',
#   'organismos',
#   'reguladores',
#   'fijan',
#   'través',
#   'diferentes',
#   'estándares',
#   'comunicaciones',
#   'niveles',
#   'máximos',
#   'permitidos',
#   'emisión',
#   'banda',
#   'así',
#   'límites',
#   'distorsión',
#   'banda',
#   'ejemplo',
#   'especificando',
#   'porcentajes',
#   'máximos',
#   'error',
#   'constelaciones',
#   'sanciones',
#   'violar',
#   'cualquiera',
#   'especificaciones',
#   'potencia',
#   'transmisión',
#   'emisión',
#   'banda',
#   'multas',
#   'elevadas',
#   'series',
#   'volterra',
#   'pueden',
#   'ser',
#   'usadas',
#   'describir',
#   'sistema',
#   'estable',
#   'lineal',
#   'pérdida',
#   'memoria',
#   'error',
#   'arbitrario',
#   'pequeño',
#   'embargo',
#   'desventajas',
#   'principales',
#   'incremento',
#   'dramático',
#   'número',
#   'parámetros',
#   'respecto',
#   'orden',
#   'linealidad',
#   'profundidad',
#   'memoria',
#   'causa',
#   'incremento',
#   'drástico',
#   'complejidad',
#   'cálculo',
#   'identificación',
#   'parámetros',
#   'razón',
#   'resulta',
#   'altamente',
#   'impráctico',
#   'uso',
#   'series',
#   'completas',
#   'volterra',
#   'representar',
#   'matemáticamente',
#   'comportamiento',
#   'sistemas',
#   'alta',
#   'linealidad',
#   'profundidad',
#   'memoria',
#   'requiere',
#   'uso',
#   'truncaciones',
#   'mpm',
#   'wiener',
#   'hammerstein',
#   'costo',
#   'computacional',
#   'cálculo',
#   'kernels',
#   'cada',
#   'modelo',
#   'reducido',
#   'comparación',
#   'series',
#   'completas',
#   'aunado',
#   'proceso',
#   'modelado',
#   'comportamiento',
#   'pa',
#   'sistema',
#   'completo',
#   'incluya',
#   'diversos',
#   'modelos',
#   'comportamiento',
#   'necesario',
#   'desarrollar',
#   'técnicas',
#   'medición',
#   'bajo',
#   'costo',
#   'métodos',
#   'tradicionales',
#   'medición',
#   'través',
#   'vna',
#   'indispensables',
#   'realizar',
#   'proceso',
#   'linealización',
#   'medición',
#   'fase',
#   'parámetro',
#   'dispersión',
#   's',
#   'provee',
#   'información',
#   'distorsión',
#   'fase',
#   'pa',
#   'embargo',
#   'menciona',
#   'involucra',
#   'costoso',
#   'uso',
#   'equipo',
#   'laboratorio',
#   'además',
#   'instalación',
#   'calibración',
#   'previa',
#   'involucra',
#   'diversas',
#   'consideraciones',
#   'método',
#   'tradicional',
#   'medición',
#   'anterior',
#   'lleva',
#   'necesidad',
#   'contar',
#   'sistema',
#   'digital',
#   'completo',
#   'pueda',
#   'modelar',
#   'curvas',
#   'distorsión',
#   'pa',
#   'estimar',
#   'comportamiento',
#   'si',
#   'pa',
#   'utilizado',
#   'dut',
#   'realizar',
#   'proceso',
#   'modelado',
#   'utilizar',
#   'algoritmos',
#   'aprendizaje',
#   'ann',
#   'anfis',
#   'dado',
#   'obtuvo',
#   'comportamiento',
#   'complejos',
#   'pas',
#   'infinidad',
#   'datos',
#   'estimar',
#   'además',
#   'estimar',
#   'distorsión',
#   'fase',
#   'pa',
#   'usando',
#   'teoría',
#   'transformación',
#   'amplitud',
#   'fase'],
#  'Problema33': ['principales',
#   'problemas',
#   'sistemas',
#   'normales',
#   'sensado',
#   'estructuras',
#   'presentan',
#   'puntuales',
#   'necesitan',
#   'cableado',
#   'protección',
#   'resulta',
#   'pesado',
#   'incrementado',
#   'peso',
#   'total',
#   'estructura',
#   'además',
#   'emplea',
#   'cableado',
#   'alimentación',
#   'energía',
#   'mejor',
#   'caso',
#   'emplean',
#   'baterías',
#   'utiliza',
#   'comunicación',
#   'inalámbrica',
#   'aunado',
#   'ocasiones',
#   'necesita',
#   'colocar',
#   'sensores',
#   'lugares',
#   'difícil',
#   'acceso',
#   'así',
#   'formar',
#   'red',
#   'sensores',
#   'buscar',
#   'mayor',
#   'exactitud',
#   'anterior',
#   'involucra',
#   'sistema',
#   'adquisición',
#   'limitado',
#   'número',
#   'canales',
#   'caso',
#   'requerir',
#   'mayor',
#   'cantidad',
#   'sensores',
#   'necesitará',
#   'varios',
#   'sistemas',
#   'adquisición',
#   'necesario',
#   'entonces',
#   'estudiar',
#   'técnicas',
#   'actuales',
#   'sensado',
#   'emplean',
#   'diferentes',
#   'tipos',
#   'fibras',
#   'ópticas',
#   'estándar',
#   'dopadas',
#   'tierras',
#   'raras',
#   'empleo',
#   'métodos',
#   'menos',
#   'complejos',
#   'permitan',
#   'sensado'],
#  'Problema34': ['visin',
#   'artificial',
#   'segmentacin',
#   'imgenes',
#   'proceso',
#   'particin',
#   'imagen',
#   'digital',
#   'mltiples',
#   'segmentos',
#   'conjuntos',
#   'pxeles',
#   'tambin',
#   'conocidos',
#   'superpxeles',
#   'objetivo',
#   'segmentacin',
#   'simplificar',
#   'cambiar',
#   'representacin',
#   'imagen',
#   'ms',
#   'significativo',
#   'fcil',
#   'analizar',
#   'segmentacin',
#   'imgenes',
#   'utiliza',
#   'normalmente',
#   'localizar',
#   'objetos',
#   'bordes',
#   'regiones',
#   'lneas',
#   'curvas',
#   'etc',
#   'imgenes',
#   'ms',
#   'precisamente',
#   'segmentacin',
#   'imgenes',
#   'proceso',
#   'asignar',
#   'etiqueta',
#   'cada',
#   'pxel',
#   'imagen',
#   'modo',
#   'pxeles',
#   'misma',
#   'etiqueta',
#   'comparten',
#   'ciertas',
#   'caractersticas',
#   'comunes',
#   'resultado',
#   'segmentacin',
#   'conjunto',
#   'segmentos',
#   'cubren',
#   'colectivamente',
#   'toda',
#   'imagen',
#   'conjunto',
#   'contornos',
#   'extrados',
#   'imagen',
#   'ver',
#   'deteccin',
#   'bordes',
#   'cada',
#   'pxeles',
#   'regin',
#   'similar',
#   'respecto',
#   'alguna',
#   'caracterstica',
#   'propiedad',
#   'calculada',
#   'color',
#   'intensidad',
#   'textura',
#   'regiones',
#   'adyacentes',
#   'significativamente',
#   'diferentes',
#   'respecto',
#   'misma',
#   'caracterstica',
#   's',
#   'segmentacin',
#   'imagen',
#   'consiste',
#   'particin',
#   'dicha',
#   'imagen',
#   'diferentes',
#   'regiones',
#   'similares',
#   'alguna',
#   'caracterstica',
#   'predefinida',
#   'seres',
#   'humanos',
#   'usamos',
#   'sentido',
#   'visual',
#   'separar',
#   'entorno',
#   'inmediato',
#   'objetos',
#   'distintos',
#   'esfuerzo',
#   'alguno',
#   'reconocerlos',
#   'guiar',
#   'movimientos',
#   'casi',
#   'todas',
#   'actividades',
#   'vida',
#   'kn',
#   'plataniotis',
#   'anvenetsanopoulos',
#   'p',
#   'traducido',
#   'segmentacin',
#   'caracterstica',
#   'importante',
#   'percepcin',
#   'visual',
#   'humana',
#   'manifiesta',
#   'forma',
#   'espontnea',
#   'natural',
#   'aunque',
#   'estn',
#   'involucrados',
#   'procesos',
#   'complejos',
#   'anlisis',
#   'color',
#   'forma',
#   'movimiento',
#   'textura',
#   'etc',
#   'color',
#   'caracterstica',
#   'visual',
#   'poderosa',
#   'robusta',
#   'diferenciar',
#   'diferentes',
#   'objetos',
#   'imagen',
#   'importante',
#   'fuente',
#   'informacin',
#   'proceso',
#   'segmentacin',
#   'puede',
#   'casos',
#   'ser',
#   'utilizado',
#   'nica',
#   'caracterstica',
#   'nico',
#   'descriptor',
#   'segmentacin',
#   'objetos',
#   'inters',
#   'trabajo',
#   'tesis',
#   'busca',
#   'investigar',
#   'mtodo',
#   'propio',
#   'segmentacin',
#   'color',
#   'imgenes',
#   'color',
#   'mtodo',
#   'slo',
#   'utiliza',
#   'informacin',
#   'color',
#   'realizar',
#   'segmentacin',
#   'considera',
#   'indispensable',
#   'paso',
#   'previo',
#   'reconocimiento',
#   'trabajo',
#   'pretende',
#   'llegar',
#   'reconocimiento',
#   'objetos',
#   'clases',
#   'objetos',
#   'sino',
#   'nicamente',
#   'segmentacin',
#   'imagen',
#   'regiones',
#   'homogneas',
#   'color',
#   'podran',
#   'ser',
#   'utilizadas',
#   'alimentar',
#   'tareas']}

# %% [markdown]
# ## Select a specific number of vectors to work with

# %%
TSU_structured = getNVector(len(TSU_structured), TSU_structured)
Lic_structured = getNVector(len(Lic_structured), Lic_structured)
Masters_structured = getNVector(len(Masters_structured), Masters_structured)
Phd_structured = getNVector(len(Phd_structured), Phd_structured)

len(TSU_structured)
len(Lic_structured)
len(Masters_structured)
len(Phd_structured)
# Out:
# 33

# %% [markdown]
# ## Divide our data in eighty and twenty percent (This in order to have some experimental data)

# %%
twenty_TSU, eighty_TSU = divideEightyTwenty(TSU_structured)
twenty_Lic, eighty_Lic = divideEightyTwenty(Lic_structured)
twenty_Masters, eighty_Masters = divideEightyTwenty(Masters_structured)
twenty_Phd, eighty_Phd = divideEightyTwenty(Phd_structured)

len(twenty_TSU)
len(eighty_TSU)
len(twenty_Lic)
len(eighty_Lic)
len(twenty_Masters)
len(eighty_Masters)
len(twenty_Phd)
len(eighty_Phd)
# Out:
# 26

# %% [markdown]
# ## Obtain the Relative Frequency

# %%
twentyRFTSU = relFreq(twenty_TSU)
eightyRFTSU = relFreq(eighty_TSU)
twentyRFLic = relFreq(twenty_Lic)
eightyRFLic = relFreq(eighty_Lic)
twentyRFMasters = relFreq(twenty_Masters)
eightyRFMasters = relFreq(eighty_Masters)
twentyRFPhd = relFreq(twenty_Phd)
eightyRFPhd = relFreq(eighty_Phd)

len(twentyRFTSU)
len(eightyRFTSU)
len(twentyRFLic)
len(eightyRFLic)
len(twentyRFMasters)
len(eightyRFMasters)
len(twentyRFPhd)
len(eightyRFPhd)
# Out:
# 26

# %% [markdown]
# ## Most Common Spanish Words

# %%
mostCommonDic = mostCommon()
mostCommonDic
# Out:
# {'Frec.absoluta': 'Frec.normalizada',
#  'de': '9999518',
#  'la': '6277560',
#  'que': '4681839',
#  'el': '4569652',
#  'en': '4234281',
#  'y': '4180279',
#  'a': '3260939',
#  'los': '2618657',
#  'se': '2022514',
#  'del': '1857225',
#  'las': '1686741',
#  'un': '1659827',
#  'por': '1561904',
#  'con': '1481607',
#  'no': '1465503',
#  'una': '1347603',
#  'su': '1103617',
#  'para': '1062152',
#  'es': '1019669',
#  'al': '951054',
#  'lo': '866955',
#  'como': '773465',
#  'más': '661696',
#  'o': '542284',
#  'pero': '450512',
#  'sus': '449870',
#  'le': '413241',
#  'ha': '380339',
#  'me': '374368',
#  'si': '327480',
#  'sin': '298383',
#  'sobre': '289704',
#  'este': '285461',
#  'ya': '274177',
#  'entre': '267493',
#  'cuando': '257272',
#  'todo': '247340',
#  'esta': '238841',
#  'ser': '232924',
#  'son': '232415',
#  'dos': '228439',
#  'también': '227411',
#  'fue': '223791',
#  'había': '223430',
#  'era': '219933',
#  'muy': '208540',
#  'años': '203027',
#  'hasta': '202935',
#  'desde': '198647',
#  'está': '194168',
#  'mi': '186360',
#  'porque': '185700',
#  'qué': '184956',
#  'sólo': '170552',
#  'han': '169718',
#  'yo': '167684',
#  'hay': '164940',
#  'vez': '163538',
#  'puede': '161219',
#  'todos': '158168',
#  'así': '155645',
#  'nos': '154412',
#  'ni': '153451',
#  'parte': '148750',
#  'tiene': '147274',
#  'él': '139080',
#  'uno': '136020',
#  'donde': '132077',
#  'bien': '130957',
#  'tiempo': '130896',
#  'mismo': '130746',
#  'ese': '127976',
#  'ahora': '125661',
#  'cada': '124558',
#  'e': '123729',
#  'vida': '123491',
#  'otro': '121983',
#  'después': '121746',
#  'te': '120052',
#  'otros': '119500',
#  'aunque': '115556',
#  'esa': '115377',
#  'eso': '114523',
#  'hace': '114507',
#  'otra': '113982',
#  'gobierno': '113011',
#  'tan': '112471',
#  'durante': '112020',
#  'siempre': '111557',
#  'día': '110921',
#  'tanto': '110679',
#  'ella': '110620',
#  'tres': '109542',
#  'sí': '108631',
#  'dijo': '108471',
#  'sido': '107352',
#  'gran': '106991',
#  'país': '104568',
#  'según': '104204',
#  'menos': '103498',
#  'mundo': '101745',
#  'año': '100790',
#  'antes': '100761',
#  'estado': '100757',
#  'contra': '100403',
#  'sino': '98145',
#  'forma': '97165',
#  'caso': '96979',
#  'nada': '96340',
#  'hacer': '96063',
#  'general': '95768',
#  'estaba': '93607',
#  'poco': '92205',
#  'estos': '91398',
#  'presidente': '91350',
#  'mayor': '90166',
#  'ante': '87990',
#  'unos': '86747',
#  'les': '86363',
#  'algo': '85999',
#  'hacia': '85122',
#  'casa': '85064',
#  'ellos': '84636',
#  'ayer': '84310',
#  'hecho': '83898',
#  'primera': '83428',
#  'mucho': '83240',
#  'mientras': '82630',
#  'además': '82576',
#  'quien': '82555',
#  'momento': '82132',
#  'millones': '81999',
#  'esto': '81979',
#  'españa': '80195',
#  'hombre': '80152',
#  'están': '79844',
#  'pues': '79642',
#  'hoy': '78479',
#  'lugar': '78250',
#  'madrid': '77837',
#  'nacional': '77541',
#  'trabajo': '77478',
#  'otras': '77428',
#  'mejor': '77315',
#  'nuevo': '77262',
#  'decir': '76867',
#  'algunos': '76107',
#  'entonces': '75706',
#  'todas': '75517',
#  'días': '75144',
#  'debe': '74229',
#  'política': '73464',
#  'cómo': '73100',
#  'casi': '72965',
#  'toda': '72248',
#  'tal': '71419',
#  'luego': '70522',
#  'pasado': '70484',
#  'primer': '69918',
#  'medio': '69273',
#  'va': '69098',
#  'estas': '69071',
#  'sea': '68921',
#  'tenía': '67093',
#  'nunca': '66939',
#  'poder': '66900',
#  'aquí': '66821',
#  'ver': '66479',
#  'veces': '66441',
#  'embargo': '66116',
#  'partido': '65492',
#  'personas': '65410',
#  'grupo': '65390',
#  'cuenta': '65368',
#  'pueden': '63889',
#  'tienen': '63652',
#  'misma': '63462',
#  'nueva': '63427',
#  'cual': '62309',
#  'fueron': '62220',
#  'mujer': '61936',
#  'frente': '61469',
#  'josé': '61080',
#  'tras': '60064',
#  'cosas': '59580',
#  'fin': '59108',
#  'ciudad': '59049',
#  'he': '58965',
#  'social': '58484',
#  'manera': '58134',
#  'tener': '58029',
#  'sistema': '57810',
#  'será': '57808',
#  'historia': '57791',
#  'muchos': '57523',
#  'juan': '57204',
#  'tipo': '56606',
#  'cuatro': '56570',
#  'dentro': '56565',
#  'nuestro': '56307',
#  'punto': '56259',
#  'dice': '56253',
#  'ello': '55768',
#  'cualquier': '55361',
#  'noche': '55281',
#  'aún': '54761',
#  'agua': '54702',
#  'parece': '54554',
#  'haber': '54150',
#  'situación': '54020',
#  'fuera': '53979',
#  'bajo': '53243',
#  'grandes': '52362',
#  'nuestra': '52321',
#  'ejemplo': '51803',
#  'acuerdo': '51485',
#  'habían': '50397',
#  'usted': '50073',
#  'estados': '49814',
#  'hizo': '49733',
#  'nadie': '49689',
#  'países': '49445',
#  'horas': '49389',
#  'posible': '49082',
#  'tarde': '48963',
#  'ley': '48945',
#  'importante': '48397',
#  'guerra': '48391',
#  'desarrollo': '48378',
#  'proceso': '48064',
#  'realidad': '47650',
#  'sentido': '47559',
#  'lado': '47315',
#  'mí': '47248',
#  'tu': '47057',
#  'cambio': '46814',
#  'allí': '46771',
#  'mano': '46657',
#  'eran': '46367',
#  'estar': '46282',
#  'san': '46004',
#  'número': '45985',
#  'sociedad': '45974',
#  'unas': '45565',
#  'centro': '45456',
#  'padre': '45236',
#  'gente': '45235',
#  'final': '44920',
#  'relación': '44617',
#  'cuerpo': '44470',
#  'obra': '44308',
#  'incluso': '44285',
#  'través': '44212',
#  'último': '44086',
#  'madre': '43697',
#  'mis': '43564',
#  'modo': '43478',
#  'problemas': '43295',
#  'cinco': '43283',
#  'carlos': '42834',
#  'hombres': '42544',
#  'información': '42423',
#  'ojos': '42371',
#  'muerte': '42341',
#  'nombre': '42284',
#  'algunas': '42223',
#  'público': '42201',
#  'mujeres': '42094',
#  'siglo': '41890',
#  'todavía': '41792',
#  'meses': '41650',
#  'mañana': '41368',
#  'esos': '41184',
#  'nosotros': '40870',
#  'hora': '40581',
#  'muchas': '40566',
#  'pueblo': '40425',
#  'alguna': '40406',
#  'dar': '40396',
#  'problema': '40295',
#  'don': '40224',
#  'da': '40191',
#  'tú': '40119',
#  'derecho': '39939',
#  'verdad': '39924',
#  'maría': '39812',
#  'unidos': '39806',
#  'podría': '39797',
#  'sería': '39731',
#  'junto': '39521',
#  'cabeza': '39451',
#  'aquel': '39377',
#  'luis': '39370',
#  'cuanto': '38519',
#  'tierra': '38352',
#  'equipo': '38214',
#  'segundo': '38160',
#  'director': '38096',
#  'dicho': '38074',
#  'cierto': '37979',
#  'casos': '37796',
#  'manos': '37736',
#  'nivel': '37419',
#  'podía': '37403',
#  'familia': '37376',
#  'largo': '37315',
#  'partir': '37278',
#  'falta': '37196',
#  'llegar': '37054',
#  'propio': '36979',
#  'ministro': '36337',
#  'cosa': '36267',
#  'primero': '36232',
#  'seguridad': '36054',
#  'hemos': '35988',
#  'mal': '35964',
#  'trata': '35744',
#  'algún': '35564',
#  'tuvo': '35490',
#  'respecto': '35394',
#  'semana': '35354',
#  'varios': '35315',
#  'real': '35222',
#  'sé': '35154',
#  'voz': '34982',
#  'paso': '34921',
#  'señor': '34905',
#  'mil': '34834',
#  'quienes': '34743',
#  'proyecto': '34716',
#  'mercado': '34677',
#  'mayoría': '34634',
#  'luz': '34617',
#  'claro': '34589',
#  'iba': '34380',
#  'éste': '34338',
#  'pesetas': '34204',
#  'orden': '33982',
#  'español': '33920',
#  'buena': '33759',
#  'quiere': '33735',
#  'aquella': '33723',
#  'programa': '33620',
#  'palabras': '33485',
#  'internacional': '33448',
#  'van': '33398',
#  'esas': '33382',
#  'segunda': '33363',
#  'empresa': '33301',
#  'puesto': '33254',
#  'ahí': '33248',
#  'propia': '33149',
#  'm': '33099',
#  'libro': '33056',
#  'igual': '32950',
#  'político': '32928',
#  'persona': '32756',
#  'últimos': '32689',
#  'ellas': '32635',
#  'total': '32539',
#  'creo': '32504',
#  'tengo': '32413',
#  'dios': '32373',
#  'c': '32345',
#  'española': '32140',
#  'condiciones': '32094',
#  'méxico': '32084',
#  'fuerza': '32082',
#  'solo': '32010',
#  'único': '31999',
#  'acción': '31789',
#  'amor': '31690',
#  'policía': '31598',
#  'puerta': '31503',
#  'pesar': '31436',
#  'zona': '31365',
#  'sabe': '31358',
#  'calle': '31330',
#  'interior': '31198',
#  'tampoco': '31014',
#  'música': '30968',
#  'ningún': '30962',
#  'vista': '30952',
#  'campo': '30775',
#  'buen': '30756',
#  'hubiera': '30754',
#  'saber': '30644',
#  'obras': '30575',
#  'razón': '30539',
#  'ex': '30522',
#  'niños': '30449',
#  'presencia': '30426',
#  'tema': '30398',
#  'dinero': '30386',
#  'comisión': '30350',
#  'antonio': '30339',
#  'servicio': '30318',
#  'hijo': '30298',
#  'última': '30269',
#  'ciento': '30146',
#  'estoy': '30136',
#  'hablar': '30127',
#  'dio': '30123',
#  'minutos': '30012',
#  'producción': '29875',
#  'camino': '29830',
#  'seis': '29812',
#  'quién': '29760',
#  'fondo': '29750',
#  'dirección': '29708',
#  'papel': '29702',
#  'demás': '29623',
#  'barcelona': '29613',
#  'idea': '29613',
#  'especial': '29458',
#  'diferentes': '29378',
#  'dado': '29292',
#  'base': '29243',
#  'capital': '29220',
#  'ambos': '29178',
#  'europa': '29171',
#  'libertad': '29119',
#  'relaciones': '29055',
#  'espacio': '28844',
#  'medios': '28828',
#  'ir': '28757',
#  'actual': '28719',
#  'población': '28668',
#  'empresas': '28653',
#  'estudio': '28640',
#  'salud': '28630',
#  'servicios': '28547',
#  'haya': '28528',
#  'principio': '28476',
#  'siendo': '28468',
#  'cultura': '28382',
#  'anterior': '28310',
#  'alto': '28306',
#  'media': '28292',
#  'mediante': '28252',
#  'primeros': '28193',
#  'arte': '28165',
#  'paz': '28159',
#  'sector': '28156',
#  'imagen': '28109',
#  'medida': '28101',
#  'deben': '28008',
#  'datos': '28003',
#  'consejo': '27968',
#  'personal': '27930',
#  'interés': '27919',
#  'julio': '27919',
#  'grupos': '27863',
#  'miembros': '27843',
#  'ninguna': '27822',
#  'existe': '27779',
#  'cara': '27756',
#  'edad': '27731',
#  'etc': '27709',
#  'movimiento': '27696',
#  'visto': '27677',
#  'llegó': '27556',
#  'puntos': '27488',
#  'actividad': '27283',
#  'bueno': '27256',
#  'uso': '27235',
#  'niño': '27157',
#  'difícil': '27109',
#  'joven': '27024',
#  'futuro': '26989',
#  'aquellos': '26975',
#  'mes': '26958',
#  'pronto': '26934',
#  'soy': '26903',
#  'hacía': '26850',
#  'nuevos': '26828',
#  'nuestros': '26789',
#  'estaban': '26694',
#  'posibilidad': '26611',
#  'sigue': '26580',
#  'cerca': '26495',
#  'resultados': '26413',
#  'educación': '26327',
#  'atención': '26299',
#  'gonzález': '26281',
#  'capacidad': '26228',
#  'efecto': '26209',
#  'necesario': '26149',
#  'valor': '26106',
#  'aire': '26060',
#  'investigación': '26001',
#  'siguiente': '25891',
#  'figura': '25859',
#  'central': '25780',
#  'comunidad': '25745',
#  'necesidad': '25699',
#  'serie': '25677',
#  'organización': '25647',
#  'nuevas': '25638',
#  'calidad': '25597',
#  'economía': '25553',
#  'carácter': '25528',
#  'jefe': '25526',
#  'estamos': '25495',
#  'prensa': '25472',
#  'control': '25219',
#  'sociales': '25197',
#  'universidad': '25155',
#  'militar': '25150',
#  'cabo': '25125',
#  'diez': '25114',
#  'fuerzas': '25106',
#  'congreso': '25073',
#  'ésta': '25041',
#  'hijos': '24995',
#  'justicia': '24983',
#  'mundial': '24963',
#  'dólares': '24939',
#  'juego': '24922',
#  'económica': '24845',
#  'políticos': '24824',
#  'duda': '24821',
#  'recursos': '24800',
#  'pública': '24775',
#  'crisis': '24760',
#  'próximo': '24728',
#  'tenemos': '24716',
#  'decisión': '24685',
#  'varias': '24657',
#  'popular': '24543',
#  'tenido': '24472',
#  'apenas': '24440',
#  'época': '24358',
#  'banco': '24341',
#  'presente': '24211',
#  'menor': '24142',
#  'quiero': '24054',
#  'pasar': '24048',
#  'resultado': '24030',
#  'televisión': '23938',
#  'encuentra': '23833',
#  'gracias': '23794',
#  'ministerio': '23781',
#  'conjunto': '23735',
#  'defensa': '23717',
#  'alguien': '23626',
#  'queda': '23600',
#  'hacen': '23508',
#  'pasa': '23503',
#  'resto': '23366',
#  'causa': '23283',
#  'seguir': '23261',
#  'allá': '23155',
#  'palabra': '23090',
#  'voy': '23067',
#  'cuya': '23048',
#  'vamos': '23036',
#  'mar': '23022',
#  'estudios': '23011',
#  'derechos': '22989',
#  'importancia': '22969',
#  'cuales': '22961',
#  'contrario': '22957',
#  'manuel': '22924',
#  'garcía': '22851',
#  'fuerte': '22828',
#  'sol': '22823',
#  'jóvenes': '22791',
#  'apoyo': '22776',
#  'habría': '22760',
#  'civil': '22758',
#  'miguel': '22755',
#  'pedro': '22738',
#  'partidos': '22728',
#  'libre': '22640',
#  'fuentes': '22592',
#  'administración': '22536',
#  'común': '22536',
#  'dejar': '22499',
#  'cine': '22492',
#  'salir': '22447',
#  'comunicación': '22434',
#  'b': '22407',
#  'experiencia': '22402',
#  'demasiado': '22378',
#  'plan': '22279',
#  'respuesta': '22259',
#  'energía': '22241',
#  'izquierda': '22232',
#  'función': '22148',
#  'principal': '22074',
#  'superior': '22014',
#  'naturaleza': '22002',
#  'podemos': '21958',
#  'unión': '21933',
#  'especialmente': '21931',
#  'rey': '21907',
#  'domingo': '21823',
#  'favor': '21818',
#  'cantidad': '21812',
#  'elecciones': '21781',
#  'clase': '21733',
#  'productos': '21731',
#  'españoles': '21693',
#  'conocer': '21681',
#  'teatro': '21663',
#  'importantes': '21597',
#  'evitar': '21587',
#  'color': '21575',
#  'actividades': '21564',
#  'mesa': '21558',
#  'p': '21518',
#  'decía': '21458',
#  'cuyo': '21444',
#  'debido': '21378',
#  'alta': '21377',
#  'francisco': '21361',
#  'secretario': '21351',
#  'objeto': '21336',
#  'quizá': '21323',
#  'posición': '21168',
#  'parecía': '21152',
#  'natural': '21146',
#  'elementos': '21133',
#  'hubo': '21112',
#  'objetivo': '21097',
#  'formas': '21083',
#  'única': '21076',
#  'pueda': '21061',
#  'origen': '21055',
#  'blanco': '21035',
#  'mismos': '21006',
#  'lleva': '20947',
#  'económico': '20927',
#  'opinión': '20927',
#  'ayuda': '20918',
#  'oficial': '20905',
#  'silencio': '20896',
#  'buenos': '20881',
#  'pensar': '20880',
#  'república': '20854',
#  'dónde': '20846',
#  'sangre': '20798',
#  'encuentro': '20719',
#  'siquiera': '20708',
#  'autor': '20676',
#  'reunión': '20609',
#  'haciendo': '20582',
#  'suelo': '20565',
#  'muestra': '20563',
#  'viejo': '20558',
#  'encima': '20522',
#  'resulta': '20497',
#  'tomar': '20492',
#  'bastante': '20488',
#  'siete': '20483',
#  'lucha': '20434',
#  'pudo': '20404',
#  'amigos': '20369',
#  'línea': '20338',
#  'sur': '20334',
#  'pocos': '20289',
#  'medidas': '20225',
#  'norte': '20173',
#  'partes': '20137',
#  'iglesia': '20101',
#  'tratamiento': '20030',
#  'existencia': '19997',
#  'cargo': '19935',
#  'grande': '19882',
#  'américa': '19874',
#  'boca': '19829',
#  'plaza': '19792',
#  'pie': '19780',
#  'trabajadores': '19723',
#  'poner': '19722',
#  'existen': '19634',
#  'viene': '19630',
#  'permite': '19607',
#  'análisis': '19554',
#  'argentina': '19553',
#  'acto': '19520',
#  'hechos': '19465',
#  'tiempos': '19394',
#  'políticas': '19285',
#  'radio': '19271',
#  'puedo': '19230',
#  'crecimiento': '19202',
#  'francia': '19193',
#  'compañía': '19178',
#  'amigo': '19176',
#  'autoridades': '19175',
#  'realizar': '19166',
#  'acciones': '19075',
#  'padres': '19075',
#  'diario': '19064',
#  've': '19059',
#  'derecha': '19049',
#  'ambiente': '19000',
#  'i': '18980',
#  'habrá': '18951',
#  'precisamente': '18930',
#  'enfermedad': '18927',
#  'especie': '18903',
#  'ejército': '18900',
#  'santa': '18890',
#  'cambios': '18886',
#  'río': '18885',
#  'sabía': '18873',
#  'seguro': '18856',
#  'espera': '18850',
#  'momentos': '18847',
#  'viaje': '18834',
#  'quería': '18827',
#  'ocho': '18818',
#  'vivir': '18817',
#  'región': '18771',
#  'formación': '18743',
#  'escuela': '18722',
#  'cuarto': '18721',
#  'valores': '18677',
#  'quedó': '18674',
#  'participación': '18598',
#  'éxito': '18595',
#  'baja': '18542',
#  'artículo': '18504',
#  'principales': '18490',
#  'fernando': '18468',
#  'metros': '18468',
#  'marcha': '18427',
#  'régimen': '18382',
#  'consecuencia': '18358',
#  'conocimiento': '18346',
#  'corazón': '18331',
#  'campaña': '18261',
#  'estructura': '18261',
#  'efectos': '18253',
#  'finalmente': '18231',
#  'modelo': '18221',
#  'carta': '18218',
#  'construcción': '18098',
#  'médico': '18083',
#  'miedo': '18049',
#  'mayores': '17976',
#  'entrada': '17955',
#  'humanos': '17917',
#  'sean': '17892',
#  'actitud': '17843',
#  'deja': '17838',
#  'dejó': '17827',
#  'd': '17810',
#  'llevar': '17798',
#  'negro': '17774',
#  'texto': '17714',
#  'mitad': '17705',
#  'estuvo': '17681',
#  'alrededor': '17639',
#  'acerca': '17598',
#  'peso': '17589',
#  'humano': '17581',
#  'pequeño': '17577',
#  'fecha': '17551',
#  'serán': '17529',
#  'doctor': '17526',
#  'ideas': '17495',
#  'vino': '17491',
#  'materia': '17468',
#  'llega': '17456',
#  'carrera': '17451',
#  'cierta': '17389',
#  'sola': '17362',
#  'psoe': '17360',
#  'lejos': '17339',
#  'juez': '17328',
#  'características': '17307',
#  'riesgo': '17271',
#  'fácil': '17205',
#  'diferencia': '17178',
#  'cultural': '17164',
#  'libros': '17146',
#  'práctica': '17142',
#  'mayo': '17123',
#  'nuestras': '17121',
#  'programas': '17118',
#  'memoria': '17083',
#  'llegado': '17052',
#  'plazo': '16976',
#  'expresión': '16966',
#  'diciembre': '16954',
#  'mantener': '16948',
#  'enero': '16929',
#  'volver': '16898',
#  'cuadro': '16891',
#  'producto': '16851',
#  'produce': '16845',
#  'europea': '16842',
#  'conciencia': '16829',
#  'tenían': '16811',
#  'atrás': '16786',
#  'felipe': '16782',
#  'creación': '16777',
#  'chile': '16768',
#  'precio': '16767',
#  'película': '16761',
#  'puerto': '16749',
#  'fuego': '16685',
#  'cuestión': '16666',
#  'pasó': '16644',
#  'costa': '16638',
#  'supuesto': '16637',
#  'local': '16607',
#  'habla': '16597',
#  'aspectos': '16569',
#  'cuba': '16565',
#  'sala': '16524',
#  'cámara': '16523',
#  'vuelta': '16521',
#  'vía': '16508',
#  'mirada': '16481',
#  'mejores': '16443',
#  'informe': '16436',
#  'unidad': '16427',
#  'distintos': '16415',
#  'suerte': '16390',
#  'tales': '16386',
#  'mira': '16334',
#  'llamado': '16312',
#  'técnica': '16308',
#  'título': '16308',
#  's': '16293',
#  'principios': '16282',
#  'octubre': '16228',
#  'volvió': '16207',
#  'período': '16199',
#  'g': '16194',
#  'encontrar': '16166',
#  'democracia': '16159',
#  'aumento': '16145',
#  'fútbol': '16137',
#  'prueba': '16113',
#  'consumo': '16095',
#  'pese': '16043',
#  'ocasiones': '16026',
#  'exterior': '15988',
#  'solución': '15967',
#  'u': '15967',
#  'hija': '15958',
#  'sueño': '15944',
#  'parís': '15929',
#  'capaz': '15925',
#  'ocasión': '15924',
#  'industria': '15902',
#  'adelante': '15900',
#  'salida': '15899',
#  'ciencia': '15885',
#  'asunto': '15844',
#  'asociación': '15835',
#  'puso': '15831',
#  'intereses': '15830',
#  'oro': '15811',
#  'podrá': '15804',
#  'pregunta': '15741',
#  'oposición': '15736',
#  'entrar': '15711',
#  'señora': '15705',
#  'señaló': '15699',
#  'santiago': '15697',
#  'dolor': '15685',
#  'zonas': '15679',
#  'comercio': '15637',
#  'operación': '15633',
#  'tribunal': '15609',
#  'instituciones': '15606',
#  'temas': '15569',
#  'militares': '15566',
#  'junio': '15555',
#  'marco': '15548',
#  'sectores': '15541',
#  'hacerlo': '15539',
#  'aspecto': '15528',
#  'razones': '15527',
#  'contenido': '15481',
#  'juicio': '15481',
#  'electoral': '15465',
#  'considera': '15460',
#  'tendrá': '15431',
#  'mucha': '15397',
#  'voluntad': '15394',
#  'dicen': '15383',
#  'recuerdo': '15382',
#  'socialista': '15371',
#  'área': '15369',
#  'aparece': '15367',
#  'vio': '15334',
#  'cama': '15328',
#  'aun': '15317',
#  'presenta': '15315',
#  'pp': '15293',
#  'revolución': '15285',
#  'busca': '15280',
#  'abril': '15278',
#  'rodríguez': '15272',
#  'fiscal': '15265',
#  'lópez': '15245',
#  'victoria': '15241',
#  'violencia': '15235',
#  'primeras': '15226',
#  'pequeña': '15214',
#  'armas': '15153',
#  'debía': '15149',
#  'ii': '15123',
#  'esfuerzo': '15109',
#  'humana': '15107',
#  'posibilidades': '15090',
#  'centros': '15076',
#  'profesional': '15075',
#  'asimismo': '15048',
#  'grado': '15048',
#  'has': '15027',
#  'toma': '15003',
#  'distintas': '14926',
#  'material': '14915',
#  'carne': '14905',
#  'llama': '14903',
#  'particular': '14876',
#  'jorge': '14867',
#  'trabajar': '14837',
#  'propuesta': '14830',
#  'muerto': '14816',
#  'precios': '14809',
#  'reforma': '14779',
#  'hermano': '14736',
#  'corte': '14735',
#  'comenzó': '14733',
#  'etapa': '14716',
#  'obstante': '14695',
#  'pone': '14685',
#  'diversos': '14671',
#  'visita': '14660',
#  'concepto': '14657',
#  'pacientes': '14637',
#  'semanas': '14603',
#  'tipos': '14592',
#  'solamente': '14520',
#  'deseo': '14499',
#  'sistemas': '14484',
#  'encuentran': '14482',
#  'siguientes': '14475',
#  'martín': '14429',
#  'suficiente': '14414',
#  'marzo': '14408',
#  'propios': '14404',
#  'jamás': '14371',
#  'dan': '14364',
#  'club': '14359',
#  'instituto': '14354',
#  'constitución': '14299',
#  'curso': '14290',
#  'lenguaje': '14270',
#  'estilo': '14237',
#  'rosa': '14180',
#  'imposible': '14178',
#  'pablo': '14152',
#  'buscar': '14151',
#  'peor': '14145',
#  'piel': '14128',
#  'arriba': '14085',
#  'generales': '14073',
#  'septiembre': '14072',
#  'blanca': '14061',
#  'r': '14041',
#  'aquellas': '13996',
#  'teoría': '13935',
#  'animales': '13916',
#  'hicieron': '13913',
#  'larga': '13908',
#  'perdido': '13890',
#  'imágenes': '13887',
#  'paciente': '13885',
#  'conseguir': '13871',
#  'máximo': '13855',
#  'noviembre': '13848',
#  'j': '13831',
#  'líder': '13830',
#  'hospital': '13823',
#  'diversas': '13816',
#  'rafael': '13804',
#  'vuelve': '13799',
#  'destino': '13783',
#  'torno': '13781',
#  'proyectos': '13773',
#  'flores': '13763',
#  'niveles': '13759',
#  'afirmó': '13758',
#  'explicó': '13751',
#  'n': '13748',
#  'somos': '13727',
#  'términos': '13719',
#  'premio': '13701',
#  ...}

# %% [markdown]
# ## Obtain the Log of the Common Value

# %%
twentyLFTSU = logFreq(twenty_TSU, mostCommonDic)
eightyLFTSU = logFreq(eighty_TSU, mostCommonDic)
twentyLFLic = logFreq(twenty_Lic, mostCommonDic)
eightyLFLic = logFreq(eighty_Lic, mostCommonDic)
twentyLFMasters = logFreq(twenty_Masters, mostCommonDic)
eightyLFMasters = logFreq(eighty_Masters, mostCommonDic)
twentyLFPhd = logFreq(twenty_Phd, mostCommonDic)
eightyLFPhd = logFreq(eighty_Phd, mostCommonDic)

twentyLFTSU
eightyLFTSU
twentyLFLic
eightyLFLic
twentyLFMasters
eightyLFMasters
twentyLFPhd
eightyLFPhd
# Out:
# {'Problema9': {'minería': 0.0,
#   'texto': 9.782110566369528,
#   'área': 9.640107772607312,
#   'investigación': 10.165890277802454,
#   'reciente': 0.0,
#   'procesamiento': 0.0,
#   'textos': 0.0,
#   'define': 0.0,
#   'proceso': 10.780288735123806,
#   'descubrimiento': 0.0,
#   'patrones': 0.0,
#   'interesantes': 0.0,
#   'colección': 0.0,
#   'deben': 10.240245462634501,
#   'existir': 0.0,
#   'explícitamente': 0.0,
#   'ningún': 10.34051592510041,
#   'surgir': 0.0,
#   'relacionar': 0.0,
#   'contenido': 9.647368744540465,
#   'varios': 10.472063081843023,
#   'hearst': 0.0,
#   'kodratoff': 0.0,
#   'consiste': 0.0,
#   'dos': 12.339024495252145,
#   'etapas': 0.0,
#   'principales': 9.82498532438117,
#   'etapa': 9.596690616224665,
#   'preprocesamiento': 0.0,
#   'tan': 11.630450689618431,
#   'primera': 11.331739263416525,
#   'transforman': 0.0,
#   'algún': 10.47908916924103,
#   'tipo': 10.94387026564006,
#   'representación': 0.0,
#   'estructurada': 0.0,
#   'semiestructurada': 0.0,
#   'facilite': 0.0,
#   'posterior': 0.0,
#   'análisis': 9.880935148065616,
#   'mientras': 11.32212808969523,
#   'segunda': 10.415202780486952,
#   'representaciones': 0.0,
#   'intermedias': 0.0,
#   'analizan': 0.0,
#   'objetivo': 9.956886129260823,
#   'descubrir': 0.0,
#   'nuevos': 10.197201397219628,
#   'conocimiento': 9.8171668460696,
#   'entonces': 11.234612696522394,
#   'dependiendo': 0.0,
#   'métodos': 0.0,
#   'aplicados': 0.0,
#   'construidas': 0.0,
#   'función': 10.005502477942859,
#   'dicha': 0.0,
#   'usados': 0.0,
#   'consecuencia': 9.817820725779036,
#   'descubiertos': 0.0,
#   'figura': 10.160413981817907,
#   'muestra': 9.931248623321519,
#   'estrategias': 0.0,
#   'usadas': 0.0,
#   'actuales': 0.0,
#   'sistemas': 9.580799870885532,
#   'acuerdo': 10.849045782090851,
#   'mayoría': 10.452591137512096,
#   'limitan': 0.0,
#   'resultados': 10.181611592175802,
#   'nivel': 10.52993387579382,
#   'temático': 0.0,
#   'entidad': 0.0,
#   'imposibilitan': 0.0,
#   'cosas': 10.995075226267273,
#   'detalladas': 0.0,
#   'consensos': 0.0,
#   'ejemplo': 10.855203341628478,
#   'respondan': 0.0,
#   'preguntas': 0.0,
#   'cuál': 0.0,
#   'opinión': 9.94879547024067,
#   'mayoritaria': 0.0,
#   'mexicanos': 0.0,
#   'gobierno': 11.635240438089491,
#   'fox': 0.0,
#   'tendencias': 0.0,
#   'indiquen': 0.0,
#   'si': 12.699182263490384,
#   'existido': 0.0,
#   'variaciones': 0.0,
#   'postura': 0.0,
#   'respecto': 10.47429759323113,
#   'educación': 10.17835030752565,
#   'desviaciones': 0.0,
#   'identifiquen': 0.0,
#   'opiniones': 0.0,
#   'raras': 0.0,
#   'desempeño': 0.0,
#   'selección': 0.0,
#   'mexicana': 0.0,
#   'fútbol': 9.688870050941352,
#   'idea': 10.295968733085997,
#   'mejorar': 0.0,
#   'expresividad': 0.0,
#   'diversidad': 0.0,
#   'descubrimientos': 0.0,
#   'usar': 0.0,
#   'completa': 0.0,
#   'actualmente': 0.0,
#   'siguiendo': 0.0,
#   'enfoque': 0.0,
#   'propone': 0.0,
#   'grafos': 0.0,
#   'conceptuales': 0.0,
#   'sowa': 0.0,
#   'seleccionaron': 0.0,
#   'árboles': 0.0,
#   'sintácticos': 0.0,
#   'predicados': 0.0,
#   'lógicos': 0.0,
#   'klone': 0.0,
#   'siguientes': 9.580178302441196,
#   'razones': 9.65033572298117,
#   'permiten': 0.0,
#   'representar': 0.0,
#   'adecuadamente': 0.0,
#   'términos': 9.526537012326164,
#   'eficiencia': 0.0,
#   'notacional': 0.0,
#   'información': 10.655445946975886,
#   'lenguaje': 9.565914710470881,
#   'natural': 9.959206041292472,
#   'disponen': 0.0,
#   'mecanismos': 0.0,
#   'formales': 0.0,
#   'facilitan': 0.0,
#   'manipulación': 0.0,
#   'transformación': 0.0,
#   'ver': 11.104641387298265,
#   'sección': 0.0,
#   'usan': 0.0,
#   'tareas': 0.0,
#   'afines': 0.0,
#   'recuperación': 0.0,
#   'agrupamiento': 0.0,
#   'ahora': 11.741343083907129,
#   'bien': 11.782624304024536,
#   'realizar': 9.860893154903707,
#   'usando': 0.0,
#   'involucra': 0.0,
#   'problemas': 10.675792433881902,
#   'diferentes': 10.28800137389136,
#   'primer': 11.155078405801317,
#   'lugar': 11.2676641084024,
#   'segundo': 10.549543125562224,
#   'automático': 0.0,
#   'conjunto': 10.074706030985418,
#   'problema': 10.603982670758612,
#   'complejo': 0.0,
#   'vinculado': 0.0,
#   'sintáctico': 0.0,
#   'semántico': 0.0,
#   'and': 0.0,
#   'way': 0.0,
#   'debido': 9.97011763483389,
#   'ello': 10.928955507166235,
#   'existen': 9.885018036252466,
#   'enfocan': 0.0,
#   'dominio': 0.0,
#   'único': 10.373459931293572,
#   'restringido': 0.0,
#   'ejemplos': 0.0,
#   'partes': 9.910314197878405,
#   'artículos': 0.0,
#   'científicos': 0.0,
#   'myaeng': 0.0,
#   'khoo': 0.0,
#   'lópezlópez': 0.0,
#   'montesygómez': 0.0,
#   'et': 0.0,
#   'expedientes': 0.0,
#   'médicos': 0.0,
#   'baud': 0.0,
#   'rassinoux': 0.0,
#   'casos': 10.539958555902517,
#   'legales': 0.0,
#   'boucier': 0.0,
#   'rajman': 0.0,
#   'manuales': 0.0,
#   'referencia': 0.0,
#   'petermann': 0.0,
#   'parte': 11.910022323407876,
#   'orientado': 0.0,
#   'descriptivos': 0.0,
#   'conocimientos': 0.0,
#   'estudiado': 0.0,
#   'mineau': 0.0,
#   'godin': 0.0,
#   'bournaud': 0.0,
#   'ganascia': 0.0,
#   'míller': 0.0,
#   'así': 11.95533305200011,
#   'pues': 11.285296870871345,
#   'trabajo': 11.257749304074707,
#   'enfoca': 0.0,
#   'representan': 0.0,
#   'tipos': 9.588228712314113,
#   'agrupamientos': 0.0,
#   'asociaciones': 0.0},
#  'Problema10': {'objetivo': 9.956886129260823,
#   'desambiguación': 0.0,
#   'sentidos': 0.0,
#   'palabras': 10.41885285634415,
#   'determinar': 0.0,
#   'significado': 0.0,
#   'correcto': 0.0,
#   'sentido': 10.769726324511337,
#   'palabra': 10.047154902348542,
#   'dada': 0.0,
#   'contexto': 0.0,
#   'consi': 0.0,
#   'dera': 0.0,
#   'problemas': 10.675792433881902,
#   'difíciles': 0.0,
#   'nivel': 10.52993387579382,
#   'léxico': 0.0,
#   'procesamiento': 0.0,
#   'lenguaje': 9.565914710470881,
#   'natural': 9.959206041292472,
#   'fundamental': 0.0,
#   'aplicaciones': 0.0,
#   'traducción': 0.0,
#   'automática': 0.0,
#   'recuperación': 0.0,
#   'información': 10.655445946975886,
#   'etc': 10.22951254915098,
#   'dificultades': 0.0,
#   'provienen': 0.0,
#   'orígenes': 0.0,
#   'incluyendo': 0.0,
#   'falta': 10.523956507598088,
#   'medios': 10.269102416044332,
#   'formalizar': 0.0,
#   'propiedades': 0.0,
#   'parámetros': 0.0,
#   'caracterizan': 0.0,
#   'uso': 10.212258189817774,
#   'pa': 0.0,
#   'labra': 0.0,
#   'ambigua': 0.0,
#   'particular': 9.60750445504496,
#   'inventario': 0.0,
#   'usuales': 0.0,
#   'enfoques': 0.0,
#   'existen': 9.885018036252466,
#   'wsd': 0.0,
#   'aprendizaje': 0.0,
#   'supervisado': 0.0,
#   'exitoso': 0.0,
#   'fecha': 9.77286620732769,
#   'emplea': 0.0,
#   'corpus': 0.0,
#   'cada': 11.732526749860027,
#   'ocurrencia': 0.0,
#   'w': 0.0,
#   'manualmente': 0.0,
#   'anotada': 0.0,
#   'acuer': 0.0,
#   'do': 0.0,
#   'existencia': 9.903337541285003,
#   'diccionario': 0.0,
#   'forma': 11.484165843298804,
#   'sirve': 0.0,
#   'material': 9.61012269694885,
#   'entrenamiento': 0.0,
#   'algoritmo': 0.0,
#   'cuyo': 9.973200164947428,
#   'resultado': 10.087058328730514,
#   'modelo': 9.810330054049878,
#   'automáticamente': 0.0,
#   'aprendido': 0.0,
#   'puede': 11.990518968113976,
#   'ser': 12.358467499081977,
#   'usado': 0.0,
#   'atribuir': 0.0,
#   'empleados': 0.0,
#   'tarea': 0.0,
#   'clasificación': 0.0,
#   'supervisada': 0.0,
#   'requieren': 0.0,
#   'gran': 11.580499997756885,
#   'cantidad': 9.990215556045952,
#   'ejemplos': 0.0,
#   'requisito': 0.0,
#   'hace': 11.64839123547892,
#   'enfoque': 0.0,
#   'pervisado': 0.0,
#   'impracticable': 0.0,
#   'tratar': 0.0,
#   'desambiguar': 0.0,
#   'todas': 11.23211307545407,
#   'textos': 0.0,
#   'problema': 10.603982670758612,
#   'llamado': 9.699656312254291,
#   'obstáculo': 0.0,
#   'adquisición': 0.0,
#   'conocimientos': 0.0,
#   'reconocido': 0.0,
#   'mejor': 11.255643264909532,
#   'manera': 10.97050596961306,
#   'adquirir': 0.0,
#   'etiquetas': 0.0,
#   'labras': 0.0,
#   'mano': 10.750578248609145,
#   'embargo': 11.099166054037244,
#   'formulación': 0.0,
#   'manual': 0.0,
#   'inventarios': 0.0,
#   'basada': 0.0,
#   'intuición': 0.0,
#   'lexicógrafos': 0.0,
#   'visto': 10.228357022355016,
#   'afectada': 0.0,
#   'incluyen': 0.0,
#   'alto': 10.250829075293785,
#   'costo': 0.0,
#   'asignación': 0.0,
#   'arbitraria': 0.0,
#   'emparejamiento': 0.0,
#   'equivocado': 0.0,
#   'dominios': 0.0,
#   'aplicación': 0.0,
#   'debido': 9.97011763483389,
#   'anteriores': 0.0,
#   'inconvenientes': 0.0,
#   'acercamientos': 0.0,
#   'supervisados': 0.0,
#   're': 0.0,
#   'cibido': 0.0,
#   'mucha': 9.641927964229918,
#   'atención': 10.177286194629282,
#   'últimos': 10.394793908855744,
#   'años': 12.221094254105662,
#   'pues': 11.285296870871345,
#   'potencial': 0.0,
#   'superar': 0.0,
#   'cuello': 0.0,
#   'botella': 0.0,
#   'conseguido': 0.0,
#   'introducción': 0.0,
#   'directamente': 0.0,
#   'parece': 10.906946315795638,
#   'simple': 0.0,
#   'vista': 10.34019289638035,
#   'ventaja': 0.0,
#   'constituye': 0.0,
#   'principal': 10.002155724332829,
#   'desventaja': 0.0,
#   'lleva': 9.949750717005767,
#   'cabo': 10.131618645361376,
#   'partiendo': 0.0,
#   'conjunto': 10.074706030985418,
#   'bien': 11.782624304024536,
#   'definido': 0.0,
#   'conlle': 0.0,
#   'va': 11.143281065776831,
#   'muchas': 10.610685556318733,
#   'ocasiones': 9.681967682338016,
#   'obtención': 0.0,
#   'resultados': 10.181611592175802,
#   'pobres': 0.0,
#   'proceso': 10.780288735123806},
#  'Problema11': {'área': 9.640107772607312,
#   'reconocimiento': 0.0,
#   'automático': 0.0,
#   'emociones': 0.0,
#   'investigación': 10.165890277802454,
#   'activa': 0.0,
#   'últimos': 10.394793908855744,
#   'años': 12.221094254105662,
#   'obstante': 9.595262578853017,
#   'aun': 9.636718601664555,
#   'solución': 9.678279371339702,
#   'clara': 0.0,
#   'problema': 10.603982670758612,
#   'diversos': 9.593628035139645,
#   'inconvenientes': 0.0,
#   'influido': 0.0,
#   'construcción': 9.803556713911078,
#   'apropiada': 0.0,
#   'lado': 10.764582648942334,
#   'factor': 0.0,
#   'afecta': 0.0,
#   'desempeño': 0.0,
#   'reconocedores': 0.0,
#   'contextos': 0.0,
#   'reales': 0.0,
#   'dificultad': 0.0,
#   'generar': 0.0,
#   'bases': 0.0,
#   'datos': 10.240066926275098,
#   'espontáneas': 0.0,
#   'generalmente': 0.0,
#   'trabajado': 0.0,
#   'actuadas': 0.0,
#   'cuales': 10.041552403492023,
#   'proporcionan': 0.0,
#   'retratos': 0.0,
#   'representando': 0.0,
#   'expresiones': 0.0,
#   'prototípicas': 0.0,
#   'intensas': 0.0,
#   'facilitan': 0.0,
#   'búsqueda': 0.0,
#   'correlación': 0.0,
#   'acústica': 0.0,
#   'subsecuente': 0.0,
#   'clasificación': 0.0,
#   'automática': 0.0,
#   'embargo': 11.099166054037244,
#   'buenos': 9.946594933570061,
#   'resultados': 10.181611592175802,
#   'trasladar': 0.0,
#   'conocimiento': 9.8171668460696,
#   'extraído': 0.0,
#   'steidl': 0.0,
#   'características': 9.758866322925,
#   'grabaciones': 0.0,
#   'estudio': 10.262559621074582,
#   'alta': 9.97007085667928,
#   'calidad': 10.150230436100662,
#   'eliminan': 0.0,
#   'problemas': 10.675792433881902,
#   'procesamiento': 0.0,
#   'señal': 0.0,
#   'ejemplo': 10.855203341628478,
#   'ruido': 0.0,
#   'reverberación': 0.0,
#   'puede': 11.990518968113976,
#   'garantizar': 0.0,
#   'cantidad': 9.990215556045952,
#   'balanceada': 0.0,
#   'ejemplos': 0.0,
#   'clase': 9.986587121705702,
#   'contraparte': 0.0,
#   'muestran': 0.0,
#   'elocuciones': 0.0,
#   'contenido': 9.647368744540465,
#   'emocional': 0.0,
#   'perteneciente': 0.0,
#   'sola': 9.762039188951753,
#   'sino': 11.494201255971948,
#   'mezcla': 0.0,
#   'casos': 10.539958555902517,
#   'existen': 9.885018036252466,
#   'carga': 0.0,
#   'ligera': 0.0,
#   'cercana': 0.0,
#   'neutro': 0.0,
#   'además': 11.321474360388509,
#   'suelen': 0.0,
#   'grabarse': 0.0,
#   'ambientes': 0.0,
#   'ruidosos': 0.0,
#   'conversaciones': 0.0,
#   'telefónicas': 0.0,
#   'programas': 9.747885820441555,
#   'televisión': 10.083222433433315,
#   'conlleva': 0.0,
#   'inclusión': 0.0,
#   'finalmente': 9.810878720803466,
#   'naturaleza': 9.99888863729938,
#   'misma': 11.058196580556109,
#   'posible': 10.801247647790849,
#   'asegurar': 0.0,
#   'reto': 0.0,
#   'resolver': 0.0,
#   'identificación': 0.0,
#   'conjunto': 10.074706030985418,
#   'acústicas': 0.0,
#   'permitan': 0.0,
#   'reconocer': 0.0,
#   'habla': 9.71697723512072,
#   'espontánea': 0.0,
#   'trabajo': 11.257749304074707,
#   'hecho': 11.337357054268905,
#   'fecha': 9.77286620732769,
#   'centrado': 0.0,
#   'principalmente': 0.0,
#   'relacionadas': 0.0,
#   'aspectos': 9.715288758569297,
#   'prosódicos': 0.0,
#   'descubierto': 0.0,
#   'acercamos': 0.0,
#   'escenario': 0.0,
#   'realista': 0.0,
#   'menos': 11.547307567829359,
#   'fiable': 0.0,
#   'prosodia': 0.0,
#   'indicador': 0.0,
#   'hablante': 0.0,
#   'batliner': 0.0,
#   'et': 0.0,
#   'necesario': 10.171566227844085,
#   'encontrar': 9.69066555029379,
#   'complementen': 0.0,
#   'información': 10.655445946975886,
#   'proporciona': 0.0,
#   'aspecto': 9.650400124848845,
#   'prosódico': 0.0,
#   'voz': 10.462588922467008,
#   'mayoría': 10.452591137512096,
#   'trabajos': 0.0,
#   'utilizado': 0.0,
#   'modelos': 0.0,
#   'emocionales': 0.0,
#   'discretos': 0.0,
#   'claramente': 0.0,
#   'identificadas': 0.0,
#   'corpus': 0.0,
#   'entrenamiento': 0.0,
#   'bajo': 10.882621619531593,
#   'enfoque': 0.0,
#   'existe': 10.232035618540193,
#   'valoración': 0.0,
#   'emoción': 0.0,
#   'varias': 10.11281611481661,
#   'reglas': 0.0,
#   'discriminación': 0.0,
#   'cuestión': 9.721125994942152,
#   'forma': 11.484165843298804,
#   'prácticamente': 0.0,
#   'repetir': 0.0,
#   'si': 12.699182263490384,
#   'desea': 0.0,
#   'agregar': 0.0,
#   'nueva': 11.057644917277374,
#   'trabajar': 9.604879339950793,
#   'parecen': 0.0,
#   'ser': 12.358467499081977,
#   'adecuados': 0.0,
#   'representan': 0.0,
#   'apropiadamente': 0.0,
#   'traslape': 0.0,
#   'pesar': 10.355709011986066,
#   'avances': 0.0,
#   'importantes': 9.980309695137413,
#   'comprobado': 0.0,
#   'realistas': 0.0,
#   'aún': 10.910733540740393,
#   'falta': 10.523956507598088,
#   'hacer': 11.472759505212103,
#   'proponer': 0.0,
#   'explorar': 0.0,
#   'enfoques': 0.0,
#   'llegar': 10.520131587109958,
#   'buen': 10.333840376152072,
#   'aplicaciones': 0.0,
#   'mundo': 11.53022496204829,
#   'real': 10.469426166355031,
#   'ello': 10.928955507166235,
#   'tesis': 0.0,
#   'propone': 0.0,
#   'diversificadas': 0.0,
#   'expandan': 0.0,
#   'uso': 10.212258189817774,
#   'lingsticas': 0.0,
#   'emplear': 0.0,
#   'modelo': 9.810330054049878,
#   'continuo': 0.0,
#   'permita': 0.0,
#   'apegarnos': 0.0,
#   'realidad': 10.771637909082347,
#   'basado': 0.0,
#   'tridimensional': 0.0,
#   'cuyas': 0.0,
#   'primitivas': 0.0,
#   'valencia': 0.0,
#   'activación': 0.0,
#   'dominación': 0.0,
#   'emplearán': 0.0,
#   'incluyen': 0.0,
#   'prosódicas': 0.0,
#   'espectrales': 0.0,
#   'explorará': 0.0,
#   'complemento': 0.0,
#   'soporte': 0.0,
#   'estático': 0.0,
#   'dinámico': 0.0},
#  'Problema12': {'tesis': 0.0,
#   'parte': 11.910022323407876,
#   'considerar': 0.0,
#   'tecnologías': 0.0,
#   'general': 11.469683878931205,
#   'tic': 0.0,
#   'particular': 9.60750445504496,
#   'neutrales': 0.0,
#   'autónomas': 0.0,
#   'tal': 11.176319219370214,
#   'sentido': 10.769726324511337,
#   'premisas': 0.0,
#   'clave': 0.0,
#   'ver': 11.104641387298265,
#   'idea': 10.295968733085997,
#   'pieza': 0.0,
#   'tecnología': 0.0,
#   'adquiere': 0.0,
#   'significado': 0.0,
#   'dentro': 10.943145698360567,
#   'grupos': 10.235054922800046,
#   'sociales': 10.134480218793737,
#   'amplios': 0.0,
#   'decir': 11.249831934653027,
#   'desarrolla': 0.0,
#   'bajo': 10.882621619531593,
#   'propia': 10.40876782924649,
#   'lógica': 0.0,
#   'técnica': 9.699411063939143,
#   'inmanente': 0.0,
#   'adquieren': 0.0,
#   'significados': 0.0,
#   'mundo': 11.53022496204829,
#   'social': 10.976508491537329,
#   'dan': 9.572480355345974,
#   'forma': 11.484165843298804,
#   'constriñen': 0.0,
#   'desarrollo': 10.786800443913076,
#   'menudo': 0.0,
#   'etapas': 0.0,
#   'iniciales': 0.0,
#   'producción': 10.304777289233812,
#   'conciben': 0.0,
#   'diferentes': 10.28800137389136,
#   'enfrentados': 0.0,
#   'concepción': 0.0,
#   'instrumentalista': 0.0,
#   'aquella': 10.425935376129907,
#   'considera': 9.646011322141414,
#   'simples': 0.0,
#   'herramientas': 0.0,
#   'artefactos': 0.0,
#   'construidos': 0.0,
#   'diversidad': 0.0,
#   'tareas': 0.0,
#   'colabora': 0.0,
#   'consolidar': 0.0,
#   'percepción': 0.0,
#   'misma': 11.058196580556109,
#   'neutral': 0.0,
#   'problema': 10.603982670758612,
#   'mayor': 11.409407694857888,
#   'planteo': 0.0,
#   'independiente': 0.0,
#   'cualquier': 10.921630653712223,
#   'sistema': 10.964917050076522,
#   'político': 10.402078638633776,
#   'así': 11.95533305200011,
#   'puede': 11.990518968113976,
#   'ser': 12.358467499081977,
#   'transferida': 0.0,
#   'espacio': 10.26965727803665,
#   'mayores': 9.796792813865165,
#   'consecuencias': 0.0,
#   'tales': 9.70418259070176,
#   'cosmovisiones': 0.0,
#   'reduccionistas': 0.0,
#   'esconden': 0.0,
#   'potencial': 0.0,
#   'peligro': 0.0,
#   'acarrea': 0.0,
#   'ignorar': 0.0,
#   'redes': 0.0,
#   'intereses': 9.669662152875057,
#   'económicos': 0.0,
#   'políticos': 10.119566206128216,
#   'aquellos': 10.202665790126336,
#   'diseñan': 0.0,
#   'desarrollan': 0.0,
#   'financian': 0.0,
#   'controlan': 0.0,
#   'gonzález': 10.176601523624978,
#   'garcía': 10.036750159040897,
#   'lópez': 9.632006859422356,
#   'cerezo': 0.0,
#   'luján': 0.0,
#   'informática': 0.0,
#   'agudizó': 0.0,
#   'centralidad': 0.0,
#   'tecnológico': 0.0,
#   'procesos': 0.0,
#   'cambio': 10.753937582469849,
#   'mismo': 11.781011788724976,
#   'tiempo': 11.782158393753479,
#   'pareciera': 0.0,
#   'demandan': 0.0,
#   'promueven': 0.0,
#   'motivan': 0.0,
#   'cambios': 9.846176185823014,
#   'tecnológicos': 0.0,
#   'importancia': 10.041900759689755,
#   'alcanzado': 0.0,
#   'relativa': 0.0,
#   'investigadores': 0.0,
#   'provenientes': 0.0,
#   'tradiciones': 0.0,
#   'disciplinares': 0.0,
#   'diversas': 9.533582619826515,
#   'obstante': 9.595262578853017,
#   'pregunta': 9.664024052354822,
#   'cómo': 11.199583645737869,
#   'articulan': 0.0,
#   'junto': 10.584587455185398,
#   'institucionales': 0.0,
#   'organizacionales': 0.0,
#   'cognitivos': 0.0,
#   'simbólicos': 0.0,
#   'territoriales': 0.0,
#   'crucial': 0.0,
#   'aún': 10.910733540740393,
#   'permanece': 0.0,
#   'abierta': 0.0,
#   'si': 12.699182263490384,
#   'bien': 11.782624304024536,
#   'haber': 10.899513252429136,
#   'cada': 11.732526749860027,
#   'vez': 12.004800658217194,
#   'esfuerzos': 0.0,
#   'sistematizar': 0.0,
#   'teorías': 0.0,
#   'torno': 9.531046110875145,
#   'distintas': 9.610859937691332,
#   'problemáticas': 0.0,
#   'términos': 9.526537012326164,
#   'formulaciones': 0.0,
#   'descripciones': 0.0,
#   'revelan': 0.0,
#   'insuficientes': 0.0,
#   'frente': 11.02628826167047,
#   'dimensiones': 0.0,
#   'fenómeno': 0.0,
#   'termina': 0.0,
#   'estabilizarse': 0.0,
#   'efecto': 10.17385814221302,
#   'apenas': 10.103976413285531,
#   'configuración': 0.0,
#   'comienza': 0.0,
#   'consolidarse': 0.0,
#   'produce': 9.731809155840653,
#   'algún': 10.47908916924103,
#   'obliga': 0.0,
#   'revisar': 0.0,
#   'hace': 11.64839123547892,
#   'pensaba': 0.0,
#   'castells': 0.0,
#   'paradigma': 0.0,
#   'información': 10.655445946975886,
#   'evoluciona': 0.0,
#   'hacia': 11.35184080054004,
#   'cierre': 0.0,
#   'sino': 11.494201255971948,
#   'apertura': 0.0,
#   'red': 0.0,
#   'multifacética': 0.0,
#   'poderoso': 0.0,
#   'imponente': 0.0,
#   'materialidad': 0.0,
#   'adaptable': 0.0,
#   'abierto': 0.0,
#   'histórico': 0.0,
#   'cualidades': 0.0,
#   'decisivas': 0.0,
#   'carácter': 10.14753116795808,
#   'integrador': 0.0,
#   'complejidad': 0.0,
#   'interconexión': 0.0,
#   'generación': 0.0,
#   'incertidumbre': 0.0,
#   'surge': 0.0,
#   'escenario': 0.0,
#   'caracterizado': 0.0,
#   'entorno': 0.0,
#   'resulta': 9.928033812954128,
#   'central': 10.157354276493178,
#   'contar': 0.0,
#   'adecuado': 0.0,
#   'corpus': 0.0,
#   'teórico': 0.0,
#   'estudio': 10.262559621074582,
#   'específico': 0.0,
#   'supuesto': 9.719384409659742,
#   'finalidad': 0.0,
#   'desafíos': 0.0,
#   'complejos': 0.0,
#   'lado': 10.764582648942334,
#   'debe': 11.214910188378656,
#   'tener': 10.968698164570208,
#   'consideración': 0.0,
#   'flexibilidad': 0.0,
#   'imponen': 0.0,
#   'posible': 10.801247647790849,
#   'enmarcar': 0.0,
#   'distintos': 9.705950829935693,
#   'campos': 0.0,
#   'marcado': 0.0,
#   'inestabilidad': 0.0,
#   'velocidad': 0.0,
#   'obsolescencia': 0.0,
#   'importante': 10.787193107312595,
#   'contribuir': 0.0,
#   'consolidación': 0.0,
#   'conocimientos': 0.0,
#   'descripción': 0.0,
#   'experiencias': 0.0,
#   'fin': 10.987121558023524,
#   'ir': 10.266636494850344,
#   'constituyendo': 0.0,
#   'permita': 0.0,
#   'aproximar': 0.0,
#   'comprensión': 0.0,
#   'fenómenos': 0.0,
#   'singularidad': 0.0,
#   'medida': 10.243560441877241,
#   'difunden': 0.0,
#   'vida': 11.723923557900767,
#   'cotidiana': 0.0,
#   'internalizan': 0.0,
#   'naturalizan': 0.0,
#   'determinados': 0.0,
#   'usos': 0.0,
#   'desconoce': 0.0,
#   'cuán': 0.0,
#   'complejo': 0.0,
#   'funcionamiento': 0.0,
#   'interno': 0.0,
#   'contribuye': 0.0,
#   'crear': 0.0,
#   'mágica': 0.0,
#   'fantástica': 0.0,
#   'refuerza': 0.0,
#   'encuentra': 10.078826453902199,
#   'arraigada': 0.0,
#   'estudios': 10.043727641450573,
#   'orientados': 0.0,
#   'analizar': 0.0,
#   'impactos': 0.0,
#   'efectos': 9.812084729062784,
#   'nuevas': 10.15183090487208,
#   'sociedad': 10.735831298284362,
#   'deterministas': 0.0,
#   'tienden': 0.0,
#   'naturalizar': 0.0,
#   'aparente': 0.0,
#   'neutralidad': 0.0,
#   'autonomía': 0.0,
#   'relación': 10.705870231302164,
#   'suele': 0.0,
#   'describir': 0.0,
#   'proceso': 10.780288735123806,
#   'autónomo': 0.0,
#   'sigue': 10.187914332267237,
#   'margen': 0.0,
#   'dinámica': 0.0,
#   'piensa': 0.0,
#   'propio': 10.518105462931352,
#   'curso': 9.567315270923913,
#   'intervención': 0.0,
#   'humana': 9.622913491543725,
#   'autónoma': 0.0,
#   'patrocina': 0.0,
#   'unidireccional': 0.0,
#   'desarrollos': 0.0,
#   'influyen': 0.0,
#   'significativamente': 0.0,
#   'orden': 10.433586251645703,
#   'mientras': 11.32212808969523,
#   'muestra': 9.931248623321519,
#   'contrario': 10.041378179875572,
#   'impermeable': 0.0,
#   'influencia': 0.0,
#   'factores': 0.0,
#   'ámbito': 0.0,
#   'pues': 11.285296870871345,
#   'exterior': 9.679593719831214,
#   'emparentadas': 0.0,
#   'ideas': 9.769670404801788,
#   'encuentran': 9.580661777948766,
#   'sostienen': 0.0,
#   'determinado': 0.0,
#   'supuestos': 0.0,
#   'consideran': 0.0,
#   'base': 10.283395507779986,
#   'condición': 0.0,
#   'fundamental': 0.0,
#   'afecta': 0.0,
#   'modos': 0.0,
#   'existencia': 9.903337541285003,
#   'fuente': 0.0,
#   'sostiene': 0.0,
#   'moldeada': 0.0,
#   'socialmente': 0.0,
#   'radica': 0.0,
#   'enfoques': 0.0,
#   'tecnocráticos': 0.0,
#   'ignoran': 0.0,
#   'consiguiente': 0.0,
#   'abrir': 0.0,
#   'caja': 0.0,
#   'negra': 0.0,
#   'vuelve': 9.532351404751555,
#   'evitar': 9.979846560634877,
#   'recaer': 0.0,
#   'viejo': 9.931005438572868,
#   'dualismo': 0.0,
#   'ello': 10.928955507166235,
#   'opciones': 0.0,
#   'cristalizan': 0.0,
#   'encastran': 0.0,
#   'instituyen': 0.0,
#   'desafío': 0.0,
#   'deviene': 0.0,
#   'comprender': 0.0,
#   'mismas': 0.0,
#   'construidas': 0.0,
#   'adopción': 0.0,
#   'través': 10.696751524430846,
#   'conceptualizaciones': 0.0,
#   'dinámicas': 0.0,
#   'den': 0.0,
#   'lugar': 11.2676641084024,
#   'análisis': 9.880935148065616,
#   'relaciones': 10.276945864509205,
#   'requirió': 0.0,
#   'abordaje': 0.0,
#   'analítico': 0.0,
#   'conceptual': 0.0,
#   'generó': 0.0,
#   'mediante': 10.248919530528813,
#   'procedimiento': 0.0,
#   'triangulación': 0.0,
#   'teórica': 0.0,
#   'dicha': 0.0,
#   'combinaron': 0.0,
#   'conceptos': 0.0,
#   'acuñados': 0.0,
#   'educación': 10.17835030752565,
#   'superior': 9.999433893583337,
#   'universidades': 0.0,
#   'universidad': 10.13281196292542,
#   'denominada': 0.0,
#   'conocimiento': 9.8171668460696,
#   'modifica': 0.0,
#   'misión': 0.0,
#   'institucional': 0.0,
#   'amplían': 0.0,
#   'alcances': 0.0,
#   'medio': 11.145810498870537,
#   'propuestas': 0.0,
#   'virtuales': 0.0,
#   'enseñanza': 0.0,
#   'casos': 10.539958555902517,
#   'trascienden': 0.0,
#   'límites': 0.0,
#   'campus': 0.0,
#   'dependiendo': 0.0,
#   'tramas': 0.0,
#   'co': 0.0,
#   'construyen': 0.0,
#   'acrecientan': 0.0,
#   'posibilidades': 9.621787551761894,
#   'expansivas': 0.0,
#   'ramificando': 0.0,
#   'área': 9.640107772607312,
#   'geográfica': 0.0,
#   'instituciones': 9.655410734676707,
#   'universitarias': 0.0,
#   'virtual': 0.0,
#   'entidad': 0.0,
#   'desterritorializada': 0.0,
#   'física': 0.0,
#   'virtualmente': 0.0,
#   'situado': 0.0,
#   'soporte': 0.0,
#   'dado': 10.28506972018096,
#   'elementos': 9.958591078762153,
#   'componentes': 0.0,
#   'circulan': 0.0,
#   'contexto': 0.0,
#   'local': 9.717579572206754,
#   'regional': 0.0,
#   'influyó': 0.0,
#   'localización': 0.0,
#   'nacionales': 0.0,
#   'argentinas': 0.0,
#   'privilegió': 0.0,
#   'socio': 0.0,
#   'productivo': 0.0,
#   'región': 9.840068404666473,
#   'pertenencia': 0.0,
#   'dichas': 0.0,
#   'establecidas': 0.0,
#   'organismos': 0.0,
#   'vinculados': 0.0,
#   'ubicadas': 0.0,
#   'manera': 10.97050596961306,
#   'dimensión': 0.0,
#   'territorial': 0.0,
#   'elemento': 0.0,
#   'objeto': 9.96815106586185,
#   'obra': 10.698920526636824,
#   'siempre': 11.622290950020936,
#   'veremos': 0.0,
#   'capítulo': 0.0,
#   'incorporado': 0.0,
#   'construcción': 9.803556713911078,
#   'argentina': 9.880884006326275,
#   'américa': 9.897167623791308,
#   'latina': 0.0,
#   'enfoque': 0.0,
#   'combine': 0.0,
#   'disciplinas': 0.0,
#   'necesario': 10.171566227844085,
#   'características': 9.758866322925,
#   'éstas': 0.0,
#   'pueden': 11.06490248157219,
#   'brindar': 0.0,
#   'condiciones': 10.376424375759305,
#   'producen': 0.0,
#   'utilizan': 0.0,
#   'países': 10.808616219704092,
#   'presentan': 0.0,
#   'distinta': 0.0,
#   'centrales': 0.0,
#   'situación': 10.897109627346607,
#   'demanda': 0.0,
#   'cuenta': 11.087788121064543,
#   'cognitivas': 0.0,
#   'simbólicas': 0.0,
#   'económicas': 0.0,
#   'artefactuales': 0.0,
#   'consecuentemente': 0.0,
#   'genere': 0.0,
#   'pensamiento': 0.0,
#   'sociotécnicas': 0.0},
#  'Problema13': {'actualmente': 0.0,
#   'encontramos': 0.0,
#   'denominada': 0.0,
#   'sociedad': 10.735831298284362,
#   'red': 0.0,
#   'acuerdo': 10.849045782090851,
#   'castells': 0.0,
#   'generó': 0.0,
#   'revolución': 9.634627234324935,
#   'tecnológica': 0.0,
#   'información': 10.655445946975886,
#   'florecimiento': 0.0,
#   'redes': 0.0,
#   'sociales': 10.134480218793737,
#   'creando': 0.0,
#   'nueva': 11.057644917277374,
#   'estructura': 9.812522917162035,
#   'social': 10.976508491537329,
#   'dominante': 0.0,
#   'economía': 10.14851000556878,
#   'informacionalglobal': 0.0,
#   'cultura': 10.253510420394482,
#   'virtualidadreal': 0.0,
#   'nuevo': 11.254957522501838,
#   'tipo': 10.94387026564006,
#   'inició': 0.0,
#   'aproximadamente': 0.0,
#   'años': 12.221094254105662,
#   'siglo': 10.64280241394108,
#   'pasado': 11.163141012688621,
#   'incorporación': 0.0,
#   'serie': 10.153350928549719,
#   'nuevas': 10.15183090487208,
#   'tecnologías': 0.0,
#   'medios': 10.269102416044332,
#   'finalidad': 0.0,
#   'señala': 0.0,
#   'macluhan': 0.0,
#   'extender': 0.0,
#   'cuerpo': 10.702570083504742,
#   'mente': 0.0,
#   'traído': 0.0,
#   'consigo': 0.0,
#   'transformaciones': 0.0,
#   'aspectos': 9.715288758569297,
#   'económicos': 0.0,
#   'políticos': 10.119566206128216,
#   'culturales': 0.0,
#   'comunicacionales': 0.0,
#   'tecnológicos': 0.0,
#   'psicológicos': 0.0,
#   'educativos': 0.0,
#   'establece': 0.0,
#   'inicios': 0.0,
#   'futuro': 10.203184654566114,
#   'avizora': 0.0,
#   'diversos': 9.593628035139645,
#   'campos': 0.0,
#   'incluidos': 0.0,
#   'educativo': 0.0,
#   'aspecto': 9.650400124848845,
#   'importante': 10.787193107312595,
#   'países': 10.808616219704092,
#   'vienen': 0.0,
#   'incorporando': 0.0,
#   'manera': 10.97050596961306,
#   'homogénea': 0.0,
#   'sino': 11.494201255971948,
#   'existen': 9.885018036252466,
#   'grandes': 10.865936416391367,
#   'diferencias': 0.0,
#   'tal': 11.176319219370214,
#   'refiere': 0.0,
#   'barbero': 0.0,
#   'p': 9.976645073153854,
#   'brecha': 0.0,
#   'digital': 0.0,
#   'realidad': 10.771637909082347,
#   'mientras': 11.32212808969523,
#   'desarrollados': 0.0,
#   'cerca': 10.184711314926863,
#   'hogares': 0.0,
#   'acceso': 0.0,
#   'internet': 0.0,
#   'lima': 0.0,
#   'reporte': 0.0,
#   'instituto': 9.571783927990017,
#   'nacional': 11.258562107711272,
#   'estadística': 0.0,
#   'informática': 0.0,
#   'perú': 0.0,
#   'disponen': 0.0,
#   'computadora': 0.0,
#   'instalado': 0.0,
#   'hogar': 0.0,
#   'fenómeno': 0.0,
#   'debe': 11.214910188378656,
#   'tomar': 9.927789845059094,
#   'cuenta': 11.087788121064543,
#   'campo': 10.334457951052654,
#   'apoyo': 10.033462628957874,
#   'tic': 0.0,
#   'caso': 11.482249739201768,
#   'especialmente': 9.995656440007505,
#   'generación': 0.0,
#   'joven': 10.204480639047581,
#   'edad': 10.230306199986291,
#   'forma': 11.484165843298804,
#   'permanente': 0.0,
#   'da': 10.601398368945096,
#   'principalmente': 0.0,
#   'cabinas': 0.0,
#   'públicas': 0.0,
#   'aparte': 0.0,
#   'proyecto': 10.454955954764136,
#   'huascarán': 0.0,
#   'instituciones': 9.655410734676707,
#   'educativas': 0.0,
#   'evidencia': 0.0,
#   'mayor': 11.409407694857888,
#   'jóvenes': 10.034121000171332,
#   'incluso': 10.698401298243683,
#   'marco': 9.651687291972113,
#   'año': 11.520794423348924,
#   'viene': 9.884814287270506,
#   'implementando': 0.0,
#   'paulatinamente': 0.0,
#   'integración': 0.0,
#   'sistema': 10.964917050076522,
#   'educación': 10.17835030752565,
#   'básica': 0.0,
#   'habiéndose': 0.0,
#   'iniciado': 0.0,
#   'través': 10.696751524430846,
#   'dirección': 10.299171648789187,
#   'ministerio': 10.076642221505265,
#   'visión': 0.0,
#   'peruano': 0.0,
#   'crear': 0.0,
#   'entornos': 0.0,
#   'aprendizaje': 0.0,
#   'mejor': 11.255643264909532,
#   'calidad': 10.150230436100662,
#   'mayores': 9.796792813865165,
#   'oportunidades': 0.0,
#   'política': 11.204550769293357,
#   'intercultural': 0.0,
#   'bilinge': 0.0,
#   'mediante': 10.248919530528813,
#   'proceso': 10.780288735123806,
#   'sostenido': 0.0,
#   'aplicación': 0.0,
#   'comunicación': 10.018332944205168,
#   'niveles': 9.529448434427817,
#   'procesos': 0.0,
#   'estudiantes': 0.0,
#   'inmersos': 0.0,
#   'estudian': 0.0,
#   'semanalmente': 0.0,
#   'aulas': 0.0,
#   'innovación': 0.0,
#   'pedagógica': 0.0,
#   'promedio': 0.0,
#   'horas': 10.807483006316131,
#   'pedagógicas': 0.0,
#   'mes': 10.202035378298214,
#   'escolar': 0.0,
#   'así': 11.95533305200011,
#   'interacción': 0.0,
#   'regular': 0.0,
#   'planificada': 0.0,
#   'decir': 11.249831934653027,
#   'implica': 0.0,
#   'contacto': 0.0,
#   'efectos': 9.812084729062784,
#   'tecnología': 0.0,
#   'efecto': 10.17385814221302,
#   'referido': 0.0,
#   'desempeño': 0.0,
#   'académico': 0.0,
#   'desarrollo': 10.786800443913076,
#   'asignaturas': 0.0,
#   'cursan': 0.0,
#   'regularmente': 0.0,
#   'matemática': 0.0,
#   'ciencias': 0.0,
#   'comprende': 0.0,
#   'residuos': 0.0,
#   'cognitivos': 0.0,
#   'van': 10.416251296932378,
#   'generando': 0.0,
#   'concretizan': 0.0,
#   'capacidades': 0.0,
#   'tecnológicas': 0.0,
#   'cuales': 10.041552403492023,
#   'denominamos': 0.0},
#  'Problema14': {'avances': 0.0,
#   'tecnología': 0.0,
#   'técnicas': 0.0,
#   'criptográficas': 0.0,
#   'hecho': 11.337357054268905,
#   'posible': 10.801247647790849,
#   'considerar': 0.0,
#   'votaciones': 0.0,
#   'electrónicas': 0.0,
#   'alternativa': 0.0,
#   'factible': 0.0,
#   'elecciones': 9.988793309115229,
#   'tradicionales': 0.0,
#   'medios': 10.269102416044332,
#   'comunicación': 10.018332944205168,
#   'internet': 0.0,
#   'dispositivos': 0.0,
#   'electrónicos': 0.0,
#   'computadoras': 0.0,
#   'personales': 0.0,
#   'teléfonos': 0.0,
#   'celulares': 0.0,
#   'tarjetas': 0.0,
#   'inteligentes': 0.0,
#   'etc': 10.22951254915098,
#   'facilitan': 0.0,
#   'captura': 0.0,
#   'transmisión': 0.0,
#   'recepción': 0.0,
#   'voto': 0.0,
#   'permitiendo': 0.0,
#   'así': 11.95533305200011,
#   'sistema': 10.964917050076522,
#   'cómodo': 0.0,
#   'votantes': 0.0,
#   'eficiente': 0.0,
#   'autoridades': 9.861362626235456,
#   'electorales': 0.0,
#   'embargo': 11.099166054037244,
#   'eficiencia': 0.0,
#   'comodidad': 0.0,
#   'ofrecen': 0.0,
#   'esquemas': 0.0,
#   'votación': 0.0,
#   'electrónica': 0.0,
#   'abren': 0.0,
#   'puerta': 10.357838058374103,
#   'distintos': 9.705950829935693,
#   'problemas': 10.675792433881902,
#   'existentes': 0.0,
#   'ejemplo': 10.855203341628478,
#   'identificación': 0.0,
#   'votante': 0.0,
#   'tan': 11.630450689618431,
#   'simple': 0.0,
#   'convencionales': 0.0,
#   'si': 12.699182263490384,
#   'considera': 9.646011322141414,
#   'debe': 11.214910188378656,
#   'ser': 12.358467499081977,
#   'identificado': 0.0,
#   'votar': 0.0,
#   'vez': 12.004800658217194,
#   'identidad': 0.0,
#   'anónima': 0.0,
#   'momento': 11.31608298807539,
#   'emitir': 0.0,
#   'problema': 10.603982670758612,
#   'auditoria': 0.0,
#   'elección': 0.0,
#   'resguardo': 0.0,
#   'boletas': 0.0,
#   'impresas': 0.0,
#   'ofrece': 0.0,
#   'garantía': 0.0,
#   'escrutinio': 0.0,
#   'existieran': 0.0,
#   'dudas': 0.0,
#   'desconfianza': 0.0,
#   'resultados': 10.181611592175802,
#   'finales': 0.0,
#   'bastaría': 0.0,
#   'realizar': 9.860893154903707,
#   'recuento': 0.0,
#   'votos': 0.0,
#   'verificar': 0.0,
#   'validez': 0.0,
#   'resultado': 10.087058328730514,
#   'final': 10.71263840885238,
#   'manera': 10.97050596961306,
#   'capturado': 0.0,
#   'transmitido': 0.0,
#   'urna': 0.0,
#   'electoral': 9.64633468511917,
#   'contabilizado': 0.0,
#   'periodo': 0.0,
#   'alguna': 10.606733567773487,
#   'comprobación': 0.0,
#   'contundente': 0.0,
#   'asegure': 0.0,
#   'correctamente': 0.0,
#   'recibido': 0.0,
#   'indican': 0.0,
#   'mencionados': 0.0,
#   'considerando': 0.0,
#   'canal': 0.0,
#   'inseguro': 0.0,
#   'necesarios': 0.0,
#   'seguridad': 10.492773093561983,
#   'permitan': 0.0,
#   'ofrecer': 0.0,
#   'privacidad': 0.0,
#   'requeridas': 0.0,
#   'proceso': 10.780288735123806,
#   'siempre': 11.622290950020936,
#   'obvia': 0.0,
#   'forma': 11.484165843298804,
#   'alcanzar': 0.0,
#   'tales': 9.70418259070176,
#   'características': 9.758866322925,
#   'precio': 9.727167947937808,
#   'razonable': 0.0,
#   'debido': 9.97011763483389,
#   'lleva': 9.949750717005767,
#   'cabo': 10.131618645361376,
#   'mecanismos': 0.0,
#   'aseguran': 0.0,
#   'pueden': 11.06490248157219,
#   'demasiado': 10.015833612367667,
#   'costosos': 0.0,
#   'administradores': 0.0,
#   'entidades': 0.0,
#   'lado': 10.764582648942334,
#   'inconvenientes': 0.0,
#   'usuarios': 0.0,
#   'sentido': 10.769726324511337,
#   'puede': 11.990518968113976,
#   'completamente': 0.0,
#   'automatizado': 0.0,
#   'obstante': 9.595262578853017,
#   'mediante': 10.248919530528813,
#   'uso': 10.212258189817774,
#   'herramientas': 0.0,
#   'satisfacer': 0.0,
#   'requisitos': 0.0,
#   'importantes': 9.980309695137413,
#   'asociados': 0.0,
#   'tesis': 0.0,
#   'interesados': 0.0,
#   'sistemas': 9.580799870885532,
#   'cuales': 10.041552403492023,
#   'utilizan': 0.0,
#   'transmitir': 0.0,
#   'informalmente': 0.0,
#   'tipo': 10.94387026564006,
#   'definir': 0.0,
#   'sigue': 10.187914332267237,
#   'definición': 0.0,
#   'electrónico': 0.0,
#   'genera': 0.0,
#   'permite': 9.883641924315421,
#   'dispositivo': 0.0,
#   'transmitirlo': 0.0,
#   'hacia': 11.35184080054004,
#   'depositado': 0.0,
#   'término': 0.0,
#   'jornada': 0.0,
#   'general': 11.469683878931205,
#   'cubrir': 0.0,
#   'funcionales': 0.0,
#   'servicios': 10.259307130753884,
#   'protegerse': 0.0,
#   'potenciales': 0.0,
#   'ataques': 0.0,
#   'provenientes': 0.0,
#   'red': 0.0,
#   'esenciales': 0.0,
#   'siguientes': 9.580178302441196,
#   'autenticación': 0.0,
#   'sólo': 12.046795514544378,
#   'incluidos': 0.0,
#   'padrón': 0.0,
#   'autorizados': 0.0,
#   'anonimato': 0.0,
#   'coerción': 0.0,
#   'nadie': 10.813538859620264,
#   'capaz': 9.675645480440364,
#   'determinar': 0.0,
#   'valor': 10.169920451948736,
#   'vincularlo': 0.0,
#   'unicidad': 0.0,
#   'ningún': 10.34051592510041,
#   'sola': 9.762039188951753,
#   'integridad': 0.0,
#   'modificados': 0.0,
#   'olvidados': 0.0,
#   'borrados': 0.0,
#   'detectado': 0.0,
#   'verificación': 0.0,
#   'auditoría': 0.0,
#   'contados': 0.0,
#   'demostrando': 0.0,
#   'honorabilidad': 0.0},
#  'Problema15': {'imágenes': 9.53870842969938,
#   'adquiridas': 0.0,
#   'remotamente': 0.0,
#   'empleadas': 0.0,
#   'construcción': 9.803556713911078,
#   'mapas': 0.0,
#   'temáticos': 0.0,
#   'pueden': 11.06490248157219,
#   'ser': 12.358467499081977,
#   'generados': 0.0,
#   'través': 10.696751524430846,
#   'proceso': 10.780288735123806,
#   'análisis': 9.880935148065616,
#   'normalmente': 0.0,
#   'incluye': 0.0,
#   'etapas': 0.0,
#   'segmentación': 0.0,
#   'extracción': 0.0,
#   'características': 9.758866322925,
#   'regiones': 0.0,
#   'interés': 10.237062739615967,
#   'etapa': 9.596690616224665,
#   'clasificación': 0.0,
#   'sensadas': 0.0,
#   'refiere': 0.0,
#   'reconocimiento': 0.0,
#   'coberturas': 0.0,
#   'cada': 11.732526749860027,
#   'tipo': 10.94387026564006,
#   'suelo': 9.931345880664525,
#   'presentes': 0.0,
#   'superficie': 0.0,
#   'terrestre': 0.0,
#   'contexto': 0.0,
#   'incluyen': 0.0,
#   'zonas': 9.66007751636045,
#   'urbanas': 0.0,
#   'vegetación': 0.0,
#   'bosque': 0.0,
#   'pastizales': 0.0,
#   'manglares': 0.0,
#   'etc': 10.22951254915098,
#   'cuerpos': 0.0,
#   'agua': 10.909655550812957,
#   'mares': 0.0,
#   'ríos': 0.0,
#   'lagos': 0.0,
#   'dedicadas': 0.0,
#   'cultivo': 0.0,
#   'plantas': 0.0,
#   'partir': 10.52615861929175,
#   'área': 9.640107772607312,
#   'investigación': 10.165890277802454,
#   'importante': 10.787193107312595,
#   'aplicación': 0.0,
#   'éstos': 0.0,
#   'obtención': 0.0,
#   'conocimiento': 9.8171668460696,
#   'medio': 11.145810498870537,
#   'ambiente': 9.852194258148577,
#   'global': 0.0,
#   'usos': 0.0,
#   'recursos': 10.118598932153073,
#   'renovables': 0.0,
#   'desastres': 0.0,
#   'naturales': 0.0,
#   'geología': 0.0,
#   'anterior': 10.250970378105945,
#   'trabaja': 0.0,
#   'alta': 9.97007085667928,
#   'calidad': 10.150230436100662,
#   'logrado': 0.0,
#   'esquemas': 0.0,
#   'utilizados': 0.0,
#   'momento': 11.31608298807539,
#   'históricamente': 0.0,
#   'ecologistas': 0.0,
#   'estudiado': 0.0,
#   'homogéneas': 0.0,
#   'caracterizar': 0.0,
#   'entender': 0.0,
#   'procesos': 0.0,
#   'ecosistemas': 0.0,
#   'evitado': 0.0,
#   'áreas': 0.0,
#   'heterogéneas': 0.0,
#   'resultado': 10.087058328730514,
#   'transición': 0.0,
#   'frecuentemente': 0.0,
#   'ignoradas': 0.0,
#   'reducidas': 0.0,
#   'líneas': 0.0,
#   'mapa': 0.0,
#   'temático': 0.0,
#   'embargo': 11.099166054037244,
#   'llamadas': 0.0,
#   'ecotonos': 0.0,
#   'controlan': 0.0,
#   'flujo': 0.0,
#   'materiales': 0.0,
#   'influencia': 0.0,
#   'biodiversidad': 0.0,
#   'fortin': 0.0,
#   'generación': 0.0,
#   'mejor': 11.255643264909532,
#   'presenta': 9.636588019266876,
#   'clasifican': 0.0,
#   'básicamente': 0.0,
#   'cobertura': 0.0,
#   'homogénea': 0.0,
#   'considera': 9.646011322141414,
#   'aquella': 10.425935376129907,
#   'constituida': 0.0,
#   'sola': 9.762039188951753,
#   'paso': 10.460843646427818,
#   'ejemplo': 10.855203341628478,
#   'pasar': 10.087807111992756,
#   'descubierto': 0.0,
#   'realiza': 0.0,
#   'manera': 10.97050596961306,
#   'abrupta': 0.0,
#   'sino': 11.494201255971948,
#   'forma': 11.484165843298804,
#   'gradual': 0.0,
#   'generándose': 0.0,
#   'zona': 10.353447900530844,
#   'formada': 0.0,
#   'caso': 11.482249739201768,
#   'ver': 11.104641387298265,
#   'figura': 10.160413981817907,
#   'genera': 0.0,
#   'límites': 0.0,
#   'indeterminados': 0.0,
#   'encuentra': 10.078826453902199,
#   'compuesta': 0.0,
#   'proporcional': 0.0,
#   'delimitan': 0.0,
#   'debido': 9.97011763483389,
#   'determinar': 0.0,
#   'composición': 0.0,
#   'resulta': 9.928033812954128,
#   'trivial': 0.0},
#  'Problema16': {'gracias': 10.077188727036472,
#   'avances': 0.0,
#   'reconocimiento': 0.0,
#   'automático': 0.0,
#   'habla': 9.71697723512072,
#   'posible': 10.801247647790849,
#   'realizar': 9.860893154903707,
#   'búsqueda': 0.0,
#   'información': 10.655445946975886,
#   'grandes': 10.865936416391367,
#   'colecciones': 0.0,
#   'orales': 0.0,
#   'supuesto': 9.719384409659742,
#   'calidad': 10.150230436100662,
#   'transcripciones': 0.0,
#   'ende': 0.0,
#   'éxito': 9.830648006359171,
#   'recuperación': 0.0,
#   'fuertemente': 0.0,
#   'ligado': 0.0,
#   'rendimiento': 0.0,
#   'reconocedor': 0.0,
#   'momento': 11.31608298807539,
#   'inglés': 0.0,
#   'lengua': 0.0,
#   'investigada': 0.0,
#   'mayor': 11.409407694857888,
#   'número': 10.736070535336799,
#   'herramientas': 0.0,
#   'obtener': 0.0,
#   'casi': 11.197735153101846,
#   'correctas': 0.0,
#   'siempre': 11.622290950020936,
#   'trate': 0.0,
#   'elocuciones': 0.0,
#   'limpias': 0.0,
#   'bien': 11.782624304024536,
#   'formadas': 0.0,
#   'ejemplo': 10.855203341628478,
#   'computadora': 0.0,
#   'puede': 11.990518968113976,
#   'transcripción': 0.0,
#   'lector': 0.0,
#   'wall': 0.0,
#   'street': 0.0,
#   'journal': 0.0,
#   'tan': 11.630450689618431,
#   'sólo': 12.046795514544378,
#   'error': 0.0,
#   'nivel': 10.52993387579382,
#   'palabra': 10.047154902348542,
#   'wer': 0.0,
#   'siglas': 0.0,
#   'word': 0.0,
#   'rate': 0.0,
#   'embargo': 11.099166054037244,
#   'empieza': 0.0,
#   'elevarse': 0.0,
#   'cuanto': 10.558906905035101,
#   'condiciones': 10.376424375759305,
#   'cercanas': 0.0,
#   'conversación': 0.0,
#   'real': 10.469426166355031,
#   'caso': 11.482249739201768,
#   'transmisión': 0.0,
#   'radiofónica': 0.0,
#   'podemos': 9.996886816794678,
#   'tener': 10.968698164570208,
#   'telefónica': 0.0,
#   'datos': 10.240066926275098,
#   'dan': 9.572480355345974,
#   'idea': 10.295968733085997,
#   'reto': 0.0,
#   'grabaciones': 0.0,
#   'conversaciones': 0.0,
#   'espontáneas': 0.0,
#   'origen': 9.954893340596028,
#   'errores': 0.0,
#   'variada': 0.0,
#   'naturaleza': 9.99888863729938,
#   'continuación': 0.0,
#   'presentan': 0.0,
#   'brevemente': 0.0,
#   'principales': 9.82498532438117,
#   'motivos': 0.0,
#   'impactan': 0.0,
#   'desempeño': 0.0,
#   'actual': 10.265314203614462,
#   'posteriormente': 0.0,
#   'discutir': 0.0,
#   'impacto': 0.0,
#   'ri': 0.0,
#   'palabras': 10.41885285634415,
#   'vocabulario': 0.0,
#   'rah': 0.0,
#   'propone': 0.0,
#   'ortográfica': 0.0,
#   'audio': 0.0,
#   'apoyándose': 0.0,
#   'diccionario': 0.0,
#   'reconocer': 0.0,
#   'existir': 0.0,
#   'entrada': 9.795623906660182,
#   'correcta': 0.0,
#   'pronunciaciones': 0.0,
#   'intentará': 0.0,
#   'aproximar': 0.0,
#   'contenidas': 0.0,
#   'dentro': 10.943145698360567,
#   'así': 11.95533305200011,
#   'oov': 0.0,
#   'outofvocabulary': 0.0,
#   'substituida': 0.0,
#   'fonéticamente': 0.0,
#   'similar': 0.0,
#   'peor': 9.557116483735667,
#   'aún': 10.910733540740393,
#   'grupo': 11.088124620555321,
#   'cuya': 10.045334276764365,
#   'pronunciación': 0.0,
#   'conjunta': 0.0,
#   'diversos': 9.593628035139645,
#   'trabajos': 0.0,
#   'abordado': 0.0,
#   'especialmente': 9.995656440007505,
#   'problema': 10.603982670758612,
#   'olson': 0.0,
#   'oard': 0.0,
#   'olsson': 0.0,
#   'experimentos': 0.0,
#   'witbrock': 0.0,
#   'hauptmann': 0.0,
#   'mostraron': 0.0,
#   'caída': 0.0,
#   'efectividad': 0.0,
#   'debida': 0.0,
#   'cabe': 0.0,
#   'remarcar': 0.0,
#   'presente': 10.094562354324832,
#   'prácticamente': 0.0,
#   'imposible': 9.559446746414963,
#   'contar': 0.0,
#   'completo': 0.0,
#   'debido': 9.97011763483389,
#   'constante': 0.0,
#   'creación': 9.7277641797704,
#   'nuevas': 10.15183090487208,
#   'lenguaje': 9.565914710470881,
#   'fácilmente': 0.0,
#   'observada': 0.0,
#   'trata': 10.484137701868928,
#   'nombres': 0.0,
#   'propios': 9.575261224768767,
#   'tales': 9.70418259070176,
#   'empresas': 10.263013428702846,
#   'personas': 11.088430430955258,
#   'lugares': 0.0,
#   'organizaciones': 0.0,
#   'etc': 10.22951254915098,
#   'delimitación': 0.0,
#   'hablado': 0.0,
#   'marca': 0.0,
#   'separación': 0.0,
#   'manera': 10.97050596961306,
#   'elocución': 0.0,
#   'observa': 0.0,
#   'secuencia': 0.0,
#   'única': 9.955890231329176,
#   'fonemas': 0.0,
#   'debe': 11.214910188378656,
#   'identificar': 0.0,
#   'correctamente': 0.0,
#   'pronunciadas': 0.0,
#   'partir': 10.52615861929175,
#   'dicha': 0.0,
#   'ello': 10.928955507166235,
#   'elige': 0.0,
#   'través': 10.696751524430846,
#   'métodos': 0.0,
#   'probabilísticos': 0.0,
#   'provocar': 0.0,
#   'incorrecta': 0.0,
#   'modelo': 9.810330054049878,
#   'probabilístico': 0.0,
#   'comúnmente': 0.0,
#   'usado': 0.0,
#   'asigna': 0.0,
#   'probabilidades': 0.0,
#   'secuencias': 0.0,
#   'probabilidad': 0.0,
#   'viene': 9.884814287270506,
#   'condicionada': 0.0,
#   'precedentes': 0.0,
#   'incorpora': 0.0,
#   'lingística': 0.0,
#   'proceso': 10.780288735123806,
#   'decodificación': 0.0,
#   'mejorando': 0.0,
#   'propuestas': 0.0,
#   'desafortunadamente': 0.0,
#   'genera': 0.0,
#   'altas': 0.0,
#   'comunes': 0.0,
#   'preposiciones': 0.0,
#   'artículos': 0.0,
#   'partículas': 0.0,
#   'encontrarlas': 0.0,
#   'parte': 11.910022323407876,
#   'elocuente': 0.0,
#   'interpretarse': 0.0,
#   'cuente': 0.0,
#   'dada': 0.0,
#   'alta': 9.97007085667928,
#   'frecuentes': 0.0,
#   'inclinará': 0.0,
#   'última': 10.317879365460813,
#   'opción': 0.0,
#   'fenómenos': 0.0,
#   'espontánea': 0.0,
#   'finalmente': 9.810878720803466,
#   'existen': 9.885018036252466,
#   'tipo': 10.94387026564006,
#   'generados': 0.0,
#   'tratar': 0.0,
#   'diferente': 0.0,
#   'cuyo': 9.973200164947428,
#   'contenido': 9.647368744540465,
#   'noticias': 0.0,
#   'cuales': 10.041552403492023,
#   'mantienen': 0.0,
#   'temática': 0.0,
#   'buena': 10.427002327418107,
#   'entonación': 0.0,
#   'repetición': 0.0,
#   'acontecimientos': 0.0,
#   'entrevistas': 0.0,
#   'lingísticos': 0.0,
#   'véase': 0.0,
#   'tabla': 0.0,
#   'pasan': 0.0,
#   'inadvertidos': 0.0,
#   'persona': 10.39684143039008,
#   'fuente': 0.0,
#   'recordar': 0.0,
#   'llevar': 9.786841370416807,
#   'texto': 9.782110566369528,
#   'cualquier': 10.921630653712223,
#   'sonido': 0.0,
#   'grabación': 0.0,
#   'forma': 11.484165843298804,
#   'risa': 0.0,
#   'transformada': 0.0,
#   'alterando': 0.0},
#  'Problema17': {'c': 10.384214728478085,
#   'on': 0.0,
#   'coleccion': 0.0,
#   'objetos': 0.0,
#   'cada': 11.732526749860027,
#   'descrito': 0.0,
#   'través': 10.696751524430846,
#   'conjunto': 10.074706030985418,
#   'rasgos': 0.0,
#   'r': 9.549736900114642,
#   'algoritmo': 0.0,
#   'agrupamiento': 0.0,
#   'aquel': 10.580937168488774,
#   'organiza': 0.0,
#   'mencionada': 0.0,
#   'clases': 0.0,
#   'grupos': 10.235054922800046,
#   'forma': 11.484165843298804,
#   'tal': 11.176319219370214,
#   'semejanza': 0.0,
#   'pertenecientes': 0.0,
#   'mismo': 11.781011788724976,
#   'grupo': 11.088124620555321,
#   'alta': 9.97007085667928,
#   'contraposicion': 0.0,
#   'diferentes': 10.28800137389136,
#   'dice': 10.937614651977828,
#   'obtenido': 0.0,
#   'solapado': 0.0,
#   'si': 12.699182263490384,
#   'dicho': 10.547286913465735,
#   'existen': 9.885018036252466,
#   'pertenezcan': 0.0,
#   'mas': 0.0,
#   'vez': 12.004800658217194,
#   'descrita': 0.0,
#   'anteriormente': 0.0,
#   'jerarquico': 0.0,
#   'construye': 0.0,
#   'estructura': 9.812522917162035,
#   'compuesta': 0.0,
#   'k': 0.0,
#   'niveles': 9.529448434427817,
#   'nivel': 10.52993387579382,
#   'general': 11.469683878931205,
#   'supremo': 0.0,
#   'específico': 0.0,
#   'infimo': 0.0,
#   'cumple': 0.0,
#   'siguientes': 9.580178302441196,
#   'condiciones': 10.376424375759305,
#   'gigi': 0.0,
#   'gimii': 0.0,
#   'satisface': 0.0,
#   'm': 10.407258349428416,
#   'gijj': 0.0,
#   'gij': 0.0,
#   'lt': 0.0,
#   'b': 10.017128689025176,
#   'nk': 0.0,
#   'ooon': 0.0,
#   'n': 9.528648637969724,
#   'i': 9.85114107216392,
#   'jm': 0.0,
#   'existe': 10.232035618540193,
#   'relacion': 0.0,
#   'padrehijo': 0.0,
#   'menos': 11.547307567829359,
#   'elemento': 0.0,
#   'giq': 0.0,
#   'q': 0.0,
#   'adicionalmente': 0.0,
#   'entonces': 11.234612696522394,
#   'puede': 11.990518968113976,
#   'decir': 11.249831934653027,
#   'tambien': 0.0,
#   'eshijode': 0.0,
#   'd': 9.787515376283707,
#   'j': 9.534667728624708,
#   'gi': 0.0,
#   'u': 9.678279371339702,
#   'condicion': 0.0,
#   'establece': 0.0,
#   'est': 0.0,
#   'formado': 0.0,
#   'características': 9.758866322925,
#   'presentan': 0.0,
#   'conforman': 0.0,
#   'dichos': 0.0,
#   'relación': 10.705870231302164,
#   'umero': 0.0,
#   'inmediato': 0.0,
#   'inferior': 0.0,
#   'plantea': 0.0,
#   'ultimo': 0.0,
#   'jerarquía': 0.0,
#   'unitario': 0.0,
#   'parte': 11.910022323407876,
#   'elementos': 9.958591078762153,
#   'finalmente': 9.810878720803466,
#   'define': 0.0,
#   'cualquier': 10.921630653712223,
#   'g': 9.69239608224606,
#   'obtiene': 0.0,
#   'traves': 0.0,
#   'unión': 9.995747630961425,
#   'cuales': 10.041552403492023,
#   'ejemplo': 10.855203341628478,
#   'muestra': 9.931248623321519,
#   'figura': 10.160413981817907,
#   'solapados': 0.0,
#   'dicha': 0.0,
#   'permite': 9.883641924315421,
#   'obtenidos': 0.0,
#   'pueda': 9.955178267941482,
#   'ser': 12.358467499081977,
#   'problema': 10.603982670758612,
#   'propuesta': 9.604407435131979,
#   'tesis': 0.0,
#   'doctoral': 0.0,
#   'desarrollo': 10.786800443913076,
#   'algoritmos': 0.0,
#   'jerarquicos': 0.0,
#   'jer': 0.0,
#   'arquicos': 0.0,
#   'din': 0.0,
#   'amicos': 0.0,
#   'obtengan': 0.0,
#   'pueden': 11.06490248157219},
#  'Problema18': {'i': 9.85114107216392,
#   'conjunto': 10.074706030985418,
#   'ítems': 0.0,
#   'c': 10.384214728478085,
#   'clases': 0.0,
#   'tc': 0.0,
#   'transacciones': 0.0,
#   'forma': 11.484165843298804,
#   'fi': 0.0,
#   'in': 0.0,
#   'cg': 0.0,
#   'tal': 11.176319219370214,
#   'knik': 0.0,
#   'ver': 11.104641387298265,
#   'tabla': 0.0,
#   'r': 9.549736900114642,
#   'ordenado': 0.0,
#   'reglas': 0.0,
#   'x': 0.0,
#   'w': 0.0,
#   'funcion': 0.0,
#   'asigna': 0.0,
#   'peso': 9.775028985632325,
#   'cada': 11.732526749860027,
#   'regla': 0.0,
#   'd': 9.787515376283707,
#   'criterio': 0.0,
#   'decision': 0.0,
#   'utiliza': 0.0,
#   'asignar': 0.0,
#   'clase': 9.986587121705702,
#   'transaccion': 0.0,
#   't': 0.0,
#   'desee': 0.0,
#   'clasificar': 0.0,
#   'dados': 0.0,
#   'construir': 0.0,
#   'clasificador': 0.0,
# ...
#   'cuales': 10.041552403492023,
#   'pueden': 11.06490248157219,
#   'clasificar': 0.0,
#   'dependiendo': 0.0,
#   'flujo': 0.0,
#   'datos': 10.240066926275098,
#   'través': 10.696751524430846,
#   'red': 0.0,
#   'estáticas': 0.0,
#   'recurrentes': 0.0,
#   'siempre': 11.622290950020936,
#   'dirección': 10.299171648789187,
#   'entrada': 9.795623906660182,
#   'salida': 9.67401149314871,
#   'neuronal': 0.0,
#   'mientras': 11.32212808969523,
#   'recurrente': 0.0,
#   'mueve': 0.0,
#   'realimentación': 0.0,
#   'capas': 0.0,
#   'interiores': 0.0,
#   'forma': 11.484165843298804,
#   'tipo': 10.94387026564006,
#   'aprendizaje': 0.0,
#   'si': 12.699182263490384,
#   'entrena': 0.0,
#   'conjunto': 10.074706030985418,
#   'previo': 0.0,
#   'trabajo': 11.257749304074707,
#   'sistema': 10.964917050076522,
#   'proceso': 10.780288735123806,
#   'conoce': 0.0,
#   'cambio': 10.753937582469849,
#   'aprende': 0.0,
#   'tiempo': 11.782158393753479,
#   'real': 10.469426166355031,
#   'trabaja': 0.0,
#   'mutuamente': 0.0,
#   'llama': 9.609317813948794,
#   'clase': 9.986587121705702,
#   'sistemas': 9.580799870885532,
#   'procesos': 0.0,
#   'tratan': 0.0,
#   'tesis': 0.0,
#   'modelados': 0.0,
#   'ecuaciones': 0.0,
#   'diferenciales': 0.0,
#   'embargo': 11.099166054037244,
#   'mecanismos': 0.0,
#   'solo': 10.37380363296391,
#   'conocen': 0.0,
#   'estructura': 9.812522917162035,
#   'modelo': 9.810330054049878,
#   'ejemplo': 10.855203341628478,
#   'x': 0.0,
#   'fx': 0.0,
#   'gxu': 0.0,
#   'hx': 0.0,
#   'algún': 10.47908916924103,
#   'particular': 9.60750445504496,
#   'f': 0.0,
#   'irn': 0.0,
#   'g': 9.69239608224606,
#   'irnr': 0.0,
#   'vector': 0.0,
#   'control': 10.135352957662207,
#   'u': 9.678279371339702,
#   'irr': 0.0,
#   'r': 9.549736900114642,
#   'n': 9.528648637969724,
#   'variables': 0.0,
#   'irm': 0.0,
#   'entonces': 11.234612696522394,
#   'dada': 0.0,
#   'representación': 0.0,
#   'dinámico': 0.0,
#   'funciones': 0.0,
#   'gx': 0.0,
#   'desconocidas': 0.0,
#   'dinámicos': 0.0,
#   'clasifican': 0.0,
#   'acuerdo': 10.849045782090851,
#   'grado': 9.619000370980867,
#   'actuación': 0.0,
#   'número': 10.736070535336799,
#   'actuadores': 0.0,
#   'respecto': 10.47429759323113,
#   'grados': 0.0,
#   'libertad': 10.279146161061627,
#   'completamente': 0.0,
#   'actuados': 0.0,
#   'subastados': 0.0,
#   'igual': 10.402746539930654,
#   'actúa': 0.0,
#   'dores': 0.0,
#   'menos': 11.547307567829359,
#   'difíciles': 0.0,
#   'controlar': 0.0,
#   'alto': 10.250829075293785,
#   'incertidumbre': 0.0,
#   'integran': 0.0,
#   'todas': 11.23211307545407,
#   'dinámicas': 0.0,
#   'físico': 0.0,
#   'fricción': 0.0,
#   'zona': 10.353447900530844,
#   'muerta': 0.0,
#   'saturación': 0.0,
#   'vacilas': 0.0,
#   'perdida': 0.0,
#   'movimiento': 10.22904327741599,
#   'mecanismo': 0.0,
#   'causado': 0.0,
#   'holgura': 0.0,
#   'partes': 9.910314197878405,
#   'conveniente': 0.0,
#   'uso': 10.212258189817774,
#   'dado': 10.28506972018096,
#   'capacidad': 10.17458282138351,
#   'aprender': 0.0,
#   'adaptarse': 0.0,
#   'recientemente': 0.0,
#   'avances': 0.0,
#   'área': 9.640107772607312,
#   'gran': 11.580499997756885,
#   'impulso': 0.0,
#   'lineales': 0.0,
#   'aprovecha': 0.0,
#   'modelar': 0.0,
#   'habilidad': 0.0,
#   'ejecución': 0.0,
#   'narendra': 0.0,
#   'parthasarathy': 0.0,
#   'demuestran': 0.0,
#   'neurales': 0.0,
#   'ser': 12.358467499081977,
#   'usadas': 0.0,
#   'efectivamente': 0.0,
#   'identificación': 0.0,
#   'problema': 10.603982670758612,
#   'determinación': 0.0,
#   'difícil': 10.207621055054725,
#   'obtener': 0.0,
#   'desconocimiento': 0.0,
#   'parámetros': 0.0,
#   'adaptativos': 0.0,
#   'útiles': 0.0,
#   'tales': 9.70418259070176,
#   'situaciones': 0.0,
#   'dinámica': 0.0,
#   'desconoce': 0.0,
#   'controladores': 0.0,
#   'permiten': 0.0,
#   'necesidad': 10.154207359620441,
#   'entrenamiento': 0.0,
#   'además': 11.321474360388509,
#   'desempeño': 0.0,
#   'sujeto': 0.0,
#   'realizado': 0.0,
#   'delimitados': 0.0,
#   'controlador': 0.0,
#   'basado': 0.0,
#   'retroalimentación': 0.0,
#   'confiable': 0.0,
#   'respaldado': 0.0,
#   'estudio': 10.262559621074582,
#   'estabilidad': 0.0,
#   'importante': 10.787193107312595,
#   'notar': 0.0,
#   'trabajos': 0.0,
#   'investigación': 10.165890277802454,
#   'literatura': 0.0,
#   'lazo': 0.0,
#   'cerrado': 0.0,
#   'confiabilidad': 0.0,
#   'propuestos': 0.0,
#   'degradada': 0.0,
#   'campo': 10.334457951052654,
#   'conocimiento': 9.8171668460696,
#   'necesita': 0.0,
#   'encuentran': 9.580661777948766,
#   'pendubot': 0.0,
#   'acrobot': 0.0,
#   'péndulo': 0.0,
#   'furuta': 0.0,
#   'rueda': 0.0,
#   'inercial': 0.0,
#   'seguimiento': 0.0,
#   'trayectorias': 0.0,
#   'conocer': 9.98419157995109},
#  'Problema32': {'incremento': 0.0,
#   'potencia': 0.0,
#   'crucial': 0.0,
#   'alcanzar': 0.0,
#   'relación': 10.705870231302164,
#   'señal': 0.0,
#   'ruido': 0.0,
#   'deseada': 0.0,
#   'receptor': 0.0,
#   'pudiera': 0.0,
#   'ser': 12.358467499081977,
#   'detectable': 0.0,
#   'hacer': 11.472759505212103,
#   'posible': 10.801247647790849,
#   'comunicación': 10.018332944205168,
#   'inalámbrica': 0.0,
#   'amplio': 0.0,
#   'ancho': 0.0,
#   'banda': 0.0,
#   'necesario': 10.171566227844085,
#   'basarse': 0.0,
#   'esquemas': 0.0,
#   'multiplexación': 0.0,
#   'complejos': 0.0,
#   'acceso': 0.0,
#   'múltiple': 0.0,
#   'división': 0.0,
#   'código': 0.0,
#   'ancha': 0.0,
#   'wcdma': 0.0,
#   'frecuencias': 0.0,
#   'ortogonales': 0.0,
#   'ofdm': 0.0,
#   'técnicas': 0.0,
#   'modulación': 0.0,
#   'amplitud': 0.0,
#   'cuadratura': 0.0,
#   'qam': 0.0,
#   'incluso': 10.698401298243683,
#   'desplazamiento': 0.0,
#   'fase': 0.0,
#   'qpsk': 0.0,
#   'momento': 11.31608298807539,
#   'transmitir': 0.0,
#   'altas': 0.0,
#   'tasas': 0.0,
#   'datos': 10.240066926275098,
#   'produce': 9.731809155840653,
#   'recrecimiento': 0.0,
#   'espectral': 0.0,
#   'agregan': 0.0,
#   'efectos': 9.812084729062784,
#   'memoria': 9.745839095947058,
#   'linealidades': 0.0,
#   'debido': 9.97011763483389,
#   'características': 9.758866322925,
#   'intrínsecas': 0.0,
#   'pa': 0.0,
#   'dispositivo': 0.0,
#   'etapa': 9.596690616224665,
#   'transmisor': 0.0,
#   'agrega': 0.0,
#   'mayoría': 10.452591137512096,
#   'existen': 9.885018036252466,
#   'esfuerzos': 0.0,
#   'investigación': 10.165890277802454,
#   'basados': 0.0,
#   'polinomios': 0.0,
#   'modelos': 0.0,
#   'toman': 0.0,
#   'cuenta': 11.087788121064543,
#   'redes': 0.0,
#   'neuronales': 0.0,
#   'embargo': 11.099166054037244,
#   'existe': 10.232035618540193,
#   'plataforma': 0.0,
#   'completa': 0.0,
#   'capaz': 9.675645480440364,
#   'emular': 0.0,
#   'hardware': 0.0,
#   'comportamientos': 0.0,
#   'adecuados': 0.0,
#   'pas': 0.0,
#   'parta': 0.0,
#   'mediciones': 0.0,
#   'curvas': 0.0,
#   'distorsión': 0.0,
#   'amam': 0.0,
#   'ampm': 0.0,
#   'otorgue': 0.0,
#   'integración': 0.0,
#   'permitan': 0.0,
#   'niveles': 9.529448434427817,
#   'linealidad': 0.0,
#   'orden': 10.433586251645703,
#   'variables': 0.0,
#   'polinomiales': 0.0,
#   'aprendizaje': 0.0,
#   'además': 11.321474360388509,
#   'algoritmos': 0.0,
#   'adaptativos': 0.0,
#   'modelar': 0.0,
#   'componente': 0.0,
#   'principal': 10.002155724332829,
#   'consumo': 9.686263943732909,
#   'energía': 10.009692711382444,
#   'establecer': 0.0,
#   'compromiso': 0.0,
#   'eficiencia': 0.0,
#   'lograr': 0.0,
#   'propósito': 0.0,
#   'contar': 0.0,
#   'comportamiento': 0.0,
#   'nivel': 10.52993387579382,
#   'variable': 0.0,
#   'linealización': 0.0,
#   'convertido': 0.0,
#   'área': 9.640107772607312,
#   'gran': 11.580499997756885,
#   'interés': 10.237062739615967,
#   'sistemas': 9.580799870885532,
#   'modernos': 0.0,
#   'requieren': 0.0,
#   'describan': 0.0,
#   'fielmente': 0.0,
#   'funcionamiento': 0.0,
#   'cabe': 0.0,
#   'indicar': 0.0,
#   'diversas': 9.533582619826515,
#   'proceso': 10.780288735123806,
#   'contribuye': 0.0,
#   'trabajarlo': 0.0,
#   'linealmente': 0.0,
#   'mencionar': 0.0,
#   'métodos': 0.0,
#   'comúnmente': 0.0,
#   'utilizados': 0.0,
#   'encuentra': 10.078826453902199,
#   'prealimentación': 0.0,
#   'retroalimentación': 0.0,
#   'predistorsión': 0.0,
#   'analógica': 0.0,
#   'mencionados': 0.0,
#   'eficientes': 0.0,
#   'aplicaciones': 0.0,
#   'baja': 9.827793708166928,
#   'frecuencia': 0.0,
#   'pueden': 11.06490248157219,
#   'sufrir': 0.0,
#   'pérdidas': 0.0,
#   'estabilidad': 0.0,
#   'producidos': 0.0,
#   'repercuten': 0.0,
#   'dos': 12.339024495252145,
#   'maneras': 0.0,
#   'lado': 10.764582648942334,
#   'causan': 0.0,
#   'dando': 0.0,
#   'lugar': 11.2676641084024,
#   'interferencias': 0.0,
#   'canales': 0.0,
#   'transmisión': 0.0,
#   'adyacentes': 0.0,
#   'operación': 9.657139343577324,
#   'asignada': 0.0,
#   'mientras': 11.32212808969523,
#   'dentro': 10.943145698360567,
#   'propia': 10.40876782924649,
#   'degradando': 0.0,
#   'tasa': 0.0,
#   'error': 0.0,
#   'bits': 0.0,
#   'ber': 0.0,
#   'organismos': 0.0,
#   'reguladores': 0.0,
#   'fijan': 0.0,
#   'través': 10.696751524430846,
#   'diferentes': 10.28800137389136,
#   'estándares': 0.0,
#   'comunicaciones': 0.0,
#   'máximos': 0.0,
#   'permitidos': 0.0,
#   'emisión': 0.0,
#   'así': 11.95533305200011,
#   'límites': 0.0,
#   'ejemplo': 10.855203341628478,
#   'especificando': 0.0,
#   'porcentajes': 0.0,
#   'constelaciones': 0.0,
#   'sanciones': 0.0,
#   'violar': 0.0,
#   'cualquiera': 0.0,
#   'especificaciones': 0.0,
#   'multas': 0.0,
#   'elevadas': 0.0,
#   'series': 0.0,
#   'volterra': 0.0,
#   'usadas': 0.0,
#   'describir': 0.0,
#   'sistema': 10.964917050076522,
#   'estable': 0.0,
#   'lineal': 0.0,
#   'pérdida': 0.0,
#   'arbitrario': 0.0,
#   'pequeño': 9.774346508212899,
#   'desventajas': 0.0,
#   'principales': 9.82498532438117,
#   'dramático': 0.0,
#   'número': 10.736070535336799,
#   'parámetros': 0.0,
#   'respecto': 10.47429759323113,
#   'profundidad': 0.0,
#   'causa': 10.055478759522249,
#   'drástico': 0.0,
#   'complejidad': 0.0,
#   'cálculo': 0.0,
#   'identificación': 0.0,
#   'razón': 10.326759834294158,
#   'resulta': 9.928033812954128,
#   'altamente': 0.0,
#   'impráctico': 0.0,
#   'uso': 10.212258189817774,
#   'completas': 0.0,
#   'representar': 0.0,
#   'matemáticamente': 0.0,
#   'alta': 9.97007085667928,
#   'requiere': 0.0,
#   'truncaciones': 0.0,
#   'mpm': 0.0,
#   'wiener': 0.0,
#   'hammerstein': 0.0,
#   'costo': 0.0,
#   'computacional': 0.0,
#   'kernels': 0.0,
#   'cada': 11.732526749860027,
#   'modelo': 9.810330054049878,
#   'reducido': 0.0,
#   'comparación': 0.0,
#   'aunado': 0.0,
#   'modelado': 0.0,
#   'completo': 0.0,
#   'incluya': 0.0,
#   'diversos': 9.593628035139645,
#   'desarrollar': 0.0,
#   'medición': 0.0,
#   'bajo': 10.882621619531593,
#   'tradicionales': 0.0,
#   'vna': 0.0,
#   'indispensables': 0.0,
#   'realizar': 9.860893154903707,
#   'parámetro': 0.0,
#   'dispersión': 0.0,
#   's': 9.698490846702954,
#   'provee': 0.0,
#   'información': 10.655445946975886,
#   'menciona': 0.0,
#   'involucra': 0.0,
#   'costoso': 0.0,
#   'equipo': 10.55095721959942,
#   'laboratorio': 0.0,
#   'instalación': 0.0,
#   'calibración': 0.0,
#   'previa': 0.0,
#   'consideraciones': 0.0,
#   'método': 0.0,
#   'tradicional': 0.0,
#   'anterior': 10.250970378105945,
#   'lleva': 9.949750717005767,
#   'necesidad': 10.154207359620441,
#   'digital': 0.0,
#   'pueda': 9.955178267941482,
#   'estimar': 0.0,
#   'si': 12.699182263490384,
#   'utilizado': 0.0,
#   'dut': 0.0,
#   'utilizar': 0.0,
#   'ann': 0.0,
#   'anfis': 0.0,
#   'dado': 10.28506972018096,
#   'obtuvo': 0.0,
#   'infinidad': 0.0,
#   'usando': 0.0,
#   'teoría': 9.542158939916048,
#   'transformación': 0.0},
#  'Problema33': {'principales': 9.82498532438117,
#   'problemas': 10.675792433881902,
#   'sistemas': 9.580799870885532,
#   'normales': 0.0,
#   'sensado': 0.0,
#   'estructuras': 0.0,
#   'presentan': 0.0,
#   'puntuales': 0.0,
#   'necesitan': 0.0,
#   'cableado': 0.0,
#   'protección': 0.0,
#   'resulta': 9.928033812954128,
#   'pesado': 0.0,
#   'incrementado': 0.0,
#   'peso': 9.775028985632325,
#   'total': 10.390194648893312,
#   'estructura': 9.812522917162035,
#   'además': 11.321474360388509,
#   'emplea': 0.0,
#   'alimentación': 0.0,
#   'energía': 10.009692711382444,
#   'mejor': 11.255643264909532,
#   'caso': 11.482249739201768,
#   'emplean': 0.0,
#   'baterías': 0.0,
#   'utiliza': 0.0,
#   'comunicación': 10.018332944205168,
#   'inalámbrica': 0.0,
#   'aunado': 0.0,
#   'ocasiones': 9.681967682338016,
#   'necesita': 0.0,
#   'colocar': 0.0,
#   'sensores': 0.0,
#   'lugares': 0.0,
#   'difícil': 10.207621055054725,
#   'acceso': 0.0,
#   'así': 11.95533305200011,
#   'formar': 0.0,
#   'red': 0.0,
#   'buscar': 9.557540571952371,
#   'mayor': 11.409407694857888,
#   'exactitud': 0.0,
#   'anterior': 10.250970378105945,
#   'involucra': 0.0,
#   'sistema': 10.964917050076522,
#   'adquisición': 0.0,
#   'limitado': 0.0,
#   'número': 10.736070535336799,
#   'canales': 0.0,
#   'requerir': 0.0,
#   'cantidad': 9.990215556045952,
#   'necesitará': 0.0,
#   'varios': 10.472063081843023,
#   'necesario': 10.171566227844085,
#   'entonces': 11.234612696522394,
#   'estudiar': 0.0,
#   'técnicas': 0.0,
#   'actuales': 0.0,
#   'diferentes': 10.28800137389136,
#   'tipos': 9.588228712314113,
#   'fibras': 0.0,
#   'ópticas': 0.0,
#   'estándar': 0.0,
#   'dopadas': 0.0,
#   'tierras': 0.0,
#   'raras': 0.0,
#   'empleo': 0.0,
#   'métodos': 0.0,
#   'menos': 11.547307567829359,
#   'complejos': 0.0,
#   'permitan': 0.0},
#  'Problema34': {'visin': 0.0,
#   'artificial': 0.0,
#   'segmentacin': 0.0,
#   'imgenes': 0.0,
#   'proceso': 10.780288735123806,
#   'particin': 0.0,
#   'imagen': 10.243845088739151,
#   'digital': 0.0,
#   'mltiples': 0.0,
#   'segmentos': 0.0,
#   'conjuntos': 0.0,
#   'pxeles': 0.0,
#   'tambin': 0.0,
#   'conocidos': 0.0,
#   'superpxeles': 0.0,
#   'objetivo': 9.956886129260823,
#   'simplificar': 0.0,
#   'cambiar': 0.0,
#   'representacin': 0.0,
#   'ms': 0.0,
#   'significativo': 0.0,
#   'fcil': 0.0,
#   'analizar': 0.0,
#   'utiliza': 0.0,
#   'normalmente': 0.0,
#   'localizar': 0.0,
#   'objetos': 0.0,
#   'bordes': 0.0,
#   'regiones': 0.0,
#   'lneas': 0.0,
#   'curvas': 0.0,
#   'etc': 10.22951254915098,
#   'precisamente': 9.848503244203368,
#   'asignar': 0.0,
#   'etiqueta': 0.0,
#   'cada': 11.732526749860027,
#   'pxel': 0.0,
#   'modo': 10.680010342017125,
#   'misma': 11.058196580556109,
#   'comparten': 0.0,
#   'ciertas': 0.0,
#   'caractersticas': 0.0,
#   'comunes': 0.0,
#   'resultado': 10.087058328730514,
#   'conjunto': 10.074706030985418,
#   'cubren': 0.0,
#   'colectivamente': 0.0,
#   'toda': 11.187859923930635,
#   'contornos': 0.0,
#   'extrados': 0.0,
#   'ver': 11.104641387298265,
#   'deteccin': 0.0,
#   'regin': 0.0,
#   'similar': 0.0,
#   'respecto': 10.47429759323113,
#   'alguna': 10.606733567773487,
#   'caracterstica': 0.0,
#   'propiedad': 0.0,
#   'calculada': 0.0,
#   'color': 9.979290515951629,
#   'intensidad': 0.0,
#   'textura': 0.0,
#   'adyacentes': 0.0,
#   'significativamente': 0.0,
#   'diferentes': 10.28800137389136,
#   's': 9.698490846702954,
#   'consiste': 0.0,
#   'dicha': 0.0,
#   'similares': 0.0,
#   'predefinida': 0.0,
#   'seres': 0.0,
#   'humanos': 9.793505261799899,
#   'usamos': 0.0,
#   'sentido': 10.769726324511337,
#   'visual': 0.0,
#   'separar': 0.0,
#   'entorno': 0.0,
#   'inmediato': 0.0,
#   'distintos': 9.705950829935693,
#   'esfuerzo': 9.62304587173984,
#   'alguno': 0.0,
#   'reconocerlos': 0.0,
#   'guiar': 0.0,
#   'movimientos': 0.0,
#   'casi': 11.197735153101846,
#   'todas': 11.23211307545407,
#   'actividades': 9.97878053657156,
#   'vida': 11.723923557900767,
#   'kn': 0.0,
#   'plataniotis': 0.0,
#   'anvenetsanopoulos': 0.0,
#   'p': 9.976645073153854,
#   'traducido': 0.0,
#   'importante': 10.787193107312595,
#   'percepcin': 0.0,
#   'humana': 9.622913491543725,
#   'manifiesta': 0.0,
#   'forma': 11.484165843298804,
#   'espontnea': 0.0,
#   'natural': 9.959206041292472,
#   'aunque': 11.657510539927786,
#   'estn': 0.0,
#   'involucrados': 0.0,
#   'procesos': 0.0,
#   'complejos': 0.0,
#   'anlisis': 0.0,
#   'movimiento': 10.22904327741599,
#   'poderosa': 0.0,
#   'robusta': 0.0,
#   'diferenciar': 0.0,
#   'fuente': 0.0,
#   'informacin': 0.0,
#   'puede': 11.990518968113976,
#   'casos': 10.539958555902517,
#   'ser': 12.358467499081977,
#   'utilizado': 0.0,
#   'nica': 0.0,
#   'nico': 0.0,
#   'descriptor': 0.0,
#   'inters': 0.0,
#   'trabajo': 11.257749304074707,
#   'tesis': 0.0,
#   'busca': 9.634300062720511,
#   'investigar': 0.0,
#   'mtodo': 0.0,
#   'propio': 10.518105462931352,
#   'slo': 0.0,
#   'realizar': 9.860893154903707,
#   'considera': 9.646011322141414,
#   'indispensable': 0.0,
#   'paso': 10.460843646427818,
#   'previo': 0.0,
#   'reconocimiento': 0.0,
#   'pretende': 0.0,
#   'llegar': 10.520131587109958,
#   'clases': 0.0,
#   'sino': 11.494201255971948,
#   'nicamente': 0.0,
#   'homogneas': 0.0,
#   'podran': 0.0,
#   'utilizadas': 0.0,
#   'alimentar': 0.0,
#   'tareas': 0.0}}

# %% [markdown]
# ## Create the Vocabulary

# %%
voc = obtainVocSingle(TSU_structured)
voc = obtainVocDouble(TSU_structured, Lic_structured)
voc = obtainVoc(TSU_structured, Lic_structured, Masters_structured, Phd_structured)
len(voc)
# Out:
# 11733

# %% [markdown]
# ## Padding (Dimensionate the Vectors based on the size of the Vocabulary)

# %%
# For TSU
twentyPadRFTSU = dimRelFreq(twentyRFTSU, voc)
twentyPadLFTSU = dimRelFreq(twentyLFTSU, voc)
eightyPadRFTSU = dimRelFreq(eightyRFTSU, voc)
eightyPadLFTSU = dimRelFreq(eightyLFTSU, voc)
twentyPadRFTSU
eightyPadRFTSU
twentyPadLFTSU
eightyPadLFTSU
# For Lic
twentyPadRFLic = dimRelFreq(twentyRFLic, voc)
twentyPadLFLic = dimRelFreq(twentyLFLic, voc)
eightyPadRFLic = dimRelFreq(eightyRFLic, voc)
eightyPadLFLic = dimRelFreq(eightyLFLic, voc)
twentyPadRFLic
twentyPadLFLic
eightyPadRFLic
eightyPadLFLic
# For Masters
twentyPadRFMasters = dimRelFreq(twentyRFMasters, voc)
twentyPadLFMasters = dimRelFreq(twentyLFMasters, voc)
eightyPadRFMasters = dimRelFreq(eightyRFMasters, voc)
eightyPadLFMasters = dimRelFreq(eightyLFMasters, voc)
# For Phd
twentyPadRFPhd = dimRelFreq(twentyRFPhd, voc)
twentyPadLFPhd = dimRelFreq(twentyLFPhd, voc)
eightyPadRFPhd = dimRelFreq(eightyRFPhd, voc)
eightyPadLFPhd = dimRelFreq(eightyLFPhd, voc)

# %% [markdown]
# ## Concatenate Local and Global Vectors

# %%
# TSU
twentyConTSU = concatenateDictionaries(twentyPadRFTSU, twentyPadLFTSU)
eightyConTSU = concatenateDictionaries(eightyPadRFTSU, eightyPadLFTSU)
twentyConLic = concatenateDictionaries(twentyPadRFLic, twentyPadLFLic)
eightyConLic = concatenateDictionaries(eightyPadRFLic, eightyPadLFLic)
twentyConMasters = concatenateDictionaries(twentyPadRFMasters, twentyPadLFMasters)
eightyConMasters = concatenateDictionaries(eightyPadRFMasters, eightyPadLFMasters)
twentyConPhd = concatenateDictionaries(twentyPadRFPhd, twentyPadLFPhd)
eightyConPhd = concatenateDictionaries(eightyPadRFPhd, eightyPadLFPhd)
np.array((twentyConLic)).sum()
np.array((eightyConLic)).sum()
np.array((twentyConMasters)).sum()
np.array((eightyConMasters)).sum()
np.array((twentyConPhd)).sum()
np.array((eightyConPhd)).sum()
# Out:
# 17245.27181305777

# %% [markdown]
# ## Expand and Classify Data

# %%
# HST and Undergraduate
twentyPOneTL, twentyMOneTL = comConData(twentyConTSU, twentyConLic)
eightyPOneTL, eightyMOneTL = comConData(eightyConTSU, eightyConLic)
np.array((twentyPOneTL)).sum()
np.array((twentyMOneTL)).sum()
# HST and Masters
twentyPOneTM, twentyMOneTM = comConData(twentyConTSU, twentyConMasters)
eightyPOneTM, eightyMOneTM = comConData(eightyConTSU, eightyConMasters)
# HST and Phd
twentyPOneTP, twentyMOneTP = comConData(twentyConTSU, twentyConPhd)
eightyPOneTP, eightyMOneTP = comConData(eightyConTSU, eightyConPhd)
# Undergraduate and Masters
twentyPOneUM, twentyMOneUM = comConData(twentyConLic, twentyConMasters)
eightyPOneUM, eightyMOneUM = comConData(eightyConLic, eightyConMasters)
# Undergraduate and Phd
twentyPOneUP, twentyMOneUP = comConData(twentyConLic, twentyConPhd)
eightyPOneUP, eightyMOneUP = comConData(eightyConLic, eightyConPhd)
# Masters and Phd
twentyPOneMP, twentyMOneMP = comConData(twentyConMasters, twentyConPhd)
eightyPOneMP, eightyMOneMP = comConData(eightyConMasters, eightyConPhd)

# %% [markdown]
# ## Append the Data and Create Classification Vector

# %%
# HST and Undergraduate
TLM_test, tly_test = allTogetherNowDouble(twentyPOneTL, twentyMOneTL)
len(TLM_test)
len(tly_test)
TLM_train, tly_train = allTogetherNowDouble(eightyPOneTL, eightyMOneTL)
len(TLM_train)
len(tly_train)
# HST and Masters
TMM_test, tmy_test = allTogetherNowDouble(twentyPOneTM, twentyMOneTM)
TMM_train, tmy_train = allTogetherNowDouble(eightyPOneTM, eightyMOneTM)
#HST and Phd
TPM_test, tpy_test = allTogetherNowDouble(twentyPOneTP, twentyMOneTP)
TPM_train, tpy_train = allTogetherNowDouble(eightyPOneTP, eightyMOneTP)
#Undergraduate and Masters
UMM_test, umy_test = allTogetherNowDouble(twentyPOneUM, twentyMOneUM)
UMM_train, umy_train = allTogetherNowDouble(eightyPOneUM, eightyMOneUM)
#Undergraduate and PhD
UPM_test, upy_test = allTogetherNowDouble(twentyPOneUP, twentyMOneUP)
UPM_train, upy_train = allTogetherNowDouble(eightyPOneUP, eightyMOneUP)
#Masters and PhD
MPM_test, mpy_test = allTogetherNowDouble(twentyPOneMP, twentyMOneMP)
MPM_train, mpy_train = allTogetherNowDouble(eightyPOneMP, eightyMOneMP)

# %%
len(TMM_test[0])
len(TMM_train[0])
# Out:
# 46932

# %% [markdown]
# # HST and Udergraduate

# %% [markdown]
# ## SVM Classifier

# %%
svclassifier = svm.SVC()
svclassifier.fit(TLM_train, tly_train)
# Out:
# /Users/josemedardotapiatellez/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = svclassifier.predict(TLM_test)

print("The accuracy value for the SVM classifier is: {} %".format(obtain_accuracy(tly_test, y_pred)*100))
# Out:
# The accuracy value for the SVM classifier is: 35.08403361344538 %

# %% [markdown]
# ## K Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors = 3)
neigh.fit(TLM_train, tly_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = neigh.predict(TLM_test)
print('The accurracy value for the KNN classifier is: {} %'.format(obtain_accuracy(tly_test, y_pred)*100))
# Out:
# The accurracy value for the KNN classifier is: 44.537815126050425 %

# %% [markdown]
# ## Multilayer Perceptron

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha = 1e-5, hidden_layer_sizes=(5, 2), random_state=1)
clf.fit(TLM_train, tly_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(5, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred = clf.predict(TLM_test)
print("The accuracy value for the Multilayer Perceptron is: {} %".format(obtain_accuracy(tly_test, y_pred)*100))
# Out:
# The accuracy value for the Multilayer Perceptron is: 41.38655462184874 %

# %% [markdown]
# # HST and Masters

# %% [markdown]
# ## SVM Classifier

# %%
svclassifier = svm.SVC()
svclassifier.fit(TMM_train, tmy_train)
# Out:
# /Users/josemedardotapiatellez/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = svclassifier.predict(TMM_test)
print("The accuracy value for the SVM classifier is: {} %".format(obtain_accuracy(tmy_test, y_pred)*100))
# Out:
# The accuracy value for the SVM classifier is: 52.77777777777778 %

# %% [markdown]
# ## K Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors = 3)
neigh.fit(TMM_train, tmy_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = neigh.predict(TMM_test)
print('The accurracy value for the KNN classifier is: {} %'.format(obtain_accuracy(tmy_test, y_pred)*100))
# Out:
# The accurracy value for the KNN classifier is: 56.290849673202615 %

# %% [markdown]
# ## Multilayer Perceptron

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha = 1e-5, hidden_layer_sizes=(5, 2), random_state=1)
clf.fit(TMM_train, tmy_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(5, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred = clf.predict(TMM_test)
print("The accuracy value for the Multilayer Perceptron is: {} %".format(obtain_accuracy(tmy_test, y_pred)*100))
# Out:
# The accuracy value for the Multilayer Perceptron is: 61.356209150326805 %

# %% [markdown]
# # HST and PhD

# %% [markdown]
# ## SVM Classifier

# %%
svclassifier = svm.SVC()
svclassifier.fit(TPM_train, tpy_train)
# Out:
# /Users/josemedardotapiatellez/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = svclassifier.predict(TPM_test)
print("The accuracy value for the SVM classifier is: {} %".format(obtain_accuracy(tpy_test, y_pred)*100))
# Out:
# The accuracy value for the SVM classifier is: 79.83193277310924 %

# %% [markdown]
# ## K Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors = 3)
neigh.fit(TPM_train, tpy_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = neigh.predict(TPM_test)
print('The accurracy value for the KNN classifier is: {} %'.format(obtain_accuracy(tpy_test, y_pred)*100))
# Out:
# The accurracy value for the KNN classifier is: 57.14285714285714 %

# %% [markdown]
# ## Multilayer Perceptron

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha = 1e-5, hidden_layer_sizes=(5, 2), random_state=1)
clf.fit(TPM_train, tpy_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(5, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred = clf.predict(TPM_test)
print("The accuracy value for the Multilayer Perceptron is: {} %".format(obtain_accuracy(tpy_test, y_pred)*100))
# Out:
# The accuracy value for the Multilayer Perceptron is: 86.97478991596638 %

# %% [markdown]
# # Undergraduate and Masters

# %% [markdown]
# ## SVM Classifier

# %%
svclassifier = svm.SVC()
svclassifier.fit(UMM_train, umy_train)
# Out:
# /Users/josemedardotapiatellez/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = svclassifier.predict(UMM_test)
print("The accuracy value for the SVM classifier is: {} %".format(obtain_accuracy(umy_test, y_pred)*100))
# Out:
# The accuracy value for the SVM classifier is: 57.341269841269835 %

# %% [markdown]
# ## K Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors = 3)
neigh.fit(UMM_train, umy_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = neigh.predict(UMM_test)
print('The accurracy value for the KNN classifier is: {} %'.format(obtain_accuracy(umy_test, y_pred)*100))
# Out:
# The accurracy value for the KNN classifier is: 52.083333333333336 %

# %% [markdown]
# ## Multilayer Perceptron

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha = 1e-5, hidden_layer_sizes=(5, 2), random_state=1)
clf.fit(UMM_train, umy_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(5, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred = clf.predict(UMM_test)
print("The accuracy value for the Multilayer Perceptron is: {} %".format(obtain_accuracy(umy_test, y_pred)*100))
# Out:
# The accuracy value for the Multilayer Perceptron is: 68.45238095238095 %

# %% [markdown]
# # Undergraduate and PhD

# %% [markdown]
# ## SVM Classifier

# %%
svclassifier = svm.SVC()
svclassifier.fit(UPM_train, upy_train)
# Out:
# /Users/josemedardotapiatellez/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = svclassifier.predict(UPM_test)
print("The accuracy value for the SVM classifier is: {} %".format(obtain_accuracy(upy_test, y_pred)*100))
# Out:
# The accuracy value for the SVM classifier is: 74.48979591836735 %

# %% [markdown]
# ## K Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors = 3)
neigh.fit(UPM_train, upy_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = neigh.predict(UPM_test)
print('The accurracy value for the KNN classifier is: {} %'.format(obtain_accuracy(upy_test, y_pred)*100))
# Out:
# The accurracy value for the KNN classifier is: 40.816326530612244 %

# %% [markdown]
# ## Multilayer Perceptron

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha = 1e-5, hidden_layer_sizes=(5, 2), random_state=1)
clf.fit(UPM_train, upy_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(5, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred = clf.predict(UPM_test)
print("The accuracy value for the Multilayer Perceptron is: {} %".format(obtain_accuracy(upy_test, y_pred)*100))
# Out:
# The accuracy value for the Multilayer Perceptron is: 64.79591836734694 %

# %% [markdown]
# # Masters and PhD

# %% [markdown]
# ## SVM Classifier

# %%
svclassifier = svm.SVC()
svclassifier.fit(MPM_train, mpy_train)
# Out:
# /Users/josemedardotapiatellez/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = svclassifier.predict(MPM_test)
print("The accuracy value for the SVM classifier is: {} %".format(obtain_accuracy(mpy_test, y_pred)*100))
# Out:
# The accuracy value for the SVM classifier is: 69.04761904761905 %

# %% [markdown]
# ## K Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors = 3)
neigh.fit(MPM_train, mpy_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = neigh.predict(MPM_test)
print('The accurracy value for the KNN classifier is: {} %'.format(obtain_accuracy(mpy_test, y_pred)*100))
# Out:
# The accurracy value for the KNN classifier is: 50.79365079365079 %

# %% [markdown]
# ## Multilayer Perceptron

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha = 1e-5, hidden_layer_sizes=(5, 2), random_state=1)
clf.fit(MPM_train, mpy_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(5, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred = clf.predict(MPM_test)
print("The accuracy value for the Multilayer Perceptron is: {} %".format(obtain_accuracy(mpy_test, y_pred)*100))
# Out:
# The accuracy value for the Multilayer Perceptron is: 79.16666666666666 %
