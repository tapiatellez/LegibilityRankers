# %% [markdown]
# # Legibility

# %% [markdown]
# ## Libraries

# %%
from bs4 import BeautifulSoup
from nltk.stem import PorterStemmer
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import numpy as np
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
#Generate random integer values
from random import seed
from random import randint
import math
#Regular Expressions
import re

# %%
sent = 'This is an example sentence, and it is actually a beautiful one.'
fdist = FreqDist(word_tokenize(sent))
fdist
# Out:
# FreqDist({'is': 2, 'This': 1, 'an': 1, 'example': 1, 'sentence': 1, ',': 1, 'and': 1, 'it': 1, 'actually': 1, 'a': 1, ...})

# %% [markdown]
# ## Functions

# %%
#Functions:
#The following function receives a string indicating the path to follow and
#and returns the data in the file.
def openFile(s):
    file = open(s)
    data_file = file.read()
    file.close()
    return data_file
#The following function receives the data from the stop word's file, splits them
#and extends them.
def cleanStop(sw):
    csw = [ts for ts in sw.split()]
    esw = ['.', ',',';',':', '/','"', '?', '!', '¡', '<', '>', 'El', '>El']
    csw.extend(esw)
    return csw
#   The following function utilizes beautiful soup to obtain the methodologies
#   and put them into
def bsMeth(s):
    # Use beautiful Soup to separate the methodologies
    with open(s) as fp:
        soup = BeautifulSoup(fp, 'xml')
    all = soup.find_all('Justificacion')

    counter = 1
    justificacion = ""
    for met in soup.find_all('Justificacion'):
        [s.extract() for s in met.findAll('Justificacion')]
        ######print("*Metodologia", counter)
        #####print(met)
        justificacion = justificacion + str(met) + "\n"
        #####print("\n")
        counter += 1
    return justificacion
#   The following function receives the methodologies and separates them. It
#   creates a dictionary-matrix with the following structure:
#   Methodologies-Number-Word
def sepMeth(justificacion):
    met_matrix = {}
    counter_met = 1
    for met in justificacion:
        met_vector = {}
        counter_word = 1
        met = [d for d in met.split()]
        for word in met:
            met_vector[counter_word] = word
            counter_word += 1
        if(met_vector):
            met_vector.popitem()
        met_matrix["Justificacion" + str(counter_met)] = met_vector
        counter_met += 1
    return met_matrix

#   The following function receives the Stop Words and the Methodologies and
#   removes the stop words from the methodologies (It basically returns the
#   methodologies clean.).
def cleanMeth(sw, meth):
    cleanMeth_matrix = {}
    for m, m_vector in meth.items():
        cleanMeth_vector = {}
        for num, word in m_vector.items():
            word = word.lower()
            word = re.sub('[^a-zñáéíóú]', '', word)
            if (word not in sw) and word:
                cleanMeth_vector[num] = word
        cleanMeth_matrix[m] = cleanMeth_vector
    return cleanMeth_matrix
#   The following function receives the clean methodologies and returns a
#   dictionary with the structure Methodologies-WordVector
def listMeth(meth):
    listMethMatrix = {}
    for m, m_vector in meth.items():
        listMethVector = []
        for num, word in m_vector.items():
            listMethVector.append(word)
        listMethMatrix[m] = listMethVector
    return listMethMatrix
#   The following function gets the frequency of each word and divides them by
#   the amount of words in the document.
def relFreq(meth):
    freqMethMatrix = {}
    for m, m_vector in meth.items():
        freqMethVector = {}
        sizeM = len(m_vector)
        freq = nltk.FreqDist(m_vector)
        for word, frequency in freq.most_common():
            if word not in freqMethVector:
#                 print('Frequency: {}, SizeM: {}'.format(frequency, sizeM))
                freqMethVector[word] = frequency/sizeM
        freqMethMatrix[m] = freqMethVector
    return freqMethMatrix
#   The following function opens the frequency for the most common words in
#   spanish and returns a dictionary with the following structure: Word-Freq
def mostCommon():
    f = open("frecuencia.txt", "r")
    mostCommonVector = {}
    for line in f:
        line = [d for d in line.split()]
        line[2] = line[2].replace(',', '')
        mostCommonVector[line[1]] = line[2]
    return mostCommonVector
#   The following function receives the dictionary with the sections and
#   returns a Dictionary-Matrix with the following form:
#   Section#-Word:LogFrequency
def logFreq(meth, common):
    logFreqMatrix = {}
    for m, methVector in meth.items():
        logFreqVector = {}
        for word in methVector:
            ####print("Word:", word)
            if (word in common):
                ####print("Word:", word)
                ####print("Value:", common[word])
                logFreqVector[word] = np.log(float(common[word]))
            else:
                logFreqVector[word] = 0.0
        logFreqMatrix[m] = logFreqVector
    return logFreqMatrix
#   The following function receives a single dictionary dictionary of specific
#   sections. It returns a vocabulary based on all the words that appear in the
#   the complete set of documents.
def obtainVocSingle(D):
    voc = []
    for s, svec in D.items():
        for word in svec:
            if word not in voc:
                voc.append(word)
    return voc
#   The following function receives two dictionaries of specific sections. It returns
#   It returns a vocabulary based on all the words that appear in the complete set of
#   documents.
def obtainVocDouble(d1, d2):
    voc = []
    for s, svec in d1.items():
        for word in svec:
            if word not in voc:
                voc.append(word)
    for s, svec in d2.items():
        for word in svec:
            if word not in voc:
                voc.append(word)
    return voc

#   The following function creates a vocabulary for all the words that appear in
#   justifications.
def obtainVoc(TSU, Lic, Maestria, Doctorado):
    vocabulary = []
    for m, mvec in TSU.items():
        for word in mvec:
            if word not in vocabulary:
                vocabulary.append(word)
    for m, mvec in Lic.items():
        for word in mvec:
            if word not in vocabulary:
                vocabulary.append(word)
    for m, mvec in Maestria.items():
        for word in mvec:
            if word not in vocabulary:
                vocabulary.append(word)
    for m, mvec in Doctorado.items():
        for word in mvec:
            if word not in vocabulary:
                vocabulary.append(word)
    return vocabulary
#   The following function creates a vocabulary for all the words that appear in
#   justifications.
def obtainVoc3(TSU, Lic, Maestria):
    vocabulary = []
    for m, mvec in TSU.items():
        for word in mvec:
            if word not in vocabulary:
                vocabulary.append(word)
    for m, mvec in Lic.items():
        for word in mvec:
            if word not in vocabulary:
                vocabulary.append(word)
    for m, mvec in Maestria.items():
        for word in mvec:
            if word not in vocabulary:
                vocabulary.append(word)
    return vocabulary
#   The following function utilizes the vocabulary to dimensionate the relative
#   frequency.
def dimRelFreq(matrix, voc):
    dimRelFreqMatrix = {}
    for j, jvec in matrix.items():
        dimRelFreqVec = {}
        for word in voc:
            if word in jvec:
                dimRelFreqVec[word] = jvec[word]
            else:
                dimRelFreqVec[word] = 0.0
        dimRelFreqMatrix[j] = dimRelFreqVec
    return dimRelFreqMatrix

#   The following function subcatenates two matrices, it subtracts one from the
#   vector from the other and return the result in the following form
#   Justification-ResultantVector
def substract(A, B):
    resultantMatrix = {}
    for (a, avec), (b, bvec) in zip(A.items(), B.items()):
        resultantVec = []
        for (wa, va), (wb, vb) in zip(avec.items(), bvec.items()):
            resultantVec.append(va-vb)
        resultantMatrix[a] = resultantVec
    return resultantMatrix
#   The following function substracts entrance by entrance two dictionary
#   vectors. It returns the result of the subtraction but in a vector, no longer
#   a dictionary.
def substractVec(A, B):
    resultantVec = []
    for (wa, va), (wb, vb) in zip(A.items(), B.items()):
        resultantVec.append(va-vb)
    return resultantVec
#   The following function receives two dictionary matrixes, and concatenates
#   their respective vectors row by row
def concatenate(A, B):
    resultantMatrix = []
    for(a, avec), (b, bvec) in zip(A.items(), B.items()):
        resultantVec = []
        resultantVec = avec + bvec
        ###print(len(resultantVec))
        resultantMatrix.append(resultantVec)
    return resultantMatrix
#   The following function receives two list-vectors and concatenates them in
#   the order A+B. It returns the concatenated vector.
def concatenateVec(A, B):
    resultantVec = A + B
    return resultantVec
#   The followign function receives two dictionary list-vector and concatenates
#   them vector-entry by vector-entry. It returns that concatenation.
def concatenateDictionaries(A, B):
    resultantMatrix = []
    for(a, avec), (b, bvec) in zip(A.items(), B.items()):
        resultantVec = []
        for (wa, va) in avec.items():
            resultantVec.append(va)
        for(wb, vb) in bvec.items():
            resultantVec.append(vb)
        resultantMatrix.append(resultantVec)
    return resultantMatrix
#   The following function receives a dictionary-dictionary and returns a
#   a dictionary-list.
def enlist(A):
    resultantMatrix = {}
    for (a, avec) in (A.items()):
        resultantVec = []
        for(w, v) in avec.items():
            resultantVec.append(v)
        resultantMatrix[a] = resultantVec
    return resultantMatrix
#   The following function receives a dictionary-vector and returns a
#   list.
def enlistVec(A):
    resultantVec = []
    for(w, v) in A.items():
        resultantVec.append(v)
    return resultantVec

#   The following function takes two matrixes A, B and returns a training matrix
#   and a classification matrix. The training matrix contains all the related
#   vectors in a single matrix.
def training(A, B):
    trainingMatrix = []
    classMatrix = []
    for av in A:
        trainingMatrix.append(av)
        classMatrix.append(-1.0)
    for bv in B:
        trainingMatrix.append(bv)
        classMatrix.append(1.0)
    return (trainingMatrix, classMatrix)
#   The following function takes fifty vectors from A, B matrixes and stores
#   them in a single matrix (This will be our training matrix). The Function
#   also creates a vector as the classification vector.
def trainingR(A, B, C, D, E, F):
    trainingMatrix = []
    classMatrix = []
    for av in A:
        trainingMatrix.append(av)
        classMatrix.append(-1.0)
    for cv in C:
        trainingMatrix.append(cv)
        classMatrix.append(-1.0)
    for ev in E:
        trainingMatrix.append(ev)
        classMatrix.append(-1.0)
    for bv in B:
        trainingMatrix.append(bv)
        classMatrix.append(1.0)
    for dv in D:
        trainingMatrix.append(dv)
        classMatrix.append(1.0)
    for fv in F:
        trainingMatrix.append(fv)
        classMatrix.append(1.0)
    return(trainingMatrix, classMatrix)
#   The following function receives two dictionaries and returns the vectors
#   in the dictionary concatenated with the other matrix and a classification
#   matrix.
def trainingL(A, B):
    tMatrix = []
    cMatrix = []
    for a, avec in A.items():
        tMatrix.append(avec)
        cMatrix.append(-1.0)
    for b, bvec in B.items():
        tMatrix.append(bvec)
        cMatrix.append(1.0)
    return (tMatrix, cMatrix)
def trainingLR(A, B, C, D, E, F):
    trainingMatrix = []
    classMatrix = []
    for a, avec in A.items():
        trainingMatrix.append(avec)
        classMatrix.append(-1.0)
    for c, cvec in C.items():
        trainingMatrix.append(cvec)
        classMatrix.append(-1.0)
    for e, evec in E.items():
        trainingMatrix.append(evec)
        classMatrix.append(-1.0)
    for b, bvec in B.items():
        trainingMatrix.append(bvec)
        classMatrix.append(1.0)
    for d, dvec in D.items():
        trainingMatrix.append(dvec)
        classMatrix.append(1.0)
    for f, fvec in F.items():
        trainingMatrix.append(fvec)
        classMatrix.append(1.0)
    return(trainingMatrix, classMatrix)
###############################################
#           Science Contribution              #
###############################################

#   The following function receives a dimensionalized vector from one of the
#   possible classes of justifications and returns a test vector.
def obtainTest(A, B):
    # seed random number generator
    seed(1)
    # generate the random number
    r = randint(0, len(A))
    counter = 0
    testRF = {}
    testLF = {}
    for (wordA, vwordA), (wordB, vwordB) in zip(A.items(), B.items()):
        if counter == r:
            testRF = vwordA
            testLF = vwordB
            impWord = wordA
        counter += 1
    A.pop(impWord)
    B.pop(impWord)
    return (testRF, testLF)

#   The following function receives a Matrix and returns a random vector in it.
#   This vector will be use as a representative vector of the class in order
#   to classify a text file as easier or more difficult than it.
def random(A, B):
    seed(1)
    r = randint(0, len(A))
    counter = 0
    randRF = []
    randLF = []
    for (wordA, vwordA), (wordB, vwordB) in zip(A.items(), B.items()):
        if counter == r:
            randRF = vwordA
            randLF = vwordB
            impWord = wordA
        counter += 1
    A.pop(impWord)
    B.pop(impWord)
    return(randRF, randLF)
#   The following function receives a set of vectors and returns a random vector
#   from the collection.
def randomR(A):
    seed()
    print("Length of vector for random choice:", len(A))
    random = randint(0, len(A)-1)
    randVector = A[random]
    return randVector, random
#   The following function receives a set of matrixes and returns a list of random
#   vectors, one for each matrix.
def obtainRandomVectorsR(A, B, C, D):
    vecList = []
    vecPosition = []
    randomVecA, randomPositionA = randomR(A)
    vecList.append(randomVecA)
    vecPosition.append(randomPositionA)
    randomVecB, randomPositionB = randomR(B)
    vecList.append(randomVecB)
    vecPosition.append(randomPositionB)
    randomVecC, randomPositionC = randomR(C)
    vecList.append(randomVecC)
    vecPosition.append(randomPositionC)
    return vecList
#   The following function receives a set of matrixes and returns a list of random
#   vectors, one for each matrix.
def obtainRandomVectors3(A, B, C):
    vecList = []
    vecPosition = []
    randomVecA, randomPositionA = randomR(A)
    vecList.append(randomVecA)
    vecPosition.append(randomPositionA)
    randomVecB, randomPositionB = randomR(B)
    vecList.append(randomVecB)
    vecPosition.append(randomPositionB)
    randomVecC, randomPositionC = randomR(C)
    vecList.append(randomVecC)
    vecPosition.append(randomPositionC)
    return vecList, vecPosition
#   The following function receives eight matrixes and returns two lists: the
#   first list contains all the random RF vectors and the second list contains
#   LF vectors.
def obtainRandomVectors(A, B, C, D, E, F, G, H):
    vecListRF = [None]*4
    vecListLF = [None]*4
    (vecListRF[0], vecListLF[0]) = random(A, B)
    (vecListRF[1], vecListLF[1]) = random(C, D)
    (vecListRF[2], vecListLF[2]) = random(E, F)
    (vecListRF[3], vecListLF[3]) = random(G, H)

    return (vecListRF, vecListLF)
#   The following function receives eight matrixes two test vector related to
#   RF and LF, the general training matrix and its classyfying vector. The
#   function returns the maximum level of difficulty of the text.
def obtainGrade(lRF, lLF, testRF, testLF, tMatrix, CV):
    #Train the SVM
    clf = svm.SVC()
    clf.fit(tMatrix, CV)

    grade = 0
    goodGrade = 0
    ##print(testRF)
    for (vecRF, vecLF) in zip(lRF, lLF):
        testSubRF = substractVec(testRF, vecRF)
        testSubLF = substractVec(testLF, vecLF)
        conTest = concatenateVec(testSubRF, testSubLF)
        result = clf.predict([conTest])
        #print("Resultado: ")
        #print(result[0])
        if (result[0] == -1.0 or goodGrade>=3):
            #print("Entering results:")
            #print("Grade: ", grade)
            if(grade == 0):
                print("Your text is as good as TSU.")
            elif(grade == 1):
                print("Your text is as good as Lic.")
            elif(grade == 2):
                print("Your text is as good as Maestria.")
            elif(grade >= 3):
                print("Your text is as good as Doctorado.")
            break
        else:
            goodGrade += 1

        grade = grade + 1
#   The following function receives a list with the respective centroids, a
#   vector test in order to try and the training matrix with its respective
#   classes.
def obtainGradeR(centroidList, testRF, testLF, tMatrix, CV):
    clf = svm.SVC()
    clf.fit(tMatrix, CV)

    grade = 0
    goodGrade = 0
    #print(testRF)
    #print(len(testRF))
    testRF = enlistVec(testRF)
    testLF = enlistVec(testLF)
    conTest = concatenateVec(testRF, testLF)
    conTest = np.array(conTest)
    #print(conTest)
    #print(len(conTest))
    result = clf.predict([conTest])
    for vec in centroidList:
        vec = np.array(vec)
        #print(vec)
        #print(len(vec))
        subVec = conTest - vec
        #print(subVec)
        #print(len(subVec))
        result = clf.predict([subVec])
        #print(result)
        if (result[0] == -1.0 or goodGrade>=3):
            if(grade == 0):
                print("Your text is as good as TSU.")
            elif(grade == 1):
                print("Your text is as good as Lic.")
            elif(grade == 2):
                print("Your text is as good as Maestria.")
            elif(grade >= 3):
                print("Your text is as good as Doctorado.")
            break
        else:
            goodGrade += 1

        grade = grade + 1
#   The following function receives a test vector and a list of random vectors.
#   It returns the grade of the vector.
def obtainGradeRandom(vector, vector_list, clf):
    grade = 0
    goodGrade = 0
    for vec in vector_list:
        vector = vector - vec
        result = clf.predict([vector])
        #print("Result: ", result)
        if (result[0] == -1.0 or goodGrade>=3):
            if(grade == 0):
                #print("Your text is as good as TSU.")
                return 0
            elif(grade == 1):
                #print("Your text is as good as Lic.")
                return 1
            elif(grade >= 2):
                #print("Your text is as good as Maestria.")
                return 2
            break
        else:
            goodGrade += 1

        grade = grade + 1
#   The following function receives a testMatrix, its vector classification and a
#   list of random vector. It returns the accuracy of the evaluator.
def randomEvaluator(test_matrix, classification, vector_list, clf):
    acc = 0
    print("Test Matrix: ")
    print(test_matrix)
    print("Length of Random: ", len(test_matrix))
    for i in range(len(test_matrix)):
        grade = obtainGradeRandom(test_matrix[i], vector_list, clf)
        #print("Grade: ", grade)
        #print("Classification: ", int(classification[i]))
        if grade == int(classification[i]):
            acc += 1
    return acc/len(test_matrix)
# #   The following function receives a testMatrix, its vector classification and a
# #   list of random vector and the plain justifications. It returns the justification
# #   and its respective classification wether it was wrong or not.
def getJustificationEvaluation(test_matrix, classification, vector_list, clf, justificacionTSU, justificacionLic, justificacionMaestria):
    acc = 0
    print("Test Matrix: ")
    print(test_matrix)
    print("Length of Random: ", len(test_matrix))
    counter = 1
    for i in range(len(test_matrix)):
        grade = obtainGradeRandom(test_matrix[i], vector_list, clf)
        #print("Grade: ", grade)
        #print("Classification: ", int(classification[i]))
        if counter <= 11:
            print("Justificacion de TSU:")
            if grade == int(classification[i]):
                print("Justificacion Correcta: ")
                print(justificacionTSU[counter])
                acc += 1
            else:
                print("Justificacion Incorrecta: ")
                print(justificacionTSU[counter])
            counter += 1
        elif 12<= counter <=23:
            print("Justificaciones de Licenciatura")
            if grade == int(classification[i]):
                print("Justificacion Correcta: ")
                print(justificacionLic[counter])
                acc += 1
            else:
                print("Justificacion Incorrecta: ")
                print(justificacionLic[counter])
            counter += 1
        else:
            print("Justificaciones de Maestria: ")
            if grade == int(classification[i]):
                print("Justificacion Correcta: ")
                print(justificacionMaestria[counter])
                acc += 1
            else:
                print("Justificacion Incorrecta: ")
                print(justificacionMaestria[counter])
            counter += 1

    return acc/len(test_matrix)
#   The following function receives all the justifications for all the different
#   scholar levels and a list for the positions of the random vectors.
#   It returns the random selected vectors and prints them in screen.
def getRandomJustifications(list, A, B, C):
    print("TSU random justification:")
    print(A[list[0]+6])
    print("Lic. random justification: ")
    print(A[list[1]+6])
    print("Maestria random justification: ")
    print(A[list[2]+6])


#   The following function receives two matrixes, one related to the Relative
#   Frequency vectors and one related to the Logarithmic Frequency. It concatenates
#   them, tranforms them into a vector instead of a dictionary and returns the
#   centroid of them all.
def centroid(A, B):
    A = enlist(A)
    B = enlist(B)
    M = concatenate(A, B)
    #Transform into a numpy array
    Marray = np.array(M)
    length = len(Marray)
    centroid = np.zeros(33642)
    for vec in Marray:
        centroid = np.add(centroid, vec)
    centroid = centroid*(1/len(M[0]))
    return centroid

def centroidR(A, B):
    A = enlist(A)
    B = enlist(B)
    M = concatenate(A, B)
    length = len(M)
    centroid = np.zeros(33642)
    for i in range(length):
        for j in range(len(M[0])):
            centroid[j] = centroid[j] + M[i][j]
    for j in range(len(M[0])):
        centroid[j] = centroid[j]/(len(M[0]))
    return centroid
#   The following function receives a matrix and returns its centroid.
def centroidRR(A):
    centroid = np.zeros(len(A[0]))
    for vec in A:
        centroid = centroid + vec
    return centroid/(len(A))
#   The following function receives the test matrix, the classification vector,
#   the centroid list and the svm classifier. It returns the accuracy of the centroid
#   evaluator.
def centroidEvaluator(test_matrix, classification, centroids, clf):
    acc = 0
    for i in range(len(test_matrix)):
        grade = obtainGradeRandom(test_matrix[i], centroids, clf)
        #print("Grade: ", grade)
        #print("Classification: ", int(classification[i]))
        if grade == int(classification[i]):
            acc += 1
    return acc/len(test_matrix)
#   The following function receives four matrixes and returns a list of centroids.
#   One for each matrix.
def obtainCentroids(A, B, C, D):
    list = []
    list.append(centroidRR(A))
    list.append(centroidRR(B))
    list.append(centroidRR(C))
    list.append(centroidRR(D))
    return list
#   The following function receives four matrixes and returns a list of centroids.
#   One for each matrix.
def obtainCentroids3(A, B, C):
    list = []
    list.append(centroidRR(A))
    list.append(centroidRR(B))
    list.append(centroidRR(C))
    return list
#   The following function removes the len zero vectors from the dictionary and
#   returns a dictionary.
def removeZero(GM):
    l = []
    for n, w_vec in GM.items():
        if len(w_vec) == 0:
            l.append(n)
    for e in l:
        del GM[e]
    return GM

#   The follwing function receives a matrix and eliminates the zero lenght vectors
#   from it.
def cleanVector(A):
    return removeZero(A)

#   The following function receives the four grade matrixes and eliminates the
#   zero length vectors from it.
def cleanVectors(A, B, C, D):
    
    return removeZero(A), removeZero(B), removeZero(C), removeZero(D)
#   The following function gets the size of the smallest vector in the dictionary
#   vector-word matrix.
def smallest(GM):
    smallestValue = 1000000
    for n, w_vec in GM.items():
        if smallestValue > len(w_vec):
            smallestValue = len(w_vec)
    return smallestValue
#   The following function gets the size of the biggest vector in the dictionry
#   vector-word matrix.
def biggest(GM):
    biggestValue = 0
    for n, w_vec in GM.items():
        if biggestValue < len(w_vec):
            biggestValue = len(w_vec)
    return biggestValue
#   The following function receives a grade matrix and returns the average size
#   of the vectors in it.
def average(GM):
    averageValue = 0
    allElements = len(GM)
    for n, w_vec in GM.items():
        averageValue = averageValue + len(w_vec)
    return (averageValue/allElements)
#   The following function receives a grade matrix and returns a dictionary with
#   the size of the smallest vector, the biggest vector and the average sizes
#   of the vectors.
def returnSizes(GM):
    sizes = {}
    sizes['Smallest'] = smallest(GM)
    sizes['Biggest'] = biggest(GM)
    sizes['Average'] = average(GM)
    return sizes
#   The following function receives two grade matrixes dimensionalized and concatenated
#   and returns the substraction of both of them.
def subInc(A, B):
    matrix = []
    A = np.array(A)
    B = np.array(B)
    for vecA in A:
        for vecB in B:
            matrix.append(vecA - vecB)
    return matrix
#   The following function receives two matrices dimensionalized and concatenated
#   and returns their conmutative combination in two differente matrices. The plusOne
#   and the minusOne.
def comData(A, B):
    plusOne = subInc(B, A)
    minusOne = subInc(A, B)
    return plusOne, minusOne
#   The following function receives a matrix and returns the 80 percent of the values
#   in one matrix and the other twenty in another matrix.
def eightyTwenty(A):
    m = np.array([])
    twenty = math.ceil(len(A)*(1/5))
    for i in range(twenty):
        np.append(m, A[i], 0)
        np.delete(A, i, 0)
    return A, m
#   The following function receives the plusOne and minusOne version for all the grades
#   and returns the training matrix along with its classification vector.
def allTogetherNow(POT, MOT, POL, MOL, POM, MOM):
    M = np.array([])
    y = np.array([])
    M = np.append(POT, POL, 0)
    M = np.append(M, POM, 0)
    M = np.append(M, MOT, 0)
    M = np.append(M, MOL, 0)
    M = np.append(M, MOM, 0)
    y1 = np.ones(len(POT) + len(POL) + len(POM))
    y2 = np.zeros(len(MOT) + len(MOL) + len(MOM))
    y2 = y2-1
    y = np.append(y1, y2, 0)
    return M, y
#   The following function receives plusOne and minusOne version for all the grades
#   and returns the training matrix along with its classification vector.
def allTogetherNow(POT, MOT, POL, MOL):
    M = np.array([])
    y = np.array([])
    M = np.append(POT, POL, 0)
    M = np.append(M, MOT, 0)
    M = np.append(M, MOL, 0)
    y1 = np.ones(len(POT) + len(POL))
    y2 = np.zeros(len(MOT) + len(MOL))
    y2 = y2-1
    y = np.append(y1, y2, 0)
    return M, y
#   The following function receives a plusOne and a minusOne matrix. It returns a 
#   an appended matrix of the both along with its classification vector.
def allTogetherNowDouble(PO, MO):
    M = np.array([])
    y = np.array([])
    M = np.append(PO, MO, axis = 0)
    y1 = np.ones(len(PO))
    y2 = np.zeros(len(MO))
    y = np.append(y1, y2, axis = 0)
    return M, y

#   The following function receives a dictionary-list matrix and returns eighty
#   percent of the vectors in one matrix and the other twenty percent in another
#   matrix.
def divideEightyTwenty(M):
    twenty = {}
    eighty = {}
    counter = 0
    stop = int(len(M)/5)
    for v, vvec in M.items():
        if counter <= stop:
            twenty[v] = vvec
        else:
            eighty[v] = vvec
        counter += 1
    return twenty, eighty
#   The following function receives two matrixes the plusOne and the minusOne and
#   returns it's respective trainingMatrix with their related classification vector.
def togetherNow(A, B):
    M = np.array([])
    y = np.array([])
    M = np.append(A,B,0)
    y1 = np.ones(len(A))
    y2 = np.zeros(len(B))
    y2 = y2-1
    y = np.append(y1, y2, 0)
    return M, y
#   The following function divides our whole training set into 80 percent for
#   training and 20 percent for testing. It returns both matrixes.
def getEightyTwenty(M, y):
    print("Enter Eighty Twenty")
    np.c_[M, y]
    length = len(M)
    testMatrix = np.array([])
    print(int(length*(1/5)))
    seed(1)
    for i in range(int(length*(1/5))):
        print(i)
        random = randint(0, length)
        np.append(testMatrix, M[random])
        np.delete(M, random, 0)
    with open('traingMatrix.txt', 'wb') as f:
        for line in trainingMatrix:
            np.savetxt(f, line, fmt = '%.2f')
    return trainingMatrix, testMatrix
#   The following function receives the M matrix which corresponds to the training
#   objects and the test matrix. It first trains the SVM for later test the accuracy
#   of it five times. Finally it returns the five accuracies along with its standard
#   deviation.
def testAccuracy(M, tM):
    #Get the training Matrix just values
    M = np.array(M)
    y = M[:, len(M[0])-1]
    M = np.delete(M, len(M[0])-1, 1)
    yt = tM[:, len(tM[0])-1]
    tM = np.delete(tM, len(tM[0])-1, 1)
    # Train the svm
    clf = svm.SVC()
    clf.fit(M)
    for i in range(5):
        counter = 0
        for j in range(len(tM)):
            if clf.predict(tM[i]) == y[i]:
                counter += 1
        accuracy.append(counter/len(tM))
    return accuracy
#   The following function receives four matrixes and constructs a single matrix
#   with the vectors of all the other matrixes and a vector with their grade
#   classification.
def testEvaluatorMatrix(A, B, C, D):
    M = np.array([])
    M = np.concatenate((A, B), axis = 0)
    M = np.concatenate((M, C), axis = 0)
    M = np.concatenate((M, D), axis = 0)
    y = np.array([])
    y1 = np.zeros(len(A))
    y2 = np.zeros(len(B)) + 1
    y3 = np.zeros(len(C))  + 2
    y4 = np.zeros(len(D)) + 3
    y = np.concatenate((y1, y2), axis = 0)
    y = np.concatenate((y, y3), axis = 0)
    y = np.concatenate((y, y4), axis = 0)
    return M, y
#   The following function receives four matrixes and constructs a single matrix
#   with the vectors of all the other matrixes and a vector with their grade
#   classification.
def testEvaluatorMatrix3(A, B, C):
    M = np.array([])
    M = np.concatenate((A, B), axis = 0)
    M = np.concatenate((M, C), axis = 0)
    y = np.array([])
    y1 = np.zeros(len(A))
    y2 = np.zeros(len(B)) + 1
    y3 = np.zeros(len(C))  + 2
    y = np.concatenate((y1, y2), axis = 0)
    y = np.concatenate((y, y3), axis = 0)
    return M, y
#   The following function receives a number (amount of specific sections to retrieve) and
#   a dictionary of specific sections.
def getNVector(n, A):
    rA = {}
    counter = 0
    stop = n
    for (a, avec) in A.items():
        if counter < stop: 
            rA[a] = avec
        else:
            break
        counter += 1
    return rA
#   The following function receives four matrixes and a number. It returns the
#   amount of vectors in the number for each of the matrixes.
def getNVectors(n, A, B, C, D):
    rA = {}
    rB = {}
    rC = {}
    rD = {}
    for (a, avec), (b, bvec), (c, cvec), (d, dvec) in zip (A.items(), B.items(), C.items(), D.items()):
        rA[a] = avec
        rB[b] = bvec
        rC[c] = cvec
        rD[d] = dvec
    return rA, rB, rC, rD
#   The following function receives three matrixes and a number. It returns the
#   amount of vectors in the number for each of the matrixes.
def get3NVectors(n, A, B, C):
    rA = {}
    rB = {}
    rC = {}
    counter = 0
    stop = n
    for (a, avec), (b, bvec), (c, cvec) in zip (A.items(), B.items(), C.items()):
        if counter < stop:
            rA[a] = avec
            rB[b] = bvec
            rC[c] = cvec
        else:
            break
        counter+=1
    return rA, rB, rC
#   The following function receives two vectors, actual results for the test vector and the
#   predicted vector produced by our classifier, it then returns the accuracy report for
#   our classifier. Accuracy considered as number of correct predictions divided by total
#   number of predictions made.
def obtain_accuracy(a, b):
    correct = np.where(a == b)
    return np.size(correct)/np.size(a)
    

#   Open the stop words file.
sw = openFile("stopWords.txt")
#   Curate the stop words.
sw = cleanStop(sw)
sw
# Out:
# ['a',
#  'al',
#  'algo',
#  'algunas',
#  'algunos',
#  'ante',
#  'antes',
#  'como',
#  'con',
#  'contra',
#  'cual',
#  'cuando',
#  'de',
#  'del',
#  'desde',
#  'donde',
#  'durante',
#  'e',
#  'el',
#  'ella',
#  'ellas',
#  'ellos',
#  'en',
#  'entre',
#  'era',
#  'erais',
#  'eran',
#  'eras',
#  'eres',
#  'es',
#  'esa',
#  'esas',
#  'ese',
#  'eso',
#  'esos',
#  'esta',
#  'estaba',
#  'estabais',
#  'estaban',
#  'estabas',
#  'estad',
#  'estada',
#  'estadas',
#  'estado',
#  'estados',
#  'estamos',
#  'estando',
#  'estar',
#  'estaremos',
#  'estará',
#  'estarán',
#  'estarás',
#  'estaré',
#  'estaréis',
#  'estaría',
#  'estaríais',
#  'estaríamos',
#  'estarían',
#  'estarías',
#  'estas',
#  'este',
#  'estemos',
#  'esto',
#  'estos',
#  'estoy',
#  'estuve',
#  'estuviera',
#  'estuvierais',
#  'estuvieran',
#  'estuvieras',
#  'estuvieron',
#  'estuviese',
#  'estuvieseis',
#  'estuviesen',
#  'estuvieses',
#  'estuvimos',
#  'estuviste',
#  'estuvisteis',
#  'estuviéramos',
#  'estuviésemos',
#  'estuvo',
#  'está',
#  'estábamos',
#  'estáis',
#  'están',
#  'estás',
#  'esté',
#  'estéis',
#  'estén',
#  'estés',
#  'fue',
#  'fuera',
#  'fuerais',
#  'fueran',
#  'fueras',
#  'fueron',
#  'fuese',
#  'fueseis',
#  'fuesen',
#  'fueses',
#  'fui',
#  'fuimos',
#  'fuiste',
#  'fuisteis',
#  'fuéramos',
#  'fuésemos',
#  'ha',
#  'habida',
#  'habidas',
#  'habido',
#  'habidos',
#  'habiendo',
#  'habremos',
#  'habrá',
#  'habrán',
#  'habrás',
#  'habré',
#  'habréis',
#  'habría',
#  'habríais',
#  'habríamos',
#  'habrían',
#  'habrías',
#  'habéis',
#  'había',
#  'habíais',
#  'habíamos',
#  'habían',
#  'habías',
#  'han',
#  'has',
#  'hasta',
#  'hay',
#  'haya',
#  'hayamos',
#  'hayan',
#  'hayas',
#  'hayáis',
#  'he',
#  'hemos',
#  'hube',
#  'hubiera',
#  'hubierais',
#  'hubieran',
#  'hubieras',
#  'hubieron',
#  'hubiese',
#  'hubieseis',
#  'hubiesen',
#  'hubieses',
#  'hubimos',
#  'hubiste',
#  'hubisteis',
#  'hubiéramos',
#  'hubiésemos',
#  'hubo',
#  'la',
#  'las',
#  'le',
#  'les',
#  'lo',
#  'los',
#  'me',
#  'mi',
#  'mis',
#  'mucho',
#  'muchos',
#  'muy',
#  'más',
#  'mí',
#  'mía',
#  'mías',
#  'mío',
#  'míos',
#  'nada',
#  'ni',
#  'no',
#  'nos',
#  'nosotras',
#  'nosotros',
#  'nuestra',
#  'nuestras',
#  'nuestro',
#  'nuestros',
#  'o',
#  'os',
#  'otra',
#  'otras',
#  'otro',
#  'otros',
#  'para',
#  'pero',
#  'poco',
#  'por',
#  'porque',
#  'que',
#  'quien',
#  'quienes',
#  'qué',
#  'se',
#  'sea',
#  'seamos',
#  'sean',
#  'seas',
#  'seremos',
#  'será',
#  'serán',
#  'serás',
#  'seré',
#  'seréis',
#  'sería',
#  'seríais',
#  'seríamos',
#  'serían',
#  'serías',
#  'seáis',
#  'sido',
#  'siendo',
#  'sin',
#  'sobre',
#  'sois',
#  'somos',
#  'son',
#  'soy',
#  'su',
#  'sus',
#  'suya',
#  'suyas',
#  'suyo',
#  'suyos',
#  'sí',
#  'también',
#  'tanto',
#  'te',
#  'tendremos',
#  'tendrá',
#  'tendrán',
#  'tendrás',
#  'tendré',
#  'tendréis',
#  'tendría',
#  'tendríais',
#  'tendríamos',
#  'tendrían',
#  'tendrías',
#  'tened',
#  'tenemos',
#  'tenga',
#  'tengamos',
#  'tengan',
#  'tengas',
#  'tengo',
#  'tengáis',
#  'tenida',
#  'tenidas',
#  'tenido',
#  'tenidos',
#  'teniendo',
#  'tenéis',
#  'tenía',
#  'teníais',
#  'teníamos',
#  'tenían',
#  'tenías',
#  'ti',
#  'tiene',
#  'tienen',
#  'tienes',
#  'todo',
#  'todos',
#  'tu',
#  'tus',
#  'tuve',
#  'tuviera',
#  'tuvierais',
#  'tuvieran',
#  'tuvieras',
#  'tuvieron',
#  'tuviese',
#  'tuvieseis',
#  'tuviesen',
#  'tuvieses',
#  'tuvimos',
#  'tuviste',
#  'tuvisteis',
#  'tuviéramos',
#  'tuviésemos',
#  'tuvo',
#  'tuya',
#  'tuyas',
#  'tuyo',
#  'tuyos',
#  'tú',
#  'un',
#  'una',
#  'uno',
#  'unos',
#  'vosotras',
#  'vosotros',
#  'vuestra',
#  'vuestras',
#  'vuestro',
#  'vuestros',
#  'y',
#  'ya',
#  'yo',
#  'él',
#  'éramos',
#  '.',
#  ',',
#  ';',
#  ':',
#  '/',
#  '"',
#  '?',
#  '!',
#  '¡',
#  '<',
#  '>',
#  'El',
#  '>El']

# %%
# !ls
# Out:
# AvancesRecuperacionDeInformacion-3.pdf obtainMet1.0.py
# Doctorado.xml                          obtainMet10.0.py
# LegibilityRevisedJustification.py      obtainMet2.0.py
# Licenciatura.xml                       obtainMet3.0.py
# Maestria.xml                           obtainMet4.0.py
# SoftwareRevision.ipynb                 obtainMet5.0.py
# TSU.xml                                obtainMet6.0.py
# completeTrainingData.txt               obtainMet6.0py.py
# frecuencia.txt                         obtainMet7.0.py
# justificacionDoctorado.xml             obtainMet8.0.py
# justificacionLic.xml                   obtainMet9.0.py
# justificacionMaestria.xml              rp_svm.py
# justificacionTSU.xml                   stopWords.txt
# obatinMet9.0.py                        tesis.xml
# obtainMet.py

# %% [markdown]
# # Main

# %% [markdown]
# ## Obtain Justifications

# %%
justificationTSU = bsMeth('justificacionTSU.xml')
justificationLic = bsMeth('justificacionLic.xml')
justificationMasters = bsMeth('justificacionMaestria.xml')
justificationPhd = bsMeth('justificacionDoctorado.xml')
justificationTSU
justificationLic
justificationMasters
justificationPhd
# Out:
# '<Justificacion>En la sección anterior se ha evidenciado la importancia de las WNN y las ventajas que\nofrecen estos modelos sobre las RNA con pesos, y se han fundamentado estos hechos con\nreferencias bibliográficas correspondientes a trabajos de investigación científica de punta realizada por equipos internacionales. Por otro lado, se ha enfatizado la existencia, la importancia y la aplicación de los modelos asociativos Alfa-Beta, cuyas características más importantes son similares a las que exhiben las WNN, en cuanto eficacia, eficiencia y facilidad de implementación.\nCiertamente algunos connotados autores en el área de las redes neuronales sin pesos\nhan creado modelos relacionados con memorias asociativas [6, 8, 19, 30, 56, 79]; otros, han incursionado en los modelos asociativos Alfa-Beta [19-24, 70], o bien, han realizado\nimplementaciones en hardware de algunos modelos conocidos de redes neuronales sin\npesos [25-29, 41, 60, 67, 72, 74-77, 91]. Sin embargo, hasta noviembre de 2007, no se han\nreportado en la literatura trabajos científicos donde se relacionen específicamente las redes neuronales sin pesos con los modelos de memorias asociativas Alfa-Beta.\nEl presente trabajo de tesis queda justificado porque incluye, de manera central, la\ncreación y diseño de un nuevo modelo de redes neuronales sin pesos, basado en los\noperadores Alfa y Beta, los cuales son tomados de los modelos de memorias asociativas\nAlfa-Beta. Por otro lado, se establecen las condiciones necesarias y suficientes de\nequivalencia de las redes neuronales sin pesos y los circuitos booleanos, y se presenta un\nestudio completo de factibilidad de implementación en hardware del nuevo modelo, el cual\nexhibe un alto desempeño, derivado del hecho de que es un hecho ya probado que la\ndensidad aritmética de los modelos de memorias asociativas Alfa y Beta es menor que la\notros modelos relevantes de memorias asociativas, como las morfológicas [18].</Justificacion>\n<Justificacion>La idea de considerar la necesidad de seguridad de redes ad hoc no es nueva, inclusive en redes de sensores hay ataques específicos ante los cuales es necesario utilizar mecanismos de proteccion para evitar ataques de suplantacion y negacion de servicios, entre otros posibles; sin embargo no todas las tecnicas utilizadas en soluciones a estos problemas en redes ad hoc, no son del todo aplicables en una WSN.\nCon el fin de establecer claramente los riesgos a que se expone la informacion en una WSN en un ataque, conviene retomar una definición de la seguridad de la informacion, la cual consiste en otorgarle a la informacion cuatro propiedades basicas, como se indica en [50]:\nConfidencialidad, Autenticidad, Integridad,Disponibilidad.\nCon base en estas cuatro propiedades, los escenarios de riesgo en una WSN, y sobre todo, considerando el impacto de un ataque sobre la operacion de la red, se considera que el problema de la suplantacion de nodos es uno de los mas severos dada la mecanica de operacion de la red. A fin de ilustrar esta situacion, en las siguientes líneas se plantea un ataque hipotetico.\nUna red de WSN con topología ad hoc esta formada por varios nodos, entre los cuales existe una relacion de confianza mutua, por lo que cada uno puede establecer enlaces con cualquier otro nodo que este dentro de su area de cobertura. Estos enlaces permiten a la WSN cumplir sus dos funciones basicas: recoleccion y transporte de datos y órdenes de control de la red. En las condiciones mas críticas, no se tiene forma alguna de establecer\nautenticidad entre los nodos de la red.\nPara esta red, la ejecucion de un ataque de suplantacion es una situacion no muy ajena a la realidad. Este ataque puede llevarse a cabo por lo menos de las siguientes dos formas:\nCon la captura de un nodo y la manipulacion del mismo.\nCon la incorporacion de un dispositivo que se haga pasar por un nodo de la red autentico.\nLa realizacion del primer ataque es muy simple, ya que como se ha dicho anteriormente, un ...

# %% [markdown]
# ## Separate Justifications

# %%
justificationTSU = [j for j in justificationTSU.split("<Justificacion>")]
justificationLic = [j for j in justificationLic.split("<Justificacion>")]
justificationMasters = [j for j in justificationMasters.split('<Justificacion>')]
justificationPhd = [j for j in justificationPhd.split('<Justificacion>')]
justificationTSU
justificationLic
justificationMasters
justificationPhd
# Out:
# ['',
#  'En la sección anterior se ha evidenciado la importancia de las WNN y las ventajas que\nofrecen estos modelos sobre las RNA con pesos, y se han fundamentado estos hechos con\nreferencias bibliográficas correspondientes a trabajos de investigación científica de punta realizada por equipos internacionales. Por otro lado, se ha enfatizado la existencia, la importancia y la aplicación de los modelos asociativos Alfa-Beta, cuyas características más importantes son similares a las que exhiben las WNN, en cuanto eficacia, eficiencia y facilidad de implementación.\nCiertamente algunos connotados autores en el área de las redes neuronales sin pesos\nhan creado modelos relacionados con memorias asociativas [6, 8, 19, 30, 56, 79]; otros, han incursionado en los modelos asociativos Alfa-Beta [19-24, 70], o bien, han realizado\nimplementaciones en hardware de algunos modelos conocidos de redes neuronales sin\npesos [25-29, 41, 60, 67, 72, 74-77, 91]. Sin embargo, hasta noviembre de 2007, no se han\nreportado en la literatura trabajos científicos donde se relacionen específicamente las redes neuronales sin pesos con los modelos de memorias asociativas Alfa-Beta.\nEl presente trabajo de tesis queda justificado porque incluye, de manera central, la\ncreación y diseño de un nuevo modelo de redes neuronales sin pesos, basado en los\noperadores Alfa y Beta, los cuales son tomados de los modelos de memorias asociativas\nAlfa-Beta. Por otro lado, se establecen las condiciones necesarias y suficientes de\nequivalencia de las redes neuronales sin pesos y los circuitos booleanos, y se presenta un\nestudio completo de factibilidad de implementación en hardware del nuevo modelo, el cual\nexhibe un alto desempeño, derivado del hecho de que es un hecho ya probado que la\ndensidad aritmética de los modelos de memorias asociativas Alfa y Beta es menor que la\notros modelos relevantes de memorias asociativas, como las morfológicas [18].</Justificacion>\n',
#  'La idea de considerar la necesidad de seguridad de redes ad hoc no es nueva, inclusive en redes de sensores hay ataques específicos ante los cuales es necesario utilizar mecanismos de proteccion para evitar ataques de suplantacion y negacion de servicios, entre otros posibles; sin embargo no todas las tecnicas utilizadas en soluciones a estos problemas en redes ad hoc, no son del todo aplicables en una WSN.\nCon el fin de establecer claramente los riesgos a que se expone la informacion en una WSN en un ataque, conviene retomar una definición de la seguridad de la informacion, la cual consiste en otorgarle a la informacion cuatro propiedades basicas, como se indica en [50]:\nConfidencialidad, Autenticidad, Integridad,Disponibilidad.\nCon base en estas cuatro propiedades, los escenarios de riesgo en una WSN, y sobre todo, considerando el impacto de un ataque sobre la operacion de la red, se considera que el problema de la suplantacion de nodos es uno de los mas severos dada la mecanica de operacion de la red. A fin de ilustrar esta situacion, en las siguientes líneas se plantea un ataque hipotetico.\nUna red de WSN con topología ad hoc esta formada por varios nodos, entre los cuales existe una relacion de confianza mutua, por lo que cada uno puede establecer enlaces con cualquier otro nodo que este dentro de su area de cobertura. Estos enlaces permiten a la WSN cumplir sus dos funciones basicas: recoleccion y transporte de datos y órdenes de control de la red. En las condiciones mas críticas, no se tiene forma alguna de establecer\nautenticidad entre los nodos de la red.\nPara esta red, la ejecucion de un ataque de suplantacion es una situacion no muy ajena a la realidad. Este ataque puede llevarse a cabo por lo menos de las siguientes dos formas:\nCon la captura de un nodo y la manipulacion del mismo.\nCon la incorporacion de un dispositivo que se haga pasar por un nodo de la red autentico.\nLa realizacion del primer ataque es muy simple, ya que como se ha dicho anteriormente, uno de los problemas del dispositivo en sí es la facilidad de ser capturado, ya que la mayoría de las veces los sensores no cuentan con mecanismos de proteccion física alguna, ademas de estar expuestos a fallas, e interrupcion en su servicio.\nPara el caso del segundo ataque, si bien se requiere la construccion de un\nsensor compatible con la WSN, esto no parece ser muy complicado una vez que se tiene la posibilidad de capturar uno o mas nodos originales y recuperar informacion del mismo que permita completar la construccion.\nDada la dinámica de operacion de las WSN, y las posibilidades de ocurrencia de un ataque de suplantacion, es conveniente evaluar que tan graves podrían ser los daños en caso de la realizacion del mismo para así tener una mejor perspectiva del enfoque del problema que adopta el presente estudio.\nBajo la suposicion que un tercer elemento ha logrado suplantar un nodo autentico en la red, los daños generados a partir de tal accion pueden agruparse en dos casos generales:\n1. Una parte de la informacion recolectada por la WSN tendra que hacer un salto a traves del nodo comprometido, esto pone en riesgo la disponibilidad, la integridad y la confidencialidad de dicha informacion, ya que ésta podría perderse, alterarse o en un caso extremo, ser expuestos a terceros no autorizados.\n2. De igual forma, las órdenes de control que viajan por la red pueden ser interceptadas y alteradas al momento de pasar por el nodo comprometido, acarreando un mal funcionamiento de la WSN, llegando en algunos casos incluso a poner en riesgo la integridad de elementos circundantes al sensor o del sensor mismo.\nLa ocurrencia de cualquiera de estos casos anteriores sería en menoscabo de la operacion de la WSN, lo que repercutiría en consecuencias acordes a la importancia de la mision que desempeñe dicha red. Esto deja sobre la mesa la necesidad de contar con mecanismos de autenticidad que operen en las WSNs.\nEn terminos generales, el problema de establecimien ...
#  'Es importante abordar el problema del agrupamiento conceptual ya que en muchas \nciencias el especialista está interesado en encontrar no sólo los agrupamientos en que se \nclasifican los objetos sino además las propiedades que caracterizan a estos agrupamientos. \nSin embargo, las herramientas que se han diseñado hasta el momento tienen algunas \nlimitantes al ser aplicados en problemas donde se tienen objetos descritos por variables \ncualitativas y cuantitativas mezcladas. Además, no permiten trabajar con ausencia de \ninformación en las descripciones de los objetos. \nEn muchas ocasiones los conceptos obtenidos por los algoritmos no son fácilmente \ninterpretables, no cubren a todos los objetos del agrupamiento o cubren objetos que \npertenecen a otros agrupamientos. \nUna restricción fuerte de estos algoritmos es que los conceptos deben ser disjuntos, es \ndecir, los objetos sólo pueden pertenecer a una clase. Sin embargo, en muchos problemas\nreales no sucede así, ya que los objetos pueden pertenecer a más de una clase y en este caso\nlos conceptos deberían ser no disjuntos. \nTambién es importante desarrollar algoritmos conceptuales difusos ya que en \nproblemas reales el especialista puede estar interesado en conocer en qué grado pertenece \nun objeto a cada uno de los agrupamientos, más que saber si un objeto pertenece o no a un \nagrupamiento.</Justificacion>\n',
#  'El uso tan frecuente de las computadoras en la actualidad ha conllevado al desa-\nrrollo de múltiples aplicaciones tecnológicas, cuya base es el lenguaje natural. Aunado\na esto, el surgimiento de Internet y con ello la gran reserva de recursos de información\ndigitales, incita el desarrollo de algoritmos de búsqueda eficientes, que ponen a nuestra\ndisposición todo un mundo de lenguaje. Con esta plataforma es común el uso de apli-\ncaciones importantes de la ling\x7fuística computacional, como: la traducción automática,\nel manejo y gestión de documentos, la generación de texto y resúmenes, las bibliote-\ncas digitales, las interfaces en lenguaje natural, etc.; cuya efectividad depende en gran\nmedida de la eficacia de los algoritmos que han sido propuestos y que en todas estas\ntareas consideran la desambiguación de los sentidos de las palabras.\nLa investigación y mejora de algoritmos de WSD conduce, por consiguiente, a la\nmejora en las aplicaciones antes mencionadas, lo que justifica el área de investigación\nseleccionada para esta tesis.\nMuchos métodos han sido propuestos para llevar a cabo la desambiguación y entre\nellos los supervisados han sido de los más sobresalientes, con la presente dificultad de\nque requieren datos etiquetados de sentidos, adquiridos en la gran mayoría de las oca-\nsiones, de forma manual.\nLa disponibilidad de los conjuntos adecuados de datos etiquetados es por tanto un\nfactor significativo y crucial para el entrenamiento de algoritmos basados en aprendi-\nzaje. Por desgracia, estos recursos son difíciles de obtener y de crear, pues requieren\nque cada una de las palabras haya sido etiquetada con su sentido. Este procedimiento\nresulta muy costoso y por ello solamente algunos artículos de vocabulario terminan\nsiendo etiquetados.\nMientras el cuello de botella léxico parece estar resuelto para el idioma inglés, no\nexiste un amplio rango de recursos ling\x7fuísticos para el procesamiento del lenguaje na-\ntural en otros idiomas [11]. El recurso de mayor cobertura de palabras es Princeton\nWordNet, un lexicón de concordancia semántica para el idioma inglés1\n, que agrupa los\nsinónimos en conjuntos denominados synsets y proporciona a las palabras su defini-\nción. El propósito de éste es producir una combinación de diccionario y tesauro que sea\nintuitivamente utilizable y respalde el análisis de texto automático y las aplicaciones\nde inteligencia artificial. Sin embargo, su utilidad como recurso de entrenamiento y\nevaluación para anotadores de sentidos supervisados está actualmente algo limitada\npor su metodología secuencial. Esta notación obliga a los intérpretes a familiarizarse\ncon los inventarios de sentidos de cada palabra [2].\nA pesar de sus inconvenientes, este recurso representa una contribución muy im-\nportante al campo, proporcionando el primer conjunto de datos balanceados de larga\nescala para el estudio de las propiedades de polisemia en el idioma inglés.\nDesafortunadamente, no existe para el idioma español un recurso léxico de tal mag-\nnitud con el cual se pueda proveer de sentido a las palabras, aunque se han están\nllevando a cabo esfuerzos en esta dirección. Por lo tanto, la búsqueda de recursos dis-\nponibles que permitan asociar etiquetas de sentidos y más aún, esto lo realice de forma\nautomática, es una tarea intermedia indispensable en el procesamiento de lenguaje\nnatural</Justificacion>\n',
#  'Esta tesis espera realizar distintas contribuciones. En primer lugar, \nincorporando determinadas herramientas conceptuales desarrolladas en el campo de \nlos estudios sociales de la ciencia y la tecnología que no han sido mayormente \naplicadas al estudio particular de las Tecnologías de la Información y la Comunicación. \nAñadir aquellos conceptos presentes en el estudio de las tecnologías en general \npermitiría comprender lo particular de los procesos de incorporación de TIC y de la \nconstrucción de "campus virtuales\x9d en universidades del país. Junto con ello, \nproporcionar nuevos andamiajes teóricos vinculados con las características \ninherentes a las TIC. Este propósito se presenta como inédito ya que pocos trabajos \nen el ámbito de las ciencias sociales han analizado las dinámicas de desarrollo \ntecnológico que posibilitan la construcción de entornos "virtuales\x9d que se gestan en las \nuniversidades desde un enfoque que se encuadre en el propuesto por el campo de los \nestudios sociales de la ciencia y la tecnología. \nEn ese sentido se aspira a establecer una ruptura con aquellas formas \n"cristalizadas\x9d de determinismo tecnológico que consideran que la creciente "difusión\x9d \ny proliferación de las Tecnologías de la Información y la Comunicación producen \n"efectos\x9d en la "sociedad\x9d y se limitan a una mirada meramente instrumental dejando \nde lado aquellas que hacen hincapié en la tecnología como construcción social, \nentendiendo que no hay una relación sociedad-tecnología, como si se tratara de dos \nentidades separadas y que la distinción misma entre social y técnico debe \nconsiderarse como el resultado de un proceso de "co-construcción\x9d.\nPor otra parte, esta investigación espera contribuir al campo de los estudios \nde la educación superior y los estudios sobre universidad en el cual aparece \ncomo vacante la problemática vinculada a la educación universitaria "virtual\x9d. La \nutilización de la tecnología para la enseñanza y la investigación no es únicamente una \ncuestión técnica, puesto que replantea cuestiones fundamentales no sólo sobre los \nmétodos de trabajo sino sobre las metas y los propósitos que persiguen las \ninstituciones universitarias. Así, el estudio de los "campus virtuales\x9d de las \nuniversidades nacionales argentinas podría contribuir a replantear la dinámica de \nformulación de políticas y toma de decisiones al interior de la universidad. \nPor último se espera contribuir a los estudios que relacionan los procesos \nde "innovación\x9d tecnológica y los territorios indagando en la nueva dimensión \nespacio-temporal que generan las TIC y en las condiciones territoriales, económicas, \nsociales, organizacionales y simbólicas, entre otras, que inciden sobre la \nimplementación de los "campus virtuales\x9d"</Justificacion>\n',
#  'Actualmente nos encontramos en un proceso de constantes cambios y transformaciones \nque obedecen a una serie de factores y entre ellas a la incorporación vertiginosa de \nnuevas tecnologías de la información y la comunicación en diversos campos, incluidos \nen el aspecto educativo. De acuerdo a la UNESCO (2005) los sistemas educativos de \ntodo el mundo se enfrentan actualmente al desafío de utilizar las nuevas tecnologías de \nla información y la comunicación TIC para proveer a sus estudiantes con las \nherramientas y conocimientos necesarios para el siglo XXI. En el año 2005, el Informe \nMundial sobre la Educación de la UNESCO, "El Imperativo de la Calidad\x9d, enfatizó en \nla importancia de los métodos de aprendizaje y en la utilización de materiales \neducativos, infraestructura y acceso a las TIC, como un importante desafío en el campo \neducativo. \nLas tecnologías de la información y la comunicación TIC son un factor de vital \nimportancia en la transformación de diversos campos de la sociedad. En el campo \neducativo las TIC tienen el potencial de transformar la naturaleza de la educación en \ncuanto a dónde y cómo se produce el proceso de enseñanza aprendizaje, así como de \nintroducir cambios en los roles de los profesores y los estudiantes, y en las diferentes \nacciones que se realiza en el proceso educativo, incluido en temas de gestión \ninstitucional. \nEn este nuevo panorama se enfatiza la importancia de desarrollar nuevas competencias, \ncapacidades, habilidades y uso de herramientas. De acuerdo a Valzacchi (2003) los estudiantes deben cultivar las siguientes destrezas que según los estándares de la \nInternational Society for Technology in Education son necesarios para desenvolverse \nen el siglo XXI. Estas son: manejarse con soltura en el empleo de la tecnología; \ncomunicar información e ideas usando una gran variedad de medios y formatos; \nacceder, intercambiar, compilar, organizar, analizar y sintetizar información; saber \nencontrar información adicional; saber evaluar la información y sus fuentes; construir, \nproducir y publicar modelos, contenidos y otros trabajos creativos; colaborar y cooperar \nen grupos de trabajo e interactuar con otros en forma apropiada y ética. \nEn el país se inició el proceso de integración de las TIC en el sistema educativo público \nestatal a través del Proyecto Huascarán y actualmente a través de la Dirección General \nde Tecnologías Educativas del Ministerio de Educación, con la finalidad que las TIC de \nacuerdo al (Ministerio de Educación, 2007, p.60) "mejoren la calidad de la educación \nsecundaria para que los estudiantes alcancen una formación integral que comprenda la \nconsecución de logros de aprendizaje y una sólida formación en valores\x9d. \nEsta investigación también se justifica teniendo en consideración que de acuerdo a \n(Guiloff, 2007, p.11) "no existe suficiente información sobre el compromiso e \ninteracción tecnológica relacionada con las actividades de aprendizaje formal de los \nestudiantes\x9d y de acuerdo a (Condie, 2007, p.75) "a la fecha hay muchos estudios de la \nrelación entre TIC y la educación, sin embargo varían de acuerdo a las regiones donde \nse han realizado, con estudiantes de ciertas características y disciplinas; siendo \nnecesario hacer investigaciones locales específicas\x9d. \nAsimismo este tema es de especial importancia y de actualidad, y de acuerdo a las \ndiversas organizaciones, instituciones e investigadores que vienen trabajando sobre las \nTIC y la educación, han convocado a realizar investigaciones a nivel micro con la \nfinalidad de contribuir a la generación de conocimiento científico. \nEl trabajo también se justifica puesto que permitirá entregar a las autoridades que \nvienen implementando la integración de las TIC a través de la Dirección General de \nTecnologías Educativas del Ministerio de Educación, resultados sobre el desarrollo de \ncapacidades TIC en los estudiantes.</Justificacion>\n',
#  'Los problemas de optimización industriales, en general, son muy demandantes en cuanto al\nuso de los recursos computacionales. En la investigación hecha por Zabinsky [14] se\ndescribe el ambiente donde operan y diseñan las aplicaciones de ingeniería. Estos\nambientes tienen restricciones en los tiempos de entrega de sus productos originadas por los compromisos con los clientes. Los desarrollos propuestos para encontrar las soluciones a los problemas técnicos, particularmente los de optimización, se ven afectados por dichas\nrestricciones, es necesario disponer de herramientas que permitan atacar y resolver los\nproblemas en los tiempos establecidos.\nUna alternativa que permite superar las restricciones de tiempo de los problemas de\ningeniería es la implementación, en hardware especializado, de los algoritmos numéricos\nutilizados. Bajo este enfoque se abre la posibilidad de disminuir el tiempo de ejecución del esquema seleccionado, comparado con una plataforma de procesamiento convencional,\ncuando la implementación en hardware es soportada por el estudio detallado del algoritmo\nseleccionado. Así, en la puesta en marcha en hardware se busca, usualmente, utilizar los\nalgoritmos con menor costo computacional.\nPor lo anterior es primordial seleccionar el procedimiento que presente un bajo costo\ncomputacional. Los algoritmos deterministas ofrecen la ventaja de tener tal característica, si se comparan con los métodos de exploración estocástica. Está propiedad es más notable cuando la demanda computacional está definida por la forma en que se plantea el problema a resolver. El método propuesto por Gutmann [11][29] pertenece a las estrategias deterministas para OG por lo que lo convierte en un buen candidato para dicha tarea.\nEl algoritmo de Gutmann utiliza un conjunto de puntos, { , ( )} i i x f x , 1... , m\ni i = n x , que son empleados para generar una superficie de interpolación en la cual cada punto de entrada implica una evaluación del modelo f (x) . Al realizar una depuración del conjunto de puntos inicial se reduce el número de evaluaciones de f (x) , por lo que el costo computacional del método disminuirá. Dicha depuración debe realizarse de tal forma que la superficie de interpolación no sea alterada.\nPor lo general, los problemas a resolver no son bien comportados. En condiciones reales,\nlos diseños están sometidos a diversas perturbaciones que alteran el funcionamiento de la\naplicación las cuales son, comúnmente, modeladas como ruido gaussiano. El algoritmo de\nGutmann, de acuerdo a la evidencia encontrada [28], presenta problemas de convergencia\nal estar sometido a estas condiciones. Es deseable que el funcionamiento del algoritmo no\nsea afectado por el ruido, de lo contrario se corre el riesgo de que el modelo no represente de manera realista el fenómeno bajo consideración.</Justificacion>\n',
#  'Tras analizar la propuesta MDA de OMG se han detectado dos\nimportantes carencias relacionadas con el tratamiento de los modelos iniciales:\n* No se aclara cómo deben manejarse los modelos ligados al negocio,\nlo que se conoce como modelos independientes de la computación ó\nCIM.\n* No se describe cómo deben asociarse esos modelos CIM con los\nprimeros modelos del software a desarrollar, es decir, con los PIM.\nDebido a las carencias mencionadas la mayoría de trabajos relacionados\ncon el desarrollo de software basado en MDD ó MDA suelen enfocarse desde\nuna perspectiva puramente tecnológica. Salvo contadas excepciones no se\ntrabaja partiendo desde un punto de vista orientado al negocio y relacionado\ncon los objetivos empresariales.\nLa mayor parte de las investigaciones actuales sobre este campo están\ncentradas en aspectos técnicos que pueden mejorar la obtención de código a\npartir de modelos más o menos abstractos. Esos modelos suelen estar\ndirectamente relacionados con el software, como son los modelos de requisitos,\nde información, de casos de uso, de análisis, de diseño, etc.\n\nDe todo lo anterior se deduce que la falta de conexión real entre el\ndominio del negocio y el tecnológico provoca que, en la mayoría de los casos,\nlos modelos del negocio no sean utilizados como punto de partida de los\nprocesos de desarrollo de software. Este problema se aprecia claramente en el\námbito de MDA, siendo evidente la falta de asociación entre modelos CIM y\nPIM.\nLas metodologías de desarrollo ágil de software tiene como punto fuerte\nla conexión de los aspectos asociados al negocio con los tecnológicos. Sin\nembargo, no se ajusta a la especificación MDA y por lo tanto no puede aportar\nlos beneficios inherentes, relacionados con el desarrollo de software dirigido por\nmodelos.\nPor consiguiente, una vez expuestas de forma resumida las ventajas,\ndesventajas y deficiencias de los modelos de desarrollo mencionados y con el\nobjetivo de solventar sus puntos débiles y aprovechar sus aportaciones,\nplanteamos la siguiente hipótesis de partida en esta tesis:\nLa combinación de la especificación MDA con la idea del\ndesarrollo ágil resultaría muy ventajosa de cara a un desarrollo\nde software flexible y asociado a los procesos del negocio.</Justificacion>\n',
#  'La presente tesis se justifica, además del interés objetivo de la misma, en la\nformación y el desarrollo académico del autor, así como en razones personales. En\n1995, confluyeron una serie de hechos casi consecutivos: el final de la Licenciatura\nen Ciencias de la Información, en la rama de Periodismo; el surgimiento del interés por la investigación en documentación periodística, fomentado por el Dr. Félix del\nValle Gastaminza en los citados estudios, en la Universidad Complutense de Madrid;\nla introducción del autor en el uso de Internet, como usuario, y el surgimiento de la\nprensa accesible a través de Internet en España, a semejanza de lo sucedido ya en\naños anteriores en otros lugares.\nLa intersección de estas circunstancias produjo el interés por investigar la aplicación\nde la documentación periodística a esos nuevos contenidos periodísticos. El\ndesarrollo de los mismos corrió paralelo a la formación posterior del autor, desde\n1996, en los cursos del Doctorado en Documentación en la Universidad Carlos ifi de\nMadrid.\nMuy pronto, contó con la tutela del profesor Antonio Hernández Pérez, del\nDepartamento de Biblioteconomía y Documentación de la misma universidad, y\nlicenciado y doctor en Ciencias de la Información por la Universidad Complutense\nde Madrid. A esta formación común a la del doctorado se unía también el interés por\nlos mismos temas, así como en otros relacionados con las Tecnologías de la\nInformación aplicadas documentalmente a contenidos accesibles en Internet.\nAdemás de la dirección por el Dr. Hernández de la tesina de doctorado, esa tutela se\nmanifestó mediante la inclusión en varios proyectos en los que participaron ambos,\nprincipalmente, dirigidos por la Dra. Mercedes Caridad Sebastián, del mismo\nDepartamento. En esos proyectos, el autor participó como becario FPI del Ministerio\nde Educación y Ciencia, entre 1998 y 2000, bajo la tutela del Dr. Hernández, y desde\noctubre de 2000, como Ayudante de Escuela Universitaria en el citado\nDepartamento.\nVarios de esos proyectos estaban relacionados con el tratamiento de contenidos\nperiodísticos representados mediante marcado de texto, dirigidos por el Dr. Carlos\nDelgado Kloos, del Dpto. de Ingeniería Telemática de la Universidad Carlos ifi de\nMadrid. Ese fue el caso del titulado Periotrónico: Concepción y desarrollo de un\nperiódico electrónico personalizado (CICYT TEL97-0788), entre 1998 y 1999, y del\nsubsiguiente proyecto InfoMedia: un sistema multiplataforma para la publicación de\nDavid Rodríguez Mazeos información (CICYT TEL99-0207), entre 2000 y 2002, así como del proyecto\nInfoFlex: Gestión de contenidos flexible y distribuida basada en tecnologías Web\n(T1C2003-07208), dirigido por el Dr. Luis Sánchez Fernández, del mismo\nDepartamento, que se desarrollará a partir de 2004.\nEn esos proyectos, se investiga el uso de lenguajes de marcado de texto periodístico\nbasado en XML. De esa investigación se derivó el interés definitivo del director y del\nautor de esta tesis por desarrollar la aplicación de este metalenguaje, y de los\nlenguajes derivados del mismo desarrollados por instituciones internacionales, en los\ncentros de documentación periodística pertenecientes a medios de comunicación\naccesibles en Internet.\nEste interés por la documentación periodística y por su desarrollo en Internet se ha\nvisto reflejado también en el plano docente, donde, tras participar corno A.E.U. en\ndiversas asignaturas relacionadas con las tecnologías de la información en la\nDiplomatura en Biblioteconomia y Documentación, el autor participa en la docencia\nde asignaturas, dentro de la Licenciatura en Periodismo de la Universidad Carlos ifi\nde Madrid, que están relacionadas con la documentación €\x9dcomo Documentación\nInformativa, desde el curso 2002/2003€\x9d, o con el uso de Internet con fines\nperiodísticos, como Aplicaciones de la Red al Periodismo (desde el curso\n2003/2004).</Justificacion>\n',
#  'Esta tesis espera realizar distintas contribuciones. En primer lugar,\nincorporando determinadas herramientas conceptuales desarrolladas en el campo de\nlos estudios sociales de la ciencia y la tecnología que no han sido mayormente\naplicadas al estudio particular de las Tecnologías de la Información y la Comunicación.\nAñadir aquellos conceptos presentes en el estudio de las tecnologías en general\npermitiría comprender lo particular de los procesos de incorporación de TIC y de la\nconstrucción de "campus virtuales\x9d en universidades del país. Junto con ello,\nproporcionar nuevos andamiajes teóricos vinculados con las características\ninherentes a las TIC. Este propósito se presenta como inédito ya que pocos trabajos\nen el ámbito de las ciencias sociales han analizado las dinámicas de desarrollo\ntecnológico que posibilitan la construcción de entornos "virtuales\x9d que se gestan en las\nuniversidades desde un enfoque que se encuadre en el propuesto por el campo de los\nestudios sociales de la ciencia y la tecnología.\nEn ese sentido se aspira a establecer una ruptura con aquellas formas\n"cristalizadas\x9d de determinismo tecnológico que consideran que la creciente "difusión\x9d\ny proliferación de las Tecnologías de la Información y la Comunicación producen\n"efectos\x9d en la "sociedad\x9d y se limitan a una mirada meramente instrumental dejando\nde lado aquellas que hacen hincapié en la tecnología como construcción social,\nentendiendo que no hay una relación sociedad-tecnología, como si se tratara de dos\nentidades separadas y que la distinción misma entre social y técnico debe\nconsiderarse como el resultado de un proceso de "co-construcción\x9d.\nPor otra parte, esta investigación espera contribuir al campo de los estudios\nde la educación superior y los estudios sobre universidad en el cual aparece\ncomo vacante la problemática vinculada a la educación universitaria "virtual\x9d. La\nutilización de la tecnología para la enseñanza y la investigación no es únicamente una\ncuestión técnica, puesto que replantea cuestiones fundamentales no sólo sobre los\nmétodos de trabajo sino sobre las metas y los propósitos que persiguen las\ninstituciones universitarias. Así, el estudio de los "campus virtuales\x9d de las\nuniversidades nacionales argentinas podría contribuir a replantear la dinámica de\nformulación de políticas y toma de decisiones al interior de la universidad.\nPor último se espera contribuir a los estudios que relacionan los procesos\nde "innovación\x9d tecnológica y los territorios indagando en la nueva dimensión\nespacio-temporal que generan las TIC y en las condiciones territoriales, económicas,\nsociales, organizacionales y simbólicas, entre otras, que inciden sobre la\nimplementación de los "campus virtuales\x9d.\n\nDe esta forma, se busca abrir nuevas posibilidades de triangulación teórica,\nentre la sociología de la tecnología, los estudios vinculados a la educación superior y a\nla universidad en particular y los estudios orientados a comprender las distintas\ndinámicas de los territorios contribuyendo a ampliar los alcances de los actuales\nestudios sociales de la tecnología.</Justificacion>\n',
#  'La necesidad de cada vez más capacidad de cómputo para muchas aplicaciones importantes, incluyendo modelado, simulación y sistemas inteligentes, tales como los que realizan máquinas de visión, ha motivado que  la investigación en el área de arquitecturas de cómputo haya avanzado de manera considerable en los últimos años. Los sistemas requieren mejor desempeño del que puede proporcionar las máquinas que existen  actualmente o las que podrán ser construidas en un futuro cercano. Actualmente se están alcanzando los límites de las capacidades de procesamiento de los diseños seriales, una opción para alcanzar las velocidades de procesamiento deseadas, es físicamente posible es a través de procesamiento paralelo [hm94].\n\nLas arquitecturas Reconfigurables prometen ser una valiosa alternativa  a los dispositivos de cómputo convencionales. El hardware no es estático sino que se adapta a las aplicaciones, a diferencia de los procesadores o ASICs. Las técnicas de reconfiguración se utilizan ampliamente en procesamiento paralelo, particularmente en arreglos de procesadores tales como los sistólicos.\nLa necesidad de suspender la operación de los dispositivos, aún para realizar pequeños cambios, tiene un impacto crítico si se van a usar como aceleradores de un algoritmo en aplicaciones donde la naturaleza de las tareas que van a ejecutar es cambiante. La reconfiguración dinámica permite realizar cambios en la configuración de un dispositivo "al vuelo\x9d durante la operación del sistema [mr01].\n\nA partir de estos conceptos, este trabajo se propone reducir el cuello de botella de los sistemas basados en el modelo de Von Neumann, explorar y analizar las técnicas de reconfiguración dinámica junto con la implementación de algoritmos basados en operaciones de ventanas  para poder proponer soluciónes más acordes a las restricciones de tiempo real. De manera específica el uso de la reconfiguración parcial. \n\nExisten una serie de problemas que se deben manejar asociados con el uso de FPGAs acoplados a un procesador, primero el proceso de mapeo de un algoritmo en los FPGAs no es automático. Típicamente el programador es quien debe cuidar  la forma de identificar un algoritmo (o una parte de él) para ser implementado en hardware y las herramientas especializadas para convertir el algoritmo en una descripción de hardware. La presente propuesta pretende determinar la mejor forma de resolver el problema del codiseño HW/SW [nj02].\n\nOtro  desafío interesante asociado con la computación reconfigurable es la reconfiguración dinámica en sí misma, y sobre todo como manejarla, lo cual es el objetivo principal de este proyecto.\n\nLos FPGAs tradicionales tienen tiempos de configuración relativamente largos, por lo que para aplicaciones que dependen de modificaciones en línea, cualquier retardo de configuración incrementa el tiempo total de cómputo y por tanto el desempeño global. Otro de los objetivos de este trabajo es disminuir este efecto utilizando reconfiguración parcial que permite modificar sólo un área del FPGA sin perturbar el funcionamiento del resto del dispositivo. El desafío consiste en determinar la granularidad apropiada para el sistema en relación al desempeño obtenido.\n\nFinalmente, se plantea la posibilidad de generar un sistema que permita optimizar área, reducir el consumo de potencia, de bajo costo y que cuente con la habilidad de hacerlo compatible con otras tecnologías.</Justificacion>\n',
#  'El aumento del volumen y variedad de información en las Bases de Datos ha incrementado la dificultad para la clasificación, caracterización y comprensión de las mismas, una solución a este problema es el uso de técnicas de análisis de datos, Reconocimiento de Patrones o minería de datos entre otras. \n\n \tEn base al estudio de los trabajos relacionados, una forma de abordar el problema es encontrar regularidades que puedan representar a los conjuntos de datos, permitiendo caracterizarlos y de esta manera reducir información. Una forma de hacer esto es utilizar conjuntos de representantes los cuales son una herramienta útil para la clasificación supervisada y la caracterización de universos estructurados. Sin embargo,  no se cuenta con un algoritmo para su cálculo, exceptuando la verificación de la definición contra todo el espacio de búsqueda. \n\n\nOtro problema  es que los representantes pueden incluir mucha redundancia y por tal motivo pueden llegar a ser demasiados (por ejemplo en un conjunto de 798 objetos, con 31 rasgos y 5 clases se encontraron 15362 representantes)\n\n\nPor todo esto,  es necesario contar  con una herramienta que permita encontrar un subconjunto de representantes que sea adecuado para la clasificación y/o la caracterización.</Justificacion>\n',
#  'Es enorme la cantidad de imágenes en crudo que se tiene almacenada de la\nsuperficie terrestre. La interpretación de las imágenes es laboriosa y consume tiempo,\npor lo cual es inimaginable la interpretación sin la ayuda del procesamiento de\nimágenes[23]. Pongamos el ejemplo de las imágenes satelitales que se tienen del\nterritorio nacional tomadas por la constelación de satélites SPOT, sin considerar\nlas imágenes que se siguen adquiriendo. Hasta el primer trimestre de este año,\nlas imágenes tomadas por el satélite SPOT 5 alcanzan la cantidad de 10,200 imágenes aproximadamente. Entre ellas se encuentran imágenes pancromáticas y\nmultiespectrales de resolución espacial de 20, 10, 5 y 2.5 metros sin contabilizar las\nde los otros dos satélites que permanecen en órbita SPOT 2 y 44. Del satélite SPOT\n4 se tienen 825 imágenes pancromáticas de 10m de resolución que cubren casi todo\nel territorio nacional.\nPor otro lado, las herramientas que se han diseñado tienen algunas limitantes al\nser aplicadas a la clasificación de coberturas espectralmente similares, obteniendo\nresultados de clasificación entre el 62.7% [17] y 73% [20].\nUna de las desventajas de los algoritmos comúnmente empleados en la clasificación de\ncoberturas, es que no involucran información espacial de los objetos que están siendo\nclasificados, por lo cual un modelo probabilístico resulta atractivo en este dominio.\nSin embargo, los objetos en imágenes satelitáles presentan además geometrías y/o\ncaracterísticas estocásticas, la cual es información a considerar para incrementar los\nporcentajes de reconocimiento [25].\nPor último, el algoritmo aplicado sobre algún tipo de cobertura en particular para\nobtener su clasificación fina podría ser extendido para otros tipos de cobertura con\ncomportamiento similar.</Justificacion>\n',
#  'La justificación de la investigación doctoral se fundamenta en los siguientes criterios:\n1. Conveniencia. Se pretende elevar la eficacia de la enseñanza provista al estudiante a través de los SEBW. Para ello, se evalúan las experiencias y se eligen aquellas, que se supone, habrán de estimular positivamente el aprendizaje del estudiante de la mejor manera.\n2. Relevancia social. Se busca mejorar el aprendizaje del estudiante al personalizar la enseñanza que un SEBW le provee. Para este fin se consideran las capacidades cognitivas, las preferencias de aprendizaje y ciertos atributos de la personalidad del estudiante.\n3. Implicaciones prácticas. Se procura adecuar la enseñanza a cada estudiante con base en las variedades de contenido, secuencia y evaluación disponibles en un SEBW. De esta forma, se promueve un paradigma general para diversos dominios de enseñanza.\n4. Valor teórico. Se concibe el proceso de enseñanza-aprendizaje como un fenómeno causa-efecto. Por lo tanto, además de formular un modelo causal para caracterizar a dicho proceso, se recolecta evidencia empírica que sustente la verificación de la hipótesis.\n5. Utilidad métodológica. Se define un marco de trabajo para evaluar los conceptos que componen un modelo del estudiante. Con base en exámenes psicológicos se emite un diagnóstico del individuo acerca de su personalidad, sus preferencias de aprendizaje y sus capacidades cognitivas.\n6. Consecuencias. La investigación busca tratar al estudiante en forma individualizada. Bajo este precepto, se impulsa un paradigma de servicio alterno al tradicional, ofertado por la educación presencial y a distancia, en el cual a los estudiantes se les trata sin distinción.\n7. Viabilidad. El desarrollo de la investigación y su comprobación experimental se lleva a cabo en su propio dominio: la educación basada en Web.\n8. Comprobación. Para verificar la tesis se crea un prototipo8 del modelo del estudiante basado en mapas cognitivos. El prototipo forma parte de un SEBW que provee enseñanza sobre un dominio de conocimiento específico a una muestra de voluntarios. La muestra se organiza en dos grupos: el primer grupo recibe el soporte del modelo del estudiante; mientras que el otro no cuenta con su respaldo. Al final del experimento, se comparan los alcances logrados por los dos grupos para identificar la ventaja del modelo del estudiante.</Justificacion>\n',
#  'Tomando en cuenta la revisión que se hizo del estado del arte y generalizando el problema de clasificación en este tipo de dominios del diagnóstico médico, nuestra justificación es la siguiente:\nExiste la necesidad de desarrollar un algoritmo de aprendizaje inductivo que permita resolver problemas de clasificación binaria a partir de conjuntos de datos no balanceados, alcanzando un consenso apropiado entre precisión y comprensibilidad. Por otro lado, la extracción de conocimiento útil a partir de conjuntos de datos médicos, puede ayudar a predecir la incidencia de algún tipo de enfermedad, lo que representaría la oportunidad de aplicar a tiempo un tratamiento médico, capaz de evitar, eliminar o disminuir en cierto grado la aparición de la misma.</Justificacion>\n',
#  'Esta tesis trata de la planificación de sistemas de tiempo real utilizando sistemas \nmultiprocesador de memoria compartida. La principal motivación para iniciar la\ninvestigación en la planificación de sistemas de tiempo real está fundamentada en el\nplan estratégico del departamento en el que trabajo, el Departament d’Enginyeria\nInformàtica i Matemàtiques de la Universitat Rovira i Virgili. Esta universidad está\nubicada en un entorno geográfico donde las instalaciones industriales con entornos\nde tiempo real críticos abundan: refinerías de petróleo, industrias petroquímicas,\ndiversas centrales nucleares, etc. Así, las líneas del departamento estaban\nprincipalmente enfocadas al “tiempo-real”, tanto en la parte docente como en la parte \ninvestigadora. \n\nEn lo referente a la planificación de sistemas de tiempo real, la teoría para los\nsistemas monoprocesador ya estaba muy consolidada. Para los sistemas distribuidos\nhabía abundante bibliografía pero para los sistemas multiprocesador con memoria\ncompartida al principio apenas se encontraban referencias. Esto era debido a los\nenormes problemas que conlleva y a una praxis que utilizaba el multiprocesador\ncomo si fuesen monoprocesadores independientes o como si fuese un sistema\ndistribuido.  \n\nRecientemente las arquitecturas multiprocesador se han ido popularizando. Su uso va\ndesde los ordenadores personales hasta grandes servidores y computadores, pasando\npor los sistemas empotrados. Con los límites actuales del hardware, es más fácil y\ncon un menor coste incrementar la capacidad de cálculo con un multiprocesador que\nrealizarlo con sistemas de un procesador de equivalente capacidad. Así, han ido\napareciendo diversos chips Multi-Core o Chip-level Multiprocessors (CMP). Los\nfabricantes de procesadores con mayor volumen, como son Intel y AMD, primero\nlanzaron al mercado chips con dos procesadores (por ejemplo AMD Athlon X2 e Intel\nCore Duo) y en la actualidad ya son frecuentes con cuatro procesadores (Quad-Core\nAMD Opteron y Quad-Core Intel Xeon). En la Tabla 4 se resumen los procesadores\nmulticore actuales, donde se aprecia la gran evolución en los últimos años. </Justificacion>\n',
#  'Evidencias que apoyan la propuesta\n\n* Para la indexación se ha estudiado que las unidades óptimas son las palabras,\nmientras que para la traducción es mejor emplear unidades más grandes (Verdejo\net al., 2000), ya que el uso de palabras individuales para traducir no resuelve\nel problema de la ambig\x7fuedad semántica.\n* La estadística sobre coocurrencia de términos permite realizar traducciones más\nfiables (Ballesteros and Croft, 1998) que la simple utilización de diccionarios.\nAplicarla sobre sintagmas nominales va a mantener esta característica (recordemos\nque un sintagma nominal se compone de varios términos).\n* La utilización de sintagmas nominales, con un contenido semántico más claro\npara el usuario, proporcionará una mejor información a efectos de interacción\nque el simple uso estadístico de la coocurrencia de términos próximos que se\nhace en (Ballesteros and Croft, 1998).\n* Diversos estudios como (Pe~nas et al., 2001; Dennis et al., 2002) muestran que\nlos sintagmas son una forma natural para los usuarios de refinar una consulta.\nRepresentan conceptos de una forma más clara y con un mayor contenido\nsemántico que los términos aislados.\n* Además, la determinación de los sintagmas y su utilización como índices puede\nhacerse de manera eficiente (Pe~nas, 2002).</Justificacion>\n',
#  'Las estructuras metálicas usadas en la industria del transporte, tales como bastidores de pared y\npiso de vehículos automotores, están sometidas a cargas cíclicas durante su vida de servicio,\ninduciendo la aparición de grietas por fatiga. En las estructuras soldadas de aleaciones de\naluminio tratables térmicamente el riesgo de aparición de una grieta es probable, debido a la\nheterogeneidad en las propiedades mecánicas de las zonas que comprenden la unión. Por lo\nanterior surge la necesidad de realizar uniones experimentales de soldaduras que permitan\nretardar el crecimiento de grietas por fatiga en uniones soldadas en aleaciones de este tipo. Para\nello se establecen estudios comparativos entre dos procesos de unión; por ejemplo, el proceso\nconvencional de soldadura de arco eléctrico con material de aporte y gas de protección, la\nimplementación de la técnica de arco eléctrico indirecto modificado. Con ello se busca\nidentificar una técnica de aplicación de soldadura que permita incrementar la vida a la fatiga de\nlos componentes soldados.</Justificacion>\n',
#  'En la literatura hay una gran diversidad de controladores adaptativos que usan redes neuronales, sin embargo, es importante el desarrollo de nuevos controladores con mejor desempeño, menor tiempo de convergencia y más confiables.\nLos sistemas que son difíciles de modelar o de los que no se dispone de un modelo dinámico, pueden ser objeto de estudio usando redes neuronales para la identificación del mismo. En el caso de incertidumbres en el modelo dinámico, las dinámicas no modeladas pueden ser aproximadas por redes neuronales. El control neuronal puede aplicarse a sistemas robóticos en la industria, que ayudaría a la reducción de tiempos en los procesos productivos, con la reducción del mantenimiento a los sistemas robóticos, dado que las dinámicas de estos sistemas cambian con el tiempo debido al desgaste de sus mecanismos o factores externos como la adhesión de polvo o suciedad. También, el control neuronal se puede usar para el control de sistemas humano-robóticos con la finalidad de ayudar a las personas con discapacidades físicas, y al control de dinámicas complejas como los robots bípedos o similares. También, esta investigación puede ser usada en el campo educativo como una referencia en investigaciones en el ´área de control neuronal aplicada a mecanismos.\n</Justificacion>\n',
#  'En las ultimas décadas se ha constatado el creciente interés que presentan los  \nrobots caminantes, tanto desde el punto de vista de la investigación básica como  \nde sus potenciales aplicaciones. Una de las principales características de los robots\nequipados con patas es su capacidad para poder desplazarse sobre una amplia\nvariedad de terrenos no estructurados. Esta particularidad los hace muy atractivos\npara su aplicación practica como robots de servicios en los que se requiere la  \nlocomoción sobre terreno natural, el cual se caracteriza por presentar superficies  \nirregulares, diversos tipos de obstáculos y distintas pendientes. Sin embargo, el caminar sobre terreno natural implica que tanto la geometría como las propiedades\nfísicas de los elementos que rodean al robot son desconocidas y muy variables, por\nlo que es necesario dotar al robot de una estrategia que adapte su comportamiento\ncon respecto al entorno. Si bien el modelo del robot puede ser conocido con\nprecisión razonable, resulta difícil obtener una descripción detallada del entorno,  \nespecialmente en lo que respecta a sus propiedades físicas.\nLa estabilidad de los robots caminantes durante la realización del ciclo de  \nlocomoción, es de gran importancia. Por lo tanto, la consideración de una determinada medida de estabilidad durante la locomoción influye de manera directa en \nla seguridad del robot.\nEn este trabajo se presenta el planteamiento de estrategias de adaptabilidad\npara el robot hexápodo Hex-piderix, basadas en un modelo geométrico, en el cual  \nno es necesario conocer el ambiente, pues con tan solo saber que extremidades  \nestán tocando la superficie es posible estimar el plano de apoyo.  \nEn este documento se presenta el diseño y simulación de estrategias de adaptabilidad para el robot caminante hexápodo Hex-piderix basadas en un modelo\ngeométrico. La validación de cada una de ellas se realiza sobre un plano con distinto grado de inclinación; además de que se analiza la estabilidad estática de cada  \npostura con el criterio de estabilidad estático normalizado por el peso (SNE, por  \nsus siglas en ingles)\n</Justificacion>\n',
#  'Este trabajo de tesis se desarrolla debido a la necesidad de un sistema completo capaz de\npredecir los efectos indeseables de memoria en un PA con profundidad de memoria y órdenes\nde no linealidad variables. Para ello se desarrollan modelos polinomiales y basados en\ntruncaciones de las series de Volterra como Wiener, Hammerstein y MPM, además de utilizar\ntécnicas de aprendizaje como ANN y ANFIS dentro de una tarjeta de desarrollo FPGA/DSP, y una\ntécnica de medición de bajo costo de las curvas de distorsión en amplitud y en fase.\nEl sistema es controlado por una Interfaz Gráfica de Usuario (GUI) la cual permite de manera\nsimple abrir las mediciones reales de cualquier PA basado en sus curvas de distorsión AM/AM y\nAM/PM y obtener los coeficientes respectivos del MPM obtenidos a través del método Error\nCuadrático Mínimo (LSE).\nEl sistema tiene niveles variables de memoria y órdenes de no linealidad variables para\nadecuarse al comportamiento del PA. La parte principal del trabajo está basada en la\nherramienta de diseño DSP Builder la cual permite traducir un programa de sistema como\nMatlab/Simulink a VHDL ahorrando tiempo de diseño. En la parte final se realiza una\ncomparación con modelado a través de VHDL puro, y modelado obtenido a través de ANN y\nANFIS.\nLa ventaja de utilizar este sistema de simulación es el uso de algoritmos para etapas de\nlinealización posteriores. En trabajos desarrollados como autor se probó la eficiencia de los\nmodelos a través de FPGA [44-46].</Justificacion>\n',
#  'Existen elementos estructurales y mecánicos utilizados en Ingeniería como estructuras, chasis\nde autos, componentes aéreos, estructuras marinas, válvulas, etc., son fabricados con la\naleación de aluminio 6061-T6.\nPara la fabricación de dichos elementos se requieren procesos de unión, uno de ellos es la\nsoldadura. La soldadura es un proceso metalúrgico que requiere el entendimiento del\ncomportamiento del material durante su producción ya que la mayoría de los procesos de\nsoldadura, al igual que en la fundición de metales, requieren de altas temperaturas para hacer\nposible la unión de los materiales involucrados.\nEn la aleación de aluminio 6061-T6 se presenta una degradación en las propiedades mecánicas\ndebido al efecto térmico del proceso de soldadura. Además, la alta solubilidad del hidrógeno en\nel aluminio líquido que cuando ocurre el proceso de solidificación queda atrapado, generando\nporosidad en el material.\nTambién se sabe que es posible reducir el efecto térmico ya que con la técnica AEIM [23] al\nutilizar un solo paso de soldadura reduce el efecto en la microestructura final. Para este caso la\naleación a unir se encuentra en un estado de solubilización y envejecido artificial (-T6) pero\ncuando alcanza temperaturas muy elevadas se obtiene un sobreenvejecido en la aleación, lo\ncual disminuye las propiedades mecánicas. Sin embargo, el tratamiento térmico T6 es un\nproceso reversible, por lo tanto, se puede considerar como alternativa para mejorar las\npropiedades mecánicas de las uniones de aluminio soldadas con un tratamiento térmico postsoldadura.\nUna mejora en las propiedades mecánicas de uniones de aluminio soldadas se aprecia en un\nincremento en la resistencia a la fatiga para elementos estructurales que son sometidos a cargas\ncíclicas. Al incrementar la resistencia a la fatiga se retarda la aparición de grietas por fatiga. Por\nlo anterior surge la necesidad de hacer uniones soldadas que permitan aumentar la resistencia a\nla fatiga y retardar el crecimiento de grietas por fatiga en aleaciones de este tipo con la\nimplementación de la técnica AEIM y un tratamiento térmico post-soldadura</Justificacion>\n',
#  'Los sensores basados en fibra óptica ofrecen algunas ventajas sobre los sensores más\ntradicionales tales como inmunidad a interferencias electromagnéticas, son ultraligeros,\npueden ser empleados en ambientes altamente corrosivos o explosivos, y su uso en\naplicaciones para sensado remoto es factible debido a las bajas pérdidas de señal que las\nfibras ópticas presentan.</Justificacion>\n',
#  'En los Ãºltimos aÃ±os se ha dedicado considerable esfuerzo al problema de la segmentaciÃ³n del color en imÃ¡genes digitales dada su importancia y potencial. Hasta hace poco, la mayorÃ\xada de los enfoques publicados para la segmentaciÃ³n del color se basaba en tÃ©cnicas monocromÃ¡ticas aplicadas a cada componente de color de la imagen, en diferentes espacios de color (RGB u otros) y en diferentes formas, para producir una composiciÃ³n. Estos enfoques tienen el problema inherente de una pÃ©rdida significativa de la informaciÃ³n de\ncolor durante el proceso [3][4].</Justificacion>\n']

# %% [markdown]
# ## Structure the Data

# %%
TSU_structured = sepMeth(justificationTSU)
Lic_structured = sepMeth(justificationLic)
Masters_structured = sepMeth(justificationMasters)
Phd_structured = sepMeth(justificationPhd)
TSU_structured
Lic_structured
Masters_structured
Phd_structured
# Out:
# {'Justificacion1': {},
#  'Justificacion2': {1: 'En',
#   2: 'la',
#   3: 'sección',
#   4: 'anterior',
#   5: 'se',
#   6: 'ha',
#   7: 'evidenciado',
#   8: 'la',
#   9: 'importancia',
#   10: 'de',
#   11: 'las',
#   12: 'WNN',
#   13: 'y',
#   14: 'las',
#   15: 'ventajas',
#   16: 'que',
#   17: 'ofrecen',
#   18: 'estos',
#   19: 'modelos',
#   20: 'sobre',
#   21: 'las',
#   22: 'RNA',
#   23: 'con',
#   24: 'pesos,',
#   25: 'y',
#   26: 'se',
#   27: 'han',
#   28: 'fundamentado',
#   29: 'estos',
#   30: 'hechos',
#   31: 'con',
#   32: 'referencias',
#   33: 'bibliográficas',
#   34: 'correspondientes',
#   35: 'a',
#   36: 'trabajos',
#   37: 'de',
#   38: 'investigación',
#   39: 'científica',
#   40: 'de',
#   41: 'punta',
#   42: 'realizada',
#   43: 'por',
#   44: 'equipos',
#   45: 'internacionales.',
#   46: 'Por',
#   47: 'otro',
#   48: 'lado,',
#   49: 'se',
#   50: 'ha',
#   51: 'enfatizado',
#   52: 'la',
#   53: 'existencia,',
#   54: 'la',
#   55: 'importancia',
#   56: 'y',
#   57: 'la',
#   58: 'aplicación',
#   59: 'de',
#   60: 'los',
#   61: 'modelos',
#   62: 'asociativos',
#   63: 'Alfa-Beta,',
#   64: 'cuyas',
#   65: 'características',
#   66: 'más',
#   67: 'importantes',
#   68: 'son',
#   69: 'similares',
#   70: 'a',
#   71: 'las',
#   72: 'que',
#   73: 'exhiben',
#   74: 'las',
#   75: 'WNN,',
#   76: 'en',
#   77: 'cuanto',
#   78: 'eficacia,',
#   79: 'eficiencia',
#   80: 'y',
#   81: 'facilidad',
#   82: 'de',
#   83: 'implementación.',
#   84: 'Ciertamente',
#   85: 'algunos',
#   86: 'connotados',
#   87: 'autores',
#   88: 'en',
#   89: 'el',
#   90: 'área',
#   91: 'de',
#   92: 'las',
#   93: 'redes',
#   94: 'neuronales',
#   95: 'sin',
#   96: 'pesos',
#   97: 'han',
#   98: 'creado',
#   99: 'modelos',
#   100: 'relacionados',
#   101: 'con',
#   102: 'memorias',
#   103: 'asociativas',
#   104: '[6,',
#   105: '8,',
#   106: '19,',
#   107: '30,',
#   108: '56,',
#   109: '79];',
#   110: 'otros,',
#   111: 'han',
#   112: 'incursionado',
#   113: 'en',
#   114: 'los',
#   115: 'modelos',
#   116: 'asociativos',
#   117: 'Alfa-Beta',
#   118: '[19-24,',
#   119: '70],',
#   120: 'o',
#   121: 'bien,',
#   122: 'han',
#   123: 'realizado',
#   124: 'implementaciones',
#   125: 'en',
#   126: 'hardware',
#   127: 'de',
#   128: 'algunos',
#   129: 'modelos',
#   130: 'conocidos',
#   131: 'de',
#   132: 'redes',
#   133: 'neuronales',
#   134: 'sin',
#   135: 'pesos',
#   136: '[25-29,',
#   137: '41,',
#   138: '60,',
#   139: '67,',
#   140: '72,',
#   141: '74-77,',
#   142: '91].',
#   143: 'Sin',
#   144: 'embargo,',
#   145: 'hasta',
#   146: 'noviembre',
#   147: 'de',
#   148: '2007,',
#   149: 'no',
#   150: 'se',
#   151: 'han',
#   152: 'reportado',
#   153: 'en',
#   154: 'la',
#   155: 'literatura',
#   156: 'trabajos',
#   157: 'científicos',
#   158: 'donde',
#   159: 'se',
#   160: 'relacionen',
#   161: 'específicamente',
#   162: 'las',
#   163: 'redes',
#   164: 'neuronales',
#   165: 'sin',
#   166: 'pesos',
#   167: 'con',
#   168: 'los',
#   169: 'modelos',
#   170: 'de',
#   171: 'memorias',
#   172: 'asociativas',
#   173: 'Alfa-Beta.',
#   174: 'El',
#   175: 'presente',
#   176: 'trabajo',
#   177: 'de',
#   178: 'tesis',
#   179: 'queda',
#   180: 'justificado',
#   181: 'porque',
#   182: 'incluye,',
#   183: 'de',
#   184: 'manera',
#   185: 'central,',
#   186: 'la',
#   187: 'creación',
#   188: 'y',
#   189: 'diseño',
#   190: 'de',
#   191: 'un',
#   192: 'nuevo',
#   193: 'modelo',
#   194: 'de',
#   195: 'redes',
#   196: 'neuronales',
#   197: 'sin',
#   198: 'pesos,',
#   199: 'basado',
#   200: 'en',
#   201: 'los',
#   202: 'operadores',
#   203: 'Alfa',
#   204: 'y',
#   205: 'Beta,',
#   206: 'los',
#   207: 'cuales',
#   208: 'son',
#   209: 'tomados',
#   210: 'de',
#   211: 'los',
#   212: 'modelos',
#   213: 'de',
#   214: 'memorias',
#   215: 'asociativas',
#   216: 'Alfa-Beta.',
#   217: 'Por',
#   218: 'otro',
#   219: 'lado,',
#   220: 'se',
#   221: 'establecen',
#   222: 'las',
#   223: 'condiciones',
#   224: 'necesarias',
#   225: 'y',
#   226: 'suficientes',
#   227: 'de',
#   228: 'equivalencia',
#   229: 'de',
#   230: 'las',
#   231: 'redes',
#   232: 'neuronales',
#   233: 'sin',
#   234: 'pesos',
#   235: 'y',
#   236: 'los',
#   237: 'circuitos',
#   238: 'booleanos,',
#   239: 'y',
#   240: 'se',
#   241: 'presenta',
#   242: 'un',
#   243: 'estudio',
#   244: 'completo',
#   245: 'de',
#   246: 'factibilidad',
#   247: 'de',
#   248: 'implementación',
#   249: 'en',
#   250: 'hardware',
#   251: 'del',
#   252: 'nuevo',
#   253: 'modelo,',
#   254: 'el',
#   255: 'cual',
#   256: 'exhibe',
#   257: 'un',
#   258: 'alto',
#   259: 'desempeño,',
#   260: 'derivado',
#   261: 'del',
#   262: 'hecho',
#   263: 'de',
#   264: 'que',
#   265: 'es',
#   266: 'un',
#   267: 'hecho',
#   268: 'ya',
#   269: 'probado',
#   270: 'que',
#   271: 'la',
#   272: 'densidad',
#   273: 'aritmética',
#   274: 'de',
#   275: 'los',
#   276: 'modelos',
#   277: 'de',
#   278: 'memorias',
#   279: 'asociativas',
#   280: 'Alfa',
#   281: 'y',
#   282: 'Beta',
#   283: 'es',
#   284: 'menor',
#   285: 'que',
#   286: 'la',
#   287: 'otros',
#   288: 'modelos',
#   289: 'relevantes',
#   290: 'de',
#   291: 'memorias',
#   292: 'asociativas,',
#   293: 'como',
#   294: 'las',
#   295: 'morfológicas'},
#  'Justificacion3': {1: 'La',
#   2: 'idea',
#   3: 'de',
#   4: 'considerar',
#   5: 'la',
#   6: 'necesidad',
#   7: 'de',
#   8: 'seguridad',
#   9: 'de',
#   10: 'redes',
#   11: 'ad',
#   12: 'hoc',
#   13: 'no',
#   14: 'es',
#   15: 'nueva,',
#   16: 'inclusive',
#   17: 'en',
#   18: 'redes',
#   19: 'de',
#   20: 'sensores',
#   21: 'hay',
#   22: 'ataques',
#   23: 'específicos',
#   24: 'ante',
#   25: 'los',
#   26: 'cuales',
#   27: 'es',
#   28: 'necesario',
#   29: 'utilizar',
#   30: 'mecanismos',
#   31: 'de',
#   32: 'proteccion',
#   33: 'para',
#   34: 'evitar',
#   35: 'ataques',
#   36: 'de',
#   37: 'suplantacion',
#   38: 'y',
#   39: 'negacion',
#   40: 'de',
#   41: 'servicios,',
#   42: 'entre',
#   43: 'otros',
#   44: 'posibles;',
#   45: 'sin',
#   46: 'embargo',
#   47: 'no',
#   48: 'todas',
#   49: 'las',
#   50: 'tecnicas',
#   51: 'utilizadas',
#   52: 'en',
#   53: 'soluciones',
#   54: 'a',
#   55: 'estos',
#   56: 'problemas',
#   57: 'en',
#   58: 'redes',
#   59: 'ad',
#   60: 'hoc,',
#   61: 'no',
#   62: 'son',
#   63: 'del',
#   64: 'todo',
#   65: 'aplicables',
#   66: 'en',
#   67: 'una',
#   68: 'WSN.',
#   69: 'Con',
#   70: 'el',
#   71: 'fin',
#   72: 'de',
#   73: 'establecer',
#   74: 'claramente',
#   75: 'los',
#   76: 'riesgos',
#   77: 'a',
#   78: 'que',
#   79: 'se',
#   80: 'expone',
#   81: 'la',
#   82: 'informacion',
#   83: 'en',
#   84: 'una',
#   85: 'WSN',
#   86: 'en',
#   87: 'un',
#   88: 'ataque,',
#   89: 'conviene',
#   90: 'retomar',
#   91: 'una',
#   92: 'definición',
#   93: 'de',
#   94: 'la',
#   95: 'seguridad',
#   96: 'de',
#   97: 'la',
#   98: 'informacion,',
#   99: 'la',
#   100: 'cual',
#   101: 'consiste',
#   102: 'en',
#   103: 'otorgarle',
#   104: 'a',
#   105: 'la',
#   106: 'informacion',
#   107: 'cuatro',
#   108: 'propiedades',
#   109: 'basicas,',
#   110: 'como',
#   111: 'se',
#   112: 'indica',
#   113: 'en',
#   114: '[50]:',
#   115: 'Confidencialidad,',
#   116: 'Autenticidad,',
#   117: 'Integridad,Disponibilidad.',
#   118: 'Con',
#   119: 'base',
#   120: 'en',
#   121: 'estas',
#   122: 'cuatro',
#   123: 'propiedades,',
#   124: 'los',
#   125: 'escenarios',
#   126: 'de',
#   127: 'riesgo',
#   128: 'en',
#   129: 'una',
#   130: 'WSN,',
#   131: 'y',
#   132: 'sobre',
#   133: 'todo,',
#   134: 'considerando',
#   135: 'el',
#   136: 'impacto',
#   137: 'de',
#   138: 'un',
#   139: 'ataque',
#   140: 'sobre',
#   141: 'la',
#   142: 'operacion',
#   143: 'de',
#   144: 'la',
#   145: 'red,',
#   146: 'se',
#   147: 'considera',
#   148: 'que',
#   149: 'el',
#   150: 'problema',
#   151: 'de',
#   152: 'la',
#   153: 'suplantacion',
#   154: 'de',
#   155: 'nodos',
#   156: 'es',
#   157: 'uno',
#   158: 'de',
#   159: 'los',
#   160: 'mas',
#   161: 'severos',
#   162: 'dada',
#   163: 'la',
#   164: 'mecanica',
#   165: 'de',
#   166: 'operacion',
#   167: 'de',
#   168: 'la',
#   169: 'red.',
#   170: 'A',
#   171: 'fin',
#   172: 'de',
#   173: 'ilustrar',
#   174: 'esta',
#   175: 'situacion,',
#   176: 'en',
#   177: 'las',
#   178: 'siguientes',
#   179: 'líneas',
#   180: 'se',
#   181: 'plantea',
#   182: 'un',
#   183: 'ataque',
#   184: 'hipotetico.',
#   185: 'Una',
#   186: 'red',
#   187: 'de',
#   188: 'WSN',
#   189: 'con',
#   190: 'topología',
#   191: 'ad',
#   192: 'hoc',
#   193: 'esta',
#   194: 'formada',
#   195: 'por',
#   196: 'varios',
#   197: 'nodos,',
#   198: 'entre',
#   199: 'los',
#   200: 'cuales',
#   201: 'existe',
#   202: 'una',
#   203: 'relacion',
#   204: 'de',
#   205: 'confianza',
#   206: 'mutua,',
#   207: 'por',
#   208: 'lo',
#   209: 'que',
#   210: 'cada',
#   211: 'uno',
#   212: 'puede',
#   213: 'establecer',
#   214: 'enlaces',
#   215: 'con',
#   216: 'cualquier',
#   217: 'otro',
#   218: 'nodo',
#   219: 'que',
#   220: 'este',
#   221: 'dentro',
#   222: 'de',
#   223: 'su',
#   224: 'area',
#   225: 'de',
#   226: 'cobertura.',
#   227: 'Estos',
#   228: 'enlaces',
#   229: 'permiten',
#   230: 'a',
#   231: 'la',
#   232: 'WSN',
#   233: 'cumplir',
#   234: 'sus',
#   235: 'dos',
#   236: 'funciones',
#   237: 'basicas:',
#   238: 'recoleccion',
#   239: 'y',
#   240: 'transporte',
#   241: 'de',
#   242: 'datos',
#   243: 'y',
#   244: 'órdenes',
#   245: 'de',
#   246: 'control',
#   247: 'de',
#   248: 'la',
#   249: 'red.',
#   250: 'En',
#   251: 'las',
#   252: 'condiciones',
#   253: 'mas',
#   254: 'críticas,',
#   255: 'no',
#   256: 'se',
#   257: 'tiene',
#   258: 'forma',
#   259: 'alguna',
#   260: 'de',
#   261: 'establecer',
#   262: 'autenticidad',
#   263: 'entre',
#   264: 'los',
#   265: 'nodos',
#   266: 'de',
#   267: 'la',
#   268: 'red.',
#   269: 'Para',
#   270: 'esta',
#   271: 'red,',
#   272: 'la',
#   273: 'ejecucion',
#   274: 'de',
#   275: 'un',
#   276: 'ataque',
#   277: 'de',
#   278: 'suplantacion',
#   279: 'es',
#   280: 'una',
#   281: 'situacion',
#   282: 'no',
#   283: 'muy',
#   284: 'ajena',
#   285: 'a',
#   286: 'la',
#   287: 'realidad.',
#   288: 'Este',
#   289: 'ataque',
#   290: 'puede',
#   291: 'llevarse',
#   292: 'a',
#   293: 'cabo',
#   294: 'por',
#   295: 'lo',
#   296: 'menos',
#   297: 'de',
#   298: 'las',
#   299: 'siguientes',
#   300: 'dos',
#   301: 'formas:',
#   302: 'Con',
#   303: 'la',
#   304: 'captura',
#   305: 'de',
#   306: 'un',
#   307: 'nodo',
#   308: 'y',
#   309: 'la',
#   310: 'manipulacion',
#   311: 'del',
#   312: 'mismo.',
#   313: 'Con',
#   314: 'la',
#   315: 'incorporacion',
#   316: 'de',
#   317: 'un',
#   318: 'dispositivo',
#   319: 'que',
#   320: 'se',
#   321: 'haga',
#   322: 'pasar',
#   323: 'por',
#   324: 'un',
#   325: 'nodo',
#   326: 'de',
#   327: 'la',
#   328: 'red',
#   329: 'autentico.',
#   330: 'La',
#   331: 'realizacion',
#   332: 'del',
#   333: 'primer',
#   334: 'ataque',
#   335: 'es',
#   336: 'muy',
#   337: 'simple,',
#   338: 'ya',
#   339: 'que',
#   340: 'como',
#   341: 'se',
#   342: 'ha',
#   343: 'dicho',
#   344: 'anteriormente,',
#   345: 'uno',
#   346: 'de',
#   347: 'los',
#   348: 'problemas',
#   349: 'del',
#   350: 'dispositivo',
#   351: 'en',
#   352: 'sí',
#   353: 'es',
#   354: 'la',
#   355: 'facilidad',
#   356: 'de',
#   357: 'ser',
#   358: 'capturado,',
#   359: 'ya',
#   360: 'que',
#   361: 'la',
#   362: 'mayoría',
#   363: 'de',
#   364: 'las',
#   365: 'veces',
#   366: 'los',
#   367: 'sensores',
#   368: 'no',
#   369: 'cuentan',
#   370: 'con',
#   371: 'mecanismos',
#   372: 'de',
#   373: 'proteccion',
#   374: 'física',
#   375: 'alguna,',
#   376: 'ademas',
#   377: 'de',
#   378: 'estar',
#   379: 'expuestos',
#   380: 'a',
#   381: 'fallas,',
#   382: 'e',
#   383: 'interrupcion',
#   384: 'en',
#   385: 'su',
#   386: 'servicio.',
#   387: 'Para',
#   388: 'el',
#   389: 'caso',
#   390: 'del',
#   391: 'segundo',
#   392: 'ataque,',
#   393: 'si',
#   394: 'bien',
#   395: 'se',
#   396: 'requiere',
#   397: 'la',
#   398: 'construccion',
#   399: 'de',
#   400: 'un',
#   401: 'sensor',
#   402: 'compatible',
#   403: 'con',
#   404: 'la',
#   405: 'WSN,',
#   406: 'esto',
#   407: 'no',
#   408: 'parece',
#   409: 'ser',
#   410: 'muy',
#   411: 'complicado',
#   412: 'una',
#   413: 'vez',
#   414: 'que',
#   415: 'se',
#   416: 'tiene',
#   417: 'la',
#   418: 'posibilidad',
#   419: 'de',
#   420: 'capturar',
#   421: 'uno',
#   422: 'o',
#   423: 'mas',
#   424: 'nodos',
#   425: 'originales',
#   426: 'y',
#   427: 'recuperar',
#   428: 'informacion',
#   429: 'del',
#   430: 'mismo',
#   431: 'que',
#   432: 'permita',
#   433: 'completar',
#   434: 'la',
#   435: 'construccion.',
#   436: 'Dada',
#   437: 'la',
#   438: 'dinámica',
#   439: 'de',
#   440: 'operacion',
#   441: 'de',
#   442: 'las',
#   443: 'WSN,',
#   444: 'y',
#   445: 'las',
#   446: 'posibilidades',
#   447: 'de',
#   448: 'ocurrencia',
#   449: 'de',
#   450: 'un',
#   451: 'ataque',
#   452: 'de',
#   453: 'suplantacion,',
#   454: 'es',
#   455: 'conveniente',
#   456: 'evaluar',
#   457: 'que',
#   458: 'tan',
#   459: 'graves',
#   460: 'podrían',
#   461: 'ser',
#   462: 'los',
#   463: 'daños',
#   464: 'en',
#   465: 'caso',
#   466: 'de',
#   467: 'la',
#   468: 'realizacion',
#   469: 'del',
#   470: 'mismo',
#   471: 'para',
#   472: 'así',
#   473: 'tener',
#   474: 'una',
#   475: 'mejor',
#   476: 'perspectiva',
#   477: 'del',
#   478: 'enfoque',
#   479: 'del',
#   480: 'problema',
#   481: 'que',
#   482: 'adopta',
#   483: 'el',
#   484: 'presente',
#   485: 'estudio.',
#   486: 'Bajo',
#   487: 'la',
#   488: 'suposicion',
#   489: 'que',
#   490: 'un',
#   491: 'tercer',
#   492: 'elemento',
#   493: 'ha',
#   494: 'logrado',
#   495: 'suplantar',
#   496: 'un',
#   497: 'nodo',
#   498: 'autentico',
#   499: 'en',
#   500: 'la',
#   501: 'red,',
#   502: 'los',
#   503: 'daños',
#   504: 'generados',
#   505: 'a',
#   506: 'partir',
#   507: 'de',
#   508: 'tal',
#   509: 'accion',
#   510: 'pueden',
#   511: 'agruparse',
#   512: 'en',
#   513: 'dos',
#   514: 'casos',
#   515: 'generales:',
#   516: '1.',
#   517: 'Una',
#   518: 'parte',
#   519: 'de',
#   520: 'la',
#   521: 'informacion',
#   522: 'recolectada',
#   523: 'por',
#   524: 'la',
#   525: 'WSN',
#   526: 'tendra',
#   527: 'que',
#   528: 'hacer',
#   529: 'un',
#   530: 'salto',
#   531: 'a',
#   532: 'traves',
#   533: 'del',
#   534: 'nodo',
#   535: 'comprometido,',
#   536: 'esto',
#   537: 'pone',
#   538: 'en',
#   539: 'riesgo',
#   540: 'la',
#   541: 'disponibilidad,',
#   542: 'la',
#   543: 'integridad',
#   544: 'y',
#   545: 'la',
#   546: 'confidencialidad',
#   547: 'de',
#   548: 'dicha',
#   549: 'informacion,',
#   550: 'ya',
#   551: 'que',
#   552: 'ésta',
#   553: 'podría',
#   554: 'perderse,',
#   555: 'alterarse',
#   556: 'o',
#   557: 'en',
#   558: 'un',
#   559: 'caso',
#   560: 'extremo,',
#   561: 'ser',
#   562: 'expuestos',
#   563: 'a',
#   564: 'terceros',
#   565: 'no',
#   566: 'autorizados.',
#   567: '2.',
#   568: 'De',
#   569: 'igual',
#   570: 'forma,',
#   571: 'las',
#   572: 'órdenes',
#   573: 'de',
#   574: 'control',
#   575: 'que',
#   576: 'viajan',
#   577: 'por',
#   578: 'la',
#   579: 'red',
#   580: 'pueden',
#   581: 'ser',
#   582: 'interceptadas',
#   583: 'y',
#   584: 'alteradas',
#   585: 'al',
#   586: 'momento',
#   587: 'de',
#   588: 'pasar',
#   589: 'por',
#   590: 'el',
#   591: 'nodo',
#   592: 'comprometido,',
#   593: 'acarreando',
#   594: 'un',
#   595: 'mal',
#   596: 'funcionamiento',
#   597: 'de',
#   598: 'la',
#   599: 'WSN,',
#   600: 'llegando',
#   601: 'en',
#   602: 'algunos',
#   603: 'casos',
#   604: 'incluso',
#   605: 'a',
#   606: 'poner',
#   607: 'en',
#   608: 'riesgo',
#   609: 'la',
#   610: 'integridad',
#   611: 'de',
#   612: 'elementos',
#   613: 'circundantes',
#   614: 'al',
#   615: 'sensor',
#   616: 'o',
#   617: 'del',
#   618: 'sensor',
#   619: 'mismo.',
#   620: 'La',
#   621: 'ocurrencia',
#   622: 'de',
#   623: 'cualquiera',
#   624: 'de',
#   625: 'estos',
#   626: 'casos',
#   627: 'anteriores',
#   628: 'sería',
#   629: 'en',
#   630: 'menoscabo',
#   631: 'de',
#   632: 'la',
#   633: 'operacion',
#   634: 'de',
#   635: 'la',
#   636: 'WSN,',
#   637: 'lo',
#   638: 'que',
#   639: 'repercutiría',
#   640: 'en',
#   641: 'consecuencias',
#   642: 'acordes',
#   643: 'a',
#   644: 'la',
#   645: 'importancia',
#   646: 'de',
#   647: 'la',
#   648: 'mision',
#   649: 'que',
#   650: 'desempeñe',
#   651: 'dicha',
#   652: 'red.',
#   653: 'Esto',
#   654: 'deja',
#   655: 'sobre',
#   656: 'la',
#   657: 'mesa',
#   658: 'la',
#   659: 'necesidad',
#   660: 'de',
#   661: 'contar',
#   662: 'con',
#   663: 'mecanismos',
#   664: 'de',
#   665: 'autenticidad',
#   666: 'que',
#   667: 'operen',
#   668: 'en',
#   669: 'las',
#   670: 'WSNs.',
#   671: 'En',
#   672: 'terminos',
#   673: 'generales,',
#   674: 'el',
#   675: 'problema',
#   676: 'de',
#   677: 'establecimiento',
#   678: 'de',
#   679: 'identidad',
#   680: 'tiene',
#   681: 'solucion',
#   682: 'mediante',
#   683: 'un',
#   684: 'proceso',
#   685: 'de',
#   686: 'autenticacion',
#   687: 'entre',
#   688: 'pares.',
#   689: 'En',
#   690: 'las',
#   691: 'redes',
#   692: 'de',
#   693: 'comunicaciones',
#   694: 'y',
#   695: 'en',
#   696: 'los',
#   697: 'sistemas',
#   698: 'de',
#   699: 'informacion,',
#   700: 'este',
#   701: 'proceso',
#   702: 'comunmente',
#   703: 'involucra',
#   704: 'el',
#   705: 'uso',
#   706: 'de',
#   707: 'mecanismos',
#   708: 'criptograficos,',
#   709: 'ya',
#   710: 'sean',
#   711: 'de',
#   712: 'clave',
#   713: 'secreta',
#   714: 'osimetricos,',
#   715: 'o',
#   716: 'bien',
#   717: 'de',
#   718: 'clave',
#   719: 'publica',
#   720: 'o',
#   721: 'asimetricos.',
#   722: 'La',
#   723: 'autenticidad',
#   724: 'en',
#   725: 'una',
#   726: 'WSN',
#   727: 'debe',
#   728: 'ser',
#   729: 'una',
#   730: 'propiedad',
#   731: 'inherente',
#   732: 'de',
#   733: 'la',
#   734: 'propia',
#   735: 'red,',
#   736: 'ya',
#   737: 'que',
#   738: 'como',
#   739: 'se',
#   740: 'ha',
#   741: 'establecido',
#   742: 'en',
#   743: 'la',
#   744: 'seccion',
#   745: 'anterior,',
#   746: 'un',
#   747: 'ataque',
#   748: 'originado',
#   749: 'a',
#   750: 'raíz',
#   751: 'de',
#   752: 'la',
#   753: 'falta',
#   754: 'de',
#   755: 'ésta',
#   756: 'puede',
#   757: 'llegar',
#   758: 'a',
#   759: 'comprometer',
#   760: 'el',
#   761: 'funcionamiento',
#   762: 'de',
#   763: 'la',
#   764: 'red',
#   765: 'completa.',
#   766: 'Sin',
#   767: 'embargo,',
#   768: 'a',
#   769: 'diferencia',
#   770: 'de',
#   771: 'otros',
#   772: 'entornos,',
#   773: 'las',
#   774: 'WSN',
#   775: 'tienen',
#   776: 'como',
#   777: 'un',
#   778: 'marco',
#   779: 'de',
#   780: 'operacion',
#   781: 'muy',
#   782: 'reducido',
#   783: 'en',
#   784: 'recursos,',
#   785: 'por',
#   786: 'lo',
#   787: 'que',
#   788: 'la',
#   789: 'seleccion',
#   790: 'de',
#   791: 'los',
#   792: 'mecanismos',
#   793: 'de',
#   794: 'autenticidad',
#   795: 'a',
#   796: 'utilizar',
#   797: 'debe',
#   798: 'ser',
#   799: 'acorde',
#   800: 'a',
#   801: 'dichas'},
#  'Justificacion4': {1: 'Es',
#   2: 'importante',
#   3: 'abordar',
#   4: 'el',
#   5: 'problema',
#   6: 'del',
#   7: 'agrupamiento',
#   8: 'conceptual',
#   9: 'ya',
#   10: 'que',
#   11: 'en',
#   12: 'muchas',
#   13: 'ciencias',
#   14: 'el',
#   15: 'especialista',
#   16: 'está',
#   17: 'interesado',
#   18: 'en',
#   19: 'encontrar',
#   20: 'no',
#   21: 'sólo',
#   22: 'los',
#   23: 'agrupamientos',
#   24: 'en',
#   25: 'que',
#   26: 'se',
#   27: 'clasifican',
#   28: 'los',
#   29: 'objetos',
#   30: 'sino',
#   31: 'además',
#   32: 'las',
#   33: 'propiedades',
#   34: 'que',
#   35: 'caracterizan',
#   36: 'a',
#   37: 'estos',
#   38: 'agrupamientos.',
#   39: 'Sin',
#   40: 'embargo,',
#   41: 'las',
#   42: 'herramientas',
#   43: 'que',
#   44: 'se',
#   45: 'han',
#   46: 'diseñado',
#   47: 'hasta',
#   48: 'el',
#   49: 'momento',
#   50: 'tienen',
#   51: 'algunas',
#   52: 'limitantes',
#   53: 'al',
#   54: 'ser',
#   55: 'aplicados',
#   56: 'en',
#   57: 'problemas',
#   58: 'donde',
#   59: 'se',
#   60: 'tienen',
#   61: 'objetos',
#   62: 'descritos',
#   63: 'por',
#   64: 'variables',
#   65: 'cualitativas',
#   66: 'y',
#   67: 'cuantitativas',
#   68: 'mezcladas.',
#   69: 'Además,',
#   70: 'no',
#   71: 'permiten',
#   72: 'trabajar',
#   73: 'con',
#   74: 'ausencia',
#   75: 'de',
#   76: 'información',
#   77: 'en',
#   78: 'las',
#   79: 'descripciones',
#   80: 'de',
#   81: 'los',
#   82: 'objetos.',
#   83: 'En',
#   84: 'muchas',
#   85: 'ocasiones',
#   86: 'los',
#   87: 'conceptos',
#   88: 'obtenidos',
#   89: 'por',
#   90: 'los',
#   91: 'algoritmos',
#   92: 'no',
#   93: 'son',
#   94: 'fácilmente',
#   95: 'interpretables,',
#   96: 'no',
#   97: 'cubren',
#   98: 'a',
#   99: 'todos',
#   100: 'los',
#   101: 'objetos',
#   102: 'del',
#   103: 'agrupamiento',
#   104: 'o',
#   105: 'cubren',
#   106: 'objetos',
#   107: 'que',
#   108: 'pertenecen',
#   109: 'a',
#   110: 'otros',
#   111: 'agrupamientos.',
#   112: 'Una',
#   113: 'restricción',
#   114: 'fuerte',
#   115: 'de',
#   116: 'estos',
#   117: 'algoritmos',
#   118: 'es',
#   119: 'que',
#   120: 'los',
#   121: 'conceptos',
#   122: 'deben',
#   123: 'ser',
#   124: 'disjuntos,',
#   125: 'es',
#   126: 'decir,',
#   127: 'los',
#   128: 'objetos',
#   129: 'sólo',
#   130: 'pueden',
#   131: 'pertenecer',
#   132: 'a',
#   133: 'una',
#   134: 'clase.',
#   135: 'Sin',
#   136: 'embargo,',
#   137: 'en',
#   138: 'muchos',
#   139: 'problemas',
#   140: 'reales',
#   141: 'no',
#   142: 'sucede',
#   143: 'así,',
#   144: 'ya',
#   145: 'que',
#   146: 'los',
#   147: 'objetos',
#   148: 'pueden',
#   149: 'pertenecer',
#   150: 'a',
#   151: 'más',
#   152: 'de',
#   153: 'una',
#   154: 'clase',
#   155: 'y',
#   156: 'en',
#   157: 'este',
#   158: 'caso',
#   159: 'los',
#   160: 'conceptos',
#   161: 'deberían',
#   162: 'ser',
#   163: 'no',
#   164: 'disjuntos.',
#   165: 'También',
#   166: 'es',
#   167: 'importante',
#   168: 'desarrollar',
#   169: 'algoritmos',
#   170: 'conceptuales',
#   171: 'difusos',
#   172: 'ya',
#   173: 'que',
#   174: 'en',
#   175: 'problemas',
#   176: 'reales',
#   177: 'el',
#   178: 'especialista',
#   179: 'puede',
#   180: 'estar',
#   181: 'interesado',
#   182: 'en',
#   183: 'conocer',
#   184: 'en',
#   185: 'qué',
#   186: 'grado',
#   187: 'pertenece',
#   188: 'un',
#   189: 'objeto',
#   190: 'a',
#   191: 'cada',
#   192: 'uno',
#   193: 'de',
#   194: 'los',
#   195: 'agrupamientos,',
#   196: 'más',
#   197: 'que',
#   198: 'saber',
#   199: 'si',
#   200: 'un',
#   201: 'objeto',
#   202: 'pertenece',
#   203: 'o',
#   204: 'no',
#   205: 'a',
#   206: 'un'},
#  'Justificacion5': {1: 'El',
#   2: 'uso',
#   3: 'tan',
#   4: 'frecuente',
#   5: 'de',
#   6: 'las',
#   7: 'computadoras',
#   8: 'en',
#   9: 'la',
#   10: 'actualidad',
#   11: 'ha',
#   12: 'conllevado',
#   13: 'al',
#   14: 'desa-',
#   15: 'rrollo',
#   16: 'de',
#   17: 'múltiples',
#   18: 'aplicaciones',
#   19: 'tecnológicas,',
#   20: 'cuya',
#   21: 'base',
#   22: 'es',
#   23: 'el',
#   24: 'lenguaje',
#   25: 'natural.',
#   26: 'Aunado',
#   27: 'a',
#   28: 'esto,',
#   29: 'el',
#   30: 'surgimiento',
#   31: 'de',
#   32: 'Internet',
#   33: 'y',
#   34: 'con',
#   35: 'ello',
#   36: 'la',
#   37: 'gran',
#   38: 'reserva',
#   39: 'de',
#   40: 'recursos',
#   41: 'de',
#   42: 'información',
#   43: 'digitales,',
#   44: 'incita',
#   45: 'el',
#   46: 'desarrollo',
#   47: 'de',
#   48: 'algoritmos',
#   49: 'de',
#   50: 'búsqueda',
#   51: 'eficientes,',
#   52: 'que',
#   53: 'ponen',
#   54: 'a',
#   55: 'nuestra',
#   56: 'disposición',
#   57: 'todo',
#   58: 'un',
#   59: 'mundo',
#   60: 'de',
#   61: 'lenguaje.',
#   62: 'Con',
#   63: 'esta',
#   64: 'plataforma',
#   65: 'es',
#   66: 'común',
#   67: 'el',
#   68: 'uso',
#   69: 'de',
#   70: 'apli-',
#   71: 'caciones',
#   72: 'importantes',
#   73: 'de',
#   74: 'la',
#   75: 'ling\x7fuística',
#   76: 'computacional,',
#   77: 'como:',
#   78: 'la',
#   79: 'traducción',
#   80: 'automática,',
#   81: 'el',
#   82: 'manejo',
#   83: 'y',
#   84: 'gestión',
#   85: 'de',
#   86: 'documentos,',
#   87: 'la',
#   88: 'generación',
#   89: 'de',
#   90: 'texto',
#   91: 'y',
#   92: 'resúmenes,',
#   93: 'las',
#   94: 'bibliote-',
#   95: 'cas',
#   96: 'digitales,',
#   97: 'las',
#   98: 'interfaces',
#   99: 'en',
#   100: 'lenguaje',
#   101: 'natural,',
#   102: 'etc.;',
#   103: 'cuya',
#   104: 'efectividad',
#   105: 'depende',
#   106: 'en',
#   107: 'gran',
#   108: 'medida',
#   109: 'de',
#   110: 'la',
#   111: 'eficacia',
#   112: 'de',
#   113: 'los',
#   114: 'algoritmos',
#   115: 'que',
#   116: 'han',
#   117: 'sido',
#   118: 'propuestos',
#   119: 'y',
#   120: 'que',
#   121: 'en',
#   122: 'todas',
#   123: 'estas',
#   124: 'tareas',
#   125: 'consideran',
#   126: 'la',
#   127: 'desambiguación',
#   128: 'de',
#   129: 'los',
#   130: 'sentidos',
#   131: 'de',
#   132: 'las',
#   133: 'palabras.',
#   134: 'La',
#   135: 'investigación',
#   136: 'y',
#   137: 'mejora',
#   138: 'de',
#   139: 'algoritmos',
#   140: 'de',
#   141: 'WSD',
#   142: 'conduce,',
#   143: 'por',
#   144: 'consiguiente,',
#   145: 'a',
#   146: 'la',
#   147: 'mejora',
#   148: 'en',
#   149: 'las',
#   150: 'aplicaciones',
#   151: 'antes',
#   152: 'mencionadas,',
#   153: 'lo',
#   154: 'que',
#   155: 'justifica',
#   156: 'el',
#   157: 'área',
#   158: 'de',
#   159: 'investigación',
#   160: 'seleccionada',
#   161: 'para',
#   162: 'esta',
#   163: 'tesis.',
#   164: 'Muchos',
#   165: 'métodos',
#   166: 'han',
#   167: 'sido',
#   168: 'propuestos',
#   169: 'para',
#   170: 'llevar',
#   171: 'a',
#   172: 'cabo',
#   173: 'la',
#   174: 'desambiguación',
#   175: 'y',
#   176: 'entre',
#   177: 'ellos',
#   178: 'los',
#   179: 'supervisados',
#   180: 'han',
#   181: 'sido',
#   182: 'de',
#   183: 'los',
#   184: 'más',
#   185: 'sobresalientes,',
#   186: 'con',
#   187: 'la',
#   188: 'presente',
#   189: 'dificultad',
#   190: 'de',
#   191: 'que',
#   192: 'requieren',
#   193: 'datos',
#   194: 'etiquetados',
#   195: 'de',
#   196: 'sentidos,',
#   197: 'adquiridos',
#   198: 'en',
#   199: 'la',
#   200: 'gran',
#   201: 'mayoría',
#   202: 'de',
#   203: 'las',
#   204: 'oca-',
#   205: 'siones,',
#   206: 'de',
#   207: 'forma',
#   208: 'manual.',
#   209: 'La',
#   210: 'disponibilidad',
#   211: 'de',
#   212: 'los',
#   213: 'conjuntos',
#   214: 'adecuados',
#   215: 'de',
#   216: 'datos',
#   217: 'etiquetados',
#   218: 'es',
#   219: 'por',
#   220: 'tanto',
#   221: 'un',
#   222: 'factor',
#   223: 'significativo',
#   224: 'y',
#   225: 'crucial',
#   226: 'para',
#   227: 'el',
#   228: 'entrenamiento',
#   229: 'de',
#   230: 'algoritmos',
#   231: 'basados',
#   232: 'en',
#   233: 'aprendi-',
#   234: 'zaje.',
#   235: 'Por',
#   236: 'desgracia,',
#   237: 'estos',
#   238: 'recursos',
#   239: 'son',
#   240: 'difíciles',
#   241: 'de',
#   242: 'obtener',
#   243: 'y',
#   244: 'de',
#   245: 'crear,',
#   246: 'pues',
#   247: 'requieren',
#   248: 'que',
#   249: 'cada',
#   250: 'una',
#   251: 'de',
#   252: 'las',
#   253: 'palabras',
#   254: 'haya',
#   255: 'sido',
#   256: 'etiquetada',
#   257: 'con',
#   258: 'su',
#   259: 'sentido.',
#   260: 'Este',
#   261: 'procedimiento',
#   262: 'resulta',
#   263: 'muy',
#   264: 'costoso',
#   265: 'y',
#   266: 'por',
#   267: 'ello',
#   268: 'solamente',
#   269: 'algunos',
#   270: 'artículos',
#   271: 'de',
#   272: 'vocabulario',
#   273: 'terminan',
#   274: 'siendo',
#   275: 'etiquetados.',
#   276: 'Mientras',
#   277: 'el',
#   278: 'cuello',
#   279: 'de',
#   280: 'botella',
#   281: 'léxico',
#   282: 'parece',
#   283: 'estar',
#   284: 'resuelto',
#   285: 'para',
#   286: 'el',
#   287: 'idioma',
#   288: 'inglés,',
#   289: 'no',
#   290: 'existe',
#   291: 'un',
#   292: 'amplio',
#   293: 'rango',
#   294: 'de',
#   295: 'recursos',
#   296: 'ling\x7fuísticos',
#   297: 'para',
#   298: 'el',
#   299: 'procesamiento',
#   300: 'del',
#   301: 'lenguaje',
#   302: 'na-',
#   303: 'tural',
#   304: 'en',
#   305: 'otros',
#   306: 'idiomas',
#   307: '[11].',
#   308: 'El',
#   309: 'recurso',
#   310: 'de',
#   311: 'mayor',
#   312: 'cobertura',
#   313: 'de',
#   314: 'palabras',
#   315: 'es',
#   316: 'Princeton',
#   317: 'WordNet,',
#   318: 'un',
#   319: 'lexicón',
#   320: 'de',
#   321: 'concordancia',
#   322: 'semántica',
#   323: 'para',
#   324: 'el',
#   325: 'idioma',
#   326: 'inglés1',
#   327: ',',
#   328: 'que',
#   329: 'agrupa',
#   330: 'los',
#   331: 'sinónimos',
#   332: 'en',
#   333: 'conjuntos',
#   334: 'denominados',
#   335: 'synsets',
#   336: 'y',
#   337: 'proporciona',
#   338: 'a',
#   339: 'las',
#   340: 'palabras',
#   341: 'su',
#   342: 'defini-',
#   343: 'ción.',
#   344: 'El',
#   345: 'propósito',
#   346: 'de',
#   347: 'éste',
#   348: 'es',
#   349: 'producir',
#   350: 'una',
#   351: 'combinación',
#   352: 'de',
#   353: 'diccionario',
#   354: 'y',
#   355: 'tesauro',
#   356: 'que',
#   357: 'sea',
#   358: 'intuitivamente',
#   359: 'utilizable',
#   360: 'y',
#   361: 'respalde',
#   362: 'el',
#   363: 'análisis',
#   364: 'de',
#   365: 'texto',
#   366: 'automático',
#   367: 'y',
#   368: 'las',
#   369: 'aplicaciones',
#   370: 'de',
#   371: 'inteligencia',
#   372: 'artificial.',
#   373: 'Sin',
#   374: 'embargo,',
#   375: 'su',
#   376: 'utilidad',
#   377: 'como',
#   378: 'recurso',
#   379: 'de',
#   380: 'entrenamiento',
#   381: 'y',
#   382: 'evaluación',
#   383: 'para',
#   384: 'anotadores',
#   385: 'de',
#   386: 'sentidos',
#   387: 'supervisados',
#   388: 'está',
#   389: 'actualmente',
#   390: 'algo',
#   391: 'limitada',
#   392: 'por',
#   393: 'su',
#   394: 'metodología',
#   395: 'secuencial.',
#   396: 'Esta',
#   397: 'notación',
#   398: 'obliga',
#   399: 'a',
#   400: 'los',
#   401: 'intérpretes',
#   402: 'a',
#   403: 'familiarizarse',
#   404: 'con',
#   405: 'los',
#   406: 'inventarios',
#   407: 'de',
#   408: 'sentidos',
#   409: 'de',
#   410: 'cada',
#   411: 'palabra',
#   412: '[2].',
#   413: 'A',
#   414: 'pesar',
#   415: 'de',
#   416: 'sus',
#   417: 'inconvenientes,',
#   418: 'este',
#   419: 'recurso',
#   420: 'representa',
#   421: 'una',
#   422: 'contribución',
#   423: 'muy',
#   424: 'im-',
#   425: 'portante',
#   426: 'al',
#   427: 'campo,',
#   428: 'proporcionando',
#   429: 'el',
#   430: 'primer',
#   431: 'conjunto',
#   432: 'de',
#   433: 'datos',
#   434: 'balanceados',
#   435: 'de',
#   436: 'larga',
#   437: 'escala',
#   438: 'para',
#   439: 'el',
#   440: 'estudio',
#   441: 'de',
#   442: 'las',
#   443: 'propiedades',
#   444: 'de',
#   445: 'polisemia',
#   446: 'en',
#   447: 'el',
#   448: 'idioma',
#   449: 'inglés.',
#   450: 'Desafortunadamente,',
#   451: 'no',
#   452: 'existe',
#   453: 'para',
#   454: 'el',
#   455: 'idioma',
#   456: 'español',
#   457: 'un',
#   458: 'recurso',
#   459: 'léxico',
#   460: 'de',
#   461: 'tal',
#   462: 'mag-',
#   463: 'nitud',
#   464: 'con',
#   465: 'el',
#   466: 'cual',
#   467: 'se',
#   468: 'pueda',
#   469: 'proveer',
#   470: 'de',
#   471: 'sentido',
#   472: 'a',
#   473: 'las',
#   474: 'palabras,',
#   475: 'aunque',
#   476: 'se',
#   477: 'han',
#   478: 'están',
#   479: 'llevando',
#   480: 'a',
#   481: 'cabo',
#   482: 'esfuerzos',
#   483: 'en',
#   484: 'esta',
#   485: 'dirección.',
#   486: 'Por',
#   487: 'lo',
#   488: 'tanto,',
#   489: 'la',
#   490: 'búsqueda',
#   491: 'de',
#   492: 'recursos',
#   493: 'dis-',
#   494: 'ponibles',
#   495: 'que',
#   496: 'permitan',
#   497: 'asociar',
#   498: 'etiquetas',
#   499: 'de',
#   500: 'sentidos',
#   501: 'y',
#   502: 'más',
#   503: 'aún,',
#   504: 'esto',
#   505: 'lo',
#   506: 'realice',
#   507: 'de',
#   508: 'forma',
#   509: 'automática,',
#   510: 'es',
#   511: 'una',
#   512: 'tarea',
#   513: 'intermedia',
#   514: 'indispensable',
#   515: 'en',
#   516: 'el',
#   517: 'procesamiento',
#   518: 'de',
#   519: 'lenguaje'},
#  'Justificacion6': {1: 'Esta',
#   2: 'tesis',
#   3: 'espera',
#   4: 'realizar',
#   5: 'distintas',
#   6: 'contribuciones.',
#   7: 'En',
#   8: 'primer',
#   9: 'lugar,',
#   10: 'incorporando',
#   11: 'determinadas',
#   12: 'herramientas',
#   13: 'conceptuales',
#   14: 'desarrolladas',
#   15: 'en',
#   16: 'el',
#   17: 'campo',
#   18: 'de',
#   19: 'los',
#   20: 'estudios',
#   21: 'sociales',
#   22: 'de',
#   23: 'la',
#   24: 'ciencia',
#   25: 'y',
#   26: 'la',
#   27: 'tecnología',
#   28: 'que',
#   29: 'no',
#   30: 'han',
#   31: 'sido',
#   32: 'mayormente',
#   33: 'aplicadas',
#   34: 'al',
#   35: 'estudio',
#   36: 'particular',
#   37: 'de',
#   38: 'las',
#   39: 'Tecnologías',
#   40: 'de',
#   41: 'la',
#   42: 'Información',
#   43: 'y',
#   44: 'la',
#   45: 'Comunicación.',
#   46: 'Añadir',
#   47: 'aquellos',
#   48: 'conceptos',
#   49: 'presentes',
#   50: 'en',
#   51: 'el',
#   52: 'estudio',
#   53: 'de',
#   54: 'las',
#   55: 'tecnologías',
#   56: 'en',
#   57: 'general',
#   58: 'permitiría',
#   59: 'comprender',
#   60: 'lo',
#   61: 'particular',
#   62: 'de',
#   63: 'los',
#   64: 'procesos',
#   65: 'de',
#   66: 'incorporación',
#   67: 'de',
#   68: 'TIC',
#   69: 'y',
#   70: 'de',
#   71: 'la',
#   72: 'construcción',
#   73: 'de',
#   74: '"campus',
#   75: 'virtuales\x9d',
#   76: 'en',
#   77: 'universidades',
#   78: 'del',
#   79: 'país.',
#   80: 'Junto',
#   81: 'con',
#   82: 'ello,',
#   83: 'proporcionar',
#   84: 'nuevos',
#   85: 'andamiajes',
#   86: 'teóricos',
#   87: 'vinculados',
#   88: 'con',
#   89: 'las',
#   90: 'características',
#   91: 'inherentes',
#   92: 'a',
#   93: 'las',
#   94: 'TIC.',
#   95: 'Este',
#   96: 'propósito',
#   97: 'se',
#   98: 'presenta',
#   99: 'como',
#   100: 'inédito',
#   101: 'ya',
#   102: 'que',
#   103: 'pocos',
#   104: 'trabajos',
#   105: 'en',
#   106: 'el',
#   107: 'ámbito',
#   108: 'de',
#   109: 'las',
#   110: 'ciencias',
#   111: 'sociales',
#   112: 'han',
#   113: 'analizado',
#   114: 'las',
#   115: 'dinámicas',
#   116: 'de',
#   117: 'desarrollo',
#   118: 'tecnológico',
#   119: 'que',
#   120: 'posibilitan',
#   121: 'la',
#   122: 'construcción',
#   123: 'de',
#   124: 'entornos',
#   125: '"virtuales\x9d',
#   126: 'que',
#   127: 'se',
#   128: 'gestan',
#   129: 'en',
#   130: 'las',
#   131: 'universidades',
#   132: 'desde',
#   133: 'un',
#   134: 'enfoque',
#   135: 'que',
#   136: 'se',
#   137: 'encuadre',
#   138: 'en',
#   139: 'el',
#   140: 'propuesto',
#   141: 'por',
#   142: 'el',
#   143: 'campo',
#   144: 'de',
#   145: 'los',
#   146: 'estudios',
#   147: 'sociales',
#   148: 'de',
#   149: 'la',
#   150: 'ciencia',
#   151: 'y',
#   152: 'la',
#   153: 'tecnología.',
#   154: 'En',
#   155: 'ese',
#   156: 'sentido',
#   157: 'se',
#   158: 'aspira',
#   159: 'a',
#   160: 'establecer',
#   161: 'una',
#   162: 'ruptura',
#   163: 'con',
#   164: 'aquellas',
#   165: 'formas',
#   166: '"cristalizadas\x9d',
#   167: 'de',
#   168: 'determinismo',
#   169: 'tecnológico',
#   170: 'que',
#   171: 'consideran',
#   172: 'que',
#   173: 'la',
#   174: 'creciente',
#   175: '"difusión\x9d',
#   176: 'y',
#   177: 'proliferación',
#   178: 'de',
#   179: 'las',
#   180: 'Tecnologías',
#   181: 'de',
#   182: 'la',
#   183: 'Información',
#   184: 'y',
#   185: 'la',
#   186: 'Comunicación',
#   187: 'producen',
#   188: '"efectos\x9d',
#   189: 'en',
#   190: 'la',
#   191: '"sociedad\x9d',
#   192: 'y',
#   193: 'se',
#   194: 'limitan',
#   195: 'a',
#   196: 'una',
#   197: 'mirada',
#   198: 'meramente',
#   199: 'instrumental',
#   200: 'dejando',
#   201: 'de',
#   202: 'lado',
#   203: 'aquellas',
#   204: 'que',
#   205: 'hacen',
#   206: 'hincapié',
#   207: 'en',
#   208: 'la',
#   209: 'tecnología',
#   210: 'como',
#   211: 'construcción',
#   212: 'social,',
#   213: 'entendiendo',
#   214: 'que',
#   215: 'no',
#   216: 'hay',
#   217: 'una',
#   218: 'relación',
#   219: 'sociedad-tecnología,',
#   220: 'como',
#   221: 'si',
#   222: 'se',
#   223: 'tratara',
#   224: 'de',
#   225: 'dos',
#   226: 'entidades',
#   227: 'separadas',
#   228: 'y',
#   229: 'que',
#   230: 'la',
#   231: 'distinción',
#   232: 'misma',
#   233: 'entre',
#   234: 'social',
#   235: 'y',
#   236: 'técnico',
#   237: 'debe',
#   238: 'considerarse',
#   239: 'como',
#   240: 'el',
#   241: 'resultado',
#   242: 'de',
#   243: 'un',
#   244: 'proceso',
#   245: 'de',
#   246: '"co-construcción\x9d.',
#   247: 'Por',
#   248: 'otra',
#   249: 'parte,',
#   250: 'esta',
#   251: 'investigación',
#   252: 'espera',
#   253: 'contribuir',
#   254: 'al',
#   255: 'campo',
#   256: 'de',
#   257: 'los',
#   258: 'estudios',
#   259: 'de',
#   260: 'la',
#   261: 'educación',
#   262: 'superior',
#   263: 'y',
#   264: 'los',
#   265: 'estudios',
#   266: 'sobre',
#   267: 'universidad',
#   268: 'en',
#   269: 'el',
#   270: 'cual',
#   271: 'aparece',
#   272: 'como',
#   273: 'vacante',
#   274: 'la',
#   275: 'problemática',
#   276: 'vinculada',
#   277: 'a',
#   278: 'la',
#   279: 'educación',
#   280: 'universitaria',
#   281: '"virtual\x9d.',
#   282: 'La',
#   283: 'utilización',
#   284: 'de',
#   285: 'la',
#   286: 'tecnología',
#   287: 'para',
#   288: 'la',
#   289: 'enseñanza',
#   290: 'y',
#   291: 'la',
#   292: 'investigación',
#   293: 'no',
#   294: 'es',
#   295: 'únicamente',
#   296: 'una',
#   297: 'cuestión',
#   298: 'técnica,',
#   299: 'puesto',
#   300: 'que',
#   301: 'replantea',
#   302: 'cuestiones',
#   303: 'fundamentales',
#   304: 'no',
#   305: 'sólo',
#   306: 'sobre',
#   307: 'los',
#   308: 'métodos',
#   309: 'de',
#   310: 'trabajo',
#   311: 'sino',
#   312: 'sobre',
#   313: 'las',
#   314: 'metas',
#   315: 'y',
#   316: 'los',
#   317: 'propósitos',
#   318: 'que',
#   319: 'persiguen',
#   320: 'las',
#   321: 'instituciones',
#   322: 'universitarias.',
#   323: 'Así,',
#   324: 'el',
#   325: 'estudio',
#   326: 'de',
#   327: 'los',
#   328: '"campus',
#   329: 'virtuales\x9d',
#   330: 'de',
#   331: 'las',
#   332: 'universidades',
#   333: 'nacionales',
#   334: 'argentinas',
#   335: 'podría',
#   336: 'contribuir',
#   337: 'a',
#   338: 'replantear',
#   339: 'la',
#   340: 'dinámica',
#   341: 'de',
#   342: 'formulación',
#   343: 'de',
#   344: 'políticas',
#   345: 'y',
#   346: 'toma',
#   347: 'de',
#   348: 'decisiones',
#   349: 'al',
#   350: 'interior',
#   351: 'de',
#   352: 'la',
#   353: 'universidad.',
#   354: 'Por',
#   355: 'último',
#   356: 'se',
#   357: 'espera',
#   358: 'contribuir',
#   359: 'a',
#   360: 'los',
#   361: 'estudios',
#   362: 'que',
#   363: 'relacionan',
#   364: 'los',
#   365: 'procesos',
#   366: 'de',
#   367: '"innovación\x9d',
#   368: 'tecnológica',
#   369: 'y',
#   370: 'los',
#   371: 'territorios',
#   372: 'indagando',
#   373: 'en',
#   374: 'la',
#   375: 'nueva',
#   376: 'dimensión',
#   377: 'espacio-temporal',
#   378: 'que',
#   379: 'generan',
#   380: 'las',
#   381: 'TIC',
#   382: 'y',
#   383: 'en',
#   384: 'las',
#   385: 'condiciones',
#   386: 'territoriales,',
#   387: 'económicas,',
#   388: 'sociales,',
#   389: 'organizacionales',
#   390: 'y',
#   391: 'simbólicas,',
#   392: 'entre',
#   393: 'otras,',
#   394: 'que',
#   395: 'inciden',
#   396: 'sobre',
#   397: 'la',
#   398: 'implementación',
#   399: 'de',
#   400: 'los',
#   401: '"campus'},
#  'Justificacion7': {1: 'Actualmente',
#   2: 'nos',
#   3: 'encontramos',
#   4: 'en',
#   5: 'un',
#   6: 'proceso',
#   7: 'de',
#   8: 'constantes',
#   9: 'cambios',
#   10: 'y',
#   11: 'transformaciones',
#   12: 'que',
#   13: 'obedecen',
#   14: 'a',
#   15: 'una',
#   16: 'serie',
#   17: 'de',
#   18: 'factores',
#   19: 'y',
#   20: 'entre',
#   21: 'ellas',
#   22: 'a',
#   23: 'la',
#   24: 'incorporación',
#   25: 'vertiginosa',
#   26: 'de',
#   27: 'nuevas',
#   28: 'tecnologías',
#   29: 'de',
#   30: 'la',
#   31: 'información',
#   32: 'y',
#   33: 'la',
#   34: 'comunicación',
#   35: 'en',
#   36: 'diversos',
#   37: 'campos,',
#   38: 'incluidos',
#   39: 'en',
#   40: 'el',
#   41: 'aspecto',
#   42: 'educativo.',
#   43: 'De',
#   44: 'acuerdo',
#   45: 'a',
#   46: 'la',
#   47: 'UNESCO',
#   48: '(2005)',
#   49: 'los',
#   50: 'sistemas',
#   51: 'educativos',
#   52: 'de',
#   53: 'todo',
#   54: 'el',
#   55: 'mundo',
#   56: 'se',
#   57: 'enfrentan',
#   58: 'actualmente',
#   59: 'al',
#   60: 'desafío',
#   61: 'de',
#   62: 'utilizar',
#   63: 'las',
#   64: 'nuevas',
#   65: 'tecnologías',
#   66: 'de',
#   67: 'la',
#   68: 'información',
#   69: 'y',
#   70: 'la',
#   71: 'comunicación',
#   72: 'TIC',
#   73: 'para',
#   74: 'proveer',
#   75: 'a',
#   76: 'sus',
#   77: 'estudiantes',
#   78: 'con',
#   79: 'las',
#   80: 'herramientas',
#   81: 'y',
#   82: 'conocimientos',
#   83: 'necesarios',
#   84: 'para',
#   85: 'el',
#   86: 'siglo',
#   87: 'XXI.',
#   88: 'En',
#   89: 'el',
#   90: 'año',
#   91: '2005,',
#   92: 'el',
#   93: 'Informe',
#   94: 'Mundial',
#   95: 'sobre',
#   96: 'la',
#   97: 'Educación',
#   98: 'de',
#   99: 'la',
#   100: 'UNESCO,',
#   101: '"El',
#   102: 'Imperativo',
#   103: 'de',
#   104: 'la',
#   105: 'Calidad\x9d,',
#   106: 'enfatizó',
#   107: 'en',
#   108: 'la',
#   109: 'importancia',
#   110: 'de',
#   111: 'los',
#   112: 'métodos',
#   113: 'de',
#   114: 'aprendizaje',
#   115: 'y',
#   116: 'en',
#   117: 'la',
#   118: 'utilización',
#   119: 'de',
#   120: 'materiales',
#   121: 'educativos,',
#   122: 'infraestructura',
#   123: 'y',
#   124: 'acceso',
#   125: 'a',
#   126: 'las',
#   127: 'TIC,',
#   128: 'como',
#   129: 'un',
#   130: 'importante',
#   131: 'desafío',
#   132: 'en',
#   133: 'el',
#   134: 'campo',
#   135: 'educativo.',
#   136: 'Las',
#   137: 'tecnologías',
#   138: 'de',
#   139: 'la',
#   140: 'información',
#   141: 'y',
#   142: 'la',
#   143: 'comunicación',
#   144: 'TIC',
#   145: 'son',
#   146: 'un',
#   147: 'factor',
#   148: 'de',
#   149: 'vital',
#   150: 'importancia',
#   151: 'en',
#   152: 'la',
#   153: 'transformación',
#   154: 'de',
#   155: 'diversos',
#   156: 'campos',
#   157: 'de',
#   158: 'la',
#   159: 'sociedad.',
#   160: 'En',
#   161: 'el',
#   162: 'campo',
#   163: 'educativo',
#   164: 'las',
#   165: 'TIC',
#   166: 'tienen',
#   167: 'el',
#   168: 'potencial',
#   169: 'de',
#   170: 'transformar',
#   171: 'la',
#   172: 'naturaleza',
#   173: 'de',
#   174: 'la',
#   175: 'educación',
#   176: 'en',
#   177: 'cuanto',
#   178: 'a',
#   179: 'dónde',
#   180: 'y',
#   181: 'cómo',
#   182: 'se',
#   183: 'produce',
#   184: 'el',
#   185: 'proceso',
#   186: 'de',
#   187: 'enseñanza',
#   188: 'aprendizaje,',
#   189: 'así',
#   190: 'como',
#   191: 'de',
#   192: 'introducir',
#   193: 'cambios',
#   194: 'en',
#   195: 'los',
#   196: 'roles',
#   197: 'de',
#   198: 'los',
#   199: 'profesores',
#   200: 'y',
#   201: 'los',
#   202: 'estudiantes,',
#   203: 'y',
#   204: 'en',
#   205: 'las',
#   206: 'diferentes',
#   207: 'acciones',
#   208: 'que',
#   209: 'se',
#   210: 'realiza',
#   211: 'en',
#   212: 'el',
#   213: 'proceso',
#   214: 'educativo,',
#   215: 'incluido',
#   216: 'en',
#   217: 'temas',
#   218: 'de',
#   219: 'gestión',
#   220: 'institucional.',
#   221: 'En',
#   222: 'este',
#   223: 'nuevo',
#   224: 'panorama',
#   225: 'se',
#   226: 'enfatiza',
#   227: 'la',
#   228: 'importancia',
#   229: 'de',
#   230: 'desarrollar',
#   231: 'nuevas',
#   232: 'competencias,',
#   233: 'capacidades,',
#   234: 'habilidades',
#   235: 'y',
#   236: 'uso',
#   237: 'de',
#   238: 'herramientas.',
#   239: 'De',
#   240: 'acuerdo',
#   241: 'a',
#   242: 'Valzacchi',
#   243: '(2003)',
#   244: 'los',
#   245: 'estudiantes',
#   246: 'deben',
#   247: 'cultivar',
#   248: 'las',
#   249: 'siguientes',
#   250: 'destrezas',
#   251: 'que',
#   252: 'según',
#   253: 'los',
#   254: 'estándares',
#   255: 'de',
#   256: 'la',
#   257: 'International',
#   258: 'Society',
#   259: 'for',
#   260: 'Technology',
#   261: 'in',
#   262: 'Education',
#   263: 'son',
#   264: 'necesarios',
#   265: 'para',
#   266: 'desenvolverse',
#   267: 'en',
#   268: 'el',
#   269: 'siglo',
#   270: 'XXI.',
#   271: 'Estas',
#   272: 'son:',
#   273: 'manejarse',
#   274: 'con',
#   275: 'soltura',
#   276: 'en',
#   277: 'el',
#   278: 'empleo',
#   279: 'de',
#   280: 'la',
#   281: 'tecnología;',
#   282: 'comunicar',
#   283: 'información',
#   284: 'e',
#   285: 'ideas',
#   286: 'usando',
#   287: 'una',
#   288: 'gran',
#   289: 'variedad',
#   290: 'de',
#   291: 'medios',
#   292: 'y',
#   293: 'formatos;',
#   294: 'acceder,',
#   295: 'intercambiar,',
#   296: 'compilar,',
#   297: 'organizar,',
#   298: 'analizar',
#   299: 'y',
#   300: 'sintetizar',
#   301: 'información;',
#   302: 'saber',
#   303: 'encontrar',
#   304: 'información',
#   305: 'adicional;',
#   306: 'saber',
#   307: 'evaluar',
#   308: 'la',
#   309: 'información',
#   310: 'y',
#   311: 'sus',
#   312: 'fuentes;',
#   313: 'construir,',
#   314: 'producir',
#   315: 'y',
#   316: 'publicar',
#   317: 'modelos,',
#   318: 'contenidos',
#   319: 'y',
#   320: 'otros',
#   321: 'trabajos',
#   322: 'creativos;',
#   323: 'colaborar',
#   324: 'y',
#   325: 'cooperar',
#   326: 'en',
#   327: 'grupos',
#   328: 'de',
#   329: 'trabajo',
#   330: 'e',
#   331: 'interactuar',
#   332: 'con',
#   333: 'otros',
#   334: 'en',
#   335: 'forma',
#   336: 'apropiada',
#   337: 'y',
#   338: 'ética.',
#   339: 'En',
#   340: 'el',
#   341: 'país',
#   342: 'se',
#   343: 'inició',
#   344: 'el',
#   345: 'proceso',
#   346: 'de',
#   347: 'integración',
#   348: 'de',
#   349: 'las',
#   350: 'TIC',
#   351: 'en',
#   352: 'el',
#   353: 'sistema',
#   354: 'educativo',
#   355: 'público',
#   356: 'estatal',
#   357: 'a',
#   358: 'través',
#   359: 'del',
#   360: 'Proyecto',
#   361: 'Huascarán',
#   362: 'y',
#   363: 'actualmente',
#   364: 'a',
#   365: 'través',
#   366: 'de',
#   367: 'la',
#   368: 'Dirección',
#   369: 'General',
#   370: 'de',
#   371: 'Tecnologías',
#   372: 'Educativas',
#   373: 'del',
#   374: 'Ministerio',
#   375: 'de',
#   376: 'Educación,',
#   377: 'con',
#   378: 'la',
#   379: 'finalidad',
#   380: 'que',
#   381: 'las',
#   382: 'TIC',
#   383: 'de',
#   384: 'acuerdo',
#   385: 'al',
#   386: '(Ministerio',
#   387: 'de',
#   388: 'Educación,',
#   389: '2007,',
#   390: 'p.60)',
#   391: '"mejoren',
#   392: 'la',
#   393: 'calidad',
#   394: 'de',
#   395: 'la',
#   396: 'educación',
#   397: 'secundaria',
#   398: 'para',
#   399: 'que',
#   400: 'los',
#   401: 'estudiantes',
#   402: 'alcancen',
#   403: 'una',
#   404: 'formación',
#   405: 'integral',
#   406: 'que',
#   407: 'comprenda',
#   408: 'la',
#   409: 'consecución',
#   410: 'de',
#   411: 'logros',
#   412: 'de',
#   413: 'aprendizaje',
#   414: 'y',
#   415: 'una',
#   416: 'sólida',
#   417: 'formación',
#   418: 'en',
#   419: 'valores\x9d.',
#   420: 'Esta',
#   421: 'investigación',
#   422: 'también',
#   423: 'se',
#   424: 'justifica',
#   425: 'teniendo',
#   426: 'en',
#   427: 'consideración',
#   428: 'que',
#   429: 'de',
#   430: 'acuerdo',
#   431: 'a',
#   432: '(Guiloff,',
#   433: '2007,',
#   434: 'p.11)',
#   435: '"no',
#   436: 'existe',
#   437: 'suficiente',
#   438: 'información',
#   439: 'sobre',
#   440: 'el',
#   441: 'compromiso',
#   442: 'e',
#   443: 'interacción',
#   444: 'tecnológica',
#   445: 'relacionada',
#   446: 'con',
#   447: 'las',
#   448: 'actividades',
#   449: 'de',
#   450: 'aprendizaje',
#   451: 'formal',
#   452: 'de',
#   453: 'los',
#   454: 'estudiantes\x9d',
#   455: 'y',
#   456: 'de',
#   457: 'acuerdo',
#   458: 'a',
#   459: '(Condie,',
#   460: '2007,',
#   461: 'p.75)',
#   462: '"a',
#   463: 'la',
#   464: 'fecha',
#   465: 'hay',
#   466: 'muchos',
#   467: 'estudios',
#   468: 'de',
#   469: 'la',
#   470: 'relación',
#   471: 'entre',
#   472: 'TIC',
#   473: 'y',
#   474: 'la',
#   475: 'educación,',
#   476: 'sin',
#   477: 'embargo',
#   478: 'varían',
#   479: 'de',
#   480: 'acuerdo',
#   481: 'a',
#   482: 'las',
#   483: 'regiones',
#   484: 'donde',
#   485: 'se',
#   486: 'han',
#   487: 'realizado,',
#   488: 'con',
#   489: 'estudiantes',
#   490: 'de',
#   491: 'ciertas',
#   492: 'características',
#   493: 'y',
#   494: 'disciplinas;',
#   495: 'siendo',
#   496: 'necesario',
#   497: 'hacer',
#   498: 'investigaciones',
#   499: 'locales',
#   500: 'específicas\x9d.',
#   501: 'Asimismo',
#   502: 'este',
#   503: 'tema',
#   504: 'es',
#   505: 'de',
#   506: 'especial',
#   507: 'importancia',
#   508: 'y',
#   509: 'de',
#   510: 'actualidad,',
#   511: 'y',
#   512: 'de',
#   513: 'acuerdo',
#   514: 'a',
#   515: 'las',
#   516: 'diversas',
#   517: 'organizaciones,',
#   518: 'instituciones',
#   519: 'e',
#   520: 'investigadores',
#   521: 'que',
#   522: 'vienen',
#   523: 'trabajando',
#   524: 'sobre',
#   525: 'las',
#   526: 'TIC',
#   527: 'y',
#   528: 'la',
#   529: 'educación,',
#   530: 'han',
#   531: 'convocado',
#   532: 'a',
#   533: 'realizar',
#   534: 'investigaciones',
#   535: 'a',
#   536: 'nivel',
#   537: 'micro',
#   538: 'con',
#   539: 'la',
#   540: 'finalidad',
#   541: 'de',
#   542: 'contribuir',
#   543: 'a',
#   544: 'la',
#   545: 'generación',
#   546: 'de',
#   547: 'conocimiento',
#   548: 'científico.',
#   549: 'El',
#   550: 'trabajo',
#   551: 'también',
#   552: 'se',
#   553: 'justifica',
#   554: 'puesto',
#   555: 'que',
#   556: 'permitirá',
#   557: 'entregar',
#   558: 'a',
#   559: 'las',
#   560: 'autoridades',
#   561: 'que',
#   562: 'vienen',
#   563: 'implementando',
#   564: 'la',
#   565: 'integración',
#   566: 'de',
#   567: 'las',
#   568: 'TIC',
#   569: 'a',
#   570: 'través',
#   571: 'de',
#   572: 'la',
#   573: 'Dirección',
#   574: 'General',
#   575: 'de',
#   576: 'Tecnologías',
#   577: 'Educativas',
#   578: 'del',
#   579: 'Ministerio',
#   580: 'de',
#   581: 'Educación,',
#   582: 'resultados',
#   583: 'sobre',
#   584: 'el',
#   585: 'desarrollo',
#   586: 'de',
#   587: 'capacidades',
#   588: 'TIC',
#   589: 'en',
#   590: 'los'},
#  'Justificacion8': {1: 'Los',
#   2: 'problemas',
#   3: 'de',
#   4: 'optimización',
#   5: 'industriales,',
#   6: 'en',
#   7: 'general,',
#   8: 'son',
#   9: 'muy',
#   10: 'demandantes',
#   11: 'en',
#   12: 'cuanto',
#   13: 'al',
#   14: 'uso',
#   15: 'de',
#   16: 'los',
#   17: 'recursos',
#   18: 'computacionales.',
#   19: 'En',
#   20: 'la',
#   21: 'investigación',
#   22: 'hecha',
#   23: 'por',
#   24: 'Zabinsky',
#   25: '[14]',
#   26: 'se',
#   27: 'describe',
#   28: 'el',
#   29: 'ambiente',
#   30: 'donde',
#   31: 'operan',
#   32: 'y',
#   33: 'diseñan',
#   34: 'las',
#   35: 'aplicaciones',
#   36: 'de',
#   37: 'ingeniería.',
#   38: 'Estos',
#   39: 'ambientes',
#   40: 'tienen',
#   41: 'restricciones',
#   42: 'en',
#   43: 'los',
#   44: 'tiempos',
#   45: 'de',
#   46: 'entrega',
#   47: 'de',
#   48: 'sus',
#   49: 'productos',
#   50: 'originadas',
#   51: 'por',
#   52: 'los',
#   53: 'compromisos',
#   54: 'con',
#   55: 'los',
#   56: 'clientes.',
#   57: 'Los',
#   58: 'desarrollos',
#   59: 'propuestos',
#   60: 'para',
#   61: 'encontrar',
#   62: 'las',
#   63: 'soluciones',
#   64: 'a',
#   65: 'los',
#   66: 'problemas',
#   67: 'técnicos,',
#   68: 'particularmente',
#   69: 'los',
#   70: 'de',
#   71: 'optimización,',
#   72: 'se',
#   73: 'ven',
#   74: 'afectados',
#   75: 'por',
#   76: 'dichas',
#   77: 'restricciones,',
#   78: 'es',
#   79: 'necesario',
#   80: 'disponer',
#   81: 'de',
#   82: 'herramientas',
#   83: 'que',
#   84: 'permitan',
#   85: 'atacar',
#   86: 'y',
#   87: 'resolver',
#   88: 'los',
#   89: 'problemas',
#   90: 'en',
#   91: 'los',
#   92: 'tiempos',
#   93: 'establecidos.',
#   94: 'Una',
#   95: 'alternativa',
#   96: 'que',
#   97: 'permite',
#   98: 'superar',
#   99: 'las',
#   100: 'restricciones',
#   101: 'de',
#   102: 'tiempo',
#   103: 'de',
#   104: 'los',
#   105: 'problemas',
#   106: 'de',
#   107: 'ingeniería',
#   108: 'es',
#   109: 'la',
#   110: 'implementación,',
#   111: 'en',
#   112: 'hardware',
#   113: 'especializado,',
#   114: 'de',
#   115: 'los',
#   116: 'algoritmos',
#   117: 'numéricos',
#   118: 'utilizados.',
#   119: 'Bajo',
#   120: 'este',
#   121: 'enfoque',
#   122: 'se',
#   123: 'abre',
#   124: 'la',
#   125: 'posibilidad',
#   126: 'de',
#   127: 'disminuir',
#   128: 'el',
#   129: 'tiempo',
#   130: 'de',
#   131: 'ejecución',
#   132: 'del',
#   133: 'esquema',
#   134: 'seleccionado,',
#   135: 'comparado',
#   136: 'con',
#   137: 'una',
#   138: 'plataforma',
#   139: 'de',
#   140: 'procesamiento',
#   141: 'convencional,',
#   142: 'cuando',
#   143: 'la',
#   144: 'implementación',
#   145: 'en',
#   146: 'hardware',
#   147: 'es',
#   148: 'soportada',
#   149: 'por',
#   150: 'el',
# ...
#   40: 'con',
#   41: 'patas',
#   42: 'es',
#   43: 'su',
#   44: 'capacidad',
#   45: 'para',
#   46: 'poder',
#   47: 'desplazarse',
#   48: 'sobre',
#   49: 'una',
#   50: 'amplia',
#   51: 'variedad',
#   52: 'de',
#   53: 'terrenos',
#   54: 'no',
#   55: 'estructurados.',
#   56: 'Esta',
#   57: 'particularidad',
#   58: 'los',
#   59: 'hace',
#   60: 'muy',
#   61: 'atractivos',
#   62: 'para',
#   63: 'su',
#   64: 'aplicación',
#   65: 'practica',
#   66: 'como',
#   67: 'robots',
#   68: 'de',
#   69: 'servicios',
#   70: 'en',
#   71: 'los',
#   72: 'que',
#   73: 'se',
#   74: 'requiere',
#   75: 'la',
#   76: 'locomoción',
#   77: 'sobre',
#   78: 'terreno',
#   79: 'natural,',
#   80: 'el',
#   81: 'cual',
#   82: 'se',
#   83: 'caracteriza',
#   84: 'por',
#   85: 'presentar',
#   86: 'superficies',
#   87: 'irregulares,',
#   88: 'diversos',
#   89: 'tipos',
#   90: 'de',
#   91: 'obstáculos',
#   92: 'y',
#   93: 'distintas',
#   94: 'pendientes.',
#   95: 'Sin',
#   96: 'embargo,',
#   97: 'el',
#   98: 'caminar',
#   99: 'sobre',
#   100: 'terreno',
#   101: 'natural',
#   102: 'implica',
#   103: 'que',
#   104: 'tanto',
#   105: 'la',
#   106: 'geometría',
#   107: 'como',
#   108: 'las',
#   109: 'propiedades',
#   110: 'físicas',
#   111: 'de',
#   112: 'los',
#   113: 'elementos',
#   114: 'que',
#   115: 'rodean',
#   116: 'al',
#   117: 'robot',
#   118: 'son',
#   119: 'desconocidas',
#   120: 'y',
#   121: 'muy',
#   122: 'variables,',
#   123: 'por',
#   124: 'lo',
#   125: 'que',
#   126: 'es',
#   127: 'necesario',
#   128: 'dotar',
#   129: 'al',
#   130: 'robot',
#   131: 'de',
#   132: 'una',
#   133: 'estrategia',
#   134: 'que',
#   135: 'adapte',
#   136: 'su',
#   137: 'comportamiento',
#   138: 'con',
#   139: 'respecto',
#   140: 'al',
#   141: 'entorno.',
#   142: 'Si',
#   143: 'bien',
#   144: 'el',
#   145: 'modelo',
#   146: 'del',
#   147: 'robot',
#   148: 'puede',
#   149: 'ser',
#   150: 'conocido',
#   151: 'con',
#   152: 'precisión',
#   153: 'razonable,',
#   154: 'resulta',
#   155: 'difícil',
#   156: 'obtener',
#   157: 'una',
#   158: 'descripción',
#   159: 'detallada',
#   160: 'del',
#   161: 'entorno,',
#   162: 'especialmente',
#   163: 'en',
#   164: 'lo',
#   165: 'que',
#   166: 'respecta',
#   167: 'a',
#   168: 'sus',
#   169: 'propiedades',
#   170: 'físicas.',
#   171: 'La',
#   172: 'estabilidad',
#   173: 'de',
#   174: 'los',
#   175: 'robots',
#   176: 'caminantes',
#   177: 'durante',
#   178: 'la',
#   179: 'realización',
#   180: 'del',
#   181: 'ciclo',
#   182: 'de',
#   183: 'locomoción,',
#   184: 'es',
#   185: 'de',
#   186: 'gran',
#   187: 'importancia.',
#   188: 'Por',
#   189: 'lo',
#   190: 'tanto,',
#   191: 'la',
#   192: 'consideración',
#   193: 'de',
#   194: 'una',
#   195: 'determinada',
#   196: 'medida',
#   197: 'de',
#   198: 'estabilidad',
#   199: 'durante',
#   200: 'la',
#   201: 'locomoción',
#   202: 'influye',
#   203: 'de',
#   204: 'manera',
#   205: 'directa',
#   206: 'en',
#   207: 'la',
#   208: 'seguridad',
#   209: 'del',
#   210: 'robot.',
#   211: 'En',
#   212: 'este',
#   213: 'trabajo',
#   214: 'se',
#   215: 'presenta',
#   216: 'el',
#   217: 'planteamiento',
#   218: 'de',
#   219: 'estrategias',
#   220: 'de',
#   221: 'adaptabilidad',
#   222: 'para',
#   223: 'el',
#   224: 'robot',
#   225: 'hexápodo',
#   226: 'Hex-piderix,',
#   227: 'basadas',
#   228: 'en',
#   229: 'un',
#   230: 'modelo',
#   231: 'geométrico,',
#   232: 'en',
#   233: 'el',
#   234: 'cual',
#   235: 'no',
#   236: 'es',
#   237: 'necesario',
#   238: 'conocer',
#   239: 'el',
#   240: 'ambiente,',
#   241: 'pues',
#   242: 'con',
#   243: 'tan',
#   244: 'solo',
#   245: 'saber',
#   246: 'que',
#   247: 'extremidades',
#   248: 'están',
#   249: 'tocando',
#   250: 'la',
#   251: 'superficie',
#   252: 'es',
#   253: 'posible',
#   254: 'estimar',
#   255: 'el',
#   256: 'plano',
#   257: 'de',
#   258: 'apoyo.',
#   259: 'En',
#   260: 'este',
#   261: 'documento',
#   262: 'se',
#   263: 'presenta',
#   264: 'el',
#   265: 'diseño',
#   266: 'y',
#   267: 'simulación',
#   268: 'de',
#   269: 'estrategias',
#   270: 'de',
#   271: 'adaptabilidad',
#   272: 'para',
#   273: 'el',
#   274: 'robot',
#   275: 'caminante',
#   276: 'hexápodo',
#   277: 'Hex-piderix',
#   278: 'basadas',
#   279: 'en',
#   280: 'un',
#   281: 'modelo',
#   282: 'geométrico.',
#   283: 'La',
#   284: 'validación',
#   285: 'de',
#   286: 'cada',
#   287: 'una',
#   288: 'de',
#   289: 'ellas',
#   290: 'se',
#   291: 'realiza',
#   292: 'sobre',
#   293: 'un',
#   294: 'plano',
#   295: 'con',
#   296: 'distinto',
#   297: 'grado',
#   298: 'de',
#   299: 'inclinación;',
#   300: 'además',
#   301: 'de',
#   302: 'que',
#   303: 'se',
#   304: 'analiza',
#   305: 'la',
#   306: 'estabilidad',
#   307: 'estática',
#   308: 'de',
#   309: 'cada',
#   310: 'postura',
#   311: 'con',
#   312: 'el',
#   313: 'criterio',
#   314: 'de',
#   315: 'estabilidad',
#   316: 'estático',
#   317: 'normalizado',
#   318: 'por',
#   319: 'el',
#   320: 'peso',
#   321: '(SNE,',
#   322: 'por',
#   323: 'sus',
#   324: 'siglas',
#   325: 'en',
#   326: 'ingles)'},
#  'Justificacion22': {1: 'Este',
#   2: 'trabajo',
#   3: 'de',
#   4: 'tesis',
#   5: 'se',
#   6: 'desarrolla',
#   7: 'debido',
#   8: 'a',
#   9: 'la',
#   10: 'necesidad',
#   11: 'de',
#   12: 'un',
#   13: 'sistema',
#   14: 'completo',
#   15: 'capaz',
#   16: 'de',
#   17: 'predecir',
#   18: 'los',
#   19: 'efectos',
#   20: 'indeseables',
#   21: 'de',
#   22: 'memoria',
#   23: 'en',
#   24: 'un',
#   25: 'PA',
#   26: 'con',
#   27: 'profundidad',
#   28: 'de',
#   29: 'memoria',
#   30: 'y',
#   31: 'órdenes',
#   32: 'de',
#   33: 'no',
#   34: 'linealidad',
#   35: 'variables.',
#   36: 'Para',
#   37: 'ello',
#   38: 'se',
#   39: 'desarrollan',
#   40: 'modelos',
#   41: 'polinomiales',
#   42: 'y',
#   43: 'basados',
#   44: 'en',
#   45: 'truncaciones',
#   46: 'de',
#   47: 'las',
#   48: 'series',
#   49: 'de',
#   50: 'Volterra',
#   51: 'como',
#   52: 'Wiener,',
#   53: 'Hammerstein',
#   54: 'y',
#   55: 'MPM,',
#   56: 'además',
#   57: 'de',
#   58: 'utilizar',
#   59: 'técnicas',
#   60: 'de',
#   61: 'aprendizaje',
#   62: 'como',
#   63: 'ANN',
#   64: 'y',
#   65: 'ANFIS',
#   66: 'dentro',
#   67: 'de',
#   68: 'una',
#   69: 'tarjeta',
#   70: 'de',
#   71: 'desarrollo',
#   72: 'FPGA/DSP,',
#   73: 'y',
#   74: 'una',
#   75: 'técnica',
#   76: 'de',
#   77: 'medición',
#   78: 'de',
#   79: 'bajo',
#   80: 'costo',
#   81: 'de',
#   82: 'las',
#   83: 'curvas',
#   84: 'de',
#   85: 'distorsión',
#   86: 'en',
#   87: 'amplitud',
#   88: 'y',
#   89: 'en',
#   90: 'fase.',
#   91: 'El',
#   92: 'sistema',
#   93: 'es',
#   94: 'controlado',
#   95: 'por',
#   96: 'una',
#   97: 'Interfaz',
#   98: 'Gráfica',
#   99: 'de',
#   100: 'Usuario',
#   101: '(GUI)',
#   102: 'la',
#   103: 'cual',
#   104: 'permite',
#   105: 'de',
#   106: 'manera',
#   107: 'simple',
#   108: 'abrir',
#   109: 'las',
#   110: 'mediciones',
#   111: 'reales',
#   112: 'de',
#   113: 'cualquier',
#   114: 'PA',
#   115: 'basado',
#   116: 'en',
#   117: 'sus',
#   118: 'curvas',
#   119: 'de',
#   120: 'distorsión',
#   121: 'AM/AM',
#   122: 'y',
#   123: 'AM/PM',
#   124: 'y',
#   125: 'obtener',
#   126: 'los',
#   127: 'coeficientes',
#   128: 'respectivos',
#   129: 'del',
#   130: 'MPM',
#   131: 'obtenidos',
#   132: 'a',
#   133: 'través',
#   134: 'del',
#   135: 'método',
#   136: 'Error',
#   137: 'Cuadrático',
#   138: 'Mínimo',
#   139: '(LSE).',
#   140: 'El',
#   141: 'sistema',
#   142: 'tiene',
#   143: 'niveles',
#   144: 'variables',
#   145: 'de',
#   146: 'memoria',
#   147: 'y',
#   148: 'órdenes',
#   149: 'de',
#   150: 'no',
#   151: 'linealidad',
#   152: 'variables',
#   153: 'para',
#   154: 'adecuarse',
#   155: 'al',
#   156: 'comportamiento',
#   157: 'del',
#   158: 'PA.',
#   159: 'La',
#   160: 'parte',
#   161: 'principal',
#   162: 'del',
#   163: 'trabajo',
#   164: 'está',
#   165: 'basada',
#   166: 'en',
#   167: 'la',
#   168: 'herramienta',
#   169: 'de',
#   170: 'diseño',
#   171: 'DSP',
#   172: 'Builder',
#   173: 'la',
#   174: 'cual',
#   175: 'permite',
#   176: 'traducir',
#   177: 'un',
#   178: 'programa',
#   179: 'de',
#   180: 'sistema',
#   181: 'como',
#   182: 'Matlab/Simulink',
#   183: 'a',
#   184: 'VHDL',
#   185: 'ahorrando',
#   186: 'tiempo',
#   187: 'de',
#   188: 'diseño.',
#   189: 'En',
#   190: 'la',
#   191: 'parte',
#   192: 'final',
#   193: 'se',
#   194: 'realiza',
#   195: 'una',
#   196: 'comparación',
#   197: 'con',
#   198: 'modelado',
#   199: 'a',
#   200: 'través',
#   201: 'de',
#   202: 'VHDL',
#   203: 'puro,',
#   204: 'y',
#   205: 'modelado',
#   206: 'obtenido',
#   207: 'a',
#   208: 'través',
#   209: 'de',
#   210: 'ANN',
#   211: 'y',
#   212: 'ANFIS.',
#   213: 'La',
#   214: 'ventaja',
#   215: 'de',
#   216: 'utilizar',
#   217: 'este',
#   218: 'sistema',
#   219: 'de',
#   220: 'simulación',
#   221: 'es',
#   222: 'el',
#   223: 'uso',
#   224: 'de',
#   225: 'algoritmos',
#   226: 'para',
#   227: 'etapas',
#   228: 'de',
#   229: 'linealización',
#   230: 'posteriores.',
#   231: 'En',
#   232: 'trabajos',
#   233: 'desarrollados',
#   234: 'como',
#   235: 'autor',
#   236: 'se',
#   237: 'probó',
#   238: 'la',
#   239: 'eficiencia',
#   240: 'de',
#   241: 'los',
#   242: 'modelos',
#   243: 'a',
#   244: 'través',
#   245: 'de',
#   246: 'FPGA'},
#  'Justificacion23': {1: 'Existen',
#   2: 'elementos',
#   3: 'estructurales',
#   4: 'y',
#   5: 'mecánicos',
#   6: 'utilizados',
#   7: 'en',
#   8: 'Ingeniería',
#   9: 'como',
#   10: 'estructuras,',
#   11: 'chasis',
#   12: 'de',
#   13: 'autos,',
#   14: 'componentes',
#   15: 'aéreos,',
#   16: 'estructuras',
#   17: 'marinas,',
#   18: 'válvulas,',
#   19: 'etc.,',
#   20: 'son',
#   21: 'fabricados',
#   22: 'con',
#   23: 'la',
#   24: 'aleación',
#   25: 'de',
#   26: 'aluminio',
#   27: '6061-T6.',
#   28: 'Para',
#   29: 'la',
#   30: 'fabricación',
#   31: 'de',
#   32: 'dichos',
#   33: 'elementos',
#   34: 'se',
#   35: 'requieren',
#   36: 'procesos',
#   37: 'de',
#   38: 'unión,',
#   39: 'uno',
#   40: 'de',
#   41: 'ellos',
#   42: 'es',
#   43: 'la',
#   44: 'soldadura.',
#   45: 'La',
#   46: 'soldadura',
#   47: 'es',
#   48: 'un',
#   49: 'proceso',
#   50: 'metalúrgico',
#   51: 'que',
#   52: 'requiere',
#   53: 'el',
#   54: 'entendimiento',
#   55: 'del',
#   56: 'comportamiento',
#   57: 'del',
#   58: 'material',
#   59: 'durante',
#   60: 'su',
#   61: 'producción',
#   62: 'ya',
#   63: 'que',
#   64: 'la',
#   65: 'mayoría',
#   66: 'de',
#   67: 'los',
#   68: 'procesos',
#   69: 'de',
#   70: 'soldadura,',
#   71: 'al',
#   72: 'igual',
#   73: 'que',
#   74: 'en',
#   75: 'la',
#   76: 'fundición',
#   77: 'de',
#   78: 'metales,',
#   79: 'requieren',
#   80: 'de',
#   81: 'altas',
#   82: 'temperaturas',
#   83: 'para',
#   84: 'hacer',
#   85: 'posible',
#   86: 'la',
#   87: 'unión',
#   88: 'de',
#   89: 'los',
#   90: 'materiales',
#   91: 'involucrados.',
#   92: 'En',
#   93: 'la',
#   94: 'aleación',
#   95: 'de',
#   96: 'aluminio',
#   97: '6061-T6',
#   98: 'se',
#   99: 'presenta',
#   100: 'una',
#   101: 'degradación',
#   102: 'en',
#   103: 'las',
#   104: 'propiedades',
#   105: 'mecánicas',
#   106: 'debido',
#   107: 'al',
#   108: 'efecto',
#   109: 'térmico',
#   110: 'del',
#   111: 'proceso',
#   112: 'de',
#   113: 'soldadura.',
#   114: 'Además,',
#   115: 'la',
#   116: 'alta',
#   117: 'solubilidad',
#   118: 'del',
#   119: 'hidrógeno',
#   120: 'en',
#   121: 'el',
#   122: 'aluminio',
#   123: 'líquido',
#   124: 'que',
#   125: 'cuando',
#   126: 'ocurre',
#   127: 'el',
#   128: 'proceso',
#   129: 'de',
#   130: 'solidificación',
#   131: 'queda',
#   132: 'atrapado,',
#   133: 'generando',
#   134: 'porosidad',
#   135: 'en',
#   136: 'el',
#   137: 'material.',
#   138: 'También',
#   139: 'se',
#   140: 'sabe',
#   141: 'que',
#   142: 'es',
#   143: 'posible',
#   144: 'reducir',
#   145: 'el',
#   146: 'efecto',
#   147: 'térmico',
#   148: 'ya',
#   149: 'que',
#   150: 'con',
#   151: 'la',
#   152: 'técnica',
#   153: 'AEIM',
#   154: '[23]',
#   155: 'al',
#   156: 'utilizar',
#   157: 'un',
#   158: 'solo',
#   159: 'paso',
#   160: 'de',
#   161: 'soldadura',
#   162: 'reduce',
#   163: 'el',
#   164: 'efecto',
#   165: 'en',
#   166: 'la',
#   167: 'microestructura',
#   168: 'final.',
#   169: 'Para',
#   170: 'este',
#   171: 'caso',
#   172: 'la',
#   173: 'aleación',
#   174: 'a',
#   175: 'unir',
#   176: 'se',
#   177: 'encuentra',
#   178: 'en',
#   179: 'un',
#   180: 'estado',
#   181: 'de',
#   182: 'solubilización',
#   183: 'y',
#   184: 'envejecido',
#   185: 'artificial',
#   186: '(-T6)',
#   187: 'pero',
#   188: 'cuando',
#   189: 'alcanza',
#   190: 'temperaturas',
#   191: 'muy',
#   192: 'elevadas',
#   193: 'se',
#   194: 'obtiene',
#   195: 'un',
#   196: 'sobreenvejecido',
#   197: 'en',
#   198: 'la',
#   199: 'aleación,',
#   200: 'lo',
#   201: 'cual',
#   202: 'disminuye',
#   203: 'las',
#   204: 'propiedades',
#   205: 'mecánicas.',
#   206: 'Sin',
#   207: 'embargo,',
#   208: 'el',
#   209: 'tratamiento',
#   210: 'térmico',
#   211: 'T6',
#   212: 'es',
#   213: 'un',
#   214: 'proceso',
#   215: 'reversible,',
#   216: 'por',
#   217: 'lo',
#   218: 'tanto,',
#   219: 'se',
#   220: 'puede',
#   221: 'considerar',
#   222: 'como',
#   223: 'alternativa',
#   224: 'para',
#   225: 'mejorar',
#   226: 'las',
#   227: 'propiedades',
#   228: 'mecánicas',
#   229: 'de',
#   230: 'las',
#   231: 'uniones',
#   232: 'de',
#   233: 'aluminio',
#   234: 'soldadas',
#   235: 'con',
#   236: 'un',
#   237: 'tratamiento',
#   238: 'térmico',
#   239: 'postsoldadura.',
#   240: 'Una',
#   241: 'mejora',
#   242: 'en',
#   243: 'las',
#   244: 'propiedades',
#   245: 'mecánicas',
#   246: 'de',
#   247: 'uniones',
#   248: 'de',
#   249: 'aluminio',
#   250: 'soldadas',
#   251: 'se',
#   252: 'aprecia',
#   253: 'en',
#   254: 'un',
#   255: 'incremento',
#   256: 'en',
#   257: 'la',
#   258: 'resistencia',
#   259: 'a',
#   260: 'la',
#   261: 'fatiga',
#   262: 'para',
#   263: 'elementos',
#   264: 'estructurales',
#   265: 'que',
#   266: 'son',
#   267: 'sometidos',
#   268: 'a',
#   269: 'cargas',
#   270: 'cíclicas.',
#   271: 'Al',
#   272: 'incrementar',
#   273: 'la',
#   274: 'resistencia',
#   275: 'a',
#   276: 'la',
#   277: 'fatiga',
#   278: 'se',
#   279: 'retarda',
#   280: 'la',
#   281: 'aparición',
#   282: 'de',
#   283: 'grietas',
#   284: 'por',
#   285: 'fatiga.',
#   286: 'Por',
#   287: 'lo',
#   288: 'anterior',
#   289: 'surge',
#   290: 'la',
#   291: 'necesidad',
#   292: 'de',
#   293: 'hacer',
#   294: 'uniones',
#   295: 'soldadas',
#   296: 'que',
#   297: 'permitan',
#   298: 'aumentar',
#   299: 'la',
#   300: 'resistencia',
#   301: 'a',
#   302: 'la',
#   303: 'fatiga',
#   304: 'y',
#   305: 'retardar',
#   306: 'el',
#   307: 'crecimiento',
#   308: 'de',
#   309: 'grietas',
#   310: 'por',
#   311: 'fatiga',
#   312: 'en',
#   313: 'aleaciones',
#   314: 'de',
#   315: 'este',
#   316: 'tipo',
#   317: 'con',
#   318: 'la',
#   319: 'implementación',
#   320: 'de',
#   321: 'la',
#   322: 'técnica',
#   323: 'AEIM',
#   324: 'y',
#   325: 'un',
#   326: 'tratamiento',
#   327: 'térmico'},
#  'Justificacion24': {1: 'Los',
#   2: 'sensores',
#   3: 'basados',
#   4: 'en',
#   5: 'fibra',
#   6: 'óptica',
#   7: 'ofrecen',
#   8: 'algunas',
#   9: 'ventajas',
#   10: 'sobre',
#   11: 'los',
#   12: 'sensores',
#   13: 'más',
#   14: 'tradicionales',
#   15: 'tales',
#   16: 'como',
#   17: 'inmunidad',
#   18: 'a',
#   19: 'interferencias',
#   20: 'electromagnéticas,',
#   21: 'son',
#   22: 'ultraligeros,',
#   23: 'pueden',
#   24: 'ser',
#   25: 'empleados',
#   26: 'en',
#   27: 'ambientes',
#   28: 'altamente',
#   29: 'corrosivos',
#   30: 'o',
#   31: 'explosivos,',
#   32: 'y',
#   33: 'su',
#   34: 'uso',
#   35: 'en',
#   36: 'aplicaciones',
#   37: 'para',
#   38: 'sensado',
#   39: 'remoto',
#   40: 'es',
#   41: 'factible',
#   42: 'debido',
#   43: 'a',
#   44: 'las',
#   45: 'bajas',
#   46: 'pérdidas',
#   47: 'de',
#   48: 'señal',
#   49: 'que',
#   50: 'las',
#   51: 'fibras',
#   52: 'ópticas'},
#  'Justificacion25': {1: 'En',
#   2: 'los',
#   3: 'Ãºltimos',
#   4: 'aÃ±os',
#   5: 'se',
#   6: 'ha',
#   7: 'dedicado',
#   8: 'considerable',
#   9: 'esfuerzo',
#   10: 'al',
#   11: 'problema',
#   12: 'de',
#   13: 'la',
#   14: 'segmentaciÃ³n',
#   15: 'del',
#   16: 'color',
#   17: 'en',
#   18: 'imÃ¡genes',
#   19: 'digitales',
#   20: 'dada',
#   21: 'su',
#   22: 'importancia',
#   23: 'y',
#   24: 'potencial.',
#   25: 'Hasta',
#   26: 'hace',
#   27: 'poco,',
#   28: 'la',
#   29: 'mayorÃ\xada',
#   30: 'de',
#   31: 'los',
#   32: 'enfoques',
#   33: 'publicados',
#   34: 'para',
#   35: 'la',
#   36: 'segmentaciÃ³n',
#   37: 'del',
#   38: 'color',
#   39: 'se',
#   40: 'basaba',
#   41: 'en',
#   42: 'tÃ©cnicas',
#   43: 'monocromÃ¡ticas',
#   44: 'aplicadas',
#   45: 'a',
#   46: 'cada',
#   47: 'componente',
#   48: 'de',
#   49: 'color',
#   50: 'de',
#   51: 'la',
#   52: 'imagen,',
#   53: 'en',
#   54: 'diferentes',
#   55: 'espacios',
#   56: 'de',
#   57: 'color',
#   58: '(RGB',
#   59: 'u',
#   60: 'otros)',
#   61: 'y',
#   62: 'en',
#   63: 'diferentes',
#   64: 'formas,',
#   65: 'para',
#   66: 'producir',
#   67: 'una',
#   68: 'composiciÃ³n.',
#   69: 'Estos',
#   70: 'enfoques',
#   71: 'tienen',
#   72: 'el',
#   73: 'problema',
#   74: 'inherente',
#   75: 'de',
#   76: 'una',
#   77: 'pÃ©rdida',
#   78: 'significativa',
#   79: 'de',
#   80: 'la',
#   81: 'informaciÃ³n',
#   82: 'de',
#   83: 'color',
#   84: 'durante',
#   85: 'el',
#   86: 'proceso'}}

# %% [markdown]
# ## Remove Empty Dictionaries

# %%
TSU_structured = cleanVector(TSU_structured)
Lic_structured = cleanVector(Lic_structured)
Masters_structured = cleanVector(Masters_structured)
Phd_structured = cleanVector(Phd_structured)
TSU_structured
Lic_structured
Masters_structured
Phd_structured
# Out:
# {'Justificacion2': {1: 'En',
#   2: 'la',
#   3: 'sección',
#   4: 'anterior',
#   5: 'se',
#   6: 'ha',
#   7: 'evidenciado',
#   8: 'la',
#   9: 'importancia',
#   10: 'de',
#   11: 'las',
#   12: 'WNN',
#   13: 'y',
#   14: 'las',
#   15: 'ventajas',
#   16: 'que',
#   17: 'ofrecen',
#   18: 'estos',
#   19: 'modelos',
#   20: 'sobre',
#   21: 'las',
#   22: 'RNA',
#   23: 'con',
#   24: 'pesos,',
#   25: 'y',
#   26: 'se',
#   27: 'han',
#   28: 'fundamentado',
#   29: 'estos',
#   30: 'hechos',
#   31: 'con',
#   32: 'referencias',
#   33: 'bibliográficas',
#   34: 'correspondientes',
#   35: 'a',
#   36: 'trabajos',
#   37: 'de',
#   38: 'investigación',
#   39: 'científica',
#   40: 'de',
#   41: 'punta',
#   42: 'realizada',
#   43: 'por',
#   44: 'equipos',
#   45: 'internacionales.',
#   46: 'Por',
#   47: 'otro',
#   48: 'lado,',
#   49: 'se',
#   50: 'ha',
#   51: 'enfatizado',
#   52: 'la',
#   53: 'existencia,',
#   54: 'la',
#   55: 'importancia',
#   56: 'y',
#   57: 'la',
#   58: 'aplicación',
#   59: 'de',
#   60: 'los',
#   61: 'modelos',
#   62: 'asociativos',
#   63: 'Alfa-Beta,',
#   64: 'cuyas',
#   65: 'características',
#   66: 'más',
#   67: 'importantes',
#   68: 'son',
#   69: 'similares',
#   70: 'a',
#   71: 'las',
#   72: 'que',
#   73: 'exhiben',
#   74: 'las',
#   75: 'WNN,',
#   76: 'en',
#   77: 'cuanto',
#   78: 'eficacia,',
#   79: 'eficiencia',
#   80: 'y',
#   81: 'facilidad',
#   82: 'de',
#   83: 'implementación.',
#   84: 'Ciertamente',
#   85: 'algunos',
#   86: 'connotados',
#   87: 'autores',
#   88: 'en',
#   89: 'el',
#   90: 'área',
#   91: 'de',
#   92: 'las',
#   93: 'redes',
#   94: 'neuronales',
#   95: 'sin',
#   96: 'pesos',
#   97: 'han',
#   98: 'creado',
#   99: 'modelos',
#   100: 'relacionados',
#   101: 'con',
#   102: 'memorias',
#   103: 'asociativas',
#   104: '[6,',
#   105: '8,',
#   106: '19,',
#   107: '30,',
#   108: '56,',
#   109: '79];',
#   110: 'otros,',
#   111: 'han',
#   112: 'incursionado',
#   113: 'en',
#   114: 'los',
#   115: 'modelos',
#   116: 'asociativos',
#   117: 'Alfa-Beta',
#   118: '[19-24,',
#   119: '70],',
#   120: 'o',
#   121: 'bien,',
#   122: 'han',
#   123: 'realizado',
#   124: 'implementaciones',
#   125: 'en',
#   126: 'hardware',
#   127: 'de',
#   128: 'algunos',
#   129: 'modelos',
#   130: 'conocidos',
#   131: 'de',
#   132: 'redes',
#   133: 'neuronales',
#   134: 'sin',
#   135: 'pesos',
#   136: '[25-29,',
#   137: '41,',
#   138: '60,',
#   139: '67,',
#   140: '72,',
#   141: '74-77,',
#   142: '91].',
#   143: 'Sin',
#   144: 'embargo,',
#   145: 'hasta',
#   146: 'noviembre',
#   147: 'de',
#   148: '2007,',
#   149: 'no',
#   150: 'se',
#   151: 'han',
#   152: 'reportado',
#   153: 'en',
#   154: 'la',
#   155: 'literatura',
#   156: 'trabajos',
#   157: 'científicos',
#   158: 'donde',
#   159: 'se',
#   160: 'relacionen',
#   161: 'específicamente',
#   162: 'las',
#   163: 'redes',
#   164: 'neuronales',
#   165: 'sin',
#   166: 'pesos',
#   167: 'con',
#   168: 'los',
#   169: 'modelos',
#   170: 'de',
#   171: 'memorias',
#   172: 'asociativas',
#   173: 'Alfa-Beta.',
#   174: 'El',
#   175: 'presente',
#   176: 'trabajo',
#   177: 'de',
#   178: 'tesis',
#   179: 'queda',
#   180: 'justificado',
#   181: 'porque',
#   182: 'incluye,',
#   183: 'de',
#   184: 'manera',
#   185: 'central,',
#   186: 'la',
#   187: 'creación',
#   188: 'y',
#   189: 'diseño',
#   190: 'de',
#   191: 'un',
#   192: 'nuevo',
#   193: 'modelo',
#   194: 'de',
#   195: 'redes',
#   196: 'neuronales',
#   197: 'sin',
#   198: 'pesos,',
#   199: 'basado',
#   200: 'en',
#   201: 'los',
#   202: 'operadores',
#   203: 'Alfa',
#   204: 'y',
#   205: 'Beta,',
#   206: 'los',
#   207: 'cuales',
#   208: 'son',
#   209: 'tomados',
#   210: 'de',
#   211: 'los',
#   212: 'modelos',
#   213: 'de',
#   214: 'memorias',
#   215: 'asociativas',
#   216: 'Alfa-Beta.',
#   217: 'Por',
#   218: 'otro',
#   219: 'lado,',
#   220: 'se',
#   221: 'establecen',
#   222: 'las',
#   223: 'condiciones',
#   224: 'necesarias',
#   225: 'y',
#   226: 'suficientes',
#   227: 'de',
#   228: 'equivalencia',
#   229: 'de',
#   230: 'las',
#   231: 'redes',
#   232: 'neuronales',
#   233: 'sin',
#   234: 'pesos',
#   235: 'y',
#   236: 'los',
#   237: 'circuitos',
#   238: 'booleanos,',
#   239: 'y',
#   240: 'se',
#   241: 'presenta',
#   242: 'un',
#   243: 'estudio',
#   244: 'completo',
#   245: 'de',
#   246: 'factibilidad',
#   247: 'de',
#   248: 'implementación',
#   249: 'en',
#   250: 'hardware',
#   251: 'del',
#   252: 'nuevo',
#   253: 'modelo,',
#   254: 'el',
#   255: 'cual',
#   256: 'exhibe',
#   257: 'un',
#   258: 'alto',
#   259: 'desempeño,',
#   260: 'derivado',
#   261: 'del',
#   262: 'hecho',
#   263: 'de',
#   264: 'que',
#   265: 'es',
#   266: 'un',
#   267: 'hecho',
#   268: 'ya',
#   269: 'probado',
#   270: 'que',
#   271: 'la',
#   272: 'densidad',
#   273: 'aritmética',
#   274: 'de',
#   275: 'los',
#   276: 'modelos',
#   277: 'de',
#   278: 'memorias',
#   279: 'asociativas',
#   280: 'Alfa',
#   281: 'y',
#   282: 'Beta',
#   283: 'es',
#   284: 'menor',
#   285: 'que',
#   286: 'la',
#   287: 'otros',
#   288: 'modelos',
#   289: 'relevantes',
#   290: 'de',
#   291: 'memorias',
#   292: 'asociativas,',
#   293: 'como',
#   294: 'las',
#   295: 'morfológicas'},
#  'Justificacion3': {1: 'La',
#   2: 'idea',
#   3: 'de',
#   4: 'considerar',
#   5: 'la',
#   6: 'necesidad',
#   7: 'de',
#   8: 'seguridad',
#   9: 'de',
#   10: 'redes',
#   11: 'ad',
#   12: 'hoc',
#   13: 'no',
#   14: 'es',
#   15: 'nueva,',
#   16: 'inclusive',
#   17: 'en',
#   18: 'redes',
#   19: 'de',
#   20: 'sensores',
#   21: 'hay',
#   22: 'ataques',
#   23: 'específicos',
#   24: 'ante',
#   25: 'los',
#   26: 'cuales',
#   27: 'es',
#   28: 'necesario',
#   29: 'utilizar',
#   30: 'mecanismos',
#   31: 'de',
#   32: 'proteccion',
#   33: 'para',
#   34: 'evitar',
#   35: 'ataques',
#   36: 'de',
#   37: 'suplantacion',
#   38: 'y',
#   39: 'negacion',
#   40: 'de',
#   41: 'servicios,',
#   42: 'entre',
#   43: 'otros',
#   44: 'posibles;',
#   45: 'sin',
#   46: 'embargo',
#   47: 'no',
#   48: 'todas',
#   49: 'las',
#   50: 'tecnicas',
#   51: 'utilizadas',
#   52: 'en',
#   53: 'soluciones',
#   54: 'a',
#   55: 'estos',
#   56: 'problemas',
#   57: 'en',
#   58: 'redes',
#   59: 'ad',
#   60: 'hoc,',
#   61: 'no',
#   62: 'son',
#   63: 'del',
#   64: 'todo',
#   65: 'aplicables',
#   66: 'en',
#   67: 'una',
#   68: 'WSN.',
#   69: 'Con',
#   70: 'el',
#   71: 'fin',
#   72: 'de',
#   73: 'establecer',
#   74: 'claramente',
#   75: 'los',
#   76: 'riesgos',
#   77: 'a',
#   78: 'que',
#   79: 'se',
#   80: 'expone',
#   81: 'la',
#   82: 'informacion',
#   83: 'en',
#   84: 'una',
#   85: 'WSN',
#   86: 'en',
#   87: 'un',
#   88: 'ataque,',
#   89: 'conviene',
#   90: 'retomar',
#   91: 'una',
#   92: 'definición',
#   93: 'de',
#   94: 'la',
#   95: 'seguridad',
#   96: 'de',
#   97: 'la',
#   98: 'informacion,',
#   99: 'la',
#   100: 'cual',
#   101: 'consiste',
#   102: 'en',
#   103: 'otorgarle',
#   104: 'a',
#   105: 'la',
#   106: 'informacion',
#   107: 'cuatro',
#   108: 'propiedades',
#   109: 'basicas,',
#   110: 'como',
#   111: 'se',
#   112: 'indica',
#   113: 'en',
#   114: '[50]:',
#   115: 'Confidencialidad,',
#   116: 'Autenticidad,',
#   117: 'Integridad,Disponibilidad.',
#   118: 'Con',
#   119: 'base',
#   120: 'en',
#   121: 'estas',
#   122: 'cuatro',
#   123: 'propiedades,',
#   124: 'los',
#   125: 'escenarios',
#   126: 'de',
#   127: 'riesgo',
#   128: 'en',
#   129: 'una',
#   130: 'WSN,',
#   131: 'y',
#   132: 'sobre',
#   133: 'todo,',
#   134: 'considerando',
#   135: 'el',
#   136: 'impacto',
#   137: 'de',
#   138: 'un',
#   139: 'ataque',
#   140: 'sobre',
#   141: 'la',
#   142: 'operacion',
#   143: 'de',
#   144: 'la',
#   145: 'red,',
#   146: 'se',
#   147: 'considera',
#   148: 'que',
#   149: 'el',
#   150: 'problema',
#   151: 'de',
#   152: 'la',
#   153: 'suplantacion',
#   154: 'de',
#   155: 'nodos',
#   156: 'es',
#   157: 'uno',
#   158: 'de',
#   159: 'los',
#   160: 'mas',
#   161: 'severos',
#   162: 'dada',
#   163: 'la',
#   164: 'mecanica',
#   165: 'de',
#   166: 'operacion',
#   167: 'de',
#   168: 'la',
#   169: 'red.',
#   170: 'A',
#   171: 'fin',
#   172: 'de',
#   173: 'ilustrar',
#   174: 'esta',
#   175: 'situacion,',
#   176: 'en',
#   177: 'las',
#   178: 'siguientes',
#   179: 'líneas',
#   180: 'se',
#   181: 'plantea',
#   182: 'un',
#   183: 'ataque',
#   184: 'hipotetico.',
#   185: 'Una',
#   186: 'red',
#   187: 'de',
#   188: 'WSN',
#   189: 'con',
#   190: 'topología',
#   191: 'ad',
#   192: 'hoc',
#   193: 'esta',
#   194: 'formada',
#   195: 'por',
#   196: 'varios',
#   197: 'nodos,',
#   198: 'entre',
#   199: 'los',
#   200: 'cuales',
#   201: 'existe',
#   202: 'una',
#   203: 'relacion',
#   204: 'de',
#   205: 'confianza',
#   206: 'mutua,',
#   207: 'por',
#   208: 'lo',
#   209: 'que',
#   210: 'cada',
#   211: 'uno',
#   212: 'puede',
#   213: 'establecer',
#   214: 'enlaces',
#   215: 'con',
#   216: 'cualquier',
#   217: 'otro',
#   218: 'nodo',
#   219: 'que',
#   220: 'este',
#   221: 'dentro',
#   222: 'de',
#   223: 'su',
#   224: 'area',
#   225: 'de',
#   226: 'cobertura.',
#   227: 'Estos',
#   228: 'enlaces',
#   229: 'permiten',
#   230: 'a',
#   231: 'la',
#   232: 'WSN',
#   233: 'cumplir',
#   234: 'sus',
#   235: 'dos',
#   236: 'funciones',
#   237: 'basicas:',
#   238: 'recoleccion',
#   239: 'y',
#   240: 'transporte',
#   241: 'de',
#   242: 'datos',
#   243: 'y',
#   244: 'órdenes',
#   245: 'de',
#   246: 'control',
#   247: 'de',
#   248: 'la',
#   249: 'red.',
#   250: 'En',
#   251: 'las',
#   252: 'condiciones',
#   253: 'mas',
#   254: 'críticas,',
#   255: 'no',
#   256: 'se',
#   257: 'tiene',
#   258: 'forma',
#   259: 'alguna',
#   260: 'de',
#   261: 'establecer',
#   262: 'autenticidad',
#   263: 'entre',
#   264: 'los',
#   265: 'nodos',
#   266: 'de',
#   267: 'la',
#   268: 'red.',
#   269: 'Para',
#   270: 'esta',
#   271: 'red,',
#   272: 'la',
#   273: 'ejecucion',
#   274: 'de',
#   275: 'un',
#   276: 'ataque',
#   277: 'de',
#   278: 'suplantacion',
#   279: 'es',
#   280: 'una',
#   281: 'situacion',
#   282: 'no',
#   283: 'muy',
#   284: 'ajena',
#   285: 'a',
#   286: 'la',
#   287: 'realidad.',
#   288: 'Este',
#   289: 'ataque',
#   290: 'puede',
#   291: 'llevarse',
#   292: 'a',
#   293: 'cabo',
#   294: 'por',
#   295: 'lo',
#   296: 'menos',
#   297: 'de',
#   298: 'las',
#   299: 'siguientes',
#   300: 'dos',
#   301: 'formas:',
#   302: 'Con',
#   303: 'la',
#   304: 'captura',
#   305: 'de',
#   306: 'un',
#   307: 'nodo',
#   308: 'y',
#   309: 'la',
#   310: 'manipulacion',
#   311: 'del',
#   312: 'mismo.',
#   313: 'Con',
#   314: 'la',
#   315: 'incorporacion',
#   316: 'de',
#   317: 'un',
#   318: 'dispositivo',
#   319: 'que',
#   320: 'se',
#   321: 'haga',
#   322: 'pasar',
#   323: 'por',
#   324: 'un',
#   325: 'nodo',
#   326: 'de',
#   327: 'la',
#   328: 'red',
#   329: 'autentico.',
#   330: 'La',
#   331: 'realizacion',
#   332: 'del',
#   333: 'primer',
#   334: 'ataque',
#   335: 'es',
#   336: 'muy',
#   337: 'simple,',
#   338: 'ya',
#   339: 'que',
#   340: 'como',
#   341: 'se',
#   342: 'ha',
#   343: 'dicho',
#   344: 'anteriormente,',
#   345: 'uno',
#   346: 'de',
#   347: 'los',
#   348: 'problemas',
#   349: 'del',
#   350: 'dispositivo',
#   351: 'en',
#   352: 'sí',
#   353: 'es',
#   354: 'la',
#   355: 'facilidad',
#   356: 'de',
#   357: 'ser',
#   358: 'capturado,',
#   359: 'ya',
#   360: 'que',
#   361: 'la',
#   362: 'mayoría',
#   363: 'de',
#   364: 'las',
#   365: 'veces',
#   366: 'los',
#   367: 'sensores',
#   368: 'no',
#   369: 'cuentan',
#   370: 'con',
#   371: 'mecanismos',
#   372: 'de',
#   373: 'proteccion',
#   374: 'física',
#   375: 'alguna,',
#   376: 'ademas',
#   377: 'de',
#   378: 'estar',
#   379: 'expuestos',
#   380: 'a',
#   381: 'fallas,',
#   382: 'e',
#   383: 'interrupcion',
#   384: 'en',
#   385: 'su',
#   386: 'servicio.',
#   387: 'Para',
#   388: 'el',
#   389: 'caso',
#   390: 'del',
#   391: 'segundo',
#   392: 'ataque,',
#   393: 'si',
#   394: 'bien',
#   395: 'se',
#   396: 'requiere',
#   397: 'la',
#   398: 'construccion',
#   399: 'de',
#   400: 'un',
#   401: 'sensor',
#   402: 'compatible',
#   403: 'con',
#   404: 'la',
#   405: 'WSN,',
#   406: 'esto',
#   407: 'no',
#   408: 'parece',
#   409: 'ser',
#   410: 'muy',
#   411: 'complicado',
#   412: 'una',
#   413: 'vez',
#   414: 'que',
#   415: 'se',
#   416: 'tiene',
#   417: 'la',
#   418: 'posibilidad',
#   419: 'de',
#   420: 'capturar',
#   421: 'uno',
#   422: 'o',
#   423: 'mas',
#   424: 'nodos',
#   425: 'originales',
#   426: 'y',
#   427: 'recuperar',
#   428: 'informacion',
#   429: 'del',
#   430: 'mismo',
#   431: 'que',
#   432: 'permita',
#   433: 'completar',
#   434: 'la',
#   435: 'construccion.',
#   436: 'Dada',
#   437: 'la',
#   438: 'dinámica',
#   439: 'de',
#   440: 'operacion',
#   441: 'de',
#   442: 'las',
#   443: 'WSN,',
#   444: 'y',
#   445: 'las',
#   446: 'posibilidades',
#   447: 'de',
#   448: 'ocurrencia',
#   449: 'de',
#   450: 'un',
#   451: 'ataque',
#   452: 'de',
#   453: 'suplantacion,',
#   454: 'es',
#   455: 'conveniente',
#   456: 'evaluar',
#   457: 'que',
#   458: 'tan',
#   459: 'graves',
#   460: 'podrían',
#   461: 'ser',
#   462: 'los',
#   463: 'daños',
#   464: 'en',
#   465: 'caso',
#   466: 'de',
#   467: 'la',
#   468: 'realizacion',
#   469: 'del',
#   470: 'mismo',
#   471: 'para',
#   472: 'así',
#   473: 'tener',
#   474: 'una',
#   475: 'mejor',
#   476: 'perspectiva',
#   477: 'del',
#   478: 'enfoque',
#   479: 'del',
#   480: 'problema',
#   481: 'que',
#   482: 'adopta',
#   483: 'el',
#   484: 'presente',
#   485: 'estudio.',
#   486: 'Bajo',
#   487: 'la',
#   488: 'suposicion',
#   489: 'que',
#   490: 'un',
#   491: 'tercer',
#   492: 'elemento',
#   493: 'ha',
#   494: 'logrado',
#   495: 'suplantar',
#   496: 'un',
#   497: 'nodo',
#   498: 'autentico',
#   499: 'en',
#   500: 'la',
#   501: 'red,',
#   502: 'los',
#   503: 'daños',
#   504: 'generados',
#   505: 'a',
#   506: 'partir',
#   507: 'de',
#   508: 'tal',
#   509: 'accion',
#   510: 'pueden',
#   511: 'agruparse',
#   512: 'en',
#   513: 'dos',
#   514: 'casos',
#   515: 'generales:',
#   516: '1.',
#   517: 'Una',
#   518: 'parte',
#   519: 'de',
#   520: 'la',
#   521: 'informacion',
#   522: 'recolectada',
#   523: 'por',
#   524: 'la',
#   525: 'WSN',
#   526: 'tendra',
#   527: 'que',
#   528: 'hacer',
#   529: 'un',
#   530: 'salto',
#   531: 'a',
#   532: 'traves',
#   533: 'del',
#   534: 'nodo',
#   535: 'comprometido,',
#   536: 'esto',
#   537: 'pone',
#   538: 'en',
#   539: 'riesgo',
#   540: 'la',
#   541: 'disponibilidad,',
#   542: 'la',
#   543: 'integridad',
#   544: 'y',
#   545: 'la',
#   546: 'confidencialidad',
#   547: 'de',
#   548: 'dicha',
#   549: 'informacion,',
#   550: 'ya',
#   551: 'que',
#   552: 'ésta',
#   553: 'podría',
#   554: 'perderse,',
#   555: 'alterarse',
#   556: 'o',
#   557: 'en',
#   558: 'un',
#   559: 'caso',
#   560: 'extremo,',
#   561: 'ser',
#   562: 'expuestos',
#   563: 'a',
#   564: 'terceros',
#   565: 'no',
#   566: 'autorizados.',
#   567: '2.',
#   568: 'De',
#   569: 'igual',
#   570: 'forma,',
#   571: 'las',
#   572: 'órdenes',
#   573: 'de',
#   574: 'control',
#   575: 'que',
#   576: 'viajan',
#   577: 'por',
#   578: 'la',
#   579: 'red',
#   580: 'pueden',
#   581: 'ser',
#   582: 'interceptadas',
#   583: 'y',
#   584: 'alteradas',
#   585: 'al',
#   586: 'momento',
#   587: 'de',
#   588: 'pasar',
#   589: 'por',
#   590: 'el',
#   591: 'nodo',
#   592: 'comprometido,',
#   593: 'acarreando',
#   594: 'un',
#   595: 'mal',
#   596: 'funcionamiento',
#   597: 'de',
#   598: 'la',
#   599: 'WSN,',
#   600: 'llegando',
#   601: 'en',
#   602: 'algunos',
#   603: 'casos',
#   604: 'incluso',
#   605: 'a',
#   606: 'poner',
#   607: 'en',
#   608: 'riesgo',
#   609: 'la',
#   610: 'integridad',
#   611: 'de',
#   612: 'elementos',
#   613: 'circundantes',
#   614: 'al',
#   615: 'sensor',
#   616: 'o',
#   617: 'del',
#   618: 'sensor',
#   619: 'mismo.',
#   620: 'La',
#   621: 'ocurrencia',
#   622: 'de',
#   623: 'cualquiera',
#   624: 'de',
#   625: 'estos',
#   626: 'casos',
#   627: 'anteriores',
#   628: 'sería',
#   629: 'en',
#   630: 'menoscabo',
#   631: 'de',
#   632: 'la',
#   633: 'operacion',
#   634: 'de',
#   635: 'la',
#   636: 'WSN,',
#   637: 'lo',
#   638: 'que',
#   639: 'repercutiría',
#   640: 'en',
#   641: 'consecuencias',
#   642: 'acordes',
#   643: 'a',
#   644: 'la',
#   645: 'importancia',
#   646: 'de',
#   647: 'la',
#   648: 'mision',
#   649: 'que',
#   650: 'desempeñe',
#   651: 'dicha',
#   652: 'red.',
#   653: 'Esto',
#   654: 'deja',
#   655: 'sobre',
#   656: 'la',
#   657: 'mesa',
#   658: 'la',
#   659: 'necesidad',
#   660: 'de',
#   661: 'contar',
#   662: 'con',
#   663: 'mecanismos',
#   664: 'de',
#   665: 'autenticidad',
#   666: 'que',
#   667: 'operen',
#   668: 'en',
#   669: 'las',
#   670: 'WSNs.',
#   671: 'En',
#   672: 'terminos',
#   673: 'generales,',
#   674: 'el',
#   675: 'problema',
#   676: 'de',
#   677: 'establecimiento',
#   678: 'de',
#   679: 'identidad',
#   680: 'tiene',
#   681: 'solucion',
#   682: 'mediante',
#   683: 'un',
#   684: 'proceso',
#   685: 'de',
#   686: 'autenticacion',
#   687: 'entre',
#   688: 'pares.',
#   689: 'En',
#   690: 'las',
#   691: 'redes',
#   692: 'de',
#   693: 'comunicaciones',
#   694: 'y',
#   695: 'en',
#   696: 'los',
#   697: 'sistemas',
#   698: 'de',
#   699: 'informacion,',
#   700: 'este',
#   701: 'proceso',
#   702: 'comunmente',
#   703: 'involucra',
#   704: 'el',
#   705: 'uso',
#   706: 'de',
#   707: 'mecanismos',
#   708: 'criptograficos,',
#   709: 'ya',
#   710: 'sean',
#   711: 'de',
#   712: 'clave',
#   713: 'secreta',
#   714: 'osimetricos,',
#   715: 'o',
#   716: 'bien',
#   717: 'de',
#   718: 'clave',
#   719: 'publica',
#   720: 'o',
#   721: 'asimetricos.',
#   722: 'La',
#   723: 'autenticidad',
#   724: 'en',
#   725: 'una',
#   726: 'WSN',
#   727: 'debe',
#   728: 'ser',
#   729: 'una',
#   730: 'propiedad',
#   731: 'inherente',
#   732: 'de',
#   733: 'la',
#   734: 'propia',
#   735: 'red,',
#   736: 'ya',
#   737: 'que',
#   738: 'como',
#   739: 'se',
#   740: 'ha',
#   741: 'establecido',
#   742: 'en',
#   743: 'la',
#   744: 'seccion',
#   745: 'anterior,',
#   746: 'un',
#   747: 'ataque',
#   748: 'originado',
#   749: 'a',
#   750: 'raíz',
#   751: 'de',
#   752: 'la',
#   753: 'falta',
#   754: 'de',
#   755: 'ésta',
#   756: 'puede',
#   757: 'llegar',
#   758: 'a',
#   759: 'comprometer',
#   760: 'el',
#   761: 'funcionamiento',
#   762: 'de',
#   763: 'la',
#   764: 'red',
#   765: 'completa.',
#   766: 'Sin',
#   767: 'embargo,',
#   768: 'a',
#   769: 'diferencia',
#   770: 'de',
#   771: 'otros',
#   772: 'entornos,',
#   773: 'las',
#   774: 'WSN',
#   775: 'tienen',
#   776: 'como',
#   777: 'un',
#   778: 'marco',
#   779: 'de',
#   780: 'operacion',
#   781: 'muy',
#   782: 'reducido',
#   783: 'en',
#   784: 'recursos,',
#   785: 'por',
#   786: 'lo',
#   787: 'que',
#   788: 'la',
#   789: 'seleccion',
#   790: 'de',
#   791: 'los',
#   792: 'mecanismos',
#   793: 'de',
#   794: 'autenticidad',
#   795: 'a',
#   796: 'utilizar',
#   797: 'debe',
#   798: 'ser',
#   799: 'acorde',
#   800: 'a',
#   801: 'dichas'},
#  'Justificacion4': {1: 'Es',
#   2: 'importante',
#   3: 'abordar',
#   4: 'el',
#   5: 'problema',
#   6: 'del',
#   7: 'agrupamiento',
#   8: 'conceptual',
#   9: 'ya',
#   10: 'que',
#   11: 'en',
#   12: 'muchas',
#   13: 'ciencias',
#   14: 'el',
#   15: 'especialista',
#   16: 'está',
#   17: 'interesado',
#   18: 'en',
#   19: 'encontrar',
#   20: 'no',
#   21: 'sólo',
#   22: 'los',
#   23: 'agrupamientos',
#   24: 'en',
#   25: 'que',
#   26: 'se',
#   27: 'clasifican',
#   28: 'los',
#   29: 'objetos',
#   30: 'sino',
#   31: 'además',
#   32: 'las',
#   33: 'propiedades',
#   34: 'que',
#   35: 'caracterizan',
#   36: 'a',
#   37: 'estos',
#   38: 'agrupamientos.',
#   39: 'Sin',
#   40: 'embargo,',
#   41: 'las',
#   42: 'herramientas',
#   43: 'que',
#   44: 'se',
#   45: 'han',
#   46: 'diseñado',
#   47: 'hasta',
#   48: 'el',
#   49: 'momento',
#   50: 'tienen',
#   51: 'algunas',
#   52: 'limitantes',
#   53: 'al',
#   54: 'ser',
#   55: 'aplicados',
#   56: 'en',
#   57: 'problemas',
#   58: 'donde',
#   59: 'se',
#   60: 'tienen',
#   61: 'objetos',
#   62: 'descritos',
#   63: 'por',
#   64: 'variables',
#   65: 'cualitativas',
#   66: 'y',
#   67: 'cuantitativas',
#   68: 'mezcladas.',
#   69: 'Además,',
#   70: 'no',
#   71: 'permiten',
#   72: 'trabajar',
#   73: 'con',
#   74: 'ausencia',
#   75: 'de',
#   76: 'información',
#   77: 'en',
#   78: 'las',
#   79: 'descripciones',
#   80: 'de',
#   81: 'los',
#   82: 'objetos.',
#   83: 'En',
#   84: 'muchas',
#   85: 'ocasiones',
#   86: 'los',
#   87: 'conceptos',
#   88: 'obtenidos',
#   89: 'por',
#   90: 'los',
#   91: 'algoritmos',
#   92: 'no',
#   93: 'son',
#   94: 'fácilmente',
#   95: 'interpretables,',
#   96: 'no',
#   97: 'cubren',
#   98: 'a',
#   99: 'todos',
#   100: 'los',
#   101: 'objetos',
#   102: 'del',
#   103: 'agrupamiento',
#   104: 'o',
#   105: 'cubren',
#   106: 'objetos',
#   107: 'que',
#   108: 'pertenecen',
#   109: 'a',
#   110: 'otros',
#   111: 'agrupamientos.',
#   112: 'Una',
#   113: 'restricción',
#   114: 'fuerte',
#   115: 'de',
#   116: 'estos',
#   117: 'algoritmos',
#   118: 'es',
#   119: 'que',
#   120: 'los',
#   121: 'conceptos',
#   122: 'deben',
#   123: 'ser',
#   124: 'disjuntos,',
#   125: 'es',
#   126: 'decir,',
#   127: 'los',
#   128: 'objetos',
#   129: 'sólo',
#   130: 'pueden',
#   131: 'pertenecer',
#   132: 'a',
#   133: 'una',
#   134: 'clase.',
#   135: 'Sin',
#   136: 'embargo,',
#   137: 'en',
#   138: 'muchos',
#   139: 'problemas',
#   140: 'reales',
#   141: 'no',
#   142: 'sucede',
#   143: 'así,',
#   144: 'ya',
#   145: 'que',
#   146: 'los',
#   147: 'objetos',
#   148: 'pueden',
#   149: 'pertenecer',
#   150: 'a',
#   151: 'más',
#   152: 'de',
#   153: 'una',
#   154: 'clase',
#   155: 'y',
#   156: 'en',
#   157: 'este',
#   158: 'caso',
#   159: 'los',
#   160: 'conceptos',
#   161: 'deberían',
#   162: 'ser',
#   163: 'no',
#   164: 'disjuntos.',
#   165: 'También',
#   166: 'es',
#   167: 'importante',
#   168: 'desarrollar',
#   169: 'algoritmos',
#   170: 'conceptuales',
#   171: 'difusos',
#   172: 'ya',
#   173: 'que',
#   174: 'en',
#   175: 'problemas',
#   176: 'reales',
#   177: 'el',
#   178: 'especialista',
#   179: 'puede',
#   180: 'estar',
#   181: 'interesado',
#   182: 'en',
#   183: 'conocer',
#   184: 'en',
#   185: 'qué',
#   186: 'grado',
#   187: 'pertenece',
#   188: 'un',
#   189: 'objeto',
#   190: 'a',
#   191: 'cada',
#   192: 'uno',
#   193: 'de',
#   194: 'los',
#   195: 'agrupamientos,',
#   196: 'más',
#   197: 'que',
#   198: 'saber',
#   199: 'si',
#   200: 'un',
#   201: 'objeto',
#   202: 'pertenece',
#   203: 'o',
#   204: 'no',
#   205: 'a',
#   206: 'un'},
#  'Justificacion5': {1: 'El',
#   2: 'uso',
#   3: 'tan',
#   4: 'frecuente',
#   5: 'de',
#   6: 'las',
#   7: 'computadoras',
#   8: 'en',
#   9: 'la',
#   10: 'actualidad',
#   11: 'ha',
#   12: 'conllevado',
#   13: 'al',
#   14: 'desa-',
#   15: 'rrollo',
#   16: 'de',
#   17: 'múltiples',
#   18: 'aplicaciones',
#   19: 'tecnológicas,',
#   20: 'cuya',
#   21: 'base',
#   22: 'es',
#   23: 'el',
#   24: 'lenguaje',
#   25: 'natural.',
#   26: 'Aunado',
#   27: 'a',
#   28: 'esto,',
#   29: 'el',
#   30: 'surgimiento',
#   31: 'de',
#   32: 'Internet',
#   33: 'y',
#   34: 'con',
#   35: 'ello',
#   36: 'la',
#   37: 'gran',
#   38: 'reserva',
#   39: 'de',
#   40: 'recursos',
#   41: 'de',
#   42: 'información',
#   43: 'digitales,',
#   44: 'incita',
#   45: 'el',
#   46: 'desarrollo',
#   47: 'de',
#   48: 'algoritmos',
#   49: 'de',
#   50: 'búsqueda',
#   51: 'eficientes,',
#   52: 'que',
#   53: 'ponen',
#   54: 'a',
#   55: 'nuestra',
#   56: 'disposición',
#   57: 'todo',
#   58: 'un',
#   59: 'mundo',
#   60: 'de',
#   61: 'lenguaje.',
#   62: 'Con',
#   63: 'esta',
#   64: 'plataforma',
#   65: 'es',
#   66: 'común',
#   67: 'el',
#   68: 'uso',
#   69: 'de',
#   70: 'apli-',
#   71: 'caciones',
#   72: 'importantes',
#   73: 'de',
#   74: 'la',
#   75: 'ling\x7fuística',
#   76: 'computacional,',
#   77: 'como:',
#   78: 'la',
#   79: 'traducción',
#   80: 'automática,',
#   81: 'el',
#   82: 'manejo',
#   83: 'y',
#   84: 'gestión',
#   85: 'de',
#   86: 'documentos,',
#   87: 'la',
#   88: 'generación',
#   89: 'de',
#   90: 'texto',
#   91: 'y',
#   92: 'resúmenes,',
#   93: 'las',
#   94: 'bibliote-',
#   95: 'cas',
#   96: 'digitales,',
#   97: 'las',
#   98: 'interfaces',
#   99: 'en',
#   100: 'lenguaje',
#   101: 'natural,',
#   102: 'etc.;',
#   103: 'cuya',
#   104: 'efectividad',
#   105: 'depende',
#   106: 'en',
#   107: 'gran',
#   108: 'medida',
#   109: 'de',
#   110: 'la',
#   111: 'eficacia',
#   112: 'de',
#   113: 'los',
#   114: 'algoritmos',
#   115: 'que',
#   116: 'han',
#   117: 'sido',
#   118: 'propuestos',
#   119: 'y',
#   120: 'que',
#   121: 'en',
#   122: 'todas',
#   123: 'estas',
#   124: 'tareas',
#   125: 'consideran',
#   126: 'la',
#   127: 'desambiguación',
#   128: 'de',
#   129: 'los',
#   130: 'sentidos',
#   131: 'de',
#   132: 'las',
#   133: 'palabras.',
#   134: 'La',
#   135: 'investigación',
#   136: 'y',
#   137: 'mejora',
#   138: 'de',
#   139: 'algoritmos',
#   140: 'de',
#   141: 'WSD',
#   142: 'conduce,',
#   143: 'por',
#   144: 'consiguiente,',
#   145: 'a',
#   146: 'la',
#   147: 'mejora',
#   148: 'en',
#   149: 'las',
#   150: 'aplicaciones',
#   151: 'antes',
#   152: 'mencionadas,',
#   153: 'lo',
#   154: 'que',
#   155: 'justifica',
#   156: 'el',
#   157: 'área',
#   158: 'de',
#   159: 'investigación',
#   160: 'seleccionada',
#   161: 'para',
#   162: 'esta',
#   163: 'tesis.',
#   164: 'Muchos',
#   165: 'métodos',
#   166: 'han',
#   167: 'sido',
#   168: 'propuestos',
#   169: 'para',
#   170: 'llevar',
#   171: 'a',
#   172: 'cabo',
#   173: 'la',
#   174: 'desambiguación',
#   175: 'y',
#   176: 'entre',
#   177: 'ellos',
#   178: 'los',
#   179: 'supervisados',
#   180: 'han',
#   181: 'sido',
#   182: 'de',
#   183: 'los',
#   184: 'más',
#   185: 'sobresalientes,',
#   186: 'con',
#   187: 'la',
#   188: 'presente',
#   189: 'dificultad',
#   190: 'de',
#   191: 'que',
#   192: 'requieren',
#   193: 'datos',
#   194: 'etiquetados',
#   195: 'de',
#   196: 'sentidos,',
#   197: 'adquiridos',
#   198: 'en',
#   199: 'la',
#   200: 'gran',
#   201: 'mayoría',
#   202: 'de',
#   203: 'las',
#   204: 'oca-',
#   205: 'siones,',
#   206: 'de',
#   207: 'forma',
#   208: 'manual.',
#   209: 'La',
#   210: 'disponibilidad',
#   211: 'de',
#   212: 'los',
#   213: 'conjuntos',
#   214: 'adecuados',
#   215: 'de',
#   216: 'datos',
#   217: 'etiquetados',
#   218: 'es',
#   219: 'por',
#   220: 'tanto',
#   221: 'un',
#   222: 'factor',
#   223: 'significativo',
#   224: 'y',
#   225: 'crucial',
#   226: 'para',
#   227: 'el',
#   228: 'entrenamiento',
#   229: 'de',
#   230: 'algoritmos',
#   231: 'basados',
#   232: 'en',
#   233: 'aprendi-',
#   234: 'zaje.',
#   235: 'Por',
#   236: 'desgracia,',
#   237: 'estos',
#   238: 'recursos',
#   239: 'son',
#   240: 'difíciles',
#   241: 'de',
#   242: 'obtener',
#   243: 'y',
#   244: 'de',
#   245: 'crear,',
#   246: 'pues',
#   247: 'requieren',
#   248: 'que',
#   249: 'cada',
#   250: 'una',
#   251: 'de',
#   252: 'las',
#   253: 'palabras',
#   254: 'haya',
#   255: 'sido',
#   256: 'etiquetada',
#   257: 'con',
#   258: 'su',
#   259: 'sentido.',
#   260: 'Este',
#   261: 'procedimiento',
#   262: 'resulta',
#   263: 'muy',
#   264: 'costoso',
#   265: 'y',
#   266: 'por',
#   267: 'ello',
#   268: 'solamente',
#   269: 'algunos',
#   270: 'artículos',
#   271: 'de',
#   272: 'vocabulario',
#   273: 'terminan',
#   274: 'siendo',
#   275: 'etiquetados.',
#   276: 'Mientras',
#   277: 'el',
#   278: 'cuello',
#   279: 'de',
#   280: 'botella',
#   281: 'léxico',
#   282: 'parece',
#   283: 'estar',
#   284: 'resuelto',
#   285: 'para',
#   286: 'el',
#   287: 'idioma',
#   288: 'inglés,',
#   289: 'no',
#   290: 'existe',
#   291: 'un',
#   292: 'amplio',
#   293: 'rango',
#   294: 'de',
#   295: 'recursos',
#   296: 'ling\x7fuísticos',
#   297: 'para',
#   298: 'el',
#   299: 'procesamiento',
#   300: 'del',
#   301: 'lenguaje',
#   302: 'na-',
#   303: 'tural',
#   304: 'en',
#   305: 'otros',
#   306: 'idiomas',
#   307: '[11].',
#   308: 'El',
#   309: 'recurso',
#   310: 'de',
#   311: 'mayor',
#   312: 'cobertura',
#   313: 'de',
#   314: 'palabras',
#   315: 'es',
#   316: 'Princeton',
#   317: 'WordNet,',
#   318: 'un',
#   319: 'lexicón',
#   320: 'de',
#   321: 'concordancia',
#   322: 'semántica',
#   323: 'para',
#   324: 'el',
#   325: 'idioma',
#   326: 'inglés1',
#   327: ',',
#   328: 'que',
#   329: 'agrupa',
#   330: 'los',
#   331: 'sinónimos',
#   332: 'en',
#   333: 'conjuntos',
#   334: 'denominados',
#   335: 'synsets',
#   336: 'y',
#   337: 'proporciona',
#   338: 'a',
#   339: 'las',
#   340: 'palabras',
#   341: 'su',
#   342: 'defini-',
#   343: 'ción.',
#   344: 'El',
#   345: 'propósito',
#   346: 'de',
#   347: 'éste',
#   348: 'es',
#   349: 'producir',
#   350: 'una',
#   351: 'combinación',
#   352: 'de',
#   353: 'diccionario',
#   354: 'y',
#   355: 'tesauro',
#   356: 'que',
#   357: 'sea',
#   358: 'intuitivamente',
#   359: 'utilizable',
#   360: 'y',
#   361: 'respalde',
#   362: 'el',
#   363: 'análisis',
#   364: 'de',
#   365: 'texto',
#   366: 'automático',
#   367: 'y',
#   368: 'las',
#   369: 'aplicaciones',
#   370: 'de',
#   371: 'inteligencia',
#   372: 'artificial.',
#   373: 'Sin',
#   374: 'embargo,',
#   375: 'su',
#   376: 'utilidad',
#   377: 'como',
#   378: 'recurso',
#   379: 'de',
#   380: 'entrenamiento',
#   381: 'y',
#   382: 'evaluación',
#   383: 'para',
#   384: 'anotadores',
#   385: 'de',
#   386: 'sentidos',
#   387: 'supervisados',
#   388: 'está',
#   389: 'actualmente',
#   390: 'algo',
#   391: 'limitada',
#   392: 'por',
#   393: 'su',
#   394: 'metodología',
#   395: 'secuencial.',
#   396: 'Esta',
#   397: 'notación',
#   398: 'obliga',
#   399: 'a',
#   400: 'los',
#   401: 'intérpretes',
#   402: 'a',
#   403: 'familiarizarse',
#   404: 'con',
#   405: 'los',
#   406: 'inventarios',
#   407: 'de',
#   408: 'sentidos',
#   409: 'de',
#   410: 'cada',
#   411: 'palabra',
#   412: '[2].',
#   413: 'A',
#   414: 'pesar',
#   415: 'de',
#   416: 'sus',
#   417: 'inconvenientes,',
#   418: 'este',
#   419: 'recurso',
#   420: 'representa',
#   421: 'una',
#   422: 'contribución',
#   423: 'muy',
#   424: 'im-',
#   425: 'portante',
#   426: 'al',
#   427: 'campo,',
#   428: 'proporcionando',
#   429: 'el',
#   430: 'primer',
#   431: 'conjunto',
#   432: 'de',
#   433: 'datos',
#   434: 'balanceados',
#   435: 'de',
#   436: 'larga',
#   437: 'escala',
#   438: 'para',
#   439: 'el',
#   440: 'estudio',
#   441: 'de',
#   442: 'las',
#   443: 'propiedades',
#   444: 'de',
#   445: 'polisemia',
#   446: 'en',
#   447: 'el',
#   448: 'idioma',
#   449: 'inglés.',
#   450: 'Desafortunadamente,',
#   451: 'no',
#   452: 'existe',
#   453: 'para',
#   454: 'el',
#   455: 'idioma',
#   456: 'español',
#   457: 'un',
#   458: 'recurso',
#   459: 'léxico',
#   460: 'de',
#   461: 'tal',
#   462: 'mag-',
#   463: 'nitud',
#   464: 'con',
#   465: 'el',
#   466: 'cual',
#   467: 'se',
#   468: 'pueda',
#   469: 'proveer',
#   470: 'de',
#   471: 'sentido',
#   472: 'a',
#   473: 'las',
#   474: 'palabras,',
#   475: 'aunque',
#   476: 'se',
#   477: 'han',
#   478: 'están',
#   479: 'llevando',
#   480: 'a',
#   481: 'cabo',
#   482: 'esfuerzos',
#   483: 'en',
#   484: 'esta',
#   485: 'dirección.',
#   486: 'Por',
#   487: 'lo',
#   488: 'tanto,',
#   489: 'la',
#   490: 'búsqueda',
#   491: 'de',
#   492: 'recursos',
#   493: 'dis-',
#   494: 'ponibles',
#   495: 'que',
#   496: 'permitan',
#   497: 'asociar',
#   498: 'etiquetas',
#   499: 'de',
#   500: 'sentidos',
#   501: 'y',
#   502: 'más',
#   503: 'aún,',
#   504: 'esto',
#   505: 'lo',
#   506: 'realice',
#   507: 'de',
#   508: 'forma',
#   509: 'automática,',
#   510: 'es',
#   511: 'una',
#   512: 'tarea',
#   513: 'intermedia',
#   514: 'indispensable',
#   515: 'en',
#   516: 'el',
#   517: 'procesamiento',
#   518: 'de',
#   519: 'lenguaje'},
#  'Justificacion6': {1: 'Esta',
#   2: 'tesis',
#   3: 'espera',
#   4: 'realizar',
#   5: 'distintas',
#   6: 'contribuciones.',
#   7: 'En',
#   8: 'primer',
#   9: 'lugar,',
#   10: 'incorporando',
#   11: 'determinadas',
#   12: 'herramientas',
#   13: 'conceptuales',
#   14: 'desarrolladas',
#   15: 'en',
#   16: 'el',
#   17: 'campo',
#   18: 'de',
#   19: 'los',
#   20: 'estudios',
#   21: 'sociales',
#   22: 'de',
#   23: 'la',
#   24: 'ciencia',
#   25: 'y',
#   26: 'la',
#   27: 'tecnología',
#   28: 'que',
#   29: 'no',
#   30: 'han',
#   31: 'sido',
#   32: 'mayormente',
#   33: 'aplicadas',
#   34: 'al',
#   35: 'estudio',
#   36: 'particular',
#   37: 'de',
#   38: 'las',
#   39: 'Tecnologías',
#   40: 'de',
#   41: 'la',
#   42: 'Información',
#   43: 'y',
#   44: 'la',
#   45: 'Comunicación.',
#   46: 'Añadir',
#   47: 'aquellos',
#   48: 'conceptos',
#   49: 'presentes',
#   50: 'en',
#   51: 'el',
#   52: 'estudio',
#   53: 'de',
#   54: 'las',
#   55: 'tecnologías',
#   56: 'en',
#   57: 'general',
#   58: 'permitiría',
#   59: 'comprender',
#   60: 'lo',
#   61: 'particular',
#   62: 'de',
#   63: 'los',
#   64: 'procesos',
#   65: 'de',
#   66: 'incorporación',
#   67: 'de',
#   68: 'TIC',
#   69: 'y',
#   70: 'de',
#   71: 'la',
#   72: 'construcción',
#   73: 'de',
#   74: '"campus',
#   75: 'virtuales\x9d',
#   76: 'en',
#   77: 'universidades',
#   78: 'del',
#   79: 'país.',
#   80: 'Junto',
#   81: 'con',
#   82: 'ello,',
#   83: 'proporcionar',
#   84: 'nuevos',
#   85: 'andamiajes',
#   86: 'teóricos',
#   87: 'vinculados',
#   88: 'con',
#   89: 'las',
#   90: 'características',
#   91: 'inherentes',
#   92: 'a',
#   93: 'las',
#   94: 'TIC.',
#   95: 'Este',
#   96: 'propósito',
#   97: 'se',
#   98: 'presenta',
#   99: 'como',
#   100: 'inédito',
#   101: 'ya',
#   102: 'que',
#   103: 'pocos',
#   104: 'trabajos',
#   105: 'en',
#   106: 'el',
#   107: 'ámbito',
#   108: 'de',
#   109: 'las',
#   110: 'ciencias',
#   111: 'sociales',
#   112: 'han',
#   113: 'analizado',
#   114: 'las',
#   115: 'dinámicas',
#   116: 'de',
#   117: 'desarrollo',
#   118: 'tecnológico',
#   119: 'que',
#   120: 'posibilitan',
#   121: 'la',
#   122: 'construcción',
#   123: 'de',
#   124: 'entornos',
#   125: '"virtuales\x9d',
#   126: 'que',
#   127: 'se',
#   128: 'gestan',
#   129: 'en',
#   130: 'las',
#   131: 'universidades',
#   132: 'desde',
#   133: 'un',
#   134: 'enfoque',
#   135: 'que',
#   136: 'se',
#   137: 'encuadre',
#   138: 'en',
#   139: 'el',
#   140: 'propuesto',
#   141: 'por',
#   142: 'el',
#   143: 'campo',
#   144: 'de',
#   145: 'los',
#   146: 'estudios',
#   147: 'sociales',
#   148: 'de',
#   149: 'la',
#   150: 'ciencia',
#   151: 'y',
#   152: 'la',
#   153: 'tecnología.',
#   154: 'En',
#   155: 'ese',
#   156: 'sentido',
#   157: 'se',
#   158: 'aspira',
#   159: 'a',
#   160: 'establecer',
#   161: 'una',
#   162: 'ruptura',
#   163: 'con',
#   164: 'aquellas',
#   165: 'formas',
#   166: '"cristalizadas\x9d',
#   167: 'de',
#   168: 'determinismo',
#   169: 'tecnológico',
#   170: 'que',
#   171: 'consideran',
#   172: 'que',
#   173: 'la',
#   174: 'creciente',
#   175: '"difusión\x9d',
#   176: 'y',
#   177: 'proliferación',
#   178: 'de',
#   179: 'las',
#   180: 'Tecnologías',
#   181: 'de',
#   182: 'la',
#   183: 'Información',
#   184: 'y',
#   185: 'la',
#   186: 'Comunicación',
#   187: 'producen',
#   188: '"efectos\x9d',
#   189: 'en',
#   190: 'la',
#   191: '"sociedad\x9d',
#   192: 'y',
#   193: 'se',
#   194: 'limitan',
#   195: 'a',
#   196: 'una',
#   197: 'mirada',
#   198: 'meramente',
#   199: 'instrumental',
#   200: 'dejando',
#   201: 'de',
#   202: 'lado',
#   203: 'aquellas',
#   204: 'que',
#   205: 'hacen',
#   206: 'hincapié',
#   207: 'en',
#   208: 'la',
#   209: 'tecnología',
#   210: 'como',
#   211: 'construcción',
#   212: 'social,',
#   213: 'entendiendo',
#   214: 'que',
#   215: 'no',
#   216: 'hay',
#   217: 'una',
#   218: 'relación',
#   219: 'sociedad-tecnología,',
#   220: 'como',
#   221: 'si',
#   222: 'se',
#   223: 'tratara',
#   224: 'de',
#   225: 'dos',
#   226: 'entidades',
#   227: 'separadas',
#   228: 'y',
#   229: 'que',
#   230: 'la',
#   231: 'distinción',
#   232: 'misma',
#   233: 'entre',
#   234: 'social',
#   235: 'y',
#   236: 'técnico',
#   237: 'debe',
#   238: 'considerarse',
#   239: 'como',
#   240: 'el',
#   241: 'resultado',
#   242: 'de',
#   243: 'un',
#   244: 'proceso',
#   245: 'de',
#   246: '"co-construcción\x9d.',
#   247: 'Por',
#   248: 'otra',
#   249: 'parte,',
#   250: 'esta',
#   251: 'investigación',
#   252: 'espera',
#   253: 'contribuir',
#   254: 'al',
#   255: 'campo',
#   256: 'de',
#   257: 'los',
#   258: 'estudios',
#   259: 'de',
#   260: 'la',
#   261: 'educación',
#   262: 'superior',
#   263: 'y',
#   264: 'los',
#   265: 'estudios',
#   266: 'sobre',
#   267: 'universidad',
#   268: 'en',
#   269: 'el',
#   270: 'cual',
#   271: 'aparece',
#   272: 'como',
#   273: 'vacante',
#   274: 'la',
#   275: 'problemática',
#   276: 'vinculada',
#   277: 'a',
#   278: 'la',
#   279: 'educación',
#   280: 'universitaria',
#   281: '"virtual\x9d.',
#   282: 'La',
#   283: 'utilización',
#   284: 'de',
#   285: 'la',
#   286: 'tecnología',
#   287: 'para',
#   288: 'la',
#   289: 'enseñanza',
#   290: 'y',
#   291: 'la',
#   292: 'investigación',
#   293: 'no',
#   294: 'es',
#   295: 'únicamente',
#   296: 'una',
#   297: 'cuestión',
#   298: 'técnica,',
#   299: 'puesto',
#   300: 'que',
#   301: 'replantea',
#   302: 'cuestiones',
#   303: 'fundamentales',
#   304: 'no',
#   305: 'sólo',
#   306: 'sobre',
#   307: 'los',
#   308: 'métodos',
#   309: 'de',
#   310: 'trabajo',
#   311: 'sino',
#   312: 'sobre',
#   313: 'las',
#   314: 'metas',
#   315: 'y',
#   316: 'los',
#   317: 'propósitos',
#   318: 'que',
#   319: 'persiguen',
#   320: 'las',
#   321: 'instituciones',
#   322: 'universitarias.',
#   323: 'Así,',
#   324: 'el',
#   325: 'estudio',
#   326: 'de',
#   327: 'los',
#   328: '"campus',
#   329: 'virtuales\x9d',
#   330: 'de',
#   331: 'las',
#   332: 'universidades',
#   333: 'nacionales',
#   334: 'argentinas',
#   335: 'podría',
#   336: 'contribuir',
#   337: 'a',
#   338: 'replantear',
#   339: 'la',
#   340: 'dinámica',
#   341: 'de',
#   342: 'formulación',
#   343: 'de',
#   344: 'políticas',
#   345: 'y',
#   346: 'toma',
#   347: 'de',
#   348: 'decisiones',
#   349: 'al',
#   350: 'interior',
#   351: 'de',
#   352: 'la',
#   353: 'universidad.',
#   354: 'Por',
#   355: 'último',
#   356: 'se',
#   357: 'espera',
#   358: 'contribuir',
#   359: 'a',
#   360: 'los',
#   361: 'estudios',
#   362: 'que',
#   363: 'relacionan',
#   364: 'los',
#   365: 'procesos',
#   366: 'de',
#   367: '"innovación\x9d',
#   368: 'tecnológica',
#   369: 'y',
#   370: 'los',
#   371: 'territorios',
#   372: 'indagando',
#   373: 'en',
#   374: 'la',
#   375: 'nueva',
#   376: 'dimensión',
#   377: 'espacio-temporal',
#   378: 'que',
#   379: 'generan',
#   380: 'las',
#   381: 'TIC',
#   382: 'y',
#   383: 'en',
#   384: 'las',
#   385: 'condiciones',
#   386: 'territoriales,',
#   387: 'económicas,',
#   388: 'sociales,',
#   389: 'organizacionales',
#   390: 'y',
#   391: 'simbólicas,',
#   392: 'entre',
#   393: 'otras,',
#   394: 'que',
#   395: 'inciden',
#   396: 'sobre',
#   397: 'la',
#   398: 'implementación',
#   399: 'de',
#   400: 'los',
#   401: '"campus'},
#  'Justificacion7': {1: 'Actualmente',
#   2: 'nos',
#   3: 'encontramos',
#   4: 'en',
#   5: 'un',
#   6: 'proceso',
#   7: 'de',
#   8: 'constantes',
#   9: 'cambios',
#   10: 'y',
#   11: 'transformaciones',
#   12: 'que',
#   13: 'obedecen',
#   14: 'a',
#   15: 'una',
#   16: 'serie',
#   17: 'de',
#   18: 'factores',
#   19: 'y',
#   20: 'entre',
#   21: 'ellas',
#   22: 'a',
#   23: 'la',
#   24: 'incorporación',
#   25: 'vertiginosa',
#   26: 'de',
#   27: 'nuevas',
#   28: 'tecnologías',
#   29: 'de',
#   30: 'la',
#   31: 'información',
#   32: 'y',
#   33: 'la',
#   34: 'comunicación',
#   35: 'en',
#   36: 'diversos',
#   37: 'campos,',
#   38: 'incluidos',
#   39: 'en',
#   40: 'el',
#   41: 'aspecto',
#   42: 'educativo.',
#   43: 'De',
#   44: 'acuerdo',
#   45: 'a',
#   46: 'la',
#   47: 'UNESCO',
#   48: '(2005)',
#   49: 'los',
#   50: 'sistemas',
#   51: 'educativos',
#   52: 'de',
#   53: 'todo',
#   54: 'el',
#   55: 'mundo',
#   56: 'se',
#   57: 'enfrentan',
#   58: 'actualmente',
#   59: 'al',
#   60: 'desafío',
#   61: 'de',
#   62: 'utilizar',
#   63: 'las',
#   64: 'nuevas',
#   65: 'tecnologías',
#   66: 'de',
#   67: 'la',
#   68: 'información',
#   69: 'y',
#   70: 'la',
#   71: 'comunicación',
#   72: 'TIC',
#   73: 'para',
#   74: 'proveer',
#   75: 'a',
#   76: 'sus',
#   77: 'estudiantes',
#   78: 'con',
#   79: 'las',
#   80: 'herramientas',
#   81: 'y',
#   82: 'conocimientos',
#   83: 'necesarios',
#   84: 'para',
#   85: 'el',
#   86: 'siglo',
#   87: 'XXI.',
#   88: 'En',
#   89: 'el',
#   90: 'año',
#   91: '2005,',
#   92: 'el',
#   93: 'Informe',
#   94: 'Mundial',
#   95: 'sobre',
#   96: 'la',
#   97: 'Educación',
#   98: 'de',
#   99: 'la',
#   100: 'UNESCO,',
#   101: '"El',
#   102: 'Imperativo',
#   103: 'de',
#   104: 'la',
#   105: 'Calidad\x9d,',
#   106: 'enfatizó',
#   107: 'en',
#   108: 'la',
#   109: 'importancia',
#   110: 'de',
#   111: 'los',
#   112: 'métodos',
#   113: 'de',
#   114: 'aprendizaje',
#   115: 'y',
#   116: 'en',
#   117: 'la',
#   118: 'utilización',
#   119: 'de',
#   120: 'materiales',
#   121: 'educativos,',
#   122: 'infraestructura',
#   123: 'y',
#   124: 'acceso',
#   125: 'a',
#   126: 'las',
#   127: 'TIC,',
#   128: 'como',
#   129: 'un',
#   130: 'importante',
#   131: 'desafío',
#   132: 'en',
#   133: 'el',
#   134: 'campo',
#   135: 'educativo.',
#   136: 'Las',
#   137: 'tecnologías',
#   138: 'de',
#   139: 'la',
#   140: 'información',
#   141: 'y',
#   142: 'la',
#   143: 'comunicación',
#   144: 'TIC',
#   145: 'son',
#   146: 'un',
#   147: 'factor',
#   148: 'de',
#   149: 'vital',
#   150: 'importancia',
#   151: 'en',
#   152: 'la',
#   153: 'transformación',
#   154: 'de',
#   155: 'diversos',
#   156: 'campos',
#   157: 'de',
#   158: 'la',
#   159: 'sociedad.',
#   160: 'En',
#   161: 'el',
#   162: 'campo',
#   163: 'educativo',
#   164: 'las',
#   165: 'TIC',
#   166: 'tienen',
#   167: 'el',
#   168: 'potencial',
#   169: 'de',
#   170: 'transformar',
#   171: 'la',
#   172: 'naturaleza',
#   173: 'de',
#   174: 'la',
#   175: 'educación',
#   176: 'en',
#   177: 'cuanto',
#   178: 'a',
#   179: 'dónde',
#   180: 'y',
#   181: 'cómo',
#   182: 'se',
#   183: 'produce',
#   184: 'el',
#   185: 'proceso',
#   186: 'de',
#   187: 'enseñanza',
#   188: 'aprendizaje,',
#   189: 'así',
#   190: 'como',
#   191: 'de',
#   192: 'introducir',
#   193: 'cambios',
#   194: 'en',
#   195: 'los',
#   196: 'roles',
#   197: 'de',
#   198: 'los',
#   199: 'profesores',
#   200: 'y',
#   201: 'los',
#   202: 'estudiantes,',
#   203: 'y',
#   204: 'en',
#   205: 'las',
#   206: 'diferentes',
#   207: 'acciones',
#   208: 'que',
#   209: 'se',
#   210: 'realiza',
#   211: 'en',
#   212: 'el',
#   213: 'proceso',
#   214: 'educativo,',
#   215: 'incluido',
#   216: 'en',
#   217: 'temas',
#   218: 'de',
#   219: 'gestión',
#   220: 'institucional.',
#   221: 'En',
#   222: 'este',
#   223: 'nuevo',
#   224: 'panorama',
#   225: 'se',
#   226: 'enfatiza',
#   227: 'la',
#   228: 'importancia',
#   229: 'de',
#   230: 'desarrollar',
#   231: 'nuevas',
#   232: 'competencias,',
#   233: 'capacidades,',
#   234: 'habilidades',
#   235: 'y',
#   236: 'uso',
#   237: 'de',
#   238: 'herramientas.',
#   239: 'De',
#   240: 'acuerdo',
#   241: 'a',
#   242: 'Valzacchi',
#   243: '(2003)',
#   244: 'los',
#   245: 'estudiantes',
#   246: 'deben',
#   247: 'cultivar',
#   248: 'las',
#   249: 'siguientes',
#   250: 'destrezas',
#   251: 'que',
#   252: 'según',
#   253: 'los',
#   254: 'estándares',
#   255: 'de',
#   256: 'la',
#   257: 'International',
#   258: 'Society',
#   259: 'for',
#   260: 'Technology',
#   261: 'in',
#   262: 'Education',
#   263: 'son',
#   264: 'necesarios',
#   265: 'para',
#   266: 'desenvolverse',
#   267: 'en',
#   268: 'el',
#   269: 'siglo',
#   270: 'XXI.',
#   271: 'Estas',
#   272: 'son:',
#   273: 'manejarse',
#   274: 'con',
#   275: 'soltura',
#   276: 'en',
#   277: 'el',
#   278: 'empleo',
#   279: 'de',
#   280: 'la',
#   281: 'tecnología;',
#   282: 'comunicar',
#   283: 'información',
#   284: 'e',
#   285: 'ideas',
#   286: 'usando',
#   287: 'una',
#   288: 'gran',
#   289: 'variedad',
#   290: 'de',
#   291: 'medios',
#   292: 'y',
#   293: 'formatos;',
#   294: 'acceder,',
#   295: 'intercambiar,',
#   296: 'compilar,',
#   297: 'organizar,',
#   298: 'analizar',
#   299: 'y',
#   300: 'sintetizar',
#   301: 'información;',
#   302: 'saber',
#   303: 'encontrar',
#   304: 'información',
#   305: 'adicional;',
#   306: 'saber',
#   307: 'evaluar',
#   308: 'la',
#   309: 'información',
#   310: 'y',
#   311: 'sus',
#   312: 'fuentes;',
#   313: 'construir,',
#   314: 'producir',
#   315: 'y',
#   316: 'publicar',
#   317: 'modelos,',
#   318: 'contenidos',
#   319: 'y',
#   320: 'otros',
#   321: 'trabajos',
#   322: 'creativos;',
#   323: 'colaborar',
#   324: 'y',
#   325: 'cooperar',
#   326: 'en',
#   327: 'grupos',
#   328: 'de',
#   329: 'trabajo',
#   330: 'e',
#   331: 'interactuar',
#   332: 'con',
#   333: 'otros',
#   334: 'en',
#   335: 'forma',
#   336: 'apropiada',
#   337: 'y',
#   338: 'ética.',
#   339: 'En',
#   340: 'el',
#   341: 'país',
#   342: 'se',
#   343: 'inició',
#   344: 'el',
#   345: 'proceso',
#   346: 'de',
#   347: 'integración',
#   348: 'de',
#   349: 'las',
#   350: 'TIC',
#   351: 'en',
#   352: 'el',
#   353: 'sistema',
#   354: 'educativo',
#   355: 'público',
#   356: 'estatal',
#   357: 'a',
#   358: 'través',
#   359: 'del',
#   360: 'Proyecto',
#   361: 'Huascarán',
#   362: 'y',
#   363: 'actualmente',
#   364: 'a',
#   365: 'través',
#   366: 'de',
#   367: 'la',
#   368: 'Dirección',
#   369: 'General',
#   370: 'de',
#   371: 'Tecnologías',
#   372: 'Educativas',
#   373: 'del',
#   374: 'Ministerio',
#   375: 'de',
#   376: 'Educación,',
#   377: 'con',
#   378: 'la',
#   379: 'finalidad',
#   380: 'que',
#   381: 'las',
#   382: 'TIC',
#   383: 'de',
#   384: 'acuerdo',
#   385: 'al',
#   386: '(Ministerio',
#   387: 'de',
#   388: 'Educación,',
#   389: '2007,',
#   390: 'p.60)',
#   391: '"mejoren',
#   392: 'la',
#   393: 'calidad',
#   394: 'de',
#   395: 'la',
#   396: 'educación',
#   397: 'secundaria',
#   398: 'para',
#   399: 'que',
#   400: 'los',
#   401: 'estudiantes',
#   402: 'alcancen',
#   403: 'una',
#   404: 'formación',
#   405: 'integral',
#   406: 'que',
#   407: 'comprenda',
#   408: 'la',
#   409: 'consecución',
#   410: 'de',
#   411: 'logros',
#   412: 'de',
#   413: 'aprendizaje',
#   414: 'y',
#   415: 'una',
#   416: 'sólida',
#   417: 'formación',
#   418: 'en',
#   419: 'valores\x9d.',
#   420: 'Esta',
#   421: 'investigación',
#   422: 'también',
#   423: 'se',
#   424: 'justifica',
#   425: 'teniendo',
#   426: 'en',
#   427: 'consideración',
#   428: 'que',
#   429: 'de',
#   430: 'acuerdo',
#   431: 'a',
#   432: '(Guiloff,',
#   433: '2007,',
#   434: 'p.11)',
#   435: '"no',
#   436: 'existe',
#   437: 'suficiente',
#   438: 'información',
#   439: 'sobre',
#   440: 'el',
#   441: 'compromiso',
#   442: 'e',
#   443: 'interacción',
#   444: 'tecnológica',
#   445: 'relacionada',
#   446: 'con',
#   447: 'las',
#   448: 'actividades',
#   449: 'de',
#   450: 'aprendizaje',
#   451: 'formal',
#   452: 'de',
#   453: 'los',
#   454: 'estudiantes\x9d',
#   455: 'y',
#   456: 'de',
#   457: 'acuerdo',
#   458: 'a',
#   459: '(Condie,',
#   460: '2007,',
#   461: 'p.75)',
#   462: '"a',
#   463: 'la',
#   464: 'fecha',
#   465: 'hay',
#   466: 'muchos',
#   467: 'estudios',
#   468: 'de',
#   469: 'la',
#   470: 'relación',
#   471: 'entre',
#   472: 'TIC',
#   473: 'y',
#   474: 'la',
#   475: 'educación,',
#   476: 'sin',
#   477: 'embargo',
#   478: 'varían',
#   479: 'de',
#   480: 'acuerdo',
#   481: 'a',
#   482: 'las',
#   483: 'regiones',
#   484: 'donde',
#   485: 'se',
#   486: 'han',
#   487: 'realizado,',
#   488: 'con',
#   489: 'estudiantes',
#   490: 'de',
#   491: 'ciertas',
#   492: 'características',
#   493: 'y',
#   494: 'disciplinas;',
#   495: 'siendo',
#   496: 'necesario',
#   497: 'hacer',
#   498: 'investigaciones',
#   499: 'locales',
#   500: 'específicas\x9d.',
#   501: 'Asimismo',
#   502: 'este',
#   503: 'tema',
#   504: 'es',
#   505: 'de',
#   506: 'especial',
#   507: 'importancia',
#   508: 'y',
#   509: 'de',
#   510: 'actualidad,',
#   511: 'y',
#   512: 'de',
#   513: 'acuerdo',
#   514: 'a',
#   515: 'las',
#   516: 'diversas',
#   517: 'organizaciones,',
#   518: 'instituciones',
#   519: 'e',
#   520: 'investigadores',
#   521: 'que',
#   522: 'vienen',
#   523: 'trabajando',
#   524: 'sobre',
#   525: 'las',
#   526: 'TIC',
#   527: 'y',
#   528: 'la',
#   529: 'educación,',
#   530: 'han',
#   531: 'convocado',
#   532: 'a',
#   533: 'realizar',
#   534: 'investigaciones',
#   535: 'a',
#   536: 'nivel',
#   537: 'micro',
#   538: 'con',
#   539: 'la',
#   540: 'finalidad',
#   541: 'de',
#   542: 'contribuir',
#   543: 'a',
#   544: 'la',
#   545: 'generación',
#   546: 'de',
#   547: 'conocimiento',
#   548: 'científico.',
#   549: 'El',
#   550: 'trabajo',
#   551: 'también',
#   552: 'se',
#   553: 'justifica',
#   554: 'puesto',
#   555: 'que',
#   556: 'permitirá',
#   557: 'entregar',
#   558: 'a',
#   559: 'las',
#   560: 'autoridades',
#   561: 'que',
#   562: 'vienen',
#   563: 'implementando',
#   564: 'la',
#   565: 'integración',
#   566: 'de',
#   567: 'las',
#   568: 'TIC',
#   569: 'a',
#   570: 'través',
#   571: 'de',
#   572: 'la',
#   573: 'Dirección',
#   574: 'General',
#   575: 'de',
#   576: 'Tecnologías',
#   577: 'Educativas',
#   578: 'del',
#   579: 'Ministerio',
#   580: 'de',
#   581: 'Educación,',
#   582: 'resultados',
#   583: 'sobre',
#   584: 'el',
#   585: 'desarrollo',
#   586: 'de',
#   587: 'capacidades',
#   588: 'TIC',
#   589: 'en',
#   590: 'los'},
#  'Justificacion8': {1: 'Los',
#   2: 'problemas',
#   3: 'de',
#   4: 'optimización',
#   5: 'industriales,',
#   6: 'en',
#   7: 'general,',
#   8: 'son',
#   9: 'muy',
#   10: 'demandantes',
#   11: 'en',
#   12: 'cuanto',
#   13: 'al',
#   14: 'uso',
#   15: 'de',
#   16: 'los',
#   17: 'recursos',
#   18: 'computacionales.',
#   19: 'En',
#   20: 'la',
#   21: 'investigación',
#   22: 'hecha',
#   23: 'por',
#   24: 'Zabinsky',
#   25: '[14]',
#   26: 'se',
#   27: 'describe',
#   28: 'el',
#   29: 'ambiente',
#   30: 'donde',
#   31: 'operan',
#   32: 'y',
#   33: 'diseñan',
#   34: 'las',
#   35: 'aplicaciones',
#   36: 'de',
#   37: 'ingeniería.',
#   38: 'Estos',
#   39: 'ambientes',
#   40: 'tienen',
#   41: 'restricciones',
#   42: 'en',
#   43: 'los',
#   44: 'tiempos',
#   45: 'de',
#   46: 'entrega',
#   47: 'de',
#   48: 'sus',
#   49: 'productos',
#   50: 'originadas',
#   51: 'por',
#   52: 'los',
#   53: 'compromisos',
#   54: 'con',
#   55: 'los',
#   56: 'clientes.',
#   57: 'Los',
#   58: 'desarrollos',
#   59: 'propuestos',
#   60: 'para',
#   61: 'encontrar',
#   62: 'las',
#   63: 'soluciones',
#   64: 'a',
#   65: 'los',
#   66: 'problemas',
#   67: 'técnicos,',
#   68: 'particularmente',
#   69: 'los',
#   70: 'de',
#   71: 'optimización,',
#   72: 'se',
#   73: 'ven',
#   74: 'afectados',
#   75: 'por',
#   76: 'dichas',
#   77: 'restricciones,',
#   78: 'es',
#   79: 'necesario',
#   80: 'disponer',
#   81: 'de',
#   82: 'herramientas',
#   83: 'que',
#   84: 'permitan',
#   85: 'atacar',
#   86: 'y',
#   87: 'resolver',
#   88: 'los',
#   89: 'problemas',
#   90: 'en',
#   91: 'los',
#   92: 'tiempos',
#   93: 'establecidos.',
#   94: 'Una',
#   95: 'alternativa',
#   96: 'que',
#   97: 'permite',
#   98: 'superar',
#   99: 'las',
#   100: 'restricciones',
#   101: 'de',
#   102: 'tiempo',
#   103: 'de',
#   104: 'los',
#   105: 'problemas',
#   106: 'de',
#   107: 'ingeniería',
#   108: 'es',
#   109: 'la',
#   110: 'implementación,',
#   111: 'en',
#   112: 'hardware',
#   113: 'especializado,',
#   114: 'de',
#   115: 'los',
#   116: 'algoritmos',
#   117: 'numéricos',
#   118: 'utilizados.',
#   119: 'Bajo',
#   120: 'este',
#   121: 'enfoque',
#   122: 'se',
#   123: 'abre',
#   124: 'la',
#   125: 'posibilidad',
#   126: 'de',
#   127: 'disminuir',
#   128: 'el',
#   129: 'tiempo',
#   130: 'de',
#   131: 'ejecución',
#   132: 'del',
#   133: 'esquema',
#   134: 'seleccionado,',
#   135: 'comparado',
#   136: 'con',
#   137: 'una',
#   138: 'plataforma',
#   139: 'de',
#   140: 'procesamiento',
#   141: 'convencional,',
#   142: 'cuando',
#   143: 'la',
#   144: 'implementación',
#   145: 'en',
#   146: 'hardware',
#   147: 'es',
#   148: 'soportada',
#   149: 'por',
#   150: 'el',
#   151: 'estudio',
# ...
#   40: 'con',
#   41: 'patas',
#   42: 'es',
#   43: 'su',
#   44: 'capacidad',
#   45: 'para',
#   46: 'poder',
#   47: 'desplazarse',
#   48: 'sobre',
#   49: 'una',
#   50: 'amplia',
#   51: 'variedad',
#   52: 'de',
#   53: 'terrenos',
#   54: 'no',
#   55: 'estructurados.',
#   56: 'Esta',
#   57: 'particularidad',
#   58: 'los',
#   59: 'hace',
#   60: 'muy',
#   61: 'atractivos',
#   62: 'para',
#   63: 'su',
#   64: 'aplicación',
#   65: 'practica',
#   66: 'como',
#   67: 'robots',
#   68: 'de',
#   69: 'servicios',
#   70: 'en',
#   71: 'los',
#   72: 'que',
#   73: 'se',
#   74: 'requiere',
#   75: 'la',
#   76: 'locomoción',
#   77: 'sobre',
#   78: 'terreno',
#   79: 'natural,',
#   80: 'el',
#   81: 'cual',
#   82: 'se',
#   83: 'caracteriza',
#   84: 'por',
#   85: 'presentar',
#   86: 'superficies',
#   87: 'irregulares,',
#   88: 'diversos',
#   89: 'tipos',
#   90: 'de',
#   91: 'obstáculos',
#   92: 'y',
#   93: 'distintas',
#   94: 'pendientes.',
#   95: 'Sin',
#   96: 'embargo,',
#   97: 'el',
#   98: 'caminar',
#   99: 'sobre',
#   100: 'terreno',
#   101: 'natural',
#   102: 'implica',
#   103: 'que',
#   104: 'tanto',
#   105: 'la',
#   106: 'geometría',
#   107: 'como',
#   108: 'las',
#   109: 'propiedades',
#   110: 'físicas',
#   111: 'de',
#   112: 'los',
#   113: 'elementos',
#   114: 'que',
#   115: 'rodean',
#   116: 'al',
#   117: 'robot',
#   118: 'son',
#   119: 'desconocidas',
#   120: 'y',
#   121: 'muy',
#   122: 'variables,',
#   123: 'por',
#   124: 'lo',
#   125: 'que',
#   126: 'es',
#   127: 'necesario',
#   128: 'dotar',
#   129: 'al',
#   130: 'robot',
#   131: 'de',
#   132: 'una',
#   133: 'estrategia',
#   134: 'que',
#   135: 'adapte',
#   136: 'su',
#   137: 'comportamiento',
#   138: 'con',
#   139: 'respecto',
#   140: 'al',
#   141: 'entorno.',
#   142: 'Si',
#   143: 'bien',
#   144: 'el',
#   145: 'modelo',
#   146: 'del',
#   147: 'robot',
#   148: 'puede',
#   149: 'ser',
#   150: 'conocido',
#   151: 'con',
#   152: 'precisión',
#   153: 'razonable,',
#   154: 'resulta',
#   155: 'difícil',
#   156: 'obtener',
#   157: 'una',
#   158: 'descripción',
#   159: 'detallada',
#   160: 'del',
#   161: 'entorno,',
#   162: 'especialmente',
#   163: 'en',
#   164: 'lo',
#   165: 'que',
#   166: 'respecta',
#   167: 'a',
#   168: 'sus',
#   169: 'propiedades',
#   170: 'físicas.',
#   171: 'La',
#   172: 'estabilidad',
#   173: 'de',
#   174: 'los',
#   175: 'robots',
#   176: 'caminantes',
#   177: 'durante',
#   178: 'la',
#   179: 'realización',
#   180: 'del',
#   181: 'ciclo',
#   182: 'de',
#   183: 'locomoción,',
#   184: 'es',
#   185: 'de',
#   186: 'gran',
#   187: 'importancia.',
#   188: 'Por',
#   189: 'lo',
#   190: 'tanto,',
#   191: 'la',
#   192: 'consideración',
#   193: 'de',
#   194: 'una',
#   195: 'determinada',
#   196: 'medida',
#   197: 'de',
#   198: 'estabilidad',
#   199: 'durante',
#   200: 'la',
#   201: 'locomoción',
#   202: 'influye',
#   203: 'de',
#   204: 'manera',
#   205: 'directa',
#   206: 'en',
#   207: 'la',
#   208: 'seguridad',
#   209: 'del',
#   210: 'robot.',
#   211: 'En',
#   212: 'este',
#   213: 'trabajo',
#   214: 'se',
#   215: 'presenta',
#   216: 'el',
#   217: 'planteamiento',
#   218: 'de',
#   219: 'estrategias',
#   220: 'de',
#   221: 'adaptabilidad',
#   222: 'para',
#   223: 'el',
#   224: 'robot',
#   225: 'hexápodo',
#   226: 'Hex-piderix,',
#   227: 'basadas',
#   228: 'en',
#   229: 'un',
#   230: 'modelo',
#   231: 'geométrico,',
#   232: 'en',
#   233: 'el',
#   234: 'cual',
#   235: 'no',
#   236: 'es',
#   237: 'necesario',
#   238: 'conocer',
#   239: 'el',
#   240: 'ambiente,',
#   241: 'pues',
#   242: 'con',
#   243: 'tan',
#   244: 'solo',
#   245: 'saber',
#   246: 'que',
#   247: 'extremidades',
#   248: 'están',
#   249: 'tocando',
#   250: 'la',
#   251: 'superficie',
#   252: 'es',
#   253: 'posible',
#   254: 'estimar',
#   255: 'el',
#   256: 'plano',
#   257: 'de',
#   258: 'apoyo.',
#   259: 'En',
#   260: 'este',
#   261: 'documento',
#   262: 'se',
#   263: 'presenta',
#   264: 'el',
#   265: 'diseño',
#   266: 'y',
#   267: 'simulación',
#   268: 'de',
#   269: 'estrategias',
#   270: 'de',
#   271: 'adaptabilidad',
#   272: 'para',
#   273: 'el',
#   274: 'robot',
#   275: 'caminante',
#   276: 'hexápodo',
#   277: 'Hex-piderix',
#   278: 'basadas',
#   279: 'en',
#   280: 'un',
#   281: 'modelo',
#   282: 'geométrico.',
#   283: 'La',
#   284: 'validación',
#   285: 'de',
#   286: 'cada',
#   287: 'una',
#   288: 'de',
#   289: 'ellas',
#   290: 'se',
#   291: 'realiza',
#   292: 'sobre',
#   293: 'un',
#   294: 'plano',
#   295: 'con',
#   296: 'distinto',
#   297: 'grado',
#   298: 'de',
#   299: 'inclinación;',
#   300: 'además',
#   301: 'de',
#   302: 'que',
#   303: 'se',
#   304: 'analiza',
#   305: 'la',
#   306: 'estabilidad',
#   307: 'estática',
#   308: 'de',
#   309: 'cada',
#   310: 'postura',
#   311: 'con',
#   312: 'el',
#   313: 'criterio',
#   314: 'de',
#   315: 'estabilidad',
#   316: 'estático',
#   317: 'normalizado',
#   318: 'por',
#   319: 'el',
#   320: 'peso',
#   321: '(SNE,',
#   322: 'por',
#   323: 'sus',
#   324: 'siglas',
#   325: 'en',
#   326: 'ingles)'},
#  'Justificacion22': {1: 'Este',
#   2: 'trabajo',
#   3: 'de',
#   4: 'tesis',
#   5: 'se',
#   6: 'desarrolla',
#   7: 'debido',
#   8: 'a',
#   9: 'la',
#   10: 'necesidad',
#   11: 'de',
#   12: 'un',
#   13: 'sistema',
#   14: 'completo',
#   15: 'capaz',
#   16: 'de',
#   17: 'predecir',
#   18: 'los',
#   19: 'efectos',
#   20: 'indeseables',
#   21: 'de',
#   22: 'memoria',
#   23: 'en',
#   24: 'un',
#   25: 'PA',
#   26: 'con',
#   27: 'profundidad',
#   28: 'de',
#   29: 'memoria',
#   30: 'y',
#   31: 'órdenes',
#   32: 'de',
#   33: 'no',
#   34: 'linealidad',
#   35: 'variables.',
#   36: 'Para',
#   37: 'ello',
#   38: 'se',
#   39: 'desarrollan',
#   40: 'modelos',
#   41: 'polinomiales',
#   42: 'y',
#   43: 'basados',
#   44: 'en',
#   45: 'truncaciones',
#   46: 'de',
#   47: 'las',
#   48: 'series',
#   49: 'de',
#   50: 'Volterra',
#   51: 'como',
#   52: 'Wiener,',
#   53: 'Hammerstein',
#   54: 'y',
#   55: 'MPM,',
#   56: 'además',
#   57: 'de',
#   58: 'utilizar',
#   59: 'técnicas',
#   60: 'de',
#   61: 'aprendizaje',
#   62: 'como',
#   63: 'ANN',
#   64: 'y',
#   65: 'ANFIS',
#   66: 'dentro',
#   67: 'de',
#   68: 'una',
#   69: 'tarjeta',
#   70: 'de',
#   71: 'desarrollo',
#   72: 'FPGA/DSP,',
#   73: 'y',
#   74: 'una',
#   75: 'técnica',
#   76: 'de',
#   77: 'medición',
#   78: 'de',
#   79: 'bajo',
#   80: 'costo',
#   81: 'de',
#   82: 'las',
#   83: 'curvas',
#   84: 'de',
#   85: 'distorsión',
#   86: 'en',
#   87: 'amplitud',
#   88: 'y',
#   89: 'en',
#   90: 'fase.',
#   91: 'El',
#   92: 'sistema',
#   93: 'es',
#   94: 'controlado',
#   95: 'por',
#   96: 'una',
#   97: 'Interfaz',
#   98: 'Gráfica',
#   99: 'de',
#   100: 'Usuario',
#   101: '(GUI)',
#   102: 'la',
#   103: 'cual',
#   104: 'permite',
#   105: 'de',
#   106: 'manera',
#   107: 'simple',
#   108: 'abrir',
#   109: 'las',
#   110: 'mediciones',
#   111: 'reales',
#   112: 'de',
#   113: 'cualquier',
#   114: 'PA',
#   115: 'basado',
#   116: 'en',
#   117: 'sus',
#   118: 'curvas',
#   119: 'de',
#   120: 'distorsión',
#   121: 'AM/AM',
#   122: 'y',
#   123: 'AM/PM',
#   124: 'y',
#   125: 'obtener',
#   126: 'los',
#   127: 'coeficientes',
#   128: 'respectivos',
#   129: 'del',
#   130: 'MPM',
#   131: 'obtenidos',
#   132: 'a',
#   133: 'través',
#   134: 'del',
#   135: 'método',
#   136: 'Error',
#   137: 'Cuadrático',
#   138: 'Mínimo',
#   139: '(LSE).',
#   140: 'El',
#   141: 'sistema',
#   142: 'tiene',
#   143: 'niveles',
#   144: 'variables',
#   145: 'de',
#   146: 'memoria',
#   147: 'y',
#   148: 'órdenes',
#   149: 'de',
#   150: 'no',
#   151: 'linealidad',
#   152: 'variables',
#   153: 'para',
#   154: 'adecuarse',
#   155: 'al',
#   156: 'comportamiento',
#   157: 'del',
#   158: 'PA.',
#   159: 'La',
#   160: 'parte',
#   161: 'principal',
#   162: 'del',
#   163: 'trabajo',
#   164: 'está',
#   165: 'basada',
#   166: 'en',
#   167: 'la',
#   168: 'herramienta',
#   169: 'de',
#   170: 'diseño',
#   171: 'DSP',
#   172: 'Builder',
#   173: 'la',
#   174: 'cual',
#   175: 'permite',
#   176: 'traducir',
#   177: 'un',
#   178: 'programa',
#   179: 'de',
#   180: 'sistema',
#   181: 'como',
#   182: 'Matlab/Simulink',
#   183: 'a',
#   184: 'VHDL',
#   185: 'ahorrando',
#   186: 'tiempo',
#   187: 'de',
#   188: 'diseño.',
#   189: 'En',
#   190: 'la',
#   191: 'parte',
#   192: 'final',
#   193: 'se',
#   194: 'realiza',
#   195: 'una',
#   196: 'comparación',
#   197: 'con',
#   198: 'modelado',
#   199: 'a',
#   200: 'través',
#   201: 'de',
#   202: 'VHDL',
#   203: 'puro,',
#   204: 'y',
#   205: 'modelado',
#   206: 'obtenido',
#   207: 'a',
#   208: 'través',
#   209: 'de',
#   210: 'ANN',
#   211: 'y',
#   212: 'ANFIS.',
#   213: 'La',
#   214: 'ventaja',
#   215: 'de',
#   216: 'utilizar',
#   217: 'este',
#   218: 'sistema',
#   219: 'de',
#   220: 'simulación',
#   221: 'es',
#   222: 'el',
#   223: 'uso',
#   224: 'de',
#   225: 'algoritmos',
#   226: 'para',
#   227: 'etapas',
#   228: 'de',
#   229: 'linealización',
#   230: 'posteriores.',
#   231: 'En',
#   232: 'trabajos',
#   233: 'desarrollados',
#   234: 'como',
#   235: 'autor',
#   236: 'se',
#   237: 'probó',
#   238: 'la',
#   239: 'eficiencia',
#   240: 'de',
#   241: 'los',
#   242: 'modelos',
#   243: 'a',
#   244: 'través',
#   245: 'de',
#   246: 'FPGA'},
#  'Justificacion23': {1: 'Existen',
#   2: 'elementos',
#   3: 'estructurales',
#   4: 'y',
#   5: 'mecánicos',
#   6: 'utilizados',
#   7: 'en',
#   8: 'Ingeniería',
#   9: 'como',
#   10: 'estructuras,',
#   11: 'chasis',
#   12: 'de',
#   13: 'autos,',
#   14: 'componentes',
#   15: 'aéreos,',
#   16: 'estructuras',
#   17: 'marinas,',
#   18: 'válvulas,',
#   19: 'etc.,',
#   20: 'son',
#   21: 'fabricados',
#   22: 'con',
#   23: 'la',
#   24: 'aleación',
#   25: 'de',
#   26: 'aluminio',
#   27: '6061-T6.',
#   28: 'Para',
#   29: 'la',
#   30: 'fabricación',
#   31: 'de',
#   32: 'dichos',
#   33: 'elementos',
#   34: 'se',
#   35: 'requieren',
#   36: 'procesos',
#   37: 'de',
#   38: 'unión,',
#   39: 'uno',
#   40: 'de',
#   41: 'ellos',
#   42: 'es',
#   43: 'la',
#   44: 'soldadura.',
#   45: 'La',
#   46: 'soldadura',
#   47: 'es',
#   48: 'un',
#   49: 'proceso',
#   50: 'metalúrgico',
#   51: 'que',
#   52: 'requiere',
#   53: 'el',
#   54: 'entendimiento',
#   55: 'del',
#   56: 'comportamiento',
#   57: 'del',
#   58: 'material',
#   59: 'durante',
#   60: 'su',
#   61: 'producción',
#   62: 'ya',
#   63: 'que',
#   64: 'la',
#   65: 'mayoría',
#   66: 'de',
#   67: 'los',
#   68: 'procesos',
#   69: 'de',
#   70: 'soldadura,',
#   71: 'al',
#   72: 'igual',
#   73: 'que',
#   74: 'en',
#   75: 'la',
#   76: 'fundición',
#   77: 'de',
#   78: 'metales,',
#   79: 'requieren',
#   80: 'de',
#   81: 'altas',
#   82: 'temperaturas',
#   83: 'para',
#   84: 'hacer',
#   85: 'posible',
#   86: 'la',
#   87: 'unión',
#   88: 'de',
#   89: 'los',
#   90: 'materiales',
#   91: 'involucrados.',
#   92: 'En',
#   93: 'la',
#   94: 'aleación',
#   95: 'de',
#   96: 'aluminio',
#   97: '6061-T6',
#   98: 'se',
#   99: 'presenta',
#   100: 'una',
#   101: 'degradación',
#   102: 'en',
#   103: 'las',
#   104: 'propiedades',
#   105: 'mecánicas',
#   106: 'debido',
#   107: 'al',
#   108: 'efecto',
#   109: 'térmico',
#   110: 'del',
#   111: 'proceso',
#   112: 'de',
#   113: 'soldadura.',
#   114: 'Además,',
#   115: 'la',
#   116: 'alta',
#   117: 'solubilidad',
#   118: 'del',
#   119: 'hidrógeno',
#   120: 'en',
#   121: 'el',
#   122: 'aluminio',
#   123: 'líquido',
#   124: 'que',
#   125: 'cuando',
#   126: 'ocurre',
#   127: 'el',
#   128: 'proceso',
#   129: 'de',
#   130: 'solidificación',
#   131: 'queda',
#   132: 'atrapado,',
#   133: 'generando',
#   134: 'porosidad',
#   135: 'en',
#   136: 'el',
#   137: 'material.',
#   138: 'También',
#   139: 'se',
#   140: 'sabe',
#   141: 'que',
#   142: 'es',
#   143: 'posible',
#   144: 'reducir',
#   145: 'el',
#   146: 'efecto',
#   147: 'térmico',
#   148: 'ya',
#   149: 'que',
#   150: 'con',
#   151: 'la',
#   152: 'técnica',
#   153: 'AEIM',
#   154: '[23]',
#   155: 'al',
#   156: 'utilizar',
#   157: 'un',
#   158: 'solo',
#   159: 'paso',
#   160: 'de',
#   161: 'soldadura',
#   162: 'reduce',
#   163: 'el',
#   164: 'efecto',
#   165: 'en',
#   166: 'la',
#   167: 'microestructura',
#   168: 'final.',
#   169: 'Para',
#   170: 'este',
#   171: 'caso',
#   172: 'la',
#   173: 'aleación',
#   174: 'a',
#   175: 'unir',
#   176: 'se',
#   177: 'encuentra',
#   178: 'en',
#   179: 'un',
#   180: 'estado',
#   181: 'de',
#   182: 'solubilización',
#   183: 'y',
#   184: 'envejecido',
#   185: 'artificial',
#   186: '(-T6)',
#   187: 'pero',
#   188: 'cuando',
#   189: 'alcanza',
#   190: 'temperaturas',
#   191: 'muy',
#   192: 'elevadas',
#   193: 'se',
#   194: 'obtiene',
#   195: 'un',
#   196: 'sobreenvejecido',
#   197: 'en',
#   198: 'la',
#   199: 'aleación,',
#   200: 'lo',
#   201: 'cual',
#   202: 'disminuye',
#   203: 'las',
#   204: 'propiedades',
#   205: 'mecánicas.',
#   206: 'Sin',
#   207: 'embargo,',
#   208: 'el',
#   209: 'tratamiento',
#   210: 'térmico',
#   211: 'T6',
#   212: 'es',
#   213: 'un',
#   214: 'proceso',
#   215: 'reversible,',
#   216: 'por',
#   217: 'lo',
#   218: 'tanto,',
#   219: 'se',
#   220: 'puede',
#   221: 'considerar',
#   222: 'como',
#   223: 'alternativa',
#   224: 'para',
#   225: 'mejorar',
#   226: 'las',
#   227: 'propiedades',
#   228: 'mecánicas',
#   229: 'de',
#   230: 'las',
#   231: 'uniones',
#   232: 'de',
#   233: 'aluminio',
#   234: 'soldadas',
#   235: 'con',
#   236: 'un',
#   237: 'tratamiento',
#   238: 'térmico',
#   239: 'postsoldadura.',
#   240: 'Una',
#   241: 'mejora',
#   242: 'en',
#   243: 'las',
#   244: 'propiedades',
#   245: 'mecánicas',
#   246: 'de',
#   247: 'uniones',
#   248: 'de',
#   249: 'aluminio',
#   250: 'soldadas',
#   251: 'se',
#   252: 'aprecia',
#   253: 'en',
#   254: 'un',
#   255: 'incremento',
#   256: 'en',
#   257: 'la',
#   258: 'resistencia',
#   259: 'a',
#   260: 'la',
#   261: 'fatiga',
#   262: 'para',
#   263: 'elementos',
#   264: 'estructurales',
#   265: 'que',
#   266: 'son',
#   267: 'sometidos',
#   268: 'a',
#   269: 'cargas',
#   270: 'cíclicas.',
#   271: 'Al',
#   272: 'incrementar',
#   273: 'la',
#   274: 'resistencia',
#   275: 'a',
#   276: 'la',
#   277: 'fatiga',
#   278: 'se',
#   279: 'retarda',
#   280: 'la',
#   281: 'aparición',
#   282: 'de',
#   283: 'grietas',
#   284: 'por',
#   285: 'fatiga.',
#   286: 'Por',
#   287: 'lo',
#   288: 'anterior',
#   289: 'surge',
#   290: 'la',
#   291: 'necesidad',
#   292: 'de',
#   293: 'hacer',
#   294: 'uniones',
#   295: 'soldadas',
#   296: 'que',
#   297: 'permitan',
#   298: 'aumentar',
#   299: 'la',
#   300: 'resistencia',
#   301: 'a',
#   302: 'la',
#   303: 'fatiga',
#   304: 'y',
#   305: 'retardar',
#   306: 'el',
#   307: 'crecimiento',
#   308: 'de',
#   309: 'grietas',
#   310: 'por',
#   311: 'fatiga',
#   312: 'en',
#   313: 'aleaciones',
#   314: 'de',
#   315: 'este',
#   316: 'tipo',
#   317: 'con',
#   318: 'la',
#   319: 'implementación',
#   320: 'de',
#   321: 'la',
#   322: 'técnica',
#   323: 'AEIM',
#   324: 'y',
#   325: 'un',
#   326: 'tratamiento',
#   327: 'térmico'},
#  'Justificacion24': {1: 'Los',
#   2: 'sensores',
#   3: 'basados',
#   4: 'en',
#   5: 'fibra',
#   6: 'óptica',
#   7: 'ofrecen',
#   8: 'algunas',
#   9: 'ventajas',
#   10: 'sobre',
#   11: 'los',
#   12: 'sensores',
#   13: 'más',
#   14: 'tradicionales',
#   15: 'tales',
#   16: 'como',
#   17: 'inmunidad',
#   18: 'a',
#   19: 'interferencias',
#   20: 'electromagnéticas,',
#   21: 'son',
#   22: 'ultraligeros,',
#   23: 'pueden',
#   24: 'ser',
#   25: 'empleados',
#   26: 'en',
#   27: 'ambientes',
#   28: 'altamente',
#   29: 'corrosivos',
#   30: 'o',
#   31: 'explosivos,',
#   32: 'y',
#   33: 'su',
#   34: 'uso',
#   35: 'en',
#   36: 'aplicaciones',
#   37: 'para',
#   38: 'sensado',
#   39: 'remoto',
#   40: 'es',
#   41: 'factible',
#   42: 'debido',
#   43: 'a',
#   44: 'las',
#   45: 'bajas',
#   46: 'pérdidas',
#   47: 'de',
#   48: 'señal',
#   49: 'que',
#   50: 'las',
#   51: 'fibras',
#   52: 'ópticas'},
#  'Justificacion25': {1: 'En',
#   2: 'los',
#   3: 'Ãºltimos',
#   4: 'aÃ±os',
#   5: 'se',
#   6: 'ha',
#   7: 'dedicado',
#   8: 'considerable',
#   9: 'esfuerzo',
#   10: 'al',
#   11: 'problema',
#   12: 'de',
#   13: 'la',
#   14: 'segmentaciÃ³n',
#   15: 'del',
#   16: 'color',
#   17: 'en',
#   18: 'imÃ¡genes',
#   19: 'digitales',
#   20: 'dada',
#   21: 'su',
#   22: 'importancia',
#   23: 'y',
#   24: 'potencial.',
#   25: 'Hasta',
#   26: 'hace',
#   27: 'poco,',
#   28: 'la',
#   29: 'mayorÃ\xada',
#   30: 'de',
#   31: 'los',
#   32: 'enfoques',
#   33: 'publicados',
#   34: 'para',
#   35: 'la',
#   36: 'segmentaciÃ³n',
#   37: 'del',
#   38: 'color',
#   39: 'se',
#   40: 'basaba',
#   41: 'en',
#   42: 'tÃ©cnicas',
#   43: 'monocromÃ¡ticas',
#   44: 'aplicadas',
#   45: 'a',
#   46: 'cada',
#   47: 'componente',
#   48: 'de',
#   49: 'color',
#   50: 'de',
#   51: 'la',
#   52: 'imagen,',
#   53: 'en',
#   54: 'diferentes',
#   55: 'espacios',
#   56: 'de',
#   57: 'color',
#   58: '(RGB',
#   59: 'u',
#   60: 'otros)',
#   61: 'y',
#   62: 'en',
#   63: 'diferentes',
#   64: 'formas,',
#   65: 'para',
#   66: 'producir',
#   67: 'una',
#   68: 'composiciÃ³n.',
#   69: 'Estos',
#   70: 'enfoques',
#   71: 'tienen',
#   72: 'el',
#   73: 'problema',
#   74: 'inherente',
#   75: 'de',
#   76: 'una',
#   77: 'pÃ©rdida',
#   78: 'significativa',
#   79: 'de',
#   80: 'la',
#   81: 'informaciÃ³n',
#   82: 'de',
#   83: 'color',
#   84: 'durante',
#   85: 'el',
#   86: 'proceso'}}

# %% [markdown]
# ## Obtain Size for the Justification Data

# %%
sizesTSU = returnSizes(TSU_structured)
sizesLic = returnSizes(Lic_structured)
sizesMasters = returnSizes(Masters_structured)
sizesPhd = returnSizes(Phd_structured)
sizesTSU
sizesLic 
sizesMasters
sizesPhd
# Out:
# {'Smallest': 52, 'Biggest': 801, 'Average': 333.4583333333333}

# %% [markdown]
# ## Remove Stop Words and Cleaning

# %%
TSU_structured = cleanMeth(sw, TSU_structured)
Lic_structured = cleanMeth(sw, Lic_structured)
Masters_structured = cleanMeth(sw, Masters_structured)
Phd_structured = cleanMeth(sw, Phd_structured)
TSU_structured
Lic_structured
Masters_structured
Phd_structured
# Out:
# {'Justificacion2': {3: 'sección',
#   4: 'anterior',
#   7: 'evidenciado',
#   9: 'importancia',
#   12: 'wnn',
#   15: 'ventajas',
#   17: 'ofrecen',
#   19: 'modelos',
#   22: 'rna',
#   24: 'pesos',
#   28: 'fundamentado',
#   30: 'hechos',
#   32: 'referencias',
#   33: 'bibliográficas',
#   34: 'correspondientes',
#   36: 'trabajos',
#   38: 'investigación',
#   39: 'científica',
#   41: 'punta',
#   42: 'realizada',
#   44: 'equipos',
#   45: 'internacionales',
#   48: 'lado',
#   51: 'enfatizado',
#   53: 'existencia',
#   55: 'importancia',
#   58: 'aplicación',
#   61: 'modelos',
#   62: 'asociativos',
#   63: 'alfabeta',
#   64: 'cuyas',
#   65: 'características',
#   67: 'importantes',
#   69: 'similares',
#   73: 'exhiben',
#   75: 'wnn',
#   77: 'cuanto',
#   78: 'eficacia',
#   79: 'eficiencia',
#   81: 'facilidad',
#   83: 'implementación',
#   84: 'ciertamente',
#   86: 'connotados',
#   87: 'autores',
#   90: 'área',
#   93: 'redes',
#   94: 'neuronales',
#   96: 'pesos',
#   98: 'creado',
#   99: 'modelos',
#   100: 'relacionados',
#   102: 'memorias',
#   103: 'asociativas',
#   112: 'incursionado',
#   115: 'modelos',
#   116: 'asociativos',
#   117: 'alfabeta',
#   121: 'bien',
#   123: 'realizado',
#   124: 'implementaciones',
#   126: 'hardware',
#   129: 'modelos',
#   130: 'conocidos',
#   132: 'redes',
#   133: 'neuronales',
#   135: 'pesos',
#   144: 'embargo',
#   146: 'noviembre',
#   152: 'reportado',
#   155: 'literatura',
#   156: 'trabajos',
#   157: 'científicos',
#   160: 'relacionen',
#   161: 'específicamente',
#   163: 'redes',
#   164: 'neuronales',
#   166: 'pesos',
#   169: 'modelos',
#   171: 'memorias',
#   172: 'asociativas',
#   173: 'alfabeta',
#   175: 'presente',
#   176: 'trabajo',
#   178: 'tesis',
#   179: 'queda',
#   180: 'justificado',
#   182: 'incluye',
#   184: 'manera',
#   185: 'central',
#   187: 'creación',
#   189: 'diseño',
#   192: 'nuevo',
#   193: 'modelo',
#   195: 'redes',
#   196: 'neuronales',
#   198: 'pesos',
#   199: 'basado',
#   202: 'operadores',
#   203: 'alfa',
#   205: 'beta',
#   207: 'cuales',
#   209: 'tomados',
#   212: 'modelos',
#   214: 'memorias',
#   215: 'asociativas',
#   216: 'alfabeta',
#   219: 'lado',
#   221: 'establecen',
#   223: 'condiciones',
#   224: 'necesarias',
#   226: 'suficientes',
#   228: 'equivalencia',
#   231: 'redes',
#   232: 'neuronales',
#   234: 'pesos',
#   237: 'circuitos',
#   238: 'booleanos',
#   241: 'presenta',
#   243: 'estudio',
#   244: 'completo',
#   246: 'factibilidad',
#   248: 'implementación',
#   250: 'hardware',
#   252: 'nuevo',
#   253: 'modelo',
#   256: 'exhibe',
#   258: 'alto',
#   259: 'desempeño',
#   260: 'derivado',
#   262: 'hecho',
#   267: 'hecho',
#   269: 'probado',
#   272: 'densidad',
#   273: 'aritmética',
#   276: 'modelos',
#   278: 'memorias',
#   279: 'asociativas',
#   280: 'alfa',
#   282: 'beta',
#   284: 'menor',
#   288: 'modelos',
#   289: 'relevantes',
#   291: 'memorias',
#   292: 'asociativas',
#   295: 'morfológicas'},
#  'Justificacion3': {2: 'idea',
#   4: 'considerar',
#   6: 'necesidad',
#   8: 'seguridad',
#   10: 'redes',
#   11: 'ad',
#   12: 'hoc',
#   15: 'nueva',
#   16: 'inclusive',
#   18: 'redes',
#   20: 'sensores',
#   22: 'ataques',
#   23: 'específicos',
#   26: 'cuales',
#   28: 'necesario',
#   29: 'utilizar',
#   30: 'mecanismos',
#   32: 'proteccion',
#   34: 'evitar',
#   35: 'ataques',
#   37: 'suplantacion',
#   39: 'negacion',
#   41: 'servicios',
#   44: 'posibles',
#   46: 'embargo',
#   48: 'todas',
#   50: 'tecnicas',
#   51: 'utilizadas',
#   53: 'soluciones',
#   56: 'problemas',
#   58: 'redes',
#   59: 'ad',
#   60: 'hoc',
#   65: 'aplicables',
#   68: 'wsn',
#   71: 'fin',
#   73: 'establecer',
#   74: 'claramente',
#   76: 'riesgos',
#   80: 'expone',
#   82: 'informacion',
#   85: 'wsn',
#   88: 'ataque',
#   89: 'conviene',
#   90: 'retomar',
#   92: 'definición',
#   95: 'seguridad',
#   98: 'informacion',
#   101: 'consiste',
#   103: 'otorgarle',
#   106: 'informacion',
#   107: 'cuatro',
#   108: 'propiedades',
#   109: 'basicas',
#   112: 'indica',
#   115: 'confidencialidad',
#   116: 'autenticidad',
#   117: 'integridaddisponibilidad',
#   119: 'base',
#   122: 'cuatro',
#   123: 'propiedades',
#   125: 'escenarios',
#   127: 'riesgo',
#   130: 'wsn',
#   134: 'considerando',
#   136: 'impacto',
#   139: 'ataque',
#   142: 'operacion',
#   145: 'red',
#   147: 'considera',
#   150: 'problema',
#   153: 'suplantacion',
#   155: 'nodos',
#   160: 'mas',
#   161: 'severos',
#   162: 'dada',
#   164: 'mecanica',
#   166: 'operacion',
#   169: 'red',
#   171: 'fin',
#   173: 'ilustrar',
#   175: 'situacion',
#   178: 'siguientes',
#   179: 'líneas',
#   181: 'plantea',
#   183: 'ataque',
#   184: 'hipotetico',
#   186: 'red',
#   188: 'wsn',
#   190: 'topología',
#   191: 'ad',
#   192: 'hoc',
#   194: 'formada',
#   196: 'varios',
#   197: 'nodos',
#   200: 'cuales',
#   201: 'existe',
#   203: 'relacion',
#   205: 'confianza',
#   206: 'mutua',
#   210: 'cada',
#   212: 'puede',
#   213: 'establecer',
#   214: 'enlaces',
#   216: 'cualquier',
#   218: 'nodo',
#   221: 'dentro',
#   224: 'area',
#   226: 'cobertura',
#   228: 'enlaces',
#   229: 'permiten',
#   232: 'wsn',
#   233: 'cumplir',
#   235: 'dos',
#   236: 'funciones',
#   237: 'basicas',
#   238: 'recoleccion',
#   240: 'transporte',
#   242: 'datos',
#   244: 'órdenes',
#   246: 'control',
#   249: 'red',
#   252: 'condiciones',
#   253: 'mas',
#   254: 'críticas',
#   258: 'forma',
#   259: 'alguna',
#   261: 'establecer',
#   262: 'autenticidad',
#   265: 'nodos',
#   268: 'red',
#   271: 'red',
#   273: 'ejecucion',
#   276: 'ataque',
#   278: 'suplantacion',
#   281: 'situacion',
#   284: 'ajena',
#   287: 'realidad',
#   289: 'ataque',
#   290: 'puede',
#   291: 'llevarse',
#   293: 'cabo',
#   296: 'menos',
#   299: 'siguientes',
#   300: 'dos',
#   301: 'formas',
#   304: 'captura',
#   307: 'nodo',
#   310: 'manipulacion',
#   312: 'mismo',
#   315: 'incorporacion',
#   318: 'dispositivo',
#   321: 'haga',
#   322: 'pasar',
#   325: 'nodo',
#   328: 'red',
#   329: 'autentico',
#   331: 'realizacion',
#   333: 'primer',
#   334: 'ataque',
#   337: 'simple',
#   343: 'dicho',
#   344: 'anteriormente',
#   348: 'problemas',
#   350: 'dispositivo',
#   355: 'facilidad',
#   357: 'ser',
#   358: 'capturado',
#   362: 'mayoría',
#   365: 'veces',
#   367: 'sensores',
#   369: 'cuentan',
#   371: 'mecanismos',
#   373: 'proteccion',
#   374: 'física',
#   375: 'alguna',
#   376: 'ademas',
#   379: 'expuestos',
#   381: 'fallas',
#   383: 'interrupcion',
#   386: 'servicio',
#   389: 'caso',
#   391: 'segundo',
#   392: 'ataque',
#   393: 'si',
#   394: 'bien',
#   396: 'requiere',
#   398: 'construccion',
#   401: 'sensor',
#   402: 'compatible',
#   405: 'wsn',
#   408: 'parece',
#   409: 'ser',
#   411: 'complicado',
#   413: 'vez',
#   418: 'posibilidad',
#   420: 'capturar',
#   423: 'mas',
#   424: 'nodos',
#   425: 'originales',
#   427: 'recuperar',
#   428: 'informacion',
#   430: 'mismo',
#   432: 'permita',
#   433: 'completar',
#   435: 'construccion',
#   436: 'dada',
#   438: 'dinámica',
#   440: 'operacion',
#   443: 'wsn',
#   446: 'posibilidades',
#   448: 'ocurrencia',
#   451: 'ataque',
#   453: 'suplantacion',
#   455: 'conveniente',
#   456: 'evaluar',
#   458: 'tan',
#   459: 'graves',
#   460: 'podrían',
#   461: 'ser',
#   463: 'daños',
#   465: 'caso',
#   468: 'realizacion',
#   470: 'mismo',
#   472: 'así',
#   473: 'tener',
#   475: 'mejor',
#   476: 'perspectiva',
#   478: 'enfoque',
#   480: 'problema',
#   482: 'adopta',
#   484: 'presente',
#   485: 'estudio',
#   486: 'bajo',
#   488: 'suposicion',
#   491: 'tercer',
#   492: 'elemento',
#   494: 'logrado',
#   495: 'suplantar',
#   497: 'nodo',
#   498: 'autentico',
#   501: 'red',
#   503: 'daños',
#   504: 'generados',
#   506: 'partir',
#   508: 'tal',
#   509: 'accion',
#   510: 'pueden',
#   511: 'agruparse',
#   513: 'dos',
#   514: 'casos',
#   515: 'generales',
#   518: 'parte',
#   521: 'informacion',
#   522: 'recolectada',
#   525: 'wsn',
#   526: 'tendra',
#   528: 'hacer',
#   530: 'salto',
#   532: 'traves',
#   534: 'nodo',
#   535: 'comprometido',
#   537: 'pone',
#   539: 'riesgo',
#   541: 'disponibilidad',
#   543: 'integridad',
#   546: 'confidencialidad',
#   548: 'dicha',
#   549: 'informacion',
#   552: 'ésta',
#   553: 'podría',
#   554: 'perderse',
#   555: 'alterarse',
#   559: 'caso',
#   560: 'extremo',
#   561: 'ser',
#   562: 'expuestos',
#   564: 'terceros',
#   566: 'autorizados',
#   569: 'igual',
#   570: 'forma',
#   572: 'órdenes',
#   574: 'control',
#   576: 'viajan',
#   579: 'red',
#   580: 'pueden',
#   581: 'ser',
#   582: 'interceptadas',
#   584: 'alteradas',
#   586: 'momento',
#   588: 'pasar',
#   591: 'nodo',
#   592: 'comprometido',
#   593: 'acarreando',
#   595: 'mal',
#   596: 'funcionamiento',
#   599: 'wsn',
#   600: 'llegando',
#   603: 'casos',
#   604: 'incluso',
#   606: 'poner',
#   608: 'riesgo',
#   610: 'integridad',
#   612: 'elementos',
#   613: 'circundantes',
#   615: 'sensor',
#   618: 'sensor',
#   619: 'mismo',
#   621: 'ocurrencia',
#   623: 'cualquiera',
#   626: 'casos',
#   627: 'anteriores',
#   630: 'menoscabo',
#   633: 'operacion',
#   636: 'wsn',
#   639: 'repercutiría',
#   641: 'consecuencias',
#   642: 'acordes',
#   645: 'importancia',
#   648: 'mision',
#   650: 'desempeñe',
#   651: 'dicha',
#   652: 'red',
#   654: 'deja',
#   657: 'mesa',
#   659: 'necesidad',
#   661: 'contar',
#   663: 'mecanismos',
#   665: 'autenticidad',
#   667: 'operen',
#   670: 'wsns',
#   672: 'terminos',
#   673: 'generales',
#   675: 'problema',
#   677: 'establecimiento',
#   679: 'identidad',
#   681: 'solucion',
#   682: 'mediante',
#   684: 'proceso',
#   686: 'autenticacion',
#   688: 'pares',
#   691: 'redes',
#   693: 'comunicaciones',
#   697: 'sistemas',
#   699: 'informacion',
#   701: 'proceso',
#   702: 'comunmente',
#   703: 'involucra',
#   705: 'uso',
#   707: 'mecanismos',
#   708: 'criptograficos',
#   712: 'clave',
#   713: 'secreta',
#   714: 'osimetricos',
#   716: 'bien',
#   718: 'clave',
#   719: 'publica',
#   721: 'asimetricos',
#   723: 'autenticidad',
#   726: 'wsn',
#   727: 'debe',
#   728: 'ser',
#   730: 'propiedad',
#   731: 'inherente',
#   734: 'propia',
#   735: 'red',
#   741: 'establecido',
#   744: 'seccion',
#   745: 'anterior',
#   747: 'ataque',
#   748: 'originado',
#   750: 'raíz',
#   753: 'falta',
#   755: 'ésta',
#   756: 'puede',
#   757: 'llegar',
#   759: 'comprometer',
#   761: 'funcionamiento',
#   764: 'red',
#   765: 'completa',
#   767: 'embargo',
#   769: 'diferencia',
#   772: 'entornos',
#   774: 'wsn',
#   778: 'marco',
#   780: 'operacion',
#   782: 'reducido',
#   784: 'recursos',
#   789: 'seleccion',
#   792: 'mecanismos',
#   794: 'autenticidad',
#   796: 'utilizar',
#   797: 'debe',
#   798: 'ser',
#   799: 'acorde',
#   801: 'dichas'},
#  'Justificacion4': {2: 'importante',
#   3: 'abordar',
#   5: 'problema',
#   7: 'agrupamiento',
#   8: 'conceptual',
#   12: 'muchas',
#   13: 'ciencias',
#   15: 'especialista',
#   17: 'interesado',
#   19: 'encontrar',
#   21: 'sólo',
#   23: 'agrupamientos',
#   27: 'clasifican',
#   29: 'objetos',
#   30: 'sino',
#   31: 'además',
#   33: 'propiedades',
#   35: 'caracterizan',
#   38: 'agrupamientos',
#   40: 'embargo',
#   42: 'herramientas',
#   46: 'diseñado',
#   49: 'momento',
#   52: 'limitantes',
#   54: 'ser',
#   55: 'aplicados',
#   57: 'problemas',
#   61: 'objetos',
#   62: 'descritos',
#   64: 'variables',
#   65: 'cualitativas',
#   67: 'cuantitativas',
#   68: 'mezcladas',
#   69: 'además',
#   71: 'permiten',
#   72: 'trabajar',
#   74: 'ausencia',
#   76: 'información',
#   79: 'descripciones',
#   82: 'objetos',
#   84: 'muchas',
#   85: 'ocasiones',
#   87: 'conceptos',
#   88: 'obtenidos',
#   91: 'algoritmos',
#   94: 'fácilmente',
#   95: 'interpretables',
#   97: 'cubren',
#   101: 'objetos',
#   103: 'agrupamiento',
#   105: 'cubren',
#   106: 'objetos',
#   108: 'pertenecen',
#   111: 'agrupamientos',
#   113: 'restricción',
#   114: 'fuerte',
#   117: 'algoritmos',
#   121: 'conceptos',
#   122: 'deben',
#   123: 'ser',
#   124: 'disjuntos',
#   126: 'decir',
#   128: 'objetos',
#   129: 'sólo',
#   130: 'pueden',
#   131: 'pertenecer',
#   134: 'clase',
#   136: 'embargo',
#   139: 'problemas',
#   140: 'reales',
#   142: 'sucede',
#   143: 'así',
#   147: 'objetos',
#   148: 'pueden',
#   149: 'pertenecer',
#   154: 'clase',
#   158: 'caso',
#   160: 'conceptos',
#   161: 'deberían',
#   162: 'ser',
#   164: 'disjuntos',
#   167: 'importante',
#   168: 'desarrollar',
#   169: 'algoritmos',
#   170: 'conceptuales',
#   171: 'difusos',
#   175: 'problemas',
#   176: 'reales',
#   178: 'especialista',
#   179: 'puede',
#   181: 'interesado',
#   183: 'conocer',
#   186: 'grado',
#   187: 'pertenece',
#   189: 'objeto',
#   191: 'cada',
#   195: 'agrupamientos',
#   198: 'saber',
#   199: 'si',
#   201: 'objeto',
#   202: 'pertenece'},
#  'Justificacion5': {2: 'uso',
#   3: 'tan',
#   4: 'frecuente',
#   7: 'computadoras',
#   10: 'actualidad',
#   12: 'conllevado',
#   14: 'desa',
#   15: 'rrollo',
#   17: 'múltiples',
#   18: 'aplicaciones',
#   19: 'tecnológicas',
#   20: 'cuya',
#   21: 'base',
#   24: 'lenguaje',
#   25: 'natural',
#   26: 'aunado',
#   30: 'surgimiento',
#   32: 'internet',
#   35: 'ello',
#   37: 'gran',
#   38: 'reserva',
#   40: 'recursos',
#   42: 'información',
#   43: 'digitales',
#   44: 'incita',
#   46: 'desarrollo',
#   48: 'algoritmos',
#   50: 'búsqueda',
#   51: 'eficientes',
#   53: 'ponen',
#   56: 'disposición',
#   59: 'mundo',
#   61: 'lenguaje',
#   64: 'plataforma',
#   66: 'común',
#   68: 'uso',
#   70: 'apli',
#   71: 'caciones',
#   72: 'importantes',
#   75: 'linguística',
#   76: 'computacional',
#   79: 'traducción',
#   80: 'automática',
#   82: 'manejo',
#   84: 'gestión',
#   86: 'documentos',
#   88: 'generación',
#   90: 'texto',
#   92: 'resúmenes',
#   94: 'bibliote',
#   95: 'cas',
#   96: 'digitales',
#   98: 'interfaces',
#   100: 'lenguaje',
#   101: 'natural',
#   102: 'etc',
#   103: 'cuya',
#   104: 'efectividad',
#   105: 'depende',
#   107: 'gran',
#   108: 'medida',
#   111: 'eficacia',
#   114: 'algoritmos',
#   118: 'propuestos',
#   122: 'todas',
#   124: 'tareas',
#   125: 'consideran',
#   127: 'desambiguación',
#   130: 'sentidos',
#   133: 'palabras',
#   135: 'investigación',
#   137: 'mejora',
#   139: 'algoritmos',
#   141: 'wsd',
#   142: 'conduce',
#   144: 'consiguiente',
#   147: 'mejora',
#   150: 'aplicaciones',
#   152: 'mencionadas',
#   155: 'justifica',
#   157: 'área',
#   159: 'investigación',
#   160: 'seleccionada',
#   163: 'tesis',
#   165: 'métodos',
#   168: 'propuestos',
#   170: 'llevar',
#   172: 'cabo',
#   174: 'desambiguación',
#   179: 'supervisados',
#   185: 'sobresalientes',
#   188: 'presente',
#   189: 'dificultad',
#   192: 'requieren',
#   193: 'datos',
#   194: 'etiquetados',
#   196: 'sentidos',
#   197: 'adquiridos',
#   200: 'gran',
#   201: 'mayoría',
#   204: 'oca',
#   205: 'siones',
#   207: 'forma',
#   208: 'manual',
#   210: 'disponibilidad',
#   213: 'conjuntos',
#   214: 'adecuados',
#   216: 'datos',
#   217: 'etiquetados',
#   222: 'factor',
#   223: 'significativo',
#   225: 'crucial',
#   228: 'entrenamiento',
#   230: 'algoritmos',
#   231: 'basados',
#   233: 'aprendi',
#   234: 'zaje',
#   236: 'desgracia',
#   238: 'recursos',
#   240: 'difíciles',
#   242: 'obtener',
#   245: 'crear',
#   246: 'pues',
#   247: 'requieren',
#   249: 'cada',
#   253: 'palabras',
#   256: 'etiquetada',
#   259: 'sentido',
#   261: 'procedimiento',
#   262: 'resulta',
#   264: 'costoso',
#   267: 'ello',
#   268: 'solamente',
#   270: 'artículos',
#   272: 'vocabulario',
#   273: 'terminan',
#   275: 'etiquetados',
#   276: 'mientras',
#   278: 'cuello',
#   280: 'botella',
#   281: 'léxico',
#   282: 'parece',
#   284: 'resuelto',
#   287: 'idioma',
#   288: 'inglés',
#   290: 'existe',
#   292: 'amplio',
#   293: 'rango',
#   295: 'recursos',
#   296: 'linguísticos',
#   299: 'procesamiento',
#   301: 'lenguaje',
#   302: 'na',
#   303: 'tural',
#   306: 'idiomas',
#   309: 'recurso',
#   311: 'mayor',
#   312: 'cobertura',
#   314: 'palabras',
#   316: 'princeton',
#   317: 'wordnet',
#   319: 'lexicón',
#   321: 'concordancia',
#   322: 'semántica',
#   325: 'idioma',
#   326: 'inglés',
#   329: 'agrupa',
#   331: 'sinónimos',
#   333: 'conjuntos',
#   334: 'denominados',
#   335: 'synsets',
#   337: 'proporciona',
#   340: 'palabras',
#   342: 'defini',
#   343: 'ción',
#   345: 'propósito',
#   347: 'éste',
#   349: 'producir',
#   351: 'combinación',
#   353: 'diccionario',
#   355: 'tesauro',
#   358: 'intuitivamente',
#   359: 'utilizable',
#   361: 'respalde',
#   363: 'análisis',
#   365: 'texto',
#   366: 'automático',
#   369: 'aplicaciones',
#   371: 'inteligencia',
#   372: 'artificial',
#   374: 'embargo',
#   376: 'utilidad',
#   378: 'recurso',
#   380: 'entrenamiento',
#   382: 'evaluación',
#   384: 'anotadores',
#   386: 'sentidos',
#   387: 'supervisados',
#   389: 'actualmente',
#   391: 'limitada',
#   394: 'metodología',
#   395: 'secuencial',
#   397: 'notación',
#   398: 'obliga',
#   401: 'intérpretes',
#   403: 'familiarizarse',
#   406: 'inventarios',
#   408: 'sentidos',
#   410: 'cada',
#   411: 'palabra',
#   414: 'pesar',
#   417: 'inconvenientes',
#   419: 'recurso',
#   420: 'representa',
#   422: 'contribución',
#   424: 'im',
#   425: 'portante',
#   427: 'campo',
#   428: 'proporcionando',
#   430: 'primer',
#   431: 'conjunto',
#   433: 'datos',
#   434: 'balanceados',
#   436: 'larga',
#   437: 'escala',
#   440: 'estudio',
#   443: 'propiedades',
#   445: 'polisemia',
#   448: 'idioma',
#   449: 'inglés',
#   450: 'desafortunadamente',
#   452: 'existe',
#   455: 'idioma',
#   456: 'español',
#   458: 'recurso',
#   459: 'léxico',
#   461: 'tal',
#   462: 'mag',
#   463: 'nitud',
#   468: 'pueda',
#   469: 'proveer',
#   471: 'sentido',
#   474: 'palabras',
#   475: 'aunque',
#   479: 'llevando',
#   481: 'cabo',
#   482: 'esfuerzos',
#   485: 'dirección',
#   490: 'búsqueda',
#   492: 'recursos',
#   493: 'dis',
#   494: 'ponibles',
#   496: 'permitan',
#   497: 'asociar',
#   498: 'etiquetas',
#   500: 'sentidos',
#   503: 'aún',
#   506: 'realice',
#   508: 'forma',
#   509: 'automática',
#   512: 'tarea',
#   513: 'intermedia',
#   514: 'indispensable',
#   517: 'procesamiento',
#   519: 'lenguaje'},
#  'Justificacion6': {2: 'tesis',
#   3: 'espera',
#   4: 'realizar',
#   5: 'distintas',
#   6: 'contribuciones',
#   8: 'primer',
#   9: 'lugar',
#   10: 'incorporando',
#   11: 'determinadas',
#   12: 'herramientas',
#   13: 'conceptuales',
#   14: 'desarrolladas',
#   17: 'campo',
#   20: 'estudios',
#   21: 'sociales',
#   24: 'ciencia',
#   27: 'tecnología',
#   32: 'mayormente',
#   33: 'aplicadas',
#   35: 'estudio',
#   36: 'particular',
#   39: 'tecnologías',
#   42: 'información',
#   45: 'comunicación',
#   46: 'añadir',
#   47: 'aquellos',
#   48: 'conceptos',
#   49: 'presentes',
#   52: 'estudio',
#   55: 'tecnologías',
#   57: 'general',
#   58: 'permitiría',
#   59: 'comprender',
#   61: 'particular',
#   64: 'procesos',
#   66: 'incorporación',
#   68: 'tic',
#   72: 'construcción',
#   74: 'campus',
#   75: 'virtuales',
#   77: 'universidades',
#   79: 'país',
#   80: 'junto',
#   82: 'ello',
#   83: 'proporcionar',
#   84: 'nuevos',
#   85: 'andamiajes',
#   86: 'teóricos',
#   87: 'vinculados',
#   90: 'características',
#   91: 'inherentes',
#   94: 'tic',
#   96: 'propósito',
#   98: 'presenta',
#   100: 'inédito',
#   103: 'pocos',
#   104: 'trabajos',
#   107: 'ámbito',
#   110: 'ciencias',
#   111: 'sociales',
#   113: 'analizado',
#   115: 'dinámicas',
#   117: 'desarrollo',
#   118: 'tecnológico',
#   120: 'posibilitan',
#   122: 'construcción',
#   124: 'entornos',
#   125: 'virtuales',
#   128: 'gestan',
#   131: 'universidades',
#   134: 'enfoque',
#   137: 'encuadre',
#   140: 'propuesto',
#   143: 'campo',
#   146: 'estudios',
#   147: 'sociales',
#   150: 'ciencia',
#   153: 'tecnología',
#   156: 'sentido',
#   158: 'aspira',
#   160: 'establecer',
#   162: 'ruptura',
#   164: 'aquellas',
#   165: 'formas',
#   166: 'cristalizadas',
#   168: 'determinismo',
#   169: 'tecnológico',
#   171: 'consideran',
#   174: 'creciente',
#   175: 'difusión',
#   177: 'proliferación',
#   180: 'tecnologías',
#   183: 'información',
#   186: 'comunicación',
#   187: 'producen',
#   188: 'efectos',
#   191: 'sociedad',
#   194: 'limitan',
#   197: 'mirada',
#   198: 'meramente',
#   199: 'instrumental',
#   200: 'dejando',
#   202: 'lado',
#   203: 'aquellas',
#   205: 'hacen',
#   206: 'hincapié',
#   209: 'tecnología',
#   211: 'construcción',
#   212: 'social',
#   213: 'entendiendo',
#   218: 'relación',
#   219: 'sociedadtecnología',
#   221: 'si',
#   223: 'tratara',
#   225: 'dos',
#   226: 'entidades',
#   227: 'separadas',
#   231: 'distinción',
#   232: 'misma',
#   234: 'social',
#   236: 'técnico',
#   237: 'debe',
#   238: 'considerarse',
#   241: 'resultado',
#   244: 'proceso',
#   246: 'coconstrucción',
#   249: 'parte',
#   251: 'investigación',
#   252: 'espera',
#   253: 'contribuir',
#   255: 'campo',
#   258: 'estudios',
#   261: 'educación',
#   262: 'superior',
#   265: 'estudios',
#   267: 'universidad',
#   271: 'aparece',
#   273: 'vacante',
#   275: 'problemática',
#   276: 'vinculada',
#   279: 'educación',
#   280: 'universitaria',
#   281: 'virtual',
#   283: 'utilización',
#   286: 'tecnología',
#   289: 'enseñanza',
#   292: 'investigación',
#   295: 'únicamente',
#   297: 'cuestión',
#   298: 'técnica',
#   299: 'puesto',
#   301: 'replantea',
#   302: 'cuestiones',
#   303: 'fundamentales',
#   305: 'sólo',
#   308: 'métodos',
#   310: 'trabajo',
#   311: 'sino',
#   314: 'metas',
#   317: 'propósitos',
#   319: 'persiguen',
#   321: 'instituciones',
#   322: 'universitarias',
#   323: 'así',
#   325: 'estudio',
#   328: 'campus',
#   329: 'virtuales',
#   332: 'universidades',
#   333: 'nacionales',
#   334: 'argentinas',
#   335: 'podría',
#   336: 'contribuir',
#   338: 'replantear',
#   340: 'dinámica',
#   342: 'formulación',
#   344: 'políticas',
#   346: 'toma',
#   348: 'decisiones',
#   350: 'interior',
#   353: 'universidad',
#   355: 'último',
#   357: 'espera',
#   358: 'contribuir',
#   361: 'estudios',
#   363: 'relacionan',
#   365: 'procesos',
#   367: 'innovación',
#   368: 'tecnológica',
#   371: 'territorios',
#   372: 'indagando',
#   375: 'nueva',
#   376: 'dimensión',
#   377: 'espaciotemporal',
#   379: 'generan',
#   381: 'tic',
#   385: 'condiciones',
#   386: 'territoriales',
#   387: 'económicas',
#   388: 'sociales',
#   389: 'organizacionales',
#   391: 'simbólicas',
#   395: 'inciden',
#   398: 'implementación',
#   401: 'campus'},
#  'Justificacion7': {1: 'actualmente',
#   3: 'encontramos',
#   6: 'proceso',
#   8: 'constantes',
#   9: 'cambios',
#   11: 'transformaciones',
#   13: 'obedecen',
#   16: 'serie',
#   18: 'factores',
#   24: 'incorporación',
#   25: 'vertiginosa',
#   27: 'nuevas',
#   28: 'tecnologías',
#   31: 'información',
#   34: 'comunicación',
#   36: 'diversos',
#   37: 'campos',
#   38: 'incluidos',
#   41: 'aspecto',
#   42: 'educativo',
#   44: 'acuerdo',
#   47: 'unesco',
#   50: 'sistemas',
#   51: 'educativos',
#   55: 'mundo',
#   57: 'enfrentan',
#   58: 'actualmente',
#   60: 'desafío',
#   62: 'utilizar',
#   64: 'nuevas',
#   65: 'tecnologías',
#   68: 'información',
#   71: 'comunicación',
#   72: 'tic',
#   74: 'proveer',
#   77: 'estudiantes',
#   80: 'herramientas',
#   82: 'conocimientos',
#   83: 'necesarios',
#   86: 'siglo',
#   87: 'xxi',
#   90: 'año',
#   93: 'informe',
#   94: 'mundial',
#   97: 'educación',
#   100: 'unesco',
#   102: 'imperativo',
#   105: 'calidad',
#   106: 'enfatizó',
#   109: 'importancia',
#   112: 'métodos',
#   114: 'aprendizaje',
#   118: 'utilización',
#   120: 'materiales',
#   121: 'educativos',
#   122: 'infraestructura',
#   124: 'acceso',
#   127: 'tic',
#   130: 'importante',
#   131: 'desafío',
#   134: 'campo',
#   135: 'educativo',
#   137: 'tecnologías',
#   140: 'información',
#   143: 'comunicación',
#   144: 'tic',
#   147: 'factor',
#   149: 'vital',
#   150: 'importancia',
#   153: 'transformación',
#   155: 'diversos',
#   156: 'campos',
#   159: 'sociedad',
#   162: 'campo',
#   163: 'educativo',
#   165: 'tic',
#   168: 'potencial',
#   170: 'transformar',
#   172: 'naturaleza',
#   175: 'educación',
#   177: 'cuanto',
#   179: 'dónde',
#   181: 'cómo',
#   183: 'produce',
#   185: 'proceso',
#   187: 'enseñanza',
#   188: 'aprendizaje',
#   189: 'así',
#   192: 'introducir',
#   193: 'cambios',
#   196: 'roles',
#   199: 'profesores',
#   202: 'estudiantes',
#   206: 'diferentes',
#   207: 'acciones',
#   210: 'realiza',
#   213: 'proceso',
#   214: 'educativo',
#   215: 'incluido',
#   217: 'temas',
#   219: 'gestión',
#   220: 'institucional',
#   223: 'nuevo',
#   224: 'panorama',
#   226: 'enfatiza',
#   228: 'importancia',
#   230: 'desarrollar',
#   231: 'nuevas',
#   232: 'competencias',
#   233: 'capacidades',
#   234: 'habilidades',
#   236: 'uso',
#   238: 'herramientas',
#   240: 'acuerdo',
#   242: 'valzacchi',
#   245: 'estudiantes',
#   246: 'deben',
#   247: 'cultivar',
#   249: 'siguientes',
#   250: 'destrezas',
#   252: 'según',
#   254: 'estándares',
#   257: 'international',
#   258: 'society',
#   259: 'for',
#   260: 'technology',
#   261: 'in',
#   262: 'education',
#   264: 'necesarios',
#   266: 'desenvolverse',
#   269: 'siglo',
#   270: 'xxi',
#   273: 'manejarse',
#   275: 'soltura',
#   278: 'empleo',
#   281: 'tecnología',
#   282: 'comunicar',
#   283: 'información',
#   285: 'ideas',
#   286: 'usando',
#   288: 'gran',
#   289: 'variedad',
#   291: 'medios',
#   293: 'formatos',
#   294: 'acceder',
#   295: 'intercambiar',
#   296: 'compilar',
#   297: 'organizar',
#   298: 'analizar',
#   300: 'sintetizar',
#   301: 'información',
#   302: 'saber',
#   303: 'encontrar',
#   304: 'información',
#   305: 'adicional',
#   306: 'saber',
#   307: 'evaluar',
#   309: 'información',
#   312: 'fuentes',
#   313: 'construir',
#   314: 'producir',
#   316: 'publicar',
#   317: 'modelos',
#   318: 'contenidos',
#   321: 'trabajos',
#   322: 'creativos',
#   323: 'colaborar',
#   325: 'cooperar',
#   327: 'grupos',
#   329: 'trabajo',
#   331: 'interactuar',
#   335: 'forma',
#   336: 'apropiada',
#   338: 'ética',
#   341: 'país',
#   343: 'inició',
#   345: 'proceso',
#   347: 'integración',
#   350: 'tic',
#   353: 'sistema',
#   354: 'educativo',
#   355: 'público',
#   356: 'estatal',
#   358: 'través',
#   360: 'proyecto',
#   361: 'huascarán',
#   363: 'actualmente',
#   365: 'través',
#   368: 'dirección',
#   369: 'general',
#   371: 'tecnologías',
#   372: 'educativas',
#   374: 'ministerio',
#   376: 'educación',
#   379: 'finalidad',
#   382: 'tic',
#   384: 'acuerdo',
#   386: 'ministerio',
#   388: 'educación',
#   390: 'p',
#   391: 'mejoren',
#   393: 'calidad',
#   396: 'educación',
#   397: 'secundaria',
#   401: 'estudiantes',
#   402: 'alcancen',
#   404: 'formación',
#   405: 'integral',
#   407: 'comprenda',
#   409: 'consecución',
#   411: 'logros',
#   413: 'aprendizaje',
#   416: 'sólida',
#   417: 'formación',
#   419: 'valores',
#   421: 'investigación',
#   424: 'justifica',
#   427: 'consideración',
#   430: 'acuerdo',
#   432: 'guiloff',
#   434: 'p',
#   436: 'existe',
#   437: 'suficiente',
#   438: 'información',
#   441: 'compromiso',
#   443: 'interacción',
#   444: 'tecnológica',
#   445: 'relacionada',
#   448: 'actividades',
#   450: 'aprendizaje',
#   451: 'formal',
#   454: 'estudiantes',
#   457: 'acuerdo',
#   459: 'condie',
#   461: 'p',
#   464: 'fecha',
#   467: 'estudios',
#   470: 'relación',
#   472: 'tic',
#   475: 'educación',
#   477: 'embargo',
#   478: 'varían',
#   480: 'acuerdo',
#   483: 'regiones',
#   487: 'realizado',
#   489: 'estudiantes',
#   491: 'ciertas',
#   492: 'características',
#   494: 'disciplinas',
#   496: 'necesario',
#   497: 'hacer',
#   498: 'investigaciones',
#   499: 'locales',
#   500: 'específicas',
#   501: 'asimismo',
#   503: 'tema',
#   506: 'especial',
#   507: 'importancia',
#   510: 'actualidad',
#   513: 'acuerdo',
#   516: 'diversas',
#   517: 'organizaciones',
#   518: 'instituciones',
#   520: 'investigadores',
#   522: 'vienen',
#   523: 'trabajando',
#   526: 'tic',
#   529: 'educación',
#   531: 'convocado',
#   533: 'realizar',
#   534: 'investigaciones',
#   536: 'nivel',
#   537: 'micro',
#   540: 'finalidad',
#   542: 'contribuir',
#   545: 'generación',
#   547: 'conocimiento',
#   548: 'científico',
#   550: 'trabajo',
#   553: 'justifica',
#   554: 'puesto',
#   556: 'permitirá',
#   557: 'entregar',
#   560: 'autoridades',
#   562: 'vienen',
#   563: 'implementando',
#   565: 'integración',
#   568: 'tic',
#   570: 'través',
#   573: 'dirección',
#   574: 'general',
#   576: 'tecnologías',
#   577: 'educativas',
#   579: 'ministerio',
#   581: 'educación',
#   582: 'resultados',
#   585: 'desarrollo',
#   587: 'capacidades',
#   588: 'tic'},
#  'Justificacion8': {2: 'problemas',
#   4: 'optimización',
#   5: 'industriales',
#   7: 'general',
#   10: 'demandantes',
#   12: 'cuanto',
#   14: 'uso',
#   17: 'recursos',
#   18: 'computacionales',
#   21: 'investigación',
#   22: 'hecha',
#   24: 'zabinsky',
#   27: 'describe',
#   29: 'ambiente',
#   31: 'operan',
#   33: 'diseñan',
#   35: 'aplicaciones',
#   37: 'ingeniería',
#   39: 'ambientes',
#   41: 'restricciones',
#   44: 'tiempos',
#   46: 'entrega',
#   49: 'productos',
#   50: 'originadas',
#   53: 'compromisos',
#   56: 'clientes',
#   58: 'desarrollos',
#   59: 'propuestos',
#   61: 'encontrar',
#   63: 'soluciones',
#   66: 'problemas',
#   67: 'técnicos',
#   68: 'particularmente',
#   71: 'optimización',
#   73: 'ven',
#   74: 'afectados',
#   76: 'dichas',
#   77: 'restricciones',
#   79: 'necesario',
#   80: 'disponer',
#   82: 'herramientas',
#   84: 'permitan',
#   85: 'atacar',
#   87: 'resolver',
#   89: 'problemas',
#   92: 'tiempos',
#   93: 'establecidos',
#   95: 'alternativa',
#   97: 'permite',
#   98: 'superar',
#   100: 'restricciones',
#   102: 'tiempo',
#   105: 'problemas',
#   107: 'ingeniería',
#   110: 'implementación',
#   112: 'hardware',
#   113: 'especializado',
#   116: 'algoritmos',
#   117: 'numéricos',
#   118: 'utilizados',
#   119: 'bajo',
#   121: 'enfoque',
#   123: 'abre',
#   125: 'posibilidad',
#   127: 'disminuir',
#   129: 'tiempo',
#   131: 'ejecución',
#   133: 'esquema',
#   134: 'seleccionado',
#   135: 'comparado',
#   138: 'plataforma',
#   140: 'procesamiento',
#   141: 'convencional',
#   144: 'implementación',
#   146: 'hardware',
#   148: 'soportada',
#   151: 'estudio',
#   152: 'detallado',
#   154: 'algoritmo',
#   155: 'seleccionado',
#   156: 'así',
#   159: 'puesta',
#   161: 'marcha',
#   163: 'hardware',
#   165: 'busca',
#   166: 'usualmente',
#   167: 'utilizar',
#   169: 'algoritmos',
#   171: 'menor',
#   172: 'costo',
#   173: 'computacional',
#   176: 'anterior',
#   178: 'primordial',
#   179: 'seleccionar',
#   181: 'procedimiento',
#   183: 'presente',
#   185: 'bajo',
#   186: 'costo',
#   187: 'computacional',
#   189: 'algoritmos',
#   190: 'deterministas',
#   191: 'ofrecen',
#   193: 'ventaja',
#   195: 'tener',
#   196: 'tal',
#   197: 'característica',
#   198: 'si',
#   200: 'comparan',
#   203: 'métodos',
#   205: 'exploración',
#   206: 'estocástica',
#   208: 'propiedad',
#   211: 'notable',
#   214: 'demanda',
#   215: 'computacional',
#   217: 'definida',
#   220: 'forma',
#   224: 'plantea',
#   226: 'problema',
#   228: 'resolver',
#   230: 'método',
#   231: 'propuesto',
#   233: 'gutmann',
#   235: 'pertenece',
#   238: 'estrategias',
#   239: 'deterministas',
#   241: 'og',
#   246: 'convierte',
#   249: 'buen',
#   250: 'candidato',
#   252: 'dicha',
#   253: 'tarea',
#   255: 'algoritmo',
#   257: 'gutmann',
#   258: 'utiliza',
#   260: 'conjunto',
#   262: 'puntos',
#   267: 'i',
#   268: 'i',
#   269: 'x',
#   270: 'f',
#   271: 'x',
#   275: 'm',
#   276: 'i',
#   277: 'i',
#   279: 'n',
#   280: 'x',
#   284: 'empleados',
#   286: 'generar',
#   288: 'superficie',
#   290: 'interpolación',
#   294: 'cada',
#   295: 'punto',
#   297: 'entrada',
#   298: 'implica',
#   300: 'evaluación',
#   302: 'modelo',
#   303: 'f',
#   304: 'x',
#   307: 'realizar',
#   309: 'depuración',
#   311: 'conjunto',
#   313: 'puntos',
#   314: 'inicial',
#   316: 'reduce',
#   318: 'número',
#   320: 'evaluaciones',
#   322: 'f',
#   323: 'x',
#   329: 'costo',
#   330: 'computacional',
#   332: 'método',
#   333: 'disminuirá',
#   334: 'dicha',
#   335: 'depuración',
#   336: 'debe',
#   337: 'realizarse',
#   339: 'tal',
#   340: 'forma',
#   343: 'superficie',
#   345: 'interpolación',
#   348: 'alterada',
#   351: 'general',
#   353: 'problemas',
#   355: 'resolver',
#   358: 'bien',
#   359: 'comportados',
#   361: 'condiciones',
#   362: 'reales',
#   364: 'diseños',
#   366: 'sometidos',
#   368: 'diversas',
#   369: 'perturbaciones',
#   371: 'alteran',
#   373: 'funcionamiento',
#   376: 'aplicación',
#   378: 'cuales',
#   380: 'comúnmente',
#   381: 'modeladas',
#   383: 'ruido',
#   384: 'gaussiano',
#   386: 'algoritmo',
#   388: 'gutmann',
#   390: 'acuerdo',
#   393: 'evidencia',
#   394: 'encontrada',
#   396: 'presenta',
#   397: 'problemas',
#   399: 'convergencia',
#   402: 'sometido',
#   405: 'condiciones',
#   407: 'deseable',
#   410: 'funcionamiento',
#   412: 'algoritmo',
#   415: 'afectado',
#   418: 'ruido',
#   421: 'contrario',
#   423: 'corre',
#   425: 'riesgo',
#   429: 'modelo',
#   431: 'represente',
#   433: 'manera',
#   434: 'realista',
#   436: 'fenómeno',
#   437: 'bajo'},
#  'Justificacion9': {1: 'tras',
#   2: 'analizar',
#   4: 'propuesta',
#   5: 'mda',
#   7: 'omg',
#   10: 'detectado',
#   11: 'dos',
#   12: 'importantes',
#   13: 'carencias',
#   14: 'relacionadas',
#   17: 'tratamiento',
#   20: 'modelos',
#   21: 'iniciales',
#   25: 'aclara',
#   26: 'cómo',
#   27: 'deben',
#   28: 'manejarse',
#   30: 'modelos',
#   31: 'ligados',
#   33: 'negocio',
#   37: 'conoce',
#   39: 'modelos',
#   40: 'independientes',
#   43: 'computación',
#   44: 'ó',
#   45: 'cim',
#   49: 'describe',
#   50: 'cómo',
#   51: 'deben',
#   52: 'asociarse',
#   54: 'modelos',
#   55: 'cim',
#   58: 'primeros',
#   59: 'modelos',
#   61: 'software',
#   63: 'desarrollar',
#   65: 'decir',
#   68: 'pim',
#   69: 'debido',
#   72: 'carencias',
#   73: 'mencionadas',
#   75: 'mayoría',
#   77: 'trabajos',
#   78: 'relacionados',
#   81: 'desarrollo',
#   83: 'software',
#   84: 'basado',
#   86: 'mdd',
#   87: 'ó',
#   88: 'mda',
#   89: 'suelen',
#   90: 'enfocarse',
#   93: 'perspectiva',
#   94: 'puramente',
#   95: 'tecnológica',
#   96: 'salvo',
#   97: 'contadas',
#   98: 'excepciones',
#   101: 'trabaja',
#   102: 'partiendo',
#   105: 'punto',
#   107: 'vista',
#   108: 'orientado',
#   110: 'negocio',
#   112: 'relacionado',
#   115: 'objetivos',
#   116: 'empresariales',
#   118: 'mayor',
#   119: 'parte',
#   122: 'investigaciones',
#   123: 'actuales',
#   126: 'campo',
#   128: 'centradas',
#   130: 'aspectos',
#   131: 'técnicos',
#   133: 'pueden',
#   134: 'mejorar',
#   136: 'obtención',
#   138: 'código',
#   140: 'partir',
#   142: 'modelos',
#   145: 'menos',
#   146: 'abstractos',
#   148: 'modelos',
#   149: 'suelen',
#   151: 'directamente',
#   152: 'relacionados',
#   155: 'software',
#   159: 'modelos',
#   161: 'requisitos',
#   163: 'información',
#   165: 'casos',
#   167: 'uso',
#   169: 'análisis',
#   171: 'diseño',
#   172: 'etc',
#   176: 'anterior',
#   178: 'deduce',
#   181: 'falta',
#   183: 'conexión',
#   184: 'real',
#   187: 'dominio',
#   189: 'negocio',
#   192: 'tecnológico',
#   193: 'provoca',
#   197: 'mayoría',
#   200: 'casos',
#   202: 'modelos',
#   204: 'negocio',
#   207: 'utilizados',
#   209: 'punto',
#   211: 'partida',
#   214: 'procesos',
#   216: 'desarrollo',
#   218: 'software',
#   220: 'problema',
#   222: 'aprecia',
#   223: 'claramente',
#   226: 'ámbito',
#   228: 'mda',
#   230: 'evidente',
#   232: 'falta',
#   234: 'asociación',
#   236: 'modelos',
#   237: 'cim',
#   239: 'pim',
#   241: 'metodologías',
#   243: 'desarrollo',
#   244: 'ágil',
#   246: 'software',
#   249: 'punto',
#   250: 'fuerte',
#   252: 'conexión',
#   255: 'aspectos',
#   256: 'asociados',
#   258: 'negocio',
#   261: 'tecnológicos',
#   263: 'embargo',
#   266: 'ajusta',
#   269: 'especificación',
#   270: 'mda',
#   276: 'puede',
#   277: 'aportar',
#   279: 'beneficios',
#   280: 'inherentes',
#   281: 'relacionados',
#   284: 'desarrollo',
#   286: 'software',
#   287: 'dirigido',
#   289: 'modelos',
#   291: 'consiguiente',
#   293: 'vez',
#   294: 'expuestas',
#   296: 'forma',
#   297: 'resumida',
#   299: 'ventajas',
#   300: 'desventajas',
#   302: 'deficiencias',
#   305: 'modelos',
#   307: 'desarrollo',
#   308: 'mencionados',
#   312: 'objetivo',
#   314: 'solventar',
#   316: 'puntos',
#   317: 'débiles',
#   319: 'aprovechar',
#   321: 'aportaciones',
#   322: 'planteamos',
#   324: 'siguiente',
#   325: 'hipótesis',
#   327: 'partida',
#   330: 'tesis',
#   332: 'combinación',
#   335: 'especificación',
#   336: 'mda',
#   339: 'idea',
#   341: 'desarrollo',
#   342: 'ágil',
#   343: 'resultaría',
#   345: 'ventajosa',
#   347: 'cara',
#   350: 'desarrollo',
#   352: 'software',
#   353: 'flexible',
#   355: 'asociado',
#   358: 'procesos'},
#  'Justificacion10': {2: 'presente',
#   3: 'tesis',
#   5: 'justifica',
#   6: 'además',
#   8: 'interés',
#   9: 'objetivo',
#   12: 'misma',
#   15: 'formación',
#   18: 'desarrollo',
#   19: 'académico',
#   21: 'autor',
#   22: 'así',
#   25: 'razones',
#   26: 'personales',
#   29: 'confluyeron',
#   31: 'serie',
#   33: 'hechos',
#   34: 'casi',
#   35: 'consecutivos',
#   37: 'final',
#   40: 'licenciatura',
#   42: 'ciencias',
#   45: 'información',
#   48: 'rama',
#   50: 'periodismo',
#   52: 'surgimiento',
#   54: 'interés',
#   57: 'investigación',
#   59: 'documentación',
#   60: 'periodística',
#   61: 'fomentado',
#   64: 'dr',
#   65: 'félix',
#   67: 'valle',
#   68: 'gastaminza',
#   71: 'citados',
#   72: 'estudios',
#   75: 'universidad',
#   76: 'complutense',
#   78: 'madrid',
#   80: 'introducción',
#   82: 'autor',
#   85: 'uso',
#   87: 'internet',
#   89: 'usuario',
#   92: 'surgimiento',
#   95: 'prensa',
#   96: 'accesible',
#   98: 'través',
#   100: 'internet',
#   102: 'españa',
#   104: 'semejanza',
#   107: 'sucedido',
#   110: 'años',
#   111: 'anteriores',
#   114: 'lugares',
#   116: 'intersección',
#   119: 'circunstancias',
#   120: 'produjo',
#   122: 'interés',
#   124: 'investigar',
#   126: 'aplicación',
#   129: 'documentación',
#   130: 'periodística',
#   133: 'nuevos',
#   134: 'contenidos',
#   135: 'periodísticos',
#   137: 'desarrollo',
#   140: 'mismos',
#   141: 'corrió',
#   142: 'paralelo',
#   145: 'formación',
#   146: 'posterior',
#   148: 'autor',
#   153: 'cursos',
#   155: 'doctorado',
#   157: 'documentación',
#   160: 'universidad',
#   161: 'carlos',
#   162: 'ifi',
#   164: 'madrid',
#   166: 'pronto',
#   167: 'contó',
#   170: 'tutela',
#   172: 'profesor',
#   173: 'antonio',
#   174: 'hernández',
#   175: 'pérez',
#   177: 'departamento',
#   179: 'biblioteconomía',
#   181: 'documentación',
#   184: 'misma',
#   185: 'universidad',
#   187: 'licenciado',
#   189: 'doctor',
#   191: 'ciencias',
#   194: 'información',
#   197: 'universidad',
#   198: 'complutense',
#   200: 'madrid',
#   203: 'formación',
#   204: 'común',
#   208: 'doctorado',
#   210: 'unía',
#   213: 'interés',
#   216: 'mismos',
#   217: 'temas',
#   218: 'así',
#   222: 'relacionados',
#   225: 'tecnologías',
#   228: 'información',
#   229: 'aplicadas',
#   230: 'documentalmente',
#   232: 'contenidos',
#   233: 'accesibles',
#   235: 'internet',
#   236: 'además',
#   239: 'dirección',
#   242: 'dr',
#   243: 'hernández',
#   246: 'tesina',
#   248: 'doctorado',
#   250: 'tutela',
#   252: 'manifestó',
#   253: 'mediante',
#   255: 'inclusión',
#   257: 'varios',
#   258: 'proyectos',
#   262: 'participaron',
#   263: 'ambos',
#   264: 'principalmente',
#   265: 'dirigidos',
#   268: 'dra',
#   269: 'mercedes',
#   270: 'caridad',
#   271: 'sebastián',
#   273: 'mismo',
#   274: 'departamento',
#   277: 'proyectos',
#   279: 'autor',
#   280: 'participó',
#   282: 'becario',
#   283: 'fpi',
#   285: 'ministerio',
#   287: 'educación',
#   289: 'ciencia',
#   294: 'bajo',
#   296: 'tutela',
#   298: 'dr',
#   299: 'hernández',
#   302: 'octubre',
#   306: 'ayudante',
#   308: 'escuela',
#   309: 'universitaria',
#   312: 'citado',
#   313: 'departamento',
#   314: 'varios',
#   317: 'proyectos',
#   319: 'relacionados',
#   322: 'tratamiento',
#   324: 'contenidos',
#   325: 'periodísticos',
#   326: 'representados',
#   327: 'mediante',
#   328: 'marcado',
#   330: 'texto',
#   331: 'dirigidos',
#   334: 'dr',
#   335: 'carlos',
#   336: 'delgado',
#   337: 'kloos',
#   339: 'dpto',
#   341: 'ingeniería',
#   342: 'telemática',
#   345: 'universidad',
#   346: 'carlos',
#   347: 'ifi',
#   349: 'madrid',
#   353: 'caso',
#   355: 'titulado',
#   356: 'periotrónico',
#   357: 'concepción',
#   359: 'desarrollo',
#   362: 'periódico',
#   363: 'electrónico',
#   364: 'personalizado',
#   365: 'cicyt',
#   366: 'tel',
#   373: 'subsiguiente',
#   374: 'proyecto',
#   375: 'infomedia',
#   377: 'sistema',
#   378: 'multiplataforma',
#   381: 'publicación',
#   383: 'david',
#   384: 'rodríguez',
#   385: 'mazeos',
#   386: 'información',
#   387: 'cicyt',
#   388: 'tel',
#   393: 'así',
#   396: 'proyecto',
#   397: 'infoflex',
#   398: 'gestión',
#   400: 'contenidos',
#   401: 'flexible',
#   403: 'distribuida',
#   404: 'basada',
#   406: 'tecnologías',
#   407: 'web',
#   408: 'tc',
#   409: 'dirigido',
#   412: 'dr',
#   413: 'luis',
#   414: 'sánchez',
#   415: 'fernández',
#   417: 'mismo',
#   418: 'departamento',
#   421: 'desarrollará',
#   423: 'partir',
#   428: 'proyectos',
#   430: 'investiga',
#   432: 'uso',
#   434: 'lenguajes',
#   436: 'marcado',
#   438: 'texto',
#   439: 'periodístico',
#   440: 'basado',
#   442: 'xml',
#   445: 'investigación',
#   447: 'derivó',
#   449: 'interés',
#   450: 'definitivo',
#   452: 'director',
#   455: 'autor',
#   458: 'tesis',
#   460: 'desarrollar',
#   462: 'aplicación',
#   465: 'metalenguaje',
#   469: 'lenguajes',
#   470: 'derivados',
#   472: 'mismo',
#   473: 'desarrollados',
#   475: 'instituciones',
#   476: 'internacionales',
#   479: 'centros',
#   481: 'documentación',
#   482: 'periodística',
#   483: 'pertenecientes',
#   485: 'medios',
#   487: 'comunicación',
#   488: 'accesibles',
#   490: 'internet',
#   492: 'interés',
#   495: 'documentación',
#   496: 'periodística',
#   500: 'desarrollo',
#   502: 'internet',
#   505: 'visto',
#   506: 'reflejado',
#   510: 'plano',
#   511: 'docente',
#   513: 'tras',
#   514: 'participar',
#   515: 'corno',
#   516: 'aeu',
#   518: 'diversas',
#   519: 'asignaturas',
#   520: 'relacionadas',
#   523: 'tecnologías',
#   526: 'información',
#   529: 'diplomatura',
#   531: 'biblioteconomia',
#   533: 'documentación',
#   535: 'autor',
#   536: 'participa',
#   539: 'docencia',
#   541: 'asignaturas',
#   542: 'dentro',
#   545: 'licenciatura',
#   547: 'periodismo',
#   550: 'universidad',
#   551: 'carlos',
#   552: 'ifi',
#   554: 'madrid',
#   557: 'relacionadas',
#   560: 'documentación',
#   562: 'documentación',
#   563: 'informativa',
#   566: 'curso',
#   571: 'uso',
#   573: 'internet',
#   575: 'fines',
#   576: 'periodísticos',
#   578: 'aplicaciones',
#   581: 'red',
#   583: 'periodismo',
#   586: 'curso'},
#  'Justificacion11': {2: 'tesis',
#   3: 'espera',
#   4: 'realizar',
#   5: 'distintas',
#   6: 'contribuciones',
#   8: 'primer',
#   9: 'lugar',
#   10: 'incorporando',
#   11: 'determinadas',
#   12: 'herramientas',
#   13: 'conceptuales',
#   14: 'desarrolladas',
#   17: 'campo',
#   20: 'estudios',
#   21: 'sociales',
#   24: 'ciencia',
#   27: 'tecnología',
#   32: 'mayormente',
#   33: 'aplicadas',
#   35: 'estudio',
#   36: 'particular',
#   39: 'tecnologías',
#   42: 'información',
#   45: 'comunicación',
#   46: 'añadir',
#   47: 'aquellos',
#   48: 'conceptos',
#   49: 'presentes',
#   52: 'estudio',
#   55: 'tecnologías',
#   57: 'general',
#   58: 'permitiría',
#   59: 'comprender',
#   61: 'particular',
#   64: 'procesos',
#   66: 'incorporación',
#   68: 'tic',
#   72: 'construcción',
#   74: 'campus',
#   75: 'virtuales',
#   77: 'universidades',
#   79: 'país',
#   80: 'junto',
#   82: 'ello',
#   83: 'proporcionar',
#   84: 'nuevos',
#   85: 'andamiajes',
#   86: 'teóricos',
#   87: 'vinculados',
#   90: 'características',
#   91: 'inherentes',
#   94: 'tic',
#   96: 'propósito',
#   98: 'presenta',
#   100: 'inédito',
#   103: 'pocos',
#   104: 'trabajos',
#   107: 'ámbito',
#   110: 'ciencias',
#   111: 'sociales',
#   113: 'analizado',
#   115: 'dinámicas',
#   117: 'desarrollo',
#   118: 'tecnológico',
#   120: 'posibilitan',
#   122: 'construcción',
#   124: 'entornos',
#   125: 'virtuales',
#   128: 'gestan',
#   131: 'universidades',
#   134: 'enfoque',
#   137: 'encuadre',
#   140: 'propuesto',
#   143: 'campo',
#   146: 'estudios',
#   147: 'sociales',
#   150: 'ciencia',
#   153: 'tecnología',
#   156: 'sentido',
#   158: 'aspira',
#   160: 'establecer',
#   162: 'ruptura',
#   164: 'aquellas',
#   165: 'formas',
#   166: 'cristalizadas',
#   168: 'determinismo',
#   169: 'tecnológico',
#   171: 'consideran',
#   174: 'creciente',
#   175: 'difusión',
#   177: 'proliferación',
#   180: 'tecnologías',
#   183: 'información',
#   186: 'comunicación',
#   187: 'producen',
#   188: 'efectos',
#   191: 'sociedad',
#   194: 'limitan',
#   197: 'mirada',
#   198: 'meramente',
#   199: 'instrumental',
#   200: 'dejando',
#   202: 'lado',
#   203: 'aquellas',
#   205: 'hacen',
#   206: 'hincapié',
#   209: 'tecnología',
#   211: 'construcción',
#   212: 'social',
#   213: 'entendiendo',
#   218: 'relación',
#   219: 'sociedadtecnología',
#   221: 'si',
#   223: 'tratara',
#   225: 'dos',
#   226: 'entidades',
#   227: 'separadas',
#   231: 'distinción',
#   232: 'misma',
#   234: 'social',
#   236: 'técnico',
#   237: 'debe',
#   238: 'considerarse',
#   241: 'resultado',
#   244: 'proceso',
#   246: 'coconstrucción',
#   249: 'parte',
#   251: 'investigación',
#   252: 'espera',
#   253: 'contribuir',
#   255: 'campo',
#   258: 'estudios',
#   261: 'educación',
#   262: 'superior',
#   265: 'estudios',
#   267: 'universidad',
#   271: 'aparece',
#   273: 'vacante',
#   275: 'problemática',
#   276: 'vinculada',
#   279: 'educación',
#   280: 'universitaria',
#   281: 'virtual',
#   283: 'utilización',
#   286: 'tecnología',
#   289: 'enseñanza',
#   292: 'investigación',
#   295: 'únicamente',
#   297: 'cuestión',
#   298: 'técnica',
#   299: 'puesto',
#   301: 'replantea',
#   302: 'cuestiones',
#   303: 'fundamentales',
#   305: 'sólo',
#   308: 'métodos',
#   310: 'trabajo',
#   311: 'sino',
#   314: 'metas',
#   317: 'propósitos',
#   319: 'persiguen',
#   321: 'instituciones',
#   322: 'universitarias',
#   323: 'así',
#   325: 'estudio',
#   328: 'campus',
#   329: 'virtuales',
#   332: 'universidades',
#   333: 'nacionales',
#   334: 'argentinas',
#   335: 'podría',
#   336: 'contribuir',
#   338: 'replantear',
#   340: 'dinámica',
#   342: 'formulación',
#   344: 'políticas',
#   346: 'toma',
#   348: 'decisiones',
#   350: 'interior',
#   353: 'universidad',
#   355: 'último',
#   357: 'espera',
#   358: 'contribuir',
#   361: 'estudios',
#   363: 'relacionan',
#   365: 'procesos',
#   367: 'innovación',
#   368: 'tecnológica',
#   371: 'territorios',
#   372: 'indagando',
#   375: 'nueva',
#   376: 'dimensión',
#   377: 'espaciotemporal',
#   379: 'generan',
#   381: 'tic',
#   385: 'condiciones',
#   386: 'territoriales',
#   387: 'económicas',
#   388: 'sociales',
#   389: 'organizacionales',
#   391: 'simbólicas',
#   395: 'inciden',
#   398: 'implementación',
#   401: 'campus',
#   402: 'virtuales',
#   405: 'forma',
#   407: 'busca',
#   408: 'abrir',
#   409: 'nuevas',
#   410: 'posibilidades',
#   412: 'triangulación',
#   413: 'teórica',
#   416: 'sociología',
#   419: 'tecnología',
#   421: 'estudios',
#   422: 'vinculados',
#   425: 'educación',
#   426: 'superior',
#   430: 'universidad',
#   432: 'particular',
#   435: 'estudios',
#   436: 'orientados',
#   438: 'comprender',
#   440: 'distintas',
#   441: 'dinámicas',
#   444: 'territorios',
#   445: 'contribuyendo',
#   447: 'ampliar',
#   449: 'alcances',
#   452: 'actuales',
#   453: 'estudios',
#   454: 'sociales'},
#  'Justificacion12': {2: 'necesidad',
#   4: 'cada',
#   5: 'vez',
#   7: 'capacidad',
#   9: 'cómputo',
#   11: 'muchas',
#   12: 'aplicaciones',
#   13: 'importantes',
#   14: 'incluyendo',
#   15: 'modelado',
#   16: 'simulación',
#   18: 'sistemas',
#   19: 'inteligentes',
#   20: 'tales',
#   24: 'realizan',
#   25: 'máquinas',
#   27: 'visión',
#   29: 'motivado',
#   32: 'investigación',
#   35: 'área',
#   37: 'arquitecturas',
#   39: 'cómputo',
#   41: 'avanzado',
#   43: 'manera',
#   44: 'considerable',
#   47: 'últimos',
#   48: 'años',
#   50: 'sistemas',
#   51: 'requieren',
#   52: 'mejor',
#   53: 'desempeño',
#   56: 'puede',
#   57: 'proporcionar',
#   59: 'máquinas',
#   61: 'existen',
#   62: 'actualmente',
#   66: 'podrán',
#   67: 'ser',
#   68: 'construidas',
#   71: 'futuro',
#   72: 'cercano',
#   73: 'actualmente',
#   76: 'alcanzando',
#   78: 'límites',
#   81: 'capacidades',
#   83: 'procesamiento',
#   86: 'diseños',
#   87: 'seriales',
#   89: 'opción',
#   91: 'alcanzar',
#   93: 'velocidades',
#   95: 'procesamiento',
#   96: 'deseadas',
#   98: 'físicamente',
#   99: 'posible',
#   102: 'través',
#   104: 'procesamiento',
#   105: 'paralelo',
#   106: 'hm',
#   108: 'arquitecturas',
#   109: 'reconfigurables',
#   110: 'prometen',
#   111: 'ser',
#   113: 'valiosa',
#   114: 'alternativa',
#   117: 'dispositivos',
#   119: 'cómputo',
#   120: 'convencionales',
#   122: 'hardware',
#   125: 'estático',
#   126: 'sino',
#   129: 'adapta',
#   132: 'aplicaciones',
#   134: 'diferencia',
#   137: 'procesadores',
#   139: 'asics',
#   141: 'técnicas',
#   143: 'reconfiguración',
#   145: 'utilizan',
#   146: 'ampliamente',
#   148: 'procesamiento',
#   149: 'paralelo',
#   150: 'particularmente',
#   152: 'arreglos',
#   154: 'procesadores',
#   155: 'tales',
#   158: 'sistólicos',
#   160: 'necesidad',
#   162: 'suspender',
#   164: 'operación',
#   167: 'dispositivos',
#   168: 'aún',
#   170: 'realizar',
#   171: 'pequeños',
#   172: 'cambios',
#   175: 'impacto',
#   176: 'crítico',
#   177: 'si',
#   179: 'van',
#   181: 'usar',
#   183: 'aceleradores',
#   186: 'algoritmo',
#   188: 'aplicaciones',
#   191: 'naturaleza',
#   194: 'tareas',
#   196: 'van',
#   198: 'ejecutar',
#   200: 'cambiante',
#   202: 'reconfiguración',
#   203: 'dinámica',
#   204: 'permite',
#   205: 'realizar',
#   206: 'cambios',
#   209: 'configuración',
#   212: 'dispositivo',
#   214: 'vuelo',
#   217: 'operación',
#   219: 'sistema',
#   220: 'mr',
#   222: 'partir',
#   225: 'conceptos',
#   227: 'trabajo',
#   229: 'propone',
#   230: 'reducir',
#   232: 'cuello',
#   234: 'botella',
#   237: 'sistemas',
#   238: 'basados',
#   241: 'modelo',
#   243: 'von',
#   244: 'neumann',
#   245: 'explorar',
#   247: 'analizar',
#   249: 'técnicas',
#   251: 'reconfiguración',
#   252: 'dinámica',
#   253: 'junto',
#   256: 'implementación',
#   258: 'algoritmos',
#   259: 'basados',
#   261: 'operaciones',
#   263: 'ventanas',
#   265: 'poder',
#   266: 'proponer',
#   267: 'soluciónes',
#   269: 'acordes',
#   272: 'restricciones',
#   274: 'tiempo',
#   275: 'real',
#   277: 'manera',
#   278: 'específica',
#   280: 'uso',
#   283: 'reconfiguración',
#   284: 'parcial',
#   285: 'existen',
#   287: 'serie',
#   289: 'problemas',
#   292: 'deben',
#   293: 'manejar',
#   294: 'asociados',
#   297: 'uso',
#   299: 'fpgas',
#   300: 'acoplados',
#   303: 'procesador',
#   304: 'primero',
#   306: 'proceso',
#   308: 'mapeo',
#   311: 'algoritmo',
#   314: 'fpgas',
#   317: 'automático',
#   318: 'típicamente',
#   320: 'programador',
#   323: 'debe',
#   324: 'cuidar',
#   326: 'forma',
#   328: 'identificar',
#   330: 'algoritmo',
#   333: 'parte',
#   337: 'ser',
#   338: 'implementado',
#   340: 'hardware',
#   343: 'herramientas',
#   344: 'especializadas',
#   346: 'convertir',
#   348: 'algoritmo',
# ...
#   259: 'mercado',
#   260: 'chips',
#   262: 'dos',
#   263: 'procesadores',
#   265: 'ejemplo',
#   266: 'amd',
#   267: 'athlon',
#   268: 'x',
#   270: 'intel',
#   271: 'core',
#   272: 'duo',
#   276: 'actualidad',
#   279: 'frecuentes',
#   281: 'cuatro',
#   282: 'procesadores',
#   283: 'quadcore',
#   284: 'amd',
#   285: 'opteron',
#   287: 'quadcore',
#   288: 'intel',
#   289: 'xeon',
#   292: 'tabla',
#   295: 'resumen',
#   297: 'procesadores',
#   298: 'multicore',
#   299: 'actuales',
#   302: 'aprecia',
#   304: 'gran',
#   305: 'evolución',
#   308: 'últimos',
#   309: 'años'},
#  'Justificacion18': {1: 'evidencias',
#   3: 'apoyan',
#   5: 'propuesta',
#   9: 'indexación',
#   12: 'estudiado',
#   15: 'unidades',
#   16: 'óptimas',
#   19: 'palabras',
#   20: 'mientras',
#   24: 'traducción',
#   26: 'mejor',
#   27: 'emplear',
#   28: 'unidades',
#   30: 'grandes',
#   31: 'verdejo',
#   32: 'et',
#   38: 'uso',
#   40: 'palabras',
#   41: 'individuales',
#   43: 'traducir',
#   45: 'resuelve',
#   47: 'problema',
#   50: 'ambiguedad',
#   51: 'semántica',
#   54: 'estadística',
#   56: 'coocurrencia',
#   58: 'términos',
#   59: 'permite',
#   60: 'realizar',
#   61: 'traducciones',
#   63: 'fiables',
#   64: 'ballesteros',
#   65: 'and',
#   66: 'croft',
#   70: 'simple',
#   71: 'utilización',
#   73: 'diccionarios',
#   74: 'aplicarla',
#   76: 'sintagmas',
#   77: 'nominales',
#   78: 'va',
#   80: 'mantener',
#   82: 'característica',
#   83: 'recordemos',
#   86: 'sintagma',
#   87: 'nominal',
#   89: 'compone',
#   91: 'varios',
#   92: 'términos',
#   95: 'utilización',
#   97: 'sintagmas',
#   98: 'nominales',
#   101: 'contenido',
#   102: 'semántico',
#   104: 'claro',
#   107: 'usuario',
#   108: 'proporcionará',
#   110: 'mejor',
#   111: 'información',
#   113: 'efectos',
#   115: 'interacción',
#   118: 'simple',
#   119: 'uso',
#   120: 'estadístico',
#   123: 'coocurrencia',
#   125: 'términos',
#   126: 'próximos',
#   129: 'hace',
#   131: 'ballesteros',
#   132: 'and',
#   133: 'croft',
#   136: 'diversos',
#   137: 'estudios',
#   139: 'penas',
#   140: 'et',
#   143: 'dennis',
#   144: 'et',
#   147: 'muestran',
#   150: 'sintagmas',
#   153: 'forma',
#   154: 'natural',
#   157: 'usuarios',
#   159: 'refinar',
#   161: 'consulta',
#   162: 'representan',
#   163: 'conceptos',
#   166: 'forma',
#   168: 'clara',
#   172: 'mayor',
#   173: 'contenido',
#   174: 'semántico',
#   177: 'términos',
#   178: 'aislados',
#   180: 'además',
#   182: 'determinación',
#   185: 'sintagmas',
#   188: 'utilización',
#   190: 'índices',
#   191: 'puede',
#   192: 'hacerse',
#   194: 'manera',
#   195: 'eficiente',
#   196: 'penas'},
#  'Justificacion19': {2: 'estructuras',
#   3: 'metálicas',
#   4: 'usadas',
#   7: 'industria',
#   9: 'transporte',
#   10: 'tales',
#   12: 'bastidores',
#   14: 'pared',
#   16: 'piso',
#   18: 'vehículos',
#   19: 'automotores',
#   21: 'sometidas',
#   23: 'cargas',
#   24: 'cíclicas',
#   27: 'vida',
#   29: 'servicio',
#   30: 'induciendo',
#   32: 'aparición',
#   34: 'grietas',
#   36: 'fatiga',
#   39: 'estructuras',
#   40: 'soldadas',
#   42: 'aleaciones',
#   44: 'aluminio',
#   45: 'tratables',
#   46: 'térmicamente',
#   48: 'riesgo',
#   50: 'aparición',
#   53: 'grieta',
#   55: 'probable',
#   56: 'debido',
#   59: 'heterogeneidad',
#   62: 'propiedades',
#   63: 'mecánicas',
#   66: 'zonas',
#   68: 'comprenden',
#   70: 'unión',
#   73: 'anterior',
#   74: 'surge',
#   76: 'necesidad',
#   78: 'realizar',
#   79: 'uniones',
#   80: 'experimentales',
#   82: 'soldaduras',
#   84: 'permitan',
#   85: 'retardar',
#   87: 'crecimiento',
#   89: 'grietas',
#   91: 'fatiga',
#   93: 'uniones',
#   94: 'soldadas',
#   96: 'aleaciones',
#   99: 'tipo',
#   101: 'ello',
#   103: 'establecen',
#   104: 'estudios',
#   105: 'comparativos',
#   107: 'dos',
#   108: 'procesos',
#   110: 'unión',
#   112: 'ejemplo',
#   114: 'proceso',
#   115: 'convencional',
#   117: 'soldadura',
#   119: 'arco',
#   120: 'eléctrico',
#   122: 'material',
#   124: 'aporte',
#   126: 'gas',
#   128: 'protección',
#   130: 'implementación',
#   133: 'técnica',
#   135: 'arco',
#   136: 'eléctrico',
#   137: 'indirecto',
#   138: 'modificado',
#   140: 'ello',
#   142: 'busca',
#   143: 'identificar',
#   145: 'técnica',
#   147: 'aplicación',
#   149: 'soldadura',
#   151: 'permita',
#   152: 'incrementar',
#   154: 'vida',
#   157: 'fatiga',
#   160: 'componentes'},
#  'Justificacion20': {3: 'literatura',
#   6: 'gran',
#   7: 'diversidad',
#   9: 'controladores',
#   10: 'adaptativos',
#   12: 'usan',
#   13: 'redes',
#   14: 'neuronales',
#   16: 'embargo',
#   18: 'importante',
#   20: 'desarrollo',
#   22: 'nuevos',
#   23: 'controladores',
#   25: 'mejor',
#   26: 'desempeño',
#   27: 'menor',
#   28: 'tiempo',
#   30: 'convergencia',
#   33: 'confiables',
#   35: 'sistemas',
#   38: 'difíciles',
#   40: 'modelar',
#   47: 'dispone',
#   50: 'modelo',
#   51: 'dinámico',
#   52: 'pueden',
#   53: 'ser',
#   54: 'objeto',
#   56: 'estudio',
#   57: 'usando',
#   58: 'redes',
#   59: 'neuronales',
#   62: 'identificación',
#   64: 'mismo',
#   67: 'caso',
#   69: 'incertidumbres',
#   72: 'modelo',
#   73: 'dinámico',
#   75: 'dinámicas',
#   77: 'modeladas',
#   78: 'pueden',
#   79: 'ser',
#   80: 'aproximadas',
#   82: 'redes',
#   83: 'neuronales',
#   85: 'control',
#   86: 'neuronal',
#   87: 'puede',
#   88: 'aplicarse',
#   90: 'sistemas',
#   91: 'robóticos',
#   94: 'industria',
#   96: 'ayudaría',
#   99: 'reducción',
#   101: 'tiempos',
#   104: 'procesos',
#   105: 'productivos',
#   108: 'reducción',
#   110: 'mantenimiento',
#   113: 'sistemas',
#   114: 'robóticos',
#   115: 'dado',
#   118: 'dinámicas',
#   121: 'sistemas',
#   122: 'cambian',
#   125: 'tiempo',
#   126: 'debido',
#   128: 'desgaste',
#   131: 'mecanismos',
#   133: 'factores',
#   134: 'externos',
#   137: 'adhesión',
#   139: 'polvo',
#   141: 'suciedad',
#   144: 'control',
#   145: 'neuronal',
#   147: 'puede',
#   148: 'usar',
#   151: 'control',
#   153: 'sistemas',
#   154: 'humanorobóticos',
#   157: 'finalidad',
#   159: 'ayudar',
#   162: 'personas',
#   164: 'discapacidades',
#   165: 'físicas',
#   168: 'control',
#   170: 'dinámicas',
#   171: 'complejas',
#   174: 'robots',
#   175: 'bípedos',
#   177: 'similares',
#   180: 'investigación',
#   181: 'puede',
#   182: 'ser',
#   183: 'usada',
#   186: 'campo',
#   187: 'educativo',
#   190: 'referencia',
#   192: 'investigaciones',
#   195: 'área',
#   197: 'control',
#   198: 'neuronal',
#   199: 'aplicada',
#   201: 'mecanismos'},
#  'Justificacion21': {3: 'ultimas',
#   4: 'décadas',
#   7: 'constatado',
#   9: 'creciente',
#   10: 'interés',
#   12: 'presentan',
#   14: 'robots',
#   15: 'caminantes',
#   19: 'punto',
#   21: 'vista',
#   24: 'investigación',
#   25: 'básica',
#   29: 'potenciales',
#   30: 'aplicaciones',
#   34: 'principales',
#   35: 'características',
#   38: 'robots',
#   39: 'equipados',
#   41: 'patas',
#   44: 'capacidad',
#   46: 'poder',
#   47: 'desplazarse',
#   50: 'amplia',
#   51: 'variedad',
#   53: 'terrenos',
#   55: 'estructurados',
#   57: 'particularidad',
#   59: 'hace',
#   61: 'atractivos',
#   64: 'aplicación',
#   65: 'practica',
#   67: 'robots',
#   69: 'servicios',
#   74: 'requiere',
#   76: 'locomoción',
#   78: 'terreno',
#   79: 'natural',
#   83: 'caracteriza',
#   85: 'presentar',
#   86: 'superficies',
#   87: 'irregulares',
#   88: 'diversos',
#   89: 'tipos',
#   91: 'obstáculos',
#   93: 'distintas',
#   94: 'pendientes',
#   96: 'embargo',
#   98: 'caminar',
#   100: 'terreno',
#   101: 'natural',
#   102: 'implica',
#   106: 'geometría',
#   109: 'propiedades',
#   110: 'físicas',
#   113: 'elementos',
#   115: 'rodean',
#   117: 'robot',
#   119: 'desconocidas',
#   122: 'variables',
#   127: 'necesario',
#   128: 'dotar',
#   130: 'robot',
#   133: 'estrategia',
#   135: 'adapte',
#   137: 'comportamiento',
#   139: 'respecto',
#   141: 'entorno',
#   142: 'si',
#   143: 'bien',
#   145: 'modelo',
#   147: 'robot',
#   148: 'puede',
#   149: 'ser',
#   150: 'conocido',
#   152: 'precisión',
#   153: 'razonable',
#   154: 'resulta',
#   155: 'difícil',
#   156: 'obtener',
#   158: 'descripción',
#   159: 'detallada',
#   161: 'entorno',
#   162: 'especialmente',
#   166: 'respecta',
#   169: 'propiedades',
#   170: 'físicas',
#   172: 'estabilidad',
#   175: 'robots',
#   176: 'caminantes',
#   179: 'realización',
#   181: 'ciclo',
#   183: 'locomoción',
#   186: 'gran',
#   187: 'importancia',
#   192: 'consideración',
#   195: 'determinada',
#   196: 'medida',
#   198: 'estabilidad',
#   201: 'locomoción',
#   202: 'influye',
#   204: 'manera',
#   205: 'directa',
#   208: 'seguridad',
#   210: 'robot',
#   213: 'trabajo',
#   215: 'presenta',
#   217: 'planteamiento',
#   219: 'estrategias',
#   221: 'adaptabilidad',
#   224: 'robot',
#   225: 'hexápodo',
#   226: 'hexpiderix',
#   227: 'basadas',
#   230: 'modelo',
#   231: 'geométrico',
#   237: 'necesario',
#   238: 'conocer',
#   240: 'ambiente',
#   241: 'pues',
#   243: 'tan',
#   244: 'solo',
#   245: 'saber',
#   247: 'extremidades',
#   249: 'tocando',
#   251: 'superficie',
#   253: 'posible',
#   254: 'estimar',
#   256: 'plano',
#   258: 'apoyo',
#   261: 'documento',
#   263: 'presenta',
#   265: 'diseño',
#   267: 'simulación',
#   269: 'estrategias',
#   271: 'adaptabilidad',
#   274: 'robot',
#   275: 'caminante',
#   276: 'hexápodo',
#   277: 'hexpiderix',
#   278: 'basadas',
#   281: 'modelo',
#   282: 'geométrico',
#   284: 'validación',
#   286: 'cada',
#   291: 'realiza',
#   294: 'plano',
#   296: 'distinto',
#   297: 'grado',
#   299: 'inclinación',
#   300: 'además',
#   304: 'analiza',
#   306: 'estabilidad',
#   307: 'estática',
#   309: 'cada',
#   310: 'postura',
#   313: 'criterio',
#   315: 'estabilidad',
#   316: 'estático',
#   317: 'normalizado',
#   320: 'peso',
#   321: 'sne',
#   324: 'siglas',
#   326: 'ingles'},
#  'Justificacion22': {2: 'trabajo',
#   4: 'tesis',
#   6: 'desarrolla',
#   7: 'debido',
#   10: 'necesidad',
#   13: 'sistema',
#   14: 'completo',
#   15: 'capaz',
#   17: 'predecir',
#   19: 'efectos',
#   20: 'indeseables',
#   22: 'memoria',
#   25: 'pa',
#   27: 'profundidad',
#   29: 'memoria',
#   31: 'órdenes',
#   34: 'linealidad',
#   35: 'variables',
#   37: 'ello',
#   39: 'desarrollan',
#   40: 'modelos',
#   41: 'polinomiales',
#   43: 'basados',
#   45: 'truncaciones',
#   48: 'series',
#   50: 'volterra',
#   52: 'wiener',
#   53: 'hammerstein',
#   55: 'mpm',
#   56: 'además',
#   58: 'utilizar',
#   59: 'técnicas',
#   61: 'aprendizaje',
#   63: 'ann',
#   65: 'anfis',
#   66: 'dentro',
#   69: 'tarjeta',
#   71: 'desarrollo',
#   72: 'fpgadsp',
#   75: 'técnica',
#   77: 'medición',
#   79: 'bajo',
#   80: 'costo',
#   83: 'curvas',
#   85: 'distorsión',
#   87: 'amplitud',
#   90: 'fase',
#   92: 'sistema',
#   94: 'controlado',
#   97: 'interfaz',
#   98: 'gráfica',
#   100: 'usuario',
#   101: 'gui',
#   104: 'permite',
#   106: 'manera',
#   107: 'simple',
#   108: 'abrir',
#   110: 'mediciones',
#   111: 'reales',
#   113: 'cualquier',
#   114: 'pa',
#   115: 'basado',
#   118: 'curvas',
#   120: 'distorsión',
#   121: 'amam',
#   123: 'ampm',
#   125: 'obtener',
#   127: 'coeficientes',
#   128: 'respectivos',
#   130: 'mpm',
#   131: 'obtenidos',
#   133: 'través',
#   135: 'método',
#   136: 'error',
#   137: 'cuadrático',
#   138: 'mínimo',
#   139: 'lse',
#   141: 'sistema',
#   143: 'niveles',
#   144: 'variables',
#   146: 'memoria',
#   148: 'órdenes',
#   151: 'linealidad',
#   152: 'variables',
#   154: 'adecuarse',
#   156: 'comportamiento',
#   158: 'pa',
#   160: 'parte',
#   161: 'principal',
#   163: 'trabajo',
#   165: 'basada',
#   168: 'herramienta',
#   170: 'diseño',
#   171: 'dsp',
#   172: 'builder',
#   175: 'permite',
#   176: 'traducir',
#   178: 'programa',
#   180: 'sistema',
#   182: 'matlabsimulink',
#   184: 'vhdl',
#   185: 'ahorrando',
#   186: 'tiempo',
#   188: 'diseño',
#   191: 'parte',
#   192: 'final',
#   194: 'realiza',
#   196: 'comparación',
#   198: 'modelado',
#   200: 'través',
#   202: 'vhdl',
#   203: 'puro',
#   205: 'modelado',
#   206: 'obtenido',
#   208: 'través',
#   210: 'ann',
#   212: 'anfis',
#   214: 'ventaja',
#   216: 'utilizar',
#   218: 'sistema',
#   220: 'simulación',
#   223: 'uso',
#   225: 'algoritmos',
#   227: 'etapas',
#   229: 'linealización',
#   230: 'posteriores',
#   232: 'trabajos',
#   233: 'desarrollados',
#   235: 'autor',
#   237: 'probó',
#   239: 'eficiencia',
#   242: 'modelos',
#   244: 'través',
#   246: 'fpga'},
#  'Justificacion23': {1: 'existen',
#   2: 'elementos',
#   3: 'estructurales',
#   5: 'mecánicos',
#   6: 'utilizados',
#   8: 'ingeniería',
#   10: 'estructuras',
#   11: 'chasis',
#   13: 'autos',
#   14: 'componentes',
#   15: 'aéreos',
#   16: 'estructuras',
#   17: 'marinas',
#   18: 'válvulas',
#   19: 'etc',
#   21: 'fabricados',
#   24: 'aleación',
#   26: 'aluminio',
#   27: 't',
#   30: 'fabricación',
#   32: 'dichos',
#   33: 'elementos',
#   35: 'requieren',
#   36: 'procesos',
#   38: 'unión',
#   44: 'soldadura',
#   46: 'soldadura',
#   49: 'proceso',
#   50: 'metalúrgico',
#   52: 'requiere',
#   54: 'entendimiento',
#   56: 'comportamiento',
#   58: 'material',
#   61: 'producción',
#   65: 'mayoría',
#   68: 'procesos',
#   70: 'soldadura',
#   72: 'igual',
#   76: 'fundición',
#   78: 'metales',
#   79: 'requieren',
#   81: 'altas',
#   82: 'temperaturas',
#   84: 'hacer',
#   85: 'posible',
#   87: 'unión',
#   90: 'materiales',
#   91: 'involucrados',
#   94: 'aleación',
#   96: 'aluminio',
#   97: 't',
#   99: 'presenta',
#   101: 'degradación',
#   104: 'propiedades',
#   105: 'mecánicas',
#   106: 'debido',
#   108: 'efecto',
#   109: 'térmico',
#   111: 'proceso',
#   113: 'soldadura',
#   114: 'además',
#   116: 'alta',
#   117: 'solubilidad',
#   119: 'hidrógeno',
#   122: 'aluminio',
#   123: 'líquido',
#   126: 'ocurre',
#   128: 'proceso',
#   130: 'solidificación',
#   131: 'queda',
#   132: 'atrapado',
#   133: 'generando',
#   134: 'porosidad',
#   137: 'material',
#   140: 'sabe',
#   143: 'posible',
#   144: 'reducir',
#   146: 'efecto',
#   147: 'térmico',
#   152: 'técnica',
#   153: 'aeim',
#   156: 'utilizar',
#   158: 'solo',
#   159: 'paso',
#   161: 'soldadura',
#   162: 'reduce',
#   164: 'efecto',
#   167: 'microestructura',
#   168: 'final',
#   171: 'caso',
#   173: 'aleación',
#   175: 'unir',
#   177: 'encuentra',
#   182: 'solubilización',
#   184: 'envejecido',
#   185: 'artificial',
#   186: 't',
#   189: 'alcanza',
#   190: 'temperaturas',
#   192: 'elevadas',
#   194: 'obtiene',
#   196: 'sobreenvejecido',
#   199: 'aleación',
#   202: 'disminuye',
#   204: 'propiedades',
#   205: 'mecánicas',
#   207: 'embargo',
#   209: 'tratamiento',
#   210: 'térmico',
#   211: 't',
#   214: 'proceso',
#   215: 'reversible',
#   220: 'puede',
#   221: 'considerar',
#   223: 'alternativa',
#   225: 'mejorar',
#   227: 'propiedades',
#   228: 'mecánicas',
#   231: 'uniones',
#   233: 'aluminio',
#   234: 'soldadas',
#   237: 'tratamiento',
#   238: 'térmico',
#   239: 'postsoldadura',
#   241: 'mejora',
#   244: 'propiedades',
#   245: 'mecánicas',
#   247: 'uniones',
#   249: 'aluminio',
#   250: 'soldadas',
#   252: 'aprecia',
#   255: 'incremento',
#   258: 'resistencia',
#   261: 'fatiga',
#   263: 'elementos',
#   264: 'estructurales',
#   267: 'sometidos',
#   269: 'cargas',
#   270: 'cíclicas',
#   272: 'incrementar',
#   274: 'resistencia',
#   277: 'fatiga',
#   279: 'retarda',
#   281: 'aparición',
#   283: 'grietas',
#   285: 'fatiga',
#   288: 'anterior',
#   289: 'surge',
#   291: 'necesidad',
#   293: 'hacer',
#   294: 'uniones',
#   295: 'soldadas',
#   297: 'permitan',
#   298: 'aumentar',
#   300: 'resistencia',
#   303: 'fatiga',
#   305: 'retardar',
#   307: 'crecimiento',
#   309: 'grietas',
#   311: 'fatiga',
#   313: 'aleaciones',
#   316: 'tipo',
#   319: 'implementación',
#   322: 'técnica',
#   323: 'aeim',
#   326: 'tratamiento',
#   327: 'térmico'},
#  'Justificacion24': {2: 'sensores',
#   3: 'basados',
#   5: 'fibra',
#   6: 'óptica',
#   7: 'ofrecen',
#   9: 'ventajas',
#   12: 'sensores',
#   14: 'tradicionales',
#   15: 'tales',
#   17: 'inmunidad',
#   19: 'interferencias',
#   20: 'electromagnéticas',
#   22: 'ultraligeros',
#   23: 'pueden',
#   24: 'ser',
#   25: 'empleados',
#   27: 'ambientes',
#   28: 'altamente',
#   29: 'corrosivos',
#   31: 'explosivos',
#   34: 'uso',
#   36: 'aplicaciones',
#   38: 'sensado',
#   39: 'remoto',
#   41: 'factible',
#   42: 'debido',
#   45: 'bajas',
#   46: 'pérdidas',
#   48: 'señal',
#   51: 'fibras',
#   52: 'ópticas'},
#  'Justificacion25': {3: 'ltimos',
#   4: 'aos',
#   7: 'dedicado',
#   8: 'considerable',
#   9: 'esfuerzo',
#   11: 'problema',
#   14: 'segmentacin',
#   16: 'color',
#   18: 'imgenes',
#   19: 'digitales',
#   20: 'dada',
#   22: 'importancia',
#   24: 'potencial',
#   26: 'hace',
#   29: 'mayora',
#   32: 'enfoques',
#   33: 'publicados',
#   36: 'segmentacin',
#   38: 'color',
#   40: 'basaba',
#   42: 'tcnicas',
#   43: 'monocromticas',
#   44: 'aplicadas',
#   46: 'cada',
#   47: 'componente',
#   49: 'color',
#   52: 'imagen',
#   54: 'diferentes',
#   55: 'espacios',
#   57: 'color',
#   58: 'rgb',
#   59: 'u',
#   63: 'diferentes',
#   64: 'formas',
#   66: 'producir',
#   68: 'composicin',
#   70: 'enfoques',
#   73: 'problema',
#   74: 'inherente',
#   77: 'prdida',
#   78: 'significativa',
#   81: 'informacin',
#   83: 'color',
#   86: 'proceso'}}

# %% [markdown]
# ## Create a Dictionary: Justification#-List of Words (Easier to handle)

# %%
TSU_structured = listMeth(TSU_structured)
Lic_structured = listMeth(Lic_structured)
Masters_structured = listMeth(Masters_structured)
Phd_structured = listMeth(Phd_structured)

TSU_structured
Lic_structured
Masters_structured
Phd_structured
# Out:
# {'Justificacion2': ['sección',
#   'anterior',
#   'evidenciado',
#   'importancia',
#   'wnn',
#   'ventajas',
#   'ofrecen',
#   'modelos',
#   'rna',
#   'pesos',
#   'fundamentado',
#   'hechos',
#   'referencias',
#   'bibliográficas',
#   'correspondientes',
#   'trabajos',
#   'investigación',
#   'científica',
#   'punta',
#   'realizada',
#   'equipos',
#   'internacionales',
#   'lado',
#   'enfatizado',
#   'existencia',
#   'importancia',
#   'aplicación',
#   'modelos',
#   'asociativos',
#   'alfabeta',
#   'cuyas',
#   'características',
#   'importantes',
#   'similares',
#   'exhiben',
#   'wnn',
#   'cuanto',
#   'eficacia',
#   'eficiencia',
#   'facilidad',
#   'implementación',
#   'ciertamente',
#   'connotados',
#   'autores',
#   'área',
#   'redes',
#   'neuronales',
#   'pesos',
#   'creado',
#   'modelos',
#   'relacionados',
#   'memorias',
#   'asociativas',
#   'incursionado',
#   'modelos',
#   'asociativos',
#   'alfabeta',
#   'bien',
#   'realizado',
#   'implementaciones',
#   'hardware',
#   'modelos',
#   'conocidos',
#   'redes',
#   'neuronales',
#   'pesos',
#   'embargo',
#   'noviembre',
#   'reportado',
#   'literatura',
#   'trabajos',
#   'científicos',
#   'relacionen',
#   'específicamente',
#   'redes',
#   'neuronales',
#   'pesos',
#   'modelos',
#   'memorias',
#   'asociativas',
#   'alfabeta',
#   'presente',
#   'trabajo',
#   'tesis',
#   'queda',
#   'justificado',
#   'incluye',
#   'manera',
#   'central',
#   'creación',
#   'diseño',
#   'nuevo',
#   'modelo',
#   'redes',
#   'neuronales',
#   'pesos',
#   'basado',
#   'operadores',
#   'alfa',
#   'beta',
#   'cuales',
#   'tomados',
#   'modelos',
#   'memorias',
#   'asociativas',
#   'alfabeta',
#   'lado',
#   'establecen',
#   'condiciones',
#   'necesarias',
#   'suficientes',
#   'equivalencia',
#   'redes',
#   'neuronales',
#   'pesos',
#   'circuitos',
#   'booleanos',
#   'presenta',
#   'estudio',
#   'completo',
#   'factibilidad',
#   'implementación',
#   'hardware',
#   'nuevo',
#   'modelo',
#   'exhibe',
#   'alto',
#   'desempeño',
#   'derivado',
#   'hecho',
#   'hecho',
#   'probado',
#   'densidad',
#   'aritmética',
#   'modelos',
#   'memorias',
#   'asociativas',
#   'alfa',
#   'beta',
#   'menor',
#   'modelos',
#   'relevantes',
#   'memorias',
#   'asociativas',
#   'morfológicas'],
#  'Justificacion3': ['idea',
#   'considerar',
#   'necesidad',
#   'seguridad',
#   'redes',
#   'ad',
#   'hoc',
#   'nueva',
#   'inclusive',
#   'redes',
#   'sensores',
#   'ataques',
#   'específicos',
#   'cuales',
#   'necesario',
#   'utilizar',
#   'mecanismos',
#   'proteccion',
#   'evitar',
#   'ataques',
#   'suplantacion',
#   'negacion',
#   'servicios',
#   'posibles',
#   'embargo',
#   'todas',
#   'tecnicas',
#   'utilizadas',
#   'soluciones',
#   'problemas',
#   'redes',
#   'ad',
#   'hoc',
#   'aplicables',
#   'wsn',
#   'fin',
#   'establecer',
#   'claramente',
#   'riesgos',
#   'expone',
#   'informacion',
#   'wsn',
#   'ataque',
#   'conviene',
#   'retomar',
#   'definición',
#   'seguridad',
#   'informacion',
#   'consiste',
#   'otorgarle',
#   'informacion',
#   'cuatro',
#   'propiedades',
#   'basicas',
#   'indica',
#   'confidencialidad',
#   'autenticidad',
#   'integridaddisponibilidad',
#   'base',
#   'cuatro',
#   'propiedades',
#   'escenarios',
#   'riesgo',
#   'wsn',
#   'considerando',
#   'impacto',
#   'ataque',
#   'operacion',
#   'red',
#   'considera',
#   'problema',
#   'suplantacion',
#   'nodos',
#   'mas',
#   'severos',
#   'dada',
#   'mecanica',
#   'operacion',
#   'red',
#   'fin',
#   'ilustrar',
#   'situacion',
#   'siguientes',
#   'líneas',
#   'plantea',
#   'ataque',
#   'hipotetico',
#   'red',
#   'wsn',
#   'topología',
#   'ad',
#   'hoc',
#   'formada',
#   'varios',
#   'nodos',
#   'cuales',
#   'existe',
#   'relacion',
#   'confianza',
#   'mutua',
#   'cada',
#   'puede',
#   'establecer',
#   'enlaces',
#   'cualquier',
#   'nodo',
#   'dentro',
#   'area',
#   'cobertura',
#   'enlaces',
#   'permiten',
#   'wsn',
#   'cumplir',
#   'dos',
#   'funciones',
#   'basicas',
#   'recoleccion',
#   'transporte',
#   'datos',
#   'órdenes',
#   'control',
#   'red',
#   'condiciones',
#   'mas',
#   'críticas',
#   'forma',
#   'alguna',
#   'establecer',
#   'autenticidad',
#   'nodos',
#   'red',
#   'red',
#   'ejecucion',
#   'ataque',
#   'suplantacion',
#   'situacion',
#   'ajena',
#   'realidad',
#   'ataque',
#   'puede',
#   'llevarse',
#   'cabo',
#   'menos',
#   'siguientes',
#   'dos',
#   'formas',
#   'captura',
#   'nodo',
#   'manipulacion',
#   'mismo',
#   'incorporacion',
#   'dispositivo',
#   'haga',
#   'pasar',
#   'nodo',
#   'red',
#   'autentico',
#   'realizacion',
#   'primer',
#   'ataque',
#   'simple',
#   'dicho',
#   'anteriormente',
#   'problemas',
#   'dispositivo',
#   'facilidad',
#   'ser',
#   'capturado',
#   'mayoría',
#   'veces',
#   'sensores',
#   'cuentan',
#   'mecanismos',
#   'proteccion',
#   'física',
#   'alguna',
#   'ademas',
#   'expuestos',
#   'fallas',
#   'interrupcion',
#   'servicio',
#   'caso',
#   'segundo',
#   'ataque',
#   'si',
#   'bien',
#   'requiere',
#   'construccion',
#   'sensor',
#   'compatible',
#   'wsn',
#   'parece',
#   'ser',
#   'complicado',
#   'vez',
#   'posibilidad',
#   'capturar',
#   'mas',
#   'nodos',
#   'originales',
#   'recuperar',
#   'informacion',
#   'mismo',
#   'permita',
#   'completar',
#   'construccion',
#   'dada',
#   'dinámica',
#   'operacion',
#   'wsn',
#   'posibilidades',
#   'ocurrencia',
#   'ataque',
#   'suplantacion',
#   'conveniente',
#   'evaluar',
#   'tan',
#   'graves',
#   'podrían',
#   'ser',
#   'daños',
#   'caso',
#   'realizacion',
#   'mismo',
#   'así',
#   'tener',
#   'mejor',
#   'perspectiva',
#   'enfoque',
#   'problema',
#   'adopta',
#   'presente',
#   'estudio',
#   'bajo',
#   'suposicion',
#   'tercer',
#   'elemento',
#   'logrado',
#   'suplantar',
#   'nodo',
#   'autentico',
#   'red',
#   'daños',
#   'generados',
#   'partir',
#   'tal',
#   'accion',
#   'pueden',
#   'agruparse',
#   'dos',
#   'casos',
#   'generales',
#   'parte',
#   'informacion',
#   'recolectada',
#   'wsn',
#   'tendra',
#   'hacer',
#   'salto',
#   'traves',
#   'nodo',
#   'comprometido',
#   'pone',
#   'riesgo',
#   'disponibilidad',
#   'integridad',
#   'confidencialidad',
#   'dicha',
#   'informacion',
#   'ésta',
#   'podría',
#   'perderse',
#   'alterarse',
#   'caso',
#   'extremo',
#   'ser',
#   'expuestos',
#   'terceros',
#   'autorizados',
#   'igual',
#   'forma',
#   'órdenes',
#   'control',
#   'viajan',
#   'red',
#   'pueden',
#   'ser',
#   'interceptadas',
#   'alteradas',
#   'momento',
#   'pasar',
#   'nodo',
#   'comprometido',
#   'acarreando',
#   'mal',
#   'funcionamiento',
#   'wsn',
#   'llegando',
#   'casos',
#   'incluso',
#   'poner',
#   'riesgo',
#   'integridad',
#   'elementos',
#   'circundantes',
#   'sensor',
#   'sensor',
#   'mismo',
#   'ocurrencia',
#   'cualquiera',
#   'casos',
#   'anteriores',
#   'menoscabo',
#   'operacion',
#   'wsn',
#   'repercutiría',
#   'consecuencias',
#   'acordes',
#   'importancia',
#   'mision',
#   'desempeñe',
#   'dicha',
#   'red',
#   'deja',
#   'mesa',
#   'necesidad',
#   'contar',
#   'mecanismos',
#   'autenticidad',
#   'operen',
#   'wsns',
#   'terminos',
#   'generales',
#   'problema',
#   'establecimiento',
#   'identidad',
#   'solucion',
#   'mediante',
#   'proceso',
#   'autenticacion',
#   'pares',
#   'redes',
#   'comunicaciones',
#   'sistemas',
#   'informacion',
#   'proceso',
#   'comunmente',
#   'involucra',
#   'uso',
#   'mecanismos',
#   'criptograficos',
#   'clave',
#   'secreta',
#   'osimetricos',
#   'bien',
#   'clave',
#   'publica',
#   'asimetricos',
#   'autenticidad',
#   'wsn',
#   'debe',
#   'ser',
#   'propiedad',
#   'inherente',
#   'propia',
#   'red',
#   'establecido',
#   'seccion',
#   'anterior',
#   'ataque',
#   'originado',
#   'raíz',
#   'falta',
#   'ésta',
#   'puede',
#   'llegar',
#   'comprometer',
#   'funcionamiento',
#   'red',
#   'completa',
#   'embargo',
#   'diferencia',
#   'entornos',
#   'wsn',
#   'marco',
#   'operacion',
#   'reducido',
#   'recursos',
#   'seleccion',
#   'mecanismos',
#   'autenticidad',
#   'utilizar',
#   'debe',
#   'ser',
#   'acorde',
#   'dichas'],
#  'Justificacion4': ['importante',
#   'abordar',
#   'problema',
#   'agrupamiento',
#   'conceptual',
#   'muchas',
#   'ciencias',
#   'especialista',
#   'interesado',
#   'encontrar',
#   'sólo',
#   'agrupamientos',
#   'clasifican',
#   'objetos',
#   'sino',
#   'además',
#   'propiedades',
#   'caracterizan',
#   'agrupamientos',
#   'embargo',
#   'herramientas',
#   'diseñado',
#   'momento',
#   'limitantes',
#   'ser',
#   'aplicados',
#   'problemas',
#   'objetos',
#   'descritos',
#   'variables',
#   'cualitativas',
#   'cuantitativas',
#   'mezcladas',
#   'además',
#   'permiten',
#   'trabajar',
#   'ausencia',
#   'información',
#   'descripciones',
#   'objetos',
#   'muchas',
#   'ocasiones',
#   'conceptos',
#   'obtenidos',
#   'algoritmos',
#   'fácilmente',
#   'interpretables',
#   'cubren',
#   'objetos',
#   'agrupamiento',
#   'cubren',
#   'objetos',
#   'pertenecen',
#   'agrupamientos',
#   'restricción',
#   'fuerte',
#   'algoritmos',
#   'conceptos',
#   'deben',
#   'ser',
#   'disjuntos',
#   'decir',
#   'objetos',
#   'sólo',
#   'pueden',
#   'pertenecer',
#   'clase',
#   'embargo',
#   'problemas',
#   'reales',
#   'sucede',
#   'así',
#   'objetos',
#   'pueden',
#   'pertenecer',
#   'clase',
#   'caso',
#   'conceptos',
#   'deberían',
#   'ser',
#   'disjuntos',
#   'importante',
#   'desarrollar',
#   'algoritmos',
#   'conceptuales',
#   'difusos',
#   'problemas',
#   'reales',
#   'especialista',
#   'puede',
#   'interesado',
#   'conocer',
#   'grado',
#   'pertenece',
#   'objeto',
#   'cada',
#   'agrupamientos',
#   'saber',
#   'si',
#   'objeto',
#   'pertenece'],
#  'Justificacion5': ['uso',
#   'tan',
#   'frecuente',
#   'computadoras',
#   'actualidad',
#   'conllevado',
#   'desa',
#   'rrollo',
#   'múltiples',
#   'aplicaciones',
#   'tecnológicas',
#   'cuya',
#   'base',
#   'lenguaje',
#   'natural',
#   'aunado',
#   'surgimiento',
#   'internet',
#   'ello',
#   'gran',
#   'reserva',
#   'recursos',
#   'información',
#   'digitales',
#   'incita',
#   'desarrollo',
#   'algoritmos',
#   'búsqueda',
#   'eficientes',
#   'ponen',
#   'disposición',
#   'mundo',
#   'lenguaje',
#   'plataforma',
#   'común',
#   'uso',
#   'apli',
#   'caciones',
#   'importantes',
#   'linguística',
#   'computacional',
#   'traducción',
#   'automática',
#   'manejo',
#   'gestión',
#   'documentos',
#   'generación',
#   'texto',
#   'resúmenes',
#   'bibliote',
#   'cas',
#   'digitales',
#   'interfaces',
#   'lenguaje',
#   'natural',
#   'etc',
#   'cuya',
#   'efectividad',
#   'depende',
#   'gran',
#   'medida',
#   'eficacia',
#   'algoritmos',
#   'propuestos',
#   'todas',
#   'tareas',
#   'consideran',
#   'desambiguación',
#   'sentidos',
#   'palabras',
#   'investigación',
#   'mejora',
#   'algoritmos',
#   'wsd',
#   'conduce',
#   'consiguiente',
#   'mejora',
#   'aplicaciones',
#   'mencionadas',
#   'justifica',
#   'área',
#   'investigación',
#   'seleccionada',
#   'tesis',
#   'métodos',
#   'propuestos',
#   'llevar',
#   'cabo',
#   'desambiguación',
#   'supervisados',
#   'sobresalientes',
#   'presente',
#   'dificultad',
#   'requieren',
#   'datos',
#   'etiquetados',
#   'sentidos',
#   'adquiridos',
#   'gran',
#   'mayoría',
#   'oca',
#   'siones',
#   'forma',
#   'manual',
#   'disponibilidad',
#   'conjuntos',
#   'adecuados',
#   'datos',
#   'etiquetados',
#   'factor',
#   'significativo',
#   'crucial',
#   'entrenamiento',
#   'algoritmos',
#   'basados',
#   'aprendi',
#   'zaje',
#   'desgracia',
#   'recursos',
#   'difíciles',
#   'obtener',
#   'crear',
#   'pues',
#   'requieren',
#   'cada',
#   'palabras',
#   'etiquetada',
#   'sentido',
#   'procedimiento',
#   'resulta',
#   'costoso',
#   'ello',
#   'solamente',
#   'artículos',
#   'vocabulario',
#   'terminan',
#   'etiquetados',
#   'mientras',
#   'cuello',
#   'botella',
#   'léxico',
#   'parece',
#   'resuelto',
#   'idioma',
#   'inglés',
#   'existe',
#   'amplio',
#   'rango',
#   'recursos',
#   'linguísticos',
#   'procesamiento',
#   'lenguaje',
#   'na',
#   'tural',
#   'idiomas',
#   'recurso',
#   'mayor',
#   'cobertura',
#   'palabras',
#   'princeton',
#   'wordnet',
#   'lexicón',
#   'concordancia',
#   'semántica',
#   'idioma',
#   'inglés',
#   'agrupa',
#   'sinónimos',
#   'conjuntos',
#   'denominados',
#   'synsets',
#   'proporciona',
#   'palabras',
#   'defini',
#   'ción',
#   'propósito',
#   'éste',
#   'producir',
#   'combinación',
#   'diccionario',
#   'tesauro',
#   'intuitivamente',
#   'utilizable',
#   'respalde',
#   'análisis',
#   'texto',
#   'automático',
#   'aplicaciones',
#   'inteligencia',
#   'artificial',
#   'embargo',
#   'utilidad',
#   'recurso',
#   'entrenamiento',
#   'evaluación',
#   'anotadores',
#   'sentidos',
#   'supervisados',
#   'actualmente',
#   'limitada',
#   'metodología',
#   'secuencial',
#   'notación',
#   'obliga',
#   'intérpretes',
#   'familiarizarse',
#   'inventarios',
#   'sentidos',
#   'cada',
#   'palabra',
#   'pesar',
#   'inconvenientes',
#   'recurso',
#   'representa',
#   'contribución',
#   'im',
#   'portante',
#   'campo',
#   'proporcionando',
#   'primer',
#   'conjunto',
#   'datos',
#   'balanceados',
#   'larga',
#   'escala',
#   'estudio',
#   'propiedades',
#   'polisemia',
#   'idioma',
#   'inglés',
#   'desafortunadamente',
#   'existe',
#   'idioma',
#   'español',
#   'recurso',
#   'léxico',
#   'tal',
#   'mag',
#   'nitud',
#   'pueda',
#   'proveer',
#   'sentido',
#   'palabras',
#   'aunque',
#   'llevando',
#   'cabo',
#   'esfuerzos',
#   'dirección',
#   'búsqueda',
#   'recursos',
#   'dis',
#   'ponibles',
#   'permitan',
#   'asociar',
#   'etiquetas',
#   'sentidos',
#   'aún',
#   'realice',
#   'forma',
#   'automática',
#   'tarea',
#   'intermedia',
#   'indispensable',
#   'procesamiento',
#   'lenguaje'],
#  'Justificacion6': ['tesis',
#   'espera',
#   'realizar',
#   'distintas',
#   'contribuciones',
#   'primer',
#   'lugar',
#   'incorporando',
#   'determinadas',
#   'herramientas',
#   'conceptuales',
#   'desarrolladas',
#   'campo',
#   'estudios',
#   'sociales',
#   'ciencia',
#   'tecnología',
#   'mayormente',
#   'aplicadas',
#   'estudio',
#   'particular',
#   'tecnologías',
#   'información',
#   'comunicación',
#   'añadir',
#   'aquellos',
#   'conceptos',
#   'presentes',
#   'estudio',
#   'tecnologías',
#   'general',
#   'permitiría',
#   'comprender',
#   'particular',
#   'procesos',
#   'incorporación',
#   'tic',
#   'construcción',
#   'campus',
#   'virtuales',
#   'universidades',
#   'país',
#   'junto',
#   'ello',
#   'proporcionar',
#   'nuevos',
#   'andamiajes',
#   'teóricos',
#   'vinculados',
#   'características',
#   'inherentes',
#   'tic',
#   'propósito',
#   'presenta',
#   'inédito',
#   'pocos',
#   'trabajos',
#   'ámbito',
#   'ciencias',
#   'sociales',
#   'analizado',
#   'dinámicas',
#   'desarrollo',
#   'tecnológico',
#   'posibilitan',
#   'construcción',
#   'entornos',
#   'virtuales',
#   'gestan',
#   'universidades',
#   'enfoque',
#   'encuadre',
#   'propuesto',
#   'campo',
#   'estudios',
#   'sociales',
#   'ciencia',
#   'tecnología',
#   'sentido',
#   'aspira',
#   'establecer',
#   'ruptura',
#   'aquellas',
#   'formas',
#   'cristalizadas',
#   'determinismo',
#   'tecnológico',
#   'consideran',
#   'creciente',
#   'difusión',
#   'proliferación',
#   'tecnologías',
#   'información',
#   'comunicación',
#   'producen',
#   'efectos',
#   'sociedad',
#   'limitan',
#   'mirada',
#   'meramente',
#   'instrumental',
#   'dejando',
#   'lado',
#   'aquellas',
#   'hacen',
#   'hincapié',
#   'tecnología',
#   'construcción',
#   'social',
#   'entendiendo',
#   'relación',
#   'sociedadtecnología',
#   'si',
#   'tratara',
#   'dos',
#   'entidades',
#   'separadas',
#   'distinción',
#   'misma',
#   'social',
#   'técnico',
#   'debe',
#   'considerarse',
#   'resultado',
#   'proceso',
#   'coconstrucción',
#   'parte',
#   'investigación',
#   'espera',
#   'contribuir',
#   'campo',
#   'estudios',
#   'educación',
#   'superior',
#   'estudios',
#   'universidad',
#   'aparece',
#   'vacante',
#   'problemática',
#   'vinculada',
#   'educación',
#   'universitaria',
#   'virtual',
#   'utilización',
#   'tecnología',
#   'enseñanza',
#   'investigación',
#   'únicamente',
#   'cuestión',
#   'técnica',
#   'puesto',
#   'replantea',
#   'cuestiones',
#   'fundamentales',
#   'sólo',
#   'métodos',
#   'trabajo',
#   'sino',
#   'metas',
#   'propósitos',
#   'persiguen',
#   'instituciones',
#   'universitarias',
#   'así',
#   'estudio',
#   'campus',
#   'virtuales',
#   'universidades',
#   'nacionales',
#   'argentinas',
#   'podría',
#   'contribuir',
#   'replantear',
#   'dinámica',
#   'formulación',
#   'políticas',
#   'toma',
#   'decisiones',
#   'interior',
#   'universidad',
#   'último',
#   'espera',
#   'contribuir',
#   'estudios',
#   'relacionan',
#   'procesos',
#   'innovación',
#   'tecnológica',
#   'territorios',
#   'indagando',
#   'nueva',
#   'dimensión',
#   'espaciotemporal',
#   'generan',
#   'tic',
#   'condiciones',
#   'territoriales',
#   'económicas',
#   'sociales',
#   'organizacionales',
#   'simbólicas',
#   'inciden',
#   'implementación',
#   'campus'],
#  'Justificacion7': ['actualmente',
#   'encontramos',
#   'proceso',
#   'constantes',
#   'cambios',
#   'transformaciones',
#   'obedecen',
#   'serie',
#   'factores',
#   'incorporación',
#   'vertiginosa',
#   'nuevas',
#   'tecnologías',
#   'información',
#   'comunicación',
#   'diversos',
#   'campos',
#   'incluidos',
#   'aspecto',
#   'educativo',
#   'acuerdo',
#   'unesco',
#   'sistemas',
#   'educativos',
#   'mundo',
#   'enfrentan',
#   'actualmente',
#   'desafío',
#   'utilizar',
#   'nuevas',
#   'tecnologías',
#   'información',
#   'comunicación',
#   'tic',
#   'proveer',
#   'estudiantes',
#   'herramientas',
#   'conocimientos',
#   'necesarios',
#   'siglo',
#   'xxi',
#   'año',
#   'informe',
#   'mundial',
#   'educación',
#   'unesco',
#   'imperativo',
#   'calidad',
#   'enfatizó',
#   'importancia',
#   'métodos',
#   'aprendizaje',
#   'utilización',
#   'materiales',
#   'educativos',
#   'infraestructura',
#   'acceso',
#   'tic',
#   'importante',
#   'desafío',
#   'campo',
#   'educativo',
#   'tecnologías',
#   'información',
#   'comunicación',
#   'tic',
#   'factor',
#   'vital',
#   'importancia',
#   'transformación',
#   'diversos',
#   'campos',
#   'sociedad',
#   'campo',
#   'educativo',
#   'tic',
#   'potencial',
#   'transformar',
#   'naturaleza',
#   'educación',
#   'cuanto',
#   'dónde',
#   'cómo',
#   'produce',
#   'proceso',
#   'enseñanza',
#   'aprendizaje',
#   'así',
#   'introducir',
#   'cambios',
#   'roles',
#   'profesores',
#   'estudiantes',
#   'diferentes',
#   'acciones',
#   'realiza',
#   'proceso',
#   'educativo',
#   'incluido',
#   'temas',
#   'gestión',
#   'institucional',
#   'nuevo',
#   'panorama',
#   'enfatiza',
#   'importancia',
#   'desarrollar',
#   'nuevas',
#   'competencias',
#   'capacidades',
#   'habilidades',
#   'uso',
#   'herramientas',
#   'acuerdo',
#   'valzacchi',
#   'estudiantes',
#   'deben',
#   'cultivar',
#   'siguientes',
#   'destrezas',
#   'según',
#   'estándares',
#   'international',
#   'society',
#   'for',
#   'technology',
#   'in',
#   'education',
#   'necesarios',
#   'desenvolverse',
#   'siglo',
#   'xxi',
#   'manejarse',
#   'soltura',
#   'empleo',
#   'tecnología',
#   'comunicar',
#   'información',
#   'ideas',
#   'usando',
#   'gran',
#   'variedad',
#   'medios',
#   'formatos',
#   'acceder',
#   'intercambiar',
#   'compilar',
#   'organizar',
#   'analizar',
#   'sintetizar',
#   'información',
#   'saber',
#   'encontrar',
#   'información',
#   'adicional',
#   'saber',
#   'evaluar',
#   'información',
#   'fuentes',
#   'construir',
#   'producir',
#   'publicar',
#   'modelos',
#   'contenidos',
#   'trabajos',
#   'creativos',
#   'colaborar',
#   'cooperar',
#   'grupos',
#   'trabajo',
#   'interactuar',
#   'forma',
#   'apropiada',
#   'ética',
#   'país',
#   'inició',
#   'proceso',
#   'integración',
#   'tic',
#   'sistema',
#   'educativo',
#   'público',
#   'estatal',
#   'través',
#   'proyecto',
#   'huascarán',
#   'actualmente',
#   'través',
#   'dirección',
#   'general',
#   'tecnologías',
#   'educativas',
#   'ministerio',
#   'educación',
#   'finalidad',
#   'tic',
#   'acuerdo',
#   'ministerio',
#   'educación',
#   'p',
#   'mejoren',
#   'calidad',
#   'educación',
#   'secundaria',
#   'estudiantes',
#   'alcancen',
#   'formación',
#   'integral',
#   'comprenda',
#   'consecución',
#   'logros',
#   'aprendizaje',
#   'sólida',
#   'formación',
#   'valores',
#   'investigación',
#   'justifica',
#   'consideración',
#   'acuerdo',
#   'guiloff',
#   'p',
#   'existe',
#   'suficiente',
#   'información',
#   'compromiso',
#   'interacción',
#   'tecnológica',
#   'relacionada',
#   'actividades',
#   'aprendizaje',
#   'formal',
#   'estudiantes',
#   'acuerdo',
#   'condie',
#   'p',
#   'fecha',
#   'estudios',
#   'relación',
#   'tic',
#   'educación',
#   'embargo',
#   'varían',
#   'acuerdo',
#   'regiones',
#   'realizado',
#   'estudiantes',
#   'ciertas',
#   'características',
#   'disciplinas',
#   'necesario',
#   'hacer',
#   'investigaciones',
#   'locales',
#   'específicas',
#   'asimismo',
#   'tema',
#   'especial',
#   'importancia',
#   'actualidad',
#   'acuerdo',
#   'diversas',
#   'organizaciones',
#   'instituciones',
#   'investigadores',
#   'vienen',
#   'trabajando',
#   'tic',
#   'educación',
#   'convocado',
#   'realizar',
#   'investigaciones',
#   'nivel',
#   'micro',
#   'finalidad',
#   'contribuir',
#   'generación',
#   'conocimiento',
#   'científico',
#   'trabajo',
#   'justifica',
#   'puesto',
#   'permitirá',
#   'entregar',
#   'autoridades',
#   'vienen',
#   'implementando',
#   'integración',
#   'tic',
#   'través',
#   'dirección',
#   'general',
#   'tecnologías',
#   'educativas',
#   'ministerio',
#   'educación',
#   'resultados',
#   'desarrollo',
#   'capacidades',
#   'tic'],
#  'Justificacion8': ['problemas',
#   'optimización',
#   'industriales',
#   'general',
#   'demandantes',
#   'cuanto',
#   'uso',
#   'recursos',
#   'computacionales',
#   'investigación',
#   'hecha',
#   'zabinsky',
#   'describe',
#   'ambiente',
#   'operan',
#   'diseñan',
#   'aplicaciones',
#   'ingeniería',
#   'ambientes',
#   'restricciones',
#   'tiempos',
#   'entrega',
#   'productos',
#   'originadas',
#   'compromisos',
#   'clientes',
#   'desarrollos',
#   'propuestos',
#   'encontrar',
#   'soluciones',
#   'problemas',
#   'técnicos',
#   'particularmente',
#   'optimización',
#   'ven',
#   'afectados',
#   'dichas',
#   'restricciones',
#   'necesario',
#   'disponer',
#   'herramientas',
#   'permitan',
#   'atacar',
#   'resolver',
#   'problemas',
#   'tiempos',
#   'establecidos',
#   'alternativa',
#   'permite',
#   'superar',
#   'restricciones',
#   'tiempo',
#   'problemas',
#   'ingeniería',
#   'implementación',
#   'hardware',
#   'especializado',
#   'algoritmos',
#   'numéricos',
#   'utilizados',
#   'bajo',
#   'enfoque',
#   'abre',
#   'posibilidad',
#   'disminuir',
#   'tiempo',
#   'ejecución',
#   'esquema',
#   'seleccionado',
#   'comparado',
#   'plataforma',
#   'procesamiento',
#   'convencional',
#   'implementación',
#   'hardware',
#   'soportada',
#   'estudio',
#   'detallado',
#   'algoritmo',
#   'seleccionado',
#   'así',
#   'puesta',
#   'marcha',
#   'hardware',
#   'busca',
#   'usualmente',
#   'utilizar',
#   'algoritmos',
#   'menor',
#   'costo',
#   'computacional',
#   'anterior',
#   'primordial',
#   'seleccionar',
#   'procedimiento',
#   'presente',
#   'bajo',
#   'costo',
#   'computacional',
#   'algoritmos',
#   'deterministas',
#   'ofrecen',
#   'ventaja',
#   'tener',
#   'tal',
#   'característica',
#   'si',
#   'comparan',
#   'métodos',
#   'exploración',
#   'estocástica',
#   'propiedad',
#   'notable',
#   'demanda',
#   'computacional',
#   'definida',
#   'forma',
#   'plantea',
#   'problema',
#   'resolver',
#   'método',
#   'propuesto',
#   'gutmann',
#   'pertenece',
#   'estrategias',
#   'deterministas',
#   'og',
#   'convierte',
#   'buen',
#   'candidato',
#   'dicha',
#   'tarea',
#   'algoritmo',
#   'gutmann',
#   'utiliza',
#   'conjunto',
#   'puntos',
#   'i',
#   'i',
#   'x',
#   'f',
#   'x',
#   'm',
#   'i',
#   'i',
#   'n',
#   'x',
#   'empleados',
#   'generar',
#   'superficie',
#   'interpolación',
#   'cada',
#   'punto',
#   'entrada',
#   'implica',
#   'evaluación',
#   'modelo',
#   'f',
#   'x',
#   'realizar',
#   'depuración',
#   'conjunto',
#   'puntos',
#   'inicial',
#   'reduce',
#   'número',
#   'evaluaciones',
#   'f',
#   'x',
#   'costo',
#   'computacional',
#   'método',
#   'disminuirá',
#   'dicha',
#   'depuración',
#   'debe',
#   'realizarse',
#   'tal',
#   'forma',
#   'superficie',
#   'interpolación',
#   'alterada',
#   'general',
#   'problemas',
#   'resolver',
#   'bien',
#   'comportados',
#   'condiciones',
#   'reales',
#   'diseños',
#   'sometidos',
#   'diversas',
#   'perturbaciones',
#   'alteran',
#   'funcionamiento',
#   'aplicación',
#   'cuales',
#   'comúnmente',
#   'modeladas',
#   'ruido',
#   'gaussiano',
#   'algoritmo',
#   'gutmann',
#   'acuerdo',
#   'evidencia',
#   'encontrada',
#   'presenta',
#   'problemas',
#   'convergencia',
#   'sometido',
#   'condiciones',
#   'deseable',
#   'funcionamiento',
#   'algoritmo',
#   'afectado',
#   'ruido',
#   'contrario',
#   'corre',
#   'riesgo',
#   'modelo',
#   'represente',
#   'manera',
#   'realista',
#   'fenómeno',
#   'bajo'],
#  'Justificacion9': ['tras',
#   'analizar',
#   'propuesta',
#   'mda',
#   'omg',
#   'detectado',
#   'dos',
#   'importantes',
#   'carencias',
#   'relacionadas',
#   'tratamiento',
#   'modelos',
#   'iniciales',
#   'aclara',
#   'cómo',
#   'deben',
#   'manejarse',
#   'modelos',
#   'ligados',
#   'negocio',
#   'conoce',
#   'modelos',
#   'independientes',
#   'computación',
#   'ó',
#   'cim',
#   'describe',
#   'cómo',
#   'deben',
#   'asociarse',
#   'modelos',
#   'cim',
#   'primeros',
#   'modelos',
#   'software',
#   'desarrollar',
#   'decir',
#   'pim',
#   'debido',
#   'carencias',
#   'mencionadas',
#   'mayoría',
#   'trabajos',
#   'relacionados',
#   'desarrollo',
#   'software',
#   'basado',
#   'mdd',
#   'ó',
#   'mda',
#   'suelen',
#   'enfocarse',
#   'perspectiva',
#   'puramente',
#   'tecnológica',
#   'salvo',
#   'contadas',
#   'excepciones',
#   'trabaja',
#   'partiendo',
#   'punto',
#   'vista',
#   'orientado',
#   'negocio',
#   'relacionado',
#   'objetivos',
#   'empresariales',
#   'mayor',
#   'parte',
#   'investigaciones',
#   'actuales',
#   'campo',
#   'centradas',
#   'aspectos',
#   'técnicos',
#   'pueden',
#   'mejorar',
#   'obtención',
#   'código',
#   'partir',
#   'modelos',
#   'menos',
#   'abstractos',
#   'modelos',
#   'suelen',
#   'directamente',
#   'relacionados',
#   'software',
#   'modelos',
#   'requisitos',
#   'información',
#   'casos',
#   'uso',
#   'análisis',
#   'diseño',
#   'etc',
#   'anterior',
#   'deduce',
#   'falta',
#   'conexión',
#   'real',
#   'dominio',
#   'negocio',
#   'tecnológico',
#   'provoca',
#   'mayoría',
#   'casos',
#   'modelos',
#   'negocio',
#   'utilizados',
#   'punto',
#   'partida',
#   'procesos',
#   'desarrollo',
#   'software',
#   'problema',
#   'aprecia',
#   'claramente',
#   'ámbito',
#   'mda',
#   'evidente',
#   'falta',
#   'asociación',
#   'modelos',
#   'cim',
#   'pim',
#   'metodologías',
#   'desarrollo',
#   'ágil',
#   'software',
#   'punto',
#   'fuerte',
#   'conexión',
#   'aspectos',
#   'asociados',
#   'negocio',
#   'tecnológicos',
#   'embargo',
#   'ajusta',
#   'especificación',
#   'mda',
#   'puede',
#   'aportar',
#   'beneficios',
#   'inherentes',
#   'relacionados',
#   'desarrollo',
#   'software',
#   'dirigido',
#   'modelos',
#   'consiguiente',
#   'vez',
#   'expuestas',
#   'forma',
#   'resumida',
#   'ventajas',
#   'desventajas',
#   'deficiencias',
#   'modelos',
#   'desarrollo',
#   'mencionados',
#   'objetivo',
#   'solventar',
#   'puntos',
#   'débiles',
#   'aprovechar',
#   'aportaciones',
#   'planteamos',
#   'siguiente',
#   'hipótesis',
#   'partida',
#   'tesis',
#   'combinación',
#   'especificación',
#   'mda',
#   'idea',
#   'desarrollo',
#   'ágil',
#   'resultaría',
#   'ventajosa',
#   'cara',
#   'desarrollo',
#   'software',
#   'flexible',
#   'asociado',
#   'procesos'],
#  'Justificacion10': ['presente',
#   'tesis',
#   'justifica',
#   'además',
#   'interés',
#   'objetivo',
#   'misma',
#   'formación',
#   'desarrollo',
#   'académico',
#   'autor',
#   'así',
#   'razones',
#   'personales',
#   'confluyeron',
#   'serie',
#   'hechos',
#   'casi',
#   'consecutivos',
#   'final',
#   'licenciatura',
#   'ciencias',
#   'información',
#   'rama',
#   'periodismo',
#   'surgimiento',
#   'interés',
#   'investigación',
#   'documentación',
#   'periodística',
#   'fomentado',
#   'dr',
#   'félix',
#   'valle',
#   'gastaminza',
#   'citados',
#   'estudios',
#   'universidad',
#   'complutense',
#   'madrid',
#   'introducción',
#   'autor',
#   'uso',
#   'internet',
#   'usuario',
#   'surgimiento',
#   'prensa',
#   'accesible',
#   'través',
#   'internet',
#   'españa',
#   'semejanza',
#   'sucedido',
#   'años',
#   'anteriores',
#   'lugares',
#   'intersección',
#   'circunstancias',
#   'produjo',
#   'interés',
#   'investigar',
#   'aplicación',
#   'documentación',
#   'periodística',
#   'nuevos',
#   'contenidos',
#   'periodísticos',
#   'desarrollo',
#   'mismos',
#   'corrió',
#   'paralelo',
#   'formación',
#   'posterior',
#   'autor',
#   'cursos',
#   'doctorado',
#   'documentación',
#   'universidad',
#   'carlos',
#   'ifi',
#   'madrid',
#   'pronto',
#   'contó',
#   'tutela',
#   'profesor',
#   'antonio',
#   'hernández',
#   'pérez',
#   'departamento',
#   'biblioteconomía',
#   'documentación',
#   'misma',
#   'universidad',
#   'licenciado',
#   'doctor',
#   'ciencias',
#   'información',
#   'universidad',
#   'complutense',
#   'madrid',
#   'formación',
#   'común',
#   'doctorado',
#   'unía',
#   'interés',
#   'mismos',
#   'temas',
#   'así',
#   'relacionados',
#   'tecnologías',
#   'información',
#   'aplicadas',
#   'documentalmente',
#   'contenidos',
#   'accesibles',
#   'internet',
#   'además',
#   'dirección',
#   'dr',
#   'hernández',
#   'tesina',
#   'doctorado',
#   'tutela',
#   'manifestó',
#   'mediante',
#   'inclusión',
#   'varios',
#   'proyectos',
#   'participaron',
#   'ambos',
#   'principalmente',
#   'dirigidos',
#   'dra',
#   'mercedes',
#   'caridad',
#   'sebastián',
#   'mismo',
#   'departamento',
#   'proyectos',
#   'autor',
#   'participó',
#   'becario',
#   'fpi',
#   'ministerio',
#   'educación',
#   'ciencia',
#   'bajo',
#   'tutela',
#   'dr',
#   'hernández',
#   'octubre',
#   'ayudante',
#   'escuela',
#   'universitaria',
#   'citado',
#   'departamento',
#   'varios',
#   'proyectos',
#   'relacionados',
#   'tratamiento',
#   'contenidos',
#   'periodísticos',
#   'representados',
#   'mediante',
#   'marcado',
#   'texto',
#   'dirigidos',
#   'dr',
#   'carlos',
#   'delgado',
#   'kloos',
#   'dpto',
#   'ingeniería',
#   'telemática',
#   'universidad',
#   'carlos',
#   'ifi',
#   'madrid',
#   'caso',
#   'titulado',
#   'periotrónico',
#   'concepción',
#   'desarrollo',
#   'periódico',
#   'electrónico',
#   'personalizado',
#   'cicyt',
#   'tel',
#   'subsiguiente',
#   'proyecto',
#   'infomedia',
#   'sistema',
#   'multiplataforma',
#   'publicación',
#   'david',
#   'rodríguez',
#   'mazeos',
#   'información',
#   'cicyt',
#   'tel',
#   'así',
#   'proyecto',
#   'infoflex',
#   'gestión',
#   'contenidos',
#   'flexible',
#   'distribuida',
#   'basada',
#   'tecnologías',
#   'web',
#   'tc',
#   'dirigido',
#   'dr',
#   'luis',
#   'sánchez',
#   'fernández',
#   'mismo',
#   'departamento',
#   'desarrollará',
#   'partir',
#   'proyectos',
#   'investiga',
#   'uso',
#   'lenguajes',
#   'marcado',
#   'texto',
#   'periodístico',
#   'basado',
#   'xml',
#   'investigación',
#   'derivó',
#   'interés',
#   'definitivo',
#   'director',
#   'autor',
#   'tesis',
#   'desarrollar',
#   'aplicación',
#   'metalenguaje',
#   'lenguajes',
#   'derivados',
#   'mismo',
#   'desarrollados',
#   'instituciones',
#   'internacionales',
#   'centros',
#   'documentación',
#   'periodística',
#   'pertenecientes',
#   'medios',
#   'comunicación',
#   'accesibles',
#   'internet',
#   'interés',
#   'documentación',
#   'periodística',
#   'desarrollo',
#   'internet',
#   'visto',
#   'reflejado',
#   'plano',
#   'docente',
#   'tras',
#   'participar',
#   'corno',
#   'aeu',
#   'diversas',
#   'asignaturas',
#   'relacionadas',
#   'tecnologías',
#   'información',
#   'diplomatura',
#   'biblioteconomia',
#   'documentación',
#   'autor',
#   'participa',
#   'docencia',
#   'asignaturas',
#   'dentro',
#   'licenciatura',
#   'periodismo',
#   'universidad',
#   'carlos',
#   'ifi',
#   'madrid',
#   'relacionadas',
#   'documentación',
#   'documentación',
#   'informativa',
#   'curso',
#   'uso',
#   'internet',
#   'fines',
#   'periodísticos',
#   'aplicaciones',
#   'red',
#   'periodismo',
#   'curso'],
#  'Justificacion11': ['tesis',
#   'espera',
#   'realizar',
#   'distintas',
#   'contribuciones',
#   'primer',
#   'lugar',
#   'incorporando',
#   'determinadas',
#   'herramientas',
#   'conceptuales',
#   'desarrolladas',
#   'campo',
#   'estudios',
#   'sociales',
#   'ciencia',
#   'tecnología',
#   'mayormente',
#   'aplicadas',
#   'estudio',
#   'particular',
#   'tecnologías',
#   'información',
#   'comunicación',
#   'añadir',
#   'aquellos',
#   'conceptos',
#   'presentes',
#   'estudio',
#   'tecnologías',
#   'general',
#   'permitiría',
#   'comprender',
#   'particular',
#   'procesos',
#   'incorporación',
#   'tic',
#   'construcción',
#   'campus',
#   'virtuales',
#   'universidades',
#   'país',
#   'junto',
#   'ello',
#   'proporcionar',
#   'nuevos',
#   'andamiajes',
#   'teóricos',
#   'vinculados',
#   'características',
#   'inherentes',
#   'tic',
#   'propósito',
#   'presenta',
#   'inédito',
#   'pocos',
#   'trabajos',
#   'ámbito',
#   'ciencias',
#   'sociales',
#   'analizado',
#   'dinámicas',
#   'desarrollo',
#   'tecnológico',
#   'posibilitan',
#   'construcción',
#   'entornos',
#   'virtuales',
#   'gestan',
#   'universidades',
#   'enfoque',
#   'encuadre',
#   'propuesto',
#   'campo',
#   'estudios',
#   'sociales',
#   'ciencia',
#   'tecnología',
#   'sentido',
#   'aspira',
#   'establecer',
#   'ruptura',
#   'aquellas',
#   'formas',
#   'cristalizadas',
#   'determinismo',
#   'tecnológico',
#   'consideran',
#   'creciente',
#   'difusión',
#   'proliferación',
#   'tecnologías',
#   'información',
#   'comunicación',
#   'producen',
#   'efectos',
#   'sociedad',
#   'limitan',
#   'mirada',
#   'meramente',
#   'instrumental',
#   'dejando',
#   'lado',
#   'aquellas',
#   'hacen',
#   'hincapié',
#   'tecnología',
#   'construcción',
#   'social',
#   'entendiendo',
#   'relación',
#   'sociedadtecnología',
#   'si',
#   'tratara',
#   'dos',
#   'entidades',
#   'separadas',
#   'distinción',
#   'misma',
#   'social',
#   'técnico',
#   'debe',
#   'considerarse',
#   'resultado',
#   'proceso',
#   'coconstrucción',
#   'parte',
#   'investigación',
#   'espera',
#   'contribuir',
#   'campo',
#   'estudios',
#   'educación',
#   'superior',
#   'estudios',
#   'universidad',
#   'aparece',
#   'vacante',
#   'problemática',
#   'vinculada',
#   'educación',
#   'universitaria',
#   'virtual',
#   'utilización',
#   'tecnología',
#   'enseñanza',
#   'investigación',
#   'únicamente',
#   'cuestión',
#   'técnica',
#   'puesto',
#   'replantea',
#   'cuestiones',
#   'fundamentales',
#   'sólo',
#   'métodos',
#   'trabajo',
#   'sino',
#   'metas',
#   'propósitos',
#   'persiguen',
#   'instituciones',
#   'universitarias',
#   'así',
#   'estudio',
#   'campus',
#   'virtuales',
#   'universidades',
#   'nacionales',
#   'argentinas',
#   'podría',
#   'contribuir',
#   'replantear',
#   'dinámica',
#   'formulación',
#   'políticas',
#   'toma',
#   'decisiones',
#   'interior',
#   'universidad',
#   'último',
#   'espera',
#   'contribuir',
#   'estudios',
#   'relacionan',
#   'procesos',
#   'innovación',
#   'tecnológica',
#   'territorios',
#   'indagando',
#   'nueva',
#   'dimensión',
#   'espaciotemporal',
#   'generan',
#   'tic',
#   'condiciones',
#   'territoriales',
#   'económicas',
#   'sociales',
#   'organizacionales',
#   'simbólicas',
#   'inciden',
#   'implementación',
#   'campus',
#   'virtuales',
#   'forma',
#   'busca',
#   'abrir',
#   'nuevas',
#   'posibilidades',
#   'triangulación',
#   'teórica',
#   'sociología',
#   'tecnología',
#   'estudios',
#   'vinculados',
#   'educación',
#   'superior',
#   'universidad',
#   'particular',
#   'estudios',
#   'orientados',
#   'comprender',
#   'distintas',
#   'dinámicas',
#   'territorios',
#   'contribuyendo',
#   'ampliar',
#   'alcances',
#   'actuales',
#   'estudios',
#   'sociales'],
#  'Justificacion12': ['necesidad',
#   'cada',
#   'vez',
#   'capacidad',
#   'cómputo',
#   'muchas',
#   'aplicaciones',
#   'importantes',
#   'incluyendo',
#   'modelado',
#   'simulación',
#   'sistemas',
#   'inteligentes',
#   'tales',
#   'realizan',
#   'máquinas',
#   'visión',
#   'motivado',
#   'investigación',
#   'área',
#   'arquitecturas',
#   'cómputo',
#   'avanzado',
#   'manera',
#   'considerable',
#   'últimos',
#   'años',
#   'sistemas',
#   'requieren',
#   'mejor',
#   'desempeño',
#   'puede',
#   'proporcionar',
#   'máquinas',
#   'existen',
#   'actualmente',
#   'podrán',
#   'ser',
#   'construidas',
#   'futuro',
#   'cercano',
#   'actualmente',
#   'alcanzando',
#   'límites',
#   'capacidades',
#   'procesamiento',
#   'diseños',
#   'seriales',
#   'opción',
#   'alcanzar',
#   'velocidades',
#   'procesamiento',
#   'deseadas',
#   'físicamente',
#   'posible',
#   'través',
#   'procesamiento',
#   'paralelo',
#   'hm',
#   'arquitecturas',
#   'reconfigurables',
#   'prometen',
#   'ser',
#   'valiosa',
#   'alternativa',
#   'dispositivos',
#   'cómputo',
#   'convencionales',
#   'hardware',
#   'estático',
#   'sino',
#   'adapta',
#   'aplicaciones',
#   'diferencia',
#   'procesadores',
#   'asics',
#   'técnicas',
#   'reconfiguración',
#   'utilizan',
#   'ampliamente',
#   'procesamiento',
#   'paralelo',
#   'particularmente',
#   'arreglos',
#   'procesadores',
#   'tales',
#   'sistólicos',
#   'necesidad',
#   'suspender',
#   'operación',
#   'dispositivos',
#   'aún',
#   'realizar',
#   'pequeños',
#   'cambios',
#   'impacto',
#   'crítico',
#   'si',
#   'van',
#   'usar',
#   'aceleradores',
#   'algoritmo',
#   'aplicaciones',
#   'naturaleza',
#   'tareas',
#   'van',
#   'ejecutar',
#   'cambiante',
#   'reconfiguración',
#   'dinámica',
#   'permite',
#   'realizar',
#   'cambios',
#   'configuración',
#   'dispositivo',
#   'vuelo',
#   'operación',
#   'sistema',
#   'mr',
#   'partir',
#   'conceptos',
#   'trabajo',
#   'propone',
#   'reducir',
#   'cuello',
#   'botella',
#   'sistemas',
#   'basados',
#   'modelo',
#   'von',
#   'neumann',
#   'explorar',
#   'analizar',
#   'técnicas',
#   'reconfiguración',
#   'dinámica',
#   'junto',
#   'implementación',
#   'algoritmos',
#   'basados',
#   'operaciones',
#   'ventanas',
#   'poder',
#   'proponer',
#   'soluciónes',
#   'acordes',
#   'restricciones',
#   'tiempo',
#   'real',
#   'manera',
#   'específica',
#   'uso',
#   'reconfiguración',
#   'parcial',
#   'existen',
#   'serie',
#   'problemas',
#   'deben',
#   'manejar',
#   'asociados',
#   'uso',
#   'fpgas',
#   'acoplados',
#   'procesador',
#   'primero',
#   'proceso',
#   'mapeo',
#   'algoritmo',
#   'fpgas',
#   'automático',
#   'típicamente',
#   'programador',
#   'debe',
#   'cuidar',
#   'forma',
#   'identificar',
#   'algoritmo',
#   'parte',
#   'ser',
#   'implementado',
#   'hardware',
#   'herramientas',
#   'especializadas',
#   'convertir',
#   'algoritmo',
#   'descripción',
#   'hardware',
#   'presente',
#   'propuesta',
#   'pretende',
#   'determinar',
#   'mejor',
#   'forma',
#   'resolver',
#   'problema',
#   'codiseño',
#   'hwsw',
#   'nj',
#   'desafío',
#   'interesante',
#   'asociado',
#   'computación',
#   'reconfigurable',
#   'reconfiguración',
#   'dinámica',
#   'misma',
#   'manejarla',
#   'objetivo',
#   'principal',
#   'proyecto',
#   'fpgas',
#   'tradicionales',
#   'tiempos',
#   'configuración',
#   'relativamente',
#   'largos',
#   'aplicaciones',
#   'dependen',
#   'modificaciones',
#   'línea',
#   'cualquier',
#   'retardo',
#   'configuración',
#   'incrementa',
#   'tiempo',
#   'total',
#   'cómputo',
#   'desempeño',
#   'global',
#   'objetivos',
#   'trabajo',
#   'disminuir',
#   'efecto',
#   'utilizando',
#   'reconfiguración',
#   'parcial',
#   'permite',
#   'modificar',
#   'sólo',
#   'área',
#   'fpga',
#   'perturbar',
#   'funcionamiento',
#   'resto',
#   'dispositivo',
#   'desafío',
#   'consiste',
#   'determinar',
#   'granularidad',
#   'apropiada',
#   'sistema',
#   'relación',
#   'desempeño',
#   'obtenido',
#   'finalmente',
#   'plantea',
#   'posibilidad',
#   'generar',
#   'sistema',
#   'permita',
#   'optimizar',
#   'área',
#   'reducir',
#   'consumo',
#   'potencia',
#   'bajo',
#   'costo',
#   'cuente',
#   'habilidad',
#   'hacerlo',
#   'compatible'],
#  'Justificacion13': ['aumento',
#   'volumen',
#   'variedad',
#   'información',
#   'bases',
#   'datos',
#   'incrementado',
#   'dificultad',
#   'clasificación',
#   'caracterización',
#   'comprensión',
#   'mismas',
#   'solución',
#   'problema',
#   'uso',
#   'técnicas',
#   'análisis',
#   'datos',
#   'reconocimiento',
#   'patrones',
#   'minería',
#   'datos',
#   'base',
#   'estudio',
#   'trabajos',
#   'relacionados',
#   'forma',
#   'abordar',
#   'problema',
#   'encontrar',
#   'regularidades',
#   'puedan',
#   'representar',
#   'conjuntos',
#   'datos',
#   'permitiendo',
#   'caracterizarlos',
#   'manera',
#   'reducir',
#   'información',
#   'forma',
#   'hacer',
#   'utilizar',
#   'conjuntos',
#   'representantes',
#   'cuales',
#   'herramienta',
#   'útil',
#   'clasificación',
#   'supervisada',
#   'caracterización',
#   'universos',
#   'estructurados',
#   'embargo',
#   'cuenta',
#   'algoritmo',
#   'cálculo',
#   'exceptuando',
#   'verificación',
#   'definición',
#   'espacio',
#   'búsqueda',
#   'problema',
#   'representantes',
#   'pueden',
#   'incluir',
#   'mucha',
#   'redundancia',
#   'tal',
#   'motivo',
#   'pueden',
#   'llegar',
#   'ser',
#   'demasiados',
#   'ejemplo',
#   'conjunto',
#   'objetos',
#   'rasgos',
#   'clases',
#   'encontraron',
#   'representantes',
#   'necesario',
#   'contar',
#   'herramienta',
#   'permita',
#   'encontrar',
#   'subconjunto',
#   'representantes',
#   'adecuado',
#   'clasificación'],
#  'Justificacion14': ['enorme',
#   'cantidad',
#   'imágenes',
#   'crudo',
#   'almacenada',
#   'superficie',
#   'terrestre',
#   'interpretación',
#   'imágenes',
#   'laboriosa',
#   'consume',
#   'tiempo',
#   'inimaginable',
#   'interpretación',
#   'ayuda',
#   'procesamiento',
#   'imágenes',
#   'pongamos',
#   'ejemplo',
#   'imágenes',
#   'satelitales',
#   'territorio',
#   'nacional',
#   'tomadas',
#   'constelación',
#   'satélites',
#   'spot',
#   'considerar',
#   'imágenes',
#   'siguen',
#   'adquiriendo',
#   'primer',
#   'trimestre',
#   'año',
#   'imágenes',
#   'tomadas',
#   'satélite',
#   'spot',
#   'alcanzan',
#   'cantidad',
#   'imágenes',
#   'aproximadamente',
#   'encuentran',
#   'imágenes',
#   'pancromáticas',
#   'multiespectrales',
#   'resolución',
#   'espacial',
#   'metros',
#   'contabilizar',
#   'dos',
#   'satélites',
#   'permanecen',
#   'órbita',
#   'spot',
#   'satélite',
#   'spot',
#   'imágenes',
#   'pancromáticas',
#   'm',
#   'resolución',
#   'cubren',
#   'casi',
#   'territorio',
#   'nacional',
#   'lado',
#   'herramientas',
#   'diseñado',
#   'limitantes',
#   'ser',
#   'aplicadas',
#   'clasificación',
#   'coberturas',
#   'espectralmente',
#   'similares',
#   'obteniendo',
#   'resultados',
#   'clasificación',
#   'desventajas',
#   'algoritmos',
#   'comúnmente',
#   'empleados',
#   'clasificación',
#   'coberturas',
#   'involucran',
#   'información',
#   'espacial',
#   'objetos',
#   'clasificados',
#   'modelo',
#   'probabilístico',
#   'resulta',
#   'atractivo',
#   'dominio',
#   'embargo',
#   'objetos',
#   'imágenes',
#   'satelitáles',
#   'presentan',
#   'además',
#   'geometrías',
#   'características',
#   'estocásticas',
#   'información',
#   'considerar',
#   'incrementar',
#   'porcentajes',
#   'reconocimiento',
#   'último',
#   'algoritmo',
#   'aplicado',
#   'algún',
#   'tipo',
#   'cobertura',
#   'particular',
#   'obtener',
#   'clasificación',
#   'fina',
#   'podría',
#   'ser',
#   'extendido',
#   'tipos',
#   'cobertura',
#   'comportamiento'],
#  'Justificacion15': ['justificación',
#   'investigación',
#   'doctoral',
#   'fundamenta',
#   'siguientes',
#   'criterios',
#   'conveniencia',
#   'pretende',
#   'elevar',
#   'eficacia',
#   'enseñanza',
#   'provista',
#   'estudiante',
#   'través',
#   'sebw',
#   'ello',
#   'evalúan',
#   'experiencias',
#   'eligen',
#   'aquellas',
#   'supone',
#   'estimular',
#   'positivamente',
#   'aprendizaje',
#   'estudiante',
#   'mejor',
#   'manera',
#   'relevancia',
#   'social',
#   'busca',
#   'mejorar',
#   'aprendizaje',
#   'estudiante',
#   'personalizar',
#   'enseñanza',
#   'sebw',
#   'provee',
#   'fin',
#   'consideran',
#   'capacidades',
#   'cognitivas',
#   'preferencias',
#   'aprendizaje',
#   'ciertos',
#   'atributos',
#   'personalidad',
#   'estudiante',
#   'implicaciones',
#   'prácticas',
#   'procura',
#   'adecuar',
#   'enseñanza',
#   'cada',
#   'estudiante',
#   'base',
#   'variedades',
#   'contenido',
#   'secuencia',
#   'evaluación',
#   'disponibles',
#   'sebw',
#   'forma',
#   'promueve',
#   'paradigma',
#   'general',
#   'diversos',
#   'dominios',
#   'enseñanza',
#   'valor',
#   'teórico',
#   'concibe',
#   'proceso',
#   'enseñanzaaprendizaje',
#   'fenómeno',
#   'causaefecto',
#   'además',
#   'formular',
#   'modelo',
#   'causal',
#   'caracterizar',
#   'dicho',
#   'proceso',
#   'recolecta',
#   'evidencia',
#   'empírica',
#   'sustente',
#   'verificación',
#   'hipótesis',
#   'utilidad',
#   'métodológica',
#   'define',
#   'marco',
#   'trabajo',
#   'evaluar',
#   'conceptos',
#   'componen',
#   'modelo',
#   'estudiante',
#   'base',
#   'exámenes',
#   'psicológicos',
#   'emite',
#   'diagnóstico',
#   'individuo',
#   'acerca',
#   'personalidad',
#   'preferencias',
#   'aprendizaje',
#   'capacidades',
#   'cognitivas',
#   'consecuencias',
#   'investigación',
#   'busca',
#   'tratar',
#   'estudiante',
#   'forma',
#   'individualizada',
#   'bajo',
#   'precepto',
#   'impulsa',
#   'paradigma',
#   'servicio',
#   'alterno',
#   'tradicional',
#   'ofertado',
#   'educación',
#   'presencial',
#   'distancia',
#   'estudiantes',
#   'trata',
#   'distinción',
#   'viabilidad',
#   'desarrollo',
#   'investigación',
#   'comprobación',
#   'experimental',
#   'lleva',
#   'cabo',
#   'propio',
#   'dominio',
#   'educación',
#   'basada',
#   'web',
#   'comprobación',
#   'verificar',
#   'tesis',
#   'crea',
#   'prototipo',
#   'modelo',
#   'estudiante',
#   'basado',
#   'mapas',
#   'cognitivos',
#   'prototipo',
#   'forma',
#   'parte',
#   'sebw',
#   'provee',
#   'enseñanza',
#   'dominio',
#   'conocimiento',
#   'específico',
#   'muestra',
#   'voluntarios',
#   'muestra',
#   'organiza',
#   'dos',
#   'grupos',
#   'primer',
#   'grupo',
#   'recibe',
#   'soporte',
#   'modelo',
#   'estudiante',
#   'mientras',
#   'cuenta',
#   'respaldo',
#   'final',
#   'experimento',
#   'comparan',
#   'alcances',
#   'logrados',
#   'dos',
#   'grupos',
#   'identificar',
#   'ventaja',
#   'modelo'],
#  'Justificacion16': ['tomando',
#   'cuenta',
#   'revisión',
#   'hizo',
#   'arte',
#   'generalizando',
#   'problema',
#   'clasificación',
#   'tipo',
#   'dominios',
#   'diagnóstico',
#   'médico',
#   'justificación',
#   'siguiente',
#   'existe',
#   'necesidad',
#   'desarrollar',
#   'algoritmo',
#   'aprendizaje',
#   'inductivo',
#   'permita',
#   'resolver',
#   'problemas',
#   'clasificación',
#   'binaria',
#   'partir',
#   'conjuntos',
#   'datos',
#   'balanceados',
#   'alcanzando',
#   'consenso',
#   'apropiado',
#   'precisión',
#   'comprensibilidad',
#   'lado',
#   'extracción',
#   'conocimiento',
#   'útil',
#   'partir',
#   'conjuntos',
#   'datos',
#   'médicos',
#   'puede',
#   'ayudar',
#   'predecir',
#   'incidencia',
#   'algún',
#   'tipo',
#   'enfermedad',
#   'representaría',
#   'oportunidad',
#   'aplicar',
#   'tiempo',
#   'tratamiento',
#   'médico',
#   'capaz',
#   'evitar',
#   'eliminar',
#   'disminuir',
#   'cierto',
#   'grado',
#   'aparición'],
#  'Justificacion17': ['tesis',
#   'trata',
#   'planificación',
#   'sistemas',
#   'tiempo',
#   'real',
#   'utilizando',
#   'sistemas',
#   'multiprocesador',
#   'memoria',
#   'compartida',
#   'principal',
#   'motivación',
#   'iniciar',
#   'investigación',
#   'planificación',
#   'sistemas',
#   'tiempo',
#   'real',
#   'fundamentada',
#   'plan',
#   'estratégico',
#   'departamento',
#   'trabajo',
#   'departament',
#   'denginyeria',
#   'informtica',
#   'i',
#   'matemtiques',
#   'universitat',
#   'rovira',
#   'i',
#   'virgili',
#   'universidad',
#   'ubicada',
#   'entorno',
#   'geográfico',
#   'instalaciones',
#   'industriales',
#   'entornos',
#   'tiempo',
#   'real',
#   'críticos',
#   'abundan',
#   'refinerías',
#   'petróleo',
#   'industrias',
#   'petroquímicas',
#   'diversas',
#   'centrales',
#   'nucleares',
#   'etc',
#   'así',
#   'líneas',
#   'departamento',
#   'principalmente',
#   'enfocadas',
#   'tiemporeal',
#   'parte',
#   'docente',
#   'parte',
#   'investigadora',
#   'referente',
#   'planificación',
#   'sistemas',
#   'tiempo',
#   'real',
#   'teoría',
#   'sistemas',
#   'monoprocesador',
#   'consolidada',
#   'sistemas',
#   'distribuidos',
#   'abundante',
#   'bibliografía',
#   'sistemas',
#   'multiprocesador',
#   'memoria',
#   'compartida',
#   'principio',
#   'apenas',
#   'encontraban',
#   'referencias',
#   'debido',
#   'enormes',
#   'problemas',
#   'conlleva',
#   'praxis',
#   'utilizaba',
#   'multiprocesador',
#   'si',
#   'monoprocesadores',
#   'independientes',
#   'si',
#   'sistema',
#   'distribuido',
#   'recientemente',
#   'arquitecturas',
#   'multiprocesador',
#   'ido',
#   'popularizando',
#   'uso',
#   'va',
#   'ordenadores',
#   'personales',
#   'grandes',
#   'servidores',
#   'computadores',
#   'pasando',
#   'sistemas',
#   'empotrados',
#   'límites',
#   'actuales',
#   'hardware',
#   'fácil',
#   'menor',
#   'coste',
#   'incrementar',
#   'capacidad',
#   'cálculo',
#   'multiprocesador',
#   'realizarlo',
#   'sistemas',
#   'procesador',
#   'equivalente',
#   'capacidad',
#   'así',
#   'ido',
#   'apareciendo',
#   'diversos',
#   'chips',
#   'multicore',
#   'chiplevel',
#   'multiprocessors',
#   'cmp',
#   'fabricantes',
#   'procesadores',
#   'mayor',
#   'volumen',
#   'intel',
#   'amd',
#   'primero',
#   'lanzaron',
#   'mercado',
#   'chips',
#   'dos',
#   'procesadores',
#   'ejemplo',
#   'amd',
#   'athlon',
#   'x',
#   'intel',
#   'core',
#   'duo',
#   'actualidad',
#   'frecuentes',
#   'cuatro',
#   'procesadores',
#   'quadcore',
#   'amd',
#   'opteron',
#   'quadcore',
#   'intel',
#   'xeon',
#   'tabla',
#   'resumen',
#   'procesadores',
#   'multicore',
#   'actuales',
#   'aprecia',
#   'gran',
#   'evolución',
#   'últimos',
#   'años'],
#  'Justificacion18': ['evidencias',
#   'apoyan',
#   'propuesta',
#   'indexación',
#   'estudiado',
#   'unidades',
#   'óptimas',
#   'palabras',
#   'mientras',
#   'traducción',
#   'mejor',
#   'emplear',
#   'unidades',
#   'grandes',
#   'verdejo',
#   'et',
#   'uso',
#   'palabras',
#   'individuales',
#   'traducir',
#   'resuelve',
#   'problema',
#   'ambiguedad',
#   'semántica',
#   'estadística',
#   'coocurrencia',
#   'términos',
#   'permite',
#   'realizar',
#   'traducciones',
#   'fiables',
#   'ballesteros',
#   'and',
#   'croft',
#   'simple',
#   'utilización',
#   'diccionarios',
#   'aplicarla',
#   'sintagmas',
#   'nominales',
#   'va',
#   'mantener',
#   'característica',
#   'recordemos',
#   'sintagma',
#   'nominal',
#   'compone',
#   'varios',
#   'términos',
#   'utilización',
#   'sintagmas',
#   'nominales',
#   'contenido',
#   'semántico',
#   'claro',
#   'usuario',
#   'proporcionará',
#   'mejor',
#   'información',
#   'efectos',
#   'interacción',
#   'simple',
#   'uso',
#   'estadístico',
#   'coocurrencia',
#   'términos',
#   'próximos',
#   'hace',
#   'ballesteros',
#   'and',
#   'croft',
#   'diversos',
#   'estudios',
#   'penas',
#   'et',
#   'dennis',
#   'et',
#   'muestran',
#   'sintagmas',
#   'forma',
#   'natural',
#   'usuarios',
#   'refinar',
#   'consulta',
#   'representan',
#   'conceptos',
#   'forma',
#   'clara',
#   'mayor',
#   'contenido',
#   'semántico',
#   'términos',
#   'aislados',
#   'además',
#   'determinación',
#   'sintagmas',
#   'utilización',
#   'índices',
#   'puede',
#   'hacerse',
#   'manera',
#   'eficiente',
#   'penas'],
#  'Justificacion19': ['estructuras',
#   'metálicas',
#   'usadas',
#   'industria',
#   'transporte',
#   'tales',
#   'bastidores',
#   'pared',
#   'piso',
#   'vehículos',
#   'automotores',
#   'sometidas',
#   'cargas',
#   'cíclicas',
#   'vida',
#   'servicio',
#   'induciendo',
#   'aparición',
#   'grietas',
#   'fatiga',
#   'estructuras',
#   'soldadas',
#   'aleaciones',
#   'aluminio',
#   'tratables',
#   'térmicamente',
#   'riesgo',
#   'aparición',
#   'grieta',
#   'probable',
#   'debido',
#   'heterogeneidad',
#   'propiedades',
#   'mecánicas',
#   'zonas',
#   'comprenden',
#   'unión',
#   'anterior',
#   'surge',
#   'necesidad',
#   'realizar',
#   'uniones',
#   'experimentales',
#   'soldaduras',
#   'permitan',
#   'retardar',
#   'crecimiento',
#   'grietas',
#   'fatiga',
#   'uniones',
#   'soldadas',
#   'aleaciones',
#   'tipo',
#   'ello',
#   'establecen',
#   'estudios',
#   'comparativos',
#   'dos',
#   'procesos',
#   'unión',
#   'ejemplo',
#   'proceso',
#   'convencional',
#   'soldadura',
#   'arco',
#   'eléctrico',
#   'material',
#   'aporte',
#   'gas',
#   'protección',
#   'implementación',
#   'técnica',
#   'arco',
#   'eléctrico',
#   'indirecto',
#   'modificado',
#   'ello',
#   'busca',
#   'identificar',
#   'técnica',
#   'aplicación',
#   'soldadura',
#   'permita',
#   'incrementar',
#   'vida',
#   'fatiga',
#   'componentes'],
#  'Justificacion20': ['literatura',
#   'gran',
#   'diversidad',
#   'controladores',
#   'adaptativos',
#   'usan',
#   'redes',
#   'neuronales',
#   'embargo',
#   'importante',
#   'desarrollo',
#   'nuevos',
#   'controladores',
#   'mejor',
#   'desempeño',
#   'menor',
#   'tiempo',
#   'convergencia',
#   'confiables',
#   'sistemas',
#   'difíciles',
#   'modelar',
#   'dispone',
#   'modelo',
#   'dinámico',
#   'pueden',
#   'ser',
#   'objeto',
#   'estudio',
#   'usando',
#   'redes',
#   'neuronales',
#   'identificación',
#   'mismo',
#   'caso',
#   'incertidumbres',
#   'modelo',
#   'dinámico',
#   'dinámicas',
#   'modeladas',
#   'pueden',
#   'ser',
#   'aproximadas',
#   'redes',
#   'neuronales',
#   'control',
#   'neuronal',
#   'puede',
#   'aplicarse',
#   'sistemas',
#   'robóticos',
#   'industria',
#   'ayudaría',
#   'reducción',
#   'tiempos',
#   'procesos',
#   'productivos',
#   'reducción',
#   'mantenimiento',
#   'sistemas',
#   'robóticos',
#   'dado',
#   'dinámicas',
#   'sistemas',
#   'cambian',
#   'tiempo',
#   'debido',
#   'desgaste',
#   'mecanismos',
#   'factores',
#   'externos',
#   'adhesión',
#   'polvo',
#   'suciedad',
#   'control',
#   'neuronal',
#   'puede',
#   'usar',
#   'control',
#   'sistemas',
#   'humanorobóticos',
#   'finalidad',
#   'ayudar',
#   'personas',
#   'discapacidades',
#   'físicas',
#   'control',
#   'dinámicas',
#   'complejas',
#   'robots',
#   'bípedos',
#   'similares',
#   'investigación',
#   'puede',
#   'ser',
#   'usada',
#   'campo',
#   'educativo',
#   'referencia',
#   'investigaciones',
#   'área',
#   'control',
#   'neuronal',
#   'aplicada',
#   'mecanismos'],
#  'Justificacion21': ['ultimas',
#   'décadas',
#   'constatado',
#   'creciente',
#   'interés',
#   'presentan',
#   'robots',
#   'caminantes',
#   'punto',
#   'vista',
#   'investigación',
#   'básica',
#   'potenciales',
#   'aplicaciones',
#   'principales',
#   'características',
#   'robots',
#   'equipados',
#   'patas',
#   'capacidad',
#   'poder',
#   'desplazarse',
#   'amplia',
#   'variedad',
#   'terrenos',
#   'estructurados',
#   'particularidad',
#   'hace',
#   'atractivos',
#   'aplicación',
#   'practica',
#   'robots',
#   'servicios',
#   'requiere',
#   'locomoción',
#   'terreno',
#   'natural',
#   'caracteriza',
#   'presentar',
#   'superficies',
#   'irregulares',
#   'diversos',
#   'tipos',
#   'obstáculos',
#   'distintas',
#   'pendientes',
#   'embargo',
#   'caminar',
#   'terreno',
#   'natural',
#   'implica',
#   'geometría',
#   'propiedades',
#   'físicas',
#   'elementos',
#   'rodean',
#   'robot',
#   'desconocidas',
#   'variables',
#   'necesario',
#   'dotar',
#   'robot',
#   'estrategia',
#   'adapte',
#   'comportamiento',
#   'respecto',
#   'entorno',
#   'si',
#   'bien',
#   'modelo',
#   'robot',
#   'puede',
#   'ser',
#   'conocido',
#   'precisión',
#   'razonable',
#   'resulta',
#   'difícil',
#   'obtener',
#   'descripción',
#   'detallada',
#   'entorno',
#   'especialmente',
#   'respecta',
#   'propiedades',
#   'físicas',
#   'estabilidad',
#   'robots',
#   'caminantes',
#   'realización',
#   'ciclo',
#   'locomoción',
#   'gran',
#   'importancia',
#   'consideración',
#   'determinada',
#   'medida',
#   'estabilidad',
#   'locomoción',
#   'influye',
#   'manera',
#   'directa',
#   'seguridad',
#   'robot',
#   'trabajo',
#   'presenta',
#   'planteamiento',
#   'estrategias',
#   'adaptabilidad',
#   'robot',
#   'hexápodo',
#   'hexpiderix',
#   'basadas',
#   'modelo',
#   'geométrico',
#   'necesario',
#   'conocer',
#   'ambiente',
#   'pues',
#   'tan',
#   'solo',
#   'saber',
#   'extremidades',
#   'tocando',
#   'superficie',
#   'posible',
#   'estimar',
#   'plano',
#   'apoyo',
#   'documento',
#   'presenta',
#   'diseño',
#   'simulación',
#   'estrategias',
#   'adaptabilidad',
#   'robot',
#   'caminante',
#   'hexápodo',
#   'hexpiderix',
#   'basadas',
#   'modelo',
#   'geométrico',
#   'validación',
#   'cada',
#   'realiza',
#   'plano',
#   'distinto',
#   'grado',
#   'inclinación',
#   'además',
#   'analiza',
#   'estabilidad',
#   'estática',
#   'cada',
#   'postura',
#   'criterio',
#   'estabilidad',
#   'estático',
#   'normalizado',
#   'peso',
#   'sne',
#   'siglas',
#   'ingles'],
#  'Justificacion22': ['trabajo',
#   'tesis',
#   'desarrolla',
#   'debido',
#   'necesidad',
#   'sistema',
#   'completo',
#   'capaz',
#   'predecir',
#   'efectos',
#   'indeseables',
#   'memoria',
#   'pa',
#   'profundidad',
#   'memoria',
#   'órdenes',
#   'linealidad',
#   'variables',
#   'ello',
#   'desarrollan',
#   'modelos',
#   'polinomiales',
#   'basados',
#   'truncaciones',
#   'series',
#   'volterra',
#   'wiener',
#   'hammerstein',
#   'mpm',
#   'además',
#   'utilizar',
#   'técnicas',
#   'aprendizaje',
#   'ann',
#   'anfis',
#   'dentro',
#   'tarjeta',
#   'desarrollo',
#   'fpgadsp',
#   'técnica',
#   'medición',
#   'bajo',
#   'costo',
#   'curvas',
#   'distorsión',
#   'amplitud',
#   'fase',
#   'sistema',
#   'controlado',
#   'interfaz',
#   'gráfica',
#   'usuario',
#   'gui',
#   'permite',
#   'manera',
#   'simple',
#   'abrir',
#   'mediciones',
#   'reales',
#   'cualquier',
#   'pa',
#   'basado',
#   'curvas',
#   'distorsión',
#   'amam',
#   'ampm',
#   'obtener',
#   'coeficientes',
#   'respectivos',
#   'mpm',
#   'obtenidos',
#   'través',
#   'método',
#   'error',
#   'cuadrático',
#   'mínimo',
#   'lse',
#   'sistema',
#   'niveles',
#   'variables',
#   'memoria',
#   'órdenes',
#   'linealidad',
#   'variables',
#   'adecuarse',
#   'comportamiento',
#   'pa',
#   'parte',
#   'principal',
#   'trabajo',
#   'basada',
#   'herramienta',
#   'diseño',
#   'dsp',
#   'builder',
#   'permite',
#   'traducir',
#   'programa',
#   'sistema',
#   'matlabsimulink',
#   'vhdl',
#   'ahorrando',
#   'tiempo',
#   'diseño',
#   'parte',
#   'final',
#   'realiza',
#   'comparación',
#   'modelado',
#   'través',
#   'vhdl',
#   'puro',
#   'modelado',
#   'obtenido',
#   'través',
#   'ann',
#   'anfis',
#   'ventaja',
#   'utilizar',
#   'sistema',
#   'simulación',
#   'uso',
#   'algoritmos',
#   'etapas',
#   'linealización',
#   'posteriores',
#   'trabajos',
#   'desarrollados',
#   'autor',
#   'probó',
#   'eficiencia',
#   'modelos',
#   'través',
#   'fpga'],
#  'Justificacion23': ['existen',
#   'elementos',
#   'estructurales',
#   'mecánicos',
#   'utilizados',
#   'ingeniería',
#   'estructuras',
#   'chasis',
#   'autos',
#   'componentes',
#   'aéreos',
#   'estructuras',
#   'marinas',
#   'válvulas',
#   'etc',
#   'fabricados',
#   'aleación',
#   'aluminio',
#   't',
#   'fabricación',
#   'dichos',
#   'elementos',
#   'requieren',
#   'procesos',
#   'unión',
#   'soldadura',
#   'soldadura',
#   'proceso',
#   'metalúrgico',
#   'requiere',
#   'entendimiento',
#   'comportamiento',
#   'material',
#   'producción',
#   'mayoría',
#   'procesos',
#   'soldadura',
#   'igual',
#   'fundición',
#   'metales',
#   'requieren',
#   'altas',
#   'temperaturas',
#   'hacer',
#   'posible',
#   'unión',
#   'materiales',
#   'involucrados',
#   'aleación',
#   'aluminio',
#   't',
#   'presenta',
#   'degradación',
#   'propiedades',
#   'mecánicas',
#   'debido',
#   'efecto',
#   'térmico',
#   'proceso',
#   'soldadura',
#   'además',
#   'alta',
#   'solubilidad',
#   'hidrógeno',
#   'aluminio',
#   'líquido',
#   'ocurre',
#   'proceso',
#   'solidificación',
#   'queda',
#   'atrapado',
#   'generando',
#   'porosidad',
#   'material',
#   'sabe',
#   'posible',
#   'reducir',
#   'efecto',
#   'térmico',
#   'técnica',
#   'aeim',
#   'utilizar',
#   'solo',
#   'paso',
#   'soldadura',
#   'reduce',
#   'efecto',
#   'microestructura',
#   'final',
#   'caso',
#   'aleación',
#   'unir',
#   'encuentra',
#   'solubilización',
#   'envejecido',
#   'artificial',
#   't',
#   'alcanza',
#   'temperaturas',
#   'elevadas',
#   'obtiene',
#   'sobreenvejecido',
#   'aleación',
#   'disminuye',
#   'propiedades',
#   'mecánicas',
#   'embargo',
#   'tratamiento',
#   'térmico',
#   't',
#   'proceso',
#   'reversible',
#   'puede',
#   'considerar',
#   'alternativa',
#   'mejorar',
#   'propiedades',
#   'mecánicas',
#   'uniones',
#   'aluminio',
#   'soldadas',
#   'tratamiento',
#   'térmico',
#   'postsoldadura',
#   'mejora',
#   'propiedades',
#   'mecánicas',
#   'uniones',
#   'aluminio',
#   'soldadas',
#   'aprecia',
#   'incremento',
#   'resistencia',
#   'fatiga',
#   'elementos',
#   'estructurales',
#   'sometidos',
#   'cargas',
#   'cíclicas',
#   'incrementar',
#   'resistencia',
#   'fatiga',
#   'retarda',
#   'aparición',
#   'grietas',
#   'fatiga',
#   'anterior',
#   'surge',
#   'necesidad',
#   'hacer',
#   'uniones',
#   'soldadas',
#   'permitan',
#   'aumentar',
#   'resistencia',
#   'fatiga',
#   'retardar',
#   'crecimiento',
#   'grietas',
#   'fatiga',
#   'aleaciones',
#   'tipo',
#   'implementación',
#   'técnica',
#   'aeim',
#   'tratamiento',
#   'térmico'],
#  'Justificacion24': ['sensores',
#   'basados',
#   'fibra',
#   'óptica',
#   'ofrecen',
#   'ventajas',
#   'sensores',
#   'tradicionales',
#   'tales',
#   'inmunidad',
#   'interferencias',
#   'electromagnéticas',
#   'ultraligeros',
#   'pueden',
#   'ser',
#   'empleados',
#   'ambientes',
#   'altamente',
#   'corrosivos',
#   'explosivos',
#   'uso',
#   'aplicaciones',
#   'sensado',
#   'remoto',
#   'factible',
#   'debido',
#   'bajas',
#   'pérdidas',
#   'señal',
#   'fibras',
#   'ópticas'],
#  'Justificacion25': ['ltimos',
#   'aos',
#   'dedicado',
#   'considerable',
#   'esfuerzo',
#   'problema',
#   'segmentacin',
#   'color',
#   'imgenes',
#   'digitales',
#   'dada',
#   'importancia',
#   'potencial',
#   'hace',
#   'mayora',
#   'enfoques',
#   'publicados',
#   'segmentacin',
#   'color',
#   'basaba',
#   'tcnicas',
#   'monocromticas',
#   'aplicadas',
#   'cada',
#   'componente',
#   'color',
#   'imagen',
#   'diferentes',
#   'espacios',
#   'color',
#   'rgb',
#   'u',
#   'diferentes',
#   'formas',
#   'producir',
#   'composicin',
#   'enfoques',
#   'problema',
#   'inherente',
#   'prdida',
#   'significativa',
#   'informacin',
#   'color',
#   'proceso']}

# %% [markdown]
# ## Select a specific number of vectors to work with

# %%
TSU_structured = getNVector(len(TSU_structured), TSU_structured)
Lic_structured = getNVector(len(Lic_structured), Lic_structured)
Masters_structured = getNVector(len(Masters_structured), Masters_structured)
Phd_structured = getNVector(len(Phd_structured), Phd_structured)

len(TSU_structured)
len(Lic_structured)
len(Masters_structured)
len(Phd_structured)
# Out:
# 24

# %% [markdown]
# ## Divide our data in eighty and twenty percent (This in order to have some experimental data)

# %%
twenty_TSU, eighty_TSU = divideEightyTwenty(TSU_structured)
twenty_Lic, eighty_Lic = divideEightyTwenty(Lic_structured)
twenty_Masters, eighty_Masters = divideEightyTwenty(Masters_structured)
twenty_Phd, eighty_Phd = divideEightyTwenty(Phd_structured)

len(twenty_TSU)
len(eighty_TSU)
len(twenty_Lic)
len(eighty_Lic)
len(twenty_Masters)
len(eighty_Masters)
len(twenty_Phd)
len(eighty_Phd)
# Out:
# 19

# %% [markdown]
# ## Obtain the Relative Frequency

# %%
twentyRFTSU = relFreq(twenty_TSU)
eightyRFTSU = relFreq(eighty_TSU)
twentyRFLic = relFreq(twenty_Lic)
eightyRFLic = relFreq(eighty_Lic)
twentyRFMasters = relFreq(twenty_Masters)
eightyRFMasters = relFreq(eighty_Masters)
twentyRFPhd = relFreq(twenty_Phd)
eightyRFPhd = relFreq(eighty_Phd)

len(twentyRFTSU)
len(eightyRFTSU)
len(twentyRFLic)
len(eightyRFLic)
len(twentyRFMasters)
len(eightyRFMasters)
len(twentyRFPhd)
len(eightyRFPhd)
# Out:
# 19

# %% [markdown]
# ## Most Common Spanish Words

# %%
mostCommonDic = mostCommon()
mostCommonDic
# Out:
# {'Frec.absoluta': 'Frec.normalizada',
#  'de': '9999518',
#  'la': '6277560',
#  'que': '4681839',
#  'el': '4569652',
#  'en': '4234281',
#  'y': '4180279',
#  'a': '3260939',
#  'los': '2618657',
#  'se': '2022514',
#  'del': '1857225',
#  'las': '1686741',
#  'un': '1659827',
#  'por': '1561904',
#  'con': '1481607',
#  'no': '1465503',
#  'una': '1347603',
#  'su': '1103617',
#  'para': '1062152',
#  'es': '1019669',
#  'al': '951054',
#  'lo': '866955',
#  'como': '773465',
#  'más': '661696',
#  'o': '542284',
#  'pero': '450512',
#  'sus': '449870',
#  'le': '413241',
#  'ha': '380339',
#  'me': '374368',
#  'si': '327480',
#  'sin': '298383',
#  'sobre': '289704',
#  'este': '285461',
#  'ya': '274177',
#  'entre': '267493',
#  'cuando': '257272',
#  'todo': '247340',
#  'esta': '238841',
#  'ser': '232924',
#  'son': '232415',
#  'dos': '228439',
#  'también': '227411',
#  'fue': '223791',
#  'había': '223430',
#  'era': '219933',
#  'muy': '208540',
#  'años': '203027',
#  'hasta': '202935',
#  'desde': '198647',
#  'está': '194168',
#  'mi': '186360',
#  'porque': '185700',
#  'qué': '184956',
#  'sólo': '170552',
#  'han': '169718',
#  'yo': '167684',
#  'hay': '164940',
#  'vez': '163538',
#  'puede': '161219',
#  'todos': '158168',
#  'así': '155645',
#  'nos': '154412',
#  'ni': '153451',
#  'parte': '148750',
#  'tiene': '147274',
#  'él': '139080',
#  'uno': '136020',
#  'donde': '132077',
#  'bien': '130957',
#  'tiempo': '130896',
#  'mismo': '130746',
#  'ese': '127976',
#  'ahora': '125661',
#  'cada': '124558',
#  'e': '123729',
#  'vida': '123491',
#  'otro': '121983',
#  'después': '121746',
#  'te': '120052',
#  'otros': '119500',
#  'aunque': '115556',
#  'esa': '115377',
#  'eso': '114523',
#  'hace': '114507',
#  'otra': '113982',
#  'gobierno': '113011',
#  'tan': '112471',
#  'durante': '112020',
#  'siempre': '111557',
#  'día': '110921',
#  'tanto': '110679',
#  'ella': '110620',
#  'tres': '109542',
#  'sí': '108631',
#  'dijo': '108471',
#  'sido': '107352',
#  'gran': '106991',
#  'país': '104568',
#  'según': '104204',
#  'menos': '103498',
#  'mundo': '101745',
#  'año': '100790',
#  'antes': '100761',
#  'estado': '100757',
#  'contra': '100403',
#  'sino': '98145',
#  'forma': '97165',
#  'caso': '96979',
#  'nada': '96340',
#  'hacer': '96063',
#  'general': '95768',
#  'estaba': '93607',
#  'poco': '92205',
#  'estos': '91398',
#  'presidente': '91350',
#  'mayor': '90166',
#  'ante': '87990',
#  'unos': '86747',
#  'les': '86363',
#  'algo': '85999',
#  'hacia': '85122',
#  'casa': '85064',
#  'ellos': '84636',
#  'ayer': '84310',
#  'hecho': '83898',
#  'primera': '83428',
#  'mucho': '83240',
#  'mientras': '82630',
#  'además': '82576',
#  'quien': '82555',
#  'momento': '82132',
#  'millones': '81999',
#  'esto': '81979',
#  'españa': '80195',
#  'hombre': '80152',
#  'están': '79844',
#  'pues': '79642',
#  'hoy': '78479',
#  'lugar': '78250',
#  'madrid': '77837',
#  'nacional': '77541',
#  'trabajo': '77478',
#  'otras': '77428',
#  'mejor': '77315',
#  'nuevo': '77262',
#  'decir': '76867',
#  'algunos': '76107',
#  'entonces': '75706',
#  'todas': '75517',
#  'días': '75144',
#  'debe': '74229',
#  'política': '73464',
#  'cómo': '73100',
#  'casi': '72965',
#  'toda': '72248',
#  'tal': '71419',
#  'luego': '70522',
#  'pasado': '70484',
#  'primer': '69918',
#  'medio': '69273',
#  'va': '69098',
#  'estas': '69071',
#  'sea': '68921',
#  'tenía': '67093',
#  'nunca': '66939',
#  'poder': '66900',
#  'aquí': '66821',
#  'ver': '66479',
#  'veces': '66441',
#  'embargo': '66116',
#  'partido': '65492',
#  'personas': '65410',
#  'grupo': '65390',
#  'cuenta': '65368',
#  'pueden': '63889',
#  'tienen': '63652',
#  'misma': '63462',
#  'nueva': '63427',
#  'cual': '62309',
#  'fueron': '62220',
#  'mujer': '61936',
#  'frente': '61469',
#  'josé': '61080',
#  'tras': '60064',
#  'cosas': '59580',
#  'fin': '59108',
#  'ciudad': '59049',
#  'he': '58965',
#  'social': '58484',
#  'manera': '58134',
#  'tener': '58029',
#  'sistema': '57810',
#  'será': '57808',
#  'historia': '57791',
#  'muchos': '57523',
#  'juan': '57204',
#  'tipo': '56606',
#  'cuatro': '56570',
#  'dentro': '56565',
#  'nuestro': '56307',
#  'punto': '56259',
#  'dice': '56253',
#  'ello': '55768',
#  'cualquier': '55361',
#  'noche': '55281',
#  'aún': '54761',
#  'agua': '54702',
#  'parece': '54554',
#  'haber': '54150',
#  'situación': '54020',
#  'fuera': '53979',
#  'bajo': '53243',
#  'grandes': '52362',
#  'nuestra': '52321',
#  'ejemplo': '51803',
#  'acuerdo': '51485',
#  'habían': '50397',
#  'usted': '50073',
#  'estados': '49814',
#  'hizo': '49733',
#  'nadie': '49689',
#  'países': '49445',
#  'horas': '49389',
#  'posible': '49082',
#  'tarde': '48963',
#  'ley': '48945',
#  'importante': '48397',
#  'guerra': '48391',
#  'desarrollo': '48378',
#  'proceso': '48064',
#  'realidad': '47650',
#  'sentido': '47559',
#  'lado': '47315',
#  'mí': '47248',
#  'tu': '47057',
#  'cambio': '46814',
#  'allí': '46771',
#  'mano': '46657',
#  'eran': '46367',
#  'estar': '46282',
#  'san': '46004',
#  'número': '45985',
#  'sociedad': '45974',
#  'unas': '45565',
#  'centro': '45456',
#  'padre': '45236',
#  'gente': '45235',
#  'final': '44920',
#  'relación': '44617',
#  'cuerpo': '44470',
#  'obra': '44308',
#  'incluso': '44285',
#  'través': '44212',
#  'último': '44086',
#  'madre': '43697',
#  'mis': '43564',
#  'modo': '43478',
#  'problemas': '43295',
#  'cinco': '43283',
#  'carlos': '42834',
#  'hombres': '42544',
#  'información': '42423',
#  'ojos': '42371',
#  'muerte': '42341',
#  'nombre': '42284',
#  'algunas': '42223',
#  'público': '42201',
#  'mujeres': '42094',
#  'siglo': '41890',
#  'todavía': '41792',
#  'meses': '41650',
#  'mañana': '41368',
#  'esos': '41184',
#  'nosotros': '40870',
#  'hora': '40581',
#  'muchas': '40566',
#  'pueblo': '40425',
#  'alguna': '40406',
#  'dar': '40396',
#  'problema': '40295',
#  'don': '40224',
#  'da': '40191',
#  'tú': '40119',
#  'derecho': '39939',
#  'verdad': '39924',
#  'maría': '39812',
#  'unidos': '39806',
#  'podría': '39797',
#  'sería': '39731',
#  'junto': '39521',
#  'cabeza': '39451',
#  'aquel': '39377',
#  'luis': '39370',
#  'cuanto': '38519',
#  'tierra': '38352',
#  'equipo': '38214',
#  'segundo': '38160',
#  'director': '38096',
#  'dicho': '38074',
#  'cierto': '37979',
#  'casos': '37796',
#  'manos': '37736',
#  'nivel': '37419',
#  'podía': '37403',
#  'familia': '37376',
#  'largo': '37315',
#  'partir': '37278',
#  'falta': '37196',
#  'llegar': '37054',
#  'propio': '36979',
#  'ministro': '36337',
#  'cosa': '36267',
#  'primero': '36232',
#  'seguridad': '36054',
#  'hemos': '35988',
#  'mal': '35964',
#  'trata': '35744',
#  'algún': '35564',
#  'tuvo': '35490',
#  'respecto': '35394',
#  'semana': '35354',
#  'varios': '35315',
#  'real': '35222',
#  'sé': '35154',
#  'voz': '34982',
#  'paso': '34921',
#  'señor': '34905',
#  'mil': '34834',
#  'quienes': '34743',
#  'proyecto': '34716',
#  'mercado': '34677',
#  'mayoría': '34634',
#  'luz': '34617',
#  'claro': '34589',
#  'iba': '34380',
#  'éste': '34338',
#  'pesetas': '34204',
#  'orden': '33982',
#  'español': '33920',
#  'buena': '33759',
#  'quiere': '33735',
#  'aquella': '33723',
#  'programa': '33620',
#  'palabras': '33485',
#  'internacional': '33448',
#  'van': '33398',
#  'esas': '33382',
#  'segunda': '33363',
#  'empresa': '33301',
#  'puesto': '33254',
#  'ahí': '33248',
#  'propia': '33149',
#  'm': '33099',
#  'libro': '33056',
#  'igual': '32950',
#  'político': '32928',
#  'persona': '32756',
#  'últimos': '32689',
#  'ellas': '32635',
#  'total': '32539',
#  'creo': '32504',
#  'tengo': '32413',
#  'dios': '32373',
#  'c': '32345',
#  'española': '32140',
#  'condiciones': '32094',
#  'méxico': '32084',
#  'fuerza': '32082',
#  'solo': '32010',
#  'único': '31999',
#  'acción': '31789',
#  'amor': '31690',
#  'policía': '31598',
#  'puerta': '31503',
#  'pesar': '31436',
#  'zona': '31365',
#  'sabe': '31358',
#  'calle': '31330',
#  'interior': '31198',
#  'tampoco': '31014',
#  'música': '30968',
#  'ningún': '30962',
#  'vista': '30952',
#  'campo': '30775',
#  'buen': '30756',
#  'hubiera': '30754',
#  'saber': '30644',
#  'obras': '30575',
#  'razón': '30539',
#  'ex': '30522',
#  'niños': '30449',
#  'presencia': '30426',
#  'tema': '30398',
#  'dinero': '30386',
#  'comisión': '30350',
#  'antonio': '30339',
#  'servicio': '30318',
#  'hijo': '30298',
#  'última': '30269',
#  'ciento': '30146',
#  'estoy': '30136',
#  'hablar': '30127',
#  'dio': '30123',
#  'minutos': '30012',
#  'producción': '29875',
#  'camino': '29830',
#  'seis': '29812',
#  'quién': '29760',
#  'fondo': '29750',
#  'dirección': '29708',
#  'papel': '29702',
#  'demás': '29623',
#  'barcelona': '29613',
#  'idea': '29613',
#  'especial': '29458',
#  'diferentes': '29378',
#  'dado': '29292',
#  'base': '29243',
#  'capital': '29220',
#  'ambos': '29178',
#  'europa': '29171',
#  'libertad': '29119',
#  'relaciones': '29055',
#  'espacio': '28844',
#  'medios': '28828',
#  'ir': '28757',
#  'actual': '28719',
#  'población': '28668',
#  'empresas': '28653',
#  'estudio': '28640',
#  'salud': '28630',
#  'servicios': '28547',
#  'haya': '28528',
#  'principio': '28476',
#  'siendo': '28468',
#  'cultura': '28382',
#  'anterior': '28310',
#  'alto': '28306',
#  'media': '28292',
#  'mediante': '28252',
#  'primeros': '28193',
#  'arte': '28165',
#  'paz': '28159',
#  'sector': '28156',
#  'imagen': '28109',
#  'medida': '28101',
#  'deben': '28008',
#  'datos': '28003',
#  'consejo': '27968',
#  'personal': '27930',
#  'interés': '27919',
#  'julio': '27919',
#  'grupos': '27863',
#  'miembros': '27843',
#  'ninguna': '27822',
#  'existe': '27779',
#  'cara': '27756',
#  'edad': '27731',
#  'etc': '27709',
#  'movimiento': '27696',
#  'visto': '27677',
#  'llegó': '27556',
#  'puntos': '27488',
#  'actividad': '27283',
#  'bueno': '27256',
#  'uso': '27235',
#  'niño': '27157',
#  'difícil': '27109',
#  'joven': '27024',
#  'futuro': '26989',
#  'aquellos': '26975',
#  'mes': '26958',
#  'pronto': '26934',
#  'soy': '26903',
#  'hacía': '26850',
#  'nuevos': '26828',
#  'nuestros': '26789',
#  'estaban': '26694',
#  'posibilidad': '26611',
#  'sigue': '26580',
#  'cerca': '26495',
#  'resultados': '26413',
#  'educación': '26327',
#  'atención': '26299',
#  'gonzález': '26281',
#  'capacidad': '26228',
#  'efecto': '26209',
#  'necesario': '26149',
#  'valor': '26106',
#  'aire': '26060',
#  'investigación': '26001',
#  'siguiente': '25891',
#  'figura': '25859',
#  'central': '25780',
#  'comunidad': '25745',
#  'necesidad': '25699',
#  'serie': '25677',
#  'organización': '25647',
#  'nuevas': '25638',
#  'calidad': '25597',
#  'economía': '25553',
#  'carácter': '25528',
#  'jefe': '25526',
#  'estamos': '25495',
#  'prensa': '25472',
#  'control': '25219',
#  'sociales': '25197',
#  'universidad': '25155',
#  'militar': '25150',
#  'cabo': '25125',
#  'diez': '25114',
#  'fuerzas': '25106',
#  'congreso': '25073',
#  'ésta': '25041',
#  'hijos': '24995',
#  'justicia': '24983',
#  'mundial': '24963',
#  'dólares': '24939',
#  'juego': '24922',
#  'económica': '24845',
#  'políticos': '24824',
#  'duda': '24821',
#  'recursos': '24800',
#  'pública': '24775',
#  'crisis': '24760',
#  'próximo': '24728',
#  'tenemos': '24716',
#  'decisión': '24685',
#  'varias': '24657',
#  'popular': '24543',
#  'tenido': '24472',
#  'apenas': '24440',
#  'época': '24358',
#  'banco': '24341',
#  'presente': '24211',
#  'menor': '24142',
#  'quiero': '24054',
#  'pasar': '24048',
#  'resultado': '24030',
#  'televisión': '23938',
#  'encuentra': '23833',
#  'gracias': '23794',
#  'ministerio': '23781',
#  'conjunto': '23735',
#  'defensa': '23717',
#  'alguien': '23626',
#  'queda': '23600',
#  'hacen': '23508',
#  'pasa': '23503',
#  'resto': '23366',
#  'causa': '23283',
#  'seguir': '23261',
#  'allá': '23155',
#  'palabra': '23090',
#  'voy': '23067',
#  'cuya': '23048',
#  'vamos': '23036',
#  'mar': '23022',
#  'estudios': '23011',
#  'derechos': '22989',
#  'importancia': '22969',
#  'cuales': '22961',
#  'contrario': '22957',
#  'manuel': '22924',
#  'garcía': '22851',
#  'fuerte': '22828',
#  'sol': '22823',
#  'jóvenes': '22791',
#  'apoyo': '22776',
#  'habría': '22760',
#  'civil': '22758',
#  'miguel': '22755',
#  'pedro': '22738',
#  'partidos': '22728',
#  'libre': '22640',
#  'fuentes': '22592',
#  'administración': '22536',
#  'común': '22536',
#  'dejar': '22499',
#  'cine': '22492',
#  'salir': '22447',
#  'comunicación': '22434',
#  'b': '22407',
#  'experiencia': '22402',
#  'demasiado': '22378',
#  'plan': '22279',
#  'respuesta': '22259',
#  'energía': '22241',
#  'izquierda': '22232',
#  'función': '22148',
#  'principal': '22074',
#  'superior': '22014',
#  'naturaleza': '22002',
#  'podemos': '21958',
#  'unión': '21933',
#  'especialmente': '21931',
#  'rey': '21907',
#  'domingo': '21823',
#  'favor': '21818',
#  'cantidad': '21812',
#  'elecciones': '21781',
#  'clase': '21733',
#  'productos': '21731',
#  'españoles': '21693',
#  'conocer': '21681',
#  'teatro': '21663',
#  'importantes': '21597',
#  'evitar': '21587',
#  'color': '21575',
#  'actividades': '21564',
#  'mesa': '21558',
#  'p': '21518',
#  'decía': '21458',
#  'cuyo': '21444',
#  'debido': '21378',
#  'alta': '21377',
#  'francisco': '21361',
#  'secretario': '21351',
#  'objeto': '21336',
#  'quizá': '21323',
#  'posición': '21168',
#  'parecía': '21152',
#  'natural': '21146',
#  'elementos': '21133',
#  'hubo': '21112',
#  'objetivo': '21097',
#  'formas': '21083',
#  'única': '21076',
#  'pueda': '21061',
#  'origen': '21055',
#  'blanco': '21035',
#  'mismos': '21006',
#  'lleva': '20947',
#  'económico': '20927',
#  'opinión': '20927',
#  'ayuda': '20918',
#  'oficial': '20905',
#  'silencio': '20896',
#  'buenos': '20881',
#  'pensar': '20880',
#  'república': '20854',
#  'dónde': '20846',
#  'sangre': '20798',
#  'encuentro': '20719',
#  'siquiera': '20708',
#  'autor': '20676',
#  'reunión': '20609',
#  'haciendo': '20582',
#  'suelo': '20565',
#  'muestra': '20563',
#  'viejo': '20558',
#  'encima': '20522',
#  'resulta': '20497',
#  'tomar': '20492',
#  'bastante': '20488',
#  'siete': '20483',
#  'lucha': '20434',
#  'pudo': '20404',
#  'amigos': '20369',
#  'línea': '20338',
#  'sur': '20334',
#  'pocos': '20289',
#  'medidas': '20225',
#  'norte': '20173',
#  'partes': '20137',
#  'iglesia': '20101',
#  'tratamiento': '20030',
#  'existencia': '19997',
#  'cargo': '19935',
#  'grande': '19882',
#  'américa': '19874',
#  'boca': '19829',
#  'plaza': '19792',
#  'pie': '19780',
#  'trabajadores': '19723',
#  'poner': '19722',
#  'existen': '19634',
#  'viene': '19630',
#  'permite': '19607',
#  'análisis': '19554',
#  'argentina': '19553',
#  'acto': '19520',
#  'hechos': '19465',
#  'tiempos': '19394',
#  'políticas': '19285',
#  'radio': '19271',
#  'puedo': '19230',
#  'crecimiento': '19202',
#  'francia': '19193',
#  'compañía': '19178',
#  'amigo': '19176',
#  'autoridades': '19175',
#  'realizar': '19166',
#  'acciones': '19075',
#  'padres': '19075',
#  'diario': '19064',
#  've': '19059',
#  'derecha': '19049',
#  'ambiente': '19000',
#  'i': '18980',
#  'habrá': '18951',
#  'precisamente': '18930',
#  'enfermedad': '18927',
#  'especie': '18903',
#  'ejército': '18900',
#  'santa': '18890',
#  'cambios': '18886',
#  'río': '18885',
#  'sabía': '18873',
#  'seguro': '18856',
#  'espera': '18850',
#  'momentos': '18847',
#  'viaje': '18834',
#  'quería': '18827',
#  'ocho': '18818',
#  'vivir': '18817',
#  'región': '18771',
#  'formación': '18743',
#  'escuela': '18722',
#  'cuarto': '18721',
#  'valores': '18677',
#  'quedó': '18674',
#  'participación': '18598',
#  'éxito': '18595',
#  'baja': '18542',
#  'artículo': '18504',
#  'principales': '18490',
#  'fernando': '18468',
#  'metros': '18468',
#  'marcha': '18427',
#  'régimen': '18382',
#  'consecuencia': '18358',
#  'conocimiento': '18346',
#  'corazón': '18331',
#  'campaña': '18261',
#  'estructura': '18261',
#  'efectos': '18253',
#  'finalmente': '18231',
#  'modelo': '18221',
#  'carta': '18218',
#  'construcción': '18098',
#  'médico': '18083',
#  'miedo': '18049',
#  'mayores': '17976',
#  'entrada': '17955',
#  'humanos': '17917',
#  'sean': '17892',
#  'actitud': '17843',
#  'deja': '17838',
#  'dejó': '17827',
#  'd': '17810',
#  'llevar': '17798',
#  'negro': '17774',
#  'texto': '17714',
#  'mitad': '17705',
#  'estuvo': '17681',
#  'alrededor': '17639',
#  'acerca': '17598',
#  'peso': '17589',
#  'humano': '17581',
#  'pequeño': '17577',
#  'fecha': '17551',
#  'serán': '17529',
#  'doctor': '17526',
#  'ideas': '17495',
#  'vino': '17491',
#  'materia': '17468',
#  'llega': '17456',
#  'carrera': '17451',
#  'cierta': '17389',
#  'sola': '17362',
#  'psoe': '17360',
#  'lejos': '17339',
#  'juez': '17328',
#  'características': '17307',
#  'riesgo': '17271',
#  'fácil': '17205',
#  'diferencia': '17178',
#  'cultural': '17164',
#  'libros': '17146',
#  'práctica': '17142',
#  'mayo': '17123',
#  'nuestras': '17121',
#  'programas': '17118',
#  'memoria': '17083',
#  'llegado': '17052',
#  'plazo': '16976',
#  'expresión': '16966',
#  'diciembre': '16954',
#  'mantener': '16948',
#  'enero': '16929',
#  'volver': '16898',
#  'cuadro': '16891',
#  'producto': '16851',
#  'produce': '16845',
#  'europea': '16842',
#  'conciencia': '16829',
#  'tenían': '16811',
#  'atrás': '16786',
#  'felipe': '16782',
#  'creación': '16777',
#  'chile': '16768',
#  'precio': '16767',
#  'película': '16761',
#  'puerto': '16749',
#  'fuego': '16685',
#  'cuestión': '16666',
#  'pasó': '16644',
#  'costa': '16638',
#  'supuesto': '16637',
#  'local': '16607',
#  'habla': '16597',
#  'aspectos': '16569',
#  'cuba': '16565',
#  'sala': '16524',
#  'cámara': '16523',
#  'vuelta': '16521',
#  'vía': '16508',
#  'mirada': '16481',
#  'mejores': '16443',
#  'informe': '16436',
#  'unidad': '16427',
#  'distintos': '16415',
#  'suerte': '16390',
#  'tales': '16386',
#  'mira': '16334',
#  'llamado': '16312',
#  'técnica': '16308',
#  'título': '16308',
#  's': '16293',
#  'principios': '16282',
#  'octubre': '16228',
#  'volvió': '16207',
#  'período': '16199',
#  'g': '16194',
#  'encontrar': '16166',
#  'democracia': '16159',
#  'aumento': '16145',
#  'fútbol': '16137',
#  'prueba': '16113',
#  'consumo': '16095',
#  'pese': '16043',
#  'ocasiones': '16026',
#  'exterior': '15988',
#  'solución': '15967',
#  'u': '15967',
#  'hija': '15958',
#  'sueño': '15944',
#  'parís': '15929',
#  'capaz': '15925',
#  'ocasión': '15924',
#  'industria': '15902',
#  'adelante': '15900',
#  'salida': '15899',
#  'ciencia': '15885',
#  'asunto': '15844',
#  'asociación': '15835',
#  'puso': '15831',
#  'intereses': '15830',
#  'oro': '15811',
#  'podrá': '15804',
#  'pregunta': '15741',
#  'oposición': '15736',
#  'entrar': '15711',
#  'señora': '15705',
#  'señaló': '15699',
#  'santiago': '15697',
#  'dolor': '15685',
#  'zonas': '15679',
#  'comercio': '15637',
#  'operación': '15633',
#  'tribunal': '15609',
#  'instituciones': '15606',
#  'temas': '15569',
#  'militares': '15566',
#  'junio': '15555',
#  'marco': '15548',
#  'sectores': '15541',
#  'hacerlo': '15539',
#  'aspecto': '15528',
#  'razones': '15527',
#  'contenido': '15481',
#  'juicio': '15481',
#  'electoral': '15465',
#  'considera': '15460',
#  'tendrá': '15431',
#  'mucha': '15397',
#  'voluntad': '15394',
#  'dicen': '15383',
#  'recuerdo': '15382',
#  'socialista': '15371',
#  'área': '15369',
#  'aparece': '15367',
#  'vio': '15334',
#  'cama': '15328',
#  'aun': '15317',
#  'presenta': '15315',
#  'pp': '15293',
#  'revolución': '15285',
#  'busca': '15280',
#  'abril': '15278',
#  'rodríguez': '15272',
#  'fiscal': '15265',
#  'lópez': '15245',
#  'victoria': '15241',
#  'violencia': '15235',
#  'primeras': '15226',
#  'pequeña': '15214',
#  'armas': '15153',
#  'debía': '15149',
#  'ii': '15123',
#  'esfuerzo': '15109',
#  'humana': '15107',
#  'posibilidades': '15090',
#  'centros': '15076',
#  'profesional': '15075',
#  'asimismo': '15048',
#  'grado': '15048',
#  'has': '15027',
#  'toma': '15003',
#  'distintas': '14926',
#  'material': '14915',
#  'carne': '14905',
#  'llama': '14903',
#  'particular': '14876',
#  'jorge': '14867',
#  'trabajar': '14837',
#  'propuesta': '14830',
#  'muerto': '14816',
#  'precios': '14809',
#  'reforma': '14779',
#  'hermano': '14736',
#  'corte': '14735',
#  'comenzó': '14733',
#  'etapa': '14716',
#  'obstante': '14695',
#  'pone': '14685',
#  'diversos': '14671',
#  'visita': '14660',
#  'concepto': '14657',
#  'pacientes': '14637',
#  'semanas': '14603',
#  'tipos': '14592',
#  'solamente': '14520',
#  'deseo': '14499',
#  'sistemas': '14484',
#  'encuentran': '14482',
#  'siguientes': '14475',
#  'martín': '14429',
#  'suficiente': '14414',
#  'marzo': '14408',
#  'propios': '14404',
#  'jamás': '14371',
#  'dan': '14364',
#  'club': '14359',
#  'instituto': '14354',
#  'constitución': '14299',
#  'curso': '14290',
#  'lenguaje': '14270',
#  'estilo': '14237',
#  'rosa': '14180',
#  'imposible': '14178',
#  'pablo': '14152',
#  'buscar': '14151',
#  'peor': '14145',
#  'piel': '14128',
#  'arriba': '14085',
#  'generales': '14073',
#  'septiembre': '14072',
#  'blanca': '14061',
#  'r': '14041',
#  'aquellas': '13996',
#  'teoría': '13935',
#  'animales': '13916',
#  'hicieron': '13913',
#  'larga': '13908',
#  'perdido': '13890',
#  'imágenes': '13887',
#  'paciente': '13885',
#  'conseguir': '13871',
#  'máximo': '13855',
#  'noviembre': '13848',
#  'j': '13831',
#  'líder': '13830',
#  'hospital': '13823',
#  'diversas': '13816',
#  'rafael': '13804',
#  'vuelve': '13799',
#  'destino': '13783',
#  'torno': '13781',
#  'proyectos': '13773',
#  'flores': '13763',
#  'niveles': '13759',
#  'afirmó': '13758',
#  'explicó': '13751',
#  'n': '13748',
#  'somos': '13727',
#  'términos': '13719',
#  'premio': '13701',
#  ...}

# %% [markdown]
# ## Obtain the Log of the Common Value

# %%
twentyLFTSU = logFreq(twenty_TSU, mostCommonDic)
eightyLFTSU = logFreq(eighty_TSU, mostCommonDic)
twentyLFLic = logFreq(twenty_Lic, mostCommonDic)
eightyLFLic = logFreq(eighty_Lic, mostCommonDic)
twentyLFMasters = logFreq(twenty_Masters, mostCommonDic)
eightyLFMasters = logFreq(eighty_Masters, mostCommonDic)
twentyLFPhd = logFreq(twenty_Phd, mostCommonDic)
eightyLFPhd = logFreq(eighty_Phd, mostCommonDic)

twentyLFTSU
eightyLFTSU
twentyLFLic
eightyLFLic
twentyLFMasters
eightyLFMasters
twentyLFPhd
eightyLFPhd
# Out:
# {'Justificacion7': {'actualmente': 0.0,
#   'encontramos': 0.0,
#   'proceso': 10.780288735123806,
#   'constantes': 0.0,
#   'cambios': 9.846176185823014,
#   'transformaciones': 0.0,
#   'obedecen': 0.0,
#   'serie': 10.153350928549719,
#   'factores': 0.0,
#   'incorporación': 0.0,
#   'vertiginosa': 0.0,
#   'nuevas': 10.15183090487208,
#   'tecnologías': 0.0,
#   'información': 10.655445946975886,
#   'comunicación': 10.018332944205168,
#   'diversos': 9.593628035139645,
#   'campos': 0.0,
#   'incluidos': 0.0,
#   'aspecto': 9.650400124848845,
#   'educativo': 0.0,
#   'acuerdo': 10.849045782090851,
#   'unesco': 0.0,
#   'sistemas': 9.580799870885532,
#   'educativos': 0.0,
#   'mundo': 11.53022496204829,
#   'enfrentan': 0.0,
#   'desafío': 0.0,
#   'utilizar': 0.0,
#   'tic': 0.0,
#   'proveer': 0.0,
#   'estudiantes': 0.0,
#   'herramientas': 0.0,
#   'conocimientos': 0.0,
#   'necesarios': 0.0,
#   'siglo': 10.64280241394108,
#   'xxi': 0.0,
#   'año': 11.520794423348924,
#   'informe': 9.707229330003301,
#   'mundial': 10.12515000756854,
#   'educación': 10.17835030752565,
#   'imperativo': 0.0,
#   'calidad': 10.150230436100662,
#   'enfatizó': 0.0,
#   'importancia': 10.041900759689755,
#   'métodos': 0.0,
#   'aprendizaje': 0.0,
#   'utilización': 0.0,
#   'materiales': 0.0,
#   'infraestructura': 0.0,
#   'acceso': 0.0,
#   'importante': 10.787193107312595,
#   'campo': 10.334457951052654,
#   'factor': 0.0,
#   'vital': 0.0,
#   'transformación': 0.0,
#   'sociedad': 10.735831298284362,
#   'potencial': 0.0,
#   'transformar': 0.0,
#   'naturaleza': 9.99888863729938,
#   'cuanto': 10.558906905035101,
#   'dónde': 9.944917362299268,
#   'cómo': 11.199583645737869,
#   'produce': 9.731809155840653,
#   'enseñanza': 0.0,
#   'así': 11.95533305200011,
#   'introducir': 0.0,
#   'roles': 0.0,
#   'profesores': 0.0,
#   'diferentes': 10.28800137389136,
#   'acciones': 9.856133856152658,
#   'realiza': 0.0,
#   'incluido': 0.0,
#   'temas': 9.653037036689675,
#   'gestión': 0.0,
#   'institucional': 0.0,
#   'nuevo': 11.254957522501838,
#   'panorama': 0.0,
#   'enfatiza': 0.0,
#   'desarrollar': 0.0,
#   'competencias': 0.0,
#   'capacidades': 0.0,
#   'habilidades': 0.0,
#   'uso': 10.212258189817774,
#   'valzacchi': 0.0,
#   'deben': 10.240245462634501,
#   'cultivar': 0.0,
#   'siguientes': 9.580178302441196,
#   'destrezas': 0.0,
#   'según': 11.554105795280545,
#   'estándares': 0.0,
#   'international': 0.0,
#   'society': 0.0,
#   'for': 0.0,
#   'technology': 0.0,
#   'in': 0.0,
#   'education': 0.0,
#   'desenvolverse': 0.0,
#   'manejarse': 0.0,
#   'soltura': 0.0,
#   'empleo': 0.0,
#   'tecnología': 0.0,
#   'comunicar': 0.0,
#   'ideas': 9.769670404801788,
#   'usando': 0.0,
#   'gran': 11.580499997756885,
#   'variedad': 0.0,
#   'medios': 10.269102416044332,
#   'formatos': 0.0,
#   'acceder': 0.0,
#   'intercambiar': 0.0,
#   'compilar': 0.0,
#   'organizar': 0.0,
#   'analizar': 0.0,
#   'sintetizar': 0.0,
#   'saber': 10.330192163636712,
#   'encontrar': 9.69066555029379,
#   'adicional': 0.0,
#   'evaluar': 0.0,
#   'fuentes': 10.025351140292969,
#   'construir': 0.0,
#   'producir': 0.0,
#   'publicar': 0.0,
#   'modelos': 0.0,
#   'contenidos': 0.0,
#   'trabajos': 0.0,
#   'creativos': 0.0,
#   'colaborar': 0.0,
#   'cooperar': 0.0,
#   'grupos': 10.235054922800046,
#   'trabajo': 11.257749304074707,
#   'interactuar': 0.0,
#   'forma': 11.484165843298804,
#   'apropiada': 0.0,
#   'ética': 0.0,
#   'país': 11.557592856465387,
#   'inició': 0.0,
#   'integración': 0.0,
#   'sistema': 10.964917050076522,
#   'público': 10.650199196425806,
#   'estatal': 0.0,
#   'través': 10.696751524430846,
#   'proyecto': 10.454955954764136,
#   'huascarán': 0.0,
#   'dirección': 10.299171648789187,
#   'general': 11.469683878931205,
#   'educativas': 0.0,
#   'ministerio': 10.076642221505265,
#   'finalidad': 0.0,
#   'p': 9.976645073153854,
#   'mejoren': 0.0,
#   'secundaria': 0.0,
#   'alcancen': 0.0,
#   'formación': 9.838575628358985,
#   'integral': 0.0,
#   'comprenda': 0.0,
#   'consecución': 0.0,
#   'logros': 0.0,
#   'sólida': 0.0,
#   'valores': 9.835048099313607,
#   'investigación': 10.165890277802454,
#   'justifica': 0.0,
#   'consideración': 0.0,
#   'guiloff': 0.0,
#   'existe': 10.232035618540193,
#   'suficiente': 9.575955235484386,
#   'compromiso': 0.0,
#   'interacción': 0.0,
#   'tecnológica': 0.0,
#   'relacionada': 0.0,
#   'actividades': 9.97878053657156,
#   'formal': 0.0,
#   'condie': 0.0,
#   'fecha': 9.77286620732769,
#   'estudios': 10.043727641450573,
#   'relación': 10.705870231302164,
#   'embargo': 11.099166054037244,
#   'varían': 0.0,
#   'regiones': 0.0,
#   'realizado': 0.0,
#   'ciertas': 0.0,
#   'características': 9.758866322925,
#   'disciplinas': 0.0,
#   'necesario': 10.171566227844085,
#   'hacer': 11.472759505212103,
#   'investigaciones': 0.0,
#   'locales': 0.0,
#   'específicas': 0.0,
#   'asimismo': 9.619000370980867,
#   'tema': 10.322132095756407,
#   'especial': 10.290720799049488,
#   'actualidad': 0.0,
#   'diversas': 9.533582619826515,
#   'organizaciones': 0.0,
#   'instituciones': 9.655410734676707,
#   'investigadores': 0.0,
#   'vienen': 0.0,
#   'trabajando': 0.0,
#   'convocado': 0.0,
#   'realizar': 9.860893154903707,
#   'nivel': 10.52993387579382,
#   'micro': 0.0,
#   'contribuir': 0.0,
#   'generación': 0.0,
#   'conocimiento': 9.8171668460696,
#   'científico': 0.0,
#   'puesto': 10.411930339600325,
#   'permitirá': 0.0,
#   'entregar': 0.0,
#   'autoridades': 9.861362626235456,
#   'implementando': 0.0,
#   'resultados': 10.181611592175802,
#   'desarrollo': 10.786800443913076},
#  'Justificacion8': {'problemas': 10.675792433881902,
#   'optimización': 0.0,
#   'industriales': 0.0,
#   'general': 11.469683878931205,
#   'demandantes': 0.0,
#   'cuanto': 10.558906905035101,
#   'uso': 10.212258189817774,
#   'recursos': 10.118598932153073,
#   'computacionales': 0.0,
#   'investigación': 10.165890277802454,
#   'hecha': 0.0,
#   'zabinsky': 0.0,
#   'describe': 0.0,
#   'ambiente': 9.852194258148577,
#   'operan': 0.0,
#   'diseñan': 0.0,
#   'aplicaciones': 0.0,
#   'ingeniería': 0.0,
#   'ambientes': 0.0,
#   'restricciones': 0.0,
#   'tiempos': 9.872719018864492,
#   'entrega': 0.0,
#   'productos': 9.986495091519735,
#   'originadas': 0.0,
#   'compromisos': 0.0,
#   'clientes': 0.0,
#   'desarrollos': 0.0,
#   'propuestos': 0.0,
#   'encontrar': 9.69066555029379,
#   'soluciones': 0.0,
#   'técnicos': 0.0,
#   'particularmente': 0.0,
#   'ven': 0.0,
#   'afectados': 0.0,
#   'dichas': 0.0,
#   'necesario': 10.171566227844085,
#   'disponer': 0.0,
#   'herramientas': 0.0,
#   'permitan': 0.0,
#   'atacar': 0.0,
#   'resolver': 0.0,
#   'establecidos': 0.0,
#   'alternativa': 0.0,
#   'permite': 9.883641924315421,
#   'superar': 0.0,
#   'tiempo': 11.782158393753479,
#   'implementación': 0.0,
#   'hardware': 0.0,
#   'especializado': 0.0,
#   'algoritmos': 0.0,
#   'numéricos': 0.0,
#   'utilizados': 0.0,
#   'bajo': 10.882621619531593,
#   'enfoque': 0.0,
#   'abre': 0.0,
#   'posibilidad': 10.189079943122826,
#   'disminuir': 0.0,
#   'ejecución': 0.0,
#   'esquema': 0.0,
#   'seleccionado': 0.0,
#   'comparado': 0.0,
#   'plataforma': 0.0,
#   'procesamiento': 0.0,
#   'convencional': 0.0,
#   'soportada': 0.0,
#   'estudio': 10.262559621074582,
#   'detallado': 0.0,
#   'algoritmo': 0.0,
#   'así': 11.95533305200011,
#   'puesta': 0.0,
#   'marcha': 9.821572259334861,
#   'busca': 9.634300062720511,
#   'usualmente': 0.0,
#   'utilizar': 0.0,
#   'menor': 10.091708341261072,
#   'costo': 0.0,
#   'computacional': 0.0,
#   'anterior': 10.250970378105945,
#   'primordial': 0.0,
#   'seleccionar': 0.0,
#   'procedimiento': 0.0,
#   'presente': 10.094562354324832,
#   'deterministas': 0.0,
#   'ofrecen': 0.0,
#   'ventaja': 0.0,
#   'tener': 10.968698164570208,
#   'tal': 11.176319219370214,
#   'característica': 0.0,
#   'si': 12.699182263490384,
#   'comparan': 0.0,
#   'métodos': 0.0,
#   'exploración': 0.0,
#   'estocástica': 0.0,
#   'propiedad': 0.0,
#   'notable': 0.0,
#   'demanda': 0.0,
#   'definida': 0.0,
#   'forma': 11.484165843298804,
#   'plantea': 0.0,
#   'problema': 10.603982670758612,
#   'método': 0.0,
#   'propuesto': 0.0,
#   'gutmann': 0.0,
#   'pertenece': 0.0,
#   'estrategias': 0.0,
#   'og': 0.0,
#   'convierte': 0.0,
#   'buen': 10.333840376152072,
#   'candidato': 0.0,
#   'dicha': 0.0,
#   'tarea': 0.0,
#   'utiliza': 0.0,
#   'conjunto': 10.074706030985418,
#   'puntos': 10.221504824783981,
#   'i': 9.85114107216392,
#   'x': 0.0,
#   'f': 0.0,
#   'm': 10.407258349428416,
#   'n': 9.528648637969724,
#   'empleados': 0.0,
#   'generar': 0.0,
#   'superficie': 0.0,
#   'interpolación': 0.0,
#   'cada': 11.732526749860027,
#   'punto': 10.937721307268031,
#   'entrada': 9.795623906660182,
#   'implica': 0.0,
#   'evaluación': 0.0,
#   'modelo': 9.810330054049878,
#   'realizar': 9.860893154903707,
#   'depuración': 0.0,
#   'inicial': 0.0,
#   'reduce': 0.0,
#   'número': 10.736070535336799,
#   'evaluaciones': 0.0,
#   'disminuirá': 0.0,
#   'debe': 11.214910188378656,
#   'realizarse': 0.0,
#   'alterada': 0.0,
#   'bien': 11.782624304024536,
#   'comportados': 0.0,
#   'condiciones': 10.376424375759305,
#   'reales': 0.0,
#   'diseños': 0.0,
#   'sometidos': 0.0,
#   'diversas': 9.533582619826515,
#   'perturbaciones': 0.0,
#   'alteran': 0.0,
#   'funcionamiento': 0.0,
#   'aplicación': 0.0,
#   'cuales': 10.041552403492023,
#   'comúnmente': 0.0,
#   'modeladas': 0.0,
#   'ruido': 0.0,
#   'gaussiano': 0.0,
#   'acuerdo': 10.849045782090851,
#   'evidencia': 0.0,
#   'encontrada': 0.0,
#   'presenta': 9.636588019266876,
#   'convergencia': 0.0,
#   'sometido': 0.0,
#   'deseable': 0.0,
#   'afectado': 0.0,
#   'contrario': 10.041378179875572,
#   'corre': 0.0,
#   'riesgo': 9.756784073343919,
#   'represente': 0.0,
#   'manera': 10.97050596961306,
#   'realista': 0.0,
#   'fenómeno': 0.0},
#  'Justificacion9': {'tras': 11.003165939386236,
#   'analizar': 0.0,
#   'propuesta': 9.604407435131979,
#   'mda': 0.0,
#   'omg': 0.0,
#   'detectado': 0.0,
#   'dos': 12.339024495252145,
#   'importantes': 9.980309695137413,
#   'carencias': 0.0,
#   'relacionadas': 0.0,
#   'tratamiento': 9.904986428659864,
#   'modelos': 0.0,
#   'iniciales': 0.0,
#   'aclara': 0.0,
#   'cómo': 11.199583645737869,
#   'deben': 10.240245462634501,
#   'manejarse': 0.0,
#   'ligados': 0.0,
#   'negocio': 0.0,
#   'conoce': 0.0,
#   'independientes': 0.0,
#   'computación': 0.0,
#   'ó': 0.0,
#   'cim': 0.0,
#   'describe': 0.0,
#   'asociarse': 0.0,
#   'primeros': 10.246828999162442,
#   'software': 0.0,
#   'desarrollar': 0.0,
#   'decir': 11.249831934653027,
#   'pim': 0.0,
#   'debido': 9.97011763483389,
#   'mencionadas': 0.0,
#   'mayoría': 10.452591137512096,
#   'trabajos': 0.0,
#   'relacionados': 0.0,
#   'desarrollo': 10.786800443913076,
#   'basado': 0.0,
#   'mdd': 0.0,
#   'suelen': 0.0,
#   'enfocarse': 0.0,
#   'perspectiva': 0.0,
#   'puramente': 0.0,
#   'tecnológica': 0.0,
#   'salvo': 0.0,
#   'contadas': 0.0,
#   'excepciones': 0.0,
#   'trabaja': 0.0,
#   'partiendo': 0.0,
#   'punto': 10.937721307268031,
#   'vista': 10.34019289638035,
#   'orientado': 0.0,
#   'relacionado': 0.0,
#   'objetivos': 0.0,
#   'empresariales': 0.0,
#   'mayor': 11.409407694857888,
#   'parte': 11.910022323407876,
#   'investigaciones': 0.0,
#   'actuales': 0.0,
#   'campo': 10.334457951052654,
#   'centradas': 0.0,
#   'aspectos': 9.715288758569297,
#   'técnicos': 0.0,
#   'pueden': 11.06490248157219,
#   'mejorar': 0.0,
#   'obtención': 0.0,
#   'código': 0.0,
#   'partir': 10.52615861929175,
#   'menos': 11.547307567829359,
#   'abstractos': 0.0,
#   'directamente': 0.0,
#   'requisitos': 0.0,
#   'información': 10.655445946975886,
#   'casos': 10.539958555902517,
#   'uso': 10.212258189817774,
#   'análisis': 9.880935148065616,
#   'diseño': 0.0,
#   'etc': 10.22951254915098,
#   'anterior': 10.250970378105945,
#   'deduce': 0.0,
#   'falta': 10.523956507598088,
#   'conexión': 0.0,
#   'real': 10.469426166355031,
#   'dominio': 0.0,
#   'tecnológico': 0.0,
#   'provoca': 0.0,
#   'utilizados': 0.0,
#   'partida': 0.0,
#   'procesos': 0.0,
#   'problema': 10.603982670758612,
#   'aprecia': 0.0,
#   'claramente': 0.0,
#   'ámbito': 0.0,
#   'evidente': 0.0,
#   'asociación': 9.66997795897274,
#   'metodologías': 0.0,
#   'ágil': 0.0,
#   'fuerte': 10.035743131656599,
#   'asociados': 0.0,
#   'tecnológicos': 0.0,
#   'embargo': 11.099166054037244,
#   'ajusta': 0.0,
#   'especificación': 0.0,
#   'puede': 11.990518968113976,
#   'aportar': 0.0,
#   'beneficios': 0.0,
#   'inherentes': 0.0,
#   'dirigido': 0.0,
#   'consiguiente': 0.0,
#   'vez': 12.004800658217194,
#   'expuestas': 0.0,
#   'forma': 11.484165843298804,
#   'resumida': 0.0,
#   'ventajas': 0.0,
#   'desventajas': 0.0,
#   'deficiencias': 0.0,
#   'mencionados': 0.0,
#   'objetivo': 9.956886129260823,
#   'solventar': 0.0,
#   'puntos': 10.221504824783981,
#   'débiles': 0.0,
#   'aprovechar': 0.0,
#   'aportaciones': 0.0,
#   'planteamos': 0.0,
#   'siguiente': 10.161650696951378,
#   'hipótesis': 0.0,
#   'tesis': 0.0,
#   'combinación': 0.0,
#   'idea': 10.295968733085997,
#   'resultaría': 0.0,
#   'ventajosa': 0.0,
#   'cara': 10.23120731201944,
#   'flexible': 0.0,
#   'asociado': 0.0},
#  'Justificacion10': {'presente': 10.094562354324832,
#   'tesis': 0.0,
#   'justifica': 0.0,
#   'además': 11.321474360388509,
#   'interés': 10.237062739615967,
#   'objetivo': 9.956886129260823,
#   'misma': 11.058196580556109,
#   'formación': 9.838575628358985,
#   'desarrollo': 10.786800443913076,
#   'académico': 0.0,
#   'autor': 9.93672888631593,
#   'así': 11.95533305200011,
#   'razones': 9.65033572298117,
#   'personales': 0.0,
#   'confluyeron': 0.0,
#   'serie': 10.153350928549719,
#   'hechos': 9.876373260044556,
#   'casi': 11.197735153101846,
#   'consecutivos': 0.0,
#   'final': 10.71263840885238,
#   'licenciatura': 0.0,
#   'ciencias': 0.0,
#   'información': 10.655445946975886,
#   'rama': 0.0,
#   'periodismo': 0.0,
#   'surgimiento': 0.0,
#   'investigación': 10.165890277802454,
#   'documentación': 0.0,
#   'periodística': 0.0,
#   'fomentado': 0.0,
#   'dr': 0.0,
#   'félix': 0.0,
#   'valle': 0.0,
#   'gastaminza': 0.0,
#   'citados': 0.0,
#   'estudios': 10.043727641450573,
#   'universidad': 10.13281196292542,
#   'complutense': 0.0,
#   'madrid': 11.262372175521085,
#   'introducción': 0.0,
#   'uso': 10.212258189817774,
#   'internet': 0.0,
#   'usuario': 0.0,
#   'prensa': 10.14533508864411,
#   'accesible': 0.0,
#   'través': 10.696751524430846,
#   'españa': 11.292216447771478,
#   'semejanza': 0.0,
#   'sucedido': 0.0,
#   'años': 12.221094254105662,
#   'anteriores': 0.0,
#   'lugares': 0.0,
#   'intersección': 0.0,
#   'circunstancias': 0.0,
#   'produjo': 0.0,
#   'investigar': 0.0,
#   'aplicación': 0.0,
#   'nuevos': 10.197201397219628,
#   'contenidos': 0.0,
#   'periodísticos': 0.0,
#   'mismos': 9.952563390182721,
#   'corrió': 0.0,
#   'paralelo': 0.0,
#   'posterior': 0.0,
#   'cursos': 0.0,
#   'doctorado': 0.0,
#   'carlos': 10.665087458730515,
#   'ifi': 0.0,
#   'pronto': 10.201144708009988,
#   'contó': 0.0,
#   'tutela': 0.0,
#   'profesor': 0.0,
#   'antonio': 10.32018929257028,
#   'hernández': 0.0,
#   'pérez': 0.0,
#   'departamento': 0.0,
#   'biblioteconomía': 0.0,
#   'licenciado': 0.0,
#   'doctor': 9.771440771615795,
#   'común': 10.022869309556208,
#   'unía': 0.0,
#   'temas': 9.653037036689675,
#   'relacionados': 0.0,
#   'tecnologías': 0.0,
#   'aplicadas': 0.0,
#   'documentalmente': 0.0,
#   'accesibles': 0.0,
#   'dirección': 10.299171648789187,
#   'tesina': 0.0,
#   'manifestó': 0.0,
#   'mediante': 10.248919530528813,
#   'inclusión': 0.0,
#   'varios': 10.472063081843023,
#   'proyectos': 9.530465432917332,
#   'participaron': 0.0,
#   'ambos': 10.28117027963184,
#   'principalmente': 0.0,
#   'dirigidos': 0.0,
#   'dra': 0.0,
#   'mercedes': 0.0,
#   'caridad': 0.0,
#   'sebastián': 0.0,
#   'mismo': 11.781011788724976,
#   'participó': 0.0,
#   'becario': 0.0,
#   'fpi': 0.0,
#   'ministerio': 10.076642221505265,
#   'educación': 10.17835030752565,
#   'ciencia': 9.673130546703616,
#   'bajo': 10.882621619531593,
#   'octubre': 9.694493424326337,
#   'ayudante': 0.0,
#   'escuela': 9.83745458193169,
#   'universitaria': 0.0,
#   'citado': 0.0,
#   'tratamiento': 9.904986428659864,
#   'representados': 0.0,
#   'marcado': 0.0,
#   'texto': 9.782110566369528,
#   'delgado': 0.0,
#   'kloos': 0.0,
#   'dpto': 0.0,
#   'ingeniería': 0.0,
#   'telemática': 0.0,
#   'caso': 11.482249739201768,
#   'titulado': 0.0,
#   'periotrónico': 0.0,
#   'concepción': 0.0,
#   'periódico': 0.0,
#   'electrónico': 0.0,
#   'personalizado': 0.0,
#   'cicyt': 0.0,
#   'tel': 0.0,
#   'subsiguiente': 0.0,
#   'proyecto': 10.454955954764136,
#   'infomedia': 0.0,
#   'sistema': 10.964917050076522,
#   'multiplataforma': 0.0,
#   'publicación': 0.0,
#   'david': 0.0,
#   'rodríguez': 9.633776365405584,
#   'mazeos': 0.0,
#   'infoflex': 0.0,
#   'gestión': 0.0,
#   'flexible': 0.0,
#   'distribuida': 0.0,
#   'basada': 0.0,
#   'web': 0.0,
#   'tc': 0.0,
#   'dirigido': 0.0,
#   'luis': 10.580759383937783,
#   'sánchez': 0.0,
#   'fernández': 0.0,
#   'desarrollará': 0.0,
#   'partir': 10.52615861929175,
#   'investiga': 0.0,
#   'lenguajes': 0.0,
#   'periodístico': 0.0,
#   'basado': 0.0,
#   'xml': 0.0,
#   'derivó': 0.0,
#   'definitivo': 0.0,
#   'director': 10.547864568726643,
#   'desarrollar': 0.0,
#   'metalenguaje': 0.0,
#   'derivados': 0.0,
#   'desarrollados': 0.0,
#   'instituciones': 9.655410734676707,
#   'internacionales': 0.0,
#   'centros': 9.620859354387026,
#   'pertenecientes': 0.0,
#   'medios': 10.269102416044332,
#   'comunicación': 10.018332944205168,
#   'visto': 10.228357022355016,
#   'reflejado': 0.0,
#   'plano': 0.0,
#   'docente': 0.0,
#   'tras': 11.003165939386236,
#   'participar': 0.0,
#   'corno': 0.0,
#   'aeu': 0.0,
#   'diversas': 9.533582619826515,
#   'asignaturas': 0.0,
#   'relacionadas': 0.0,
#   'diplomatura': 0.0,
#   'biblioteconomia': 0.0,
#   'participa': 0.0,
#   'docencia': 0.0,
#   'dentro': 10.943145698360567,
#   'informativa': 0.0,
#   'curso': 9.567315270923913,
#   'fines': 0.0,
#   'aplicaciones': 0.0,
#   'red': 0.0},
#  'Justificacion11': {'tesis': 0.0,
#   'espera': 9.844268192876157,
#   'realizar': 9.860893154903707,
#   'distintas': 9.610859937691332,
#   'contribuciones': 0.0,
#   'primer': 11.155078405801317,
#   'lugar': 11.2676641084024,
#   'incorporando': 0.0,
#   'determinadas': 0.0,
#   'herramientas': 0.0,
#   'conceptuales': 0.0,
#   'desarrolladas': 0.0,
#   'campo': 10.334457951052654,
#   'estudios': 10.043727641450573,
#   'sociales': 10.134480218793737,
#   'ciencia': 9.673130546703616,
#   'tecnología': 0.0,
#   'mayormente': 0.0,
#   'aplicadas': 0.0,
#   'estudio': 10.262559621074582,
#   'particular': 9.60750445504496,
#   'tecnologías': 0.0,
#   'información': 10.655445946975886,
#   'comunicación': 10.018332944205168,
#   'añadir': 0.0,
#   'aquellos': 10.202665790126336,
#   'conceptos': 0.0,
#   'presentes': 0.0,
#   'general': 11.469683878931205,
#   'permitiría': 0.0,
#   'comprender': 0.0,
#   'procesos': 0.0,
#   'incorporación': 0.0,
#   'tic': 0.0,
#   'construcción': 9.803556713911078,
#   'campus': 0.0,
#   'virtuales': 0.0,
#   'universidades': 0.0,
#   'país': 11.557592856465387,
#   'junto': 10.584587455185398,
#   'ello': 10.928955507166235,
#   'proporcionar': 0.0,
#   'nuevos': 10.197201397219628,
#   'andamiajes': 0.0,
#   'teóricos': 0.0,
#   'vinculados': 0.0,
#   'características': 9.758866322925,
#   'inherentes': 0.0,
#   'propósito': 0.0,
#   'presenta': 9.636588019266876,
#   'inédito': 0.0,
#   'pocos': 9.917834146243049,
#   'trabajos': 0.0,
#   'ámbito': 0.0,
#   'ciencias': 0.0,
#   'analizado': 0.0,
#   'dinámicas': 0.0,
#   'desarrollo': 10.786800443913076,
#   'tecnológico': 0.0,
#   'posibilitan': 0.0,
#   'entornos': 0.0,
#   'gestan': 0.0,
#   'enfoque': 0.0,
#   'encuadre': 0.0,
#   'propuesto': 0.0,
#   'sentido': 10.769726324511337,
#   'aspira': 0.0,
#   'establecer': 0.0,
#   'ruptura': 0.0,
#   'aquellas': 9.54652685348758,
#   'formas': 9.956222307519994,
#   'cristalizadas': 0.0,
#   'determinismo': 0.0,
#   'consideran': 0.0,
#   'creciente': 0.0,
#   'difusión': 0.0,
#   'proliferación': 0.0,
#   'producen': 0.0,
#   'efectos': 9.812084729062784,
#   'sociedad': 10.735831298284362,
#   'limitan': 0.0,
#   'mirada': 9.70996348123418,
#   'meramente': 0.0,
#   'instrumental': 0.0,
#   'dejando': 0.0,
#   'lado': 10.764582648942334,
#   'hacen': 10.065096067732542,
#   'hincapié': 0.0,
#   'social': 10.976508491537329,
#   'entendiendo': 0.0,
#   'relación': 10.705870231302164,
#   'sociedadtecnología': 0.0,
#   'si': 12.699182263490384,
#   'tratara': 0.0,
#   'dos': 12.339024495252145,
#   'entidades': 0.0,
#   'separadas': 0.0,
#   'distinción': 0.0,
#   'misma': 11.058196580556109,
#   'técnico': 0.0,
#   'debe': 11.214910188378656,
#   'considerarse': 0.0,
#   'resultado': 10.087058328730514,
#   'proceso': 10.780288735123806,
#   'coconstrucción': 0.0,
#   'parte': 11.910022323407876,
#   'investigación': 10.165890277802454,
#   'contribuir': 0.0,
#   'educación': 10.17835030752565,
#   'superior': 9.999433893583337,
#   'universidad': 10.13281196292542,
#   'aparece': 9.639977632055333,
#   'vacante': 0.0,
#   'problemática': 0.0,
#   'vinculada': 0.0,
#   'universitaria': 0.0,
#   'virtual': 0.0,
#   'utilización': 0.0,
#   'enseñanza': 0.0,
#   'únicamente': 0.0,
#   'cuestión': 9.721125994942152,
#   'técnica': 9.699411063939143,
#   'puesto': 10.411930339600325,
#   'replantea': 0.0,
#   'cuestiones': 0.0,
#   'fundamentales': 0.0,
#   'sólo': 12.046795514544378,
#   'métodos': 0.0,
#   'trabajo': 11.257749304074707,
#   'sino': 11.494201255971948,
#   'metas': 0.0,
#   'propósitos': 0.0,
#   'persiguen': 0.0,
#   'instituciones': 9.655410734676707,
#   'universitarias': 0.0,
#   'así': 11.95533305200011,
#   'nacionales': 0.0,
#   'argentinas': 0.0,
#   'podría': 10.591546811547127,
#   'replantear': 0.0,
#   'dinámica': 0.0,
#   'formulación': 0.0,
#   'políticas': 9.867082870642328,
#   'toma': 9.616005460087013,
#   'decisiones': 0.0,
#   'interior': 10.348109269178813,
#   'último': 10.693897550716283,
#   'relacionan': 0.0,
#   'innovación': 0.0,
#   'tecnológica': 0.0,
#   'territorios': 0.0,
#   'indagando': 0.0,
#   'nueva': 11.057644917277374,
#   'dimensión': 0.0,
#   'espaciotemporal': 0.0,
#   'generan': 0.0,
#   'condiciones': 10.376424375759305,
#   'territoriales': 0.0,
#   'económicas': 0.0,
#   'organizacionales': 0.0,
#   'simbólicas': 0.0,
#   'inciden': 0.0,
#   'implementación': 0.0,
#   'forma': 11.484165843298804,
#   'busca': 9.634300062720511,
#   'abrir': 0.0,
#   'nuevas': 10.15183090487208,
#   'posibilidades': 9.621787551761894,
#   'triangulación': 0.0,
#   'teórica': 0.0,
#   'sociología': 0.0,
#   'orientados': 0.0,
#   'contribuyendo': 0.0,
#   'ampliar': 0.0,
#   'alcances': 0.0,
#   'actuales': 0.0},
#  'Justificacion12': {'necesidad': 10.154207359620441,
#   'cada': 11.732526749860027,
#   'vez': 12.004800658217194,
#   'capacidad': 10.17458282138351,
#   'cómputo': 0.0,
#   'muchas': 10.610685556318733,
#   'aplicaciones': 0.0,
#   'importantes': 9.980309695137413,
#   'incluyendo': 0.0,
#   'modelado': 0.0,
#   'simulación': 0.0,
#   'sistemas': 9.580799870885532,
#   'inteligentes': 0.0,
#   'tales': 9.70418259070176,
#   'realizan': 0.0,
#   'máquinas': 0.0,
#   'visión': 0.0,
#   'motivado': 0.0,
#   'investigación': 10.165890277802454,
#   'área': 9.640107772607312,
#   'arquitecturas': 0.0,
#   'avanzado': 0.0,
#   'manera': 10.97050596961306,
#   'considerable': 0.0,
#   'últimos': 10.394793908855744,
#   'años': 12.221094254105662,
#   'requieren': 0.0,
#   'mejor': 11.255643264909532,
#   'desempeño': 0.0,
#   'puede': 11.990518968113976,
#   'proporcionar': 0.0,
#   'existen': 9.885018036252466,
#   'actualmente': 0.0,
#   'podrán': 0.0,
#   'ser': 12.358467499081977,
#   'construidas': 0.0,
#   'futuro': 10.203184654566114,
#   'cercano': 0.0,
#   'alcanzando': 0.0,
#   'límites': 0.0,
#   'capacidades': 0.0,
#   'procesamiento': 0.0,
#   'diseños': 0.0,
#   'seriales': 0.0,
#   'opción': 0.0,
#   'alcanzar': 0.0,
#   'velocidades': 0.0,
#   'deseadas': 0.0,
#   'físicamente': 0.0,
#   'posible': 10.801247647790849,
#   'través': 10.696751524430846,
#   'paralelo': 0.0,
#   'hm': 0.0,
#   'reconfigurables': 0.0,
#   'prometen': 0.0,
#   'valiosa': 0.0,
#   'alternativa': 0.0,
#   'dispositivos': 0.0,
#   'convencionales': 0.0,
#   'hardware': 0.0,
#   'estático': 0.0,
#   'sino': 11.494201255971948,
#   'adapta': 0.0,
#   'diferencia': 9.75138477432617,
#   'procesadores': 0.0,
#   'asics': 0.0,
#   'técnicas': 0.0,
#   'reconfiguración': 0.0,
#   'utilizan': 0.0,
#   'ampliamente': 0.0,
#   'particularmente': 0.0,
#   'arreglos': 0.0,
#   'sistólicos': 0.0,
#   'suspender': 0.0,
#   'operación': 9.657139343577324,
#   'aún': 10.910733540740393,
#   'realizar': 9.860893154903707,
#   'pequeños': 0.0,
#   'cambios': 9.846176185823014,
#   'impacto': 0.0,
#   'crítico': 0.0,
#   'si': 12.699182263490384,
#   'van': 10.416251296932378,
#   'usar': 0.0,
#   'aceleradores': 0.0,
#   'algoritmo': 0.0,
#   'naturaleza': 9.99888863729938,
#   'tareas': 0.0,
#   'ejecutar': 0.0,
#   'cambiante': 0.0,
#   'dinámica': 0.0,
#   'permite': 9.883641924315421,
#   'configuración': 0.0,
#   'dispositivo': 0.0,
#   'vuelo': 0.0,
#   'sistema': 10.964917050076522,
#   'mr': 0.0,
#   'partir': 10.52615861929175,
#   'conceptos': 0.0,
#   'trabajo': 11.257749304074707,
#   'propone': 0.0,
#   'reducir': 0.0,
#   'cuello': 0.0,
#   'botella': 0.0,
#   'basados': 0.0,
#   'modelo': 9.810330054049878,
#   'von': 0.0,
#   'neumann': 0.0,
#   'explorar': 0.0,
#   'analizar': 0.0,
#   'junto': 10.584587455185398,
#   'implementación': 0.0,
#   'algoritmos': 0.0,
#   'operaciones': 0.0,
#   'ventanas': 0.0,
#   'poder': 11.11095424611632,
#   'proponer': 0.0,
#   'soluciónes': 0.0,
#   'acordes': 0.0,
#   'restricciones': 0.0,
#   'tiempo': 11.782158393753479,
#   'real': 10.469426166355031,
#   'específica': 0.0,
#   'uso': 10.212258189817774,
#   'parcial': 0.0,
#   'serie': 10.153350928549719,
#   'problemas': 10.675792433881902,
#   'deben': 10.240245462634501,
#   'manejar': 0.0,
#   'asociados': 0.0,
#   'fpgas': 0.0,
#   'acoplados': 0.0,
#   'procesador': 0.0,
#   'primero': 10.49769798523605,
#   'proceso': 10.780288735123806,
#   'mapeo': 0.0,
#   'automático': 0.0,
#   'típicamente': 0.0,
#   'programador': 0.0,
#   'debe': 11.214910188378656,
#   'cuidar': 0.0,
#   'forma': 11.484165843298804,
#   'identificar': 0.0,
#   'parte': 11.910022323407876,
#   'implementado': 0.0,
#   'herramientas': 0.0,
#   'especializadas': 0.0,
#   'convertir': 0.0,
#   'descripción': 0.0,
#   'presente': 10.094562354324832,
#   'propuesta': 9.604407435131979,
#   'pretende': 0.0,
#   'determinar': 0.0,
#   'resolver': 0.0,
#   'problema': 10.603982670758612,
#   'codiseño': 0.0,
#   'hwsw': 0.0,
#   'nj': 0.0,
#   'desafío': 0.0,
#   'interesante': 0.0,
#   'asociado': 0.0,
#   'computación': 0.0,
#   'reconfigurable': 0.0,
#   'misma': 11.058196580556109,
#   'manejarla': 0.0,
#   'objetivo': 9.956886129260823,
#   'principal': 10.002155724332829,
#   'proyecto': 10.454955954764136,
#   'tradicionales': 0.0,
#   'tiempos': 9.872719018864492,
#   'relativamente': 0.0,
#   'largos': 0.0,
#   'dependen': 0.0,
#   'modificaciones': 0.0,
#   'línea': 9.920246336351083,
#   'cualquier': 10.921630653712223,
#   'retardo': 0.0,
#   'incrementa': 0.0,
#   'total': 10.390194648893312,
#   'global': 0.0,
#   'objetivos': 0.0,
#   'disminuir': 0.0,
#   'efecto': 10.17385814221302,
#   'utilizando': 0.0,
#   'modificar': 0.0,
#   'sólo': 12.046795514544378,
#   'fpga': 0.0,
#   'perturbar': 0.0,
#   'funcionamiento': 0.0,
#   'resto': 10.059037253277094,
#   'consiste': 0.0,
#   'granularidad': 0.0,
#   'apropiada': 0.0,
#   'relación': 10.705870231302164,
#   'obtenido': 0.0,
#   'finalmente': 9.810878720803466,
#   'plantea': 0.0,
#   'posibilidad': 10.189079943122826,
#   'generar': 0.0,
#   'permita': 0.0,
#   'optimizar': 0.0,
#   'consumo': 9.686263943732909,
#   'potencia': 0.0,
#   'bajo': 10.882621619531593,
#   'costo': 0.0,
#   'cuente': 0.0,
#   'habilidad': 0.0,
#   'hacerlo': 9.651108271786734,
#   'compatible': 0.0},
#  'Justificacion13': {'aumento': 9.689365683192376,
#   'volumen': 0.0,
#   'variedad': 0.0,
#   'información': 10.655445946975886,
#   'bases': 0.0,
#   'datos': 10.240066926275098,
#   'incrementado': 0.0,
#   'dificultad': 0.0,
#   'clasificación': 0.0,
#   'caracterización': 0.0,
#   'comprensión': 0.0,
#   'mismas': 0.0,
#   'solución': 9.678279371339702,
#   'problema': 10.603982670758612,
#   'uso': 10.212258189817774,
#   'técnicas': 0.0,
#   'análisis': 9.880935148065616,
#   'reconocimiento': 0.0,
#   'patrones': 0.0,
#   'minería': 0.0,
#   'base': 10.283395507779986,
#   'estudio': 10.262559621074582,
#   'trabajos': 0.0,
#   'relacionados': 0.0,
#   'forma': 11.484165843298804,
#   'abordar': 0.0,
#   'encontrar': 9.69066555029379,
#   'regularidades': 0.0,
#   'puedan': 0.0,
#   'representar': 0.0,
#   'conjuntos': 0.0,
#   'permitiendo': 0.0,
#   'caracterizarlos': 0.0,
#   'manera': 10.97050596961306,
#   'reducir': 0.0,
#   'hacer': 11.472759505212103,
#   'utilizar': 0.0,
#   'representantes': 0.0,
#   'cuales': 10.041552403492023,
#   'herramienta': 0.0,
#   'útil': 0.0,
#   'supervisada': 0.0,
#   'universos': 0.0,
#   'estructurados': 0.0,
#   'embargo': 11.099166054037244,
#   'cuenta': 11.087788121064543,
#   'algoritmo': 0.0,
#   'cálculo': 0.0,
#   'exceptuando': 0.0,
#   'verificación': 0.0,
#   'definición': 0.0,
#   'espacio': 10.26965727803665,
#   'búsqueda': 0.0,
#   'pueden': 11.06490248157219,
#   'incluir': 0.0,
#   'mucha': 9.641927964229918,
#   'redundancia': 0.0,
#   'tal': 11.176319219370214,
#   'motivo': 0.0,
#   'llegar': 10.520131587109958,
#   'ser': 12.358467499081977,
#   'demasiados': 0.0,
#   'ejemplo': 10.855203341628478,
#   'conjunto': 10.074706030985418,
#   'objetos': 0.0,
#   'rasgos': 0.0,
#   'clases': 0.0,
#   'encontraron': 0.0,
#   'necesario': 10.171566227844085,
#   'contar': 0.0,
#   'permita': 0.0,
#   'subconjunto': 0.0,
#   'adecuado': 0.0},
#  'Justificacion14': {'enorme': 0.0,
#   'cantidad': 9.990215556045952,
#   'imágenes': 9.53870842969938,
#   'crudo': 0.0,
#   'almacenada': 0.0,
#   'superficie': 0.0,
#   'terrestre': 0.0,
#   'interpretación': 0.0,
#   'laboriosa': 0.0,
#   'consume': 0.0,
#   'tiempo': 11.782158393753479,
#   'inimaginable': 0.0,
#   'ayuda': 9.948365311314214,
#   'procesamiento': 0.0,
#   'pongamos': 0.0,
#   'ejemplo': 10.855203341628478,
#   'satelitales': 0.0,
#   'territorio': 0.0,
#   'nacional': 11.258562107711272,
#   'tomadas': 0.0,
#   'constelación': 0.0,
#   'satélites': 0.0,
#   'spot': 0.0,
#   'considerar': 0.0,
#   'siguen': 0.0,
#   'adquiriendo': 0.0,
#   'primer': 11.155078405801317,
#   'trimestre': 0.0,
#   'año': 11.520794423348924,
#   'satélite': 0.0,
#   'alcanzan': 0.0,
#   'aproximadamente': 0.0,
#   'encuentran': 9.580661777948766,
#   'pancromáticas': 0.0,
#   'multiespectrales': 0.0,
#   'resolución': 0.0,
#   'espacial': 0.0,
#   'metros': 9.82379478362688,
#   'contabilizar': 0.0,
#   'dos': 12.339024495252145,
#   'permanecen': 0.0,
#   'órbita': 0.0,
#   'm': 10.407258349428416,
#   'cubren': 0.0,
#   'casi': 11.197735153101846,
#   'lado': 10.764582648942334,
#   'herramientas': 0.0,
#   'diseñado': 0.0,
#   'limitantes': 0.0,
#   'ser': 12.358467499081977,
#   'aplicadas': 0.0,
#   'clasificación': 0.0,
#   'coberturas': 0.0,
#   'espectralmente': 0.0,
#   'similares': 0.0,
#   'obteniendo': 0.0,
#   'resultados': 10.181611592175802,
#   'desventajas': 0.0,
#   'algoritmos': 0.0,
#   'comúnmente': 0.0,
#   'empleados': 0.0,
#   'involucran': 0.0,
#   'información': 10.655445946975886,
#   'objetos': 0.0,
#   'clasificados': 0.0,
#   'modelo': 9.810330054049878,
#   'probabilístico': 0.0,
#   'resulta': 9.928033812954128,
#   'atractivo': 0.0,
#   'dominio': 0.0,
#   'embargo': 11.099166054037244,
#   'satelitáles': 0.0,
#   'presentan': 0.0,
#   'además': 11.321474360388509,
#   'geometrías': 0.0,
#   'características': 9.758866322925,
#   'estocásticas': 0.0,
#   'incrementar': 0.0,
#   'porcentajes': 0.0,
#   'reconocimiento': 0.0,
#   'último': 10.693897550716283,
#   'algoritmo': 0.0,
#   'aplicado': 0.0,
#   'algún': 10.47908916924103,
#   'tipo': 10.94387026564006,
#   'cobertura': 0.0,
#   'particular': 9.60750445504496,
#   'obtener': 0.0,
#   'fina': 0.0,
#   'podría': 10.591546811547127,
#   'extendido': 0.0,
#   'tipos': 9.588228712314113,
#   'comportamiento': 0.0},
#  'Justificacion15': {'justificación': 0.0,
#   'investigación': 10.165890277802454,
#   'doctoral': 0.0,
#   'fundamenta': 0.0,
#   'siguientes': 9.580178302441196,
#   'criterios': 0.0,
#   'conveniencia': 0.0,
#   'pretende': 0.0,
#   'elevar': 0.0,
#   'eficacia': 0.0,
#   'enseñanza': 0.0,
#   'provista': 0.0,
#   'estudiante': 0.0,
#   'través': 10.696751524430846,
#   'sebw': 0.0,
#   'ello': 10.928955507166235,
#   'evalúan': 0.0,
#   'experiencias': 0.0,
#   'eligen': 0.0,
#   'aquellas': 9.54652685348758,
#   'supone': 0.0,
#   'estimular': 0.0,
#   'positivamente': 0.0,
#   'aprendizaje': 0.0,
#   'mejor': 11.255643264909532,
#   'manera': 10.97050596961306,
#   'relevancia': 0.0,
#   'social': 10.976508491537329,
#   'busca': 9.634300062720511,
#   'mejorar': 0.0,
#   'personalizar': 0.0,
#   'provee': 0.0,
#   'fin': 10.987121558023524,
#   'consideran': 0.0,
#   'capacidades': 0.0,
#   'cognitivas': 0.0,
#   'preferencias': 0.0,
#   'ciertos': 0.0,
#   'atributos': 0.0,
#   'personalidad': 0.0,
#   'implicaciones': 0.0,
#   'prácticas': 0.0,
#   'procura': 0.0,
#   'adecuar': 0.0,
#   'cada': 11.732526749860027,
#   'base': 10.283395507779986,
#   'variedades': 0.0,
#   'contenido': 9.647368744540465,
#   'secuencia': 0.0,
#   'evaluación': 0.0,
#   'disponibles': 0.0,
#   'forma': 11.484165843298804,
#   'promueve': 0.0,
#   'paradigma': 0.0,
#   'general': 11.469683878931205,
#   'diversos': 9.593628035139645,
#   'dominios': 0.0,
#   'valor': 10.169920451948736,
#   'teórico': 0.0,
#   'concibe': 0.0,
#   'proceso': 10.780288735123806,
#   'enseñanzaaprendizaje': 0.0,
#   'fenómeno': 0.0,
#   'causaefecto': 0.0,
#   'además': 11.321474360388509,
#   'formular': 0.0,
#   'modelo': 9.810330054049878,
#   'causal': 0.0,
#   'caracterizar': 0.0,
#   'dicho': 10.547286913465735,
#   'recolecta': 0.0,
#   'evidencia': 0.0,
#   'empírica': 0.0,
#   'sustente': 0.0,
#   'verificación': 0.0,
#   'hipótesis': 0.0,
#   'utilidad': 0.0,
#   'métodológica': 0.0,
#   'define': 0.0,
#   'marco': 9.651687291972113,
#   'trabajo': 11.257749304074707,
#   'evaluar': 0.0,
#   'conceptos': 0.0,
#   'componen': 0.0,
#   'exámenes': 0.0,
#   'psicológicos': 0.0,
#   'emite': 0.0,
#   'diagnóstico': 0.0,
#   'individuo': 0.0,
#   'acerca': 9.775540538205506,
#   'consecuencias': 0.0,
#   'tratar': 0.0,
#   'individualizada': 0.0,
#   'bajo': 10.882621619531593,
#   'precepto': 0.0,
#   'impulsa': 0.0,
#   'servicio': 10.319496874519963,
#   'alterno': 0.0,
#   'tradicional': 0.0,
#   'ofertado': 0.0,
#   'educación': 10.17835030752565,
#   'presencial': 0.0,
#   'distancia': 0.0,
#   'estudiantes': 0.0,
#   'trata': 10.484137701868928,
#   'distinción': 0.0,
#   'viabilidad': 0.0,
#   'desarrollo': 10.786800443913076,
#   'comprobación': 0.0,
#   'experimental': 0.0,
#   'lleva': 9.949750717005767,
#   'cabo': 10.131618645361376,
#   'propio': 10.518105462931352,
#   'dominio': 0.0,
#   'basada': 0.0,
#   'web': 0.0,
#   'verificar': 0.0,
#   'tesis': 0.0,
#   'crea': 0.0,
#   'prototipo': 0.0,
#   'basado': 0.0,
#   'mapas': 0.0,
#   'cognitivos': 0.0,
#   'parte': 11.910022323407876,
#   'conocimiento': 9.8171668460696,
#   'específico': 0.0,
#   'muestra': 9.931248623321519,
#   'voluntarios': 0.0,
#   'organiza': 0.0,
#   'dos': 12.339024495252145,
#   'grupos': 10.235054922800046,
#   'primer': 11.155078405801317,
#   'grupo': 11.088124620555321,
#   'recibe': 0.0,
#   'soporte': 0.0,
#   'mientras': 11.32212808969523,
#   'cuenta': 11.087788121064543,
#   'respaldo': 0.0,
#   'final': 10.71263840885238,
#   'experimento': 0.0,
#   'comparan': 0.0,
#   'alcances': 0.0,
#   'logrados': 0.0,
#   'identificar': 0.0,
#   'ventaja': 0.0},
#  'Justificacion16': {'tomando': 0.0,
#   'cuenta': 11.087788121064543,
#   'revisión': 0.0,
#   'hizo': 10.814423975648358,
#   'arte': 10.245835351328815,
#   'generalizando': 0.0,
#   'problema': 10.603982670758612,
#   'clasificación': 0.0,
#   'tipo': 10.94387026564006,
#   'dominios': 0.0,
#   'diagnóstico': 0.0,
#   'médico': 9.80272754938498,
#   'justificación': 0.0,
#   'siguiente': 10.161650696951378,
#   'existe': 10.232035618540193,
#   'necesidad': 10.154207359620441,
#   'desarrollar': 0.0,
#   'algoritmo': 0.0,
#   'aprendizaje': 0.0,
#   'inductivo': 0.0,
#   'permita': 0.0,
#   'resolver': 0.0,
#   'problemas': 10.675792433881902,
#   'binaria': 0.0,
#   'partir': 10.52615861929175,
#   'conjuntos': 0.0,
#   'datos': 10.240066926275098,
#   'balanceados': 0.0,
#   'alcanzando': 0.0,
#   'consenso': 0.0,
#   'apropiado': 0.0,
#   'precisión': 0.0,
#   'comprensibilidad': 0.0,
#   'lado': 10.764582648942334,
#   'extracción': 0.0,
#   'conocimiento': 9.8171668460696,
#   'útil': 0.0,
#   'médicos': 0.0,
#   'puede': 11.990518968113976,
#   'ayudar': 0.0,
#   'predecir': 0.0,
#   'incidencia': 0.0,
#   'algún': 10.47908916924103,
#   'enfermedad': 9.84834475303892,
#   'representaría': 0.0,
#   'oportunidad': 0.0,
#   'aplicar': 0.0,
#   'tiempo': 11.782158393753479,
#   'tratamiento': 9.904986428659864,
#   'capaz': 9.675645480440364,
#   'evitar': 9.979846560634877,
#   'eliminar': 0.0,
#   'disminuir': 0.0,
#   'cierto': 10.544788654372462,
#   'grado': 9.619000370980867,
#   'aparición': 0.0},
#  'Justificacion17': {'tesis': 0.0,
#   'trata': 10.484137701868928,
#   'planificación': 0.0,
#   'sistemas': 9.580799870885532,
#   'tiempo': 11.782158393753479,
#   'real': 10.469426166355031,
#   'utilizando': 0.0,
#   'multiprocesador': 0.0,
#   'memoria': 9.745839095947058,
#   'compartida': 0.0,
#   'principal': 10.002155724332829,
#   'motivación': 0.0,
#   'iniciar': 0.0,
#   'investigación': 10.165890277802454,
#   'fundamentada': 0.0,
#   'plan': 10.011399809730523,
#   'estratégico': 0.0,
#   'departamento': 0.0,
#   'trabajo': 11.257749304074707,
#   'departament': 0.0,
#   'denginyeria': 0.0,
#   'informtica': 0.0,
#   'i': 9.85114107216392,
#   'matemtiques': 0.0,
#   'universitat': 0.0,
#   'rovira': 0.0,
#   'virgili': 0.0,
#   'universidad': 10.13281196292542,
#   'ubicada': 0.0,
#   'entorno': 0.0,
#   'geográfico': 0.0,
#   'instalaciones': 0.0,
#   'industriales': 0.0,
#   'entornos': 0.0,
#   'críticos': 0.0,
#   'abundan': 0.0,
#   'refinerías': 0.0,
#   'petróleo': 0.0,
#   'industrias': 0.0,
#   'petroquímicas': 0.0,
#   'diversas': 9.533582619826515,
#   'centrales': 0.0,
#   'nucleares': 0.0,
#   'etc': 10.22951254915098,
#   'así': 11.95533305200011,
#   'líneas': 0.0,
#   'principalmente': 0.0,
#   'enfocadas': 0.0,
#   'tiemporeal': 0.0,
#   'parte': 11.910022323407876,
#   'docente': 0.0,
#   'investigadora': 0.0,
#   'referente': 0.0,
#   'teoría': 9.542158939916048,
#   'monoprocesador': 0.0,
#   'consolidada': 0.0,
#   'distribuidos': 0.0,
#   'abundante': 0.0,
#   'bibliografía': 0.0,
#   'principio': 10.256816906223763,
#   'apenas': 10.103976413285531,
#   'encontraban': 0.0,
#   'referencias': 0.0,
#   'debido': 9.97011763483389,
#   'enormes': 0.0,
#   'problemas': 10.675792433881902,
#   'conlleva': 0.0,
#   'praxis': 0.0,
#   'utilizaba': 0.0,
#   'si': 12.699182263490384,
#   'monoprocesadores': 0.0,
#   'independientes': 0.0,
#   'sistema': 10.964917050076522,
#   'distribuido': 0.0,
#   'recientemente': 0.0,
#   'arquitecturas': 0.0,
#   'ido': 0.0,
#   'popularizando': 0.0,
#   'uso': 10.212258189817774,
#   'va': 11.143281065776831,
#   'ordenadores': 0.0,
#   'personales': 0.0,
#   'grandes': 10.865936416391367,
#   'servidores': 0.0,
#   'computadores': 0.0,
#   'pasando': 0.0,
#   'empotrados': 0.0,
#   'límites': 0.0,
#   'actuales': 0.0,
#   'hardware': 0.0,
#   'fácil': 9.752955318231582,
#   'menor': 10.091708341261072,
#   'coste': 0.0,
#   'incrementar': 0.0,
#   'capacidad': 10.17458282138351,
#   'cálculo': 0.0,
#   'realizarlo': 0.0,
#   'procesador': 0.0,
#   'equivalente': 0.0,
#   'apareciendo': 0.0,
#   'diversos': 9.593628035139645,
#   'chips': 0.0,
#   'multicore': 0.0,
#   'chiplevel': 0.0,
#   'multiprocessors': 0.0,
#   'cmp': 0.0,
#   'fabricantes': 0.0,
#   'procesadores': 0.0,
#   'mayor': 11.409407694857888,
#   'volumen': 0.0,
#   'intel': 0.0,
#   'amd': 0.0,
#   'primero': 10.49769798523605,
#   'lanzaron': 0.0,
#   'mercado': 10.453831921962378,
#   'dos': 12.339024495252145,
#   'ejemplo': 10.855203341628478,
#   'athlon': 0.0,
#   'x': 0.0,
#   'core': 0.0,
#   'duo': 0.0,
#   'actualidad': 0.0,
#   'frecuentes': 0.0,
#   'cuatro': 10.943234088337201,
#   'quadcore': 0.0,
#   'opteron': 0.0,
#   'xeon': 0.0,
#   'tabla': 0.0,
#   'resumen': 0.0,
#   'aprecia': 0.0,
#   'gran': 11.580499997756885,
#   'evolución': 0.0,
#   'últimos': 10.394793908855744,
#   'años': 12.221094254105662},
#  'Justificacion18': {'evidencias': 0.0,
#   'apoyan': 0.0,
#   'propuesta': 9.604407435131979,
#   'indexación': 0.0,
#   'estudiado': 0.0,
#   'unidades': 0.0,
#   'óptimas': 0.0,
#   'palabras': 10.41885285634415,
#   'mientras': 11.32212808969523,
#   'traducción': 0.0,
#   'mejor': 11.255643264909532,
#   'emplear': 0.0,
#   'grandes': 10.865936416391367,
#   'verdejo': 0.0,
#   'et': 0.0,
#   'uso': 10.212258189817774,
#   'individuales': 0.0,
#   'traducir': 0.0,
#   'resuelve': 0.0,
#   'problema': 10.603982670758612,
#   'ambiguedad': 0.0,
#   'semántica': 0.0,
#   'estadística': 0.0,
#   'coocurrencia': 0.0,
#   'términos': 9.526537012326164,
#   'permite': 9.883641924315421,
#   'realizar': 9.860893154903707,
#   'traducciones': 0.0,
#   'fiables': 0.0,
#   'ballesteros': 0.0,
#   'and': 0.0,
#   'croft': 0.0,
#   'simple': 0.0,
#   'utilización': 0.0,
#   'diccionarios': 0.0,
#   'aplicarla': 0.0,
#   'sintagmas': 0.0,
#   'nominales': 0.0,
#   'va': 11.143281065776831,
#   'mantener': 9.73790511174645,
#   'característica': 0.0,
#   'recordemos': 0.0,
#   'sintagma': 0.0,
#   'nominal': 0.0,
#   'compone': 0.0,
#   'varios': 10.472063081843023,
#   'contenido': 9.647368744540465,
#   'semántico': 0.0,
#   'claro': 10.451290991423688,
#   'usuario': 0.0,
#   'proporcionará': 0.0,
#   'información': 10.655445946975886,
#   'efectos': 9.812084729062784,
#   'interacción': 0.0,
#   'estadístico': 0.0,
#   'próximos': 0.0,
#   'hace': 11.64839123547892,
#   'diversos': 9.593628035139645,
#   'estudios': 10.043727641450573,
#   'penas': 0.0,
#   'dennis': 0.0,
#   'muestran': 0.0,
#   'forma': 11.484165843298804,
#   'natural': 9.959206041292472,
#   'usuarios': 0.0,
#   'refinar': 0.0,
#   'consulta': 0.0,
#   'representan': 0.0,
#   'conceptos': 0.0,
#   'clara': 0.0,
#   'mayor': 11.409407694857888,
#   'aislados': 0.0,
#   'además': 11.321474360388509,
#   'determinación': 0.0,
#   'índices': 0.0,
#   'puede': 11.990518968113976,
#   'hacerse': 0.0,
#   'manera': 10.97050596961306,
#   'eficiente': 0.0},
#  'Justificacion19': {'estructuras': 0.0,
#   'metálicas': 0.0,
#   'usadas': 0.0,
#   'industria': 9.674200166461429,
#   'transporte': 0.0,
#   'tales': 9.70418259070176,
#   'bastidores': 0.0,
#   'pared': 0.0,
#   'piso': 0.0,
#   'vehículos': 0.0,
#   'automotores': 0.0,
#   'sometidas': 0.0,
#   'cargas': 0.0,
#   'cíclicas': 0.0,
#   'vida': 11.723923557900767,
#   'servicio': 10.319496874519963,
#   'induciendo': 0.0,
#   'aparición': 0.0,
#   'grietas': 0.0,
#   'fatiga': 0.0,
#   'soldadas': 0.0,
#   'aleaciones': 0.0,
#   'aluminio': 0.0,
#   'tratables': 0.0,
#   'térmicamente': 0.0,
#   'riesgo': 9.756784073343919,
#   'grieta': 0.0,
#   'probable': 0.0,
#   'debido': 9.97011763483389,
#   'heterogeneidad': 0.0,
#   'propiedades': 0.0,
#   'mecánicas': 0.0,
#   'zonas': 9.66007751636045,
#   'comprenden': 0.0,
#   'unión': 9.995747630961425,
#   'anterior': 10.250970378105945,
#   'surge': 0.0,
#   'necesidad': 10.154207359620441,
#   'realizar': 9.860893154903707,
#   'uniones': 0.0,
#   'experimentales': 0.0,
#   'soldaduras': 0.0,
#   'permitan': 0.0,
#   'retardar': 0.0,
#   'crecimiento': 9.86276971925757,
#   'tipo': 10.94387026564006,
#   'ello': 10.928955507166235,
#   'establecen': 0.0,
#   'estudios': 10.043727641450573,
#   'comparativos': 0.0,
#   'dos': 12.339024495252145,
#   'procesos': 0.0,
#   'ejemplo': 10.855203341628478,
#   'proceso': 10.780288735123806,
#   'convencional': 0.0,
#   'soldadura': 0.0,
#   'arco': 0.0,
#   'eléctrico': 0.0,
#   'material': 9.61012269694885,
#   'aporte': 0.0,
#   'gas': 0.0,
#   'protección': 0.0,
#   'implementación': 0.0,
#   'técnica': 9.699411063939143,
#   'indirecto': 0.0,
#   'modificado': 0.0,
#   'busca': 9.634300062720511,
#   'identificar': 0.0,
#   'aplicación': 0.0,
#   'permita': 0.0,
#   'incrementar': 0.0,
#   'componentes': 0.0},
#  'Justificacion20': {'literatura': 0.0,
#   'gran': 11.580499997756885,
#   'diversidad': 0.0,
#   'controladores': 0.0,
#   'adaptativos': 0.0,
#   'usan': 0.0,
#   'redes': 0.0,
#   'neuronales': 0.0,
#   'embargo': 11.099166054037244,
#   'importante': 10.787193107312595,
#   'desarrollo': 10.786800443913076,
#   'nuevos': 10.197201397219628,
#   'mejor': 11.255643264909532,
#   'desempeño': 0.0,
#   'menor': 10.091708341261072,
#   'tiempo': 11.782158393753479,
#   'convergencia': 0.0,
#   'confiables': 0.0,
#   'sistemas': 9.580799870885532,
#   'difíciles': 0.0,
#   'modelar': 0.0,
#   'dispone': 0.0,
#   'modelo': 9.810330054049878,
#   'dinámico': 0.0,
#   'pueden': 11.06490248157219,
#   'ser': 12.358467499081977,
#   'objeto': 9.96815106586185,
#   'estudio': 10.262559621074582,
#   'usando': 0.0,
#   'identificación': 0.0,
#   'mismo': 11.781011788724976,
#   'caso': 11.482249739201768,
#   'incertidumbres': 0.0,
#   'dinámicas': 0.0,
#   'modeladas': 0.0,
#   'aproximadas': 0.0,
#   'control': 10.135352957662207,
#   'neuronal': 0.0,
#   'puede': 11.990518968113976,
#   'aplicarse': 0.0,
#   'robóticos': 0.0,
#   'industria': 9.674200166461429,
#   'ayudaría': 0.0,
#   'reducción': 0.0,
#   'tiempos': 9.872719018864492,
#   'procesos': 0.0,
#   'productivos': 0.0,
#   'mantenimiento': 0.0,
#   'dado': 10.28506972018096,
#   'cambian': 0.0,
#   'debido': 9.97011763483389,
#   'desgaste': 0.0,
#   'mecanismos': 0.0,
#   'factores': 0.0,
#   'externos': 0.0,
#   'adhesión': 0.0,
#   'polvo': 0.0,
#   'suciedad': 0.0,
#   'usar': 0.0,
#   'humanorobóticos': 0.0,
#   'finalidad': 0.0,
#   'ayudar': 0.0,
#   'personas': 11.088430430955258,
#   'discapacidades': 0.0,
#   'físicas': 0.0,
#   'complejas': 0.0,
#   'robots': 0.0,
#   'bípedos': 0.0,
#   'similares': 0.0,
#   'investigación': 10.165890277802454,
#   'usada': 0.0,
#   'campo': 10.334457951052654,
#   'educativo': 0.0,
#   'referencia': 0.0,
#   'investigaciones': 0.0,
#   'área': 9.640107772607312,
#   'aplicada': 0.0},
#  'Justificacion21': {'ultimas': 0.0,
#   'décadas': 0.0,
#   'constatado': 0.0,
#   'creciente': 0.0,
#   'interés': 10.237062739615967,
#   'presentan': 0.0,
#   'robots': 0.0,
#   'caminantes': 0.0,
#   'punto': 10.937721307268031,
#   'vista': 10.34019289638035,
#   'investigación': 10.165890277802454,
#   'básica': 0.0,
#   'potenciales': 0.0,
#   'aplicaciones': 0.0,
#   'principales': 9.82498532438117,
#   'características': 9.758866322925,
#   'equipados': 0.0,
#   'patas': 0.0,
#   'capacidad': 10.17458282138351,
#   'poder': 11.11095424611632,
#   'desplazarse': 0.0,
#   'amplia': 0.0,
#   'variedad': 0.0,
#   'terrenos': 0.0,
#   'estructurados': 0.0,
#   'particularidad': 0.0,
#   'hace': 11.64839123547892,
#   'atractivos': 0.0,
#   'aplicación': 0.0,
#   'practica': 0.0,
#   'servicios': 10.259307130753884,
#   'requiere': 0.0,
#   'locomoción': 0.0,
#   'terreno': 0.0,
#   'natural': 9.959206041292472,
#   'caracteriza': 0.0,
#   'presentar': 0.0,
#   'superficies': 0.0,
#   'irregulares': 0.0,
#   'diversos': 9.593628035139645,
#   'tipos': 9.588228712314113,
#   'obstáculos': 0.0,
#   'distintas': 9.610859937691332,
#   'pendientes': 0.0,
#   'embargo': 11.099166054037244,
#   'caminar': 0.0,
#   'implica': 0.0,
#   'geometría': 0.0,
#   'propiedades': 0.0,
#   'físicas': 0.0,
#   'elementos': 9.958591078762153,
#   'rodean': 0.0,
#   'robot': 0.0,
#   'desconocidas': 0.0,
#   'variables': 0.0,
#   'necesario': 10.171566227844085,
#   'dotar': 0.0,
#   'estrategia': 0.0,
#   'adapte': 0.0,
#   'comportamiento': 0.0,
#   'respecto': 10.47429759323113,
#   'entorno': 0.0,
#   'si': 12.699182263490384,
#   'bien': 11.782624304024536,
#   'modelo': 9.810330054049878,
#   'puede': 11.990518968113976,
#   'ser': 12.358467499081977,
#   'conocido': 0.0,
#   'precisión': 0.0,
#   'razonable': 0.0,
#   'resulta': 9.928033812954128,
#   'difícil': 10.207621055054725,
#   'obtener': 0.0,
#   'descripción': 0.0,
#   'detallada': 0.0,
#   'especialmente': 9.995656440007505,
#   'respecta': 0.0,
#   'estabilidad': 0.0,
#   'realización': 0.0,
#   'ciclo': 0.0,
#   'gran': 11.580499997756885,
#   'importancia': 10.041900759689755,
#   'consideración': 0.0,
#   'determinada': 0.0,
#   'medida': 10.243560441877241,
#   'influye': 0.0,
#   'manera': 10.97050596961306,
#   'directa': 0.0,
#   'seguridad': 10.492773093561983,
#   'trabajo': 11.257749304074707,
#   'presenta': 9.636588019266876,
#   'planteamiento': 0.0,
#   'estrategias': 0.0,
#   'adaptabilidad': 0.0,
#   'hexápodo': 0.0,
#   'hexpiderix': 0.0,
#   'basadas': 0.0,
#   'geométrico': 0.0,
#   'conocer': 9.98419157995109,
#   'ambiente': 9.852194258148577,
#   'pues': 11.285296870871345,
#   'tan': 11.630450689618431,
#   'solo': 10.37380363296391,
#   'saber': 10.330192163636712,
#   'extremidades': 0.0,
#   'tocando': 0.0,
#   'superficie': 0.0,
#   'posible': 10.801247647790849,
#   'estimar': 0.0,
#   'plano': 0.0,
#   'apoyo': 10.033462628957874,
#   'documento': 0.0,
#   'diseño': 0.0,
#   'simulación': 0.0,
#   'caminante': 0.0,
#   'validación': 0.0,
#   'cada': 11.732526749860027,
#   'realiza': 0.0,
#   'distinto': 0.0,
#   'grado': 9.619000370980867,
#   'inclinación': 0.0,
#   'además': 11.321474360388509,
#   'analiza': 0.0,
#   'estática': 0.0,
#   'postura': 0.0,
#   'criterio': 0.0,
#   'estático': 0.0,
#   'normalizado': 0.0,
#   'peso': 9.775028985632325,
#   'sne': 0.0,
#   'siglas': 0.0,
#   'ingles': 0.0},
#  'Justificacion22': {'trabajo': 11.257749304074707,
#   'tesis': 0.0,
#   'desarrolla': 0.0,
#   'debido': 9.97011763483389,
#   'necesidad': 10.154207359620441,
#   'sistema': 10.964917050076522,
#   'completo': 0.0,
#   'capaz': 9.675645480440364,
#   'predecir': 0.0,
#   'efectos': 9.812084729062784,
#   'indeseables': 0.0,
#   'memoria': 9.745839095947058,
#   'pa': 0.0,
#   'profundidad': 0.0,
#   'órdenes': 0.0,
#   'linealidad': 0.0,
#   'variables': 0.0,
#   'ello': 10.928955507166235,
#   'desarrollan': 0.0,
#   'modelos': 0.0,
#   'polinomiales': 0.0,
#   'basados': 0.0,
#   'truncaciones': 0.0,
#   'series': 0.0,
#   'volterra': 0.0,
#   'wiener': 0.0,
#   'hammerstein': 0.0,
#   'mpm': 0.0,
#   'además': 11.321474360388509,
#   'utilizar': 0.0,
#   'técnicas': 0.0,
#   'aprendizaje': 0.0,
#   'ann': 0.0,
#   'anfis': 0.0,
#   'dentro': 10.943145698360567,
#   'tarjeta': 0.0,
#   'desarrollo': 10.786800443913076,
#   'fpgadsp': 0.0,
#   'técnica': 9.699411063939143,
#   'medición': 0.0,
#   'bajo': 10.882621619531593,
#   'costo': 0.0,
#   'curvas': 0.0,
#   'distorsión': 0.0,
#   'amplitud': 0.0,
#   'fase': 0.0,
#   'controlado': 0.0,
#   'interfaz': 0.0,
#   'gráfica': 0.0,
#   'usuario': 0.0,
#   'gui': 0.0,
#   'permite': 9.883641924315421,
#   'manera': 10.97050596961306,
#   'simple': 0.0,
#   'abrir': 0.0,
#   'mediciones': 0.0,
#   'reales': 0.0,
#   'cualquier': 10.921630653712223,
#   'basado': 0.0,
#   'amam': 0.0,
#   'ampm': 0.0,
#   'obtener': 0.0,
#   'coeficientes': 0.0,
#   'respectivos': 0.0,
#   'obtenidos': 0.0,
#   'través': 10.696751524430846,
#   'método': 0.0,
#   'error': 0.0,
#   'cuadrático': 0.0,
#   'mínimo': 0.0,
#   'lse': 0.0,
#   'niveles': 9.529448434427817,
#   'adecuarse': 0.0,
#   'comportamiento': 0.0,
#   'parte': 11.910022323407876,
#   'principal': 10.002155724332829,
#   'basada': 0.0,
#   'herramienta': 0.0,
#   'diseño': 0.0,
#   'dsp': 0.0,
#   'builder': 0.0,
#   'traducir': 0.0,
#   'programa': 10.422876406962606,
#   'matlabsimulink': 0.0,
#   'vhdl': 0.0,
#   'ahorrando': 0.0,
#   'tiempo': 11.782158393753479,
#   'final': 10.71263840885238,
#   'realiza': 0.0,
#   'comparación': 0.0,
#   'modelado': 0.0,
#   'puro': 0.0,
#   'obtenido': 0.0,
#   'ventaja': 0.0,
#   'simulación': 0.0,
#   'uso': 10.212258189817774,
#   'algoritmos': 0.0,
#   'etapas': 0.0,
#   'linealización': 0.0,
#   'posteriores': 0.0,
#   'trabajos': 0.0,
#   'desarrollados': 0.0,
#   'autor': 9.93672888631593,
#   'probó': 0.0,
#   'eficiencia': 0.0,
#   'fpga': 0.0},
#  'Justificacion23': {'existen': 9.885018036252466,
#   'elementos': 9.958591078762153,
#   'estructurales': 0.0,
#   'mecánicos': 0.0,
#   'utilizados': 0.0,
#   'ingeniería': 0.0,
#   'estructuras': 0.0,
#   'chasis': 0.0,
#   'autos': 0.0,
#   'componentes': 0.0,
#   'aéreos': 0.0,
#   'marinas': 0.0,
#   'válvulas': 0.0,
#   'etc': 10.22951254915098,
#   'fabricados': 0.0,
#   'aleación': 0.0,
#   'aluminio': 0.0,
#   't': 0.0,
#   'fabricación': 0.0,
#   'dichos': 0.0,
#   'requieren': 0.0,
#   'procesos': 0.0,
#   'unión': 9.995747630961425,
#   'soldadura': 0.0,
#   'proceso': 10.780288735123806,
#   'metalúrgico': 0.0,
#   'requiere': 0.0,
#   'entendimiento': 0.0,
#   'comportamiento': 0.0,
#   'material': 9.61012269694885,
#   'producción': 10.304777289233812,
#   'mayoría': 10.452591137512096,
#   'igual': 10.402746539930654,
#   'fundición': 0.0,
#   'metales': 0.0,
#   'altas': 0.0,
#   'temperaturas': 0.0,
#   'hacer': 11.472759505212103,
#   'posible': 10.801247647790849,
#   'materiales': 0.0,
#   'involucrados': 0.0,
#   'presenta': 9.636588019266876,
#   'degradación': 0.0,
#   'propiedades': 0.0,
#   'mecánicas': 0.0,
#   'debido': 9.97011763483389,
#   'efecto': 10.17385814221302,
#   'térmico': 0.0,
#   'además': 11.321474360388509,
#   'alta': 9.97007085667928,
#   'solubilidad': 0.0,
#   'hidrógeno': 0.0,
#   'líquido': 0.0,
#   'ocurre': 0.0,
#   'solidificación': 0.0,
#   'queda': 10.069001991013701,
#   'atrapado': 0.0,
#   'generando': 0.0,
#   'porosidad': 0.0,
#   'sabe': 10.353224696920396,
#   'reducir': 0.0,
#   'técnica': 9.699411063939143,
#   'aeim': 0.0,
#   'utilizar': 0.0,
#   'solo': 10.37380363296391,
#   'paso': 10.460843646427818,
#   'reduce': 0.0,
#   'microestructura': 0.0,
#   'final': 10.71263840885238,
#   'caso': 11.482249739201768,
#   'unir': 0.0,
#   'encuentra': 10.078826453902199,
#   'solubilización': 0.0,
#   'envejecido': 0.0,
#   'artificial': 0.0,
#   'alcanza': 0.0,
#   'elevadas': 0.0,
#   'obtiene': 0.0,
#   'sobreenvejecido': 0.0,
#   'disminuye': 0.0,
#   'embargo': 11.099166054037244,
#   'tratamiento': 9.904986428659864,
#   'reversible': 0.0,
#   'puede': 11.990518968113976,
#   'considerar': 0.0,
#   'alternativa': 0.0,
#   'mejorar': 0.0,
#   'uniones': 0.0,
#   'soldadas': 0.0,
#   'postsoldadura': 0.0,
#   'mejora': 0.0,
#   'aprecia': 0.0,
#   'incremento': 0.0,
#   'resistencia': 0.0,
#   'fatiga': 0.0,
#   'sometidos': 0.0,
#   'cargas': 0.0,
#   'cíclicas': 0.0,
#   'incrementar': 0.0,
#   'retarda': 0.0,
#   'aparición': 0.0,
#   'grietas': 0.0,
#   'anterior': 10.250970378105945,
#   'surge': 0.0,
#   'necesidad': 10.154207359620441,
#   'permitan': 0.0,
#   'aumentar': 0.0,
#   'retardar': 0.0,
#   'crecimiento': 9.86276971925757,
#   'aleaciones': 0.0,
#   'tipo': 10.94387026564006,
#   'implementación': 0.0},
#  'Justificacion24': {'sensores': 0.0,
#   'basados': 0.0,
#   'fibra': 0.0,
#   'óptica': 0.0,
#   'ofrecen': 0.0,
#   'ventajas': 0.0,
#   'tradicionales': 0.0,
#   'tales': 9.70418259070176,
#   'inmunidad': 0.0,
#   'interferencias': 0.0,
#   'electromagnéticas': 0.0,
#   'ultraligeros': 0.0,
#   'pueden': 11.06490248157219,
#   'ser': 12.358467499081977,
#   'empleados': 0.0,
#   'ambientes': 0.0,
#   'altamente': 0.0,
#   'corrosivos': 0.0,
#   'explosivos': 0.0,
#   'uso': 10.212258189817774,
#   'aplicaciones': 0.0,
#   'sensado': 0.0,
#   'remoto': 0.0,
#   'factible': 0.0,
#   'debido': 9.97011763483389,
#   'bajas': 0.0,
#   'pérdidas': 0.0,
#   'señal': 0.0,
#   'fibras': 0.0,
#   'ópticas': 0.0},
#  'Justificacion25': {'ltimos': 0.0,
#   'aos': 0.0,
#   'dedicado': 0.0,
#   'considerable': 0.0,
#   'esfuerzo': 9.62304587173984,
#   'problema': 10.603982670758612,
#   'segmentacin': 0.0,
#   'color': 9.979290515951629,
#   'imgenes': 0.0,
#   'digitales': 0.0,
#   'dada': 0.0,
#   'importancia': 10.041900759689755,
#   'potencial': 0.0,
#   'hace': 11.64839123547892,
#   'mayora': 0.0,
#   'enfoques': 0.0,
#   'publicados': 0.0,
#   'basaba': 0.0,
#   'tcnicas': 0.0,
#   'monocromticas': 0.0,
#   'aplicadas': 0.0,
#   'cada': 11.732526749860027,
#   'componente': 0.0,
#   'imagen': 10.243845088739151,
#   'diferentes': 10.28800137389136,
#   'espacios': 0.0,
#   'rgb': 0.0,
#   'u': 9.678279371339702,
#   'formas': 9.956222307519994,
#   'producir': 0.0,
#   'composicin': 0.0,
#   'inherente': 0.0,
#   'prdida': 0.0,
#   'significativa': 0.0,
#   'informacin': 0.0,
#   'proceso': 10.780288735123806}}

# %% [markdown]
# ## Create the Vocabulary

# %%
voc = obtainVocSingle(TSU_structured)
voc = obtainVocDouble(TSU_structured, Lic_structured)
voc = obtainVoc(TSU_structured, Lic_structured, Masters_structured, Phd_structured)
len(voc)
# Out:
# 10990

# %% [markdown]
# ## Padding (Dimensionate the Vectors based on the size of the Vocabulary)

# %%
# For TSU
twentyPadRFTSU = dimRelFreq(twentyRFTSU, voc)
twentyPadLFTSU = dimRelFreq(twentyLFTSU, voc)
eightyPadRFTSU = dimRelFreq(eightyRFTSU, voc)
eightyPadLFTSU = dimRelFreq(eightyLFTSU, voc)
twentyPadRFTSU['Justificacion2']
eightyPadRFTSU
twentyPadLFTSU
eightyPadLFTSU
# For Lic
twentyPadRFLic = dimRelFreq(twentyRFLic, voc)
twentyPadLFLic = dimRelFreq(twentyLFLic, voc)
eightyPadRFLic = dimRelFreq(eightyRFLic, voc)
eightyPadLFLic = dimRelFreq(eightyLFLic, voc)
twentyPadRFLic
twentyPadLFLic
eightyPadRFLic
eightyPadLFLic
# For Masters
twentyPadRFMasters = dimRelFreq(twentyRFMasters, voc)
twentyPadLFMasters = dimRelFreq(twentyLFMasters, voc)
eightyPadRFMasters = dimRelFreq(eightyRFMasters, voc)
eightyPadLFMasters = dimRelFreq(eightyLFMasters, voc)
# For Phd
twentyPadRFPhd = dimRelFreq(twentyRFPhd, voc)
twentyPadLFPhd = dimRelFreq(twentyLFPhd, voc)
eightyPadRFPhd = dimRelFreq(eightyRFPhd, voc)
eightyPadLFPhd = dimRelFreq(eightyLFPhd, voc)

# %% [markdown]
# ## Concatenate Local and Global Vectors

# %%
# TSU
twentyConTSU = concatenateDictionaries(twentyPadRFTSU, twentyPadLFTSU)
eightyConTSU = concatenateDictionaries(eightyPadRFTSU, eightyPadLFTSU)
twentyConLic = concatenateDictionaries(twentyPadRFLic, twentyPadLFLic)
eightyConLic = concatenateDictionaries(eightyPadRFLic, eightyPadLFLic)
twentyConMasters = concatenateDictionaries(twentyPadRFMasters, twentyPadLFMasters)
eightyConMasters = concatenateDictionaries(eightyPadRFMasters, eightyPadLFMasters)
twentyConPhd = concatenateDictionaries(twentyPadRFPhd, twentyPadLFPhd)
eightyConPhd = concatenateDictionaries(eightyPadRFPhd, eightyPadLFPhd)
np.array((twentyConLic)).sum()
np.array((eightyConLic)).sum()
np.array((twentyConMasters)).sum()
np.array((eightyConMasters)).sum()
np.array((twentyConPhd)).sum()
np.array((eightyConPhd)).sum()
# Out:
# 7449.111882532535

# %% [markdown]
# ## Expand and Classify Data

# %%
# HST and Undergraduate
twentyPOneTL, twentyMOneTL = comData(twentyConTSU, twentyConLic)
eightyPOneTL, eightyMOneTL = comData(eightyConTSU, eightyConLic)
np.array((twentyPOneTL)).sum()
np.array((twentyMOneTL)).sum()
# HST and Masters
twentyPOneTM, twentyMOneTM = comData(twentyConTSU, twentyConMasters)
eightyPOneTM, eightyMOneTM = comData(eightyConTSU, eightyConMasters)
# HST and Phd
twentyPOneTP, twentyMOneTP = comData(twentyConTSU, twentyConPhd)
eightyPOneTP, eightyMOneTP = comData(eightyConTSU, eightyConPhd)
# Undergraduate and Masters
twentyPOneUM, twentyMOneUM = comData(twentyConLic, twentyConMasters)
eightyPOneUM, eightyMOneUM = comData(eightyConLic, eightyConMasters)
# Undergraduate and Phd
twentyPOneUP, twentyMOneUP = comData(twentyConLic, twentyConPhd)
eightyPOneUP, eightyMOneUP = comData(eightyConLic, eightyConPhd)
# Masters and Phd
twentyPOneMP, twentyMOneMP = comData(twentyConMasters, twentyConPhd)
eightyPOneMP, eightyMOneMP = comData(eightyConMasters, eightyConPhd)

# %% [markdown]
# ## Append the Data and Create Classification Vector

# %%
# HST and Undergraduate
TLM_test, tly_test = allTogetherNowDouble(twentyPOneTL, twentyMOneTL)
len(TLM_test)
len(tly_test)
TLM_train, tly_train = allTogetherNowDouble(eightyPOneTL, eightyMOneTL)
len(TLM_train)
len(tly_train)
# HST and Masters
TMM_test, tmy_test = allTogetherNowDouble(twentyPOneTM, twentyMOneTM)
TMM_train, tmy_train = allTogetherNowDouble(eightyPOneTM, eightyMOneTM)
#HST and Phd
TPM_test, tpy_test = allTogetherNowDouble(twentyPOneTP, twentyMOneTP)
TPM_train, tpy_train = allTogetherNowDouble(eightyPOneTP, eightyMOneTP)
#Undergraduate and Masters
UMM_test, umy_test = allTogetherNowDouble(twentyPOneUM, twentyMOneUM)
UMM_train, umy_train = allTogetherNowDouble(eightyPOneUM, eightyMOneUM)
#Undergraduate and PhD
UPM_test, upy_test = allTogetherNowDouble(twentyPOneUP, twentyMOneUP)
UPM_train, upy_train = allTogetherNowDouble(eightyPOneUP, eightyMOneUP)
#Masters and PhD
MPM_test, mpy_test = allTogetherNowDouble(twentyPOneMP, twentyMOneMP)
MPM_train, mpy_train = allTogetherNowDouble(eightyPOneMP, eightyMOneMP)

# %% [markdown]
# # HST and Udergraduate

# %% [markdown]
# ## SVM Classifier

# %%
svclassifier = svm.SVC()
svclassifier.fit(TLM_train, tly_train)

# %%
y_pred = svclassifier.predict(TLM_test)
print("The accuracy value for the SVM classifier is: {} %".format(obtain_accuracy(tly_test, y_pred)*100))
# Out:
# The accuracy value for the SVM classifier is: 64.70588235294117 %

# %% [markdown]
# ## K Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors = 3)
neigh.fit(TLM_train, tly_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = neigh.predict(TLM_test)
print('The accurracy value for the KNN classifier is: {} %'.format(obtain_accuracy(tly_test, y_pred)*100))
# Out:
# The accurracy value for the KNN classifier is: 53.619909502262445 %

# %% [markdown]
# ## Multilayer Perceptron

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha = 1e-5, hidden_layer_sizes=(5, 2), random_state=1)
clf.fit(TLM_train, tly_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(5, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred = clf.predict(TLM_test)
print("The accuracy value for the Multilayer Perceptron is: {} %".format(obtain_accuracy(tly_test, y_pred)*100))
# Out:
# The accuracy value for the Multilayer Perceptron is: 63.87631975867269 %

# %% [markdown]
# # HST and Masters

# %% [markdown]
# ## SVM Classifier

# %%
svclassifier = svm.SVC()
svclassifier.fit(TMM_train, tmy_train)

# %%
y_pred = svclassifier.predict(TMM_test)
print("The accuracy value for the SVM classifier is: {} %".format(obtain_accuracy(tly_test, y_pred)*100))
# Out:
# The accuracy value for the SVM classifier is: 64.70588235294117 %

# %% [markdown]
# ## K Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors = 3)
neigh.fit(TMM_train, tmy_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = neigh.predict(TMM_test)
print('The accurracy value for the KNN classifier is: {} %'.format(obtain_accuracy(tly_test, y_pred)*100))
# Out:
# The accurracy value for the KNN classifier is: 53.619909502262445 %

# %% [markdown]
# ## Multilayer Perceptron

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha = 1e-5, hidden_layer_sizes=(5, 2), random_state=1)
clf.fit(TMM_train, tmy_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(5, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred = clf.predict(TMM_test)
print("The accuracy value for the Multilayer Perceptron is: {} %".format(obtain_accuracy(tly_test, y_pred)*100))
# Out:
# The accuracy value for the Multilayer Perceptron is: 63.87631975867269 %

# %% [markdown]
# # HST and PhD

# %% [markdown]
# ## SVM Classifier

# %%
svclassifier = svm.SVC()
svclassifier.fit(TPM_train, tpy_train)

# %%
y_pred = svclassifier.predict(TPM_test)
print("The accuracy value for the SVM classifier is: {} %".format(obtain_accuracy(tly_test, y_pred)*100))
# Out:
# The accuracy value for the SVM classifier is: 64.70588235294117 %

# %% [markdown]
# ## K Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors = 3)
neigh.fit(TPM_train, tpy_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = neigh.predict(TPM_test)
print('The accurracy value for the KNN classifier is: {} %'.format(obtain_accuracy(tly_test, y_pred)*100))
# Out:
# The accurracy value for the KNN classifier is: 53.619909502262445 %

# %% [markdown]
# ## Multilayer Perceptron

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha = 1e-5, hidden_layer_sizes=(5, 2), random_state=1)
clf.fit(TPM_train, tpy_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(5, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred = clf.predict(TPM_test)
print("The accuracy value for the Multilayer Perceptron is: {} %".format(obtain_accuracy(tly_test, y_pred)*100))
# Out:
# The accuracy value for the Multilayer Perceptron is: 63.87631975867269 %

# %% [markdown]
# # Undergraduate and Masters

# %% [markdown]
# ## SVM Classifier

# %%
svclassifier = svm.SVC()
svclassifier.fit(UMM_train, umy_train)

# %%
y_pred = svclassifier.predict(UMM_test)
print("The accuracy value for the SVM classifier is: {} %".format(obtain_accuracy(tly_test, y_pred)*100))
# Out:
# The accuracy value for the SVM classifier is: 64.70588235294117 %

# %% [markdown]
# ## K Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors = 3)
neigh.fit(UMM_train, umy_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = neigh.predict(UMM_test)
print('The accurracy value for the KNN classifier is: {} %'.format(obtain_accuracy(tly_test, y_pred)*100))
# Out:
# The accurracy value for the KNN classifier is: 53.619909502262445 %

# %% [markdown]
# ## Multilayer Perceptron

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha = 1e-5, hidden_layer_sizes=(5, 2), random_state=1)
clf.fit(UMM_train, umy_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(5, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred = clf.predict(UMM_test)
print("The accuracy value for the Multilayer Perceptron is: {} %".format(obtain_accuracy(tly_test, y_pred)*100))
# Out:
# The accuracy value for the Multilayer Perceptron is: 63.87631975867269 %

# %% [markdown]
# # Undergraduate and PhD

# %% [markdown]
# ## SVM Classifier

# %%
svclassifier = svm.SVC()
svclassifier.fit(UPM_train, upy_train)

# %%
y_pred = svclassifier.predict(UPM_test)
print("The accuracy value for the SVM classifier is: {} %".format(obtain_accuracy(upy_test, y_pred)*100))
# Out:
# The accuracy value for the SVM classifier is: 64.70588235294117 %

# %% [markdown]
# ## K Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors = 3)
neigh.fit(UPM_train, upy_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = neigh.predict(UPM_test)
print('The accurracy value for the KNN classifier is: {} %'.format(obtain_accuracy(upy_test, y_pred)*100))
# Out:
# The accurracy value for the KNN classifier is: 53.619909502262445 %

# %% [markdown]
# ## Multilayer Perceptron

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha = 1e-5, hidden_layer_sizes=(5, 2), random_state=1)
clf.fit(UPM_train, upy_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(5, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred = clf.predict(UPM_test)
print("The accuracy value for the Multilayer Perceptron is: {} %".format(obtain_accuracy(upy_test, y_pred)*100))
# Out:
# The accuracy value for the Multilayer Perceptron is: 63.87631975867269 %

# %% [markdown]
# # Masters and PhD

# %% [markdown]
# ## SVM Classifier

# %%
svclassifier = svm.SVC()
svclassifier.fit(UPM_train, upy_train)

# %%
y_pred = svclassifier.predict(UPM_test)
print("The accuracy value for the SVM classifier is: {} %".format(obtain_accuracy(upy_test, y_pred)*100))
# Out:
# The accuracy value for the SVM classifier is: 64.70588235294117 %

# %% [markdown]
# ## K Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors = 3)
neigh.fit(UPM_train, upy_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = neigh.predict(UPM_test)
print('The accurracy value for the KNN classifier is: {} %'.format(obtain_accuracy(upy_test, y_pred)*100))
# Out:
# The accurracy value for the KNN classifier is: 53.619909502262445 %

# %% [markdown]
# ## Multilayer Perceptron

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha = 1e-5, hidden_layer_sizes=(5, 2), random_state=1)
clf.fit(UPM_train, upy_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(5, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred = clf.predict(UPM_test)
print("The accuracy value for the Multilayer Perceptron is: {} %".format(obtain_accuracy(upy_test, y_pred)*100))
# Out:
# The accuracy value for the Multilayer Perceptron is: 63.87631975867269 %

# %% [markdown]
# # Masters and PhD

# %% [markdown]
# ## SVM

# %% [markdown]
# ## KNN

# %% [markdown]
# ## Multilayer Perceptron
